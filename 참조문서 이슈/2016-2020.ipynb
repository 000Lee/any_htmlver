# %%
# references가 존재하는 문서들의 sourceId 숫자를 뽑는 코드
import json
import re

result = []

# cmds 파일 읽기 (전체 경로 사용)
with open(r"C:\Users\LEEJUHWAN\Downloads\documents_2020_imgFixed.cmds", 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        
        # addDocument로 시작하는 줄만 처리
        if line.startswith('addDocument '):
            # "addDocument " 이후의 JSON 부분만 추출
            json_str = line.replace('addDocument ', '', 1)
            
            try:
                data = json.loads(json_str)
                
                # references가 존재하고 비어있지 않은 경우
                if 'references' in data and data['references']:
                    # sourceId에서 숫자만 추출
                    source_id = data['sourceId']  # 예: "doc_18876965_02"
                    match = re.search(r'doc_(\d+)_\d+', source_id)
                    if match:
                        number = match.group(1)  # "18876965"
                        result.append(number)
            except json.JSONDecodeError:
                # JSON 파싱 에러 시 스킵
                continue

print(f"추출된 숫자 개수: {len(result)}")
print(result)
# Out:
# 추출된 숫자 개수: 217
# ['2009508', '2009576', '2009625', '2009645', '2009740', '2981791', '3009758', '3010538', '3052701', '3071392', '3079097', '3076077', '3085548', '3085569', '3085559', '3088931', '3094529', '3091905', '3140656', '3172683', '3181517', '3183490', '3185859', '3190547', '3196683', '3222958', '3242908', '3248394', '3252498', '3266610', '3269765', '3273511', '3292325', '3316750', '3315791', '4205516', '5085502', '5124421', '5586779', '5620417', '5629439', '5641421', '5777742', '5807329', '5828386', '5830858', '5864443', '5897821', '5898072', '5913576', '5951790', '5966323', '5967517', '6055814', '6055871', '6089548', '6091980', '6115443', '6135443', '6143218', '6156934', '6194767', '6216976', '6216799', '6225013', '6227259', '6243392', '6244212', '6278118', '6278170', '6297708', '6315207', '6379123', '6383908', '6536129', '6536155', '6552040', '6563472', '6608648', '6653909', '6709462', '6729487', '6737224', '6760318', '6769794', '6768323', '6776305', '6783870', '6795885', '6821505', '6860052', '6886098', '6886123', '6935861', '6939929', '6977202', '6998842', '7005368', '7037040', '7038637', '7050680', '7052272', '7082945', '7083041', '7149391', '7153668', '7152006', '7153704', '7213965', '7213996', '7249682', '7257915', '7270702', '7280893', '7277739', '7288154', '7288080', '7343314', '7344084', '7356060', '7371392', '7376466', '7422768', '7428047', '7486008', '7512428', '7510482', '7533724', '7535328', '7561264', '7561282', '7561362', '7594499', '7687518', '7691525', '7734467', '7768806', '7768823', '7768865', '7796686', '7858931', '7858043', '7894886', '7906330', '7909555', '7914912', '7943472', '7941010', '7979431', '8012657', '8035743', '8063628', '8063652', '8110729', '8126421', '8212256', '8250987', '8301473', '8301520', '8419273', '8431395', '8439528', '8439560', '8529220', '8553635', '8562669', '8585294', '8639438', '8639474', '8782475', '8782556', '8782520', '8780710', '8819556', '8924130', '8922484', '8930204', '8953794', '8971258', '8972447', '9196803', '9196793', '9271709', '9370308', '9421378', '9477610', '9521839', '9654467', '9654473', '9674026', '9798406', '9822667', '9853610', '9994218', '10002753', '10019691', '10121473', '10514006', '10630649', '10762617', '10806678', '10827785', '10921534', '10934514', '11861495', '11859413', '12723088', '13020288', '13477815', '13611717', '13864321', '14160239', '14379678', '14832231', '14956840', '15078648', '15155817']
