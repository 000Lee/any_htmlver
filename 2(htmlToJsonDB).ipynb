# %%
pip install beautifulsoup4 pymysql lxml
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\leejuhwan\miniconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: pymysql in c:\users\leejuhwan\miniconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: lxml in c:\users\leejuhwan\miniconda3\lib\site-packages (6.0.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\leejuhwan\miniconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\leejuhwan\miniconda3\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# endYear 컬럼 추가해서 여러 기간 폴더 데이터를 하나의 테이블에 구분해서 저장할 수 있게 변경

# + type이 합의인것만 - AGREEMENT로 변경
# 디비 저장 오류 수정 

import os
import json
import re
from datetime import datetime
from bs4 import BeautifulSoup
import pymysql
from pathlib import Path

class ApprovalDocParser:
    def __init__(self, base_path):
        self.base_path = base_path
        
    def extract_source_id(self, filename):
        """파일명에서 마지막 숫자 추출"""
        numbers = re.findall(r'\d+', filename)
        return numbers[-1] if numbers else None
    
    def parse_datetime_to_unix(self, date_str):
        """날짜 문자열을 Unix timestamp(밀리초)로 변환"""
        try:
            dt = datetime.strptime(date_str.strip(), "%Y-%m-%d %H:%M:%S")
            return int(dt.timestamp() * 1000)
        except:
            return None
    
    def extract_person_info(self, text):
        """이름/직책/부서 형식에서 정보 추출"""
        text = re.sub(r'\d+', '', text).strip()
        parts = text.split('/')
        if len(parts) >= 3:
            return {
                'name': parts[0].strip(),
                'positionName': parts[1].strip(),
                'deptName': parts[2].strip()
            }
        return None
    
    def parse_html(self, html_path):
        """HTML 파일 파싱"""
        with open(html_path, 'r', encoding='utf-8') as f:
            soup = BeautifulSoup(f.read(), 'html.parser')
        
        filename = os.path.basename(html_path)
        source_id = self.extract_source_id(filename)
        
        doc_num_elem = soup.find('p', class_='team')
        doc_num = doc_num_elem.get_text(strip=True) if doc_num_elem else ""
        
        references_elem = soup.find('span', class_='disInline o-i-min-fileList')
        references = []
        if references_elem:
            next_elem = references_elem.find_next_sibling()
            if next_elem:
                references = next_elem.get_text(strip=True)
            else:
                parent = references_elem.parent
                references = parent.get_text(strip=True)
        
        title_elem = soup.find('title')
        title = title_elem.get_text(strip=True) if title_elem else ""
        
        attaches = []
        verti_tops = soup.find_all('span', class_='verti_Top')
        for vt in verti_tops:
            a_tag = vt.find('a')
            if a_tag and a_tag.get('href'):
                attaches.append({
                    'name': a_tag.get_text(strip=True),
                    'path': a_tag.get('href')
                })
        
        user_spans = soup.find_all('span', class_='user')
        drafter = {}
        if user_spans:
            first_user = user_spans[0]
            name_elem = first_user.find('span', class_='F_12_black_b')
            if name_elem:
                info = self.extract_person_info(name_elem.get_text(strip=True))
                if info:
                    drafter = {
                        'positionName': info['positionName'],
                        'deptName': info['deptName'],
                        'name': info['name'],
                        'emailId': '',
                        'deptCode': ''
                    }
        
        created_at = None
        if user_spans:
            date_elem = user_spans[0].find('span', class_='F_11_gray')
            if date_elem:
                created_at = self.parse_datetime_to_unix(date_elem.get_text(strip=True))
        
        referrers = []
        ref_th = soup.find('th', string=lambda s: s and '참조' in s)
        if ref_th:
            ref_td = ref_th.find_next_sibling('td')
            if ref_td:
                ref_text = ref_td.get_text(strip=True)
                ref_list = re.split(r'[,\s]+', ref_text)
                for ref in ref_list:
                    if ref:
                        info = self.extract_person_info(ref)
                        if info:
                            referrers.append({
                                'name': info['name'],
                                'empNo': '',
                                'deptCode': ''
                            })
        
        # 결재선 영역에서 "합의"인 사람들의 이름 추출
        agreement_names = []
        appr_line_area = soup.find('div', id='apprLineArea')
        if appr_line_area:
            red_spans = appr_line_area.find_all('span', class_='red')
            for red_span in red_spans:
                if '합의' in red_span.get_text(strip=True):
                    # red span의 부모 li의 이전 형제 li에서 이름 찾기
                    parent_li = red_span.find_parent('li')
                    if parent_li:
                        prev_li = parent_li.find_previous_sibling('li')
                        if prev_li:
                            name_text = prev_li.get_text(strip=True)
                            # 이름만 추출 (숫자 제거 등)
                            if name_text:
                                agreement_names.append(name_text)
        
        activities = []
        for idx, user_span in enumerate(user_spans):
            name_elem = user_span.find('span', class_='F_12_black_b')
            date_elem = user_span.find('span', class_='F_11_gray')
            
            if name_elem:
                info = self.extract_person_info(name_elem.get_text(strip=True))
                if info:
                    action_comment = ""
                    next_elem = user_span.next_sibling
                    while next_elem:
                        if hasattr(next_elem, 'name') and next_elem.name == 'div':
                            action_comment = next_elem.get_text(strip=True)
                            break
                        next_elem = next_elem.next_sibling
                    
                    # 기본 타입 설정
                    action_type = 'DRAFT' if idx == 0 else 'APPROVAL'
                    
                    # 이 사람이 합의자 리스트에 있으면 AGREEMENT로 변경
                    if info['name'] in agreement_names:
                        action_type = 'AGREEMENT'
                    
                    activities.append({
                        'positionName': info['positionName'],
                        'deptName': info['deptName'],
                        'actionLogType': action_type,
                        'name': info['name'],
                        'emailId': '',
                        'type': action_type,
                        'actionDate': self.parse_datetime_to_unix(date_elem.get_text(strip=True)) if date_elem else None,
                        'deptCode': '',
                        'actionComment': action_comment
                    })
        
        result = {
            'sourceId': source_id,
            'docNum': doc_num,
            'references': references,
            'docType': 'DRAFT',
            'title': title,
            'attaches': attaches,
            'drafter': drafter,
            'createdAt': created_at,
            'docBody': '',
            'docStatus': 'COMPLETE',
            'referrers': referrers,
            'activities': activities,
            'formName': '',
            'isPublic': False
        }
        
        return result
    
    def process_all_files(self):
        """모든 HTML 파일 처리"""
        all_results = []
        approval_path = Path(self.base_path) / '결재'
        
        if not approval_path.exists():
            print(f"경로를 찾을 수 없습니다: {approval_path}")
            return all_results
            
        html_files = list(approval_path.rglob('*.html'))
        # html_files = list(approval_path.rglob('*.html'))[:10]
        print(f"총 {len(html_files)}개의 HTML 파일을 찾았습니다.")
        
        for idx, html_file in enumerate(html_files, 1):
            try:
                print(f"처리 중... [{idx}/{len(html_files)}] {html_file.name}")
                result = self.parse_html(html_file)
                all_results.append(result)
            except Exception as e:
                print(f"오류 발생 ({html_file.name}): {e}")
        
        return all_results
    
    def save_to_json(self, data, output_path):
        """JSON 파일로 저장"""
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)
        print(f"JSON 파일 저장 완료: {output_path}")
    
    def save_to_mariadb(self, data, db_config, end_year):
        """MariaDB에 저장 - 안정성 강화 버전"""
        conn = None
        cursor = None
        
        try:
            print("\n=== DB 연결 시작 ===")
            print(f"Host: {db_config['host']}, Database: {db_config['database']}")
            
            # DB 연결
            conn = pymysql.connect(
                host=db_config['host'],
                user=db_config['user'],
                password=db_config['password'],
                database=db_config['database'],
                charset='utf8mb4'
            )
            print("✓ DB 연결 성공")
            
            cursor = conn.cursor()
            
            # 테이블 생성
            print("\n=== 테이블 생성 시작 ===")
            create_table_sql = """
            CREATE TABLE IF NOT EXISTS documents (
                id INT AUTO_INCREMENT PRIMARY KEY,
                source_id VARCHAR(50),
                doc_num VARCHAR(100),
                doc_type VARCHAR(50),
                title VARCHAR(500),
                doc_status VARCHAR(50),
                created_at BIGINT,
                drafter_name VARCHAR(100),
                drafter_position VARCHAR(100),
                drafter_dept VARCHAR(100),
                form_name VARCHAR(200),
                is_public BOOLEAN,
                end_year INT,
                `references` TEXT,
                attaches TEXT,
                referrers TEXT,
                activities TEXT,
                doc_body TEXT,
                created_date TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
                INDEX idx_source_id (source_id),
                INDEX idx_doc_num (doc_num),
                INDEX idx_created_at (created_at),
                INDEX idx_end_year (end_year)
            ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_unicode_ci;
            """
            cursor.execute(create_table_sql)
            print("✓ 테이블 생성/확인 완료")
            
            # 기존 데이터 확인
            cursor.execute("SELECT COUNT(*) FROM documents")
            existing_count = cursor.fetchone()[0]
            print(f"✓ 기존 데이터: {existing_count}건")
            
            # 데이터 삽입
            print(f"\n=== 데이터 삽입 시작 ({len(data)}건) ===")
            insert_sql = """
            INSERT INTO documents 
            (source_id, doc_num, doc_type, title, doc_status, created_at, 
             drafter_name, drafter_position, drafter_dept, form_name, is_public, end_year,
             `references`, attaches, referrers, activities, doc_body)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            
            success_count = 0
            error_count = 0
            error_details = []
            
            for idx, doc in enumerate(data, 1):
                try:
                    # 데이터 길이 제한 및 안전한 변환
                    def safe_string(value, max_length=None):
                        if value is None:
                            return ''
                        s = str(value).strip()
                        if max_length and len(s) > max_length:
                            s = s[:max_length]
                        return s
                    
                    # JSON 데이터를 안전하게 변환 (ensure_ascii=True로 특수문자 이스케이프)
                    def safe_json(value):
                        if not value:
                            return '[]'
                        try:
                            # ensure_ascii=True로 모든 비ASCII 문자를 이스케이프
                            return json.dumps(value, ensure_ascii=True)
                        except:
                            return '[]'
                    
                    values = (
                        safe_string(doc.get('sourceId'), 50),
                        safe_string(doc.get('docNum'), 100),
                        safe_string(doc.get('docType'), 50),
                        safe_string(doc.get('title'), 500),
                        safe_string(doc.get('docStatus'), 50),
                        doc.get('createdAt'),
                        safe_string(doc.get('drafter', {}).get('name'), 100),
                        safe_string(doc.get('drafter', {}).get('positionName'), 100),
                        safe_string(doc.get('drafter', {}).get('deptName'), 100),
                        safe_string(doc.get('formName'), 200),
                        doc.get('isPublic', False),
                        end_year,
                        safe_string(doc.get('references')),
                        safe_json(doc.get('attaches', [])),
                        safe_json(doc.get('referrers', [])),
                        safe_json(doc.get('activities', [])),
                        safe_string(doc.get('docBody'))
                    )
                    
                    cursor.execute(insert_sql, values)
                    success_count += 1
                    
                    # 100건마다만 출력 (로그 줄이기)
                    if idx % 100 == 0 or idx == len(data):
                        print(f"  진행: {idx}/{len(data)} (성공: {success_count}, 실패: {error_count})")
                    
                except Exception as e:
                    error_count += 1
                    error_msg = f"sourceId: {doc.get('sourceId')} - {str(e)[:80]}"
                    error_details.append(error_msg)
                    
                    # 처음 5개 오류만 즉시 출력
                    if error_count <= 5:
                        print(f"  [오류 {error_count}] {error_msg}")
            
            # 커밋
            print("\n=== 커밋 시작 ===")
            conn.commit()
            print(f"✓ 커밋 완료")
            
            # 결과 요약
            print(f"\n=== 결과 요약 ===")
            print(f"✓ 성공: {success_count}건")
            print(f"✗ 실패: {error_count}건")
            
            if error_count > 5:
                print(f"\n처음 5개 외 {error_count - 5}개의 추가 오류가 발생했습니다.")
                print("모든 오류 보기:")
                for err in error_details[:20]:  # 최대 20개만 출력
                    print(f"  - {err}")
                if len(error_details) > 20:
                    print(f"  ... 외 {len(error_details) - 20}개 더")
            
            # 최종 확인
            cursor.execute("SELECT COUNT(*) FROM documents")
            final_count = cursor.fetchone()[0]
            print(f"\n✓ 최종 데이터: {final_count}건 (이번 실행으로 {success_count}건 추가)")
            
        except pymysql.Error as e:
            print(f"\n❌ DB 오류 발생:")
            print(f"  Error Code: {e.args[0]}")
            print(f"  Error Message: {e.args[1]}")
            
        except Exception as e:
            print(f"\n❌ 일반 오류 발생: {e}")
            
        finally:
            if cursor:
                cursor.close()
            if conn:
                conn.close()
                print("\n✓ DB 연결 종료")


def main():
    base_path = r'C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html' #컨트롤러
    end_year = 2025  #컨트롤러 - 폴더 기간에 맞게 수정
    
    parser = ApprovalDocParser(base_path)
    
    print("HTML 파일 파싱 시작...")
    results = parser.process_all_files()
    
    output_json_path = 'two_htmltojsondb_convert.json' #컨트롤러
    parser.save_to_json(results, output_json_path)
    
    # DB 설정
    db_config = {
        'host': 'localhost',
        'user': 'root',
        'password': '1234',
        'database': 'any_approval' #컨트롤러 - 통합 DB명
    }
    
    # MariaDB에 저장
    print("\n" + "="*50)
    parser.save_to_mariadb(results, db_config, end_year)
    print("="*50)
    
    print(f"\n완료! 총 {len(results)}건 처리됨")


if __name__ == '__main__':
    main()
# Out:
# HTML 파일 파싱 시작...
# 총 8175개의 HTML 파일을 찾았습니다.
# 처리 중... [1/8175] 20210104_[LG화학 실험실행시스템 구축]에 대한 매출_매입 계약 품의_15167823.html
# 처리 중... [2/8175] 20210104_경영기획팀 외주인력 구매계약 품의_15168441.html
# 처리 중... [3/8175] 20210104_출장비 지급 신청_15162004.html
# 처리 중... [4/8175] 20210105_개인휴가 신청 _ 2021-01-06 (수), 1일_15175949.html
# 처리 중... [5/8175] 20210105_구매계약 품의(외주인력 )DGIST 연구사업 지원 플랫폼 구축(송지윤,임종덕)_15178865.html
# 처리 중... [6/8175] 20210105_구매계약 품의(외주인력) 연세대학교 산학협력단 RMS2_연구윤리_특허시스템 유지보수(박창준)_15177378.html
# 처리 중... [7/8175] 20210105_리모트콜(Remote Call) 서비스 사용 갱신 요청 드립니다_15179751.html
# 처리 중... [8/8175] 20210106_[입사품의] 경력사원 입사품의(김현성)_15188281.html
# 처리 중... [9/8175] 20210106_기타 경비 신청-교통비_15182306.html
# 처리 중... [10/8175] 20210106_대우조선해양 DSME 지식재산 관리시스템 재구축 검색엔진 구매의 건(다이퀘스트)_15184591.html
# 처리 중... [11/8175] 20210106_명함 신청_15186114.html
# 처리 중... [12/8175] 20210106_반차 휴가 신청서_허지훈_15183357.html
# 처리 중... [13/8175] 20210106_숙소경비신청(2020년12월분)_15184385.html
# 처리 중... [14/8175] 20210107_개인휴가 신청 _ 2021-01-11(월) 오후 ~ 2021-01-13(수) _ 2.5일_15194468.html
# 처리 중... [15/8175] 20210107_거제도 - 숙소 관리비(전기,가스)_15193931.html
# 처리 중... [16/8175] 20210108_휴가사용 신청_15204511.html
# 처리 중... [17/8175] 20210108_휴직신청_15204479.html
# 처리 중... [18/8175] 20210111_12월 출장비 신청의 건_15213513.html
# 처리 중... [19/8175] 20210111_2021.01.18 오후반차 ( 박희철 )_15211771.html
# 처리 중... [20/8175] 20210111_2021.01.18 오후반차(박희철)_15208122.html
# 처리 중... [21/8175] 20210111_대전 원자력연구원 출장 품의서 입니다_15213173.html
# 처리 중... [22/8175] 20210111_신우진 연차휴가 (오후반차) 신청_15215131.html
# 처리 중... [23/8175] 20210111_휴가 신청합니다._15215004.html
# 처리 중... [24/8175] 20210112_야근 교통비 지급 신청의 건_15219472.html
# 처리 중... [25/8175] 20210112_야근 식대 지급 신청의 건_15219427.html
# 처리 중... [26/8175] 20210112_연차 품의서_15223113.html
# 처리 중... [27/8175] 20210112_연차신청서(박형남) 입니다._15222759.html
# 처리 중... [28/8175] 20210114_01월 22일 휴가 사용 신청_15238785.html
# 처리 중... [29/8175] 20210114_DGIST 연구사업 평가시스템 구축 프로젝트 출장비 품의 요청_15237032.html
# 처리 중... [30/8175] 20210114_연차 품의서_15236379.html
# 처리 중... [31/8175] 20210114_휴가사용 품의(송준선)_15235939.html
# 처리 중... [32/8175] 20210115_[S_W]숙명여자대학교 지식재산권 및 기술이전 관리 시스템 고도화 SAP 연동비 구입 품의_15241791.html
# 처리 중... [33/8175] 20210115_[대금결제] 1월 외주용역비 대금 결제의 건-프리랜서(01_15)_15241300.html
# 처리 중... [34/8175] 20210115_반차 품의서_15242491.html
# 처리 중... [35/8175] 20210118_[대금결제] 관세청&quot;국가간 원산지정보 구축&quot; 매입 대금 결제의 건-이원정보기술_15255805.html
# 처리 중... [36/8175] 20210118_연차 휴가 품의_15248570.html
# 처리 중... [37/8175] 20210118_휴가 사용 신청서_15250268.html
# 처리 중... [38/8175] 20210118_휴가사용신청서_15252525.html
# 처리 중... [39/8175] 20210119_[대금결제] ETRI 통합정보(ETRIware) 유지관리 계약 - 2020년 12월분 대금 지급의 건_15260823.html
# 처리 중... [40/8175] 20210119_대중소기업 상생협력기금 종합관리시스템 구축 구매 품의(외주인력) - 권민수(중급)_15260341.html
# 처리 중... [41/8175] 20210119_대중소기업 상생협력기금 종합관리시스템 구축 구매 품의(외주인력) - 김선관(고급)_15260360.html
# 처리 중... [42/8175] 20210119_대중소기업 상생협력기금 종합관리시스템 구축 구매 품의(외주인력) - 박건규(중급)_15260370.html
# 처리 중... [43/8175] 20210119_대중소기업 상생협력기금 종합관리시스템 구축 구매 품의(외주인력) - 최동권(중급)_15260379.html
# 처리 중... [44/8175] 20210119_반차 품의서_15261417.html
# 처리 중... [45/8175] 20210119_숙명여자대학교 지식재산권 및 기술이전 관리 시스템 고도호 SAP 연동 구매 품의(넥스퍼스)_15263937.html
# 처리 중... [46/8175] 20210119_정보통신공사협회 협회비 결제요청드립니다._15263459.html
# 처리 중... [47/8175] 20210119_한국연구재단 2020년 NRF 정보시스템 통합 위탁운영 ITSM라이센스 구매계약의 건_15263948.html
# 처리 중... [48/8175] 20210120_[대금결제] Dell 사업 매입 대금 결제의 건-에스씨지솔루션즈 외(1월)_15270125.html
# 처리 중... [49/8175] 20210120_대전 원자력연구원 출장비 지급 신청서 입니다_15266468.html
# 처리 중... [50/8175] 20210121_김상욱 휴가 사용 신청서_15273227.html
# 처리 중... [51/8175] 20210121_연차휴가 결재품의_신성호 선임_15277303.html
# 처리 중... [52/8175] 20210121_연차휴가 사용 품의-한주영 선임_15274037.html
# 처리 중... [53/8175] 20210121_연차휴가 품의 - 김현성_15276089.html
# 처리 중... [54/8175] 20210122_'21년~'22년 기정원 통합유지보수 구매 신청 품의(외주인력)_15284696.html
# 처리 중... [55/8175] 20210122_[대금결제] 1월 외주용역비 대금 결제의 건-협력사_15281420.html
# 처리 중... [56/8175] 20210122_대우조선해양 숙소[전기,가스] 요금_15282191.html
# 처리 중... [57/8175] 20210122_휴가(반차) 신청_15281429.html
# 처리 중... [58/8175] 20210125_[대금결제]한국발명진흥회 SMART3 연게 IP금융 관리시스템 개발 용역 매입 대금 결제의 건-포시에스, 한국전자인증_15293791.html
# 처리 중... [59/8175] 20210125_[선거관리위원회 온라인투표관리 운영용역]에 관한 매출_매입 계약품의_15294678.html
# 처리 중... [60/8175] 20210125_구매계약 품의(외주인력) 대중소기업 상생협력기금 종합관리시스템 구축(권민수 외 3명)_15296205.html
# 처리 중... [61/8175] 20210125_연차 품의서_15288901.html
# 처리 중... [62/8175] 20210125_오후 반차 휴가 사용 신청_15290605.html
# 처리 중... [63/8175] 20210126_2021년 1월 28일(목) 반차 휴가 신청합니다_15302575.html
# 처리 중... [64/8175] 20210126_월차 사용의 건 (2월 2일, 화)_15304184.html
# 처리 중... [65/8175] 20210127_'21.01.28 출장 품의_15310441.html
# 처리 중... [66/8175] 20210127_ETRI사업팀 재직증명서 발급 요청_15309642.html
# 처리 중... [67/8175] 20210127_[대금결제] 1월 외주용역비 대금 결제의 건-협력사_15312340.html
# 처리 중... [68/8175] 20210127_퇴직 품의서 상신_15310142.html
# 처리 중... [69/8175] 20210127_한국항공우주연구원 출장 품의_15310401.html
# 처리 중... [70/8175] 20210127_휴가(반차) 신청합니다._15309482.html
# 처리 중... [71/8175] 20210128_1_29(금) 오후반차 신청_15314070.html
# 처리 중... [72/8175] 20210128_1월 기타 경비 신청합니다_15313270.html
# 처리 중... [73/8175] 20210128_2021.01.28 휴가 신청서_15315036.html
# 처리 중... [74/8175] 20210128_2021.02.02(화) 휴가 기안_15315047.html
# 처리 중... [75/8175] 20210128_[신규_고도화]숙명여자대학교 지식재산권 및 기술이전 관리 시스템 고도화 개발 용역_15319072.html
# 처리 중... [76/8175] 20210128_개인휴가 신청 _ 2021-01-29 (금), 1일_15316273.html
# 처리 중... [77/8175] 20210128_애니파이브 재직증명서 신청_15313234.html
# 처리 중... [78/8175] 20210128_연차휴가품의_15315872.html
# 처리 중... [79/8175] 20210128_휴가 신청합니다._15313563.html
# 처리 중... [80/8175] 20210129_반차 휴가 신청(1_29, 0.5일)_15324656.html
# 처리 중... [81/8175] 20210129_연차휴가 결재요청_15327002.html
# 처리 중... [82/8175] 20210129_출장품의서_15320884.html
# 처리 중... [83/8175] 20210129_휴가 사용 신청_15326487.html
# 처리 중... [84/8175] 20210131_야근식대 지급 신청의 件_15330489.html
# 처리 중... [85/8175] 20210201_2021년~2022년 기정원 정보시스템 유지보수사업 C_P 품의_15340761.html
# 처리 중... [86/8175] 20210201_[오전반차]결재요청 드립니다._15337660.html
# 처리 중... [87/8175] 20210201_[오후반차]결재요청드립니다._15337635.html
# 처리 중... [88/8175] 20210201_노트북 소보 발송에 따른 경비 사용 정산 신청 드립니다._15332304.html
# 처리 중... [89/8175] 20210201_서울대병원 외주인력 구매 신청 품의서(차영호)_15336633.html
# 처리 중... [90/8175] 20210201_휴가 사용 품의_15340814.html
# 처리 중... [91/8175] 20210202_2021년 2월 5일(금) 연차 휴가 신청합니다_15345414.html
# 처리 중... [92/8175] 20210202_21년~22년 기정원 정보시스템 통합유지보수사업 매출 품의_15347013.html
# 처리 중... [93/8175] 20210202_2월 5일 ~ 10일 휴가 사용 신청합니다._15347485.html
# 처리 중... [94/8175] 20210202_국가간 원산지정보 자료교환시스템 구축사업(베트남) C_P 품의_15348296.html
# 처리 중... [95/8175] 20210202_휴가 사용 신청서_15349060.html
# 처리 중... [96/8175] 20210203_[지급품의] 2021년도 KINPA 찬조회원사 연회비 지급 품의의 건_15351837.html
# 처리 중... [97/8175] 20210203_퇴직 품의(김현성 책임)_15356532.html
# 처리 중... [98/8175] 20210203_휴가 신청 품의_15355386.html
# 처리 중... [99/8175] 20210204_[휴가신청] 김우석 선임 연차1일 사용 신청의 건_15359740.html
# 처리 중... [100/8175] 20210204_명함발급을 요청합니다._15362351.html
# 처리 중... [101/8175] 20210205_1월 출장비 신청의 건_15370601.html
# 처리 중... [102/8175] 20210205_2021-02-15(월) 휴가 사용_15371818.html
# 처리 중... [103/8175] 20210205_숙소경비신청(2021년1월분)_15370340.html
# 처리 중... [104/8175] 20210208_'21.01.28 출장비 지급 신청 품의_15377405.html
# 처리 중... [105/8175] 20210208_[대금결제] 토요타파이낸셜 &quot;차세대 및 망분리 시스템 구축&quot; 매입대금 결제의 건 - 데이타쎌테크_15382181.html
# 처리 중... [106/8175] 20210208_연차휴가 신청_2_10(수)_15380279.html
# 처리 중... [107/8175] 20210208_택시비 지급 신청서_15385270.html
# 처리 중... [108/8175] 20210208_휴가 신청합니다._15377356.html
# 처리 중... [109/8175] 20210209_연차휴가 신청(2_22, 1일)_15392888.html
# 처리 중... [110/8175] 20210209_연차휴가 신청_15388474.html
# 처리 중... [111/8175] 20210209_한국 항공우주연구원 출장비 지급요청 품의_15391835.html
# 처리 중... [112/8175] 20210210_2021-02-15 정서연 휴가신청합니다(1일)_15398744.html
# 처리 중... [113/8175] 20210210_휴가 사용 신청의 건_15397718.html
# 처리 중... [114/8175] 20210210_휴가 사용신청서 품의_15394875.html
# 처리 중... [115/8175] 20210215_20210222 반차휴가(박희철)_15406737.html
# 처리 중... [116/8175] 20210215_반차 품의서_15407831.html
# 처리 중... [117/8175] 20210215_연차신청서(박형남) 입니다._15404259.html
# 처리 중... [118/8175] 20210216_2021.02.15 휴가 사용 신청서_15413555.html
# 처리 중... [119/8175] 20210216_기타 경비 신청 (21.02.16)_15416101.html
# 처리 중... [120/8175] 20210216_신우진 연차휴가 신청_15412559.html
# 처리 중... [121/8175] 20210216_휴가 사용 품의(송준선)_15413002.html
# 처리 중... [122/8175] 20210217_개인 휴가 신청_조신행 사원_2020.02.26(금)_15418731.html
# 처리 중... [123/8175] 20210217_대전 원자력연구원 출장 품의서 입니다_15424352.html
# 처리 중... [124/8175] 20210217_반차 휴가 품의 요청_15422130.html
# 처리 중... [125/8175] 20210217_연차휴가신청_이형균_21_02_19_15418675.html
# 처리 중... [126/8175] 20210217_휴가 신청_15423448.html
# 처리 중... [127/8175] 20210218_개인휴가 _ 2021-02-19 (금) _ 1일_15427585.html
# 처리 중... [128/8175] 20210218_김상욱 휴가 사용 신청서 입니다._15427134.html
# 처리 중... [129/8175] 20210218_신우진 재직증명서 및 근로소득원천징수 발급요청_15425947.html
# 처리 중... [130/8175] 20210218_오후 반차 신청드립니다._15428886.html
# 처리 중... [131/8175] 20210218_휴가를 신청합니다._15431940.html
# 처리 중... [132/8175] 20210219_휴가 사용 신청의 件_15439810.html
# 처리 중... [133/8175] 20210222_강원준 출장 품의서 결재 올립니다._15449793.html
# 처리 중... [134/8175] 20210222_대전 원자력연구원 출장비 지급 신청서 입니다_15443629.html
# 처리 중... [135/8175] 20210222_반차 품의서_15442285.html
# 처리 중... [136/8175] 20210222_월차휴가 사용을 신청합니다._15444686.html
# 처리 중... [137/8175] 20210222_특허청 제안서 작성 관련 출장 품의서_15443589.html
# 처리 중... [138/8175] 20210222_휴가 사용 신청서 기안합니다._15449968.html
# 처리 중... [139/8175] 20210223_단기 출장 품의의 件_15457976.html
# 처리 중... [140/8175] 20210223_연차휴가 신청의 건_15452261.html
# 처리 중... [141/8175] 20210223_휴가 신청합니다. (건강검진)_15452466.html
# 처리 중... [142/8175] 20210223_휴가사용신청서_15453360.html
# 처리 중... [143/8175] 20210224_강원준 출장비 지급 신청서 올립니다._15466074.html
# 처리 중... [144/8175] 20210224_김상욱 휴가 사용 신청서 입니다._15463060.html
# 처리 중... [145/8175] 20210224_반차 품의서_15460132.html
# 처리 중... [146/8175] 20210224_연차 휴가 품의_15461640.html
# 처리 중... [147/8175] 20210225_20210225 휴가 사용 신청서_15467415.html
# 처리 중... [148/8175] 20210225_기타 경비 신청 (21.02.25)_15468791.html
# 처리 중... [149/8175] 20210225_휴가 신청합니다._15473638.html
# 처리 중... [150/8175] 20210226_2월 교통비 신청 합니다_15475801.html
# 처리 중... [151/8175] 20210226_2월 기타 경비 신청합니다_15475811.html
# 처리 중... [152/8175] 20210226_3월 2일 연차 신청합니다_15475835.html
# 처리 중... [153/8175] 20210226_[사후품의] 연차휴가 사용_15478738.html
# 처리 중... [154/8175] 20210226_반차 결재요청_15476030.html
# 처리 중... [155/8175] 20210301_경비 신청_15485084.html
# 처리 중... [156/8175] 20210301_야근식대 지급 신청의 件_15484992.html
# 처리 중... [157/8175] 20210301_출장비 지급 신청의 件_15484981.html
# 처리 중... [158/8175] 20210302_[2021년 2월 경비신청서 입니다]_15485278.html
# 처리 중... [159/8175] 20210302_개인휴가 신청 _ 2021-03-02 (화), 0.5일_15489447.html
# 처리 중... [160/8175] 20210302_개인휴가 신청 _ 2021-03-05 (금), 1일_15489464.html
# 처리 중... [161/8175] 20210304_2월 출장비 신청의 건_15511406.html
# 처리 중... [162/8175] 20210304_연차 휴가 신청합니다_15512371.html
# 처리 중... [163/8175] 20210305_대전 원자력연구원 출장 품의서 입니다_15517450.html
# 처리 중... [164/8175] 20210305_퇴직서(박희철)_15518800.html
# 처리 중... [165/8175] 20210305_휴가 사용 신청_15515194.html
# 처리 중... [166/8175] 20210305_휴가 사용 신청_15518902.html
# 처리 중... [167/8175] 20210308_연차 휴가 신청(3_9, 1일)_15530892.html
# 처리 중... [168/8175] 20210309_숙소경비신청(2021년2월분)_15536532.html
# 처리 중... [169/8175] 20210309_휴가 신청 품의_15539864.html
# 처리 중... [170/8175] 20210310_03월 12일 휴가 사용 신청_15544598.html
# 처리 중... [171/8175] 20210310_2021년 03월 12일(금) 오후 반차 신청합니다._15543249.html
# 처리 중... [172/8175] 20210310_기타 경비 신청 (21.03.10)_15544773.html
# 처리 중... [173/8175] 20210310_대중소기업농어업협력재단 ERP 연계 추가개발 건_15548135.html
# 처리 중... [174/8175] 20210310_휴가 사용 신청합니다._15545682.html
# 처리 중... [175/8175] 20210311_2021-03-12 정서연 휴가신청합니다(1일)_15550027.html
# 처리 중... [176/8175] 20210311_개인휴가 _ 2021-03-12 (금) _ 0.5일 (오전휴무)_15550779.html
# 처리 중... [177/8175] 20210311_대중소기업상생협력기금 종합관리시스템 구축 ERP연계 추가개발 구매의 건_15555001.html
# 처리 중... [178/8175] 20210312_'21.03.15 연차품의_15563397.html
# 처리 중... [179/8175] 20210312_휴가 사용 신청서_15560602.html
# 처리 중... [180/8175] 20210315_대전 원자력연구원 출장비 지급 신청서 입니다_15568372.html
# 처리 중... [181/8175] 20210315_휴가 신청합니다._15567588.html
# 처리 중... [182/8175] 20210317_2021-02-18 정서연 휴가신청합니다(1일)_15581565.html
# 처리 중... [183/8175] 20210317_[휴가사용사후품의] 연차휴가 품의_15588086.html
# 처리 중... [184/8175] 20210317_연차 품의서_15587395.html
# 처리 중... [185/8175] 20210317_연차 품의서_15587527.html
# 처리 중... [186/8175] 20210318_[휴가]신청드립니다._15589167.html
# 처리 중... [187/8175] 20210318_개인휴가 신청 _ 2021-03-19 (금), 1일_15588762.html
# 처리 중... [188/8175] 20210318_신우진 연차휴가 (오후반차) 신청_15594295.html
# 처리 중... [189/8175] 20210318_휴가 사용 신청서_15589614.html
# 처리 중... [190/8175] 20210318_휴가 신청_15594567.html
# 처리 중... [191/8175] 20210319_[대금결제] ITO_3월 외주용역비 대금 결제의 건-프리랜서_업체(03_15)_15598972.html
# 처리 중... [192/8175] 20210322_[대금결제] ITO_3월 외주용역비 대금 결제의 건_업체(03_25)_15612862.html
# 처리 중... [193/8175] 20210322_김상욱 휴가 사용 신청서 입니다._15612084.html
# 처리 중... [194/8175] 20210322_조달청 제안서 작성 관련 출장 품의서_15612520.html
# 처리 중... [195/8175] 20210322_휴가 사용 신청의 件_15618394.html
# 처리 중... [196/8175] 20210323_[지급품의] 2021 혁신서비스 해외진출 맞춤형 지원사업 기업분담금 납부의 건_15621344.html
# 처리 중... [197/8175] 20210323_개인 휴가 신청_조신행 사원_2020.03.26(금)_15619012.html
# 처리 중... [198/8175] 20210323_기타 경비 신청 (21.03.23)_15622382.html
# 처리 중... [199/8175] 20210323_대중소기업농어업협력재단 방화벽_15620990.html
# 처리 중... [200/8175] 20210323_연차 품의서_15618962.html
# 처리 중... [201/8175] 20210323_연차휴가 신청_이형균_3_26(금)_15619833.html
# 처리 중... [202/8175] 20210323_휴가 사용 신청서_이의환 선임_15621473.html
# 처리 중... [203/8175] 20210324_집안사정으로 인한 오후 반차휴가 요청합니다._15627090.html
# 처리 중... [204/8175] 20210324_휴가 사용 신청서_15630438.html
# 처리 중... [205/8175] 20210324_휴가 사용신청서 품의_15630039.html
# 처리 중... [206/8175] 20210325_연차 휴가 품의_15635917.html
# 처리 중... [207/8175] 20210325_휴가 신청합니다. (건강검진 2차검진)_15637260.html
# 처리 중... [208/8175] 20210325_휴가 신청합니다._15640167.html
# 처리 중... [209/8175] 20210326_(계약변경) HK이노엔 지식재산시스템 유지보수 계약 품의_15646030.html
# 처리 중... [210/8175] 20210326_(계약변경) SK바이오사이언스 21년 e-patent 유지보수 계약 품의_15646240.html
# 처리 중... [211/8175] 20210326_(계약변경) SK케미칼 e-patent 21년도 유지보수 계약 품의_15646187.html
# 처리 중... [212/8175] 20210326_2021.03.31(수) 연차 품의_15645920.html
# 처리 중... [213/8175] 20210326_연차휴가품의_15642122.html
# 처리 중... [214/8175] 20210326_택시비 지급 신청서_15645550.html
# 처리 중... [215/8175] 20210329_2021.03.29 휴가 신청 합니다._15655348.html
# 처리 중... [216/8175] 20210329_[대금결제] ITO_3월 외주용역비 대금 결제의 건_업체(03_31)_15654748.html
# 처리 중... [217/8175] 20210330_'21.04.01 연차품의_15664432.html
# 처리 중... [218/8175] 20210330_4월 2일(금) 연차 사용 신청합니다._15666951.html
# 처리 중... [219/8175] 20210330_휴가 사용 신청서 [한상근 사원] 입니다._15665643.html
# 처리 중... [220/8175] 20210331_2021.04.02(금) 오후 반차 휴가 사용 신청의 건_15673391.html
# 처리 중... [221/8175] 20210331_김우선 선임 연차휴가 반차사용 신청서(4월 1일)_15670440.html
# 처리 중... [222/8175] 20210331_사원 경동윤 2021 04 05 개인 휴가 신청합니다._15670368.html
# 처리 중... [223/8175] 20210401_3월 기타 경비 신청합니다_15678061.html
# 처리 중... [224/8175] 20210402_[입사품의] 신입사원_이하연_15688842.html
# 처리 중... [225/8175] 20210402_[입사품의] 신입사원_전진원_15688759.html
# 처리 중... [226/8175] 20210402_[입사품의] 신입사원_차경석_15688711.html
# 처리 중... [227/8175] 20210402_휴가 사용 신청서_15690007.html
# 처리 중... [228/8175] 20210405_3월 출장비 신청품의의 건_15700398.html
# 처리 중... [229/8175] 20210405_[2021년 3월 경비신청서 올립니다]_15703997.html
# 처리 중... [230/8175] 20210405_[통합연구지원시스템 전문기관 데이터이관 대응사업] 프로젝트룸 임대 품의_15698390.html
# 처리 중... [231/8175] 20210405_연차휴가 품의_15698279.html
# 처리 중... [232/8175] 20210405_휴가 신청서_15696529.html
# 처리 중... [233/8175] 20210406_한국항공우주연구원 출장 품의_15704380.html
# 처리 중... [234/8175] 20210406_휴가 사용 신청서_15704439.html
# 처리 중... [235/8175] 20210407_[통합연구지원시스템 전문기관 데이터이관 대응사업] 프로젝트룸 사무기기 및 집기류 구매 품의_15717209.html
# 처리 중... [236/8175] 20210407_강원준 사원 휴가 신청서 올립니다._15721062.html
# 처리 중... [237/8175] 20210407_대전 원자력연구원 출장 품의서 입니다_15718815.html
# 처리 중... [238/8175] 20210408_2021년 4월 12일(월) 연차 휴가 신청합니다_15721578.html
# 처리 중... [239/8175] 20210408_휴가(오후반차) 신청합니다._15723250.html
# 처리 중... [240/8175] 20210409_휴가 신청서_15732937.html
# 처리 중... [241/8175] 20210412_[대금결제] ITO_4월 외주용역비 대금 결제의 건-프리랜서_업체(04_15)_15744992.html
# 처리 중... [242/8175] 20210412_개인 휴가 신청_조신행 사원_2020.04.16(금) (연차)_15738302.html
# 처리 중... [243/8175] 20210412_연차 품의서_15738561.html
# 처리 중... [244/8175] 20210412_연차휴가 결재요청드립니다._15744997.html
# 처리 중... [245/8175] 20210412_휴가 사용 신청_15742849.html
# 처리 중... [246/8175] 20210412_휴가 사용 신청서 기안합니다._15746447.html
# 처리 중... [247/8175] 20210412_휴가 사용신청서 품의_15746476.html
# 처리 중... [248/8175] 20210412_휴가사용 신청_15738065.html
# 처리 중... [249/8175] 20210413_2021.04.14(수) 연차 품의_15748264.html
# 처리 중... [250/8175] 20210413_20210413_사원 _경동윤 개인휴가(반차)신청합니다._15747068.html
# 처리 중... [251/8175] 20210413_반차 품의서_15747963.html
# 처리 중... [252/8175] 20210413_삼성SDI 지재권관리시스템 구축의 건_15750635.html
# 처리 중... [253/8175] 20210413_숙소경비신청(2021년3월분)_15749860.html
# 처리 중... [254/8175] 20210413_연차 품의서_15747972.html
# 처리 중... [255/8175] 20210413_연차휴가 신청(4_19, 1일)_15749134.html
# 처리 중... [256/8175] 20210413_한국콜마 지재권관리시스템 구축의 건_15750266.html
# 처리 중... [257/8175] 20210413_한승재-퇴직품의서_15752761.html
# 처리 중... [258/8175] 20210414_휴가 사용 신청드립니다._15760104.html
# 처리 중... [259/8175] 20210414_휴가 사용 신청합니다._15759731.html
# 처리 중... [260/8175] 20210415_휴가 사용 신청서_15762007.html
# 처리 중... [261/8175] 20210415_휴가 신청_15764930.html
# 처리 중... [262/8175] 20210415_휴가 품의 요청_15765144.html
# 처리 중... [263/8175] 20210416_[대금결제] ETRI 통합정보(ETRIware) 유지관리 계약 - 2021년 3월분 대금 지급의 건_15774451.html
# 처리 중... [264/8175] 20210419_'21.04.16 출장비 지급 신청 품의_15781758.html
# 처리 중... [265/8175] 20210419_오전 반차 사용의 건 (4월 20일, 화)_15783382.html
# 처리 중... [266/8175] 20210420_[대금결제] ITO_4월 외주용역비 대금 결제의 건-업체(04_25)_15791376.html
# 처리 중... [267/8175] 20210420_연차 품의서_15786270.html
# 처리 중... [268/8175] 20210421_연차휴가 신청_15799823.html
# 처리 중... [269/8175] 20210421_코스맥스 주차비 신청_15796734.html
# 처리 중... [270/8175] 20210422_NICE API 구매건_15807093.html
# 처리 중... [271/8175] 20210422_개인휴가 신청 _ 2021-04-23 (금), 1일_15804139.html
# 처리 중... [272/8175] 20210422_휴가 품의 드립니다._15807741.html
# 처리 중... [273/8175] 20210423_4월 26일 휴가 신청합니다._15813813.html
# 처리 중... [274/8175] 20210423_휴가 사용 신청_15811357.html
# 처리 중... [275/8175] 20210426_기타 경비 신청 (21.04.26)_15823653.html
# 처리 중... [276/8175] 20210426_사원 경동윤 04_27(화) 개인휴가(오후반차) 신청합니다._15820689.html
# 처리 중... [277/8175] 20210426_휴가 신청(04_27)입니다_15817617.html
# 처리 중... [278/8175] 20210427_2021년 4월 29일(목) 반차 휴가 신청합니다_15833815.html
# 처리 중... [279/8175] 20210427_대전 원자력연구원 출장비 지급 신청서 입니다_15826777.html
# 처리 중... [280/8175] 20210427_연차 품의서_15829825.html
# 처리 중... [281/8175] 20210427_연차 휴가 품의_15827074.html
# 처리 중... [282/8175] 20210428_[대금결제] ITO_4월 외주용역비 대금 결제의 건-업체(04_30)_15834348.html
# 처리 중... [283/8175] 20210428_신우진 휴가(오후 반차) 사용 신청서_15836981.html
# 처리 중... [284/8175] 20210428_연차 신청의 건 (4_30, 금)_15834399.html
# 처리 중... [285/8175] 20210428_휴가 사용 품의_15840015.html
# 처리 중... [286/8175] 20210429_20210430 정서연 휴가 신청합니다(1일)_15842049.html
# 처리 중... [287/8175] 20210429_야근 식대 신청합니다._15849526.html
# 처리 중... [288/8175] 20210429_연차 휴가 품의_15842305.html
# 처리 중... [289/8175] 20210429_오후반차 신청합니다._15849584.html
# 처리 중... [290/8175] 20210430_'21.04.29 출장비 지급 신청 품의_15851725.html
# 처리 중... [291/8175] 20210430_연차신청서(박형남) 입니다._15850631.html
# 처리 중... [292/8175] 20210430_월차휴가 사용신청합니다_15852361.html
# 처리 중... [293/8175] 20210430_휴가 사용 신청서 [한상근 사원] 입니다._15850672.html
# 처리 중... [294/8175] 20210503_경조사로 휴가를 신청 드립니다._15869326.html
# 처리 중... [295/8175] 20210503_연차 품의서_15862400.html
# 처리 중... [296/8175] 20210503_휴가 신청드립니다._15865691.html
# 처리 중... [297/8175] 20210504_2021년 4월 출장교통비 지급 신청서_15871474.html
# 처리 중... [298/8175] 20210504_4월 기타 경비 신청합니다_15875688.html
# 처리 중... [299/8175] 20210504_숙소경비신청(2021년4월분)_15870773.html
# 처리 중... [300/8175] 20210504_연차휴가 신청_15873929.html
# 처리 중... [301/8175] 20210504_휴가 사용 신청서_15873021.html
# 처리 중... [302/8175] 20210504_휴가 신청합니다._15872028.html
# 처리 중... [303/8175] 20210504_휴가 신청합니다._15877309.html
# 처리 중... [304/8175] 20210504_휴가 신청합니다_15875555.html
# 처리 중... [305/8175] 20210506_05월 06일 반차, 05월 10일 연차 사용 신청_15882494.html
# 처리 중... [306/8175] 20210506_[2021년 4월 경비신청서 입니다]_15879959.html
# 처리 중... [307/8175] 20210506_개인휴가 _ 2021-05-07 (금) _ 1일_15883893.html
# 처리 중... [308/8175] 20210506_휴가 신청_15880707.html
# 처리 중... [309/8175] 20210510_'21.05.17 연차품의_15905470.html
# 처리 중... [310/8175] 20210510_2021.05.14(금) 휴가 사용 신청의 건_15900408.html
# 처리 중... [311/8175] 20210510_4월 출장비 신청의 건_15902607.html
# 처리 중... [312/8175] 20210510_출장비 신청_15903380.html
# 처리 중... [313/8175] 20210510_휴가 신청_15899777.html
# 처리 중... [314/8175] 20210511_대전 원자력연구원 출장 품의서 입니다_15911671.html
# 처리 중... [315/8175] 20210511_연차휴가 신청입니다. (5_14)_15913590.html
# 처리 중... [316/8175] 20210511_휴가 사용 신청서 기안합니다._15916628.html
# 처리 중... [317/8175] 20210512_연차 휴가 품의_15922959.html
# 처리 중... [318/8175] 20210512_연차휴가 신청서_이형균_5_14(금)_15918541.html
# 처리 중... [319/8175] 20210512_휴가 사용 신청서_15917148.html
# 처리 중... [320/8175] 20210512_휴가 신청서_210517~18_15920805.html
# 처리 중... [321/8175] 20210513_5월 14일 연차 신청 합니다_15926295.html
# 처리 중... [322/8175] 20210513_[S_W]연세대학교 평가시스템 구축관련 SSL 인증서 구입 품의_15928342.html
# 처리 중... [323/8175] 20210513_개인휴가 _ 2021-05-14 (금), 오전 반차 (0.5일)_15928229.html
# 처리 중... [324/8175] 20210513_개인휴가 _ 2021-05-21 (금) 1일_15928257.html
# 처리 중... [325/8175] 20210513_연차 품의서_15925527.html
# 처리 중... [326/8175] 20210513_연차사용 품의_신성호_15925386.html
# 처리 중... [327/8175] 20210513_휴가사용품의_15929792.html
# 처리 중... [328/8175] 20210517_2021.05.20 휴가 신청_15947160.html
# 처리 중... [329/8175] 20210517_2021년 5월 21일(금) 연차 휴가 신청합니다_15946039.html
# 처리 중... [330/8175] 20210517_[대금결제] ITO_5월 외주용역비 대금 결제의 건 (2차)-프리랜서_업체(05_15)_15942504.html
# 처리 중... [331/8175] 20210517_대전 원자력연구원 출장비 지급 신청서 입니다_15940835.html
# 처리 중... [332/8175] 20210517_휴가 신청합니다._15945736.html
# 처리 중... [333/8175] 20210518_연차 품의서_15952726.html
# 처리 중... [334/8175] 20210518_장애발생 조치 지연에 따른 위약금 지급 품의_15954943.html
# 처리 중... [335/8175] 20210520_2021.05.31(월) 연차 품의_15963208.html
# 처리 중... [336/8175] 20210520_[대금결제] ITO_5월 외주용역비 대금 결제의 건-업체 (05_25)_15961394.html
# 처리 중... [337/8175] 20210520_개인 휴가 신청_조신행 사원_2021.05.24(월) (연차)_15960313.html
# 처리 중... [338/8175] 20210520_대중소 상생협력기금 종합관리시스템 구축 구매 품의(외주인력) - 최동권(중급)_15961995.html
# 처리 중... [339/8175] 20210520_연차휴가 신청_15963761.html
# 처리 중... [340/8175] 20210520_휴가 사용신청서 품의_15958511.html
# 처리 중... [341/8175] 20210520_휴가 신청 품의(송준선, 5_24 오후)_15963163.html
# 처리 중... [342/8175] 20210523_휴가 사용 신청의 件_15973322.html
# 처리 중... [343/8175] 20210524_[대금결제] 공통_5월 외주용역비 대금 결제의 건-(05_25)_15978061.html
# 처리 중... [344/8175] 20210524_[신규_SI]코스맥스 처방연구노트관리시스템 구축 매출 계약 품의_15979839.html
# 처리 중... [345/8175] 20210525_[대금결제] ITO_5월 외주용역비 대금 결제의 건-업체 (05_31)_15984267.html
# 처리 중... [346/8175] 20210525_휴가 사용 신청서_15984017.html
# 처리 중... [347/8175] 20210526_20210531_사원_경동윤 개인휴가 신청합니다._15994129.html
# 처리 중... [348/8175] 20210526_[대금결제] 공통_5월 외주용역비 대금 결제의 건-(05_31)_15995542.html
# 처리 중... [349/8175] 20210526_야근식대 신청합니다._15993168.html
# 처리 중... [350/8175] 20210526_휴가 품의 드립니다._15994205.html
# 처리 중... [351/8175] 20210527_05월 31일 휴가 사용 신청_16002993.html
# 처리 중... [352/8175] 20210527_연차 휴가 품의_16002098.html
# 처리 중... [353/8175] 20210527_휴가 사용 신청서_이의환 선임_15999958.html
# 처리 중... [354/8175] 20210528_2021년 6월 4일(금) 오전 반차 휴가 신청합니다_16009666.html
# 처리 중... [355/8175] 20210528_[지출결의] 선급금이행보증증권 납부 승인 요청의 건_16008100.html
# 처리 중... [356/8175] 20210528_[지출결의] 선급금이행보증증권 납부 승인 요청의 건_16012259.html
# 처리 중... [357/8175] 20210531_5월 야근식대 결재 요청 드립니다._16024308.html
# 처리 중... [358/8175] 20210531_[대금결제] 공통_5월 외주용역비 대금 결제의 건-(05_31) - 추가 프리랜서 2명_16019692.html
# 처리 중... [359/8175] 20210531_[휴가 신청서 입니다]_16024443.html
# 처리 중... [360/8175] 20210531_결재 요청드립니다_16024407.html
# 처리 중... [361/8175] 20210531_대전지사 출장비 지급 신청_16018357.html
# 처리 중... [362/8175] 20210531_신우진 연차 휴가 신청_16015404.html
# 처리 중... [363/8175] 20210531_연차 품의서_16015703.html
# 처리 중... [364/8175] 20210531_연차 휴가 품의_16016413.html
# 처리 중... [365/8175] 20210531_한국콜마 프로젝트 회식비_16018375.html
# 처리 중... [366/8175] 20210601_5월 기타 경비 신청 합니다_16024978.html
# 처리 중... [367/8175] 20210601_[지출결의] 선급금이행보증증권 납부 승인 요청의 건_16028718.html
# 처리 중... [368/8175] 20210601_휴가 사용 신청_16027151.html
# 처리 중... [369/8175] 20210601_휴가 사용 신청서_16031162.html
# 처리 중... [370/8175] 20210602_김우석 선임 개인 연차 신청의 건(6월 3일)_16037844.html
# 처리 중... [371/8175] 20210602_연차휴가 신청_16038293.html
# 처리 중... [372/8175] 20210602_휴가 사용 신청합니다._16034390.html
# 처리 중... [373/8175] 20210602_휴가사용 품의_16040266.html
# 처리 중... [374/8175] 20210603_휴가 사용 신청서 _ 2021-06-04 (금) _ 1일_16044473.html
# 처리 중... [375/8175] 20210604_[2021년 5월 경비신청서 올립니다]_16051408.html
# 처리 중... [376/8175] 20210604_월차 사용의 건 (6월 11일, 금)_16057125.html
# 처리 중... [377/8175] 20210607_2021.06.09(수) 휴가 사용 신청의 건_16062054.html
# 처리 중... [378/8175] 20210607_20210607_사원_경동윤 개인 오후 반차휴가 신청합니다._16061546.html
# 처리 중... [379/8175] 20210607_반차 사용 신청서_16066123.html
# 처리 중... [380/8175] 20210607_반차 휴가 사용 신청서_16069651.html
# 처리 중... [381/8175] 20210607_베트남경제연구소(Vnomics) 웹사이트 개발 및 구축 용역 구입 품의_16068037.html
# 처리 중... [382/8175] 20210607_신우진 휴가(오후 반차) 사용 신청_16066921.html
# 처리 중... [383/8175] 20210607_연차휴가 품의_신성호_16062699.html
# 처리 중... [384/8175] 20210607_연차휴가신청_16060848.html
# 처리 중... [385/8175] 20210608_5월 출장비 신청의 건_16071450.html
# 처리 중... [386/8175] 20210608_6월 10일~11일 연차 사용 신청합니다._16070446.html
# 처리 중... [387/8175] 20210608_DGIST 연구사업 평가시스템 구축 프로젝트 출장비 품의 요청_16074598.html
# 처리 중... [388/8175] 20210608_휴가 사용을 신청합니다._16075510.html
# 처리 중... [389/8175] 20210608_휴가 신청 품의_16070642.html
# 처리 중... [390/8175] 20210608_휴가신청 품의(송준선, 6_15)_16075399.html
# 처리 중... [391/8175] 20210609_2021.06.14(월) 연차 품의_16079135.html
# 처리 중... [392/8175] 20210609_데이터이관 대응사업 이관설명회 행사 품의_16081048.html
# 처리 중... [393/8175] 20210609_반차 휴가 신청 (6_9)_16080595.html
# 처리 중... [394/8175] 20210610_'21.06.15 연차품의_16088177.html
# 처리 중... [395/8175] 20210610_명함 재박급 신청_16088285.html
# 처리 중... [396/8175] 20210610_사업관리 고아라 - 6_10(목) 오후 반차 신청의 건_16087112.html
# 처리 중... [397/8175] 20210610_연차휴가 신청의 건_16087071.html
# 처리 중... [398/8175] 20210610_오후 반차 신청드립니다._16093483.html
# 처리 중... [399/8175] 20210610_휴가 사용 신청서 올립니다. 승인 부탁드리겠습니다._16093904.html
# 처리 중... [400/8175] 20210611_2021-06-14(월) 휴가 신청합니다 - 1일_16094756.html
# 처리 중... [401/8175] 20210611_[대금결제] ITO_6월 외주용역비 대금 결제의 건 - 프리랜서_업체 (06_15)_16099960.html
# 처리 중... [402/8175] 20210611_국립식량과학원 2021년 작물연구정보시스템 위탁관리 사업 - ICT사업팀_프리랜서(이형균책임)_16099327.html
# 처리 중... [403/8175] 20210614_[대금결제] 공통_5월 외주용역비 대금 결제의 건-프리랜서 (06_15) - 수정 품의_16107594.html
# 처리 중... [404/8175] 20210614_연차 품의서_16106152.html
# 처리 중... [405/8175] 20210614_휴가 사용 신청_16106657.html
# 처리 중... [406/8175] 20210614_휴가 신청합니다._16103832.html
# 처리 중... [407/8175] 20210614_휴가사용 신청의 건_16107131.html
# 처리 중... [408/8175] 20210615_휴가 사용 품의_16110803.html
# 처리 중... [409/8175] 20210617_연차 품의서_16128844.html
# 처리 중... [410/8175] 20210617_휴가신청 _ 2021-06-18(금), 1일_16127362.html
# 처리 중... [411/8175] 20210618_[대중소] KCC정보통신(주) - 웹방화벽 대금 결제 품의_16138069.html
# 처리 중... [412/8175] 20210618_휴가 신청_16133975.html
# 처리 중... [413/8175] 20210618_휴가를 신청합니다._16137360.html
# 처리 중... [414/8175] 20210618_휴가사용 신청서_16139408.html
# 처리 중... [415/8175] 20210621_[대금결제] ITO_6월 외주용역비 대금 결제의 건 - 업체 (06_25)_16145504.html
# 처리 중... [416/8175] 20210621_[연차]2021.06.23(수) 휴가신청드립니다._16142551.html
# 처리 중... [417/8175] 20210621_반차 휴가 사용 신청서_16146186.html
# 처리 중... [418/8175] 20210621_휴가 사용 신청_16143114.html
# 처리 중... [419/8175] 20210621_휴가 사용 신청서 기안합니다._16150011.html
# 처리 중... [420/8175] 20210621_휴가 사용 신청서_16141766.html
# 처리 중... [421/8175] 20210622_20210625_사원_경동윤 개인 휴가 신청합니다._16153436.html
# 처리 중... [422/8175] 20210622_20210628_휴가신청_16154143.html
# 처리 중... [423/8175] 20210622_[신규_SI]유한양행 임상시험관리시스템 구축 계약 품의_16155153.html
# 처리 중... [424/8175] 20210622_[신규_솔루션]SK실트론 지식재산관리 시스템구축계약 품의_16154985.html
# 처리 중... [425/8175] 20210622_개인 휴가 신청_조신행 사원_2021.06.25(금) (연차)_16152979.html
# 처리 중... [426/8175] 20210622_대전 원자력연구원 출장비 지급 신청서 입니다_16150576.html
# 처리 중... [427/8175] 20210622_연차 신청의 건 (6_25, 금)_16153645.html
# 처리 중... [428/8175] 20210622_휴가 신청_20210625_16154200.html
# 처리 중... [429/8175] 20210623_(서부발전) 이중화 서버 H_W (4대) 구매건_16161555.html
# 처리 중... [430/8175] 20210623_김우석 선임 6월 25일 개인연차 사용_16161057.html
# 처리 중... [431/8175] 20210623_연차 품의서_16158555.html
# 처리 중... [432/8175] 20210624_06월 28일 휴가 사용 신청_16170194.html
# 처리 중... [433/8175] 20210624_[2021년 6월 25일 - 1일 연차 휴가 요청 드립니다]_16166748.html
# 처리 중... [434/8175] 20210624_[대금결제] 공통_5월 외주용역비 대금 결제의 건-(06_25) - 수정품의_16168874.html
# 처리 중... [435/8175] 20210624_사업관리 고아라 - 6_25(금) 오후 반차 신청의 건_16167302.html
# 처리 중... [436/8175] 20210624_연차사용품의_16170363.html
# 처리 중... [437/8175] 20210625_06-28  NHN NB, monitor x 4_16177010.html
# 처리 중... [438/8175] 20210625_06-29 이랜드 Monitor, Part x 12_16177040.html
# 처리 중... [439/8175] 20210625_06-30 OOCI Server x 1_16177069.html
# 처리 중... [440/8175] 20210625_06-31 NHN NB, Monitor x 24_16177090.html
# 처리 중... [441/8175] 20210625_20210624_출장비 품의_16175008.html
# 처리 중... [442/8175] 20210625_ITO_6월 외주용역비 대금 결제의 건-업체 (06_30)_16175507.html
# 처리 중... [443/8175] 20210625_LG전자_엘지전자(주)_TIPIS 특허 등급_분류 관리 고도화_특허 포트폴리오 - IPR사업팀_엠씨에스컨설팅(이건희)_16173630.html
# 처리 중... [444/8175] 20210625_연차 품의서_16174540.html
# 처리 중... [445/8175] 20210625_연차휴가신청_16179184.html
# 처리 중... [446/8175] 20210625_휴가 사용 신청의 건_16173699.html
# 처리 중... [447/8175] 20210625_휴가 신청 품의_16176419.html
# 처리 중... [448/8175] 20210627_연차휴가품의_16181382.html
# 처리 중... [449/8175] 20210628_2021년 6월 29일(화) 연차 휴가 신청합니다_16181959.html
# 처리 중... [450/8175] 20210628_6월 기타 경비 신청합니다_16184061.html
# 처리 중... [451/8175] 20210628_ETRI PMS 실버라이트 제거를 위한 시스템 개선 사업 관련 SpreadJS 선구매 품의_16186338.html
# 처리 중... [452/8175] 20210628_[신규_솔루션](주)한전KPS 지식재산전문 통합관리시스템 구축 매출계약 품의_16186469.html
# 처리 중... [453/8175] 20210628_[외주 PM 명함발급신청]_16183387.html
# 처리 중... [454/8175] 20210628_연차 휴가 신청(7_2, 1일)_16188718.html
# 처리 중... [455/8175] 20210629_06-32 NHN Monitor x 30_16195171.html
# 처리 중... [456/8175] 20210629_06-33 한국신용 Monitor x 10_16195190.html
# 처리 중... [457/8175] 20210629_06-34 이랜드 Monitor, Part x 13_16195212.html
# 처리 중... [458/8175] 20210629_[지출결의] 선급금이행보증증권 납부 승인 요청의 건_16194413.html
# 처리 중... [459/8175] 20210629_국립식량과학원 - 숙소 계약 관련 비용 신청(정정남)_16199203.html
# 처리 중... [460/8175] 20210629_대전지사 출장비 지급 신청_16190948.html
# 처리 중... [461/8175] 20210629_식량과학원 2021년작물연구정보서비스통합위탁관리 외주인원 구매신청 품의_16199199.html
# 처리 중... [462/8175] 20210629_연차 신청합니다_16196583.html
# 처리 중... [463/8175] 20210629_연차신청서(박형남) 입니다._16199126.html
# 처리 중... [464/8175] 20210629_한국콜마 프로젝트 회식비_16190983.html
# 처리 중... [465/8175] 20210629_휴가품의서_16197908.html
# 처리 중... [466/8175] 20210630_6월 야근식대 지급 신청서 올립니다._16208111.html
# 처리 중... [467/8175] 20210630_7월 2일 금요일 연차 사용 신청서_16199633.html
# 처리 중... [468/8175] 20210630_ETRI PMS 실버라이트 제거를 위한 시스템 개선 사업 관련 매출계약 품의_16204396.html
# 처리 중... [469/8175] 20210630_신우진 재직증명서 발금 신청_16205030.html
# 처리 중... [470/8175] 20210630_재직증명서 발급 요청_16205057.html
# 처리 중... [471/8175] 20210630_휴가 신청드립니다._16206345.html
# 처리 중... [472/8175] 20210630_휴가를 신청합니다._16204236.html
# 처리 중... [473/8175] 20210630_휴가신청 품의(송준선, 7_5)_16204944.html
# 처리 중... [474/8175] 20210701_07-01 다우기술 WS, Monitor x 52_16214055.html
# 처리 중... [475/8175] 20210701_07-02 경동나비엔 Server x 1_16214097.html
# 처리 중... [476/8175] 20210701_오전 반차 사용의 건 (7월 2일, 금)_16215743.html
# 처리 중... [477/8175] 20210701_휴가신청 _ 2021-07-02 (금), 1일_16212134.html
# 처리 중... [478/8175] 20210702_07-03 NHN WS, NB, Kit x4_16223432.html
# 처리 중... [479/8175] 20210702_07-04 NHN PC, Monitor, Kit x 31_16223480.html
# 처리 중... [480/8175] 20210702_07-05 이랜드 PC x 10_16223508.html
# 처리 중... [481/8175] 20210702_2021.07.02(금) 오후 반차 사용 신청의 건_16218527.html
# 처리 중... [482/8175] 20210702_신우진 휴가사용 신청서 (21.07.05 오전 반차)_16222759.html
# 처리 중... [483/8175] 20210705_07월 07일 휴가 사용 신청_16232882.html
# 처리 중... [484/8175] 20210705_[교통비]경비청구 요청드립니다._16229309.html
# 처리 중... [485/8175] 20210705_경영기획팀 정재이 - 7_7(수) 연차 신청의 건_16234389.html
# 처리 중... [486/8175] 20210705_반차 신청합니다_16227810.html
# 처리 중... [487/8175] 20210705_반차 휴가 사용 신청서_16231680.html
# 처리 중... [488/8175] 20210705_비품 구매 품의서 올립니다._16236948.html
# 처리 중... [489/8175] 20210705_식량과학원 2021년작물연구정보서비스통합위탁관리 외주인원 구매신청 품의_16232226.html
# 처리 중... [490/8175] 20210705_오전 반차 요청_16232788.html
# 처리 중... [491/8175] 20210705_휴가 사용 신청서 올립니다._16236952.html
# 처리 중... [492/8175] 20210706_6월 출장비 신청의 건_16240936.html
# 처리 중... [493/8175] 20210706_ETRI PMS실버라이트 제거를 위한 시스템개선 관련 검색솔루션 용역 신청 품의_16242932.html
# 처리 중... [494/8175] 20210706_[관세청] 개발용 전용회선비 지급을 품의합니다~_16243145.html
# 처리 중... [495/8175] 20210707_07-06 오렌지아이 Server, Switch x 3_16251043.html
# 처리 중... [496/8175] 20210707_07-07 NHN Monitor x 26_16251131.html
# 처리 중... [497/8175] 20210707_2021-07-09 반차 신청합니다_16253436.html
# 처리 중... [498/8175] 20210707_20210707_사원_경동윤 개인 오후 반차 신청합니다._16246588.html
# 처리 중... [499/8175] 20210707_2021_07_09(금) 연차휴가 신청_16246656.html
# 처리 중... [500/8175] 20210707_오전 반차 신청합니다._16246418.html
# 처리 중... [501/8175] 20210707_휴가신청 품의(송준선, 7_9)_16246660.html
# 처리 중... [502/8175] 20210708_2021-07-09 정서연 휴가 신청합니다 - 1일_16255248.html
# 처리 중... [503/8175] 20210708_2021.07.09(금) 연차휴가 결재요청드립니다._16255365.html
# 처리 중... [504/8175] 20210708_[신규_솔루션]포스코알텍 지재권관리시스템 개발 매출계약 품의_16257697.html
# 처리 중... [505/8175] 20210708_국내상표(DAVINCI) 불사용취소심판 대응 선수금 신청 (21.07.08)_16258422.html
# 처리 중... [506/8175] 20210708_김상욱 휴가 사용 신청서 입니다._16256094.html
# 처리 중... [507/8175] 20210708_휴가 사용 품의_16260414.html
# 처리 중... [508/8175] 20210708_휴가를 신청합니다._16255121.html
# 처리 중... [509/8175] 20210709_07-08 NHN Monitor x 55_16262848.html
# 처리 중... [510/8175] 20210709_07-09 이랜드 Monitor x 10_16262862.html
# 처리 중... [511/8175] 20210709_07-10  나이스 Monitor x 20_16262881.html
# 처리 중... [512/8175] 20210709_07-11 NHN Monitor x 42_16266084.html
# 처리 중... [513/8175] 20210709_김상욱 휴가 사용 신청서 입니다_16266032.html
# 처리 중... [514/8175] 20210709_연차휴가 신청(7_19, 1일)_16265494.html
# 처리 중... [515/8175] 20210709_휴가 사용 신청_16263053.html
# 처리 중... [516/8175] 20210709_휴가 신청합니다._16264156.html
# 처리 중... [517/8175] 20210712_[대금결제] ITO_7월 외주용역비 대금 결제의 건 - 프리랜서_업체 (07_15)_16278375.html
# 처리 중... [518/8175] 20210712_반차 신청합니다_16273776.html
# 처리 중... [519/8175] 20210712_반차 휴가 신청_16273612.html
# 처리 중... [520/8175] 20210712_연차휴가 신청입니다. (7_19)_16278676.html
# 처리 중... [521/8175] 20210712_연차휴가품의서_16273278.html
# 처리 중... [522/8175] 20210712_휴가신청 품의(송준선, 7_19)_16276370.html
# 처리 중... [523/8175] 20210713_(서부발전) 모바일오피스 이중화 솔루션 구매건_16287459.html
# 처리 중... [524/8175] 20210713_[대금결제] 공통_6월 외주용역비 대금 결제의 건_프리랜서 (7_15)_16284831.html
# 처리 중... [525/8175] 20210713_연차휴가 신청_16284438.html
# 처리 중... [526/8175] 20210714_2021-07-23일 휴가 신청합니다_16289997.html
# 처리 중... [527/8175] 20210714_연차 품의서_16288935.html
# 처리 중... [528/8175] 20210714_연차 품의서_16295403.html
# 처리 중... [529/8175] 20210714_휴가 사용 신청서_16289104.html
# 처리 중... [530/8175] 20210715_(S_W) LX하우시스 지적재산관리시스템 키프리스 플러스 연동 개발 및 공급 계약 품의_16297232.html
# 처리 중... [531/8175] 20210715_(기능개선) LX하우시스(구 LG하우시스) 지적재산관리시스템 기능개선 계약품의_16297251.html
# 처리 중... [532/8175] 20210715_07-12 나이스 Server, S_W x 10_16299732.html
# 처리 중... [533/8175] 20210715_07-13 NHN NB, Monitor x 26_16299755.html
# 처리 중... [534/8175] 20210715_07-14 이랜드 Kit, Part x 4_16299767.html
# 처리 중... [535/8175] 20210715_07-15 나이스신용정보 Monitor x 228_16299774.html
# 처리 중... [536/8175] 20210715_[대금결제] 키프리스플러스 LX하우시스(구 LG하우시스) 계정_16302006.html
# 처리 중... [537/8175] 20210715_반차 결재요청_16296615.html
# 처리 중... [538/8175] 20210716_(서부발전) DRM 암복호화 솔루션 구매건_16307841.html
# 처리 중... [539/8175] 20210716_(서부발전) 서버 이중화에 의한 PDF변환 솔루션 구매건_16307793.html
# 처리 중... [540/8175] 20210716_(정책과제_수정) 인큐시스 SMART HACCP 숙성고 S_W 연동기능 개발 (에스이지)_16308513.html
# 처리 중... [541/8175] 20210716_(정책과제_수정) 인큐시스 SMART HACCP 숙성고 컨트롤러 개발 (앤플러그)_16308492.html
# 처리 중... [542/8175] 20210716_2021 하계휴가 사용 신청의 건_16307570.html
# 처리 중... [543/8175] 20210716_2021.07.16(금) 오전 반차 사용 신청의 건_16307522.html
# 처리 중... [544/8175] 20210719_[모바일오피스 고도화 용역] 태블릿PC 구매 품의_16318454.html
# 처리 중... [545/8175] 20210719_결재 요청드립니다_16321090.html
# 처리 중... [546/8175] 20210719_여름휴가 연차신청서(박형남) 입니다._16316621.html
# 처리 중... [547/8175] 20210719_하계 휴가 사용 신청(7월 22일-23일, 2일간)_16313508.html
# 처리 중... [548/8175] 20210719_휴가를 신청합니다._16314040.html
# 처리 중... [549/8175] 20210720_[교보생명 금융마이데이터 시스템구축용역]에 관한 매출_매입 계약품의_16321645.html
# 처리 중... [550/8175] 20210720_대전 원자력연구원 출장비 지급 신청서 입니다_16321967.html
# 처리 중... [551/8175] 20210720_휴가신청 품의(송준선, 7_26 ~ 8_2)_16323363.html
# 처리 중... [552/8175] 20210721_07-16 NHN NB, Monitor x51_16331403.html
# 처리 중... [553/8175] 20210721_07-17 한국신용 Monitor x 3_16331432.html
# 처리 중... [554/8175] 20210721_07-18 천재교육 Part x 1_16333755.html
# 처리 중... [555/8175] 20210721_20210721_사원 경동윤_오후반차 신청합니다._16331462.html
# 처리 중... [556/8175] 20210721_[대금결제] ITO_7월 외주용역비 대금 결제의 건 - 업체 (07_26)_16335084.html
# 처리 중... [557/8175] 20210721_연차 휴가 품의_16332149.html
# 처리 중... [558/8175] 20210721_외주인력 구매신청_16331119.html
# 처리 중... [559/8175] 20210721_하계휴가 신청의 건 (7_28~30, 8_2)_16329792.html
# 처리 중... [560/8175] 20210721_하계휴가 신청합니다._16329973.html
# 처리 중... [561/8175] 20210721_하계휴가 품의서_16330492.html
# 처리 중... [562/8175] 20210721_휴가 사용 신청서 [한상근 사원] 입니다._16335720.html
# 처리 중... [563/8175] 20210721_휴가 사용 신청서 기안합니다._16336927.html
# 처리 중... [564/8175] 20210721_휴가 신청 합니다._16333908.html
# 처리 중... [565/8175] 20210721_휴가 신청드립니다._16332910.html
# 처리 중... [566/8175] 20210722_'21.07.26 연차품의_16342260.html
# 처리 중... [567/8175] 20210722_[대금결제] 공통_6월 외주용역비 대금 결제의 건-(07_25)_16343349.html
# 처리 중... [568/8175] 20210722_개인휴가 _ 2021-07-23 (금) _ 1일_16338693.html
# 처리 중... [569/8175] 20210722_연차 휴가 품의_16340802.html
# 처리 중... [570/8175] 20210722_휴가 사용신청서 품의_16344477.html
# 처리 중... [571/8175] 20210722_휴가 신청_20210723_16337655.html
# 처리 중... [572/8175] 20210722_휴가를 신청합니다._16339273.html
# 처리 중... [573/8175] 20210723_07-19 NHN Monitor x 25_16347844.html
# 처리 중... [574/8175] 20210723_07-20 NHN Monitor x 20_16347849.html
# 처리 중... [575/8175] 20210723_[2021년 연차휴가 사용 요청 드립니다]_16350848.html
# 처리 중... [576/8175] 20210723_[대금 결제] 서부발전 서버 4대 구매 건_유니마이크로테크놀로지(주)_16350417.html
# 처리 중... [577/8175] 20210723_[디지털서비스 전용몰 구축사업] 교통비용 품의_16347859.html
# 처리 중... [578/8175] 20210723_휴가 사용 신청서_16349875.html
# 처리 중... [579/8175] 20210726_2021.07.29(목) 휴가 사용 신청합니다._16353865.html
# 처리 중... [580/8175] 20210726_대중소기업 상생협력기금 종합관리시스템 구축 - 영림원소프트랩 - ERP 추가 개발 완료에 다른 지금 요청의 건(잔금 50%)_16358148.html
# 처리 중... [581/8175] 20210726_연차 휴가 신청(8_3~8_6, 4일)_16360230.html
# 처리 중... [582/8175] 20210726_연차휴가 신청의 건(김우석 선임)_16358065.html
# 처리 중... [583/8175] 20210726_휴가 사용 신청의 건_16354802.html
# 처리 중... [584/8175] 20210726_휴가를 신청합니다._16354858.html
# 처리 중... [585/8175] 20210726_휴가신청서(코로나백신 접종)_16360218.html
# 처리 중... [586/8175] 20210727_2021-07-29 정서연 여름 휴가 신청합니다 - 4일_16368273.html
# 처리 중... [587/8175] 20210727_2021_07_30(금) 연차휴가 신청_16365379.html
# 처리 중... [588/8175] 20210727_7월 기타 경비 신청 합니다_16364023.html
# 처리 중... [589/8175] 20210727_ITO_7월 외주용역비 대금 결제의 건-업체 (07_31)_16365590.html
# 처리 중... [590/8175] 20210727_하계휴가 품의서_16363883.html
# 처리 중... [591/8175] 20210727_휴가 품의서_16367617.html
# 처리 중... [592/8175] 20210728_07-21 OOCI Server x 1_16373582.html
# 처리 중... [593/8175] 20210728_07-22 선익시스템 Part x 1_16373614.html
# 처리 중... [594/8175] 20210728_07-23 다우 Monitor x 2_16373656.html
# 처리 중... [595/8175] 20210728_07-24 토요타 Part x 1_16373689.html
# 처리 중... [596/8175] 20210728_07-25 NHN Monitor x 15_16373701.html
# 처리 중... [597/8175] 20210728_20210803_사원_경동윤 휴가 신청합니다._16371433.html
# 처리 중... [598/8175] 20210728_2021년 7월 30일(금) 연차 휴가 신청합니다_16370407.html
# 처리 중... [599/8175] 20210728_경비 품의 입니다._16382238.html
# 처리 중... [600/8175] 20210728_김상욱 휴가 사용 신청서 입니다._16375259.html
# 처리 중... [601/8175] 20210728_백신 휴가_16374007.html
# 처리 중... [602/8175] 20210728_신우진 휴가(하계휴가 4일) 신청서_16372147.html
# 처리 중... [603/8175] 20210728_연차 사용 신청서 07_30 (금) 1일_16370286.html
# 처리 중... [604/8175] 20210728_연차휴가 결재요청_16375956.html
# 처리 중... [605/8175] 20210728_휴가 사용 신청합니다._16376569.html
# 처리 중... [606/8175] 20210728_휴가를 신청합니다._16386536.html
# 처리 중... [607/8175] 20210729_07-26 NHN Monitor x 15_16391956.html
# 처리 중... [608/8175] 20210729_07-27 한국신용 Monitor x 10_16391985.html
# 처리 중... [609/8175] 20210729_[여름휴가]결재요청 드립니다._16389740.html
# 처리 중... [610/8175] 20210729_[지급품의] 차건호변리사(로키특허법률사무소) 특허출원비용 지급의 건_16387279.html
# 처리 중... [611/8175] 20210729_구매 계약(발주) 품의서(외주인력) - (주)겸유컴퍼니_16390893.html
# 처리 중... [612/8175] 20210729_휴가 사용 신청_16387931.html
# 처리 중... [613/8175] 20210729_휴가 사용 신청서_16389664.html
# 처리 중... [614/8175] 20210730_2021.08.02(월) 연차 품의_16397653.html
# 처리 중... [615/8175] 20210730_여름휴가 신청합니다._16396522.html
# 처리 중... [616/8175] 20210730_휴가 사용 신청합니다._16397721.html
# 처리 중... [617/8175] 20210731_7월 야근식대 지급 신청서 올립니다._16402505.html
# 처리 중... [618/8175] 20210731_결재 요청 드립니다_16402566.html
# 처리 중... [619/8175] 20210802_PATINEX 2021 행사 참가비 신청 (08_02)_16407993.html
# 처리 중... [620/8175] 20210802_김현호 하계휴가 신청건(2021.08.02)_16403803.html
# 처리 중... [621/8175] 20210802_반차 사용(8_3, 오후)_16406835.html
# 처리 중... [622/8175] 20210802_휴가 사용 신청서 올립니다._16411146.html
# 처리 중... [623/8175] 20210802_휴가 사용 신청서(20210804)_16408716.html
# 처리 중... [624/8175] 20210802_휴가 사용 신청의 건_16408817.html
# 처리 중... [625/8175] 20210803_08-01 다우기술 Server x 1_16415290.html
# 처리 중... [626/8175] 20210803_08-02 이랜드 NB, Kit x 16_16415357.html
# 처리 중... [627/8175] 20210803_08-03 NHN NB, Monitor x 49_16415381.html
# 처리 중... [628/8175] 20210803_7월 출장비 신청의 건_16412196.html
# 처리 중... [629/8175] 20210803_8월 5일~8월 6일 휴가 신청합니다._16413376.html
# 처리 중... [630/8175] 20210803_경영기획팀 정재이 - 8_4(수) 연차 신청의 건_16414650.html
# 처리 중... [631/8175] 20210803_기타 경비 신청 (21.08.03)_16417041.html
# 처리 중... [632/8175] 20210804_[동양시스템즈] SI사업본부 - 레져(라운딩) 접대건_16422064.html
# 처리 중... [633/8175] 20210805_연차 휴가 신청 (8_17~8_18, 2일)_16429268.html
# 처리 중... [634/8175] 20210805_하계 휴가 품의_16426138.html
# 처리 중... [635/8175] 20210805_휴가 사용 신청_16429257.html
# 처리 중... [636/8175] 20210805_휴가 신청 드립니다._16427367.html
# 처리 중... [637/8175] 20210805_휴가 신청합니다._16431997.html
# 처리 중... [638/8175] 20210806_08-04 NHN WS, Monitor x 11_16434651.html
# 처리 중... [639/8175] 20210806_08-05 NHN Monitor x 30_16434683.html
# 처리 중... [640/8175] 20210806_08-06 NHN NB, Monitor x 8_16434707.html
# 처리 중... [641/8175] 20210806_[취업통계 조사시스템 유지보수 및 청년 진로정보 시스템 구축사업] 구매 품의_16435557.html
# 처리 중... [642/8175] 20210806_삼성SDI 프로젝트 MS-OFFICE 구매요청서_16435656.html
# 처리 중... [643/8175] 20210806_퇴직 품의_16437136.html
# 처리 중... [644/8175] 20210806_휴가 사용신청서 품의_16434009.html
# 처리 중... [645/8175] 20210809_2021년 8월 11일(수) 오후 반차 휴가 신청합니다_16442755.html
# 처리 중... [646/8175] 20210809_구매 계약(발주) 품의서(외주인력) - (주)아이티혜윰_16445414.html
# 처리 중... [647/8175] 20210809_구매 계약(발주) 품의서(외주인력) - 오픈윈드_16445424.html
# 처리 중... [648/8175] 20210809_김상욱 휴가 사용 신청서_ 입니다. ( 여름휴가 )_16445388.html
# 처리 중... [649/8175] 20210809_여름휴가 결재요청_16445409.html
# 처리 중... [650/8175] 20210809_여름휴가를 신청합니다._16445469.html
# 처리 중... [651/8175] 20210809_연차휴가 신청_16448567.html
# 처리 중... [652/8175] 20210809_연차휴가를 신청합니다._16445443.html
# 처리 중... [653/8175] 20210809_하계 휴가 신청_16447913.html
# 처리 중... [654/8175] 20210809_하계휴가 사용 신청서_16446919.html
# 처리 중... [655/8175] 20210810_(기능개선) LGU+ 지식재산관리시스템 기능개선 계약 품의_16452173.html
# 처리 중... [656/8175] 20210810_08-07 코비젼 Solution x 1_16456285.html
# 처리 중... [657/8175] 20210810_08-08 Atsys Server x 1_16455373.html
# 처리 중... [658/8175] 20210810_08-09 NHN Monitor x 22_16455387.html
# 처리 중... [659/8175] 20210810_ETRI 통합정보시스템(통합문서관리) https 전환 사업 관련 C_P품의_16456143.html
# 처리 중... [660/8175] 20210810_ETRI 통합정보시스템(통합문서관리) https 전환 사업 매출계약 품의_16457537.html
# 처리 중... [661/8175] 20210810_[대금결제] ITO_외주용역비 대금 결제의 건 - 프리랜서_업체 (08_15)_16453442.html
# 처리 중... [662/8175] 20210810_연차 휴가 품의_16452436.html
# 처리 중... [663/8175] 20210810_휴가 사용 신청서_16455524.html
# 처리 중... [664/8175] 20210811_2021-08-11 정서연 휴가 신청합니다 - 0.5일_16461011.html
# 처리 중... [665/8175] 20210811_개인휴가 _ 2021-08-13 (금)_16460300.html
# 처리 중... [666/8175] 20210811_연차 품의서_16462197.html
# 처리 중... [667/8175] 20210811_연차 휴가 사용_16461963.html
# 처리 중... [668/8175] 20210811_오후 반차 사용 신청서 [한상근 사원] 입니다._16461631.html
# 처리 중... [669/8175] 20210811_전진원 사원 휴가 사용 신청서_16460080.html
# 처리 중... [670/8175] 20210811_출산휴가 품의 요청_16466639.html
# 처리 중... [671/8175] 20210811_하계 휴가 신청_16463146.html
# 처리 중... [672/8175] 20210811_하계 휴가(8_17~8_18) 사용 신청._16460249.html
# 처리 중... [673/8175] 20210811_하계휴가 품의_16462062.html
# 처리 중... [674/8175] 20210812_[대금결제] 공통_7월 외주용역비 대금 결제의 건_프리랜서 (8_15)_16470079.html
# 처리 중... [675/8175] 20210812_[디지털서비스 전용몰 구축사업]확정C_P 품의_16470566.html
# 처리 중... [676/8175] 20210812_[조달청]디지털서비스 전용몰 구축사업(RPA) 도입 구매 품의_16470739.html
# 처리 중... [677/8175] 20210813_08-10 NHN WS, Monitor x 23_16475353.html
# 처리 중... [678/8175] 20210813_08-11 NHN Monitor x 42_16475370.html
# 처리 중... [679/8175] 20210813_08-12 이랜드 PC, Kit x 4_16475385.html
# 처리 중... [680/8175] 20210813_연차휴가를 신청합니다._16476289.html
# 처리 중... [681/8175] 20210813_휴가 사용신청서 품의_16477939.html
# 처리 중... [682/8175] 20210816_연차 품의_16483193.html
# 처리 중... [683/8175] 20210817_ETRI 통합정보시스템(통합문서관리) https 전환 관련 구매신청 품의_16487003.html
# 처리 중... [684/8175] 20210817_[재기안] 삼성SDI 프로젝트 MS-OFFICE 구매요청서_16485373.html
# 처리 중... [685/8175] 20210817_연차 휴가 신청(8_23, 1일)_16483584.html
# 처리 중... [686/8175] 20210817_휴가사용품의_16483425.html
# 처리 중... [687/8175] 20210818_반차 사용 품의 드립니다_16492612.html
# 처리 중... [688/8175] 20210819_(기능개선) 한국자동차연구원 목표실적 통계 및 기술이전 프로세스 기능개선 계약 품의_16502541.html
# 처리 중... [689/8175] 20210819_2021년 여름휴가 신청(2021.08.24(화)~27(금))_16500019.html
# 처리 중... [690/8175] 20210819_8월 20일 연차 신청 합니다_16500510.html
# 처리 중... [691/8175] 20210819_여름휴가 품의서_16501064.html
# 처리 중... [692/8175] 20210819_연차사용 신청의 건 (하계휴가)_16501902.html
# 처리 중... [693/8175] 20210819_연차사용 신청의 건_16500040.html
# 처리 중... [694/8175] 20210819_연차휴가품의_16501529.html
# 처리 중... [695/8175] 20210819_오전 반차 및 월차 사용의 건 (8월 26일 오후-27일)_16504675.html
# 처리 중... [696/8175] 20210819_휴가 사용 신청_16504387.html
# 처리 중... [697/8175] 20210820_08-13 NHN NB, Monitor x 33_16509241.html
# 처리 중... [698/8175] 20210820_08-14 NHN Monitor x 20_16509261.html
# 처리 중... [699/8175] 20210820_08-15 토요타 Part x 1_16509285.html
# 처리 중... [700/8175] 20210820_08-16 NHN NB, Monitor x 23_16509307.html
# 처리 중... [701/8175] 20210820_[대금결제] ITO_8월 외주용역비 대금 결제의 건 - 업체 (08_25)_16508596.html
# 처리 중... [702/8175] 20210820_[대금결제] 삼성SDI 특허관리시스템 개선 구축 프로젝트 MS-OFFICE 구매 건_16507876.html
# 처리 중... [703/8175] 20210820_[대금결제] 한국취업통계 조사시스템 유지보수 및 청년 진로정보시스템 구축사업 용역 계약_선금 지급의 건(라온비트)_16509891.html
# 처리 중... [704/8175] 20210820_서부발전 전자회의 솔루션 구매 및 Customizing 도급계약_16510138.html
# 처리 중... [705/8175] 20210820_휴가 사용 신청_16514050.html
# 처리 중... [706/8175] 20210820_휴가 사용 신청합니다._16509088.html
# 처리 중... [707/8175] 20210823_2021년도 하계휴가 신청합니다._16521098.html
# 처리 중... [708/8175] 20210823_[통합연구지원시스템 전문기관 데이터이관 대응사업] 커뮤니티 구매 품의_16521345.html
# 처리 중... [709/8175] 20210823_국내상표(다빈치) 불사용취소심판 대응 비용 신청 (21.08.23)_16517269.html
# 처리 중... [710/8175] 20210823_대전 원자력연구원 출장비 지급 신청서 입니다_16517588.html
# 처리 중... [711/8175] 20210823_반차 사용 신청_16518756.html
# 처리 중... [712/8175] 20210823_휴가 사용 신청서(20210830)_16519460.html
# 처리 중... [713/8175] 20210824_20210827_사원_경동윤_개인휴가신청합니다._16528622.html
# 처리 중... [714/8175] 20210824_8월 27일 (금) 연차 사용 신청합니다._16529116.html
# 처리 중... [715/8175] 20210824_[대금결제] ETRI PMS 실버라이트 제거를 위한 시스템 개선 라이센스 결제품의_16528832.html
# 처리 중... [716/8175] 20210824_[대금결제] 공통_7월 외주용역비 대금 결제의 건-(08_25)_16531496.html
# 처리 중... [717/8175] 20210824_연차 품의서_16524991.html
# 처리 중... [718/8175] 20210824_연차 휴가 신청(8_30, 1일)_16530796.html
# 처리 중... [719/8175] 20210824_연차휴가 신청_16524854.html
# 처리 중... [720/8175] 20210824_휴가 사용 신청의 건_16528333.html
# 처리 중... [721/8175] 20210825_(신규) 한화시스템 2021년 지식재산관리시스템 유지보수 계약 품의_16534561.html
# 처리 중... [722/8175] 20210825_08-17 토요타 유지보수 x 1_16533567.html
# 처리 중... [723/8175] 20210825_08-18 Atsys Server x 1_16533601.html
# 처리 중... [724/8175] 20210825_08-19 경동나비엔 Server x 1_16533629.html
# 처리 중... [725/8175] 20210825_08-20 NHN NB, Monitor x 4_16533650.html
# 처리 중... [726/8175] 20210825_08-21 NHN Monitor x 20_16536224.html
# 처리 중... [727/8175] 20210825_[대금결제] 조달청 디지털서비스전용몰 RPA기반 자동화 구축 계약_선금 지급의 건 (인포비정보기술)_16537961.html
# 처리 중... [728/8175] 20210825_[하계휴가 품의]_16533250.html
# 처리 중... [729/8175] 20210825_월차 사용의 건 (8월 27일)_16533442.html
# 처리 중... [730/8175] 20210825_휴가사용 신청의 건_16534640.html
# 처리 중... [731/8175] 20210826_2021.08.30(월) 연차 품의_16546339.html
# 처리 중... [732/8175] 20210826_8월 교통비 신청합니다_16541153.html
# 처리 중... [733/8175] 20210826_8월 기타 경비 신청 합니다_16541196.html
# 처리 중... [734/8175] 20210826_녹색인증 정보시스템 개선사업의 용역계약 승인요청_16545727.html
# 처리 중... [735/8175] 20210826_연차휴가 신청의 건_16541524.html
# 처리 중... [736/8175] 20210826_오후 반차 신청드립니다._16543172.html
# 처리 중... [737/8175] 20210827_[대금결제] 2021년 녹색인증 정보시스템 개선 용역_선금 지급의 건(모렌소프트)_16552560.html
# 처리 중... [738/8175] 20210827_[대금결제] ETRI 통합정보시스템(통합문서관리) https전환_선금 지급의 건 (사이버다임)_16552282.html
# 처리 중... [739/8175] 20210827_[대금결제] 한국서부발전 태블릿PC 5대 북커버 및 로고 인쇄 비용_16552199.html
# 처리 중... [740/8175] 20210827_서부발전 태블릿 북커버 샘플 구매 신청 품의 (21.08.27)_16548875.html
# 처리 중... [741/8175] 20210827_오후 반차 신청합니다._16548251.html
# 처리 중... [742/8175] 20210830_2021년 9월 2일(목) ~ 2021년 9월 7일(화) 하계 휴가 신청합니다_16556491.html
# 처리 중... [743/8175] 20210830_ITO_8월 외주용역비 대금 결제의 건-업체 (08_31) _#2_16556761.html
# 처리 중... [744/8175] 20210830_[연차신청] 김우석 선임 연차1일 사용의 건_16559754.html
# 처리 중... [745/8175] 20210830_경영기획팀 정재이 - 9_2~9_3(목~금) 여름휴가 신청의 건_16557747.html
# 처리 중... [746/8175] 20210830_연차신청서(박형남) 입니다._16564817.html
# 처리 중... [747/8175] 20210830_인감도장 사용 품의서 (전주대 빅데이터 플랫폼)_16560189.html
# 처리 중... [748/8175] 20210831_08-22 NHN Monitor x 30_16566509.html
# 처리 중... [749/8175] 20210831_08-23 나이스 Cable x 120_16566550.html
# 처리 중... [750/8175] 20210831_반차 사용 신청_16565637.html
# 처리 중... [751/8175] 20210831_휴가 신청합니다._16565555.html
# 처리 중... [752/8175] 20210901_8월 출장비 신청의 건_16575229.html
# 처리 중... [753/8175] 20210901_[2021년 8월 경비신청서 입니다]_16573988.html
# 처리 중... [754/8175] 20210901_연차 사용 품의_16579114.html
# 처리 중... [755/8175] 20210901_휴가를 신청합니다._16577766.html
# 처리 중... [756/8175] 20210902_2021.09.06(월), 09.07(화) 오전 반차 휴가 신청(자격증 시험)_16586706.html
# 처리 중... [757/8175] 20210902_개인휴가 _ 2021-09-03(금), 1일_16584259.html
# 처리 중... [758/8175] 20210902_김상욱 휴가 사용 신청서_ 입니다._16590692.html
# 처리 중... [759/8175] 20210902_반차 사용 품의 드립니다._16590330.html
# 처리 중... [760/8175] 20210902_연차 휴가 신청(9_10, 1일)_16583597.html
# 처리 중... [761/8175] 20210902_오후반차 품의_16585074.html
# 처리 중... [762/8175] 20210903_09-01 42Dot NB x 1_16594741.html
# ...
# 처리 중... [7984/8175] 20250924_금융ITO연합회 워크숍 경비신청_26208172.html
# 처리 중... [7985/8175] 20250924_연차 사용 신청_26206307.html
# 처리 중... [7986/8175] 20250924_휴가 신청서 올립니다._26204849.html
# 처리 중... [7987/8175] 20250924_휴가 신청합니다. (2025년 09월 24일 오후)_26202354.html
# 처리 중... [7988/8175] 20250925_2025-10-10, 10-13 정서연 휴가 신청합니다 - 2일_26211312.html
# 처리 중... [7989/8175] 20250925_구매 계약(발주) 품의서(S_W,H_W)_PI첨단소재_특허관리시스템(IPMS) 구축_검색엔진(다이퀘스트-마리너3)_26216117.html
# 처리 중... [7990/8175] 20250925_신우진 연차휴가 사용 신청(25.09.30 화 , 1)_26218847.html
# 처리 중... [7991/8175] 20250925_연차휴가사후품의_26216993.html
# 처리 중... [7992/8175] 20250925_연차휴가품의_26217025.html
# 처리 중... [7993/8175] 20250925_출장비 지급 신청서_한국지질자원연구원 지식재산권관리시스템 DB전환사업 제안평가 참석의 건_26217628.html
# 처리 중... [7994/8175] 20250925_휴가 사용 신청서_26214220.html
# 처리 중... [7995/8175] 20250925_휴가 사용 신청서_이의환 책임_26216594.html
# 처리 중... [7996/8175] 20250925_휴가 신청합니다. (2025년 09월 25일 오후)_26212848.html
# 처리 중... [7997/8175] 20250926_2025.10.02(목) 연차휴가 사용 신청_26223031.html
# 처리 중... [7998/8175] 20250926_9월 26일(금) 오후 반차(0.5일) 사용 신청_26220701.html
# 처리 중... [7999/8175] 20250926_가산퍼블릭 숙소 계약 관련 인감 반출 품의 건._26221955.html
# 처리 중... [8000/8175] 20250926_숙소_가산버플릭 1401호 계약 품의_26222545.html
# 처리 중... [8001/8175] 20250926_연차사용 신청의 건_26222513.html
# 처리 중... [8002/8175] 20250926_휴가신청_26219870.html
# 처리 중... [8003/8175] 20250929_2025-09-29 임민규 휴가 신청서 올립니다._26235966.html
# 처리 중... [8004/8175] 20250929_2025년 10월 10일(금) - 1일_26232813.html
# 처리 중... [8005/8175] 20250929_9월 교통비_26235458.html
# 처리 중... [8006/8175] 20250929_9월 기타 경비 신청합니다_26235482.html
# 처리 중... [8007/8175] 20250929_[대금결제] 9월 외주용역비 대금 결제의 건(DX사업팀)_프리랜서,업체 (10_15)_26235605.html
# 처리 중... [8008/8175] 20250929_[대금결제] 9월 외주용역비 대금 결제의 건(IP솔루션팀)_프리랜서,업체 (10_15)_26235180.html
# 처리 중... [8009/8175] 20250929_[대금결제] 9월 외주용역비 대금 결제의 건(공공사업팀)_프리랜서 (10_15)_26235524.html
# 처리 중... [8010/8175] 20250929_[대금결제] 9월 외주용역비 대금 결제의 건(공통)_업체 (10_15)_26234982.html
# 처리 중... [8011/8175] 20250929_김상욱 휴가 사용 신청서_26234657.html
# 처리 중... [8012/8175] 20250929_김화연 휴가사용 신청 품의(2025.10.10)_26234839.html
# 처리 중... [8013/8175] 20250929_변경 계약(발주) 품의서(외주인력)_외주_올댓휴먼_서영준_리앤목_통합정보시스템 구축(250401~260331)_26235538.html
# 처리 중... [8014/8175] 20250929_연차 휴가 품의_26233237.html
# 처리 중... [8015/8175] 20250929_연차휴가 사용신청_26235914.html
# 처리 중... [8016/8175] 20250929_연차휴가품의_26234341.html
# 처리 중... [8017/8175] 20250929_회의실 테이블_의자 대금지급 요청드립니다._26238356.html
# 처리 중... [8018/8175] 20250929_휴가 사용 신청_김별님_26232749.html
# 처리 중... [8019/8175] 20250929_휴가사용 품의(10_10, 송준선)_26233023.html
# 처리 중... [8020/8175] 20250930_09-12 NHN Monitor x 30_26241814.html
# 처리 중... [8021/8175] 20250930_09-13 Monitor x 31_26241856.html
# 처리 중... [8022/8175] 20250930_09-14 나이스 Server x 3_26241882.html
# 처리 중... [8023/8175] 20250930_09-15 나이스 PC x 10_26241916.html
# 처리 중... [8024/8175] 20250930_10월 10일(금), 연차휴가 신청_26242570.html
# 처리 중... [8025/8175] 20250930_10월 17일 반차, 10월 22일 반차, 10월 27일 연차 신청합니다._26241286.html
# 처리 중... [8026/8175] 20250930_10월 2일(목) 연차 사용 신청_26249113.html
# 처리 중... [8027/8175] 20250930_2025-09-30 김지연 휴가 신청합니다 - 오후반차_26241284.html
# 처리 중... [8028/8175] 20250930_2025-10-10 (금) 김빌리_연차휴가 (1일)_26243999.html
# 처리 중... [8029/8175] 20250930_2025.10.10(금) 연차휴가 신청의 건_26246634.html
# 처리 중... [8030/8175] 20250930_2025.11.01. ~ 2026.04.30. (6개월) 육아휴직 신청_26242072.html
# 처리 중... [8031/8175] 20250930_2025년 10월 1일 윤영현 휴가 신청합니다. - 1일_26241320.html
# 처리 중... [8032/8175] 20250930_9월 30일 오후 반차_26247401.html
# 처리 중... [8033/8175] 20250930_[대금결제] 한국연구재단_2024년 NRF 정보시스템 통합 위탁운영_2025년 9월분 대금 지급의 건_26249499.html
# 처리 중... [8034/8175] 20250930_연차 신청합니다 (10_10)_26242729.html
# 처리 중... [8035/8175] 20250930_연차 품의서_26241493.html
# 처리 중... [8036/8175] 20250930_연차 휴가 신청 (10_10 1일)_26248067.html
# 처리 중... [8037/8175] 20250930_이지남_휴가 사용 신청서(10_2)_26243419.html
# 처리 중... [8038/8175] 20250930_휴가 사용 신청_26242079.html
# 처리 중... [8039/8175] 20250930_휴가 사용신청(10_10)_26246060.html
# 처리 중... [8040/8175] 20250930_휴가를 신청합니다._26242819.html
# 처리 중... [8041/8175] 20251001_10월 10일(금) 연차 신청_26252439.html
# 처리 중... [8042/8175] 20251001_10월 10일(목) 연차 신청_26256336.html
# 처리 중... [8043/8175] 20251001_20251010_연차 신청 합니다_26258416.html
# 처리 중... [8044/8175] 20251001_25.10.16 - 유민경 사원 연차 신청서_26255832.html
# 처리 중... [8045/8175] 20251001_[개발팀] 박종호 사원 휴가 신청_26255175.html
# 처리 중... [8046/8175] 20251001_다우오피스 (그룹웨어) 프로그램 도입(교체) 건_26261113.html
# 처리 중... [8047/8175] 20251001_다우오피스(그룹웨어) 설치비 선금 지급요청_26262500.html
# 처리 중... [8048/8175] 20251001_반차 휴가 품의_26252923.html
# 처리 중... [8049/8175] 20251001_반차사용 품의_26252599.html
# 처리 중... [8050/8175] 20251001_연차 사용 품의 - 신성호_26257774.html
# 처리 중... [8051/8175] 20251001_연차 휴가 신청(10_10, 1일)_26261770.html
# 처리 중... [8052/8175] 20251001_연차 휴가 신청(10_31, 1일)_26256911.html
# 처리 중... [8053/8175] 20251001_연차휴가 신청_26260829.html
# 처리 중... [8054/8175] 20251001_오후 반차 신청 (20251001)_26252988.html
# 처리 중... [8055/8175] 20251001_오후반차 휴가 신청서_26253484.html
# 처리 중... [8056/8175] 20251001_접대비 사용 품의서_20250902_26259211.html
# 처리 중... [8057/8175] 20251001_휴가 사용 신청_26260949.html
# 처리 중... [8058/8175] 20251001_휴가 사용 신청서 [한상근 선임] 입니다._26256484.html
# 처리 중... [8059/8175] 20251001_휴가 사용 신청서_26260799.html
# 처리 중... [8060/8175] 20251002_10_10(금) 휴가 신청_26273095.html
# 처리 중... [8061/8175] 20251002_2025년 10월 10일 연차 휴가 신청_26269665.html
# 처리 중... [8062/8175] 20251002_2025년 10월 2일, 13일 - 1.5일_26270669.html
# 처리 중... [8063/8175] 20251002_[구매-외주] KIAT 유지관리 사업 인력 계약 변경의 건(황제훈)_26272462.html
# 처리 중... [8064/8175] 20251002_[대금결제] ITO_10월 외주용역비 대금 결제의 건 (10_15)_26270327.html
# 처리 중... [8065/8175] 20251002_[휴가신청] 임현준(10_10, 금)_26271945.html
# 처리 중... [8066/8175] 20251002_김상욱 에트리 지재권시스템 기능개선 출장 품의_26269002.html
# 처리 중... [8067/8175] 20251002_연차품의신청_26273212.html
# 처리 중... [8068/8175] 20251002_휴가 사용 신청_26274723.html
# 처리 중... [8069/8175] 20251002_휴가 사용 신청서_이의환 책임_26273064.html
# 처리 중... [8070/8175] 20251002_휴가 신청_26266664.html
# 처리 중... [8071/8175] 20251002_휴가사용신청_2025년 10월 10일(금)_연차휴가(1일)_26273417.html
# 처리 중... [8072/8175] 20251002_휴가신청품의_26273409.html
# 처리 중... [8073/8175] 20251009_[매입] KIAT 2025년 정보시스템 데이터센터 통합 운영 및 유지보수 매입 - 전기케이블 포설_26278490.html
# 처리 중... [8074/8175] 20251010_2025년 10월 31일 반차 신청_이민영 사원_26282874.html
# 처리 중... [8075/8175] 20251010_2025년 11월 3일 연차 신청_이민영 사원_26282890.html
# 처리 중... [8076/8175] 20251010_김보라_휴가 사용 신청서(10_15)_26280317.html
# 처리 중... [8077/8175] 20251013_(LG전) 야근식대 지급 신청_26288190.html
# 처리 중... [8078/8175] 20251013_2025년 11월 03일(월) - 1일_26292290.html
# 처리 중... [8079/8175] 20251013_[대금결제] 9월 외주용역비 대금 결제의 건(DX사업팀)_프리랜서,업체 (10_15)_26294261.html
# 처리 중... [8080/8175] 20251013_김상욱 에트리 출장비 지급 신청서_8월_26291955.html
# 처리 중... [8081/8175] 20251014_2025 KINPA 행사 컨퍼런스백 제작 비용_메가플러스(10_14)_26307756.html
# 처리 중... [8082/8175] 20251014_20251015, 20251023 사원 이규범 개인휴가 신청합니다_26302267.html
# 처리 중... [8083/8175] 20251014_비품 구매의 건_26305944.html
# 처리 중... [8084/8175] 20251014_연차 품의서_26302052.html
# 처리 중... [8085/8175] 20251014_전산실이전 및 재구축(용역비,P770 기술지원비) 매출품의_26302742.html
# 처리 중... [8086/8175] 20251014_한국원자력연구원 출장 품의_26302211.html
# 처리 중... [8087/8175] 20251014_휴가 신청건_26300325.html
# 처리 중... [8088/8175] 20251014_휴가 신청합니다._26300301.html
# 처리 중... [8089/8175] 20251015_25.10.28 ~ 25.10.31 - 유민경 사원 연차 신청서_26317968.html
# 처리 중... [8090/8175] 20251015_[한국원자력연구원] 대전 원자력연구원 방문_26310393.html
# 처리 중... [8091/8175] 20251015_김상욱 에트리 출장비 지급 신청서_9월_26312747.html
# 처리 중... [8092/8175] 20251015_반차 휴가 품의서_26315116.html
# 처리 중... [8093/8175] 20251015_야근식대 지급 신청서 [한상근 선임] 입니다._26313613.html
# 처리 중... [8094/8175] 20251015_연차 품의서_26313340.html
# 처리 중... [8095/8175] 20251016_[ATC+과제]간접비_CES2026 공동관 참가 비용(1차)_아이엠월드_26322481.html
# 처리 중... [8096/8175] 20251016_[선박의장]대금결제_연구시설장비비_GPU 서버 업그레이드_한국렌탈_26322351.html
# 처리 중... [8097/8175] 20251016_매출 계약 품의서_한국에너지공과대학교_지식재산권 관리시스템 고도화 용역_26319584.html
# 처리 중... [8098/8175] 20251016_반차 휴가 품의_26327041.html
# 처리 중... [8099/8175] 20251017_10-01 NHN PC, Monitor x 32_26329166.html
# 처리 중... [8100/8175] 20251017_10-02 NHN Monitor x 50_26329187.html
# 처리 중... [8101/8175] 20251017_10_21(화) 오전 반차 신청_26330129.html
# 처리 중... [8102/8175] 20251017_10월 27일(월)~28(화) 연차 신청_26330079.html
# 처리 중... [8103/8175] 20251017_10월 KR-01호 ㈜다우기술  P2725DE _ 2EA 발주의 건_26329168.html
# 처리 중... [8104/8175] 20251017_[ATC+과제]대금결제_간접비_CES2026 공동관 참가 비용(1차)_아이엠월드_26332959.html
# 처리 중... [8105/8175] 20251017_김상욱 휴가 사용 신청서 입니다._26328382.html
# 처리 중... [8106/8175] 20251017_반차 휴가 품의_26329871.html
# 처리 중... [8107/8175] 20251017_연차 사용 품의 - 신성호_26328007.html
# 처리 중... [8108/8175] 20251017_연차 사용 품의(오후반차) - 신성호_26328028.html
# 처리 중... [8109/8175] 20251018_10월 22일, 31일 휴가신청합니다._26336187.html
# 처리 중... [8110/8175] 20251019_휴가 사용 신청서_김상호_26337020.html
# 처리 중... [8111/8175] 20251020_2025 KINPA 행사 경품 구매 및 물품 대여 비용 (10_20)_26344398.html
# 처리 중... [8112/8175] 20251020_[대금결제] 9월 도급비용 대금 결제의 건(공통)_업체 (10_25)_26342715.html
# 처리 중... [8113/8175] 20251020_[대금결제] 9월 외주용역비 대금 결제의 건(DX사업본부_발진회)_업체 (10_25)_26342951.html
# 처리 중... [8114/8175] 20251020_[대금결제] 9월 외주용역비 대금 결제의 건(DX사업팀)_업체 (10_25)_26343185.html
# 처리 중... [8115/8175] 20251020_[대금결제] 9월 외주용역비 대금 결제의 건(ETRI팀)_업체 (10_25)_26343397.html
# 처리 중... [8116/8175] 20251020_[대금결제] 9월 외주용역비 대금 결제의 건(IP솔루션팀)_업체 (10_25)_26342824.html
# 처리 중... [8117/8175] 20251020_[대금결제] 9월 외주용역비 대금 결제의 건(공공사업팀)_업체 (10_25)_26343084.html
# 처리 중... [8118/8175] 20251020_[대금결제] ETRI 통합정보(ETRIware) 유지관리 계약 - 2025년 9월분 대금 지급의 건_26343687.html
# 처리 중... [8119/8175] 20251020_연차 품의서_26337844.html
# 처리 중... [8120/8175] 20251020_연차 품의서_26338607.html
# 처리 중... [8121/8175] 20251020_휴가 신청합니다._26339547.html
# 처리 중... [8122/8175] 20251021_10월 KR-02호 ㈜다우기술  P2725DE _ 10EA 발주의 건_26349251.html
# 처리 중... [8123/8175] 20251021_[대금결제] Dell 사업 매입 대금 결제의 건-에스씨지솔루션즈 외(9월)_26352776.html
# 처리 중... [8124/8175] 20251021_[대금결제] ITO_10월 외주용역비 대금 결제의 건 (10_25)_26352114.html
# 처리 중... [8125/8175] 20251021_[대금결제] 연차등록료(2025년 11월)수수료지급_원니스(10_25)_26352029.html
# 처리 중... [8126/8175] 20251021_[대금결제] 연차료 사업 관납료 대금 결제의 건-원니스(2025.12월_4분기추가)_26352187.html
# 처리 중... [8127/8175] 20251021_[대금결제] 자동차손해배상진흥원_감시감독관리시스템 구축_WEB_WAS_DB 서버 구축 - 필라테크_26350336.html
# 처리 중... [8128/8175] 20251021_[대금결제] 차세대융합기술연구원 통합정보시스템 유지관리 계약 - 2025년 9월분 대금 지급의 건_26348387.html
# 처리 중... [8129/8175] 20251021_[대금결제] 축산물품질평가원 통합유지보수 계약_9월분 대금 지급의 건_26349404.html
# 처리 중... [8130/8175] 20251021_[대금결제] 한국산업기술진흥원 데이터센터 통합 운영 및 유지보수_2025년 9월분 대금 지급의 건_26352223.html
# 처리 중... [8131/8175] 20251021_[대금결제] 한국연구재단 클라우드 네이티브 전환사업_개발용PC렌탈(연장)_한국렌탈(주)_26349877.html
# 처리 중... [8132/8175] 20251021_연차 품의서_26347874.html
# 처리 중... [8133/8175] 20251021_퇴직 품의서 결재 요청드립니다._26353974.html
# 처리 중... [8134/8175] 20251021_휴가 신청_26348466.html
# 처리 중... [8135/8175] 20251022_[개발팀] 박종호 사원 휴가 신청_26362912.html
# 처리 중... [8136/8175] 20251022_[휴가사용신청서] 연차 휴가 신청_박종아 25년 10월 27일(월)_26360477.html
# 처리 중... [8137/8175] 20251022_신우진 연차휴가 사용 신청(25.10.22, 1일)_26361165.html
# 처리 중... [8138/8175] 20251022_연차 사용 신청_26362273.html
# 처리 중... [8139/8175] 20251023_반차 신청드립니다._26369146.html
# 처리 중... [8140/8175] 20251023_세종 축평원 IT지원실 레이저프린터 토너 구매 신청 건_26365219.html
# 처리 중... [8141/8175] 20251023_연차 휴가 품의서_26370939.html
# 처리 중... [8142/8175] 20251023_출장비 지급 신청서_26367271.html
# 처리 중... [8143/8175] 20251023_휴가사용 품의(10_27, 송준선)_26371563.html
# 처리 중... [8144/8175] 20251024_연차 품의서_26375598.html
# 처리 중... [8145/8175] 20251024_연차 품의서_26376310.html
# 처리 중... [8146/8175] 20251024_연차 품의서_26376738.html
# 처리 중... [8147/8175] 20251024_연차 휴가 품의_26374932.html
# 처리 중... [8148/8175] 20251024_오후 반차 휴가 신청 (10_24 1일)_26373770.html
# 처리 중... [8149/8175] 20251024_휴가 신청합니다. (2025년 10월 24일 오전 _ 0.5일)_26373581.html
# 처리 중... [8150/8175] 20251026_연차 사용 신청_26381761.html
# 처리 중... [8151/8175] 20251027_10월 KR-03호 오오씨아이㈜  HBA355e x 2set 발주의 건_26387592.html
# 처리 중... [8152/8175] 20251027_기타 경비 신청_26383540.html
# 처리 중... [8153/8175] 20251027_신우진 연차휴가 사용 신청(25.11.03~11.04 2일)_26384640.html
# 처리 중... [8154/8175] 20251027_연차 품의서_26383472.html
# 처리 중... [8155/8175] 20251027_휴가 사용 신청드립니다._26382907.html
# 처리 중... [8156/8175] 20251028_10-03 NHN PC, Monitor x 12_26393516.html
# 처리 중... [8157/8175] 20251028_10-04 NHN Monitor x 50_26393540.html
# 처리 중... [8158/8175] 20251028_10-05 한화손보 Monitor x 1_26393568.html
# 처리 중... [8159/8175] 20251028_10월 KR-04호 다우데이타 P2425D _ 7EA 외 발주의 건_26397080.html
# 처리 중... [8160/8175] 20251028_2025년 10월 28일 윤영현 휴가 신청합니다. - 0.5일_26392919.html
# 처리 중... [8161/8175] 20251028_반차 사용신청(10_31, 오후)_26394835.html
# 처리 중... [8162/8175] 20251028_본사 출장비 신청의 건_26394912.html
# 처리 중... [8163/8175] 20251028_숙소 공과금 납부의 건._26395343.html
# 처리 중... [8164/8175] 20251028_휴가 사용 신청의 건_26394789.html
# 처리 중... [8165/8175] 20251029_개발자 교육용 서적 구매 신청 _ 이것이 Spring AI다 (한빛미디어 출판, 신용권 지음) 4권_26405557.html
# 처리 중... [8166/8175] 20251029_연차 휴가 품의_26402005.html
# 처리 중... [8167/8175] 20251030_(LG전자) 프로젝트팀 회식비 품의_26418339.html
# 처리 중... [8168/8175] 20251030_10월 교통비_26412980.html
# 처리 중... [8169/8175] 20251030_10월 기타 경비 신청합니다_26412997.html
# 처리 중... [8170/8175] 20251030_2025-10-30 임민규 휴가 신청서 올립니다._26415193.html
# 처리 중... [8171/8175] 20251030_2025.10.31(금) 연차휴가 신청의 건_26412538.html
# 처리 중... [8172/8175] 20251030_김상욱 에트리 출장비 지급 신청서_10월_26413296.html
# 처리 중... [8173/8175] 20251030_연차 사용_26415581.html
# 처리 중... [8174/8175] 20251031_2025-10-31 김지연 휴가 신청합니다 - 오후반차_26418857.html
# 처리 중... [8175/8175] 20251031_휴가 사용 신청_26418663.html
# JSON 파일 저장 완료: two_htmltojsondb_convert.json
#
# ==================================================
#
# === DB 연결 시작 ===
# Host: localhost, Database: any_approval
# ✓ DB 연결 성공
#
# === 테이블 생성 시작 ===
# ✓ 테이블 생성/확인 완료
# ✓ 기존 데이터: 0건
#
# === 데이터 삽입 시작 (8175건) ===
#   진행: 100/8175 (성공: 100, 실패: 0)
#   진행: 200/8175 (성공: 200, 실패: 0)
#   진행: 300/8175 (성공: 300, 실패: 0)
#   진행: 400/8175 (성공: 400, 실패: 0)
#   진행: 500/8175 (성공: 500, 실패: 0)
#   진행: 600/8175 (성공: 600, 실패: 0)
#   진행: 700/8175 (성공: 700, 실패: 0)
#   진행: 800/8175 (성공: 800, 실패: 0)
#   진행: 900/8175 (성공: 900, 실패: 0)
#   진행: 1000/8175 (성공: 1000, 실패: 0)
#   진행: 1100/8175 (성공: 1100, 실패: 0)
#   진행: 1200/8175 (성공: 1200, 실패: 0)
#   진행: 1300/8175 (성공: 1300, 실패: 0)
#   진행: 1400/8175 (성공: 1400, 실패: 0)
#   진행: 1500/8175 (성공: 1500, 실패: 0)
#   진행: 1600/8175 (성공: 1600, 실패: 0)
#   진행: 1700/8175 (성공: 1700, 실패: 0)
#   진행: 1800/8175 (성공: 1800, 실패: 0)
#   진행: 1900/8175 (성공: 1900, 실패: 0)
#   진행: 2000/8175 (성공: 2000, 실패: 0)
#   진행: 2100/8175 (성공: 2100, 실패: 0)
#   진행: 2200/8175 (성공: 2200, 실패: 0)
#   진행: 2300/8175 (성공: 2300, 실패: 0)
#   진행: 2400/8175 (성공: 2400, 실패: 0)
#   진행: 2500/8175 (성공: 2500, 실패: 0)
#   진행: 2600/8175 (성공: 2600, 실패: 0)
#   진행: 2700/8175 (성공: 2700, 실패: 0)
#   진행: 2800/8175 (성공: 2800, 실패: 0)
#   진행: 2900/8175 (성공: 2900, 실패: 0)
#   진행: 3000/8175 (성공: 3000, 실패: 0)
#   진행: 3100/8175 (성공: 3100, 실패: 0)
#   진행: 3200/8175 (성공: 3200, 실패: 0)
#   진행: 3300/8175 (성공: 3300, 실패: 0)
#   진행: 3400/8175 (성공: 3400, 실패: 0)
#   진행: 3500/8175 (성공: 3500, 실패: 0)
#   진행: 3600/8175 (성공: 3600, 실패: 0)
#   진행: 3700/8175 (성공: 3700, 실패: 0)
#   진행: 3800/8175 (성공: 3800, 실패: 0)
#   진행: 3900/8175 (성공: 3900, 실패: 0)
#   진행: 4000/8175 (성공: 4000, 실패: 0)
#   진행: 4100/8175 (성공: 4100, 실패: 0)
#   진행: 4200/8175 (성공: 4200, 실패: 0)
#   진행: 4300/8175 (성공: 4300, 실패: 0)
#   진행: 4400/8175 (성공: 4400, 실패: 0)
#   진행: 4500/8175 (성공: 4500, 실패: 0)
#   진행: 4600/8175 (성공: 4600, 실패: 0)
#   진행: 4700/8175 (성공: 4700, 실패: 0)
#   진행: 4800/8175 (성공: 4800, 실패: 0)
#   진행: 4900/8175 (성공: 4900, 실패: 0)
#   진행: 5000/8175 (성공: 5000, 실패: 0)
#   진행: 5100/8175 (성공: 5100, 실패: 0)
#   진행: 5200/8175 (성공: 5200, 실패: 0)
#   진행: 5300/8175 (성공: 5300, 실패: 0)
#   진행: 5400/8175 (성공: 5400, 실패: 0)
#   진행: 5500/8175 (성공: 5500, 실패: 0)
#   진행: 5600/8175 (성공: 5600, 실패: 0)
#   진행: 5700/8175 (성공: 5700, 실패: 0)
#   진행: 5800/8175 (성공: 5800, 실패: 0)
#   진행: 5900/8175 (성공: 5900, 실패: 0)
#   진행: 6000/8175 (성공: 6000, 실패: 0)
#   진행: 6100/8175 (성공: 6100, 실패: 0)
#   진행: 6200/8175 (성공: 6200, 실패: 0)
#   진행: 6300/8175 (성공: 6300, 실패: 0)
#   진행: 6400/8175 (성공: 6400, 실패: 0)
#   진행: 6500/8175 (성공: 6500, 실패: 0)
#   진행: 6600/8175 (성공: 6600, 실패: 0)
#   진행: 6700/8175 (성공: 6700, 실패: 0)
#   진행: 6800/8175 (성공: 6800, 실패: 0)
#   진행: 6900/8175 (성공: 6900, 실패: 0)
#   진행: 7000/8175 (성공: 7000, 실패: 0)
#   진행: 7100/8175 (성공: 7100, 실패: 0)
#   진행: 7200/8175 (성공: 7200, 실패: 0)
#   진행: 7300/8175 (성공: 7300, 실패: 0)
#   진행: 7400/8175 (성공: 7400, 실패: 0)
#   진행: 7500/8175 (성공: 7500, 실패: 0)
#   진행: 7600/8175 (성공: 7600, 실패: 0)
#   진행: 7700/8175 (성공: 7700, 실패: 0)
#   진행: 7800/8175 (성공: 7800, 실패: 0)
#   진행: 7900/8175 (성공: 7900, 실패: 0)
#   진행: 8000/8175 (성공: 8000, 실패: 0)
#   진행: 8100/8175 (성공: 8100, 실패: 0)
#   진행: 8175/8175 (성공: 8175, 실패: 0)
#
# === 커밋 시작 ===
# ✓ 커밋 완료
#
# === 결과 요약 ===
# ✓ 성공: 8175건
# ✗ 실패: 0건
#
# ✓ 최종 데이터: 8175건 (이번 실행으로 8175건 추가)
#
# ✓ DB 연결 종료
# ==================================================
#
# 완료! 총 8175건 처리됨

# %%
# + type이 합의인것만 - AGREEMENT로 변경

# 디비 저장 오류 수정 

import os
import json
import re
from datetime import datetime
from bs4 import BeautifulSoup
import pymysql
from pathlib import Path

class ApprovalDocParser:
    def __init__(self, base_path):
        self.base_path = base_path
        
    def extract_source_id(self, filename):
        """파일명에서 마지막 숫자 추출"""
        numbers = re.findall(r'\d+', filename)
        return numbers[-1] if numbers else None
    
    def parse_datetime_to_unix(self, date_str):
        """날짜 문자열을 Unix timestamp(밀리초)로 변환"""
        try:
            dt = datetime.strptime(date_str.strip(), "%Y-%m-%d %H:%M:%S")
            return int(dt.timestamp() * 1000)
        except:
            return None
    
    def extract_person_info(self, text):
        """이름/직책/부서 형식에서 정보 추출"""
        text = re.sub(r'\d+', '', text).strip()
        parts = text.split('/')
        if len(parts) >= 3:
            return {
                'name': parts[0].strip(),
                'positionName': parts[1].strip(),
                'deptName': parts[2].strip()
            }
        return None
    
    def parse_html(self, html_path):
        """HTML 파일 파싱"""
        with open(html_path, 'r', encoding='utf-8') as f:
            soup = BeautifulSoup(f.read(), 'html.parser')
        
        filename = os.path.basename(html_path)
        source_id = self.extract_source_id(filename)
        
        doc_num_elem = soup.find('p', class_='team')
        doc_num = doc_num_elem.get_text(strip=True) if doc_num_elem else ""
        
        references_elem = soup.find('span', class_='disInline o-i-min-fileList')
        references = []
        if references_elem:
            next_elem = references_elem.find_next_sibling()
            if next_elem:
                references = next_elem.get_text(strip=True)
            else:
                parent = references_elem.parent
                references = parent.get_text(strip=True)
        
        title_elem = soup.find('title')
        title = title_elem.get_text(strip=True) if title_elem else ""
        
        attaches = []
        verti_tops = soup.find_all('span', class_='verti_Top')
        for vt in verti_tops:
            a_tag = vt.find('a')
            if a_tag and a_tag.get('href'):
                attaches.append({
                    'name': a_tag.get_text(strip=True),
                    'path': a_tag.get('href')
                })
        
        user_spans = soup.find_all('span', class_='user')
        drafter = {}
        if user_spans:
            first_user = user_spans[0]
            name_elem = first_user.find('span', class_='F_12_black_b')
            if name_elem:
                info = self.extract_person_info(name_elem.get_text(strip=True))
                if info:
                    drafter = {
                        'positionName': info['positionName'],
                        'deptName': info['deptName'],
                        'name': info['name'],
                        'emailId': '',
                        'deptCode': ''
                    }
        
        created_at = None
        if user_spans:
            date_elem = user_spans[0].find('span', class_='F_11_gray')
            if date_elem:
                created_at = self.parse_datetime_to_unix(date_elem.get_text(strip=True))
        
        referrers = []
        ref_th = soup.find('th', string=lambda s: s and '참조' in s)
        if ref_th:
            ref_td = ref_th.find_next_sibling('td')
            if ref_td:
                ref_text = ref_td.get_text(strip=True)
                ref_list = re.split(r'[,\s]+', ref_text)
                for ref in ref_list:
                    if ref:
                        info = self.extract_person_info(ref)
                        if info:
                            referrers.append({
                                'name': info['name'],
                                'empNo': '',
                                'deptCode': ''
                            })
        
        # 결재선 영역에서 "합의"인 사람들의 이름 추출
        agreement_names = []
        appr_line_area = soup.find('div', id='apprLineArea')
        if appr_line_area:
            red_spans = appr_line_area.find_all('span', class_='red')
            for red_span in red_spans:
                if '합의' in red_span.get_text(strip=True):
                    # red span의 부모 li의 이전 형제 li에서 이름 찾기
                    parent_li = red_span.find_parent('li')
                    if parent_li:
                        prev_li = parent_li.find_previous_sibling('li')
                        if prev_li:
                            name_text = prev_li.get_text(strip=True)
                            # 이름만 추출 (숫자 제거 등)
                            if name_text:
                                agreement_names.append(name_text)
        
        activities = []
        for idx, user_span in enumerate(user_spans):
            name_elem = user_span.find('span', class_='F_12_black_b')
            date_elem = user_span.find('span', class_='F_11_gray')
            
            if name_elem:
                info = self.extract_person_info(name_elem.get_text(strip=True))
                if info:
                    action_comment = ""
                    next_elem = user_span.next_sibling
                    while next_elem:
                        if hasattr(next_elem, 'name') and next_elem.name == 'div':
                            action_comment = next_elem.get_text(strip=True)
                            break
                        next_elem = next_elem.next_sibling
                    
                    # 기본 타입 설정
                    action_type = 'DRAFT' if idx == 0 else 'APPROVAL'
                    
                    # 이 사람이 합의자 리스트에 있으면 AGREEMENT로 변경
                    if info['name'] in agreement_names:
                        action_type = 'AGREEMENT'
                    
                    activities.append({
                        'positionName': info['positionName'],
                        'deptName': info['deptName'],
                        'actionLogType': action_type,
                        'name': info['name'],
                        'emailId': '',
                        'type': action_type,
                        'actionDate': self.parse_datetime_to_unix(date_elem.get_text(strip=True)) if date_elem else None,
                        'deptCode': '',
                        'actionComment': action_comment
                    })
        
        result = {
            'sourceId': source_id,
            'docNum': doc_num,
            'references': references,
            'docType': 'DRAFT',
            'title': title,
            'attaches': attaches,
            'drafter': drafter,
            'createdAt': created_at,
            'docBody': '',
            'docStatus': 'COMPLETE',
            'referrers': referrers,
            'activities': activities,
            'formName': '',
            'isPublic': False
        }
        
        return result
    
    def process_all_files(self):
        """모든 HTML 파일 처리"""
        all_results = []
        approval_path = Path(self.base_path) / '결재'
        
        if not approval_path.exists():
            print(f"경로를 찾을 수 없습니다: {approval_path}")
            return all_results
            
        html_files = list(approval_path.rglob('*.html'))
        # html_files = list(approval_path.rglob('*.html'))[:10]
        print(f"총 {len(html_files)}개의 HTML 파일을 찾았습니다.")
        
        for idx, html_file in enumerate(html_files, 1):
            try:
                print(f"처리 중... [{idx}/{len(html_files)}] {html_file.name}")
                result = self.parse_html(html_file)
                all_results.append(result)
            except Exception as e:
                print(f"오류 발생 ({html_file.name}): {e}")
        
        return all_results
    
    def save_to_json(self, data, output_path):
        """JSON 파일로 저장"""
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)
        print(f"JSON 파일 저장 완료: {output_path}")
    
    def save_to_mariadb(self, data, db_config):
        """MariaDB에 저장 - 안정성 강화 버전"""
        conn = None
        cursor = None
        
        try:
            print("\n=== DB 연결 시작 ===")
            print(f"Host: {db_config['host']}, Database: {db_config['database']}")
            
            # DB 연결
            conn = pymysql.connect(
                host=db_config['host'],
                user=db_config['user'],
                password=db_config['password'],
                database=db_config['database'],
                charset='utf8mb4'
            )
            print("✓ DB 연결 성공")
            
            cursor = conn.cursor()
            
            # 테이블 생성
            print("\n=== 테이블 생성 시작 ===")
            create_table_sql = """
            CREATE TABLE IF NOT EXISTS documents (
                id INT AUTO_INCREMENT PRIMARY KEY,
                source_id VARCHAR(50),
                doc_num VARCHAR(100),
                doc_type VARCHAR(50),
                title VARCHAR(500),
                doc_status VARCHAR(50),
                created_at BIGINT,
                drafter_name VARCHAR(100),
                drafter_position VARCHAR(100),
                drafter_dept VARCHAR(100),
                form_name VARCHAR(200),
                is_public BOOLEAN,
                `references` TEXT,
                attaches TEXT,
                referrers TEXT,
                activities TEXT,
                doc_body TEXT,
                created_date TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
                INDEX idx_source_id (source_id),
                INDEX idx_doc_num (doc_num),
                INDEX idx_created_at (created_at)
            ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_unicode_ci;
            """
            cursor.execute(create_table_sql)
            print("✓ 테이블 생성/확인 완료")
            
            # 기존 데이터 확인
            cursor.execute("SELECT COUNT(*) FROM documents")
            existing_count = cursor.fetchone()[0]
            print(f"✓ 기존 데이터: {existing_count}건")
            
            # 데이터 삽입
            print(f"\n=== 데이터 삽입 시작 ({len(data)}건) ===")
            insert_sql = """
            INSERT INTO documents 
            (source_id, doc_num, doc_type, title, doc_status, created_at, 
             drafter_name, drafter_position, drafter_dept, form_name, is_public,
             `references`, attaches, referrers, activities, doc_body)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            
            success_count = 0
            error_count = 0
            error_details = []
            
            for idx, doc in enumerate(data, 1):
                try:
                    # 데이터 길이 제한 및 안전한 변환
                    def safe_string(value, max_length=None):
                        if value is None:
                            return ''
                        s = str(value).strip()
                        if max_length and len(s) > max_length:
                            s = s[:max_length]
                        return s
                    
                    # JSON 데이터를 안전하게 변환 (ensure_ascii=True로 특수문자 이스케이프)
                    def safe_json(value):
                        if not value:
                            return '[]'
                        try:
                            # ensure_ascii=True로 모든 비ASCII 문자를 이스케이프
                            return json.dumps(value, ensure_ascii=True)
                        except:
                            return '[]'
                    
                    values = (
                        safe_string(doc.get('sourceId'), 50),
                        safe_string(doc.get('docNum'), 100),
                        safe_string(doc.get('docType'), 50),
                        safe_string(doc.get('title'), 500),
                        safe_string(doc.get('docStatus'), 50),
                        doc.get('createdAt'),
                        safe_string(doc.get('drafter', {}).get('name'), 100),
                        safe_string(doc.get('drafter', {}).get('positionName'), 100),
                        safe_string(doc.get('drafter', {}).get('deptName'), 100),
                        safe_string(doc.get('formName'), 200),
                        doc.get('isPublic', False),
                        safe_string(doc.get('references')),
                        safe_json(doc.get('attaches', [])),
                        safe_json(doc.get('referrers', [])),
                        safe_json(doc.get('activities', [])),
                        safe_string(doc.get('docBody'))
                    )
                    
                    cursor.execute(insert_sql, values)
                    success_count += 1
                    
                    # 100건마다만 출력 (로그 줄이기)
                    if idx % 100 == 0 or idx == len(data):
                        print(f"  진행: {idx}/{len(data)} (성공: {success_count}, 실패: {error_count})")
                    
                except Exception as e:
                    error_count += 1
                    error_msg = f"sourceId: {doc.get('sourceId')} - {str(e)[:80]}"
                    error_details.append(error_msg)
                    
                    # 처음 5개 오류만 즉시 출력
                    if error_count <= 5:
                        print(f"  [오류 {error_count}] {error_msg}")
            
            # 커밋
            print("\n=== 커밋 시작 ===")
            conn.commit()
            print(f"✓ 커밋 완료")
            
            # 결과 요약
            print(f"\n=== 결과 요약 ===")
            print(f"✓ 성공: {success_count}건")
            print(f"✗ 실패: {error_count}건")
            
            if error_count > 5:
                print(f"\n처음 5개 외 {error_count - 5}개의 추가 오류가 발생했습니다.")
                print("모든 오류 보기:")
                for err in error_details[:20]:  # 최대 20개만 출력
                    print(f"  - {err}")
                if len(error_details) > 20:
                    print(f"  ... 외 {len(error_details) - 20}개 더")
            
            # 최종 확인
            cursor.execute("SELECT COUNT(*) FROM documents")
            final_count = cursor.fetchone()[0]
            print(f"\n✓ 최종 데이터: {final_count}건 (이번 실행으로 {success_count}건 추가)")
            
        except pymysql.Error as e:
            print(f"\n❌ DB 오류 발생:")
            print(f"  Error Code: {e.args[0]}")
            print(f"  Error Message: {e.args[1]}")
            
        except Exception as e:
            print(f"\n❌ 일반 오류 발생: {e}")
            
        finally:
            if cursor:
                cursor.close()
            if conn:
                conn.close()
                print("\n✓ DB 연결 종료")


def main():
    base_path = r'C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html' #컨트롤러
    
    parser = ApprovalDocParser(base_path)
    
    print("HTML 파일 파싱 시작...")
    results = parser.process_all_files()
    
    output_json_path = 'two_htmltojsondb_convert.json' #컨트롤러
    parser.save_to_json(results, output_json_path)
    
    # DB 설정
    db_config = {
        'host': 'localhost',
        'user': 'root',
        'password': '1234',
        'database': '2021010120251031' #컨트롤러
    }
    
    # MariaDB에 저장
    print("\n" + "="*50)
    parser.save_to_mariadb(results, db_config)
    print("="*50)
    
    print(f"\n완료! 총 {len(results)}건 처리됨")


if __name__ == '__main__':
    main()
# Out:
# HTML 파일 파싱 시작...
# 총 8175개의 HTML 파일을 찾았습니다.
# 처리 중... [1/8175] 20210104_[LG화학 실험실행시스템 구축]에 대한 매출_매입 계약 품의_15167823.html
# 처리 중... [2/8175] 20210104_경영기획팀 외주인력 구매계약 품의_15168441.html
# 처리 중... [3/8175] 20210104_출장비 지급 신청_15162004.html
# 처리 중... [4/8175] 20210105_개인휴가 신청 _ 2021-01-06 (수), 1일_15175949.html
# 처리 중... [5/8175] 20210105_구매계약 품의(외주인력 )DGIST 연구사업 지원 플랫폼 구축(송지윤,임종덕)_15178865.html
# 처리 중... [6/8175] 20210105_구매계약 품의(외주인력) 연세대학교 산학협력단 RMS2_연구윤리_특허시스템 유지보수(박창준)_15177378.html
# 처리 중... [7/8175] 20210105_리모트콜(Remote Call) 서비스 사용 갱신 요청 드립니다_15179751.html
# 처리 중... [8/8175] 20210106_[입사품의] 경력사원 입사품의(김현성)_15188281.html
# 처리 중... [9/8175] 20210106_기타 경비 신청-교통비_15182306.html
# 처리 중... [10/8175] 20210106_대우조선해양 DSME 지식재산 관리시스템 재구축 검색엔진 구매의 건(다이퀘스트)_15184591.html
# 처리 중... [11/8175] 20210106_명함 신청_15186114.html
# 처리 중... [12/8175] 20210106_반차 휴가 신청서_허지훈_15183357.html
# 처리 중... [13/8175] 20210106_숙소경비신청(2020년12월분)_15184385.html
# 처리 중... [14/8175] 20210107_개인휴가 신청 _ 2021-01-11(월) 오후 ~ 2021-01-13(수) _ 2.5일_15194468.html
# 처리 중... [15/8175] 20210107_거제도 - 숙소 관리비(전기,가스)_15193931.html
# 처리 중... [16/8175] 20210108_휴가사용 신청_15204511.html
# 처리 중... [17/8175] 20210108_휴직신청_15204479.html
# 처리 중... [18/8175] 20210111_12월 출장비 신청의 건_15213513.html
# 처리 중... [19/8175] 20210111_2021.01.18 오후반차 ( 박희철 )_15211771.html
# 처리 중... [20/8175] 20210111_2021.01.18 오후반차(박희철)_15208122.html
# 처리 중... [21/8175] 20210111_대전 원자력연구원 출장 품의서 입니다_15213173.html
# 처리 중... [22/8175] 20210111_신우진 연차휴가 (오후반차) 신청_15215131.html
# 처리 중... [23/8175] 20210111_휴가 신청합니다._15215004.html
# 처리 중... [24/8175] 20210112_야근 교통비 지급 신청의 건_15219472.html
# 처리 중... [25/8175] 20210112_야근 식대 지급 신청의 건_15219427.html
# 처리 중... [26/8175] 20210112_연차 품의서_15223113.html
# 처리 중... [27/8175] 20210112_연차신청서(박형남) 입니다._15222759.html
# 처리 중... [28/8175] 20210114_01월 22일 휴가 사용 신청_15238785.html
# 처리 중... [29/8175] 20210114_DGIST 연구사업 평가시스템 구축 프로젝트 출장비 품의 요청_15237032.html
# 처리 중... [30/8175] 20210114_연차 품의서_15236379.html
# 처리 중... [31/8175] 20210114_휴가사용 품의(송준선)_15235939.html
# 처리 중... [32/8175] 20210115_[S_W]숙명여자대학교 지식재산권 및 기술이전 관리 시스템 고도화 SAP 연동비 구입 품의_15241791.html
# 처리 중... [33/8175] 20210115_[대금결제] 1월 외주용역비 대금 결제의 건-프리랜서(01_15)_15241300.html
# 처리 중... [34/8175] 20210115_반차 품의서_15242491.html
# 처리 중... [35/8175] 20210118_[대금결제] 관세청&quot;국가간 원산지정보 구축&quot; 매입 대금 결제의 건-이원정보기술_15255805.html
# 처리 중... [36/8175] 20210118_연차 휴가 품의_15248570.html
# 처리 중... [37/8175] 20210118_휴가 사용 신청서_15250268.html
# 처리 중... [38/8175] 20210118_휴가사용신청서_15252525.html
# 처리 중... [39/8175] 20210119_[대금결제] ETRI 통합정보(ETRIware) 유지관리 계약 - 2020년 12월분 대금 지급의 건_15260823.html
# 처리 중... [40/8175] 20210119_대중소기업 상생협력기금 종합관리시스템 구축 구매 품의(외주인력) - 권민수(중급)_15260341.html
# 처리 중... [41/8175] 20210119_대중소기업 상생협력기금 종합관리시스템 구축 구매 품의(외주인력) - 김선관(고급)_15260360.html
# 처리 중... [42/8175] 20210119_대중소기업 상생협력기금 종합관리시스템 구축 구매 품의(외주인력) - 박건규(중급)_15260370.html
# 처리 중... [43/8175] 20210119_대중소기업 상생협력기금 종합관리시스템 구축 구매 품의(외주인력) - 최동권(중급)_15260379.html
# 처리 중... [44/8175] 20210119_반차 품의서_15261417.html
# 처리 중... [45/8175] 20210119_숙명여자대학교 지식재산권 및 기술이전 관리 시스템 고도호 SAP 연동 구매 품의(넥스퍼스)_15263937.html
# 처리 중... [46/8175] 20210119_정보통신공사협회 협회비 결제요청드립니다._15263459.html
# 처리 중... [47/8175] 20210119_한국연구재단 2020년 NRF 정보시스템 통합 위탁운영 ITSM라이센스 구매계약의 건_15263948.html
# 처리 중... [48/8175] 20210120_[대금결제] Dell 사업 매입 대금 결제의 건-에스씨지솔루션즈 외(1월)_15270125.html
# 처리 중... [49/8175] 20210120_대전 원자력연구원 출장비 지급 신청서 입니다_15266468.html
# 처리 중... [50/8175] 20210121_김상욱 휴가 사용 신청서_15273227.html
# 처리 중... [51/8175] 20210121_연차휴가 결재품의_신성호 선임_15277303.html
# 처리 중... [52/8175] 20210121_연차휴가 사용 품의-한주영 선임_15274037.html
# 처리 중... [53/8175] 20210121_연차휴가 품의 - 김현성_15276089.html
# 처리 중... [54/8175] 20210122_'21년~'22년 기정원 통합유지보수 구매 신청 품의(외주인력)_15284696.html
# 처리 중... [55/8175] 20210122_[대금결제] 1월 외주용역비 대금 결제의 건-협력사_15281420.html
# 처리 중... [56/8175] 20210122_대우조선해양 숙소[전기,가스] 요금_15282191.html
# 처리 중... [57/8175] 20210122_휴가(반차) 신청_15281429.html
# 처리 중... [58/8175] 20210125_[대금결제]한국발명진흥회 SMART3 연게 IP금융 관리시스템 개발 용역 매입 대금 결제의 건-포시에스, 한국전자인증_15293791.html
# 처리 중... [59/8175] 20210125_[선거관리위원회 온라인투표관리 운영용역]에 관한 매출_매입 계약품의_15294678.html
# 처리 중... [60/8175] 20210125_구매계약 품의(외주인력) 대중소기업 상생협력기금 종합관리시스템 구축(권민수 외 3명)_15296205.html
# 처리 중... [61/8175] 20210125_연차 품의서_15288901.html
# 처리 중... [62/8175] 20210125_오후 반차 휴가 사용 신청_15290605.html
# 처리 중... [63/8175] 20210126_2021년 1월 28일(목) 반차 휴가 신청합니다_15302575.html
# 처리 중... [64/8175] 20210126_월차 사용의 건 (2월 2일, 화)_15304184.html
# 처리 중... [65/8175] 20210127_'21.01.28 출장 품의_15310441.html
# 처리 중... [66/8175] 20210127_ETRI사업팀 재직증명서 발급 요청_15309642.html
# 처리 중... [67/8175] 20210127_[대금결제] 1월 외주용역비 대금 결제의 건-협력사_15312340.html
# 처리 중... [68/8175] 20210127_퇴직 품의서 상신_15310142.html
# 처리 중... [69/8175] 20210127_한국항공우주연구원 출장 품의_15310401.html
# 처리 중... [70/8175] 20210127_휴가(반차) 신청합니다._15309482.html
# 처리 중... [71/8175] 20210128_1_29(금) 오후반차 신청_15314070.html
# 처리 중... [72/8175] 20210128_1월 기타 경비 신청합니다_15313270.html
# 처리 중... [73/8175] 20210128_2021.01.28 휴가 신청서_15315036.html
# 처리 중... [74/8175] 20210128_2021.02.02(화) 휴가 기안_15315047.html
# 처리 중... [75/8175] 20210128_[신규_고도화]숙명여자대학교 지식재산권 및 기술이전 관리 시스템 고도화 개발 용역_15319072.html
# 처리 중... [76/8175] 20210128_개인휴가 신청 _ 2021-01-29 (금), 1일_15316273.html
# 처리 중... [77/8175] 20210128_애니파이브 재직증명서 신청_15313234.html
# 처리 중... [78/8175] 20210128_연차휴가품의_15315872.html
# 처리 중... [79/8175] 20210128_휴가 신청합니다._15313563.html
# 처리 중... [80/8175] 20210129_반차 휴가 신청(1_29, 0.5일)_15324656.html
# 처리 중... [81/8175] 20210129_연차휴가 결재요청_15327002.html
# 처리 중... [82/8175] 20210129_출장품의서_15320884.html
# 처리 중... [83/8175] 20210129_휴가 사용 신청_15326487.html
# 처리 중... [84/8175] 20210131_야근식대 지급 신청의 件_15330489.html
# 처리 중... [85/8175] 20210201_2021년~2022년 기정원 정보시스템 유지보수사업 C_P 품의_15340761.html
# 처리 중... [86/8175] 20210201_[오전반차]결재요청 드립니다._15337660.html
# 처리 중... [87/8175] 20210201_[오후반차]결재요청드립니다._15337635.html
# 처리 중... [88/8175] 20210201_노트북 소보 발송에 따른 경비 사용 정산 신청 드립니다._15332304.html
# 처리 중... [89/8175] 20210201_서울대병원 외주인력 구매 신청 품의서(차영호)_15336633.html
# 처리 중... [90/8175] 20210201_휴가 사용 품의_15340814.html
# 처리 중... [91/8175] 20210202_2021년 2월 5일(금) 연차 휴가 신청합니다_15345414.html
# 처리 중... [92/8175] 20210202_21년~22년 기정원 정보시스템 통합유지보수사업 매출 품의_15347013.html
# 처리 중... [93/8175] 20210202_2월 5일 ~ 10일 휴가 사용 신청합니다._15347485.html
# 처리 중... [94/8175] 20210202_국가간 원산지정보 자료교환시스템 구축사업(베트남) C_P 품의_15348296.html
# 처리 중... [95/8175] 20210202_휴가 사용 신청서_15349060.html
# 처리 중... [96/8175] 20210203_[지급품의] 2021년도 KINPA 찬조회원사 연회비 지급 품의의 건_15351837.html
# 처리 중... [97/8175] 20210203_퇴직 품의(김현성 책임)_15356532.html
# 처리 중... [98/8175] 20210203_휴가 신청 품의_15355386.html
# 처리 중... [99/8175] 20210204_[휴가신청] 김우석 선임 연차1일 사용 신청의 건_15359740.html
# 처리 중... [100/8175] 20210204_명함발급을 요청합니다._15362351.html
# 처리 중... [101/8175] 20210205_1월 출장비 신청의 건_15370601.html
# 처리 중... [102/8175] 20210205_2021-02-15(월) 휴가 사용_15371818.html
# 처리 중... [103/8175] 20210205_숙소경비신청(2021년1월분)_15370340.html
# 처리 중... [104/8175] 20210208_'21.01.28 출장비 지급 신청 품의_15377405.html
# 처리 중... [105/8175] 20210208_[대금결제] 토요타파이낸셜 &quot;차세대 및 망분리 시스템 구축&quot; 매입대금 결제의 건 - 데이타쎌테크_15382181.html
# 처리 중... [106/8175] 20210208_연차휴가 신청_2_10(수)_15380279.html
# 처리 중... [107/8175] 20210208_택시비 지급 신청서_15385270.html
# 처리 중... [108/8175] 20210208_휴가 신청합니다._15377356.html
# 처리 중... [109/8175] 20210209_연차휴가 신청(2_22, 1일)_15392888.html
# 처리 중... [110/8175] 20210209_연차휴가 신청_15388474.html
# 처리 중... [111/8175] 20210209_한국 항공우주연구원 출장비 지급요청 품의_15391835.html
# 처리 중... [112/8175] 20210210_2021-02-15 정서연 휴가신청합니다(1일)_15398744.html
# 처리 중... [113/8175] 20210210_휴가 사용 신청의 건_15397718.html
# 처리 중... [114/8175] 20210210_휴가 사용신청서 품의_15394875.html
# 처리 중... [115/8175] 20210215_20210222 반차휴가(박희철)_15406737.html
# 처리 중... [116/8175] 20210215_반차 품의서_15407831.html
# 처리 중... [117/8175] 20210215_연차신청서(박형남) 입니다._15404259.html
# 처리 중... [118/8175] 20210216_2021.02.15 휴가 사용 신청서_15413555.html
# 처리 중... [119/8175] 20210216_기타 경비 신청 (21.02.16)_15416101.html
# 처리 중... [120/8175] 20210216_신우진 연차휴가 신청_15412559.html
# 처리 중... [121/8175] 20210216_휴가 사용 품의(송준선)_15413002.html
# 처리 중... [122/8175] 20210217_개인 휴가 신청_조신행 사원_2020.02.26(금)_15418731.html
# 처리 중... [123/8175] 20210217_대전 원자력연구원 출장 품의서 입니다_15424352.html
# 처리 중... [124/8175] 20210217_반차 휴가 품의 요청_15422130.html
# 처리 중... [125/8175] 20210217_연차휴가신청_이형균_21_02_19_15418675.html
# 처리 중... [126/8175] 20210217_휴가 신청_15423448.html
# 처리 중... [127/8175] 20210218_개인휴가 _ 2021-02-19 (금) _ 1일_15427585.html
# 처리 중... [128/8175] 20210218_김상욱 휴가 사용 신청서 입니다._15427134.html
# 처리 중... [129/8175] 20210218_신우진 재직증명서 및 근로소득원천징수 발급요청_15425947.html
# 처리 중... [130/8175] 20210218_오후 반차 신청드립니다._15428886.html
# 처리 중... [131/8175] 20210218_휴가를 신청합니다._15431940.html
# 처리 중... [132/8175] 20210219_휴가 사용 신청의 件_15439810.html
# 처리 중... [133/8175] 20210222_강원준 출장 품의서 결재 올립니다._15449793.html
# 처리 중... [134/8175] 20210222_대전 원자력연구원 출장비 지급 신청서 입니다_15443629.html
# 처리 중... [135/8175] 20210222_반차 품의서_15442285.html
# 처리 중... [136/8175] 20210222_월차휴가 사용을 신청합니다._15444686.html
# 처리 중... [137/8175] 20210222_특허청 제안서 작성 관련 출장 품의서_15443589.html
# 처리 중... [138/8175] 20210222_휴가 사용 신청서 기안합니다._15449968.html
# 처리 중... [139/8175] 20210223_단기 출장 품의의 件_15457976.html
# 처리 중... [140/8175] 20210223_연차휴가 신청의 건_15452261.html
# 처리 중... [141/8175] 20210223_휴가 신청합니다. (건강검진)_15452466.html
# 처리 중... [142/8175] 20210223_휴가사용신청서_15453360.html
# 처리 중... [143/8175] 20210224_강원준 출장비 지급 신청서 올립니다._15466074.html
# 처리 중... [144/8175] 20210224_김상욱 휴가 사용 신청서 입니다._15463060.html
# 처리 중... [145/8175] 20210224_반차 품의서_15460132.html
# 처리 중... [146/8175] 20210224_연차 휴가 품의_15461640.html
# 처리 중... [147/8175] 20210225_20210225 휴가 사용 신청서_15467415.html
# 처리 중... [148/8175] 20210225_기타 경비 신청 (21.02.25)_15468791.html
# 처리 중... [149/8175] 20210225_휴가 신청합니다._15473638.html
# 처리 중... [150/8175] 20210226_2월 교통비 신청 합니다_15475801.html
# 처리 중... [151/8175] 20210226_2월 기타 경비 신청합니다_15475811.html
# 처리 중... [152/8175] 20210226_3월 2일 연차 신청합니다_15475835.html
# 처리 중... [153/8175] 20210226_[사후품의] 연차휴가 사용_15478738.html
# 처리 중... [154/8175] 20210226_반차 결재요청_15476030.html
# 처리 중... [155/8175] 20210301_경비 신청_15485084.html
# 처리 중... [156/8175] 20210301_야근식대 지급 신청의 件_15484992.html
# 처리 중... [157/8175] 20210301_출장비 지급 신청의 件_15484981.html
# 처리 중... [158/8175] 20210302_[2021년 2월 경비신청서 입니다]_15485278.html
# 처리 중... [159/8175] 20210302_개인휴가 신청 _ 2021-03-02 (화), 0.5일_15489447.html
# 처리 중... [160/8175] 20210302_개인휴가 신청 _ 2021-03-05 (금), 1일_15489464.html
# 처리 중... [161/8175] 20210304_2월 출장비 신청의 건_15511406.html
# 처리 중... [162/8175] 20210304_연차 휴가 신청합니다_15512371.html
# 처리 중... [163/8175] 20210305_대전 원자력연구원 출장 품의서 입니다_15517450.html
# 처리 중... [164/8175] 20210305_퇴직서(박희철)_15518800.html
# 처리 중... [165/8175] 20210305_휴가 사용 신청_15515194.html
# 처리 중... [166/8175] 20210305_휴가 사용 신청_15518902.html
# 처리 중... [167/8175] 20210308_연차 휴가 신청(3_9, 1일)_15530892.html
# 처리 중... [168/8175] 20210309_숙소경비신청(2021년2월분)_15536532.html
# 처리 중... [169/8175] 20210309_휴가 신청 품의_15539864.html
# 처리 중... [170/8175] 20210310_03월 12일 휴가 사용 신청_15544598.html
# 처리 중... [171/8175] 20210310_2021년 03월 12일(금) 오후 반차 신청합니다._15543249.html
# 처리 중... [172/8175] 20210310_기타 경비 신청 (21.03.10)_15544773.html
# 처리 중... [173/8175] 20210310_대중소기업농어업협력재단 ERP 연계 추가개발 건_15548135.html
# 처리 중... [174/8175] 20210310_휴가 사용 신청합니다._15545682.html
# 처리 중... [175/8175] 20210311_2021-03-12 정서연 휴가신청합니다(1일)_15550027.html
# 처리 중... [176/8175] 20210311_개인휴가 _ 2021-03-12 (금) _ 0.5일 (오전휴무)_15550779.html
# 처리 중... [177/8175] 20210311_대중소기업상생협력기금 종합관리시스템 구축 ERP연계 추가개발 구매의 건_15555001.html
# 처리 중... [178/8175] 20210312_'21.03.15 연차품의_15563397.html
# 처리 중... [179/8175] 20210312_휴가 사용 신청서_15560602.html
# 처리 중... [180/8175] 20210315_대전 원자력연구원 출장비 지급 신청서 입니다_15568372.html
# 처리 중... [181/8175] 20210315_휴가 신청합니다._15567588.html
# 처리 중... [182/8175] 20210317_2021-02-18 정서연 휴가신청합니다(1일)_15581565.html
# 처리 중... [183/8175] 20210317_[휴가사용사후품의] 연차휴가 품의_15588086.html
# 처리 중... [184/8175] 20210317_연차 품의서_15587395.html
# 처리 중... [185/8175] 20210317_연차 품의서_15587527.html
# 처리 중... [186/8175] 20210318_[휴가]신청드립니다._15589167.html
# 처리 중... [187/8175] 20210318_개인휴가 신청 _ 2021-03-19 (금), 1일_15588762.html
# 처리 중... [188/8175] 20210318_신우진 연차휴가 (오후반차) 신청_15594295.html
# 처리 중... [189/8175] 20210318_휴가 사용 신청서_15589614.html
# 처리 중... [190/8175] 20210318_휴가 신청_15594567.html
# 처리 중... [191/8175] 20210319_[대금결제] ITO_3월 외주용역비 대금 결제의 건-프리랜서_업체(03_15)_15598972.html
# 처리 중... [192/8175] 20210322_[대금결제] ITO_3월 외주용역비 대금 결제의 건_업체(03_25)_15612862.html
# 처리 중... [193/8175] 20210322_김상욱 휴가 사용 신청서 입니다._15612084.html
# 처리 중... [194/8175] 20210322_조달청 제안서 작성 관련 출장 품의서_15612520.html
# 처리 중... [195/8175] 20210322_휴가 사용 신청의 件_15618394.html
# 처리 중... [196/8175] 20210323_[지급품의] 2021 혁신서비스 해외진출 맞춤형 지원사업 기업분담금 납부의 건_15621344.html
# 처리 중... [197/8175] 20210323_개인 휴가 신청_조신행 사원_2020.03.26(금)_15619012.html
# 처리 중... [198/8175] 20210323_기타 경비 신청 (21.03.23)_15622382.html
# 처리 중... [199/8175] 20210323_대중소기업농어업협력재단 방화벽_15620990.html
# 처리 중... [200/8175] 20210323_연차 품의서_15618962.html
# 처리 중... [201/8175] 20210323_연차휴가 신청_이형균_3_26(금)_15619833.html
# 처리 중... [202/8175] 20210323_휴가 사용 신청서_이의환 선임_15621473.html
# 처리 중... [203/8175] 20210324_집안사정으로 인한 오후 반차휴가 요청합니다._15627090.html
# 처리 중... [204/8175] 20210324_휴가 사용 신청서_15630438.html
# 처리 중... [205/8175] 20210324_휴가 사용신청서 품의_15630039.html
# 처리 중... [206/8175] 20210325_연차 휴가 품의_15635917.html
# 처리 중... [207/8175] 20210325_휴가 신청합니다. (건강검진 2차검진)_15637260.html
# 처리 중... [208/8175] 20210325_휴가 신청합니다._15640167.html
# 처리 중... [209/8175] 20210326_(계약변경) HK이노엔 지식재산시스템 유지보수 계약 품의_15646030.html
# 처리 중... [210/8175] 20210326_(계약변경) SK바이오사이언스 21년 e-patent 유지보수 계약 품의_15646240.html
# 처리 중... [211/8175] 20210326_(계약변경) SK케미칼 e-patent 21년도 유지보수 계약 품의_15646187.html
# 처리 중... [212/8175] 20210326_2021.03.31(수) 연차 품의_15645920.html
# 처리 중... [213/8175] 20210326_연차휴가품의_15642122.html
# 처리 중... [214/8175] 20210326_택시비 지급 신청서_15645550.html
# 처리 중... [215/8175] 20210329_2021.03.29 휴가 신청 합니다._15655348.html
# 처리 중... [216/8175] 20210329_[대금결제] ITO_3월 외주용역비 대금 결제의 건_업체(03_31)_15654748.html
# 처리 중... [217/8175] 20210330_'21.04.01 연차품의_15664432.html
# 처리 중... [218/8175] 20210330_4월 2일(금) 연차 사용 신청합니다._15666951.html
# 처리 중... [219/8175] 20210330_휴가 사용 신청서 [한상근 사원] 입니다._15665643.html
# 처리 중... [220/8175] 20210331_2021.04.02(금) 오후 반차 휴가 사용 신청의 건_15673391.html
# 처리 중... [221/8175] 20210331_김우선 선임 연차휴가 반차사용 신청서(4월 1일)_15670440.html
# 처리 중... [222/8175] 20210331_사원 경동윤 2021 04 05 개인 휴가 신청합니다._15670368.html
# 처리 중... [223/8175] 20210401_3월 기타 경비 신청합니다_15678061.html
# 처리 중... [224/8175] 20210402_[입사품의] 신입사원_이하연_15688842.html
# 처리 중... [225/8175] 20210402_[입사품의] 신입사원_전진원_15688759.html
# 처리 중... [226/8175] 20210402_[입사품의] 신입사원_차경석_15688711.html
# 처리 중... [227/8175] 20210402_휴가 사용 신청서_15690007.html
# 처리 중... [228/8175] 20210405_3월 출장비 신청품의의 건_15700398.html
# 처리 중... [229/8175] 20210405_[2021년 3월 경비신청서 올립니다]_15703997.html
# 처리 중... [230/8175] 20210405_[통합연구지원시스템 전문기관 데이터이관 대응사업] 프로젝트룸 임대 품의_15698390.html
# 처리 중... [231/8175] 20210405_연차휴가 품의_15698279.html
# 처리 중... [232/8175] 20210405_휴가 신청서_15696529.html
# 처리 중... [233/8175] 20210406_한국항공우주연구원 출장 품의_15704380.html
# 처리 중... [234/8175] 20210406_휴가 사용 신청서_15704439.html
# 처리 중... [235/8175] 20210407_[통합연구지원시스템 전문기관 데이터이관 대응사업] 프로젝트룸 사무기기 및 집기류 구매 품의_15717209.html
# 처리 중... [236/8175] 20210407_강원준 사원 휴가 신청서 올립니다._15721062.html
# 처리 중... [237/8175] 20210407_대전 원자력연구원 출장 품의서 입니다_15718815.html
# 처리 중... [238/8175] 20210408_2021년 4월 12일(월) 연차 휴가 신청합니다_15721578.html
# 처리 중... [239/8175] 20210408_휴가(오후반차) 신청합니다._15723250.html
# 처리 중... [240/8175] 20210409_휴가 신청서_15732937.html
# 처리 중... [241/8175] 20210412_[대금결제] ITO_4월 외주용역비 대금 결제의 건-프리랜서_업체(04_15)_15744992.html
# 처리 중... [242/8175] 20210412_개인 휴가 신청_조신행 사원_2020.04.16(금) (연차)_15738302.html
# 처리 중... [243/8175] 20210412_연차 품의서_15738561.html
# 처리 중... [244/8175] 20210412_연차휴가 결재요청드립니다._15744997.html
# 처리 중... [245/8175] 20210412_휴가 사용 신청_15742849.html
# 처리 중... [246/8175] 20210412_휴가 사용 신청서 기안합니다._15746447.html
# 처리 중... [247/8175] 20210412_휴가 사용신청서 품의_15746476.html
# 처리 중... [248/8175] 20210412_휴가사용 신청_15738065.html
# 처리 중... [249/8175] 20210413_2021.04.14(수) 연차 품의_15748264.html
# 처리 중... [250/8175] 20210413_20210413_사원 _경동윤 개인휴가(반차)신청합니다._15747068.html
# 처리 중... [251/8175] 20210413_반차 품의서_15747963.html
# 처리 중... [252/8175] 20210413_삼성SDI 지재권관리시스템 구축의 건_15750635.html
# 처리 중... [253/8175] 20210413_숙소경비신청(2021년3월분)_15749860.html
# 처리 중... [254/8175] 20210413_연차 품의서_15747972.html
# 처리 중... [255/8175] 20210413_연차휴가 신청(4_19, 1일)_15749134.html
# 처리 중... [256/8175] 20210413_한국콜마 지재권관리시스템 구축의 건_15750266.html
# 처리 중... [257/8175] 20210413_한승재-퇴직품의서_15752761.html
# 처리 중... [258/8175] 20210414_휴가 사용 신청드립니다._15760104.html
# 처리 중... [259/8175] 20210414_휴가 사용 신청합니다._15759731.html
# 처리 중... [260/8175] 20210415_휴가 사용 신청서_15762007.html
# 처리 중... [261/8175] 20210415_휴가 신청_15764930.html
# 처리 중... [262/8175] 20210415_휴가 품의 요청_15765144.html
# 처리 중... [263/8175] 20210416_[대금결제] ETRI 통합정보(ETRIware) 유지관리 계약 - 2021년 3월분 대금 지급의 건_15774451.html
# 처리 중... [264/8175] 20210419_'21.04.16 출장비 지급 신청 품의_15781758.html
# 처리 중... [265/8175] 20210419_오전 반차 사용의 건 (4월 20일, 화)_15783382.html
# 처리 중... [266/8175] 20210420_[대금결제] ITO_4월 외주용역비 대금 결제의 건-업체(04_25)_15791376.html
# 처리 중... [267/8175] 20210420_연차 품의서_15786270.html
# 처리 중... [268/8175] 20210421_연차휴가 신청_15799823.html
# 처리 중... [269/8175] 20210421_코스맥스 주차비 신청_15796734.html
# 처리 중... [270/8175] 20210422_NICE API 구매건_15807093.html
# 처리 중... [271/8175] 20210422_개인휴가 신청 _ 2021-04-23 (금), 1일_15804139.html
# 처리 중... [272/8175] 20210422_휴가 품의 드립니다._15807741.html
# 처리 중... [273/8175] 20210423_4월 26일 휴가 신청합니다._15813813.html
# 처리 중... [274/8175] 20210423_휴가 사용 신청_15811357.html
# 처리 중... [275/8175] 20210426_기타 경비 신청 (21.04.26)_15823653.html
# 처리 중... [276/8175] 20210426_사원 경동윤 04_27(화) 개인휴가(오후반차) 신청합니다._15820689.html
# 처리 중... [277/8175] 20210426_휴가 신청(04_27)입니다_15817617.html
# 처리 중... [278/8175] 20210427_2021년 4월 29일(목) 반차 휴가 신청합니다_15833815.html
# 처리 중... [279/8175] 20210427_대전 원자력연구원 출장비 지급 신청서 입니다_15826777.html
# 처리 중... [280/8175] 20210427_연차 품의서_15829825.html
# 처리 중... [281/8175] 20210427_연차 휴가 품의_15827074.html
# 처리 중... [282/8175] 20210428_[대금결제] ITO_4월 외주용역비 대금 결제의 건-업체(04_30)_15834348.html
# 처리 중... [283/8175] 20210428_신우진 휴가(오후 반차) 사용 신청서_15836981.html
# 처리 중... [284/8175] 20210428_연차 신청의 건 (4_30, 금)_15834399.html
# 처리 중... [285/8175] 20210428_휴가 사용 품의_15840015.html
# 처리 중... [286/8175] 20210429_20210430 정서연 휴가 신청합니다(1일)_15842049.html
# 처리 중... [287/8175] 20210429_야근 식대 신청합니다._15849526.html
# 처리 중... [288/8175] 20210429_연차 휴가 품의_15842305.html
# 처리 중... [289/8175] 20210429_오후반차 신청합니다._15849584.html
# 처리 중... [290/8175] 20210430_'21.04.29 출장비 지급 신청 품의_15851725.html
# 처리 중... [291/8175] 20210430_연차신청서(박형남) 입니다._15850631.html
# 처리 중... [292/8175] 20210430_월차휴가 사용신청합니다_15852361.html
# 처리 중... [293/8175] 20210430_휴가 사용 신청서 [한상근 사원] 입니다._15850672.html
# 처리 중... [294/8175] 20210503_경조사로 휴가를 신청 드립니다._15869326.html
# 처리 중... [295/8175] 20210503_연차 품의서_15862400.html
# 처리 중... [296/8175] 20210503_휴가 신청드립니다._15865691.html
# 처리 중... [297/8175] 20210504_2021년 4월 출장교통비 지급 신청서_15871474.html
# 처리 중... [298/8175] 20210504_4월 기타 경비 신청합니다_15875688.html
# 처리 중... [299/8175] 20210504_숙소경비신청(2021년4월분)_15870773.html
# 처리 중... [300/8175] 20210504_연차휴가 신청_15873929.html
# 처리 중... [301/8175] 20210504_휴가 사용 신청서_15873021.html
# 처리 중... [302/8175] 20210504_휴가 신청합니다._15872028.html
# 처리 중... [303/8175] 20210504_휴가 신청합니다._15877309.html
# 처리 중... [304/8175] 20210504_휴가 신청합니다_15875555.html
# 처리 중... [305/8175] 20210506_05월 06일 반차, 05월 10일 연차 사용 신청_15882494.html
# 처리 중... [306/8175] 20210506_[2021년 4월 경비신청서 입니다]_15879959.html
# 처리 중... [307/8175] 20210506_개인휴가 _ 2021-05-07 (금) _ 1일_15883893.html
# 처리 중... [308/8175] 20210506_휴가 신청_15880707.html
# 처리 중... [309/8175] 20210510_'21.05.17 연차품의_15905470.html
# 처리 중... [310/8175] 20210510_2021.05.14(금) 휴가 사용 신청의 건_15900408.html
# 처리 중... [311/8175] 20210510_4월 출장비 신청의 건_15902607.html
# 처리 중... [312/8175] 20210510_출장비 신청_15903380.html
# 처리 중... [313/8175] 20210510_휴가 신청_15899777.html
# 처리 중... [314/8175] 20210511_대전 원자력연구원 출장 품의서 입니다_15911671.html
# 처리 중... [315/8175] 20210511_연차휴가 신청입니다. (5_14)_15913590.html
# 처리 중... [316/8175] 20210511_휴가 사용 신청서 기안합니다._15916628.html
# 처리 중... [317/8175] 20210512_연차 휴가 품의_15922959.html
# 처리 중... [318/8175] 20210512_연차휴가 신청서_이형균_5_14(금)_15918541.html
# 처리 중... [319/8175] 20210512_휴가 사용 신청서_15917148.html
# 처리 중... [320/8175] 20210512_휴가 신청서_210517~18_15920805.html
# 처리 중... [321/8175] 20210513_5월 14일 연차 신청 합니다_15926295.html
# 처리 중... [322/8175] 20210513_[S_W]연세대학교 평가시스템 구축관련 SSL 인증서 구입 품의_15928342.html
# 처리 중... [323/8175] 20210513_개인휴가 _ 2021-05-14 (금), 오전 반차 (0.5일)_15928229.html
# 처리 중... [324/8175] 20210513_개인휴가 _ 2021-05-21 (금) 1일_15928257.html
# 처리 중... [325/8175] 20210513_연차 품의서_15925527.html
# 처리 중... [326/8175] 20210513_연차사용 품의_신성호_15925386.html
# 처리 중... [327/8175] 20210513_휴가사용품의_15929792.html
# 처리 중... [328/8175] 20210517_2021.05.20 휴가 신청_15947160.html
# 처리 중... [329/8175] 20210517_2021년 5월 21일(금) 연차 휴가 신청합니다_15946039.html
# 처리 중... [330/8175] 20210517_[대금결제] ITO_5월 외주용역비 대금 결제의 건 (2차)-프리랜서_업체(05_15)_15942504.html
# 처리 중... [331/8175] 20210517_대전 원자력연구원 출장비 지급 신청서 입니다_15940835.html
# 처리 중... [332/8175] 20210517_휴가 신청합니다._15945736.html
# 처리 중... [333/8175] 20210518_연차 품의서_15952726.html
# 처리 중... [334/8175] 20210518_장애발생 조치 지연에 따른 위약금 지급 품의_15954943.html
# 처리 중... [335/8175] 20210520_2021.05.31(월) 연차 품의_15963208.html
# 처리 중... [336/8175] 20210520_[대금결제] ITO_5월 외주용역비 대금 결제의 건-업체 (05_25)_15961394.html
# 처리 중... [337/8175] 20210520_개인 휴가 신청_조신행 사원_2021.05.24(월) (연차)_15960313.html
# 처리 중... [338/8175] 20210520_대중소 상생협력기금 종합관리시스템 구축 구매 품의(외주인력) - 최동권(중급)_15961995.html
# 처리 중... [339/8175] 20210520_연차휴가 신청_15963761.html
# 처리 중... [340/8175] 20210520_휴가 사용신청서 품의_15958511.html
# 처리 중... [341/8175] 20210520_휴가 신청 품의(송준선, 5_24 오후)_15963163.html
# 처리 중... [342/8175] 20210523_휴가 사용 신청의 件_15973322.html
# 처리 중... [343/8175] 20210524_[대금결제] 공통_5월 외주용역비 대금 결제의 건-(05_25)_15978061.html
# 처리 중... [344/8175] 20210524_[신규_SI]코스맥스 처방연구노트관리시스템 구축 매출 계약 품의_15979839.html
# 처리 중... [345/8175] 20210525_[대금결제] ITO_5월 외주용역비 대금 결제의 건-업체 (05_31)_15984267.html
# 처리 중... [346/8175] 20210525_휴가 사용 신청서_15984017.html
# 처리 중... [347/8175] 20210526_20210531_사원_경동윤 개인휴가 신청합니다._15994129.html
# 처리 중... [348/8175] 20210526_[대금결제] 공통_5월 외주용역비 대금 결제의 건-(05_31)_15995542.html
# 처리 중... [349/8175] 20210526_야근식대 신청합니다._15993168.html
# 처리 중... [350/8175] 20210526_휴가 품의 드립니다._15994205.html
# 처리 중... [351/8175] 20210527_05월 31일 휴가 사용 신청_16002993.html
# 처리 중... [352/8175] 20210527_연차 휴가 품의_16002098.html
# 처리 중... [353/8175] 20210527_휴가 사용 신청서_이의환 선임_15999958.html
# 처리 중... [354/8175] 20210528_2021년 6월 4일(금) 오전 반차 휴가 신청합니다_16009666.html
# 처리 중... [355/8175] 20210528_[지출결의] 선급금이행보증증권 납부 승인 요청의 건_16008100.html
# 처리 중... [356/8175] 20210528_[지출결의] 선급금이행보증증권 납부 승인 요청의 건_16012259.html
# 처리 중... [357/8175] 20210531_5월 야근식대 결재 요청 드립니다._16024308.html
# 처리 중... [358/8175] 20210531_[대금결제] 공통_5월 외주용역비 대금 결제의 건-(05_31) - 추가 프리랜서 2명_16019692.html
# 처리 중... [359/8175] 20210531_[휴가 신청서 입니다]_16024443.html
# 처리 중... [360/8175] 20210531_결재 요청드립니다_16024407.html
# 처리 중... [361/8175] 20210531_대전지사 출장비 지급 신청_16018357.html
# 처리 중... [362/8175] 20210531_신우진 연차 휴가 신청_16015404.html
# 처리 중... [363/8175] 20210531_연차 품의서_16015703.html
# 처리 중... [364/8175] 20210531_연차 휴가 품의_16016413.html
# 처리 중... [365/8175] 20210531_한국콜마 프로젝트 회식비_16018375.html
# 처리 중... [366/8175] 20210601_5월 기타 경비 신청 합니다_16024978.html
# 처리 중... [367/8175] 20210601_[지출결의] 선급금이행보증증권 납부 승인 요청의 건_16028718.html
# 처리 중... [368/8175] 20210601_휴가 사용 신청_16027151.html
# 처리 중... [369/8175] 20210601_휴가 사용 신청서_16031162.html
# 처리 중... [370/8175] 20210602_김우석 선임 개인 연차 신청의 건(6월 3일)_16037844.html
# 처리 중... [371/8175] 20210602_연차휴가 신청_16038293.html
# 처리 중... [372/8175] 20210602_휴가 사용 신청합니다._16034390.html
# 처리 중... [373/8175] 20210602_휴가사용 품의_16040266.html
# 처리 중... [374/8175] 20210603_휴가 사용 신청서 _ 2021-06-04 (금) _ 1일_16044473.html
# 처리 중... [375/8175] 20210604_[2021년 5월 경비신청서 올립니다]_16051408.html
# 처리 중... [376/8175] 20210604_월차 사용의 건 (6월 11일, 금)_16057125.html
# 처리 중... [377/8175] 20210607_2021.06.09(수) 휴가 사용 신청의 건_16062054.html
# 처리 중... [378/8175] 20210607_20210607_사원_경동윤 개인 오후 반차휴가 신청합니다._16061546.html
# 처리 중... [379/8175] 20210607_반차 사용 신청서_16066123.html
# 처리 중... [380/8175] 20210607_반차 휴가 사용 신청서_16069651.html
# 처리 중... [381/8175] 20210607_베트남경제연구소(Vnomics) 웹사이트 개발 및 구축 용역 구입 품의_16068037.html
# 처리 중... [382/8175] 20210607_신우진 휴가(오후 반차) 사용 신청_16066921.html
# 처리 중... [383/8175] 20210607_연차휴가 품의_신성호_16062699.html
# 처리 중... [384/8175] 20210607_연차휴가신청_16060848.html
# 처리 중... [385/8175] 20210608_5월 출장비 신청의 건_16071450.html
# 처리 중... [386/8175] 20210608_6월 10일~11일 연차 사용 신청합니다._16070446.html
# 처리 중... [387/8175] 20210608_DGIST 연구사업 평가시스템 구축 프로젝트 출장비 품의 요청_16074598.html
# 처리 중... [388/8175] 20210608_휴가 사용을 신청합니다._16075510.html
# 처리 중... [389/8175] 20210608_휴가 신청 품의_16070642.html
# 처리 중... [390/8175] 20210608_휴가신청 품의(송준선, 6_15)_16075399.html
# 처리 중... [391/8175] 20210609_2021.06.14(월) 연차 품의_16079135.html
# 처리 중... [392/8175] 20210609_데이터이관 대응사업 이관설명회 행사 품의_16081048.html
# 처리 중... [393/8175] 20210609_반차 휴가 신청 (6_9)_16080595.html
# 처리 중... [394/8175] 20210610_'21.06.15 연차품의_16088177.html
# 처리 중... [395/8175] 20210610_명함 재박급 신청_16088285.html
# 처리 중... [396/8175] 20210610_사업관리 고아라 - 6_10(목) 오후 반차 신청의 건_16087112.html
# 처리 중... [397/8175] 20210610_연차휴가 신청의 건_16087071.html
# 처리 중... [398/8175] 20210610_오후 반차 신청드립니다._16093483.html
# 처리 중... [399/8175] 20210610_휴가 사용 신청서 올립니다. 승인 부탁드리겠습니다._16093904.html
# 처리 중... [400/8175] 20210611_2021-06-14(월) 휴가 신청합니다 - 1일_16094756.html
# 처리 중... [401/8175] 20210611_[대금결제] ITO_6월 외주용역비 대금 결제의 건 - 프리랜서_업체 (06_15)_16099960.html
# 처리 중... [402/8175] 20210611_국립식량과학원 2021년 작물연구정보시스템 위탁관리 사업 - ICT사업팀_프리랜서(이형균책임)_16099327.html
# 처리 중... [403/8175] 20210614_[대금결제] 공통_5월 외주용역비 대금 결제의 건-프리랜서 (06_15) - 수정 품의_16107594.html
# 처리 중... [404/8175] 20210614_연차 품의서_16106152.html
# 처리 중... [405/8175] 20210614_휴가 사용 신청_16106657.html
# 처리 중... [406/8175] 20210614_휴가 신청합니다._16103832.html
# 처리 중... [407/8175] 20210614_휴가사용 신청의 건_16107131.html
# 처리 중... [408/8175] 20210615_휴가 사용 품의_16110803.html
# 처리 중... [409/8175] 20210617_연차 품의서_16128844.html
# 처리 중... [410/8175] 20210617_휴가신청 _ 2021-06-18(금), 1일_16127362.html
# 처리 중... [411/8175] 20210618_[대중소] KCC정보통신(주) - 웹방화벽 대금 결제 품의_16138069.html
# 처리 중... [412/8175] 20210618_휴가 신청_16133975.html
# 처리 중... [413/8175] 20210618_휴가를 신청합니다._16137360.html
# 처리 중... [414/8175] 20210618_휴가사용 신청서_16139408.html
# 처리 중... [415/8175] 20210621_[대금결제] ITO_6월 외주용역비 대금 결제의 건 - 업체 (06_25)_16145504.html
# 처리 중... [416/8175] 20210621_[연차]2021.06.23(수) 휴가신청드립니다._16142551.html
# 처리 중... [417/8175] 20210621_반차 휴가 사용 신청서_16146186.html
# 처리 중... [418/8175] 20210621_휴가 사용 신청_16143114.html
# 처리 중... [419/8175] 20210621_휴가 사용 신청서 기안합니다._16150011.html
# 처리 중... [420/8175] 20210621_휴가 사용 신청서_16141766.html
# 처리 중... [421/8175] 20210622_20210625_사원_경동윤 개인 휴가 신청합니다._16153436.html
# 처리 중... [422/8175] 20210622_20210628_휴가신청_16154143.html
# 처리 중... [423/8175] 20210622_[신규_SI]유한양행 임상시험관리시스템 구축 계약 품의_16155153.html
# 처리 중... [424/8175] 20210622_[신규_솔루션]SK실트론 지식재산관리 시스템구축계약 품의_16154985.html
# 처리 중... [425/8175] 20210622_개인 휴가 신청_조신행 사원_2021.06.25(금) (연차)_16152979.html
# 처리 중... [426/8175] 20210622_대전 원자력연구원 출장비 지급 신청서 입니다_16150576.html
# 처리 중... [427/8175] 20210622_연차 신청의 건 (6_25, 금)_16153645.html
# 처리 중... [428/8175] 20210622_휴가 신청_20210625_16154200.html
# 처리 중... [429/8175] 20210623_(서부발전) 이중화 서버 H_W (4대) 구매건_16161555.html
# 처리 중... [430/8175] 20210623_김우석 선임 6월 25일 개인연차 사용_16161057.html
# 처리 중... [431/8175] 20210623_연차 품의서_16158555.html
# 처리 중... [432/8175] 20210624_06월 28일 휴가 사용 신청_16170194.html
# 처리 중... [433/8175] 20210624_[2021년 6월 25일 - 1일 연차 휴가 요청 드립니다]_16166748.html
# 처리 중... [434/8175] 20210624_[대금결제] 공통_5월 외주용역비 대금 결제의 건-(06_25) - 수정품의_16168874.html
# 처리 중... [435/8175] 20210624_사업관리 고아라 - 6_25(금) 오후 반차 신청의 건_16167302.html
# 처리 중... [436/8175] 20210624_연차사용품의_16170363.html
# 처리 중... [437/8175] 20210625_06-28  NHN NB, monitor x 4_16177010.html
# 처리 중... [438/8175] 20210625_06-29 이랜드 Monitor, Part x 12_16177040.html
# 처리 중... [439/8175] 20210625_06-30 OOCI Server x 1_16177069.html
# 처리 중... [440/8175] 20210625_06-31 NHN NB, Monitor x 24_16177090.html
# 처리 중... [441/8175] 20210625_20210624_출장비 품의_16175008.html
# 처리 중... [442/8175] 20210625_ITO_6월 외주용역비 대금 결제의 건-업체 (06_30)_16175507.html
# 처리 중... [443/8175] 20210625_LG전자_엘지전자(주)_TIPIS 특허 등급_분류 관리 고도화_특허 포트폴리오 - IPR사업팀_엠씨에스컨설팅(이건희)_16173630.html
# 처리 중... [444/8175] 20210625_연차 품의서_16174540.html
# 처리 중... [445/8175] 20210625_연차휴가신청_16179184.html
# 처리 중... [446/8175] 20210625_휴가 사용 신청의 건_16173699.html
# 처리 중... [447/8175] 20210625_휴가 신청 품의_16176419.html
# 처리 중... [448/8175] 20210627_연차휴가품의_16181382.html
# 처리 중... [449/8175] 20210628_2021년 6월 29일(화) 연차 휴가 신청합니다_16181959.html
# 처리 중... [450/8175] 20210628_6월 기타 경비 신청합니다_16184061.html
# 처리 중... [451/8175] 20210628_ETRI PMS 실버라이트 제거를 위한 시스템 개선 사업 관련 SpreadJS 선구매 품의_16186338.html
# 처리 중... [452/8175] 20210628_[신규_솔루션](주)한전KPS 지식재산전문 통합관리시스템 구축 매출계약 품의_16186469.html
# 처리 중... [453/8175] 20210628_[외주 PM 명함발급신청]_16183387.html
# 처리 중... [454/8175] 20210628_연차 휴가 신청(7_2, 1일)_16188718.html
# 처리 중... [455/8175] 20210629_06-32 NHN Monitor x 30_16195171.html
# 처리 중... [456/8175] 20210629_06-33 한국신용 Monitor x 10_16195190.html
# 처리 중... [457/8175] 20210629_06-34 이랜드 Monitor, Part x 13_16195212.html
# 처리 중... [458/8175] 20210629_[지출결의] 선급금이행보증증권 납부 승인 요청의 건_16194413.html
# 처리 중... [459/8175] 20210629_국립식량과학원 - 숙소 계약 관련 비용 신청(정정남)_16199203.html
# 처리 중... [460/8175] 20210629_대전지사 출장비 지급 신청_16190948.html
# 처리 중... [461/8175] 20210629_식량과학원 2021년작물연구정보서비스통합위탁관리 외주인원 구매신청 품의_16199199.html
# 처리 중... [462/8175] 20210629_연차 신청합니다_16196583.html
# 처리 중... [463/8175] 20210629_연차신청서(박형남) 입니다._16199126.html
# 처리 중... [464/8175] 20210629_한국콜마 프로젝트 회식비_16190983.html
# 처리 중... [465/8175] 20210629_휴가품의서_16197908.html
# 처리 중... [466/8175] 20210630_6월 야근식대 지급 신청서 올립니다._16208111.html
# 처리 중... [467/8175] 20210630_7월 2일 금요일 연차 사용 신청서_16199633.html
# 처리 중... [468/8175] 20210630_ETRI PMS 실버라이트 제거를 위한 시스템 개선 사업 관련 매출계약 품의_16204396.html
# 처리 중... [469/8175] 20210630_신우진 재직증명서 발금 신청_16205030.html
# 처리 중... [470/8175] 20210630_재직증명서 발급 요청_16205057.html
# 처리 중... [471/8175] 20210630_휴가 신청드립니다._16206345.html
# 처리 중... [472/8175] 20210630_휴가를 신청합니다._16204236.html
# 처리 중... [473/8175] 20210630_휴가신청 품의(송준선, 7_5)_16204944.html
# 처리 중... [474/8175] 20210701_07-01 다우기술 WS, Monitor x 52_16214055.html
# 처리 중... [475/8175] 20210701_07-02 경동나비엔 Server x 1_16214097.html
# 처리 중... [476/8175] 20210701_오전 반차 사용의 건 (7월 2일, 금)_16215743.html
# 처리 중... [477/8175] 20210701_휴가신청 _ 2021-07-02 (금), 1일_16212134.html
# 처리 중... [478/8175] 20210702_07-03 NHN WS, NB, Kit x4_16223432.html
# 처리 중... [479/8175] 20210702_07-04 NHN PC, Monitor, Kit x 31_16223480.html
# 처리 중... [480/8175] 20210702_07-05 이랜드 PC x 10_16223508.html
# 처리 중... [481/8175] 20210702_2021.07.02(금) 오후 반차 사용 신청의 건_16218527.html
# 처리 중... [482/8175] 20210702_신우진 휴가사용 신청서 (21.07.05 오전 반차)_16222759.html
# 처리 중... [483/8175] 20210705_07월 07일 휴가 사용 신청_16232882.html
# 처리 중... [484/8175] 20210705_[교통비]경비청구 요청드립니다._16229309.html
# 처리 중... [485/8175] 20210705_경영기획팀 정재이 - 7_7(수) 연차 신청의 건_16234389.html
# 처리 중... [486/8175] 20210705_반차 신청합니다_16227810.html
# 처리 중... [487/8175] 20210705_반차 휴가 사용 신청서_16231680.html
# 처리 중... [488/8175] 20210705_비품 구매 품의서 올립니다._16236948.html
# 처리 중... [489/8175] 20210705_식량과학원 2021년작물연구정보서비스통합위탁관리 외주인원 구매신청 품의_16232226.html
# 처리 중... [490/8175] 20210705_오전 반차 요청_16232788.html
# 처리 중... [491/8175] 20210705_휴가 사용 신청서 올립니다._16236952.html
# 처리 중... [492/8175] 20210706_6월 출장비 신청의 건_16240936.html
# 처리 중... [493/8175] 20210706_ETRI PMS실버라이트 제거를 위한 시스템개선 관련 검색솔루션 용역 신청 품의_16242932.html
# 처리 중... [494/8175] 20210706_[관세청] 개발용 전용회선비 지급을 품의합니다~_16243145.html
# 처리 중... [495/8175] 20210707_07-06 오렌지아이 Server, Switch x 3_16251043.html
# 처리 중... [496/8175] 20210707_07-07 NHN Monitor x 26_16251131.html
# 처리 중... [497/8175] 20210707_2021-07-09 반차 신청합니다_16253436.html
# 처리 중... [498/8175] 20210707_20210707_사원_경동윤 개인 오후 반차 신청합니다._16246588.html
# 처리 중... [499/8175] 20210707_2021_07_09(금) 연차휴가 신청_16246656.html
# 처리 중... [500/8175] 20210707_오전 반차 신청합니다._16246418.html
# 처리 중... [501/8175] 20210707_휴가신청 품의(송준선, 7_9)_16246660.html
# 처리 중... [502/8175] 20210708_2021-07-09 정서연 휴가 신청합니다 - 1일_16255248.html
# 처리 중... [503/8175] 20210708_2021.07.09(금) 연차휴가 결재요청드립니다._16255365.html
# 처리 중... [504/8175] 20210708_[신규_솔루션]포스코알텍 지재권관리시스템 개발 매출계약 품의_16257697.html
# 처리 중... [505/8175] 20210708_국내상표(DAVINCI) 불사용취소심판 대응 선수금 신청 (21.07.08)_16258422.html
# 처리 중... [506/8175] 20210708_김상욱 휴가 사용 신청서 입니다._16256094.html
# 처리 중... [507/8175] 20210708_휴가 사용 품의_16260414.html
# 처리 중... [508/8175] 20210708_휴가를 신청합니다._16255121.html
# 처리 중... [509/8175] 20210709_07-08 NHN Monitor x 55_16262848.html
# 처리 중... [510/8175] 20210709_07-09 이랜드 Monitor x 10_16262862.html
# 처리 중... [511/8175] 20210709_07-10  나이스 Monitor x 20_16262881.html
# 처리 중... [512/8175] 20210709_07-11 NHN Monitor x 42_16266084.html
# 처리 중... [513/8175] 20210709_김상욱 휴가 사용 신청서 입니다_16266032.html
# 처리 중... [514/8175] 20210709_연차휴가 신청(7_19, 1일)_16265494.html
# 처리 중... [515/8175] 20210709_휴가 사용 신청_16263053.html
# 처리 중... [516/8175] 20210709_휴가 신청합니다._16264156.html
# 처리 중... [517/8175] 20210712_[대금결제] ITO_7월 외주용역비 대금 결제의 건 - 프리랜서_업체 (07_15)_16278375.html
# 처리 중... [518/8175] 20210712_반차 신청합니다_16273776.html
# 처리 중... [519/8175] 20210712_반차 휴가 신청_16273612.html
# 처리 중... [520/8175] 20210712_연차휴가 신청입니다. (7_19)_16278676.html
# 처리 중... [521/8175] 20210712_연차휴가품의서_16273278.html
# 처리 중... [522/8175] 20210712_휴가신청 품의(송준선, 7_19)_16276370.html
# 처리 중... [523/8175] 20210713_(서부발전) 모바일오피스 이중화 솔루션 구매건_16287459.html
# 처리 중... [524/8175] 20210713_[대금결제] 공통_6월 외주용역비 대금 결제의 건_프리랜서 (7_15)_16284831.html
# 처리 중... [525/8175] 20210713_연차휴가 신청_16284438.html
# 처리 중... [526/8175] 20210714_2021-07-23일 휴가 신청합니다_16289997.html
# 처리 중... [527/8175] 20210714_연차 품의서_16288935.html
# 처리 중... [528/8175] 20210714_연차 품의서_16295403.html
# 처리 중... [529/8175] 20210714_휴가 사용 신청서_16289104.html
# 처리 중... [530/8175] 20210715_(S_W) LX하우시스 지적재산관리시스템 키프리스 플러스 연동 개발 및 공급 계약 품의_16297232.html
# 처리 중... [531/8175] 20210715_(기능개선) LX하우시스(구 LG하우시스) 지적재산관리시스템 기능개선 계약품의_16297251.html
# 처리 중... [532/8175] 20210715_07-12 나이스 Server, S_W x 10_16299732.html
# 처리 중... [533/8175] 20210715_07-13 NHN NB, Monitor x 26_16299755.html
# 처리 중... [534/8175] 20210715_07-14 이랜드 Kit, Part x 4_16299767.html
# 처리 중... [535/8175] 20210715_07-15 나이스신용정보 Monitor x 228_16299774.html
# 처리 중... [536/8175] 20210715_[대금결제] 키프리스플러스 LX하우시스(구 LG하우시스) 계정_16302006.html
# 처리 중... [537/8175] 20210715_반차 결재요청_16296615.html
# 처리 중... [538/8175] 20210716_(서부발전) DRM 암복호화 솔루션 구매건_16307841.html
# 처리 중... [539/8175] 20210716_(서부발전) 서버 이중화에 의한 PDF변환 솔루션 구매건_16307793.html
# 처리 중... [540/8175] 20210716_(정책과제_수정) 인큐시스 SMART HACCP 숙성고 S_W 연동기능 개발 (에스이지)_16308513.html
# 처리 중... [541/8175] 20210716_(정책과제_수정) 인큐시스 SMART HACCP 숙성고 컨트롤러 개발 (앤플러그)_16308492.html
# 처리 중... [542/8175] 20210716_2021 하계휴가 사용 신청의 건_16307570.html
# 처리 중... [543/8175] 20210716_2021.07.16(금) 오전 반차 사용 신청의 건_16307522.html
# 처리 중... [544/8175] 20210719_[모바일오피스 고도화 용역] 태블릿PC 구매 품의_16318454.html
# 처리 중... [545/8175] 20210719_결재 요청드립니다_16321090.html
# 처리 중... [546/8175] 20210719_여름휴가 연차신청서(박형남) 입니다._16316621.html
# 처리 중... [547/8175] 20210719_하계 휴가 사용 신청(7월 22일-23일, 2일간)_16313508.html
# 처리 중... [548/8175] 20210719_휴가를 신청합니다._16314040.html
# 처리 중... [549/8175] 20210720_[교보생명 금융마이데이터 시스템구축용역]에 관한 매출_매입 계약품의_16321645.html
# 처리 중... [550/8175] 20210720_대전 원자력연구원 출장비 지급 신청서 입니다_16321967.html
# 처리 중... [551/8175] 20210720_휴가신청 품의(송준선, 7_26 ~ 8_2)_16323363.html
# 처리 중... [552/8175] 20210721_07-16 NHN NB, Monitor x51_16331403.html
# 처리 중... [553/8175] 20210721_07-17 한국신용 Monitor x 3_16331432.html
# 처리 중... [554/8175] 20210721_07-18 천재교육 Part x 1_16333755.html
# 처리 중... [555/8175] 20210721_20210721_사원 경동윤_오후반차 신청합니다._16331462.html
# 처리 중... [556/8175] 20210721_[대금결제] ITO_7월 외주용역비 대금 결제의 건 - 업체 (07_26)_16335084.html
# 처리 중... [557/8175] 20210721_연차 휴가 품의_16332149.html
# 처리 중... [558/8175] 20210721_외주인력 구매신청_16331119.html
# 처리 중... [559/8175] 20210721_하계휴가 신청의 건 (7_28~30, 8_2)_16329792.html
# 처리 중... [560/8175] 20210721_하계휴가 신청합니다._16329973.html
# 처리 중... [561/8175] 20210721_하계휴가 품의서_16330492.html
# 처리 중... [562/8175] 20210721_휴가 사용 신청서 [한상근 사원] 입니다._16335720.html
# 처리 중... [563/8175] 20210721_휴가 사용 신청서 기안합니다._16336927.html
# 처리 중... [564/8175] 20210721_휴가 신청 합니다._16333908.html
# 처리 중... [565/8175] 20210721_휴가 신청드립니다._16332910.html
# 처리 중... [566/8175] 20210722_'21.07.26 연차품의_16342260.html
# 처리 중... [567/8175] 20210722_[대금결제] 공통_6월 외주용역비 대금 결제의 건-(07_25)_16343349.html
# 처리 중... [568/8175] 20210722_개인휴가 _ 2021-07-23 (금) _ 1일_16338693.html
# 처리 중... [569/8175] 20210722_연차 휴가 품의_16340802.html
# 처리 중... [570/8175] 20210722_휴가 사용신청서 품의_16344477.html
# 처리 중... [571/8175] 20210722_휴가 신청_20210723_16337655.html
# 처리 중... [572/8175] 20210722_휴가를 신청합니다._16339273.html
# 처리 중... [573/8175] 20210723_07-19 NHN Monitor x 25_16347844.html
# 처리 중... [574/8175] 20210723_07-20 NHN Monitor x 20_16347849.html
# 처리 중... [575/8175] 20210723_[2021년 연차휴가 사용 요청 드립니다]_16350848.html
# 처리 중... [576/8175] 20210723_[대금 결제] 서부발전 서버 4대 구매 건_유니마이크로테크놀로지(주)_16350417.html
# 처리 중... [577/8175] 20210723_[디지털서비스 전용몰 구축사업] 교통비용 품의_16347859.html
# 처리 중... [578/8175] 20210723_휴가 사용 신청서_16349875.html
# 처리 중... [579/8175] 20210726_2021.07.29(목) 휴가 사용 신청합니다._16353865.html
# 처리 중... [580/8175] 20210726_대중소기업 상생협력기금 종합관리시스템 구축 - 영림원소프트랩 - ERP 추가 개발 완료에 다른 지금 요청의 건(잔금 50%)_16358148.html
# 처리 중... [581/8175] 20210726_연차 휴가 신청(8_3~8_6, 4일)_16360230.html
# 처리 중... [582/8175] 20210726_연차휴가 신청의 건(김우석 선임)_16358065.html
# 처리 중... [583/8175] 20210726_휴가 사용 신청의 건_16354802.html
# 처리 중... [584/8175] 20210726_휴가를 신청합니다._16354858.html
# 처리 중... [585/8175] 20210726_휴가신청서(코로나백신 접종)_16360218.html
# 처리 중... [586/8175] 20210727_2021-07-29 정서연 여름 휴가 신청합니다 - 4일_16368273.html
# 처리 중... [587/8175] 20210727_2021_07_30(금) 연차휴가 신청_16365379.html
# 처리 중... [588/8175] 20210727_7월 기타 경비 신청 합니다_16364023.html
# 처리 중... [589/8175] 20210727_ITO_7월 외주용역비 대금 결제의 건-업체 (07_31)_16365590.html
# 처리 중... [590/8175] 20210727_하계휴가 품의서_16363883.html
# 처리 중... [591/8175] 20210727_휴가 품의서_16367617.html
# 처리 중... [592/8175] 20210728_07-21 OOCI Server x 1_16373582.html
# 처리 중... [593/8175] 20210728_07-22 선익시스템 Part x 1_16373614.html
# 처리 중... [594/8175] 20210728_07-23 다우 Monitor x 2_16373656.html
# 처리 중... [595/8175] 20210728_07-24 토요타 Part x 1_16373689.html
# 처리 중... [596/8175] 20210728_07-25 NHN Monitor x 15_16373701.html
# 처리 중... [597/8175] 20210728_20210803_사원_경동윤 휴가 신청합니다._16371433.html
# 처리 중... [598/8175] 20210728_2021년 7월 30일(금) 연차 휴가 신청합니다_16370407.html
# 처리 중... [599/8175] 20210728_경비 품의 입니다._16382238.html
# 처리 중... [600/8175] 20210728_김상욱 휴가 사용 신청서 입니다._16375259.html
# 처리 중... [601/8175] 20210728_백신 휴가_16374007.html
# 처리 중... [602/8175] 20210728_신우진 휴가(하계휴가 4일) 신청서_16372147.html
# 처리 중... [603/8175] 20210728_연차 사용 신청서 07_30 (금) 1일_16370286.html
# 처리 중... [604/8175] 20210728_연차휴가 결재요청_16375956.html
# 처리 중... [605/8175] 20210728_휴가 사용 신청합니다._16376569.html
# 처리 중... [606/8175] 20210728_휴가를 신청합니다._16386536.html
# 처리 중... [607/8175] 20210729_07-26 NHN Monitor x 15_16391956.html
# 처리 중... [608/8175] 20210729_07-27 한국신용 Monitor x 10_16391985.html
# 처리 중... [609/8175] 20210729_[여름휴가]결재요청 드립니다._16389740.html
# 처리 중... [610/8175] 20210729_[지급품의] 차건호변리사(로키특허법률사무소) 특허출원비용 지급의 건_16387279.html
# 처리 중... [611/8175] 20210729_구매 계약(발주) 품의서(외주인력) - (주)겸유컴퍼니_16390893.html
# 처리 중... [612/8175] 20210729_휴가 사용 신청_16387931.html
# 처리 중... [613/8175] 20210729_휴가 사용 신청서_16389664.html
# 처리 중... [614/8175] 20210730_2021.08.02(월) 연차 품의_16397653.html
# 처리 중... [615/8175] 20210730_여름휴가 신청합니다._16396522.html
# 처리 중... [616/8175] 20210730_휴가 사용 신청합니다._16397721.html
# 처리 중... [617/8175] 20210731_7월 야근식대 지급 신청서 올립니다._16402505.html
# 처리 중... [618/8175] 20210731_결재 요청 드립니다_16402566.html
# 처리 중... [619/8175] 20210802_PATINEX 2021 행사 참가비 신청 (08_02)_16407993.html
# 처리 중... [620/8175] 20210802_김현호 하계휴가 신청건(2021.08.02)_16403803.html
# 처리 중... [621/8175] 20210802_반차 사용(8_3, 오후)_16406835.html
# 처리 중... [622/8175] 20210802_휴가 사용 신청서 올립니다._16411146.html
# 처리 중... [623/8175] 20210802_휴가 사용 신청서(20210804)_16408716.html
# 처리 중... [624/8175] 20210802_휴가 사용 신청의 건_16408817.html
# 처리 중... [625/8175] 20210803_08-01 다우기술 Server x 1_16415290.html
# 처리 중... [626/8175] 20210803_08-02 이랜드 NB, Kit x 16_16415357.html
# 처리 중... [627/8175] 20210803_08-03 NHN NB, Monitor x 49_16415381.html
# 처리 중... [628/8175] 20210803_7월 출장비 신청의 건_16412196.html
# 처리 중... [629/8175] 20210803_8월 5일~8월 6일 휴가 신청합니다._16413376.html
# 처리 중... [630/8175] 20210803_경영기획팀 정재이 - 8_4(수) 연차 신청의 건_16414650.html
# 처리 중... [631/8175] 20210803_기타 경비 신청 (21.08.03)_16417041.html
# 처리 중... [632/8175] 20210804_[동양시스템즈] SI사업본부 - 레져(라운딩) 접대건_16422064.html
# 처리 중... [633/8175] 20210805_연차 휴가 신청 (8_17~8_18, 2일)_16429268.html
# 처리 중... [634/8175] 20210805_하계 휴가 품의_16426138.html
# 처리 중... [635/8175] 20210805_휴가 사용 신청_16429257.html
# 처리 중... [636/8175] 20210805_휴가 신청 드립니다._16427367.html
# 처리 중... [637/8175] 20210805_휴가 신청합니다._16431997.html
# 처리 중... [638/8175] 20210806_08-04 NHN WS, Monitor x 11_16434651.html
# 처리 중... [639/8175] 20210806_08-05 NHN Monitor x 30_16434683.html
# 처리 중... [640/8175] 20210806_08-06 NHN NB, Monitor x 8_16434707.html
# 처리 중... [641/8175] 20210806_[취업통계 조사시스템 유지보수 및 청년 진로정보 시스템 구축사업] 구매 품의_16435557.html
# 처리 중... [642/8175] 20210806_삼성SDI 프로젝트 MS-OFFICE 구매요청서_16435656.html
# 처리 중... [643/8175] 20210806_퇴직 품의_16437136.html
# 처리 중... [644/8175] 20210806_휴가 사용신청서 품의_16434009.html
# 처리 중... [645/8175] 20210809_2021년 8월 11일(수) 오후 반차 휴가 신청합니다_16442755.html
# 처리 중... [646/8175] 20210809_구매 계약(발주) 품의서(외주인력) - (주)아이티혜윰_16445414.html
# 처리 중... [647/8175] 20210809_구매 계약(발주) 품의서(외주인력) - 오픈윈드_16445424.html
# 처리 중... [648/8175] 20210809_김상욱 휴가 사용 신청서_ 입니다. ( 여름휴가 )_16445388.html
# 처리 중... [649/8175] 20210809_여름휴가 결재요청_16445409.html
# 처리 중... [650/8175] 20210809_여름휴가를 신청합니다._16445469.html
# 처리 중... [651/8175] 20210809_연차휴가 신청_16448567.html
# 처리 중... [652/8175] 20210809_연차휴가를 신청합니다._16445443.html
# 처리 중... [653/8175] 20210809_하계 휴가 신청_16447913.html
# 처리 중... [654/8175] 20210809_하계휴가 사용 신청서_16446919.html
# 처리 중... [655/8175] 20210810_(기능개선) LGU+ 지식재산관리시스템 기능개선 계약 품의_16452173.html
# 처리 중... [656/8175] 20210810_08-07 코비젼 Solution x 1_16456285.html
# 처리 중... [657/8175] 20210810_08-08 Atsys Server x 1_16455373.html
# 처리 중... [658/8175] 20210810_08-09 NHN Monitor x 22_16455387.html
# 처리 중... [659/8175] 20210810_ETRI 통합정보시스템(통합문서관리) https 전환 사업 관련 C_P품의_16456143.html
# 처리 중... [660/8175] 20210810_ETRI 통합정보시스템(통합문서관리) https 전환 사업 매출계약 품의_16457537.html
# 처리 중... [661/8175] 20210810_[대금결제] ITO_외주용역비 대금 결제의 건 - 프리랜서_업체 (08_15)_16453442.html
# 처리 중... [662/8175] 20210810_연차 휴가 품의_16452436.html
# 처리 중... [663/8175] 20210810_휴가 사용 신청서_16455524.html
# 처리 중... [664/8175] 20210811_2021-08-11 정서연 휴가 신청합니다 - 0.5일_16461011.html
# 처리 중... [665/8175] 20210811_개인휴가 _ 2021-08-13 (금)_16460300.html
# 처리 중... [666/8175] 20210811_연차 품의서_16462197.html
# 처리 중... [667/8175] 20210811_연차 휴가 사용_16461963.html
# 처리 중... [668/8175] 20210811_오후 반차 사용 신청서 [한상근 사원] 입니다._16461631.html
# 처리 중... [669/8175] 20210811_전진원 사원 휴가 사용 신청서_16460080.html
# 처리 중... [670/8175] 20210811_출산휴가 품의 요청_16466639.html
# 처리 중... [671/8175] 20210811_하계 휴가 신청_16463146.html
# 처리 중... [672/8175] 20210811_하계 휴가(8_17~8_18) 사용 신청._16460249.html
# 처리 중... [673/8175] 20210811_하계휴가 품의_16462062.html
# 처리 중... [674/8175] 20210812_[대금결제] 공통_7월 외주용역비 대금 결제의 건_프리랜서 (8_15)_16470079.html
# 처리 중... [675/8175] 20210812_[디지털서비스 전용몰 구축사업]확정C_P 품의_16470566.html
# 처리 중... [676/8175] 20210812_[조달청]디지털서비스 전용몰 구축사업(RPA) 도입 구매 품의_16470739.html
# 처리 중... [677/8175] 20210813_08-10 NHN WS, Monitor x 23_16475353.html
# 처리 중... [678/8175] 20210813_08-11 NHN Monitor x 42_16475370.html
# 처리 중... [679/8175] 20210813_08-12 이랜드 PC, Kit x 4_16475385.html
# 처리 중... [680/8175] 20210813_연차휴가를 신청합니다._16476289.html
# 처리 중... [681/8175] 20210813_휴가 사용신청서 품의_16477939.html
# 처리 중... [682/8175] 20210816_연차 품의_16483193.html
# 처리 중... [683/8175] 20210817_ETRI 통합정보시스템(통합문서관리) https 전환 관련 구매신청 품의_16487003.html
# 처리 중... [684/8175] 20210817_[재기안] 삼성SDI 프로젝트 MS-OFFICE 구매요청서_16485373.html
# 처리 중... [685/8175] 20210817_연차 휴가 신청(8_23, 1일)_16483584.html
# 처리 중... [686/8175] 20210817_휴가사용품의_16483425.html
# 처리 중... [687/8175] 20210818_반차 사용 품의 드립니다_16492612.html
# 처리 중... [688/8175] 20210819_(기능개선) 한국자동차연구원 목표실적 통계 및 기술이전 프로세스 기능개선 계약 품의_16502541.html
# 처리 중... [689/8175] 20210819_2021년 여름휴가 신청(2021.08.24(화)~27(금))_16500019.html
# 처리 중... [690/8175] 20210819_8월 20일 연차 신청 합니다_16500510.html
# 처리 중... [691/8175] 20210819_여름휴가 품의서_16501064.html
# 처리 중... [692/8175] 20210819_연차사용 신청의 건 (하계휴가)_16501902.html
# 처리 중... [693/8175] 20210819_연차사용 신청의 건_16500040.html
# 처리 중... [694/8175] 20210819_연차휴가품의_16501529.html
# 처리 중... [695/8175] 20210819_오전 반차 및 월차 사용의 건 (8월 26일 오후-27일)_16504675.html
# 처리 중... [696/8175] 20210819_휴가 사용 신청_16504387.html
# 처리 중... [697/8175] 20210820_08-13 NHN NB, Monitor x 33_16509241.html
# 처리 중... [698/8175] 20210820_08-14 NHN Monitor x 20_16509261.html
# 처리 중... [699/8175] 20210820_08-15 토요타 Part x 1_16509285.html
# 처리 중... [700/8175] 20210820_08-16 NHN NB, Monitor x 23_16509307.html
# 처리 중... [701/8175] 20210820_[대금결제] ITO_8월 외주용역비 대금 결제의 건 - 업체 (08_25)_16508596.html
# 처리 중... [702/8175] 20210820_[대금결제] 삼성SDI 특허관리시스템 개선 구축 프로젝트 MS-OFFICE 구매 건_16507876.html
# 처리 중... [703/8175] 20210820_[대금결제] 한국취업통계 조사시스템 유지보수 및 청년 진로정보시스템 구축사업 용역 계약_선금 지급의 건(라온비트)_16509891.html
# 처리 중... [704/8175] 20210820_서부발전 전자회의 솔루션 구매 및 Customizing 도급계약_16510138.html
# 처리 중... [705/8175] 20210820_휴가 사용 신청_16514050.html
# 처리 중... [706/8175] 20210820_휴가 사용 신청합니다._16509088.html
# 처리 중... [707/8175] 20210823_2021년도 하계휴가 신청합니다._16521098.html
# 처리 중... [708/8175] 20210823_[통합연구지원시스템 전문기관 데이터이관 대응사업] 커뮤니티 구매 품의_16521345.html
# 처리 중... [709/8175] 20210823_국내상표(다빈치) 불사용취소심판 대응 비용 신청 (21.08.23)_16517269.html
# 처리 중... [710/8175] 20210823_대전 원자력연구원 출장비 지급 신청서 입니다_16517588.html
# 처리 중... [711/8175] 20210823_반차 사용 신청_16518756.html
# 처리 중... [712/8175] 20210823_휴가 사용 신청서(20210830)_16519460.html
# 처리 중... [713/8175] 20210824_20210827_사원_경동윤_개인휴가신청합니다._16528622.html
# 처리 중... [714/8175] 20210824_8월 27일 (금) 연차 사용 신청합니다._16529116.html
# 처리 중... [715/8175] 20210824_[대금결제] ETRI PMS 실버라이트 제거를 위한 시스템 개선 라이센스 결제품의_16528832.html
# 처리 중... [716/8175] 20210824_[대금결제] 공통_7월 외주용역비 대금 결제의 건-(08_25)_16531496.html
# 처리 중... [717/8175] 20210824_연차 품의서_16524991.html
# 처리 중... [718/8175] 20210824_연차 휴가 신청(8_30, 1일)_16530796.html
# 처리 중... [719/8175] 20210824_연차휴가 신청_16524854.html
# 처리 중... [720/8175] 20210824_휴가 사용 신청의 건_16528333.html
# 처리 중... [721/8175] 20210825_(신규) 한화시스템 2021년 지식재산관리시스템 유지보수 계약 품의_16534561.html
# 처리 중... [722/8175] 20210825_08-17 토요타 유지보수 x 1_16533567.html
# 처리 중... [723/8175] 20210825_08-18 Atsys Server x 1_16533601.html
# 처리 중... [724/8175] 20210825_08-19 경동나비엔 Server x 1_16533629.html
# 처리 중... [725/8175] 20210825_08-20 NHN NB, Monitor x 4_16533650.html
# 처리 중... [726/8175] 20210825_08-21 NHN Monitor x 20_16536224.html
# 처리 중... [727/8175] 20210825_[대금결제] 조달청 디지털서비스전용몰 RPA기반 자동화 구축 계약_선금 지급의 건 (인포비정보기술)_16537961.html
# 처리 중... [728/8175] 20210825_[하계휴가 품의]_16533250.html
# 처리 중... [729/8175] 20210825_월차 사용의 건 (8월 27일)_16533442.html
# 처리 중... [730/8175] 20210825_휴가사용 신청의 건_16534640.html
# 처리 중... [731/8175] 20210826_2021.08.30(월) 연차 품의_16546339.html
# 처리 중... [732/8175] 20210826_8월 교통비 신청합니다_16541153.html
# 처리 중... [733/8175] 20210826_8월 기타 경비 신청 합니다_16541196.html
# 처리 중... [734/8175] 20210826_녹색인증 정보시스템 개선사업의 용역계약 승인요청_16545727.html
# 처리 중... [735/8175] 20210826_연차휴가 신청의 건_16541524.html
# 처리 중... [736/8175] 20210826_오후 반차 신청드립니다._16543172.html
# 처리 중... [737/8175] 20210827_[대금결제] 2021년 녹색인증 정보시스템 개선 용역_선금 지급의 건(모렌소프트)_16552560.html
# 처리 중... [738/8175] 20210827_[대금결제] ETRI 통합정보시스템(통합문서관리) https전환_선금 지급의 건 (사이버다임)_16552282.html
# 처리 중... [739/8175] 20210827_[대금결제] 한국서부발전 태블릿PC 5대 북커버 및 로고 인쇄 비용_16552199.html
# 처리 중... [740/8175] 20210827_서부발전 태블릿 북커버 샘플 구매 신청 품의 (21.08.27)_16548875.html
# 처리 중... [741/8175] 20210827_오후 반차 신청합니다._16548251.html
# 처리 중... [742/8175] 20210830_2021년 9월 2일(목) ~ 2021년 9월 7일(화) 하계 휴가 신청합니다_16556491.html
# 처리 중... [743/8175] 20210830_ITO_8월 외주용역비 대금 결제의 건-업체 (08_31) _#2_16556761.html
# 처리 중... [744/8175] 20210830_[연차신청] 김우석 선임 연차1일 사용의 건_16559754.html
# 처리 중... [745/8175] 20210830_경영기획팀 정재이 - 9_2~9_3(목~금) 여름휴가 신청의 건_16557747.html
# 처리 중... [746/8175] 20210830_연차신청서(박형남) 입니다._16564817.html
# 처리 중... [747/8175] 20210830_인감도장 사용 품의서 (전주대 빅데이터 플랫폼)_16560189.html
# 처리 중... [748/8175] 20210831_08-22 NHN Monitor x 30_16566509.html
# 처리 중... [749/8175] 20210831_08-23 나이스 Cable x 120_16566550.html
# 처리 중... [750/8175] 20210831_반차 사용 신청_16565637.html
# 처리 중... [751/8175] 20210831_휴가 신청합니다._16565555.html
# 처리 중... [752/8175] 20210901_8월 출장비 신청의 건_16575229.html
# 처리 중... [753/8175] 20210901_[2021년 8월 경비신청서 입니다]_16573988.html
# 처리 중... [754/8175] 20210901_연차 사용 품의_16579114.html
# 처리 중... [755/8175] 20210901_휴가를 신청합니다._16577766.html
# 처리 중... [756/8175] 20210902_2021.09.06(월), 09.07(화) 오전 반차 휴가 신청(자격증 시험)_16586706.html
# 처리 중... [757/8175] 20210902_개인휴가 _ 2021-09-03(금), 1일_16584259.html
# 처리 중... [758/8175] 20210902_김상욱 휴가 사용 신청서_ 입니다._16590692.html
# 처리 중... [759/8175] 20210902_반차 사용 품의 드립니다._16590330.html
# 처리 중... [760/8175] 20210902_연차 휴가 신청(9_10, 1일)_16583597.html
# 처리 중... [761/8175] 20210902_오후반차 품의_16585074.html
# 처리 중... [762/8175] 20210903_09-01 42Dot NB x 1_16594741.html
# ...
# 처리 중... [7985/8175] 20250924_연차 사용 신청_26206307.html
# 처리 중... [7986/8175] 20250924_휴가 신청서 올립니다._26204849.html
# 처리 중... [7987/8175] 20250924_휴가 신청합니다. (2025년 09월 24일 오후)_26202354.html
# 처리 중... [7988/8175] 20250925_2025-10-10, 10-13 정서연 휴가 신청합니다 - 2일_26211312.html
# 처리 중... [7989/8175] 20250925_구매 계약(발주) 품의서(S_W,H_W)_PI첨단소재_특허관리시스템(IPMS) 구축_검색엔진(다이퀘스트-마리너3)_26216117.html
# 처리 중... [7990/8175] 20250925_신우진 연차휴가 사용 신청(25.09.30 화 , 1)_26218847.html
# 처리 중... [7991/8175] 20250925_연차휴가사후품의_26216993.html
# 처리 중... [7992/8175] 20250925_연차휴가품의_26217025.html
# 처리 중... [7993/8175] 20250925_출장비 지급 신청서_한국지질자원연구원 지식재산권관리시스템 DB전환사업 제안평가 참석의 건_26217628.html
# 처리 중... [7994/8175] 20250925_휴가 사용 신청서_26214220.html
# 처리 중... [7995/8175] 20250925_휴가 사용 신청서_이의환 책임_26216594.html
# 처리 중... [7996/8175] 20250925_휴가 신청합니다. (2025년 09월 25일 오후)_26212848.html
# 처리 중... [7997/8175] 20250926_2025.10.02(목) 연차휴가 사용 신청_26223031.html
# 처리 중... [7998/8175] 20250926_9월 26일(금) 오후 반차(0.5일) 사용 신청_26220701.html
# 처리 중... [7999/8175] 20250926_가산퍼블릭 숙소 계약 관련 인감 반출 품의 건._26221955.html
# 처리 중... [8000/8175] 20250926_숙소_가산버플릭 1401호 계약 품의_26222545.html
# 처리 중... [8001/8175] 20250926_연차사용 신청의 건_26222513.html
# 처리 중... [8002/8175] 20250926_휴가신청_26219870.html
# 처리 중... [8003/8175] 20250929_2025-09-29 임민규 휴가 신청서 올립니다._26235966.html
# 처리 중... [8004/8175] 20250929_2025년 10월 10일(금) - 1일_26232813.html
# 처리 중... [8005/8175] 20250929_9월 교통비_26235458.html
# 처리 중... [8006/8175] 20250929_9월 기타 경비 신청합니다_26235482.html
# 처리 중... [8007/8175] 20250929_[대금결제] 9월 외주용역비 대금 결제의 건(DX사업팀)_프리랜서,업체 (10_15)_26235605.html
# 처리 중... [8008/8175] 20250929_[대금결제] 9월 외주용역비 대금 결제의 건(IP솔루션팀)_프리랜서,업체 (10_15)_26235180.html
# 처리 중... [8009/8175] 20250929_[대금결제] 9월 외주용역비 대금 결제의 건(공공사업팀)_프리랜서 (10_15)_26235524.html
# 처리 중... [8010/8175] 20250929_[대금결제] 9월 외주용역비 대금 결제의 건(공통)_업체 (10_15)_26234982.html
# 처리 중... [8011/8175] 20250929_김상욱 휴가 사용 신청서_26234657.html
# 처리 중... [8012/8175] 20250929_김화연 휴가사용 신청 품의(2025.10.10)_26234839.html
# 처리 중... [8013/8175] 20250929_변경 계약(발주) 품의서(외주인력)_외주_올댓휴먼_서영준_리앤목_통합정보시스템 구축(250401~260331)_26235538.html
# 처리 중... [8014/8175] 20250929_연차 휴가 품의_26233237.html
# 처리 중... [8015/8175] 20250929_연차휴가 사용신청_26235914.html
# 처리 중... [8016/8175] 20250929_연차휴가품의_26234341.html
# 처리 중... [8017/8175] 20250929_회의실 테이블_의자 대금지급 요청드립니다._26238356.html
# 처리 중... [8018/8175] 20250929_휴가 사용 신청_김별님_26232749.html
# 처리 중... [8019/8175] 20250929_휴가사용 품의(10_10, 송준선)_26233023.html
# 처리 중... [8020/8175] 20250930_09-12 NHN Monitor x 30_26241814.html
# 처리 중... [8021/8175] 20250930_09-13 Monitor x 31_26241856.html
# 처리 중... [8022/8175] 20250930_09-14 나이스 Server x 3_26241882.html
# 처리 중... [8023/8175] 20250930_09-15 나이스 PC x 10_26241916.html
# 처리 중... [8024/8175] 20250930_10월 10일(금), 연차휴가 신청_26242570.html
# 처리 중... [8025/8175] 20250930_10월 17일 반차, 10월 22일 반차, 10월 27일 연차 신청합니다._26241286.html
# 처리 중... [8026/8175] 20250930_10월 2일(목) 연차 사용 신청_26249113.html
# 처리 중... [8027/8175] 20250930_2025-09-30 김지연 휴가 신청합니다 - 오후반차_26241284.html
# 처리 중... [8028/8175] 20250930_2025-10-10 (금) 김빌리_연차휴가 (1일)_26243999.html
# 처리 중... [8029/8175] 20250930_2025.10.10(금) 연차휴가 신청의 건_26246634.html
# 처리 중... [8030/8175] 20250930_2025.11.01. ~ 2026.04.30. (6개월) 육아휴직 신청_26242072.html
# 처리 중... [8031/8175] 20250930_2025년 10월 1일 윤영현 휴가 신청합니다. - 1일_26241320.html
# 처리 중... [8032/8175] 20250930_9월 30일 오후 반차_26247401.html
# 처리 중... [8033/8175] 20250930_[대금결제] 한국연구재단_2024년 NRF 정보시스템 통합 위탁운영_2025년 9월분 대금 지급의 건_26249499.html
# 처리 중... [8034/8175] 20250930_연차 신청합니다 (10_10)_26242729.html
# 처리 중... [8035/8175] 20250930_연차 품의서_26241493.html
# 처리 중... [8036/8175] 20250930_연차 휴가 신청 (10_10 1일)_26248067.html
# 처리 중... [8037/8175] 20250930_이지남_휴가 사용 신청서(10_2)_26243419.html
# 처리 중... [8038/8175] 20250930_휴가 사용 신청_26242079.html
# 처리 중... [8039/8175] 20250930_휴가 사용신청(10_10)_26246060.html
# 처리 중... [8040/8175] 20250930_휴가를 신청합니다._26242819.html
# 처리 중... [8041/8175] 20251001_10월 10일(금) 연차 신청_26252439.html
# 처리 중... [8042/8175] 20251001_10월 10일(목) 연차 신청_26256336.html
# 처리 중... [8043/8175] 20251001_20251010_연차 신청 합니다_26258416.html
# 처리 중... [8044/8175] 20251001_25.10.16 - 유민경 사원 연차 신청서_26255832.html
# 처리 중... [8045/8175] 20251001_[개발팀] 박종호 사원 휴가 신청_26255175.html
# 처리 중... [8046/8175] 20251001_다우오피스 (그룹웨어) 프로그램 도입(교체) 건_26261113.html
# 처리 중... [8047/8175] 20251001_다우오피스(그룹웨어) 설치비 선금 지급요청_26262500.html
# 처리 중... [8048/8175] 20251001_반차 휴가 품의_26252923.html
# 처리 중... [8049/8175] 20251001_반차사용 품의_26252599.html
# 처리 중... [8050/8175] 20251001_연차 사용 품의 - 신성호_26257774.html
# 처리 중... [8051/8175] 20251001_연차 휴가 신청(10_10, 1일)_26261770.html
# 처리 중... [8052/8175] 20251001_연차 휴가 신청(10_31, 1일)_26256911.html
# 처리 중... [8053/8175] 20251001_연차휴가 신청_26260829.html
# 처리 중... [8054/8175] 20251001_오후 반차 신청 (20251001)_26252988.html
# 처리 중... [8055/8175] 20251001_오후반차 휴가 신청서_26253484.html
# 처리 중... [8056/8175] 20251001_접대비 사용 품의서_20250902_26259211.html
# 처리 중... [8057/8175] 20251001_휴가 사용 신청_26260949.html
# 처리 중... [8058/8175] 20251001_휴가 사용 신청서 [한상근 선임] 입니다._26256484.html
# 처리 중... [8059/8175] 20251001_휴가 사용 신청서_26260799.html
# 처리 중... [8060/8175] 20251002_10_10(금) 휴가 신청_26273095.html
# 처리 중... [8061/8175] 20251002_2025년 10월 10일 연차 휴가 신청_26269665.html
# 처리 중... [8062/8175] 20251002_2025년 10월 2일, 13일 - 1.5일_26270669.html
# 처리 중... [8063/8175] 20251002_[구매-외주] KIAT 유지관리 사업 인력 계약 변경의 건(황제훈)_26272462.html
# 처리 중... [8064/8175] 20251002_[대금결제] ITO_10월 외주용역비 대금 결제의 건 (10_15)_26270327.html
# 처리 중... [8065/8175] 20251002_[휴가신청] 임현준(10_10, 금)_26271945.html
# 처리 중... [8066/8175] 20251002_김상욱 에트리 지재권시스템 기능개선 출장 품의_26269002.html
# 처리 중... [8067/8175] 20251002_연차품의신청_26273212.html
# 처리 중... [8068/8175] 20251002_휴가 사용 신청_26274723.html
# 처리 중... [8069/8175] 20251002_휴가 사용 신청서_이의환 책임_26273064.html
# 처리 중... [8070/8175] 20251002_휴가 신청_26266664.html
# 처리 중... [8071/8175] 20251002_휴가사용신청_2025년 10월 10일(금)_연차휴가(1일)_26273417.html
# 처리 중... [8072/8175] 20251002_휴가신청품의_26273409.html
# 처리 중... [8073/8175] 20251009_[매입] KIAT 2025년 정보시스템 데이터센터 통합 운영 및 유지보수 매입 - 전기케이블 포설_26278490.html
# 처리 중... [8074/8175] 20251010_2025년 10월 31일 반차 신청_이민영 사원_26282874.html
# 처리 중... [8075/8175] 20251010_2025년 11월 3일 연차 신청_이민영 사원_26282890.html
# 처리 중... [8076/8175] 20251010_김보라_휴가 사용 신청서(10_15)_26280317.html
# 처리 중... [8077/8175] 20251013_(LG전) 야근식대 지급 신청_26288190.html
# 처리 중... [8078/8175] 20251013_2025년 11월 03일(월) - 1일_26292290.html
# 처리 중... [8079/8175] 20251013_[대금결제] 9월 외주용역비 대금 결제의 건(DX사업팀)_프리랜서,업체 (10_15)_26294261.html
# 처리 중... [8080/8175] 20251013_김상욱 에트리 출장비 지급 신청서_8월_26291955.html
# 처리 중... [8081/8175] 20251014_2025 KINPA 행사 컨퍼런스백 제작 비용_메가플러스(10_14)_26307756.html
# 처리 중... [8082/8175] 20251014_20251015, 20251023 사원 이규범 개인휴가 신청합니다_26302267.html
# 처리 중... [8083/8175] 20251014_비품 구매의 건_26305944.html
# 처리 중... [8084/8175] 20251014_연차 품의서_26302052.html
# 처리 중... [8085/8175] 20251014_전산실이전 및 재구축(용역비,P770 기술지원비) 매출품의_26302742.html
# 처리 중... [8086/8175] 20251014_한국원자력연구원 출장 품의_26302211.html
# 처리 중... [8087/8175] 20251014_휴가 신청건_26300325.html
# 처리 중... [8088/8175] 20251014_휴가 신청합니다._26300301.html
# 처리 중... [8089/8175] 20251015_25.10.28 ~ 25.10.31 - 유민경 사원 연차 신청서_26317968.html
# 처리 중... [8090/8175] 20251015_[한국원자력연구원] 대전 원자력연구원 방문_26310393.html
# 처리 중... [8091/8175] 20251015_김상욱 에트리 출장비 지급 신청서_9월_26312747.html
# 처리 중... [8092/8175] 20251015_반차 휴가 품의서_26315116.html
# 처리 중... [8093/8175] 20251015_야근식대 지급 신청서 [한상근 선임] 입니다._26313613.html
# 처리 중... [8094/8175] 20251015_연차 품의서_26313340.html
# 처리 중... [8095/8175] 20251016_[ATC+과제]간접비_CES2026 공동관 참가 비용(1차)_아이엠월드_26322481.html
# 처리 중... [8096/8175] 20251016_[선박의장]대금결제_연구시설장비비_GPU 서버 업그레이드_한국렌탈_26322351.html
# 처리 중... [8097/8175] 20251016_매출 계약 품의서_한국에너지공과대학교_지식재산권 관리시스템 고도화 용역_26319584.html
# 처리 중... [8098/8175] 20251016_반차 휴가 품의_26327041.html
# 처리 중... [8099/8175] 20251017_10-01 NHN PC, Monitor x 32_26329166.html
# 처리 중... [8100/8175] 20251017_10-02 NHN Monitor x 50_26329187.html
# 처리 중... [8101/8175] 20251017_10_21(화) 오전 반차 신청_26330129.html
# 처리 중... [8102/8175] 20251017_10월 27일(월)~28(화) 연차 신청_26330079.html
# 처리 중... [8103/8175] 20251017_10월 KR-01호 ㈜다우기술  P2725DE _ 2EA 발주의 건_26329168.html
# 처리 중... [8104/8175] 20251017_[ATC+과제]대금결제_간접비_CES2026 공동관 참가 비용(1차)_아이엠월드_26332959.html
# 처리 중... [8105/8175] 20251017_김상욱 휴가 사용 신청서 입니다._26328382.html
# 처리 중... [8106/8175] 20251017_반차 휴가 품의_26329871.html
# 처리 중... [8107/8175] 20251017_연차 사용 품의 - 신성호_26328007.html
# 처리 중... [8108/8175] 20251017_연차 사용 품의(오후반차) - 신성호_26328028.html
# 처리 중... [8109/8175] 20251018_10월 22일, 31일 휴가신청합니다._26336187.html
# 처리 중... [8110/8175] 20251019_휴가 사용 신청서_김상호_26337020.html
# 처리 중... [8111/8175] 20251020_2025 KINPA 행사 경품 구매 및 물품 대여 비용 (10_20)_26344398.html
# 처리 중... [8112/8175] 20251020_[대금결제] 9월 도급비용 대금 결제의 건(공통)_업체 (10_25)_26342715.html
# 처리 중... [8113/8175] 20251020_[대금결제] 9월 외주용역비 대금 결제의 건(DX사업본부_발진회)_업체 (10_25)_26342951.html
# 처리 중... [8114/8175] 20251020_[대금결제] 9월 외주용역비 대금 결제의 건(DX사업팀)_업체 (10_25)_26343185.html
# 처리 중... [8115/8175] 20251020_[대금결제] 9월 외주용역비 대금 결제의 건(ETRI팀)_업체 (10_25)_26343397.html
# 처리 중... [8116/8175] 20251020_[대금결제] 9월 외주용역비 대금 결제의 건(IP솔루션팀)_업체 (10_25)_26342824.html
# 처리 중... [8117/8175] 20251020_[대금결제] 9월 외주용역비 대금 결제의 건(공공사업팀)_업체 (10_25)_26343084.html
# 처리 중... [8118/8175] 20251020_[대금결제] ETRI 통합정보(ETRIware) 유지관리 계약 - 2025년 9월분 대금 지급의 건_26343687.html
# 처리 중... [8119/8175] 20251020_연차 품의서_26337844.html
# 처리 중... [8120/8175] 20251020_연차 품의서_26338607.html
# 처리 중... [8121/8175] 20251020_휴가 신청합니다._26339547.html
# 처리 중... [8122/8175] 20251021_10월 KR-02호 ㈜다우기술  P2725DE _ 10EA 발주의 건_26349251.html
# 처리 중... [8123/8175] 20251021_[대금결제] Dell 사업 매입 대금 결제의 건-에스씨지솔루션즈 외(9월)_26352776.html
# 처리 중... [8124/8175] 20251021_[대금결제] ITO_10월 외주용역비 대금 결제의 건 (10_25)_26352114.html
# 처리 중... [8125/8175] 20251021_[대금결제] 연차등록료(2025년 11월)수수료지급_원니스(10_25)_26352029.html
# 처리 중... [8126/8175] 20251021_[대금결제] 연차료 사업 관납료 대금 결제의 건-원니스(2025.12월_4분기추가)_26352187.html
# 처리 중... [8127/8175] 20251021_[대금결제] 자동차손해배상진흥원_감시감독관리시스템 구축_WEB_WAS_DB 서버 구축 - 필라테크_26350336.html
# 처리 중... [8128/8175] 20251021_[대금결제] 차세대융합기술연구원 통합정보시스템 유지관리 계약 - 2025년 9월분 대금 지급의 건_26348387.html
# 처리 중... [8129/8175] 20251021_[대금결제] 축산물품질평가원 통합유지보수 계약_9월분 대금 지급의 건_26349404.html
# 처리 중... [8130/8175] 20251021_[대금결제] 한국산업기술진흥원 데이터센터 통합 운영 및 유지보수_2025년 9월분 대금 지급의 건_26352223.html
# 처리 중... [8131/8175] 20251021_[대금결제] 한국연구재단 클라우드 네이티브 전환사업_개발용PC렌탈(연장)_한국렌탈(주)_26349877.html
# 처리 중... [8132/8175] 20251021_연차 품의서_26347874.html
# 처리 중... [8133/8175] 20251021_퇴직 품의서 결재 요청드립니다._26353974.html
# 처리 중... [8134/8175] 20251021_휴가 신청_26348466.html
# 처리 중... [8135/8175] 20251022_[개발팀] 박종호 사원 휴가 신청_26362912.html
# 처리 중... [8136/8175] 20251022_[휴가사용신청서] 연차 휴가 신청_박종아 25년 10월 27일(월)_26360477.html
# 처리 중... [8137/8175] 20251022_신우진 연차휴가 사용 신청(25.10.22, 1일)_26361165.html
# 처리 중... [8138/8175] 20251022_연차 사용 신청_26362273.html
# 처리 중... [8139/8175] 20251023_반차 신청드립니다._26369146.html
# 처리 중... [8140/8175] 20251023_세종 축평원 IT지원실 레이저프린터 토너 구매 신청 건_26365219.html
# 처리 중... [8141/8175] 20251023_연차 휴가 품의서_26370939.html
# 처리 중... [8142/8175] 20251023_출장비 지급 신청서_26367271.html
# 처리 중... [8143/8175] 20251023_휴가사용 품의(10_27, 송준선)_26371563.html
# 처리 중... [8144/8175] 20251024_연차 품의서_26375598.html
# 처리 중... [8145/8175] 20251024_연차 품의서_26376310.html
# 처리 중... [8146/8175] 20251024_연차 품의서_26376738.html
# 처리 중... [8147/8175] 20251024_연차 휴가 품의_26374932.html
# 처리 중... [8148/8175] 20251024_오후 반차 휴가 신청 (10_24 1일)_26373770.html
# 처리 중... [8149/8175] 20251024_휴가 신청합니다. (2025년 10월 24일 오전 _ 0.5일)_26373581.html
# 처리 중... [8150/8175] 20251026_연차 사용 신청_26381761.html
# 처리 중... [8151/8175] 20251027_10월 KR-03호 오오씨아이㈜  HBA355e x 2set 발주의 건_26387592.html
# 처리 중... [8152/8175] 20251027_기타 경비 신청_26383540.html
# 처리 중... [8153/8175] 20251027_신우진 연차휴가 사용 신청(25.11.03~11.04 2일)_26384640.html
# 처리 중... [8154/8175] 20251027_연차 품의서_26383472.html
# 처리 중... [8155/8175] 20251027_휴가 사용 신청드립니다._26382907.html
# 처리 중... [8156/8175] 20251028_10-03 NHN PC, Monitor x 12_26393516.html
# 처리 중... [8157/8175] 20251028_10-04 NHN Monitor x 50_26393540.html
# 처리 중... [8158/8175] 20251028_10-05 한화손보 Monitor x 1_26393568.html
# 처리 중... [8159/8175] 20251028_10월 KR-04호 다우데이타 P2425D _ 7EA 외 발주의 건_26397080.html
# 처리 중... [8160/8175] 20251028_2025년 10월 28일 윤영현 휴가 신청합니다. - 0.5일_26392919.html
# 처리 중... [8161/8175] 20251028_반차 사용신청(10_31, 오후)_26394835.html
# 처리 중... [8162/8175] 20251028_본사 출장비 신청의 건_26394912.html
# 처리 중... [8163/8175] 20251028_숙소 공과금 납부의 건._26395343.html
# 처리 중... [8164/8175] 20251028_휴가 사용 신청의 건_26394789.html
# 처리 중... [8165/8175] 20251029_개발자 교육용 서적 구매 신청 _ 이것이 Spring AI다 (한빛미디어 출판, 신용권 지음) 4권_26405557.html
# 처리 중... [8166/8175] 20251029_연차 휴가 품의_26402005.html
# 처리 중... [8167/8175] 20251030_(LG전자) 프로젝트팀 회식비 품의_26418339.html
# 처리 중... [8168/8175] 20251030_10월 교통비_26412980.html
# 처리 중... [8169/8175] 20251030_10월 기타 경비 신청합니다_26412997.html
# 처리 중... [8170/8175] 20251030_2025-10-30 임민규 휴가 신청서 올립니다._26415193.html
# 처리 중... [8171/8175] 20251030_2025.10.31(금) 연차휴가 신청의 건_26412538.html
# 처리 중... [8172/8175] 20251030_김상욱 에트리 출장비 지급 신청서_10월_26413296.html
# 처리 중... [8173/8175] 20251030_연차 사용_26415581.html
# 처리 중... [8174/8175] 20251031_2025-10-31 김지연 휴가 신청합니다 - 오후반차_26418857.html
# 처리 중... [8175/8175] 20251031_휴가 사용 신청_26418663.html
# JSON 파일 저장 완료: two_htmltojsondb_convert.json
#
# ==================================================
#
# === DB 연결 시작 ===
# Host: localhost, Database: 2021010120251031
# ✓ DB 연결 성공
#
# === 테이블 생성 시작 ===
# ✓ 테이블 생성/확인 완료
# ✓ 기존 데이터: 0건
#
# === 데이터 삽입 시작 (8175건) ===
#   진행: 100/8175 (성공: 100, 실패: 0)
#   진행: 200/8175 (성공: 200, 실패: 0)
#   진행: 300/8175 (성공: 300, 실패: 0)
#   진행: 400/8175 (성공: 400, 실패: 0)
#   진행: 500/8175 (성공: 500, 실패: 0)
#   진행: 600/8175 (성공: 600, 실패: 0)
#   진행: 700/8175 (성공: 700, 실패: 0)
#   진행: 800/8175 (성공: 800, 실패: 0)
#   진행: 900/8175 (성공: 900, 실패: 0)
#   진행: 1000/8175 (성공: 1000, 실패: 0)
#   진행: 1100/8175 (성공: 1100, 실패: 0)
#   진행: 1200/8175 (성공: 1200, 실패: 0)
#   진행: 1300/8175 (성공: 1300, 실패: 0)
#   진행: 1400/8175 (성공: 1400, 실패: 0)
#   진행: 1500/8175 (성공: 1500, 실패: 0)
#   진행: 1600/8175 (성공: 1600, 실패: 0)
#   진행: 1700/8175 (성공: 1700, 실패: 0)
#   진행: 1800/8175 (성공: 1800, 실패: 0)
#   진행: 1900/8175 (성공: 1900, 실패: 0)
#   진행: 2000/8175 (성공: 2000, 실패: 0)
#   진행: 2100/8175 (성공: 2100, 실패: 0)
#   진행: 2200/8175 (성공: 2200, 실패: 0)
#   진행: 2300/8175 (성공: 2300, 실패: 0)
#   진행: 2400/8175 (성공: 2400, 실패: 0)
#   진행: 2500/8175 (성공: 2500, 실패: 0)
#   진행: 2600/8175 (성공: 2600, 실패: 0)
#   진행: 2700/8175 (성공: 2700, 실패: 0)
#   진행: 2800/8175 (성공: 2800, 실패: 0)
#   진행: 2900/8175 (성공: 2900, 실패: 0)
#   진행: 3000/8175 (성공: 3000, 실패: 0)
#   진행: 3100/8175 (성공: 3100, 실패: 0)
#   진행: 3200/8175 (성공: 3200, 실패: 0)
#   진행: 3300/8175 (성공: 3300, 실패: 0)
#   진행: 3400/8175 (성공: 3400, 실패: 0)
#   진행: 3500/8175 (성공: 3500, 실패: 0)
#   진행: 3600/8175 (성공: 3600, 실패: 0)
#   진행: 3700/8175 (성공: 3700, 실패: 0)
#   진행: 3800/8175 (성공: 3800, 실패: 0)
#   진행: 3900/8175 (성공: 3900, 실패: 0)
#   진행: 4000/8175 (성공: 4000, 실패: 0)
#   진행: 4100/8175 (성공: 4100, 실패: 0)
#   진행: 4200/8175 (성공: 4200, 실패: 0)
#   진행: 4300/8175 (성공: 4300, 실패: 0)
#   진행: 4400/8175 (성공: 4400, 실패: 0)
#   진행: 4500/8175 (성공: 4500, 실패: 0)
#   진행: 4600/8175 (성공: 4600, 실패: 0)
#   진행: 4700/8175 (성공: 4700, 실패: 0)
#   진행: 4800/8175 (성공: 4800, 실패: 0)
#   진행: 4900/8175 (성공: 4900, 실패: 0)
#   진행: 5000/8175 (성공: 5000, 실패: 0)
#   진행: 5100/8175 (성공: 5100, 실패: 0)
#   진행: 5200/8175 (성공: 5200, 실패: 0)
#   진행: 5300/8175 (성공: 5300, 실패: 0)
#   진행: 5400/8175 (성공: 5400, 실패: 0)
#   진행: 5500/8175 (성공: 5500, 실패: 0)
#   진행: 5600/8175 (성공: 5600, 실패: 0)
#   진행: 5700/8175 (성공: 5700, 실패: 0)
#   진행: 5800/8175 (성공: 5800, 실패: 0)
#   진행: 5900/8175 (성공: 5900, 실패: 0)
#   진행: 6000/8175 (성공: 6000, 실패: 0)
#   진행: 6100/8175 (성공: 6100, 실패: 0)
#   진행: 6200/8175 (성공: 6200, 실패: 0)
#   진행: 6300/8175 (성공: 6300, 실패: 0)
#   진행: 6400/8175 (성공: 6400, 실패: 0)
#   진행: 6500/8175 (성공: 6500, 실패: 0)
#   진행: 6600/8175 (성공: 6600, 실패: 0)
#   진행: 6700/8175 (성공: 6700, 실패: 0)
#   진행: 6800/8175 (성공: 6800, 실패: 0)
#   진행: 6900/8175 (성공: 6900, 실패: 0)
#   진행: 7000/8175 (성공: 7000, 실패: 0)
#   진행: 7100/8175 (성공: 7100, 실패: 0)
#   진행: 7200/8175 (성공: 7200, 실패: 0)
#   진행: 7300/8175 (성공: 7300, 실패: 0)
#   진행: 7400/8175 (성공: 7400, 실패: 0)
#   진행: 7500/8175 (성공: 7500, 실패: 0)
#   진행: 7600/8175 (성공: 7600, 실패: 0)
#   진행: 7700/8175 (성공: 7700, 실패: 0)
#   진행: 7800/8175 (성공: 7800, 실패: 0)
#   진행: 7900/8175 (성공: 7900, 실패: 0)
#   진행: 8000/8175 (성공: 8000, 실패: 0)
#   진행: 8100/8175 (성공: 8100, 실패: 0)
#   진행: 8175/8175 (성공: 8175, 실패: 0)
#
# === 커밋 시작 ===
# ✓ 커밋 완료
#
# === 결과 요약 ===
# ✓ 성공: 8175건
# ✗ 실패: 0건
#
# ✓ 최종 데이터: 8175건 (이번 실행으로 8175건 추가)
#
# ✓ DB 연결 종료
# ==================================================
#
# 완료! 총 8175건 처리됨
