# %%
import re
import json

# 파일 경로 설정
input_file = 'documents_2015_fixed.cmds'  # 원본 파일명으로 변경하세요
output_file = 'documents_2015_fixed_fixed.cmds'  # 결과 파일명
log_file = 'removed_sourceIds.txt'  # sourceId 기록 파일

# img 태그 패턴
img_pattern = r'<img[^>]+http://office\.anyfive\.com/[^>]+>'

# 결과 저장 (딕셔너리로 변경: sourceId -> img 개수)
removed_source_ids = {}
total_lines = 0
modified_lines = 0
total_img_count = 0

print("처리 시작...")

with open(input_file, 'r', encoding='utf-8') as infile, \
     open(output_file, 'w', encoding='utf-8') as outfile:
    
    for line_num, line in enumerate(infile, 1):
        total_lines += 1
        
        # addDocument로 시작하는지 확인
        if line.strip().startswith('addDocument'):
            # 해당 줄에서 모든 img 태그 찾기
            img_tags = re.findall(img_pattern, line)
            img_count = len(img_tags)
            
            if img_count > 0:
                # sourceId 추출
                source_id_match = re.search(r'"sourceId"\s*:\s*"([^"]+)"', line)
                if source_id_match:
                    source_id = source_id_match.group(1)
                    removed_source_ids[source_id] = img_count
                    total_img_count += img_count
                    print(f"라인 {line_num}: sourceId {source_id}에서 img 태그 {img_count}개 제거")
                
                # img 태그 제거
                modified_line = re.sub(img_pattern, '', line)
                outfile.write(modified_line)
                modified_lines += 1
            else:
                # img 태그가 없으면 그대로 출력
                outfile.write(line)
        else:
            # addDocument가 아닌 줄은 그대로 출력
            outfile.write(line)

# sourceId 목록 저장
with open(log_file, 'w', encoding='utf-8') as logfile:
    logfile.write(f"총 제거된 img 태그 개수: {total_img_count}개\n")
    logfile.write(f"img 태그가 있던 문서 수: {len(removed_source_ids)}개\n")
    logfile.write("=" * 50 + "\n\n")
    
    for source_id, count in removed_source_ids.items():
        logfile.write(f"{source_id}: {count}개\n")

# 결과 출력
print("\n" + "=" * 50)
print(f"처리 완료!")
print(f"전체 라인 수: {total_lines}")
print(f"수정된 라인 수: {modified_lines}")
print(f"img 태그가 있던 문서 수: {len(removed_source_ids)}개")
print(f"총 제거된 img 태그 개수: {total_img_count}개")
print(f"\n결과 파일: {output_file}")
print(f"sourceId 목록: {log_file}")
print("=" * 50)
# Out:
# 처리 시작...
# 라인 8: sourceId 2002915에서 img 태그 1개 제거
# 라인 89: sourceId 2002996에서 img 태그 1개 제거
# 라인 130: sourceId 2003037에서 img 태그 1개 제거
# 라인 271: sourceId 2003178에서 img 태그 2개 제거
# 라인 296: sourceId 2003206에서 img 태그 1개 제거
# 라인 334: sourceId 2003238에서 img 태그 1개 제거
# 라인 376: sourceId 2003284에서 img 태그 1개 제거
# 라인 424: sourceId 2003333에서 img 태그 1개 제거
# 라인 468: sourceId 2003374에서 img 태그 1개 제거
# 라인 993: sourceId 2003899에서 img 태그 1개 제거
# 라인 1079: sourceId 2003985에서 img 태그 1개 제거
# 라인 1123: sourceId 2004033에서 img 태그 1개 제거
# 라인 1173: sourceId 2004081에서 img 태그 1개 제거
# 라인 1336: sourceId 2004242에서 img 태그 1개 제거
# 라인 1432: sourceId 2004339에서 img 태그 1개 제거
# 라인 1523: sourceId 2004431에서 img 태그 1개 제거
# 라인 1946: sourceId 2004850에서 img 태그 1개 제거
# 라인 2306: sourceId 2005217에서 img 태그 1개 제거
# 라인 2320: sourceId 2005230에서 img 태그 1개 제거
# 라인 2451: sourceId 2005360에서 img 태그 1개 제거
# 라인 2557: sourceId 2005467에서 img 태그 1개 제거
# 라인 2568: sourceId 2005476에서 img 태그 1개 제거
# 라인 2580: sourceId 2005492에서 img 태그 1개 제거
# 라인 2587: sourceId 2005494에서 img 태그 1개 제거
# 라인 2674: sourceId 2005577에서 img 태그 1개 제거
# 라인 2682: sourceId 2005588에서 img 태그 1개 제거
# 라인 2688: sourceId 2005597에서 img 태그 1개 제거
# 라인 2792: sourceId 2005704에서 img 태그 1개 제거
# 라인 2812: sourceId 2005717에서 img 태그 1개 제거
# 라인 2821: sourceId 2005728에서 img 태그 1개 제거
# 라인 2836: sourceId 2005742에서 img 태그 1개 제거
# 라인 2868: sourceId 2005775에서 img 태그 1개 제거
# 라인 2928: sourceId 2005832에서 img 태그 1개 제거
# 라인 2963: sourceId 2005871에서 img 태그 1개 제거
# 라인 2987: sourceId 2005903에서 img 태그 1개 제거
# 라인 3065: sourceId 2005979에서 img 태그 1개 제거
# 라인 3085: sourceId 2005992에서 img 태그 1개 제거
# 라인 3108: sourceId 2006013에서 img 태그 1개 제거
# 라인 3150: sourceId 2006059에서 img 태그 1개 제거
# 라인 3151: sourceId 2006066에서 img 태그 1개 제거
# 라인 3160: sourceId 2006068에서 img 태그 1개 제거
# 라인 3161: sourceId 2006069에서 img 태그 1개 제거
# 라인 3171: sourceId 2006082에서 img 태그 1개 제거
# 라인 3184: sourceId 2006089에서 img 태그 1개 제거
# 라인 3196: sourceId 2006099에서 img 태그 1개 제거
# 라인 3198: sourceId 2006107에서 img 태그 1개 제거
# 라인 3247: sourceId 2006152에서 img 태그 1개 제거
# 라인 3270: sourceId 2006181에서 img 태그 1개 제거
# 라인 3286: sourceId 2006199에서 img 태그 1개 제거
# 라인 3299: sourceId 2006206에서 img 태그 1개 제거
# 라인 3328: sourceId 2006241에서 img 태그 1개 제거
# 라인 3331: sourceId 2006239에서 img 태그 1개 제거
# 라인 3357: sourceId 2006266에서 img 태그 1개 제거
# 라인 3361: sourceId 2006265에서 img 태그 1개 제거
# 라인 3372: sourceId 2006289에서 img 태그 1개 제거
# 라인 3374: sourceId 2006288에서 img 태그 1개 제거
# 라인 3375: sourceId 2006290에서 img 태그 1개 제거
# 라인 3387: sourceId 2006295에서 img 태그 1개 제거
# 라인 3391: sourceId 2006298에서 img 태그 1개 제거
# 라인 3402: sourceId 2006311에서 img 태그 1개 제거
# 라인 3409: sourceId 2006316에서 img 태그 1개 제거
# 라인 3410: sourceId 2006326에서 img 태그 1개 제거
# 라인 3412: sourceId 2006336에서 img 태그 1개 제거
# 라인 3433: sourceId 2006337에서 img 태그 1개 제거
# 라인 3439: sourceId 2006349에서 img 태그 1개 제거
# 라인 3442: sourceId 2006354에서 img 태그 1개 제거
# 라인 3524: sourceId 2006430에서 img 태그 1개 제거
# 라인 3546: sourceId 2006452에서 img 태그 1개 제거
# 라인 3558: sourceId 2006470에서 img 태그 1개 제거
# 라인 3564: sourceId 2006471에서 img 태그 1개 제거
# 라인 3577: sourceId 2006484에서 img 태그 1개 제거
# 라인 3578: sourceId 2006489에서 img 태그 1개 제거
# 라인 3608: sourceId 2006520에서 img 태그 3개 제거
# 라인 3689: sourceId 2006601에서 img 태그 1개 제거
# 라인 3697: sourceId 2006603에서 img 태그 1개 제거
# 라인 3703: sourceId 2006612에서 img 태그 1개 제거
# 라인 3715: sourceId 2006614에서 img 태그 1개 제거
# 라인 3725: sourceId 2006633에서 img 태그 1개 제거
# 라인 3758: sourceId 2006666에서 img 태그 1개 제거
# 라인 3829: sourceId 2006747에서 img 태그 1개 제거
# 라인 3830: sourceId 2006736에서 img 태그 1개 제거
# 라인 3836: sourceId 2006735에서 img 태그 1개 제거
# 라인 3942: sourceId 2006852에서 img 태그 1개 제거
# 라인 3950: sourceId 2006862에서 img 태그 1개 제거
# 라인 4064: sourceId 2006977에서 img 태그 1개 제거
# 라인 4083: sourceId 2006991에서 img 태그 1개 제거
# 라인 4095: sourceId 2007001에서 img 태그 1개 제거
# 라인 4194: sourceId 2007107에서 img 태그 1개 제거
# 라인 4196: sourceId 2007110에서 img 태그 1개 제거
# 라인 4319: sourceId 2007239에서 img 태그 1개 제거
# 라인 4320: sourceId 2007234에서 img 태그 1개 제거
# 라인 4474: sourceId 2007383에서 img 태그 1개 제거
# 라인 4475: sourceId 2007384에서 img 태그 1개 제거
# 라인 4611: sourceId 2007518에서 img 태그 1개 제거
# 라인 4626: sourceId 2007535에서 img 태그 1개 제거
# 라인 4668: sourceId 2007577에서 img 태그 1개 제거
# 라인 4757: sourceId 2007659에서 img 태그 1개 제거
# 라인 4760: sourceId 2007667에서 img 태그 1개 제거
# 라인 4770: sourceId 2007685에서 img 태그 1개 제거
# 라인 4853: sourceId 2007762에서 img 태그 1개 제거
# 라인 4862: sourceId 2007773에서 img 태그 1개 제거
# 라인 4863: sourceId 2007771에서 img 태그 1개 제거
# 라인 4901: sourceId 2007808에서 img 태그 1개 제거
# 라인 4991: sourceId 2007903에서 img 태그 1개 제거
# 라인 4993: sourceId 2007904에서 img 태그 1개 제거
# 라인 5003: sourceId 2007909에서 img 태그 1개 제거
# 라인 5069: sourceId 2007976에서 img 태그 1개 제거
# 라인 5071: sourceId 2007983에서 img 태그 1개 제거
# 라인 5100: sourceId 2008008에서 img 태그 1개 제거
# 라인 5111: sourceId 2008021에서 img 태그 1개 제거
# 라인 5124: sourceId 2008038에서 img 태그 1개 제거
# 라인 5146: sourceId 2008054에서 img 태그 1개 제거
# 라인 5156: sourceId 2008063에서 img 태그 1개 제거
# 라인 5190: sourceId 2008095에서 img 태그 1개 제거
# 라인 5193: sourceId 2008103에서 img 태그 1개 제거
# 라인 5223: sourceId 2008132에서 img 태그 1개 제거
# 라인 5248: sourceId 2008156에서 img 태그 1개 제거
# 라인 5275: sourceId 2008184에서 img 태그 1개 제거
# 라인 5296: sourceId 2008204에서 img 태그 1개 제거
# 라인 5333: sourceId 2008240에서 img 태그 1개 제거
# 라인 5350: sourceId 2008261에서 img 태그 1개 제거
# 라인 5355: sourceId 2008264에서 img 태그 1개 제거
# 라인 5386: sourceId 2008293에서 img 태그 1개 제거
# 라인 5387: sourceId 2008295에서 img 태그 1개 제거
# 라인 5411: sourceId 2008327에서 img 태그 1개 제거
# 라인 5412: sourceId 2008322에서 img 태그 1개 제거
# 라인 5414: sourceId 2008326에서 img 태그 1개 제거
# 라인 5420: sourceId 2008337에서 img 태그 1개 제거
# 라인 5428: sourceId 2008332에서 img 태그 1개 제거
# 라인 5430: sourceId 2008334에서 img 태그 1개 제거
# 라인 5466: sourceId 2008379에서 img 태그 1개 제거
# 라인 5467: sourceId 2008380에서 img 태그 1개 제거
# 라인 5482: sourceId 2008388에서 img 태그 1개 제거
# 라인 5518: sourceId 2008427에서 img 태그 1개 제거
# 라인 5520: sourceId 2008431에서 img 태그 1개 제거
# 라인 5558: sourceId 2008473에서 img 태그 1개 제거
# 라인 5561: sourceId 2008475에서 img 태그 1개 제거
# 라인 5599: sourceId 2008509에서 img 태그 1개 제거
# 라인 5619: sourceId 2008531에서 img 태그 1개 제거
# 라인 5626: sourceId 2008536에서 img 태그 1개 제거
# 라인 5632: sourceId 2008551에서 img 태그 1개 제거
# 라인 5644: sourceId 2008559에서 img 태그 1개 제거
# 라인 5667: sourceId 2008575에서 img 태그 2개 제거
# 라인 5681: sourceId 2008596에서 img 태그 1개 제거
# 라인 5702: sourceId 2008613에서 img 태그 1개 제거
# 라인 5712: sourceId 2008621에서 img 태그 1개 제거
# 라인 5756: sourceId 2008670에서 img 태그 1개 제거
# 라인 5763: sourceId 2008676에서 img 태그 1개 제거
# 라인 5769: sourceId 2008683에서 img 태그 1개 제거
# 라인 5770: sourceId 2008684에서 img 태그 1개 제거
# 라인 5777: sourceId 2008688에서 img 태그 1개 제거
# 라인 5808: sourceId 2008719에서 img 태그 1개 제거
# 라인 5854: sourceId 2008764에서 img 태그 1개 제거
# 라인 5874: sourceId 2008783에서 img 태그 1개 제거
# 라인 5899: sourceId 2008808에서 img 태그 1개 제거
# 라인 5942: sourceId 2008852에서 img 태그 1개 제거
# 라인 5977: sourceId 2008886에서 img 태그 1개 제거
# 라인 5985: sourceId 2008901에서 img 태그 1개 제거
# 라인 5987: sourceId 2008896에서 img 태그 1개 제거
# 라인 6073: sourceId 2008981에서 img 태그 1개 제거
# 라인 6096: sourceId 2009003에서 img 태그 1개 제거
# 라인 6101: sourceId 2009011에서 img 태그 1개 제거
# 라인 6121: sourceId 2009034에서 img 태그 1개 제거
# 라인 6123: sourceId 2009031에서 img 태그 1개 제거
# 라인 6139: sourceId 2009048에서 img 태그 1개 제거
# 라인 6140: sourceId 2009052에서 img 태그 1개 제거
# 라인 6163: sourceId 2009071에서 img 태그 1개 제거
# 라인 6195: sourceId 2009106에서 img 태그 1개 제거
# 라인 6198: sourceId 2009112에서 img 태그 1개 제거
# 라인 6213: sourceId 2009124에서 img 태그 1개 제거
# 라인 6224: sourceId 2009133에서 img 태그 1개 제거
# 라인 6247: sourceId 2009154에서 img 태그 2개 제거
# 라인 6253: sourceId 2009162에서 img 태그 1개 제거
# 라인 6269: sourceId 2009182에서 img 태그 3개 제거
# 라인 6282: sourceId 2009193에서 img 태그 1개 제거
# 라인 6312: sourceId 2009220에서 img 태그 1개 제거
# 라인 6321: sourceId 2009234에서 img 태그 1개 제거
# 라인 6328: sourceId 2009240에서 img 태그 1개 제거
# 라인 6330: sourceId 2009241에서 img 태그 1개 제거
# 라인 6382: sourceId 2009298에서 img 태그 1개 제거
# 라인 6424: sourceId 2009335에서 img 태그 1개 제거
# 라인 6428: sourceId 2009339에서 img 태그 1개 제거
# 라인 6435: sourceId 2009347에서 img 태그 1개 제거
# 라인 6437: sourceId 2009350에서 img 태그 1개 제거
# 라인 6496: sourceId 2009411에서 img 태그 1개 제거
# 라인 6551: sourceId 2009460에서 img 태그 1개 제거
# 라인 6579: sourceId 2009488에서 img 태그 1개 제거
# 라인 6580: sourceId 2009489에서 img 태그 1개 제거
# 라인 6581: sourceId 2009492에서 img 태그 1개 제거
#
# ==================================================
# 처리 완료!
# 전체 라인 수: 6587
# 수정된 라인 수: 189
# img 태그가 있던 문서 수: 189개
# 총 제거된 img 태그 개수: 196개
#
# 결과 파일: documents_2015_fixed_fixed.cmds
# sourceId 목록: removed_sourceIds.txt
# ==================================================
