# %%
#이름만으로 매칭
#AGREEMENT도 처리하게 수정

# cmds 파일 업데이트 전용 스크립트 (AGREEMENT 처리 버전)
import json
import re
from pathlib import Path

# ─────────────────────────────────────────────────────────
# 설정
# ─────────────────────────────────────────────────────────
CRAWL_RESULT_JSON = "crawl_result_temp.json"
CMDS_INPUT = r"C:\Users\LEEJUHWAN\Desktop\애니파이브\전자결재\2015\documents_2015_02.cmds"
CMDS_OUTPUT = "documents_2015_actTimefixed.cmds"

# ─────────────────────────────────────────────────────────
# 유틸 함수
# ─────────────────────────────────────────────────────────
def extract_doc_number(source_id):
    """sourceId에서 문서 번호만 추출"""
    numbers = re.findall(r'\d+', source_id)
    if not numbers:
        return source_id
    return max(numbers, key=len)

def normalize_action_type(action_type):
    """AGREEMENT를 APPROVAL로 정규화"""
    if action_type == "AGREEMENT":
        return "APPROVAL"
    return action_type

# ─────────────────────────────────────────────────────────
# 1) 데이터 로드
# ─────────────────────────────────────────────────────────
print("="*70)
print("📝 cmds 파일 업데이트 시작")
print("="*70)

try:
    with open(CRAWL_RESULT_JSON, 'r', encoding='utf-8') as f:
        crawl_results = json.load(f)
    print(f"✅ {CRAWL_RESULT_JSON} 로드: {len(crawl_results)}개 문서")
except Exception as e:
    print(f"❌ {CRAWL_RESULT_JSON} 읽기 실패: {e}")
    exit(1)

if not Path(CMDS_INPUT).exists():
    print(f"❌ {CMDS_INPUT} 파일이 없습니다!")
    exit(1)

print(f"✅ {CMDS_INPUT} 파일 확인\n")

# ─────────────────────────────────────────────────────────
# 2) cmds 파일 업데이트
# ─────────────────────────────────────────────────────────
print("="*70)
print("🔄 업데이트 처리 중...")
print("="*70)

updated_count = 0
total_lines = 0
matched_docs = 0

with open(CMDS_INPUT, 'r', encoding='utf-8') as f_in, \
     open(CMDS_OUTPUT, 'w', encoding='utf-8') as f_out:
    
    for line in f_in:
        total_lines += 1
        line = line.strip()
        
        if not line.startswith("addDocument "):
            f_out.write(line + '\n')
            continue
        
        # JSON 파싱
        try:
            json_str = line[12:]
            doc = json.loads(json_str)
            source_id_raw = doc.get("sourceId")
            
            # 숫자만 추출 (매칭용)
            source_id_num = extract_doc_number(source_id_raw)
            
            # 크롤링 결과에 있는지 확인
            if source_id_num not in crawl_results:
                f_out.write(line + '\n')
                continue
            
            # 매치됨!
            matched_docs += 1
            
            # activities 업데이트
            crawled = crawl_results[source_id_num]
            activities = doc.get("activities", [])
            
            # 각 activity에 대해 크롤링 결과 매칭
            for activity in activities:
                activity_name = activity.get("name", "")
                activity_type = activity.get("type", "")
                
                # 📌 타입 정규화: AGREEMENT → APPROVAL
                normalized_type = normalize_action_type(activity_type)
                
                # 이름과 정규화된 타입으로 매칭
                for crawled_item in crawled:
                    if (crawled_item["name"] in activity_name and
                        crawled_item["action_type"] == normalized_type):
                        
                        # actionDate 업데이트
                        old_date = activity.get("actionDate")
                        new_date = crawled_item["timestamp"]
                        
                        # 실제로 변경된 경우만
                        if old_date != new_date:
                            activity["actionDate"] = new_date
                            print(f"  ✅ {source_id_raw} - {activity_name}[{activity_type}]: {old_date} → {new_date}")
                            updated_count += 1
                        
                        break  # 매칭되면 다음 activity로
            
            # 원본 sourceId는 그대로 유지
            updated_line = "addDocument " + json.dumps(doc, ensure_ascii=False, separators=(',', ':'))
            f_out.write(updated_line + '\n')
            
        except Exception as e:
            print(f"  ⚠️ 파싱 에러 (line {total_lines}): {e}")
            f_out.write(line + '\n')

print("\n" + "="*70)
print("🎉 업데이트 완료!")
print("="*70)
print(f"📊 처리 결과:")
print(f"  - 전체 문서: {total_lines}개")
print(f"  - sourceId 매치: {matched_docs}개")
print(f"  - 업데이트: {updated_count}개 결재선")
print(f"  - 출력 파일: {CMDS_OUTPUT}")
print("="*70)
# Out:
# ======================================================================
# 📝 cmds 파일 업데이트 시작
# ======================================================================
# ✅ crawl_result_temp.json 로드: 4118개 문서
# ✅ C:\Users\LEEJUHWAN\Desktop\애니파이브\전자결재\2015\documents_2015_02.cmds 파일 확인
#
# ======================================================================
# 🔄 업데이트 처리 중...
# ======================================================================
#   ✅ doc_2002908_02 - 김하응[DRAFT]: 1293894000000 → 1293958171000
#   ✅ doc_2002908_02 - 최기원[APPROVAL]: 1293980400000 → 1294020876000
#   ✅ doc_2002908_02 - 김성수[AGREEMENT]: 1293980400000 → 1294017074000
#   ✅ doc_2002909_02 - 김태정[DRAFT]: 1293980400000 → 1294033356000
#   ✅ doc_2002909_02 - 최기원[APPROVAL]: 1293980400000 → 1294053503000
#   ✅ doc_2002909_02 - CEO[APPROVAL]: 1294066800000 → 1294097631000
#   ✅ doc_2002911_02 - 최기원[DRAFT]: 1293980400000 → 1294038991000
#   ✅ doc_2002911_02 - CEO[APPROVAL]: 1294153200000 → 1294206126000
#   ✅ doc_2002912_02 - 배현찬[DRAFT]: 1293980400000 → 1294044266000
#   ✅ doc_2002912_02 - 최기원[APPROVAL]: 1293980400000 → 1294053709000
#   ✅ doc_2002912_02 - CEO[APPROVAL]: 1294066800000 → 1294097558000
#   ✅ doc_2002912_02 - 김성수[AGREEMENT]: 1293980400000 → 1294046036000
#   ✅ doc_2002917_02 - 이종수[DRAFT]: 1294066800000 → 1294135435000
#   ✅ doc_2002917_02 - 김화연[APPROVAL]: 1294066800000 → 1294138094000
#   ✅ doc_2002915_02 - 김동력[DRAFT]: 1294066800000 → 1294115392000
#   ✅ doc_2002915_02 - 최기원[APPROVAL]: 1294066800000 → 1294115768000
#   ✅ doc_2002915_02 - CEO[APPROVAL]: 1294066800000 → 1294118515000
#   ✅ doc_2002919_02 - 최기원[DRAFT]: 1294153200000 → 1294213425000
#   ✅ doc_2002919_02 - CEO[APPROVAL]: 1294153200000 → 1294213781000
#   ✅ doc_2002924_02 - 박정균[DRAFT]: 1294239600000 → 1294300231000
#   ✅ doc_2002924_02 - 최기원[APPROVAL]: 1294326000000 → 1294362891000
#   ✅ doc_2002921_02 - 송명근[DRAFT]: 1294239600000 → 1294273484000
#   ✅ doc_2002921_02 - 최성민[APPROVAL]: 1294239600000 → 1294274308000
#   ✅ doc_2002921_02 - 박정균[APPROVAL]: 1294239600000 → 1294299769000
#   ✅ doc_2002921_02 - 최기원[APPROVAL]: 1294326000000 → 1294363084000
#   ✅ doc_2002926_02 - 김동력[DRAFT]: 1294585200000 → 1294645090000
#   ✅ doc_2002926_02 - 최기원[APPROVAL]: 1294671600000 → 1294704970000
#   ✅ doc_2002926_02 - CEO[APPROVAL]: 1294671600000 → 1294724598000
#   ✅ doc_2002933_02 - 최기원[DRAFT]: 1294671600000 → 1294717790000
#   ✅ doc_2002933_02 - CEO[APPROVAL]: 1294671600000 → 1294723450000
#   ✅ doc_2002935_02 - 김동력[DRAFT]: 1294671600000 → 1294737760000
#   ✅ doc_2002935_02 - 최기원[APPROVAL]: 1294671600000 → 1294741832000
#   ✅ doc_2002935_02 - CEO[APPROVAL]: 1294758000000 → 1294786026000
#   ⚠️ 파싱 에러 (line 25): Expecting ',' delimiter: line 1 column 9903 (char 9902)
#   ✅ doc_2002937_02 - 김동력[DRAFT]: 1294671600000 → 1294739689000
#   ✅ doc_2002937_02 - 최기원[APPROVAL]: 1294671600000 → 1294741913000
#   ✅ doc_2002937_02 - CEO[APPROVAL]: 1294758000000 → 1294785992000
#   ✅ doc_2002930_02 - 최기원[DRAFT]: 1294671600000 → 1294703518000
#   ✅ doc_2002930_02 - CEO[APPROVAL]: 1294671600000 → 1294723598000
#   ✅ doc_2002938_02 - 김기동[DRAFT]: 1294671600000 → 1294742331000
#   ✅ doc_2002938_02 - 김태정[APPROVAL]: 1294671600000 → 1294742743000
#   ✅ doc_2002938_02 - 김동력[AGREEMENT]: 1294758000000 → 1294788890000
#   ✅ doc_2002938_02 - 최기원[AGREEMENT]: 1294758000000 → 1294789142000
#   ✅ doc_2002934_02 - 이종수[DRAFT]: 1294671600000 → 1294722097000
#   ✅ doc_2002934_02 - 김태정[APPROVAL]: 1294671600000 → 1294731031000
#   ✅ doc_2002934_02 - 김동력[AGREEMENT]: 1294758000000 → 1294788901000
#   ✅ doc_2002934_02 - 최기원[AGREEMENT]: 1294671600000 → 1294741817000
#   ✅ doc_2002939_02 - 안민찬[DRAFT]: 1294758000000 → 1294826693000
#   ✅ doc_2002939_02 - 김태정[APPROVAL]: 1294758000000 → 1294828934000
#   ✅ doc_2002939_02 - 김동력[AGREEMENT]: 1294844400000 → 1294876560000
#   ✅ doc_2002939_02 - 최기원[AGREEMENT]: 1294758000000 → 1294831863000
#   ✅ doc_2002940_02 - 양기훈[DRAFT]: 1294844400000 → 1294907429000
#   ✅ doc_2002940_02 - 김성수[APPROVAL]: 1294930800000 → 1294963886000
#   ✅ doc_2002940_02 - 김동력[AGREEMENT]: 1294930800000 → 1294964169000
#   ✅ doc_2002940_02 - 최기원[AGREEMENT]: 1294930800000 → 1294972042000
#   ✅ doc_2002942_02 - 이종수[DRAFT]: 1294930800000 → 1294964040000
#   ✅ doc_2002942_02 - 김태정[APPROVAL]: 1294930800000 → 1294965898000
#   ✅ doc_2002942_02 - 최기원[AGREEMENT]: 1294930800000 → 1294972077000
#   ✅ doc_2002943_02 - 김동력[DRAFT]: 1294930800000 → 1294968636000
#   ✅ doc_2002943_02 - 최기원[APPROVAL]: 1295190000000 → 1295239375000
#   ✅ doc_2002943_02 - CEO[APPROVAL]: 1295190000000 → 1295240891000
#   ✅ doc_2002943_02 - 박정균[AGREEMENT]: 1295190000000 → 1295237181000
#   ✅ doc_2002946_02 - 박정균[DRAFT]: 1295190000000 → 1295261527000
#   ✅ doc_2002946_02 - 최기원[AGREEMENT]: 1295276400000 → 1295307464000
#   ✅ doc_2002944_02 - 편영수[DRAFT]: 1295190000000 → 1295227067000
#   ✅ doc_2002944_02 - CEO[APPROVAL]: 1295190000000 → 1295228901000
#   ✅ doc_2002947_02 - 이형균[DRAFT]: 1295190000000 → 1295263439000
#   ✅ doc_2002947_02 - 김태정[APPROVAL]: 1295276400000 → 1295292289000
#   ✅ doc_2002947_02 - 최기원[AGREEMENT]: 1295276400000 → 1295307623000
#   ✅ doc_2002945_02 - 김규일[DRAFT]: 1295190000000 → 1295261014000
#   ✅ doc_2002945_02 - 박정균[APPROVAL]: 1295190000000 → 1295261989000
#   ✅ doc_2002945_02 - 최기원[AGREEMENT]: 1295276400000 → 1295307414000
#   ✅ doc_2002950_02 - 최성민[DRAFT]: 1295276400000 → 1295330498000
#   ✅ doc_2002950_02 - 김태정[APPROVAL]: 1295362800000 → 1295400741000
#   ✅ doc_2002950_02 - CEO[APPROVAL]: 1295362800000 → 1295424666000
#   ✅ doc_2002948_02 - 이민곤[DRAFT]: 1295276400000 → 1295318887000
#   ✅ doc_2002948_02 - 윤상호[APPROVAL]: 1295276400000 → 1295318972000
#   ✅ doc_2002948_02 - 박정균[APPROVAL]: 1295362800000 → 1295397687000
#   ✅ doc_2002948_02 - 최기원[AGREEMENT]: 1295362800000 → 1295401822000
#   ✅ doc_2002949_02 - 이민곤[DRAFT]: 1295276400000 → 1295319136000
#   ✅ doc_2002949_02 - 윤상호[APPROVAL]: 1295276400000 → 1295321610000
#   ✅ doc_2002949_02 - 박정균[APPROVAL]: 1295362800000 → 1295397764000
#   ✅ doc_2002949_02 - 최기원[AGREEMENT]: 1295362800000 → 1295401858000
#   ✅ doc_2002955_02 - 김동력[DRAFT]: 1295362800000 → 1295419094000
#   ✅ doc_2002955_02 - 박정균[APPROVAL]: 1295362800000 → 1295447317000
#   ✅ doc_2002955_02 - 최기원[APPROVAL]: 1295449200000 → 1295486839000
#   ✅ doc_2002955_02 - CEO[APPROVAL]: 1295449200000 → 1295518137000
#   ✅ doc_2002956_02 - 김동력[DRAFT]: 1295362800000 → 1295419310000
#   ✅ doc_2002956_02 - 김태정[APPROVAL]: 1295362800000 → 1295421213000
#   ✅ doc_2002956_02 - 최기원[APPROVAL]: 1295535600000 → 1295566046000
#   ✅ doc_2002956_02 - CEO[APPROVAL]: 1295535600000 → 1295590729000
#   ✅ doc_2002954_02 - 김동력[DRAFT]: 1295362800000 → 1295418786000
#   ✅ doc_2002954_02 - 최기원[APPROVAL]: 1295449200000 → 1295486294000
#   ✅ doc_2002954_02 - CEO[APPROVAL]: 1295449200000 → 1295518152000
#   ✅ doc_2002957_02 - 김동력[DRAFT]: 1295362800000 → 1295419443000
#   ✅ doc_2002957_02 - 김성수[APPROVAL]: 1295449200000 → 1295482298000
#   ✅ doc_2002957_02 - 최기원[APPROVAL]: 1295449200000 → 1295486971000
#   ✅ doc_2002957_02 - CEO[APPROVAL]: 1295449200000 → 1295518095000
#   ✅ doc_2002959_02 - 박정균[DRAFT]: 1295362800000 → 1295447637000
#   ✅ doc_2002959_02 - 최기원[APPROVAL]: 1295449200000 → 1295487036000
#   ✅ doc_2002958_02 - 김동력[DRAFT]: 1295362800000 → 1295427891000
#   ✅ doc_2002958_02 - 김태정[APPROVAL]: 1295449200000 → 1295489786000
#   ✅ doc_2002958_02 - 최기원[APPROVAL]: 1295535600000 → 1295566011000
#   ✅ doc_2002958_02 - CEO[APPROVAL]: 1295535600000 → 1295590752000
#   ✅ doc_2002953_02 - 김성수[DRAFT]: 1295362800000 → 1295399226000
#   ✅ doc_2002953_02 - 최기원[APPROVAL]: 1295362800000 → 1295401887000
#   ✅ doc_2002960_02 - 최기원[DRAFT]: 1295449200000 → 1295484904000
#   ✅ doc_2002960_02 - CEO[APPROVAL]: 1295449200000 → 1295514188000
#   ✅ doc_2002961_02 - 김동력[DRAFT]: 1295449200000 → 1295511060000
#   ✅ doc_2002961_02 - 최기원[APPROVAL]: 1295535600000 → 1295566078000
#   ✅ doc_2002961_02 - CEO[APPROVAL]: 1295535600000 → 1295590702000
#   ✅ doc_2002966_02 - 정주연[DRAFT]: 1295881200000 → 1295947600000
#   ✅ doc_2002966_02 - 최기원[APPROVAL]: 1295881200000 → 1295951672000
#   ✅ doc_2002966_02 - CEO[APPROVAL]: 1295881200000 → 1295951981000
#   ✅ doc_2002964_02 - 김동력[DRAFT]: 1295881200000 → 1295943561000
#   ✅ doc_2002964_02 - 최기원[APPROVAL]: 1295881200000 → 1295951692000
#   ✅ doc_2002964_02 - CEO[APPROVAL]: 1295881200000 → 1295952016000
#   ✅ doc_2002967_02 - 윤상호[DRAFT]: 1296054000000 → 1296088653000
#   ✅ doc_2002967_02 - 박정균[APPROVAL]: 1296054000000 → 1296094879000
#   ✅ doc_2002967_02 - CEO[APPROVAL]: 1296140400000 → 1296178468000
#   ✅ doc_2002967_02 - 최기원[AGREEMENT]: 1296054000000 → 1296101899000
#   ✅ doc_2002970_02 - 이형균[DRAFT]: 1296054000000 → 1296107730000
#   ✅ doc_2002970_02 - 김태정[APPROVAL]: 1296054000000 → 1296121811000
#   ✅ doc_2002976_02 - 최기원[DRAFT]: 1296140400000 → 1296207942000
#   ✅ doc_2002976_02 - CEO[APPROVAL]: 1296313200000 → 1296376545000
#   ✅ doc_2002975_02 - 편영수[DRAFT]: 1296140400000 → 1296188469000
#   ✅ doc_2002975_02 - CEO[APPROVAL]: 1296313200000 → 1296376508000
#   ✅ doc_2002975_02 - 최기원[AGREEMENT]: 1296140400000 → 1296194787000
#   ✅ doc_2002974_02 - 김동력[DRAFT]: 1296140400000 → 1296177168000
#   ✅ doc_2002974_02 - 최기원[APPROVAL]: 1296140400000 → 1296194710000
#   ✅ doc_2002974_02 - CEO[APPROVAL]: 1296313200000 → 1296376493000
#   ✅ doc_2002973_02 - 편영수[DRAFT]: 1296140400000 → 1296176645000
#   ✅ doc_2002973_02 - 최기원[AGREEMENT]: 1296140400000 → 1296194632000
#   ✅ doc_2002978_02 - 김규일[DRAFT]: 1297090800000 → 1297121758000
#   ✅ doc_2002978_02 - 박정균[APPROVAL]: 1297263600000 → 1297318185000
#   ✅ doc_2002978_02 - 최기원[APPROVAL]: 1297350000000 → 1297383054000
#   ✅ doc_2002979_02 - 김기범[DRAFT]: 1296313200000 → 1296360847000
#   ✅ doc_2002979_02 - 박정균[APPROVAL]: 1296399600000 → 1296435285000
#   ✅ doc_2002979_02 - 최기원[AGREEMENT]: 1296399600000 → 1296439070000
#   ✅ doc_2002987_02 - 박정균[DRAFT]: 1296399600000 → 1296455258000
#   ✅ doc_2002987_02 - 최기원[APPROVAL]: 1296399600000 → 1296462743000
#   ✅ doc_2002987_02 - CEO[APPROVAL]: 1296486000000 → 1296532485000
#   ✅ doc_2002988_02 - 박정균[DRAFT]: 1296399600000 → 1296455749000
#   ✅ doc_2002988_02 - 최기원[APPROVAL]: 1296399600000 → 1296462210000
#   ✅ doc_2002989_02 - 박정균[DRAFT]: 1296399600000 → 1296456175000
#   ✅ doc_2002989_02 - 최기원[APPROVAL]: 1296399600000 → 1296462161000
#   ✅ doc_2002986_02 - 김성수[DRAFT]: 1296399600000 → 1296453934000
#   ✅ doc_2002986_02 - CEO[APPROVAL]: 1296486000000 → 1296532499000
#   ✅ doc_2002986_02 - 최기원[AGREEMENT]: 1296399600000 → 1296463235000
#   ✅ doc_2002998_02 - 김동력[DRAFT]: 1297263600000 → 1297331297000
#   ✅ doc_2002998_02 - 최기원[APPROVAL]: 1297350000000 → 1297389781000
#   ✅ doc_2002998_02 - CEO[APPROVAL]: 1297522800000 → 1297565812000
#   ✅ doc_2002999_02 - 김동력[DRAFT]: 1297350000000 → 1297387949000
#   ✅ doc_2002999_02 - 최기원[APPROVAL]: 1297350000000 → 1297389943000
#   ✅ doc_2002999_02 - CEO[APPROVAL]: 1297522800000 → 1297565828000
#   ✅ doc_2003001_02 - 김동력[DRAFT]: 1297695600000 → 1297732016000
#   ✅ doc_2003001_02 - 최기원[APPROVAL]: 1297782000000 → 1297851130000
#   ✅ doc_2003004_02 - 김태정[DRAFT]: 1297782000000 → 1297816988000
#   ✅ doc_2003004_02 - CEO[APPROVAL]: 1297868400000 → 1297901079000
#   ✅ doc_2003004_02 - 최기원[AGREEMENT]: 1297782000000 → 1297847193000
#   ✅ doc_2003004_02 - 정주연[AGREEMENT]: 1297782000000 → 1297836509000
#   ✅ doc_2003006_02 - 김동력[DRAFT]: 1297782000000 → 1297846913000
#   ✅ doc_2003006_02 - 최기원[APPROVAL]: 1297782000000 → 1297847227000
#   ✅ doc_2003006_02 - CEO[APPROVAL]: 1297868400000 → 1297901059000
#   ✅ doc_2003009_02 - 김동력[DRAFT]: 1297868400000 → 1297936847000
#   ✅ doc_2003009_02 - 최기원[APPROVAL]: 1297868400000 → 1297939094000
#   ✅ doc_2003009_02 - CEO[APPROVAL]: 1298386800000 → 1298421366000
#   ✅ doc_2003011_02 - 김성수[DRAFT]: 1297954800000 → 1298015180000
#   ✅ doc_2003011_02 - 정주연[APPROVAL]: 1298386800000 → 1298437613000
#   ✅ doc_2003015_02 - 김동력[DRAFT]: 1298300400000 → 1298352059000
#   ✅ doc_2003015_02 - 최기원[APPROVAL]: 1298386800000 → 1298452449000
#   ✅ doc_2003015_02 - CEO[APPROVAL]: 1298473200000 → 1298502707000
#   ✅ doc_2003015_02 - 박정균[AGREEMENT]: 1298386800000 → 1298418325000
#   ✅ doc_2003015_02 - 편영수[AGREEMENT]: 1298300400000 → 1298352789000
#   ✅ doc_2003019_02 - 김동력[DRAFT]: 1298386800000 → 1298428716000
#   ✅ doc_2003019_02 - 최기원[APPROVAL]: 1298386800000 → 1298452831000
#   ✅ doc_2003019_02 - CEO[APPROVAL]: 1298473200000 → 1298502835000
#   ✅ doc_2003019_02 - 박정균[AGREEMENT]: 1298386800000 → 1298437755000
#   ✅ doc_2003019_02 - 정주연[AGREEMENT]: 1298386800000 → 1298440249000
#   ✅ doc_2003020_02 - 김동력[DRAFT]: 1298386800000 → 1298428850000
#   ✅ doc_2003020_02 - 최기원[APPROVAL]: 1298386800000 → 1298452856000
#   ✅ doc_2003020_02 - CEO[APPROVAL]: 1298473200000 → 1298502781000
#   ✅ doc_2003020_02 - 김태정[AGREEMENT]: 1298386800000 → 1298440323000
#   ✅ doc_2003020_02 - 정주연[AGREEMENT]: 1298386800000 → 1298440508000
#   ✅ doc_2003018_02 - 김동력[DRAFT]: 1298386800000 → 1298428517000
#   ✅ doc_2003018_02 - 최기원[APPROVAL]: 1298386800000 → 1298452794000
#   ✅ doc_2003018_02 - CEO[APPROVAL]: 1298473200000 → 1298502853000
#   ✅ doc_2003018_02 - 정주연[AGREEMENT]: 1298386800000 → 1298437672000
#   ✅ doc_2003021_02 - 김동력[DRAFT]: 1298386800000 → 1298428965000
#   ✅ doc_2003021_02 - 최기원[APPROVAL]: 1298386800000 → 1298452875000
#   ✅ doc_2003021_02 - CEO[APPROVAL]: 1298473200000 → 1298502753000
#   ✅ doc_2003021_02 - 정주연[AGREEMENT]: 1298386800000 → 1298440534000
#   ✅ doc_2003021_02 - 김성수[AGREEMENT]: 1298386800000 → 1298438959000
#   ✅ doc_2003023_02 - 편영수[DRAFT]: 1298386800000 → 1298456030000
#   ✅ doc_2003023_02 - 최기원[APPROVAL]: 1298386800000 → 1298456726000
#   ✅ doc_2003023_02 - CEO[APPROVAL]: 1298473200000 → 1298502731000
#   ✅ doc_2003023_02 - 박정균[AGREEMENT]: 1298386800000 → 1298456658000
#   ✅ doc_2003022_02 - 임기훈[DRAFT]: 1298386800000 → 1298430058000
#   ✅ doc_2003022_02 - 김태정[APPROVAL]: 1298386800000 → 1298440342000
#   ✅ doc_2003022_02 - 김동력[APPROVAL]: 1298473200000 → 1298530468000
#   ✅ doc_2003016_02 - 김미화[DRAFT]: 1298386800000 → 1298420937000
#   ✅ doc_2003016_02 - 김성수[APPROVAL]: 1298646000000 → 1298646197000
#   ✅ doc_2003029_02 - 정주연[DRAFT]: 1298473200000 → 1298535294000
#   ✅ doc_2003029_02 - 최기원[APPROVAL]: 1298473200000 → 1298543256000
#   ✅ doc_2003029_02 - CEO[APPROVAL]: 1298905200000 → 1298985277000
#   ✅ doc_2003026_02 - 박정균[DRAFT]: 1298473200000 → 1298521026000
#   ✅ doc_2003026_02 - 최기원[APPROVAL]: 1298559600000 → 1298591881000
#   ✅ doc_2003026_02 - 정주연[AGREEMENT]: 1299164400000 → 1299210645000
#   ✅ doc_2003033_02 - 김태정[DRAFT]: 1298559600000 → 1298614316000
#   ✅ doc_2003033_02 - CEO[APPROVAL]: 1299337200000 → 1299411422000
#   ✅ doc_2003033_02 - 최기원[AGREEMENT]: 1298559600000 → 1298632158000
#   ✅ doc_2003033_02 - 정주연[AGREEMENT]: 1298991600000 → 1299061938000
#   ✅ doc_2003031_02 - 이형균[DRAFT]: 1298559600000 → 1298603266000
#   ✅ doc_2003031_02 - 김태정[APPROVAL]: 1298559600000 → 1298606639000
#   ✅ doc_2003031_02 - 정주연[AGREEMENT]: 1298818800000 → 1298857079000
#   ✅ doc_2003030_02 - 박정균[DRAFT]: 1298559600000 → 1298600607000
#   ✅ doc_2003030_02 - 정주연[APPROVAL]: 1298559600000 → 1298621640000
#   ✅ doc_2003037_02 - 김기동[DRAFT]: 1298818800000 → 1298888673000
#   ✅ doc_2003037_02 - 김태정[APPROVAL]: 1298818800000 → 1298888993000
#   ✅ doc_2003037_02 - 최기원[AGREEMENT]: 1298818800000 → 1298895451000
#   ✅ doc_2003038_02 - 김하응[DRAFT]: 1298905200000 → 1298980262000
#   ✅ doc_2003038_02 - 박정균[APPROVAL]: 1299078000000 → 1299103102000
#   ✅ doc_2003038_02 - 최기원[APPROVAL]: 1299078000000 → 1299113608000
#   ✅ doc_2003038_02 - CEO[APPROVAL]: 1299337200000 → 1299413058000
#   ✅ doc_2003038_02 - 정주연[AGREEMENT]: 1298991600000 → 1299065199000
#   ✅ doc_2003039_02 - 김규일[DRAFT]: 1298905200000 → 1298989071000
#   ✅ doc_2003039_02 - 박정균[APPROVAL]: 1298991600000 → 1299027077000
#   ✅ doc_2003039_02 - 최기원[APPROVAL]: 1298991600000 → 1299034286000
#   ✅ doc_2003044_02 - 최기원[DRAFT]: 1298991600000 → 1299043151000
#   ✅ doc_2003044_02 - CEO[APPROVAL]: 1299337200000 → 1299413004000
#   ✅ doc_2003044_02 - 정주연[AGREEMENT]: 1299423600000 → 1299461754000
#   ✅ doc_2003046_02 - 편영수[DRAFT]: 1298991600000 → 1299051995000
#   ✅ doc_2003046_02 - 최기원[APPROVAL]: 1299337200000 → 1299413233000
#   ✅ doc_2003046_02 - 정주연[AGREEMENT]: 1299164400000 → 1299236868000
#   ✅ doc_2003041_02 - 김태정[DRAFT]: 1298991600000 → 1299029018000
#   ✅ doc_2003041_02 - CEO[APPROVAL]: 1298991600000 → 1299030468000
#   ✅ doc_2003048_02 - 박선용[DRAFT]: 1299078000000 → 1299132230000
#   ✅ doc_2003048_02 - 최기원[APPROVAL]: 1299337200000 → 1299413253000
#   ✅ doc_2003048_02 - 정주연[AGREEMENT]: 1299164400000 → 1299236972000
#   ✅ doc_2003047_02 - 최기원[DRAFT]: 1299078000000 → 1299116152000
#   ✅ doc_2003047_02 - CEO[APPROVAL]: 1299337200000 → 1299411382000
#   ✅ doc_2003050_02 - 김성수[DRAFT]: 1299164400000 → 1299200639000
#   ✅ doc_2003050_02 - 정주연[APPROVAL]: 1299164400000 → 1299238244000
#   ✅ doc_2003053_02 - 김성수[DRAFT]: 1299164400000 → 1299239260000
#   ✅ doc_2003053_02 - 최기원[APPROVAL]: 1299337200000 → 1299413526000
#   ✅ doc_2003053_02 - CEO[APPROVAL]: 1299337200000 → 1299413845000
#   ✅ doc_2003053_02 - 정주연[AGREEMENT]: 1299164400000 → 1299239380000
#   ✅ doc_2003061_02 - 김태정[DRAFT]: 1299423600000 → 1299496519000
#   ✅ doc_2003061_02 - 최기원[APPROVAL]: 1299596400000 → 1299661693000
#   ✅ doc_2003061_02 - CEO[APPROVAL]: 1299682800000 → 1299732665000
#   ✅ doc_2003061_02 - 정주연[AGREEMENT]: 1299596400000 → 1299627401000
#   ✅ doc_2003064_02 - 윤상호[DRAFT]: 1299510000000 → 1299550980000
#   ✅ doc_2003064_02 - 박정균[APPROVAL]: 1299682800000 → 1299707763000
#   ✅ doc_2003064_02 - 최기원[APPROVAL]: 1299682800000 → 1299728498000
#   ✅ doc_2003064_02 - CEO[APPROVAL]: 1299682800000 → 1299732626000
#   ✅ doc_2003064_02 - 정주연[AGREEMENT]: 1299682800000 → 1299725238000
#   ✅ doc_2003068_02 - 정주연[DRAFT]: 1299596400000 → 1299630991000
#   ✅ doc_2003068_02 - 최기원[APPROVAL]: 1299596400000 → 1299661786000
#   ✅ doc_2003068_02 - CEO[APPROVAL]: 1299682800000 → 1299732570000
#   ✅ doc_2003067_02 - 편영수[DRAFT]: 1299596400000 → 1299628847000
#   ✅ doc_2003067_02 - 최기원[APPROVAL]: 1299596400000 → 1299662027000
#   ✅ doc_2003067_02 - CEO[APPROVAL]: 1299682800000 → 1299732598000
#   ✅ doc_2003067_02 - 정주연[AGREEMENT]: 1299596400000 → 1299631345000
#   ✅ doc_2003072_02 - 이형균[DRAFT]: 1299682800000 → 1299731846000
#   ✅ doc_2003072_02 - 김태정[APPROVAL]: 1299682800000 → 1299732443000
#   ✅ doc_2003072_02 - 정주연[AGREEMENT]: 1299682800000 → 1299738814000
#   ✅ doc_2003073_02 - 박정균[DRAFT]: 1299769200000 → 1299834620000
#   ✅ doc_2003073_02 - 정주연[AGREEMENT]: 1300028400000 → 1300070982000
#   ✅ doc_2003073_02 - 최기원[AGREEMENT]: 1299769200000 → 1299841261000
#   ✅ doc_2003075_02 - 김규일[DRAFT]: 1300028400000 → 1300067715000
#   ✅ doc_2003075_02 - 박정균[APPROVAL]: 1300028400000 → 1300074140000
#   ✅ doc_2003075_02 - CEO[APPROVAL]: 1300114800000 → 1300147494000
#   ✅ doc_2003075_02 - 정주연[AGREEMENT]: 1300028400000 → 1300100144000
#   ✅ doc_2003075_02 - 최기원[AGREEMENT]: 1300028400000 → 1300076457000
#   ✅ doc_2003080_02 - 김동력[DRAFT]: 1300374000000 → 1300427102000
#   ✅ doc_2003080_02 - 최기원[APPROVAL]: 1300546800000 → 1300625369000
#   ✅ doc_2003080_02 - CEO[APPROVAL]: 1300633200000 → 1300686843000
#   ✅ doc_2003082_02 - 김동력[DRAFT]: 1300374000000 → 1300439414000
#   ✅ doc_2003082_02 - 최기원[APPROVAL]: 1300719600000 → 1300778140000
#   ✅ doc_2003084_02 - 최성민[DRAFT]: 1300633200000 → 1300685781000
#   ✅ doc_2003084_02 - 김태정[APPROVAL]: 1300719600000 → 1300779343000
#   ✅ doc_2003084_02 - 최기원[APPROVAL]: 1300719600000 → 1300784345000
#   ✅ doc_2003084_02 - 정주연[AGREEMENT]: 1300719600000 → 1300777679000
#   ✅ doc_2003088_02 - 김동력[DRAFT]: 1300719600000 → 1300777620000
#   ✅ doc_2003088_02 - 최기원[APPROVAL]: 1300806000000 → 1300876311000
#   ✅ doc_2003088_02 - CEO[APPROVAL]: 1300892400000 → 1300974343000
#   ✅ doc_2003088_02 - 박정균[AGREEMENT]: 1300806000000 → 1300874431000
#   ✅ doc_2003086_02 - 김동력[DRAFT]: 1300719600000 → 1300776900000
#   ✅ doc_2003086_02 - 최기원[APPROVAL]: 1300806000000 → 1300876190000
#   ✅ doc_2003086_02 - CEO[APPROVAL]: 1300892400000 → 1300974391000
#   ✅ doc_2003086_02 - 박정균[AGREEMENT]: 1300806000000 → 1300874361000
#   ✅ doc_2003090_02 - 정주연[DRAFT]: 1300806000000 → 1300875348000
#   ✅ doc_2003090_02 - 최기원[APPROVAL]: 1300806000000 → 1300876139000
#   ✅ doc_2003090_02 - CEO[APPROVAL]: 1300892400000 → 1300974194000
#   ✅ doc_2003092_02 - 김동력[DRAFT]: 1300892400000 → 1300929937000
#   ✅ doc_2003092_02 - 최기원[APPROVAL]: 1300978800000 → 1301010850000
#   ✅ doc_2003092_02 - CEO[APPROVAL]: 1301238000000 → 1301291136000
#   ✅ doc_2003092_02 - 박정균[AGREEMENT]: 1300892400000 → 1300963784000
#   ✅ doc_2003092_02 - 정주연[AGREEMENT]: 1300892400000 → 1300933679000
#   ✅ doc_2003095_02 - 김동력[DRAFT]: 1300892400000 → 1300930518000
#   ✅ doc_2003095_02 - 최기원[APPROVAL]: 1300892400000 → 1300941486000
#   ✅ doc_2003095_02 - CEO[APPROVAL]: 1300892400000 → 1300974260000
#   ✅ doc_2003095_02 - 정주연[AGREEMENT]: 1300892400000 → 1300933166000
#   ✅ doc_2003095_02 - 김태정[AGREEMENT]: 1300892400000 → 1300940785000
#   ✅ doc_2003094_02 - 김동력[DRAFT]: 1300892400000 → 1300930415000
#   ✅ doc_2003094_02 - 최기원[APPROVAL]: 1300892400000 → 1300941156000
#   ✅ doc_2003094_02 - CEO[APPROVAL]: 1300892400000 → 1300974306000
#   ✅ doc_2003094_02 - 정주연[AGREEMENT]: 1300892400000 → 1300932674000
#   ✅ doc_2003093_02 - 김동력[DRAFT]: 1300892400000 → 1300930389000
#   ✅ doc_2003093_02 - 최기원[APPROVAL]: 1300892400000 → 1300940928000
#   ✅ doc_2003093_02 - CEO[APPROVAL]: 1300892400000 → 1300974278000
#   ✅ doc_2003093_02 - 김성수[AGREEMENT]: 1300892400000 → 1300931170000
#   ✅ doc_2003093_02 - 정주연[AGREEMENT]: 1300892400000 → 1300933710000
#   ✅ doc_2003102_02 - 김동력[DRAFT]: 1300978800000 → 1301042068000
#   ✅ doc_2003102_02 - 최기원[APPROVAL]: 1301238000000 → 1301238334000
#   ✅ doc_2003102_02 - CEO[APPROVAL]: 1301238000000 → 1301290895000
#   ✅ doc_2003102_02 - 정주연[AGREEMENT]: 1300978800000 → 1301042716000
#   ✅ doc_2003097_02 - 김성수[DRAFT]: 1300978800000 → 1301017009000
#   ✅ doc_2003097_02 - 정주연[APPROVAL]: 1300978800000 → 1301041994000
#   ✅ doc_2003111_02 - 김동력[DRAFT]: 1301324400000 → 1301379492000
#   ✅ doc_2003111_02 - 최기원[APPROVAL]: 1301410800000 → 1301440496000
#   ✅ doc_2003111_02 - CEO[APPROVAL]: 1301497200000 → 1301548037000
#   ✅ doc_2003116_02 - 김하응[DRAFT]: 1301410800000 → 1301485685000
#   ✅ doc_2003116_02 - 박정균[APPROVAL]: 1301583600000 → 1301631147000
#   ✅ doc_2003116_02 - 최기원[APPROVAL]: 1301583600000 → 1301645855000
#   ✅ doc_2003116_02 - CEO[APPROVAL]: 1301670000000 → 1301699250000
#   ✅ doc_2003116_02 - 정주연[AGREEMENT]: 1301583600000 → 1301634137000
#   ✅ doc_2003117_02 - 김규일[DRAFT]: 1301410800000 → 1301487360000
#   ✅ doc_2003117_02 - 박정균[APPROVAL]: 1301497200000 → 1301530303000
#   ✅ doc_2003117_02 - 최기원[APPROVAL]: 1301497200000 → 1301536287000
#   ✅ doc_2003117_02 - 정주연[AGREEMENT]: 1301497200000 → 1301535120000
#   ✅ doc_2003119_02 - 최기원[DRAFT]: 1301497200000 → 1301557115000
#   ✅ doc_2003119_02 - CEO[APPROVAL]: 1301670000000 → 1301699197000
#   ✅ doc_2003120_02 - 이성권[DRAFT]: 1301497200000 → 1301563128000
#   ✅ doc_2003120_02 - 김태정[APPROVAL]: 1301583600000 → 1301642087000
#   ✅ doc_2003120_02 - 최성민[AGREEMENT]: 1301497200000 → 1301563324000
#   ✅ doc_2003123_02 - 정혜연[DRAFT]: 1301583600000 → 1301643714000
#   ✅ doc_2003123_02 - 김화연[APPROVAL]: 1301583600000 → 1301645361000
#   ✅ doc_2003123_02 - 김성수[APPROVAL]: 1301842800000 → 1301875149000
#   ✅ doc_2003123_02 - 정주연[AGREEMENT]: 1301842800000 → 1301894173000
#   ✅ doc_2003125_02 - 박정균[DRAFT]: 1301842800000 → 1301874838000
#   ✅ doc_2003125_02 - CEO[APPROVAL]: 1302015600000 → 1302047219000
#   ✅ doc_2003125_02 - 김동력[AGREEMENT]: 1301929200000 → 1301980989000
#   ✅ doc_2003125_02 - 최기원[AGREEMENT]: 1301929200000 → 1301982689000
#   ✅ doc_2003127_02 - 김미화[DRAFT]: 1301929200000 → 1301979321000
#   ✅ doc_2003127_02 - 김성수[APPROVAL]: 1301929200000 → 1301991336000
#   ✅ doc_2003127_02 - 정주연[AGREEMENT]: 1302102000000 → 1302137123000
#   ✅ doc_2003132_02 - 김태정[DRAFT]: 1302015600000 → 1302082876000
#   ✅ doc_2003132_02 - 김동력[APPROVAL]: 1302102000000 → 1302135817000
#   ✅ doc_2003132_02 - 최기원[APPROVAL]: 1302102000000 → 1302143350000
#   ✅ doc_2003134_02 - 박정균[DRAFT]: 1302361200000 → 1302407312000
#   ✅ doc_2003134_02 - CEO[APPROVAL]: 1302447600000 → 1302487030000
#   ✅ doc_2003136_02 - 김동력[DRAFT]: 1302447600000 → 1302504169000
#   ✅ doc_2003136_02 - 최기원[APPROVAL]: 1302447600000 → 1302512498000
#   ✅ doc_2003137_02 - 박정균[DRAFT]: 1302447600000 → 1302512153000
#   ✅ doc_2003137_02 - 정주연[APPROVAL]: 1302534000000 → 1302587927000
#   ✅ doc_2003137_02 - 최기원[APPROVAL]: 1302534000000 → 1302601998000
#   ✅ doc_2003141_02 - 김동력[DRAFT]: 1302534000000 → 1302602236000
#   ✅ doc_2003141_02 - 최기원[APPROVAL]: 1302620400000 → 1302654453000
#   ✅ doc_2003141_02 - CEO[APPROVAL]: 1302620400000 → 1302656610000
#   ✅ doc_2003141_02 - 정주연[AGREEMENT]: 1302620400000 → 1302651737000
#   ✅ doc_2003146_02 - 김동력[DRAFT]: 1302706800000 → 1302762247000
#   ✅ doc_2003146_02 - 김태정[APPROVAL]: 1302706800000 → 1302781381000
#   ✅ doc_2003146_02 - 최기원[APPROVAL]: 1302793200000 → 1302825565000
#   ✅ doc_2003146_02 - CEO[APPROVAL]: 1302793200000 → 1302840210000
#   ✅ doc_2003145_02 - 김기동[DRAFT]: 1302706800000 → 1302743160000
#   ✅ doc_2003145_02 - 김태정[APPROVAL]: 1302706800000 → 1302781398000
#   ✅ doc_2003145_02 - CEO[APPROVAL]: 1302793200000 → 1302839960000
#   ✅ doc_2003149_02 - 김하응[DRAFT]: 1303052400000 → 1303123197000
#   ✅ doc_2003149_02 - 박정균[APPROVAL]: 1303138800000 → 1303164566000
#   ✅ doc_2003149_02 - 최기원[APPROVAL]: 1303225200000 → 1303256916000
#   ✅ doc_2003149_02 - CEO[APPROVAL]: 1303225200000 → 1303272564000
#   ✅ doc_2003149_02 - 정주연[AGREEMENT]: 1303225200000 → 1303256427000
#   ✅ doc_2003148_02 - 이성권[DRAFT]: 1303052400000 → 1303122400000
#   ✅ doc_2003148_02 - 김태정[APPROVAL]: 1303052400000 → 1303132325000
#   ✅ doc_2003148_02 - 김규일[AGREEMENT]: 1303052400000 → 1303126469000
#   ✅ doc_2003151_02 - 김동력[DRAFT]: 1303138800000 → 1303190947000
#   ✅ doc_2003151_02 - 최기원[APPROVAL]: 1303225200000 → 1303260638000
#   ✅ doc_2003151_02 - CEO[APPROVAL]: 1303225200000 → 1303272796000
#   ✅ doc_2003151_02 - 정주연[AGREEMENT]: 1303225200000 → 1303256978000
#   ✅ doc_2003151_02 - 박선용[AGREEMENT]: 1303138800000 → 1303191151000
#   ✅ doc_2003150_02 - 김동력[DRAFT]: 1303138800000 → 1303190724000
#   ✅ doc_2003150_02 - 최기원[APPROVAL]: 1303225200000 → 1303260425000
#   ✅ doc_2003150_02 - CEO[APPROVAL]: 1303225200000 → 1303272737000
#   ✅ doc_2003150_02 - 정주연[AGREEMENT]: 1303225200000 → 1303256945000
#   ✅ doc_2003152_02 - 김동력[DRAFT]: 1303138800000 → 1303195317000
#   ✅ doc_2003152_02 - 최기원[APPROVAL]: 1303225200000 → 1303261105000
#   ✅ doc_2003152_02 - CEO[APPROVAL]: 1303225200000 → 1303272637000
#   ✅ doc_2003152_02 - 정주연[AGREEMENT]: 1303225200000 → 1303257017000
#   ✅ doc_2003152_02 - 김태정[AGREEMENT]: 1303225200000 → 1303252047000
#   ✅ doc_2003155_02 - 김동력[DRAFT]: 1303225200000 → 1303274749000
#   ✅ doc_2003155_02 - 최기원[APPROVAL]: 1303225200000 → 1303284356000
#   ✅ doc_2003155_02 - CEO[APPROVAL]: 1303657200000 → 1303685566000
#   ✅ doc_2003155_02 - 김태정[AGREEMENT]: 1303225200000 → 1303274874000
#   ✅ doc_2003155_02 - 정주연[AGREEMENT]: 1303225200000 → 1303274891000
#   ✅ doc_2003154_02 - 김동력[DRAFT]: 1303225200000 → 1303258547000
#   ✅ doc_2003154_02 - 최기원[APPROVAL]: 1303225200000 → 1303284118000
#   ✅ doc_2003154_02 - CEO[APPROVAL]: 1303311600000 → 1303344660000
#   ✅ doc_2003154_02 - 정주연[AGREEMENT]: 1303225200000 → 1303273333000
#   ✅ doc_2003154_02 - 김성수[AGREEMENT]: 1303225200000 → 1303258805000
#   ✅ doc_2003156_02 - 송명근[DRAFT]: 1303311600000 → 1303362781000
#   ✅ doc_2003156_02 - 김태정[APPROVAL]: 1303657200000 → 1303671726000
#   ✅ doc_2003156_02 - 김규일[AGREEMENT]: 1303398000000 → 1303442129000
#   ✅ doc_2003160_02 - 정주연[DRAFT]: 1303398000000 → 1303452762000
#   ✅ doc_2003160_02 - 최기원[APPROVAL]: 1303398000000 → 1303455749000
#   ✅ doc_2003160_02 - CEO[APPROVAL]: 1303657200000 → 1303685251000
#   ✅ doc_2003159_02 - 정주연[DRAFT]: 1303398000000 → 1303451392000
#   ✅ doc_2003159_02 - 최기원[APPROVAL]: 1303398000000 → 1303455681000
#   ✅ doc_2003159_02 - CEO[APPROVAL]: 1303657200000 → 1303685292000
#   ✅ doc_2003164_02 - 정주연[DRAFT]: 1303657200000 → 1303720714000
#   ✅ doc_2003164_02 - 최기원[APPROVAL]: 1303657200000 → 1303723020000
#   ✅ doc_2003164_02 - CEO[APPROVAL]: 1303743600000 → 1303787434000
#   ✅ doc_2003163_02 - 정주연[DRAFT]: 1303657200000 → 1303717146000
#   ✅ doc_2003163_02 - 최기원[APPROVAL]: 1303657200000 → 1303717301000
#   ✅ doc_2003163_02 - CEO[APPROVAL]: 1303743600000 → 1303787397000
#   ✅ doc_2003162_02 - 김태정[DRAFT]: 1303657200000 → 1303712292000
#   ✅ doc_2003162_02 - CEO[APPROVAL]: 1303743600000 → 1303793060000
#   ✅ doc_2003162_02 - 최기원[AGREEMENT]: 1303657200000 → 1303716862000
#   ✅ doc_2003162_02 - 정주연[AGREEMENT]: 1303657200000 → 1303713664000
#   ✅ doc_2003170_02 - 김재영[DRAFT]: 1303830000000 → 1303896313000
#   ✅ doc_2003170_02 - 이형균[APPROVAL]: 1303830000000 → 1303896362000
#   ✅ doc_2003170_02 - 김태정[APPROVAL]: 1303830000000 → 1303897659000
#   ✅ doc_2003168_02 - 이형균[DRAFT]: 1303830000000 → 1303884608000
#   ✅ doc_2003168_02 - 김태정[APPROVAL]: 1303830000000 → 1303889581000
#   ✅ doc_2003172_02 - 정현정[DRAFT]: 1303916400000 → 1303969908000
#   ✅ doc_2003172_02 - 이형균[APPROVAL]: 1303916400000 → 1303969942000
#   ✅ doc_2003172_02 - 김태정[APPROVAL]: 1304002800000 → 1304032252000
#   ✅ doc_2003186_02 - 김광희[DRAFT]: 1304002800000 → 1304063707000
#   ✅ doc_2003186_02 - 박정균[APPROVAL]: 1304002800000 → 1304069898000
#   ✅ doc_2003186_02 - 최기원[APPROVAL]: 1304262000000 → 1304327727000
#   ✅ doc_2003186_02 - 정주연[AGREEMENT]: 1304262000000 → 1304326192000
#   ✅ doc_2003179_02 - 김태정[DRAFT]: 1304002800000 → 1304040464000
#   ✅ doc_2003179_02 - CEO[APPROVAL]: 1304262000000 → 1304289135000
#   ✅ doc_2003180_02 - 김정미[DRAFT]: 1304002800000 → 1304041596000
#   ✅ doc_2003180_02 - 정주연[APPROVAL]: 1304002800000 → 1304055260000
#   ✅ doc_2003191_02 - 김하응[DRAFT]: 1304089200000 → 1304147483000
#   ✅ doc_2003191_02 - 박정균[APPROVAL]: 1304262000000 → 1304285939000
#   ✅ doc_2003191_02 - 최기원[APPROVAL]: 1304262000000 → 1304318705000
#   ✅ doc_2003191_02 - CEO[APPROVAL]: 1304348400000 → 1304383319000
#   ✅ doc_2003191_02 - 정주연[AGREEMENT]: 1304262000000 → 1304291423000
#   ✅ doc_2003200_02 - 김은영[DRAFT]: 1304348400000 → 1304379114000
#   ✅ doc_2003200_02 - 김태정[APPROVAL]: 1304348400000 → 1304382497000
#   ✅ doc_2003205_02 - 원성재[DRAFT]: 1304434800000 → 1304482315000
#   ✅ doc_2003205_02 - 박정균[APPROVAL]: 1304434800000 → 1304492117000
#   ✅ doc_2003205_02 - 정주연[APPROVAL]: 1304434800000 → 1304497371000
#   ✅ doc_2003205_02 - 최기원[APPROVAL]: 1304607600000 → 1304642129000
#   ✅ doc_2003210_02 - 박정균[DRAFT]: 1305126000000 → 1305162201000
#   ✅ doc_2003210_02 - CEO[APPROVAL]: 1307631600000 → 1307685472000
#   ✅ doc_2003210_02 - 김동력[AGREEMENT]: 1305212400000 → 1305251077000
#   ✅ doc_2003210_02 - 최기원[AGREEMENT]: 1305212400000 → 1305253633000
#   ✅ doc_2003211_02 - 이종원[DRAFT]: 1305212400000 → 1305247080000
#   ✅ doc_2003211_02 - 박정균[APPROVAL]: 1305212400000 → 1305277205000
#   ✅ doc_2003218_02 - 김동력[DRAFT]: 1305644400000 → 1305708263000
#   ✅ doc_2003218_02 - 최기원[APPROVAL]: 1305730800000 → 1305797834000
#   ✅ doc_2003218_02 - CEO[APPROVAL]: 1305903600000 → 1305964533000
#   ✅ doc_2003218_02 - 박정균[AGREEMENT]: 1305730800000 → 1305782512000
#   ✅ doc_2003218_02 - 정주연[AGREEMENT]: 1305730800000 → 1305778962000
#   ✅ doc_2003221_02 - 김동력[DRAFT]: 1305644400000 → 1305708833000
#   ✅ doc_2003221_02 - 최기원[APPROVAL]: 1305730800000 → 1305797743000
#   ✅ doc_2003221_02 - CEO[APPROVAL]: 1305903600000 → 1305964485000
#   ✅ doc_2003221_02 - 박선용[AGREEMENT]: 1305730800000 → 1305777236000
#   ✅ doc_2003221_02 - 정주연[AGREEMENT]: 1305730800000 → 1305773420000
#   ✅ doc_2003219_02 - 김동력[DRAFT]: 1305644400000 → 1305708549000
#   ✅ doc_2003219_02 - 최기원[APPROVAL]: 1305817200000 → 1305848372000
#   ✅ doc_2003219_02 - CEO[APPROVAL]: 1305903600000 → 1305964516000
#   ✅ doc_2003219_02 - 정주연[AGREEMENT]: 1305730800000 → 1305778832000
#   ✅ doc_2003219_02 - 김태정[AGREEMENT]: 1305730800000 → 1305806728000
#   ✅ doc_2003217_02 - 김동력[DRAFT]: 1305644400000 → 1305707878000
#   ✅ doc_2003217_02 - 최기원[APPROVAL]: 1305730800000 → 1305797800000
#   ✅ doc_2003217_02 - CEO[APPROVAL]: 1305903600000 → 1305964550000
#   ✅ doc_2003217_02 - 정주연[AGREEMENT]: 1305730800000 → 1305778848000
#   ✅ doc_2003220_02 - 김동력[DRAFT]: 1305644400000 → 1305708679000
#   ✅ doc_2003220_02 - 최기원[APPROVAL]: 1305817200000 → 1305854279000
#   ✅ doc_2003220_02 - CEO[APPROVAL]: 1305903600000 → 1305964499000
#   ✅ doc_2003220_02 - 김성수[AGREEMENT]: 1305817200000 → 1305850338000
#   ✅ doc_2003220_02 - 정주연[AGREEMENT]: 1305730800000 → 1305778791000
#   ✅ doc_2003222_02 - 정주연[DRAFT]: 1305730800000 → 1305797619000
#   ✅ doc_2003222_02 - 최기원[APPROVAL]: 1305730800000 → 1305797694000
#   ✅ doc_2003222_02 - CEO[APPROVAL]: 1305903600000 → 1305964467000
#   ✅ doc_2003225_02 - 정주연[DRAFT]: 1306076400000 → 1306138982000
#   ✅ doc_2003225_02 - 최기원[APPROVAL]: 1306162800000 → 1306193120000
#   ✅ doc_2003225_02 - CEO[APPROVAL]: 1306249200000 → 1306283023000
#   ✅ doc_2003228_02 - 이형균[DRAFT]: 1306162800000 → 1306219881000
#   ✅ doc_2003228_02 - 최기원[APPROVAL]: 1306162800000 → 1306225265000
#   ✅ doc_2003228_02 - 김태정[APPROVAL]: 1306249200000 → 1306284329000
#   ✅ doc_2003228_02 - CEO[APPROVAL]: 1306422000000 → 1306472235000
#   ✅ doc_2003228_02 - 김동력[AGREEMENT]: 1306162800000 → 1306220753000
#   ✅ doc_2003226_02 - 김동력[DRAFT]: 1306162800000 → 1306212964000
#   ✅ doc_2003226_02 - 최기원[APPROVAL]: 1306249200000 → 1306283784000
#   ✅ doc_2003226_02 - CEO[APPROVAL]: 1306422000000 → 1306472262000
#   ✅ doc_2003226_02 - 정주연[AGREEMENT]: 1306249200000 → 1306280984000
#   ✅ doc_2003227_02 - 김동력[DRAFT]: 1306162800000 → 1306213061000
#   ✅ doc_2003227_02 - 최기원[APPROVAL]: 1306249200000 → 1306283818000
#   ✅ doc_2003227_02 - CEO[APPROVAL]: 1306422000000 → 1306472249000
#   ✅ doc_2003227_02 - 정주연[AGREEMENT]: 1306249200000 → 1306280991000
#   ✅ doc_2003233_02 - 김기동[DRAFT]: 1306249200000 → 1306333177000
#   ✅ doc_2003233_02 - 김태정[APPROVAL]: 1306335600000 → 1306372230000
#   ✅ doc_2003233_02 - CEO[APPROVAL]: 1306422000000 → 1306471762000
#   ✅ doc_2003235_02 - 윤상호[DRAFT]: 1306422000000 → 1306460163000
#   ✅ doc_2003235_02 - 박정균[APPROVAL]: 1306508400000 → 1306542738000
#   ✅ doc_2003235_02 - 정주연[AGREEMENT]: 1306681200000 → 1306716257000
#   ✅ doc_2003245_02 - 최기원[DRAFT]: 1306681200000 → 1306741310000
#   ✅ doc_2003245_02 - CEO[APPROVAL]: 1306854000000 → 1306889684000
#   ✅ doc_2003245_02 - 정주연[AGREEMENT]: 1306767600000 → 1306808432000
#   ✅ doc_2003240_02 - 이진규[DRAFT]: 1306681200000 → 1306731333000
#   ✅ doc_2003240_02 - 김화연[APPROVAL]: 1306681200000 → 1306744018000
#   ✅ doc_2003240_02 - 김성수[APPROVAL]: 1306767600000 → 1306799900000
#   ✅ doc_2003240_02 - CEO[APPROVAL]: 1306854000000 → 1306889637000
#   ✅ doc_2003240_02 - 정주연[AGREEMENT]: 1306854000000 → 1306907860000
#   ✅ doc_2003238_02 - 양기훈[DRAFT]: 1306681200000 → 1306724111000
#   ✅ doc_2003238_02 - 박정균[APPROVAL]: 1306681200000 → 1306735058000
#   ✅ doc_2003238_02 - 최기원[APPROVAL]: 1306681200000 → 1306746578000
#   ✅ doc_2003238_02 - 정주연[APPROVAL]: 1306767600000 → 1306806404000
#   ✅ doc_2003243_02 - 박정균[DRAFT]: 1306681200000 → 1306739394000
#   ✅ doc_2003243_02 - 최기원[APPROVAL]: 1306767600000 → 1306810887000
#   ✅ doc_2003243_02 - CEO[APPROVAL]: 1306854000000 → 1306889669000
#   ✅ doc_2003243_02 - 정주연[AGREEMENT]: 1306767600000 → 1306806578000
#   ✅ doc_2003242_02 - 박정균[DRAFT]: 1306681200000 → 1306738526000
#   ✅ doc_2003242_02 - 최기원[APPROVAL]: 1306767600000 → 1306810918000
#   ✅ doc_2003242_02 - 정주연[AGREEMENT]: 1306767600000 → 1306806450000
#   ✅ doc_2003239_02 - 양기훈[DRAFT]: 1306681200000 → 1306724249000
#   ✅ doc_2003239_02 - 박정균[APPROVAL]: 1306681200000 → 1306734797000
#   ✅ doc_2003239_02 - 최기원[APPROVAL]: 1306681200000 → 1306738700000
#   ✅ doc_2003239_02 - 정주연[APPROVAL]: 1306767600000 → 1306806414000
#   ✅ doc_2003244_02 - 김규일[DRAFT]: 1306681200000 → 1306740876000
#   ✅ doc_2003244_02 - 김태정[APPROVAL]: 1306681200000 → 1306744076000
#   ✅ doc_2003244_02 - 정주연[AGREEMENT]: 1306767600000 → 1306806475000
#   ✅ doc_2003251_02 - 이형균[DRAFT]: 1306767600000 → 1306816649000
#   ✅ doc_2003251_02 - 김태정[APPROVAL]: 1306854000000 → 1306868382000
#   ✅ doc_2003251_02 - 최기원[APPROVAL]: 1306854000000 → 1306890726000
#   ✅ doc_2003251_02 - CEO[APPROVAL]: 1306940400000 → 1306996949000
#   ✅ doc_2003251_02 - 정주연[AGREEMENT]: 1306854000000 → 1306888925000
#   ✅ doc_2003250_02 - 배현찬[DRAFT]: 1306767600000 → 1306815762000
#   ✅ doc_2003250_02 - 김성수[APPROVAL]: 1306767600000 → 1306832687000
#   ✅ doc_2003250_02 - 최기원[APPROVAL]: 1306854000000 → 1306890501000
#   ✅ doc_2003250_02 - CEO[APPROVAL]: 1306940400000 → 1306996764000
#   ✅ doc_2003250_02 - 정주연[AGREEMENT]: 1306854000000 → 1306888890000
#   ✅ doc_2003247_02 - 김동력[DRAFT]: 1306767600000 → 1306803909000
#   ✅ doc_2003247_02 - 최기원[APPROVAL]: 1306940400000 → 1306973489000
#   ✅ doc_2003247_02 - CEO[APPROVAL]: 1306940400000 → 1306996812000
#   ✅ doc_2003247_02 - 박정균[AGREEMENT]: 1306940400000 → 1306971438000
#   ✅ doc_2003247_02 - 정주연[AGREEMENT]: 1306767600000 → 1306804649000
#   ✅ doc_2003253_02 - 김성수[DRAFT]: 1306767600000 → 1306832631000
#   ✅ doc_2003253_02 - 최기원[APPROVAL]: 1306854000000 → 1306890533000
#   ✅ doc_2003253_02 - CEO[APPROVAL]: 1306940400000 → 1306996606000
#   ✅ doc_2003253_02 - 정주연[AGREEMENT]: 1306854000000 → 1306889021000
#   ✅ doc_2003248_02 - 김태정[DRAFT]: 1306767600000 → 1306806519000
#   ✅ doc_2003248_02 - CEO[APPROVAL]: 1306854000000 → 1306889728000
#   ✅ doc_2003248_02 - 김동력[AGREEMENT]: 1306767600000 → 1306810282000
#   ✅ doc_2003248_02 - 최기원[AGREEMENT]: 1306767600000 → 1306810976000
#   ✅ doc_2003255_02 - 이종수[DRAFT]: 1306854000000 → 1306894594000
#   ✅ doc_2003255_02 - 김태정[APPROVAL]: 1306940400000 → 1306973433000
#   ✅ doc_2003255_02 - 최기원[APPROVAL]: 1306940400000 → 1306975737000
#   ✅ doc_2003255_02 - CEO[APPROVAL]: 1306940400000 → 1306996545000
#   ✅ doc_2003255_02 - 정주연[AGREEMENT]: 1306940400000 → 1306974047000
#   ✅ doc_2003257_02 - 김은영[DRAFT]: 1306854000000 → 1306896883000
#   ✅ doc_2003257_02 - 김태정[APPROVAL]: 1306940400000 → 1306973377000
#   ✅ doc_2003257_02 - 최기원[APPROVAL]: 1306940400000 → 1306974688000
#   ✅ doc_2003257_02 - CEO[APPROVAL]: 1306940400000 → 1306996502000
#   ✅ doc_2003257_02 - 정주연[AGREEMENT]: 1306940400000 → 1306974159000
#   ✅ doc_2003261_02 - 양기훈[DRAFT]: 1306854000000 → 1306933732000
#   ✅ doc_2003261_02 - 박정균[APPROVAL]: 1306940400000 → 1306971384000
#   ✅ doc_2003261_02 - 김동력[APPROVAL]: 1306940400000 → 1306972341000
#   ✅ doc_2003260_02 - 김기동[DRAFT]: 1306854000000 → 1306924095000
#   ✅ doc_2003260_02 - 김태정[APPROVAL]: 1306940400000 → 1306973318000
#   ✅ doc_2003260_02 - 김동력[AGREEMENT]: 1306940400000 → 1306983169000
#   ✅ doc_2003260_02 - 최기원[AGREEMENT]: 1306940400000 → 1306973851000
#   ✅ doc_2003263_02 - 김기동[DRAFT]: 1306940400000 → 1306976604000
#   ✅ doc_2003263_02 - 김태정[APPROVAL]: 1306940400000 → 1306984916000
#   ✅ doc_2003263_02 - 김동력[AGREEMENT]: 1306940400000 → 1307000318000
#   ✅ doc_2003263_02 - 최기원[AGREEMENT]: 1306940400000 → 1306988930000
#   ✅ doc_2003265_02 - 김화연[DRAFT]: 1306940400000 → 1306998372000
#   ✅ doc_2003265_02 - 김성수[APPROVAL]: 1306940400000 → 1307022610000
#   ✅ doc_2003265_02 - 김동력[APPROVAL]: 1307026800000 → 1307076836000
#   ✅ doc_2003264_02 - 김하응[DRAFT]: 1306940400000 → 1306979540000
#   ✅ doc_2003264_02 - 박정균[APPROVAL]: 1306940400000 → 1306981142000
#   ✅ doc_2003264_02 - 최기원[APPROVAL]: 1306940400000 → 1306989081000
#   ✅ doc_2003264_02 - CEO[APPROVAL]: 1306940400000 → 1306996397000
#   ✅ doc_2003264_02 - 정주연[AGREEMENT]: 1306940400000 → 1306983203000
#   ✅ doc_2003262_02 - 이성권[DRAFT]: 1306940400000 → 1306971906000
#   ✅ doc_2003262_02 - 김태정[APPROVAL]: 1307372400000 → 1307405288000
#   ✅ doc_2003262_02 - 김규일[APPROVAL]: 1307026800000 → 1307064313000
#   ✅ doc_2003268_02 - 이진근[DRAFT]: 1307372400000 → 1307426170000
#   ✅ doc_2003268_02 - 김화연[APPROVAL]: 1307372400000 → 1307432188000
#   ✅ doc_2003268_02 - 김성수[APPROVAL]: 1307372400000 → 1307435455000
#   ✅ doc_2003268_02 - 정주연[APPROVAL]: 1307372400000 → 1307435488000
#   ✅ doc_2003271_02 - 송명근[DRAFT]: 1307545200000 → 1307580612000
#   ✅ doc_2003271_02 - 김성수[APPROVAL]: 1307545200000 → 1307581455000
#   ✅ doc_2003271_02 - 정주연[AGREEMENT]: 1307631600000 → 1307661614000
#   ✅ doc_2003273_02 - 최기원[DRAFT]: 1307631600000 → 1307667599000
#   ✅ doc_2003273_02 - 정주연[AGREEMENT]: 1307631600000 → 1307681351000
#   ✅ doc_2003277_02 - 박정균[DRAFT]: 1307631600000 → 1307695171000
#   ✅ doc_2003277_02 - 최기원[APPROVAL]: 1307890800000 → 1307927830000
#   ✅ doc_2003277_02 - 정주연[AGREEMENT]: 1307890800000 → 1307927482000
#   ✅ doc_2003276_02 - 송명근[DRAFT]: 1307631600000 → 1307692664000
#   ✅ doc_2003276_02 - 김화연[APPROVAL]: 1308236400000 → 1308294473000
#   ✅ doc_2003276_02 - 김성수[APPROVAL]: 1308236400000 → 1308310930000
#   ✅ doc_2003276_02 - CEO[APPROVAL]: 1308495600000 → 1308530404000
#   ✅ doc_2003276_02 - 김동력[APPROVAL]: 1308495600000 → 1308551594000
#   ✅ doc_2003278_02 - 윤상호[DRAFT]: 1307804400000 → 1307862409000
#   ✅ doc_2003278_02 - 박정균[APPROVAL]: 1307977200000 → 1308009190000
#   ✅ doc_2003278_02 - 최기원[APPROVAL]: 1307977200000 → 1308012107000
#   ✅ doc_2003278_02 - CEO[APPROVAL]: 1307977200000 → 1308012893000
#   ✅ doc_2003278_02 - 정주연[AGREEMENT]: 1307977200000 → 1308010599000
#   ✅ doc_2003280_02 - 이종수[DRAFT]: 1307977200000 → 1308014994000
#   ✅ doc_2003280_02 - 김태정[APPROVAL]: 1307977200000 → 1308015807000
#   ✅ doc_2003280_02 - 김동력[AGREEMENT]: 1307977200000 → 1308025703000
#   ✅ doc_2003280_02 - 최기원[AGREEMENT]: 1307977200000 → 1308039101000
#   ✅ doc_2003282_02 - 양기훈[DRAFT]: 1307977200000 → 1308036343000
#   ✅ doc_2003282_02 - 박정균[APPROVAL]: 1308150000000 → 1308172372000
#   ✅ doc_2003282_02 - 김동력[APPROVAL]: 1308150000000 → 1308182778000
#   ✅ doc_2003281_02 - 김광희[DRAFT]: 1307977200000 → 1308032542000
#   ✅ doc_2003281_02 - 박정균[APPROVAL]: 1308150000000 → 1308172362000
#   ✅ doc_2003281_02 - 정주연[AGREEMENT]: 1308150000000 → 1308182166000
#   ✅ doc_2003281_02 - 최기원[AGREEMENT]: 1308150000000 → 1308182489000
#   ✅ doc_2003289_02 - 김동력[DRAFT]: 1308236400000 → 1308295079000
#   ✅ doc_2003289_02 - 최기원[APPROVAL]: 1308236400000 → 1308298540000
#   ✅ doc_2003289_02 - CEO[APPROVAL]: 1308495600000 → 1308530422000
#   ✅ doc_2003289_02 - 정주연[AGREEMENT]: 1308236400000 → 1308297479000
#   ✅ doc_2003292_02 - 김동력[DRAFT]: 1308236400000 → 1308298940000
#   ✅ doc_2003292_02 - 최기원[APPROVAL]: 1308495600000 → 1308536993000
#   ✅ doc_2003292_02 - CEO[APPROVAL]: 1308754800000 → 1308819823000
#   ✅ doc_2003292_02 - 정주연[AGREEMENT]: 1308236400000 → 1308299221000
#   ✅ doc_2003292_02 - 김성수[AGREEMENT]: 1308236400000 → 1308310951000
#   ✅ doc_2003296_02 - 정주연[DRAFT]: 1308582000000 → 1308640195000
#   ✅ doc_2003296_02 - 최기원[APPROVAL]: 1308668400000 → 1308702036000
#   ✅ doc_2003296_02 - CEO[APPROVAL]: 1308754800000 → 1308819784000
#   ✅ doc_2003299_02 - 김규일[DRAFT]: 1308754800000 → 1308788986000
#   ✅ doc_2003299_02 - 김태정[APPROVAL]: 1308754800000 → 1308804310000
#   ✅ doc_2003299_02 - 최기원[APPROVAL]: 1308754800000 → 1308817377000
#   ✅ doc_2003299_02 - 정주연[AGREEMENT]: 1308754800000 → 1308817044000
#   ✅ doc_2003303_02 - 김동력[DRAFT]: 1308754800000 → 1308805924000
#   ✅ doc_2003303_02 - 최기원[APPROVAL]: 1308754800000 → 1308817040000
#   ✅ doc_2003303_02 - CEO[APPROVAL]: 1308754800000 → 1308819753000
#   ✅ doc_2003303_02 - 김성수[AGREEMENT]: 1308754800000 → 1308815940000
#   ✅ doc_2003303_02 - 정주연[AGREEMENT]: 1308754800000 → 1308805970000
#   ✅ doc_2003301_02 - 배현찬[DRAFT]: 1308754800000 → 1308790246000
#   ✅ doc_2003301_02 - 김화연[APPROVAL]: 1308754800000 → 1308790306000
#   ✅ doc_2003301_02 - 김성수[APPROVAL]: 1308754800000 → 1308791668000
#   ✅ doc_2003301_02 - 김동력[APPROVAL]: 1308754800000 → 1308797001000
#   ✅ doc_2003305_02 - 원성재[DRAFT]: 1308841200000 → 1308887332000
#   ✅ doc_2003305_02 - 박정균[APPROVAL]: 1308841200000 → 1308898558000
#   ✅ doc_2003305_02 - 정주연[APPROVAL]: 1308841200000 → 1308900374000
#   ✅ doc_2003305_02 - 김동력[APPROVAL]: 1309100400000 → 1309135206000
#   ✅ doc_2003309_02 - 최기원[DRAFT]: 1309100400000 → 1309140456000
#   ✅ doc_2003309_02 - CEO[APPROVAL]: 1309100400000 → 1309179630000
#   ✅ doc_2003309_02 - 정주연[AGREEMENT]: 1309100400000 → 1309141341000
#   ✅ doc_2003311_02 - 최기원[DRAFT]: 1309186800000 → 1309237208000
#   ✅ doc_2003311_02 - CEO[APPROVAL]: 1309273200000 → 1309326329000
#   ✅ doc_2003311_02 - 정주연[AGREEMENT]: 1309186800000 → 1309246038000
#   ✅ doc_2003313_02 - 김화연[DRAFT]: 1309186800000 → 1309239685000
#   ✅ doc_2003313_02 - 김성수[APPROVAL]: 1309186800000 → 1309244597000
#   ✅ doc_2003313_02 - 최기원[APPROVAL]: 1309186800000 → 1309246548000
#   ✅ doc_2003313_02 - CEO[APPROVAL]: 1309273200000 → 1309326289000
#   ✅ doc_2003313_02 - 정주연[AGREEMENT]: 1309186800000 → 1309246017000
#   ✅ doc_2003316_02 - 김규일[DRAFT]: 1309186800000 → 1309265673000
#   ✅ doc_2003316_02 - 김태정[APPROVAL]: 1309273200000 → 1309309186000
#   ✅ doc_2003316_02 - 최기원[APPROVAL]: 1309359600000 → 1309418501000
#   ✅ doc_2003316_02 - CEO[APPROVAL]: 1309791600000 → 1309836198000
#   ✅ doc_2003316_02 - 정주연[AGREEMENT]: 1309359600000 → 1309417098000
#   ✅ doc_2003318_02 - 이형균[DRAFT]: 1309273200000 → 1309314746000
#   ✅ doc_2003318_02 - 김태정[APPROVAL]: 1309273200000 → 1309319367000
#   ✅ doc_2003318_02 - 최기원[APPROVAL]: 1309359600000 → 1309413627000
#   ✅ doc_2003318_02 - CEO[APPROVAL]: 1309791600000 → 1309821197000
#   ✅ doc_2003318_02 - 정주연[AGREEMENT]: 1309359600000 → 1309408304000
#   ✅ doc_2003317_02 - 김화연[DRAFT]: 1309273200000 → 1309306185000
#   ✅ doc_2003317_02 - 김성수[APPROVAL]: 1309273200000 → 1309306440000
#   ✅ doc_2003317_02 - 최기원[APPROVAL]: 1309359600000 → 1309418215000
#   ✅ doc_2003317_02 - 정주연[AGREEMENT]: 1309359600000 → 1309417043000
#   ✅ doc_2003319_02 - 김하응[DRAFT]: 1309273200000 → 1309320668000
#   ✅ doc_2003319_02 - 박정균[APPROVAL]: 1309273200000 → 1309337419000
#   ✅ doc_2003319_02 - 최기원[APPROVAL]: 1309359600000 → 1309413858000
#   ✅ doc_2003319_02 - CEO[APPROVAL]: 1309791600000 → 1309821241000
#   ✅ doc_2003319_02 - 정주연[AGREEMENT]: 1309359600000 → 1309409943000
#   ✅ doc_2003321_02 - 윤상호[DRAFT]: 1309273200000 → 1309339412000
#   ✅ doc_2003321_02 - 박정균[APPROVAL]: 1309273200000 → 1309343622000
#   ✅ doc_2003321_02 - CEO[APPROVAL]: 1309359600000 → 1309400936000
#   ✅ doc_2003326_02 - 김태정[DRAFT]: 1309446000000 → 1309499428000
#   ✅ doc_2003326_02 - 최기원[APPROVAL]: 1309705200000 → 1309739808000
#   ✅ doc_2003326_02 - CEO[APPROVAL]: 1309791600000 → 1309821215000
#   ✅ doc_2003326_02 - 정주연[AGREEMENT]: 1309446000000 → 1309505106000
#   ✅ doc_2003323_02 - 편영수[DRAFT]: 1309446000000 → 1309478457000
#   ✅ doc_2003323_02 - 이석주[APPROVAL]: 1309446000000 → 1309486773000
#   ✅ doc_2003323_02 - 최기원[APPROVAL]: 1309705200000 → 1309739788000
#   ✅ doc_2003323_02 - CEO[APPROVAL]: 1309791600000 → 1309821118000
#   ✅ doc_2003323_02 - 정주연[AGREEMENT]: 1309446000000 → 1309505930000
#   ✅ doc_2003324_02 - 최기원[DRAFT]: 1309446000000 → 1309482433000
#   ✅ doc_2003324_02 - 정주연[AGREEMENT]: 1309446000000 → 1309505289000
#   ✅ doc_2003329_02 - 윤상호[DRAFT]: 1309532400000 → 1309580011000
#   ✅ doc_2003329_02 - 박정균[APPROVAL]: 1309705200000 → 1309737375000
#   ✅ doc_2003329_02 - 최기원[APPROVAL]: 1309705200000 → 1309762416000
#   ✅ doc_2003329_02 - 정주연[AGREEMENT]: 1309705200000 → 1309760614000
#   ✅ doc_2003333_02 - 양기훈[DRAFT]: 1309705200000 → 1309760391000
#   ✅ doc_2003333_02 - 박정균[APPROVAL]: 1309791600000 → 1309822561000
#   ✅ doc_2003333_02 - 최기원[APPROVAL]: 1309791600000 → 1309841043000
#   ✅ doc_2003333_02 - 정주연[AGREEMENT]: 1309791600000 → 1309827728000
#   ✅ doc_2003331_02 - 박정균[DRAFT]: 1309705200000 → 1309739152000
#   ✅ doc_2003331_02 - 정주연[APPROVAL]: 1309705200000 → 1309760520000
#   ✅ doc_2003331_02 - 최기원[APPROVAL]: 1309705200000 → 1309767750000
#   ✅ doc_2003330_02 - 박정균[DRAFT]: 1309705200000 → 1309738015000
#   ✅ doc_2003330_02 - 최기원[APPROVAL]: 1309705200000 → 1309762473000
#   ✅ doc_2003330_02 - CEO[APPROVAL]: 1309791600000 → 1309821049000
#   ✅ doc_2003330_02 - 정주연[AGREEMENT]: 1309705200000 → 1309760600000
#   ✅ doc_2003332_02 - 김은영[DRAFT]: 1309705200000 → 1309741434000
#   ✅ doc_2003332_02 - 김태정[APPROVAL]: 1309791600000 → 1309847957000
#   ✅ doc_2003332_02 - 김하응[AGREEMENT]: 1309791600000 → 1309841860000
#   ✅ doc_2003332_02 - 김동력[AGREEMENT]: 1309791600000 → 1309851242000
#   ✅ doc_2003337_02 - 김기범[DRAFT]: 1309964400000 → 1310049445000
#   ✅ doc_2003337_02 - 박정균[APPROVAL]: 1310050800000 → 1310087692000
#   ✅ doc_2003337_02 - 정주연[AGREEMENT]: 1310050800000 → 1310115298000
#   ✅ doc_2003338_02 - 김화연[DRAFT]: 1310050800000 → 1310085289000
#   ✅ doc_2003338_02 - 김성수[APPROVAL]: 1310050800000 → 1310091462000
#   ✅ doc_2003338_02 - 최기원[APPROVAL]: 1310310000000 → 1310346165000
#   ✅ doc_2003338_02 - 정주연[AGREEMENT]: 1310050800000 → 1310115241000
#   ✅ doc_2003339_02 - 김광희[DRAFT]: 1310137200000 → 1310189377000
#   ✅ doc_2003339_02 - 박정균[APPROVAL]: 1310310000000 → 1310358939000
#   ✅ doc_2003339_02 - 최기원[APPROVAL]: 1310310000000 → 1310365377000
#   ✅ doc_2003339_02 - 정주연[AGREEMENT]: 1310310000000 → 1310372000000
#   ✅ doc_2003343_02 - 김정미[DRAFT]: 1310310000000 → 1310369644000
#   ✅ doc_2003343_02 - 김태정[APPROVAL]: 1310310000000 → 1310369877000
#   ✅ doc_2003342_02 - 박정균[DRAFT]: 1310310000000 → 1310360255000
#   ✅ doc_2003342_02 - 정주연[APPROVAL]: 1310310000000 → 1310363781000
#   ✅ doc_2003342_02 - 최기원[APPROVAL]: 1310310000000 → 1310365490000
#   ✅ doc_2003340_02 - 이종원[DRAFT]: 1310310000000 → 1310344579000
#   ✅ doc_2003340_02 - 박정균[APPROVAL]: 1310310000000 → 1310358915000
#   ✅ doc_2003340_02 - 정주연[APPROVAL]: 1310310000000 → 1310363835000
#   ✅ doc_2003344_02 - 김하응[DRAFT]: 1310396400000 → 1310432149000
# ...
#   ✅ doc_2009407_02 - 윤상호[DRAFT]: 1450018800000 → 1450060886000
#   ✅ doc_2009407_02 - 김성수[APPROVAL]: 1450018800000 → 1450076651000
#   ✅ doc_2009407_02 - 박상택[APPROVAL]: 1450018800000 → 1450080178000
#   ✅ doc_2009414_02 - 이동하[DRAFT]: 1450105200000 → 1450165603000
#   ✅ doc_2009414_02 - 박상권[APPROVAL]: 1450191600000 → 1450225202000
#   ✅ doc_2009414_02 - 김문철[AGREEMENT]: 1450191600000 → 1450249013000
#   ✅ doc_2009414_02 - 박상택[AGREEMENT]: 1450191600000 → 1450252424000
#   ✅ doc_2009416_02 - 강정례[DRAFT]: 1450105200000 → 1450190656000
#   ✅ doc_2009416_02 - 윤상호[APPROVAL]: 1450191600000 → 1450225313000
#   ✅ doc_2009416_02 - 정주연[AGREEMENT]: 1422716400000 → 1454294087000
#   ✅ doc_2009413_02 - 소성현[DRAFT]: 1450105200000 → 1450156410000
#   ✅ doc_2009413_02 - 양기훈[APPROVAL]: 1450191600000 → 1450228334000
#   ✅ doc_2009413_02 - 정주연[APPROVAL]: 1422716400000 → 1454294007000
#   ✅ doc_2009425_02 - 박상택[DRAFT]: 1450191600000 → 1450229477000
#   ✅ doc_2009425_02 - 정주연[AGREEMENT]: 1425826800000 → 1457497609000
#   ✅ doc_2009426_02 - 함지연[DRAFT]: 1450191600000 → 1450254561000
#   ✅ doc_2009426_02 - 이진오[APPROVAL]: 1450278000000 → 1450310060000
#   ✅ doc_2009426_02 - 박상택[APPROVAL]: 1450710000000 → 1450775894000
#   ✅ doc_2009426_02 - CEO[APPROVAL]: 1450882800000 → 1450939845000
#   ✅ doc_2009426_02 - 김문철[AGREEMENT]: 1450278000000 → 1450313136000
#   ✅ doc_2009417_02 - 강정례[DRAFT]: 1450191600000 → 1450191746000
#   ✅ doc_2009417_02 - 윤상호[APPROVAL]: 1450191600000 → 1450225406000
#   ✅ doc_2009417_02 - 정주연[AGREEMENT]: 1422716400000 → 1454294117000
#   ✅ doc_2009418_02 - 강정례[DRAFT]: 1450191600000 → 1450192241000
#   ✅ doc_2009418_02 - 윤상호[APPROVAL]: 1450191600000 → 1450225585000
#   ✅ doc_2009418_02 - 정주연[AGREEMENT]: 1422716400000 → 1454294185000
#   ✅ doc_2009421_02 - 강정례[DRAFT]: 1450191600000 → 1450193011000
#   ✅ doc_2009421_02 - 윤상호[APPROVAL]: 1450191600000 → 1450225705000
#   ✅ doc_2009421_02 - 정주연[AGREEMENT]: 1422716400000 → 1454294207000
#   ✅ doc_2009420_02 - 강정례[DRAFT]: 1450191600000 → 1450192958000
#   ✅ doc_2009420_02 - 윤상호[APPROVAL]: 1450191600000 → 1450225669000
#   ✅ doc_2009420_02 - 정주연[AGREEMENT]: 1422716400000 → 1454294235000
#   ✅ doc_2009422_02 - 강정례[DRAFT]: 1450191600000 → 1450193116000
#   ✅ doc_2009422_02 - 윤상호[APPROVAL]: 1450191600000 → 1450225661000
#   ✅ doc_2009422_02 - 정주연[AGREEMENT]: 1422716400000 → 1454294258000
#   ✅ doc_2009419_02 - 강정례[DRAFT]: 1450191600000 → 1450192526000
#   ✅ doc_2009419_02 - 윤상호[APPROVAL]: 1450191600000 → 1450225615000
#   ✅ doc_2009419_02 - 정주연[AGREEMENT]: 1422716400000 → 1454294153000
#   ✅ doc_2009424_02 - 원진희[DRAFT]: 1450191600000 → 1450226312000
#   ✅ doc_2009424_02 - 양기훈[APPROVAL]: 1450191600000 → 1450228355000
#   ✅ doc_2009424_02 - 김성수[APPROVAL]: 1450191600000 → 1450256558000
#   ✅ doc_2009428_02 - 윤인식[DRAFT]: 1450191600000 → 1450267890000
#   ✅ doc_2009428_02 - 정주연[APPROVAL]: 1450796400000 → 1450853943000
#   ✅ doc_2009434_02 - 양기훈[DRAFT]: 1450278000000 → 1450340238000
#   ✅ doc_2009434_02 - 김성수[APPROVAL]: 1450364400000 → 1450397479000
#   ✅ doc_2009434_02 - 박상택[APPROVAL]: 1450882800000 → 1450914927000
#   ✅ doc_2009434_02 - 김문철[AGREEMENT]: 1450364400000 → 1450402206000
#   ✅ doc_2009436_02 - 이천환[DRAFT]: 1450364400000 → 1450402848000
#   ✅ doc_2009436_02 - 김성수[APPROVAL]: 1450364400000 → 1450413077000
#   ✅ doc_2009436_02 - 박상택[APPROVAL]: 1450796400000 → 1450845487000
#   ✅ doc_2009435_02 - 이천환[DRAFT]: 1450364400000 → 1450402804000
#   ✅ doc_2009435_02 - 김성수[APPROVAL]: 1450364400000 → 1450413141000
#   ✅ doc_2009435_02 - 박상택[APPROVAL]: 1450796400000 → 1450845456000
#   ✅ doc_2009431_02 - 이천환[DRAFT]: 1450364400000 → 1450402735000
#   ✅ doc_2009431_02 - 김성수[APPROVAL]: 1450364400000 → 1450413059000
#   ✅ doc_2009431_02 - 박상택[APPROVAL]: 1450796400000 → 1450845414000
#   ✅ doc_2009432_02 - 함지연[DRAFT]: 1450364400000 → 1450396640000
#   ✅ doc_2009432_02 - 이진오[APPROVAL]: 1450364400000 → 1450403014000
#   ✅ doc_2009432_02 - 박상택[APPROVAL]: 1450796400000 → 1450845597000
#   ✅ doc_2009432_02 - CEO[APPROVAL]: 1450882800000 → 1450939944000
#   ✅ doc_2009432_02 - 김문철[AGREEMENT]: 1450364400000 → 1450403095000
#   ✅ doc_2009429_02 - 함지연[DRAFT]: 1450278000000 → 1450315617000
#   ✅ doc_2009429_02 - 이진오[APPROVAL]: 1450278000000 → 1450317714000
#   ✅ doc_2009429_02 - 박상택[APPROVAL]: 1450710000000 → 1450766376000
#   ✅ doc_2009429_02 - CEO[APPROVAL]: 1450882800000 → 1450939864000
#   ✅ doc_2009429_02 - 김문철[AGREEMENT]: 1450278000000 → 1450332265000
#   ✅ doc_2009433_02 - 편영수[DRAFT]: 1450278000000 → 1450338755000
#   ✅ doc_2009433_02 - 박정균[APPROVAL]: 1450364400000 → 1450395889000
#   ✅ doc_2009433_02 - 박상택[APPROVAL]: 1450796400000 → 1450862039000
#   ✅ doc_2009433_02 - 정주연[AGREEMENT]: 1450796400000 → 1450853967000
#   ✅ doc_2009430_02 - 유민규[DRAFT]: 1450278000000 → 1450328348000
#   ✅ doc_2009430_02 - 양기훈[APPROVAL]: 1450278000000 → 1450332052000
#   ✅ doc_2009430_02 - 김성수[APPROVAL]: 1450364400000 → 1450397109000
#   ✅ doc_2009438_02 - 정재웅[DRAFT]: 1450364400000 → 1450402369000
#   ✅ doc_2009438_02 - 윤상호[APPROVAL]: 1450364400000 → 1450418284000
#   ✅ doc_2009438_02 - 김성수[APPROVAL]: 1450364400000 → 1450430653000
#   ✅ doc_2009438_02 - 정주연[APPROVAL]: 1422716400000 → 1454294289000
#   ✅ doc_2009441_02 - 박상택[DRAFT]: 1450364400000 → 1450423086000
#   ✅ doc_2009441_02 - CEO[APPROVAL]: 1451228400000 → 1451263399000
#   ✅ doc_2009439_02 - 이천환[DRAFT]: 1450364400000 → 1450405650000
#   ✅ doc_2009439_02 - 김성수[APPROVAL]: 1450623600000 → 1450664098000
#   ✅ doc_2009439_02 - 박상택[APPROVAL]: 1450796400000 → 1450845313000
#   ✅ doc_2009445_02 - 양기훈[DRAFT]: 1450623600000 → 1450672823000
#   ✅ doc_2009445_02 - 김성수[APPROVAL]: 1450623600000 → 1450681919000
#   ✅ doc_2009445_02 - 박상택[APPROVAL]: 1450710000000 → 1450751730000
#   ✅ doc_2009445_02 - 김문철[AGREEMENT]: 1450623600000 → 1450682908000
#   ✅ doc_2009446_02 - 편영수[DRAFT]: 1450623600000 → 1450683367000
#   ✅ doc_2009446_02 - 박정균[APPROVAL]: 1450710000000 → 1450777215000
#   ✅ doc_2009446_02 - 정주연[AGREEMENT]: 1422716400000 → 1454294323000
#   ✅ doc_2009447_02 - 손한석[DRAFT]: 1450623600000 → 1450686524000
#   ✅ doc_2009447_02 - 윤상호[APPROVAL]: 1450710000000 → 1450745219000
#   ✅ doc_2009447_02 - 김성수[APPROVAL]: 1450710000000 → 1450762125000
#   ✅ doc_2009447_02 - 박상택[APPROVAL]: 1450710000000 → 1450775504000
#   ✅ doc_2009447_02 - CEO[APPROVAL]: 1450882800000 → 1450939877000
#   ✅ doc_2009447_02 - 김문철[AGREEMENT]: 1450710000000 → 1450768572000
#   ✅ doc_2009444_02 - 민영창[DRAFT]: 1450623600000 → 1450663232000
#   ✅ doc_2009444_02 - 김태정[APPROVAL]: 1450623600000 → 1450664306000
#   ✅ doc_2009444_02 - 박상택[APPROVAL]: 1450710000000 → 1450758312000
#   ✅ doc_2009444_02 - CEO[APPROVAL]: 1450882800000 → 1450939890000
#   ✅ doc_2009444_02 - 김문철[AGREEMENT]: 1451228400000 → 1451264841000
#   ✅ doc_2009442_02 - 함지연[DRAFT]: 1450623600000 → 1450655170000
#   ✅ doc_2009442_02 - 이진오[APPROVAL]: 1450623600000 → 1450665962000
#   ✅ doc_2009442_02 - 김문철[AGREEMENT]: 1450623600000 → 1450682828000
#   ✅ doc_2009450_02 - 양기훈[DRAFT]: 1450710000000 → 1450749750000
#   ✅ doc_2009450_02 - 김성수[APPROVAL]: 1451228400000 → 1451289264000
#   ✅ doc_2009450_02 - 박상택[APPROVAL]: 1451401200000 → 1451455930000
#   ✅ doc_2009450_02 - 정주연[AGREEMENT]: 1451314800000 → 1451375098000
#   ✅ doc_2009452_02 - 김형환[DRAFT]: 1450710000000 → 1450784214000
#   ✅ doc_2009452_02 - 양기훈[APPROVAL]: 1450882800000 → 1450913794000
#   ✅ doc_2009452_02 - 김성수[APPROVAL]: 1450882800000 → 1450916722000
#   ✅ doc_2009452_02 - 김문철[APPROVAL]: 1450882800000 → 1450920725000
#   ✅ doc_2009449_02 - 정재웅[DRAFT]: 1450710000000 → 1450747211000
#   ✅ doc_2009449_02 - 윤상호[APPROVAL]: 1450710000000 → 1450747928000
#   ✅ doc_2009449_02 - 김성수[APPROVAL]: 1450710000000 → 1450762151000
#   ✅ doc_2009449_02 - 정주연[APPROVAL]: 1422716400000 → 1454294351000
#   ✅ doc_2009451_02 - 김미화[DRAFT]: 1450710000000 → 1450767756000
#   ✅ doc_2009451_02 - 김성수[APPROVAL]: 1450710000000 → 1450772330000
#   ✅ doc_2009451_02 - 박상택[APPROVAL]: 1450796400000 → 1450845569000
#   ✅ doc_2009451_02 - CEO[APPROVAL]: 1450882800000 → 1450939900000
#   ✅ doc_2009451_02 - 김문철[AGREEMENT]: 1450796400000 → 1450828803000
#   ✅ doc_2009448_02 - 이송연[DRAFT]: 1450710000000 → 1450740865000
#   ✅ doc_2009448_02 - 양기훈[APPROVAL]: 1450710000000 → 1450741384000
#   ✅ doc_2009448_02 - 김성수[APPROVAL]: 1450710000000 → 1450772339000
#   ✅ doc_2009448_02 - 김문철[APPROVAL]: 1450710000000 → 1450767998000
#   ✅ doc_2009459_02 - 정주연[DRAFT]: 1450796400000 → 1450863817000
#   ✅ doc_2009459_02 - CEO[APPROVAL]: 1450882800000 → 1450939919000
#   ✅ doc_2009457_02 - 김문철[DRAFT]: 1450796400000 → 1450850730000
#   ✅ doc_2009457_02 - 박상택[APPROVAL]: 1450796400000 → 1450852115000
#   ✅ doc_2009457_02 - 정주연[AGREEMENT]: 1450796400000 → 1450852033000
#   ✅ doc_2009458_02 - 김문철[DRAFT]: 1450796400000 → 1450861041000
#   ✅ doc_2009458_02 - 박상택[APPROVAL]: 1450882800000 → 1450916092000
#   ✅ doc_2009458_02 - CEO[APPROVAL]: 1450882800000 → 1450939976000
#   ✅ doc_2009458_02 - 정주연[AGREEMENT]: 1450796400000 → 1450863279000
#   ✅ doc_2009455_02 - 소성현[DRAFT]: 1450796400000 → 1450828704000
#   ✅ doc_2009455_02 - 양기훈[APPROVAL]: 1450882800000 → 1450913819000
#   ✅ doc_2009455_02 - 김성수[APPROVAL]: 1450882800000 → 1450916738000
#   ✅ doc_2009453_02 - 이성현[DRAFT]: 1450796400000 → 1450827774000
#   ✅ doc_2009453_02 - 현광섭[APPROVAL]: 1450882800000 → 1450923681000
#   ✅ doc_2009453_02 - 김성수[APPROVAL]: 1450882800000 → 1450951067000
#   ✅ doc_2009453_02 - 류광수[AGREEMENT]: 1450882800000 → 1450945490000
#   ✅ doc_2009453_02 - 김문철[AGREEMENT]: 1451228400000 → 1451264821000
#   ✅ doc_2009454_02 - 소성현[DRAFT]: 1450796400000 → 1450828529000
#   ✅ doc_2009454_02 - 양기훈[APPROVAL]: 1450882800000 → 1450913810000
#   ✅ doc_2009454_02 - 정주연[APPROVAL]: 1422716400000 → 1454294375000
#   ✅ doc_2009460_02 - 이천환[DRAFT]: 1450882800000 → 1450918837000
#   ✅ doc_2009460_02 - 박상택[APPROVAL]: 1450882800000 → 1450932532000
#   ✅ doc_2009460_02 - CEO[APPROVAL]: 1450882800000 → 1450940138000
#   ✅ doc_2009460_02 - 정주연[AGREEMENT]: 1450882800000 → 1450926876000
#   ✅ doc_2009460_02 - 김성수[AGREEMENT]: 1450882800000 → 1450931315000
#   ✅ doc_2009464_02 - 이천환[DRAFT]: 1450882800000 → 1450921805000
#   ✅ doc_2009464_02 - 김성수[APPROVAL]: 1450882800000 → 1450933584000
#   ✅ doc_2009464_02 - 박상택[APPROVAL]: 1451228400000 → 1451264971000
#   ✅ doc_2009465_02 - 이천환[DRAFT]: 1450882800000 → 1450924289000
#   ✅ doc_2009465_02 - 김성수[APPROVAL]: 1450882800000 → 1450933630000
#   ✅ doc_2009465_02 - 박상택[APPROVAL]: 1451228400000 → 1451265352000
#   ✅ doc_2009466_02 - 이천환[DRAFT]: 1450882800000 → 1450925759000
#   ✅ doc_2009466_02 - 김성수[APPROVAL]: 1450882800000 → 1450933618000
#   ✅ doc_2009466_02 - 박상택[APPROVAL]: 1451228400000 → 1451265244000
#   ✅ doc_2009477_02 - 박정균[DRAFT]: 1450882800000 → 1450951440000
#   ✅ doc_2009477_02 - 정주연[AGREEMENT]: 1422716400000 → 1454294660000
#   ✅ doc_2009475_02 - 배설희[DRAFT]: 1450882800000 → 1450949196000
#   ✅ doc_2009475_02 - 윤상호[APPROVAL]: 1451228400000 → 1451266471000
#   ✅ doc_2009475_02 - 김성수[APPROVAL]: 1451228400000 → 1451282486000
#   ✅ doc_2009475_02 - 김문철[AGREEMENT]: 1421247600000 → 1452849312000
#   ✅ doc_2009476_02 - 김성수[DRAFT]: 1450882800000 → 1450951251000
#   ✅ doc_2009476_02 - 박상택[APPROVAL]: 1425826800000 → 1457497689000
#   ✅ doc_2009476_02 - 정주연[APPROVAL]: 1425826800000 → 1457497609000
#   ✅ doc_2009468_02 - 이천환[DRAFT]: 1450882800000 → 1450935065000
#   ✅ doc_2009468_02 - 김성수[APPROVAL]: 1450882800000 → 1450941619000
#   ✅ doc_2009468_02 - 박상택[APPROVAL]: 1451228400000 → 1451264994000
#   ✅ doc_2009468_02 - CEO[APPROVAL]: 1451314800000 → 1451347785000
#   ✅ doc_2009468_02 - 김문철[AGREEMENT]: 1451228400000 → 1451264860000
#   ✅ doc_2009467_02 - 김승범[DRAFT]: 1450882800000 → 1450929099000
#   ✅ doc_2009467_02 - 김하응[APPROVAL]: 1450882800000 → 1450929135000
#   ✅ doc_2009467_02 - 김태정[APPROVAL]: 1450969200000 → 1451043129000
#   ✅ doc_2009467_02 - 김문철[AGREEMENT]: 1451228400000 → 1451263884000
#   ✅ doc_2009461_02 - 유민규[DRAFT]: 1450882800000 → 1450919138000
#   ✅ doc_2009461_02 - 양기훈[APPROVAL]: 1450882800000 → 1450919781000
#   ✅ doc_2009461_02 - 김성수[APPROVAL]: 1450882800000 → 1450931253000
#   ✅ doc_2009463_02 - 원진희[DRAFT]: 1450882800000 → 1450921387000
#   ✅ doc_2009463_02 - 양기훈[APPROVAL]: 1450882800000 → 1450934711000
#   ✅ doc_2009463_02 - 김성수[APPROVAL]: 1450882800000 → 1450934977000
#   ✅ doc_2009462_02 - 양기훈[DRAFT]: 1450882800000 → 1450919760000
#   ✅ doc_2009462_02 - 김성수[APPROVAL]: 1450882800000 → 1450931366000
#   ✅ doc_2009462_02 - 박상택[APPROVAL]: 1451228400000 → 1451264908000
#   ✅ doc_2009462_02 - CEO[APPROVAL]: 1451314800000 → 1451347733000
#   ✅ doc_2009462_02 - 김문철[AGREEMENT]: 1450882800000 → 1450939117000
#   ✅ doc_2009479_02 - 현광섭[DRAFT]: 1451228400000 → 1451259249000
#   ✅ doc_2009479_02 - 정주연[APPROVAL]: 1422716400000 → 1454294996000
#   ✅ doc_2009480_02 - 현광섭[DRAFT]: 1451228400000 → 1451280659000
#   ✅ doc_2009480_02 - 김성수[APPROVAL]: 1451228400000 → 1451282448000
#   ✅ doc_2009480_02 - 박상택[APPROVAL]: 1451314800000 → 1451363334000
#   ✅ doc_2009480_02 - 김문철[AGREEMENT]: 1451314800000 → 1451346057000
#   ✅ doc_2009482_02 - 이형균[DRAFT]: 1451228400000 → 1451278683000
#   ✅ doc_2009482_02 - 김태정[APPROVAL]: 1451228400000 → 1451285088000
#   ✅ doc_2009482_02 - 박상택[APPROVAL]: 1425826800000 → 1457497689000
#   ✅ doc_2009482_02 - 정주연[AGREEMENT]: 1425826800000 → 1457497609000
#   ✅ doc_2009484_02 - 임현준[DRAFT]: 1451228400000 → 1451286689000
#   ✅ doc_2009484_02 - 박정균[APPROVAL]: 1451401200000 → 1451437896000
#   ✅ doc_2009484_02 - 정주연[AGREEMENT]: 1422716400000 → 1454295091000
#   ✅ doc_2009487_02 - 윤상호[DRAFT]: 1451314800000 → 1451354003000
#   ✅ doc_2009487_02 - 김성수[APPROVAL]: 1451314800000 → 1451357339000
#   ✅ doc_2009487_02 - 박상택[APPROVAL]: 1425826800000 → 1457497689000
#   ✅ doc_2009487_02 - 정주연[AGREEMENT]: 1425826800000 → 1457497609000
#   ✅ doc_2009485_02 - 이진규[DRAFT]: 1451314800000 → 1451347187000
#   ✅ doc_2009485_02 - 양기훈[APPROVAL]: 1451314800000 → 1451356170000
#   ✅ doc_2009485_02 - 김성수[APPROVAL]: 1451314800000 → 1451357359000
#   ✅ doc_2009485_02 - 김문철[APPROVAL]: 1451401200000 → 1451442684000
#   ✅ doc_2009486_02 - 함지연[DRAFT]: 1451487600000 → 1451519514000
#   ✅ doc_2009486_02 - 이진오[APPROVAL]: 1451487600000 → 1451521101000
#   ✅ doc_2009486_02 - 박상택[APPROVAL]: 1420297200000 → 1451870240000
#   ✅ doc_2009486_02 - CEO[APPROVAL]: 1420470000000 → 1452069282000
#   ✅ doc_2009486_02 - 김문철[AGREEMENT]: 1451487600000 → 1451541842000
#   ✅ doc_2009488_02 - 임현준[DRAFT]: 1451401200000 → 1451404573000
#   ✅ doc_2009488_02 - 박정균[APPROVAL]: 1451401200000 → 1451437929000
#   ✅ doc_2009488_02 - 박상택[APPROVAL]: 1425826800000 → 1457497689000
#   ✅ doc_2009488_02 - 정주연[AGREEMENT]: 1425826800000 → 1457497609000
#   ✅ doc_2009492_02 - 박정균[DRAFT]: 1451401200000 → 1451457906000
#   ✅ doc_2009492_02 - 박상택[APPROVAL]: 1425826800000 → 1457498124000
#   ✅ doc_2009492_02 - 정주연[AGREEMENT]: 1425826800000 → 1457498096000
#   ✅ doc_2009493_02 - 양기훈[DRAFT]: 1451401200000 → 1451459249000
#   ✅ doc_2009493_02 - 김성수[APPROVAL]: 1451401200000 → 1451463510000
#   ✅ doc_2009493_02 - 박상택[APPROVAL]: 1451487600000 → 1451526472000
#   ✅ doc_2009493_02 - 김문철[AGREEMENT]: 1451487600000 → 1451518594000
#   ✅ doc_2009494_02 - 정재웅[DRAFT]: 1451401200000 → 1451466486000
#   ✅ doc_2009494_02 - 윤상호[APPROVAL]: 1451401200000 → 1451467135000
#   ✅ doc_2009494_02 - 김성수[APPROVAL]: 1451401200000 → 1451467718000
#   ✅ doc_2009494_02 - 박상택[APPROVAL]: 1420297200000 → 1451890196000
#   ✅ doc_2009494_02 - CEO[APPROVAL]: 1420470000000 → 1452069260000
#   ✅ doc_2009494_02 - 김문철[APPROVAL]: 1420556400000 → 1452126324000
#   ✅ doc_2009495_02 - 박민영[DRAFT]: 1451401200000 → 1451481920000
#   ✅ doc_2009495_02 - 윤상호[APPROVAL]: 1451487600000 → 1451519469000
#   ✅ doc_2009495_02 - 김성수[APPROVAL]: 1451487600000 → 1451522091000
#   ✅ doc_2009495_02 - 박상택[APPROVAL]: 1420383600000 → 1451961695000
#   ✅ doc_2009495_02 - 김문철[AGREEMENT]: 1420383600000 → 1451955667000
#   ✅ doc_2009496_02 - 현광섭[DRAFT]: 1451487600000 → 1451532268000
#   ✅ doc_2009496_02 - 김성수[APPROVAL]: 1451487600000 → 1451548919000
#   ✅ doc_2009496_02 - 박상택[APPROVAL]: 1425826800000 → 1457498124000
#   ✅ doc_2009496_02 - 정주연[AGREEMENT]: 1425826800000 → 1457498096000
#
# ======================================================================
# 🎉 업데이트 완료!
# ======================================================================
# 📊 처리 결과:
#   - 전체 문서: 6587개
#   - sourceId 매치: 4117개
#   - 업데이트: 13952개 결재선
#   - 출력 파일: documents_2015_actTimefixed.cmds
# ======================================================================

# %%
# cmds 파일 업데이트 전용 스크립트 (sourceId 매칭 수정 버전)
import json
import re
from pathlib import Path

# ─────────────────────────────────────────────────────────
# 설정
# ─────────────────────────────────────────────────────────
NEED_CRAWLING_JSON = "need_crawling.json"
CRAWL_RESULT_JSON = "crawl_result_temp.json"
CMDS_INPUT = r"C:\Users\LEEJUHWAN\Desktop\애니파이브\전자결재\2020\documents_2020_01.cmds"
CMDS_OUTPUT = "documents_2020_actTimefixed.cmds"

# ─────────────────────────────────────────────────────────
# 유틸 함수
# ─────────────────────────────────────────────────────────
def extract_doc_number(source_id):
    """sourceId에서 문서 번호만 추출
    예: "doc_2009502_01" → "2009502"
    """
    # 숫자만 추출
    numbers = re.findall(r'\d+', source_id)
    if not numbers:
        return source_id
    
    # 가장 긴 숫자 반환 (문서번호가 제일 김)
    return max(numbers, key=len)

# ─────────────────────────────────────────────────────────
# 1) 데이터 로드
# ─────────────────────────────────────────────────────────
print("="*70)
print("📝 cmds 파일 업데이트 시작")
print("="*70)

# need_crawling.json 로드
try:
    with open(NEED_CRAWLING_JSON, 'r', encoding='utf-8') as f:
        need_crawling = json.load(f)
    print(f"✅ {NEED_CRAWLING_JSON} 로드: {len(need_crawling)}개 문서")
except Exception as e:
    print(f"❌ {NEED_CRAWLING_JSON} 읽기 실패: {e}")
    exit(1)

# crawl_result_temp.json 로드
try:
    with open(CRAWL_RESULT_JSON, 'r', encoding='utf-8') as f:
        crawl_results = json.load(f)
    print(f"✅ {CRAWL_RESULT_JSON} 로드: {len(crawl_results)}개 문서")
except Exception as e:
    print(f"❌ {CRAWL_RESULT_JSON} 읽기 실패: {e}")
    exit(1)

# cmds 파일 확인
if not Path(CMDS_INPUT).exists():
    print(f"❌ {CMDS_INPUT} 파일이 없습니다!")
    exit(1)

print(f"✅ {CMDS_INPUT} 파일 확인\n")

# ─────────────────────────────────────────────────────────
# 2) cmds 파일 업데이트
# ─────────────────────────────────────────────────────────
print("="*70)
print("🔄 업데이트 처리 중...")
print("="*70)

updated_count = 0
total_lines = 0
matched_docs = 0

with open(CMDS_INPUT, 'r', encoding='utf-8') as f_in, \
     open(CMDS_OUTPUT, 'w', encoding='utf-8') as f_out:
    
    for line in f_in:
        total_lines += 1
        line = line.strip()
        
        if not line.startswith("addDocument "):
            f_out.write(line + '\n')
            continue
        
        # JSON 파싱
        try:
            json_str = line[12:]  # "addDocument " 제거
            doc = json.loads(json_str)
            source_id_raw = doc.get("sourceId")  # "doc_2009502_01"
            
            # 📌 숫자만 추출 (매칭용)
            source_id_num = extract_doc_number(source_id_raw)  # "2009502"
            
            # 크롤링 결과에 있는지 확인
            if source_id_num not in crawl_results:
                f_out.write(line + '\n')
                continue
            
            # 🔍 매치됨!
            matched_docs += 1
            print(f"\n  🔍 매치된 문서: {source_id_raw} → {source_id_num} (line {total_lines})")
            
            # activities 업데이트
            crawled = crawl_results[source_id_num]
            need_update = need_crawling.get(source_id_num, [])
            activities = doc.get("activities", [])
            
            print(f"    - need_update 항목 수: {len(need_update)}")
            print(f"    - activities 항목 수: {len(activities)}")
            print(f"    - crawled 항목 수: {len(crawled)}")
            
            for update_info in need_update:
                target_index = update_info["index"]
                target_name = update_info["name"]
                target_action = update_info["action_type"]
                
                print(f"\n    🎯 업데이트 시도: index={target_index}, name={target_name}, action={target_action}")
                
                # activities에서 매칭되는 항목 찾기
                if target_index >= len(activities):
                    print(f"      ❌ index {target_index}가 범위 초과 (activities 길이: {len(activities)})")
                    continue
                
                activity = activities[target_index]
                
                # index, name, action_type 모두 확인
                activity_name = activity.get("name", "")
                activity_type = activity.get("type", "")
                
                print(f"      - activities[{target_index}]: name={activity_name}, type={activity_type}")
                print(f"      - 매칭 체크: '{target_name}' in '{activity_name}' = {target_name in activity_name}")
                print(f"      - 매칭 체크: '{target_action}' == '{activity_type}' = {target_action == activity_type}")
                
                if target_name in activity_name and target_action == activity_type:
                    print(f"      ✅ 첫 번째 매칭 성공!")
                    
                    # 크롤링 결과에서 해당 항목 찾기
                    found = False
                    for crawled_item in crawled:
                        print(f"        - crawled[{crawled_item['index']}]: name={crawled_item['name']}, action={crawled_item['action_type']}")
                        
                        if (crawled_item["index"] == target_index and 
                            crawled_item["name"] in activity_name and
                            crawled_item["action_type"] == activity_type):
                            
                            # actionDate 업데이트
                            old_date = activity.get("actionDate")
                            activity["actionDate"] = crawled_item["timestamp"]
                            print(f"        ✅ 업데이트: {old_date} → {crawled_item['timestamp']}")
                            updated_count += 1
                            found = True
                            break
                    
                    if not found:
                        print(f"      ⚠️ crawled에서 매칭 항목 못 찾음")
                else:
                    print(f"      ❌ 첫 번째 매칭 실패")
            
            # ⚠️ 중요: 원본 sourceId는 그대로 유지!
            # doc["sourceId"]는 여전히 "doc_2009502_01"
            updated_line = "addDocument " + json.dumps(doc, ensure_ascii=False, separators=(',', ':'))
            f_out.write(updated_line + '\n')
            
        except Exception as e:
            print(f"  ⚠️ 파싱 에러 (line {total_lines}): {e}")
            f_out.write(line + '\n')

print("\n" + "="*70)
print("🎉 업데이트 완료!")
print("="*70)
print(f"📊 처리 결과:")
print(f"  - 전체 문서: {total_lines}개")
print(f"  - sourceId 매치: {matched_docs}개")
print(f"  - 업데이트: {updated_count}개 결재선")
print(f"  - 출력 파일: {CMDS_OUTPUT}")
print("="*70)
# Out:
# ======================================================================
# 📝 cmds 파일 업데이트 시작
# ======================================================================
# ✅ need_crawling.json 로드: 171개 문서
# ✅ crawl_result_temp.json 로드: 171개 문서
# ✅ C:\Users\LEEJUHWAN\Desktop\애니파이브\전자결재\2020\documents_2020_01.cmds 파일 확인
#
# ======================================================================
# 🔄 업데이트 처리 중...
# ======================================================================
#
#   🔍 매치된 문서: doc_2009497_01 → 2009497 (line 1)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=김은미, action=DRAFT
#       - activities[0]: name=김은미, type=DRAFT
#       - 매칭 체크: '김은미' in '김은미' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김은미, action=DRAFT
#         ✅ 업데이트: 1451833200000 → 1451876977000
#
#     🎯 업데이트 시도: index=1, name=김태정, action=APPROVAL
#       - activities[1]: name=김태정, type=APPROVAL
#       - 매칭 체크: '김태정' in '김태정' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김은미, action=DRAFT
#         - crawled[1]: name=김태정, action=APPROVAL
#         ✅ 업데이트: 1451833200000 → 1451900894000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=APPROVAL
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009500_01 → 2009500 (line 3)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=윤상호, action=DRAFT
#       - activities[0]: name=윤상호, type=DRAFT
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         ✅ 업데이트: 1451833200000 → 1451892021000
#
#     🎯 업데이트 시도: index=1, name=김성수, action=APPROVAL
#       - activities[1]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         - crawled[1]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1452092400000 → 1452123245000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009499_01 → 2009499 (line 5)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=김은미, action=DRAFT
#       - activities[0]: name=김은미, type=DRAFT
#       - 매칭 체크: '김은미' in '김은미' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김은미, action=DRAFT
#         ✅ 업데이트: 1451833200000 → 1451878393000
#
#     🎯 업데이트 시도: index=1, name=김태정, action=APPROVAL
#       - activities[1]: name=김태정, type=APPROVAL
#       - 매칭 체크: '김태정' in '김태정' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김은미, action=DRAFT
#         - crawled[1]: name=김태정, action=APPROVAL
#         ✅ 업데이트: 1452092400000 → 1452124249000
#
#     🎯 업데이트 시도: index=8, name=김문철, action=APPROVAL
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009498_01 → 2009498 (line 7)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=김은미, action=DRAFT
#       - activities[0]: name=김은미, type=DRAFT
#       - 매칭 체크: '김은미' in '김은미' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김은미, action=DRAFT
#         ✅ 업데이트: 1451833200000 → 1451877554000
#
#     🎯 업데이트 시도: index=1, name=김태정, action=APPROVAL
#       - activities[1]: name=김태정, type=APPROVAL
#       - 매칭 체크: '김태정' in '김태정' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김은미, action=DRAFT
#         - crawled[1]: name=김태정, action=APPROVAL
#         ✅ 업데이트: 1451833200000 → 1451900945000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=APPROVAL
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009507_01 → 2009507 (line 8)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=원진희, action=DRAFT
#       - activities[0]: name=원진희, type=DRAFT
#       - 매칭 체크: '원진희' in '원진희' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=원진희, action=DRAFT
#         ✅ 업데이트: 1452178800000 → 1452253436000
#
#     🎯 업데이트 시도: index=1, name=양기훈, action=APPROVAL
#       - activities[1]: name=양기훈, type=APPROVAL
#       - 매칭 체크: '양기훈' in '양기훈' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=원진희, action=DRAFT
#         - crawled[1]: name=양기훈, action=APPROVAL
#         ✅ 업데이트: 1452178800000 → 1452256267000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009508_01 → 2009508 (line 11)
#     - need_update 항목 수: 2
#     - activities 항목 수: 2
#     - crawled 항목 수: 2
#
#     🎯 업데이트 시도: index=0, name=현광섭, action=DRAFT
#       - activities[0]: name=현광섭, type=DRAFT
#       - 매칭 체크: '현광섭' in '현광섭' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=현광섭, action=DRAFT
#         ✅ 업데이트: 1451919600000 → 1451984076000
#
#     🎯 업데이트 시도: index=1, name=정주연, action=APPROVAL
#       - activities[1]: name=정주연, type=APPROVAL
#       - 매칭 체크: '정주연' in '정주연' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=현광섭, action=DRAFT
#         - crawled[1]: name=정주연, action=APPROVAL
#         ✅ 업데이트: 1454252400000 → 1454300605000
#
#   🔍 매치된 문서: doc_2009506_01 → 2009506 (line 12)
#     - need_update 항목 수: 2
#     - activities 항목 수: 2
#     - crawled 항목 수: 2
#
#     🎯 업데이트 시도: index=0, name=편영수, action=DRAFT
#       - activities[0]: name=편영수, type=DRAFT
#       - 매칭 체크: '편영수' in '편영수' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         ✅ 업데이트: 1451919600000 → 1451959833000
#
#     🎯 업데이트 시도: index=1, name=김문철, action=APPROVAL
#       - activities[1]: name=김문철, type=APPROVAL
#       - 매칭 체크: '김문철' in '김문철' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         ✅ 업데이트: 1452006000000 → 1452039883000
#
#   🔍 매치된 문서: doc_2009509_01 → 2009509 (line 13)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=김승범, action=DRAFT
#       - activities[0]: name=김승범, type=DRAFT
#       - 매칭 체크: '김승범' in '김승범' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김승범, action=DRAFT
#         ✅ 업데이트: 1452006000000 → 1452054501000
#
#     🎯 업데이트 시도: index=1, name=김하응, action=APPROVAL
#       - activities[1]: name=김하응, type=APPROVAL
#       - 매칭 체크: '김하응' in '김하응' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김승범, action=DRAFT
#         - crawled[1]: name=김하응, action=APPROVAL
#         ✅ 업데이트: 1452178800000 → 1452217854000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009510_01 → 2009510 (line 14)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=양기훈, action=DRAFT
#       - activities[0]: name=양기훈, type=DRAFT
#       - 매칭 체크: '양기훈' in '양기훈' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=양기훈, action=DRAFT
#         ✅ 업데이트: 1452006000000 → 1452054876000
#
#     🎯 업데이트 시도: index=1, name=김성수, action=APPROVAL
#       - activities[1]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=양기훈, action=DRAFT
#         - crawled[1]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1452092400000 → 1452123204000
#
#     🎯 업데이트 시도: index=2, name=박상택, action=APPROVAL
#       - activities[2]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=양기훈, action=DRAFT
#         - crawled[1]: name=김성수, action=APPROVAL
#         - crawled[2]: name=김문철, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009511_01 → 2009511 (line 15)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=이형균, action=DRAFT
#       - activities[0]: name=이형균, type=DRAFT
#       - 매칭 체크: '이형균' in '이형균' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=이형균, action=DRAFT
#         ✅ 업데이트: 1452092400000 → 1452119152000
#
#     🎯 업데이트 시도: index=1, name=박상택, action=APPROVAL
#       - activities[1]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=이형균, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=박상택, action=APPROVAL
#         - crawled[3]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=CEO, action=APPROVAL
#       - activities[2]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=이형균, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=박상택, action=APPROVAL
#         - crawled[3]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009512_01 → 2009512 (line 16)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=전수정, action=DRAFT
#       - activities[0]: name=전수정, type=DRAFT
#       - 매칭 체크: '전수정' in '전수정' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=전수정, action=DRAFT
#         ✅ 업데이트: 1452092400000 → 1452127906000
#
#     🎯 업데이트 시도: index=1, name=윤상호, action=APPROVAL
#       - activities[1]: name=윤상호, type=APPROVAL
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=전수정, action=DRAFT
#         - crawled[1]: name=윤상호, action=APPROVAL
#         ✅ 업데이트: 1452092400000 → 1452128508000
#
#     🎯 업데이트 시도: index=2, name=김성수, action=APPROVAL
#       - activities[2]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=전수정, action=DRAFT
#         - crawled[1]: name=윤상호, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1452092400000 → 1452128629000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009513_01 → 2009513 (line 17)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=김문철, action=DRAFT
#       - activities[0]: name=김문철, type=DRAFT
#       - 매칭 체크: '김문철' in '김문철' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김문철, action=DRAFT
#         ✅ 업데이트: 1452178800000 → 1452225800000
#
#     🎯 업데이트 시도: index=1, name=박상택, action=APPROVAL
#       - activities[1]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김문철, action=DRAFT
#         - crawled[1]: name=박상택, action=APPROVAL
#         ✅ 업데이트: 1452178800000 → 1452226105000
#
#     🎯 업데이트 시도: index=2, name=CEO, action=APPROVAL
#       - activities[2]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김문철, action=DRAFT
#         - crawled[1]: name=박상택, action=APPROVAL
#         - crawled[2]: name=CEO, action=APPROVAL
#         ✅ 업데이트: 1452265200000 → 1452292179000
#
#   🔍 매치된 문서: doc_2009514_01 → 2009514 (line 18)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=김문철, action=DRAFT
#       - activities[0]: name=김문철, type=DRAFT
#       - 매칭 체크: '김문철' in '김문철' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김문철, action=DRAFT
#         ✅ 업데이트: 1452178800000 → 1452227822000
#
#     🎯 업데이트 시도: index=1, name=박상택, action=APPROVAL
#       - activities[1]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김문철, action=DRAFT
#         - crawled[1]: name=박상택, action=APPROVAL
#         ✅ 업데이트: 1452178800000 → 1452234711000
#
#     🎯 업데이트 시도: index=2, name=CEO, action=APPROVAL
#       - activities[2]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김문철, action=DRAFT
#         - crawled[1]: name=박상택, action=APPROVAL
#         - crawled[2]: name=CEO, action=APPROVAL
#         ✅ 업데이트: 1452265200000 → 1452292213000
#
#   🔍 매치된 문서: doc_2009515_01 → 2009515 (line 20)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=이송연, action=DRAFT
#       - activities[0]: name=이송연, type=DRAFT
#       - 매칭 체크: '이송연' in '이송연' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=이송연, action=DRAFT
#         ✅ 업데이트: 1452178800000 → 1452239232000
#
#     🎯 업데이트 시도: index=1, name=양기훈, action=APPROVAL
#       - activities[1]: name=양기훈, type=APPROVAL
#       - 매칭 체크: '양기훈' in '양기훈' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=이송연, action=DRAFT
#         - crawled[1]: name=양기훈, action=APPROVAL
#         ✅ 업데이트: 1452178800000 → 1452242182000
#
#     🎯 업데이트 시도: index=2, name=김성수, action=APPROVAL
#       - activities[2]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=이송연, action=DRAFT
#         - crawled[1]: name=양기훈, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1452178800000 → 1452245894000
#
#   🔍 매치된 문서: doc_2009519_01 → 2009519 (line 21)
#     - need_update 항목 수: 5
#     - activities 항목 수: 5
#     - crawled 항목 수: 5
#
#     🎯 업데이트 시도: index=0, name=권민선, action=DRAFT
#       - activities[0]: name=권민선, type=DRAFT
#       - 매칭 체크: '권민선' in '권민선' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         ✅ 업데이트: 1452438000000 → 1452496495000
#
#     🎯 업데이트 시도: index=1, name=박상택, action=APPROVAL
#       - activities[1]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=정주연, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#         - crawled[4]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=CEO, action=APPROVAL
#       - activities[2]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=정주연, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#         - crawled[4]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 5)
#
#     🎯 업데이트 시도: index=9, name=김성수, action=AGREEMENT
#       ❌ index 9가 범위 초과 (activities 길이: 5)
#
#   🔍 매치된 문서: doc_2009518_01 → 2009518 (line 22)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=강정례, action=DRAFT
#       - activities[0]: name=강정례, type=DRAFT
#       - 매칭 체크: '강정례' in '강정례' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         ✅ 업데이트: 1452438000000 → 1452477562000
#
#     🎯 업데이트 시도: index=1, name=윤상호, action=APPROVAL
#       - activities[1]: name=윤상호, type=APPROVAL
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         - crawled[1]: name=윤상호, action=APPROVAL
#         ✅ 업데이트: 1452438000000 → 1452492631000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009517_01 → 2009517 (line 23)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=강정례, action=DRAFT
#       - activities[0]: name=강정례, type=DRAFT
#       - 매칭 체크: '강정례' in '강정례' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         ✅ 업데이트: 1452438000000 → 1452477277000
#
#     🎯 업데이트 시도: index=1, name=윤상호, action=APPROVAL
#       - activities[1]: name=윤상호, type=APPROVAL
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         - crawled[1]: name=윤상호, action=APPROVAL
#         ✅ 업데이트: 1452438000000 → 1452492572000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009523_01 → 2009523 (line 26)
#     - need_update 항목 수: 6
#     - activities 항목 수: 6
#     - crawled 항목 수: 6
#
#     🎯 업데이트 시도: index=0, name=김형환, action=DRAFT
#       - activities[0]: name=김형환, type=DRAFT
#       - 매칭 체크: '김형환' in '김형환' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김형환, action=DRAFT
#         ✅ 업데이트: 1452524400000 → 1452586128000
#
#     🎯 업데이트 시도: index=1, name=양기훈, action=APPROVAL
#       - activities[1]: name=양기훈, type=APPROVAL
#       - 매칭 체크: '양기훈' in '양기훈' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김형환, action=DRAFT
#         - crawled[1]: name=양기훈, action=APPROVAL
#         ✅ 업데이트: 1452524400000 → 1452591870000
#
#     🎯 업데이트 시도: index=2, name=김성수, action=APPROVAL
#       - activities[2]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김형환, action=DRAFT
#         - crawled[1]: name=양기훈, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1452610800000 → 1452641140000
#
#     🎯 업데이트 시도: index=3, name=박상택, action=APPROVAL
#       - activities[3]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김형환, action=DRAFT
#         - crawled[1]: name=양기훈, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=김문철, action=APPROVAL
#         - crawled[4]: name=박상택, action=APPROVAL
#         - crawled[5]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=4, name=CEO, action=APPROVAL
#       - activities[4]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김형환, action=DRAFT
#         - crawled[1]: name=양기훈, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=김문철, action=APPROVAL
#         - crawled[4]: name=박상택, action=APPROVAL
#         - crawled[5]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김문철, action=APPROVAL
#       ❌ index 8가 범위 초과 (activities 길이: 6)
#
#   🔍 매치된 문서: doc_2009524_01 → 2009524 (line 27)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=이형균, action=DRAFT
#       - activities[0]: name=이형균, type=DRAFT
#       - 매칭 체크: '이형균' in '이형균' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=이형균, action=DRAFT
#         ✅ 업데이트: 1452524400000 → 1452606105000
#
#     🎯 업데이트 시도: index=1, name=김태정, action=APPROVAL
#       - activities[1]: name=김태정, type=APPROVAL
#       - 매칭 체크: '김태정' in '김태정' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=이형균, action=DRAFT
#         - crawled[1]: name=김태정, action=APPROVAL
#         ✅ 업데이트: 1452610800000 → 1452651526000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009525_01 → 2009525 (line 29)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=강정례, action=DRAFT
#       - activities[0]: name=강정례, type=DRAFT
#       - 매칭 체크: '강정례' in '강정례' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         ✅ 업데이트: 1452610800000 → 1452651314000
#
#     🎯 업데이트 시도: index=1, name=윤상호, action=APPROVAL
#       - activities[1]: name=윤상호, type=APPROVAL
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         - crawled[1]: name=윤상호, action=APPROVAL
#         ✅ 업데이트: 1452610800000 → 1452667315000
#
#     🎯 업데이트 시도: index=2, name=김성수, action=APPROVAL
#       - activities[2]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         - crawled[1]: name=윤상호, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1452610800000 → 1452676667000
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009526_01 → 2009526 (line 30)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=장광선, action=DRAFT
#       - activities[0]: name=장광선, type=DRAFT
#       - 매칭 체크: '장광선' in '장광선' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=장광선, action=DRAFT
#         ✅ 업데이트: 1452610800000 → 1452672709000
#
#     🎯 업데이트 시도: index=1, name=양기훈, action=APPROVAL
#       - activities[1]: name=양기훈, type=APPROVAL
#       - 매칭 체크: '양기훈' in '양기훈' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=장광선, action=DRAFT
#         - crawled[1]: name=양기훈, action=APPROVAL
#         ✅ 업데이트: 1452697200000 → 1452739741000
#
#     🎯 업데이트 시도: index=2, name=김성수, action=APPROVAL
#       - activities[2]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=장광선, action=DRAFT
#         - crawled[1]: name=양기훈, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1452697200000 → 1452745057000
#
#     🎯 업데이트 시도: index=8, name=김문철, action=APPROVAL
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009536_01 → 2009536 (line 31)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=김문철, action=DRAFT
#       - activities[0]: name=김문철, type=DRAFT
#       - 매칭 체크: '김문철' in '김문철' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김문철, action=DRAFT
#         ✅ 업데이트: 1453215600000 → 1453270635000
#
#     🎯 업데이트 시도: index=1, name=박상택, action=APPROVAL
#       - activities[1]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김문철, action=DRAFT
#         - crawled[1]: name=정주연, action=APPROVAL
#         - crawled[2]: name=박상택, action=APPROVAL
#         - crawled[3]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=CEO, action=APPROVAL
#       - activities[2]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김문철, action=DRAFT
#         - crawled[1]: name=정주연, action=APPROVAL
#         - crawled[2]: name=박상택, action=APPROVAL
#         - crawled[3]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009531_01 → 2009531 (line 32)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=권민선, action=DRAFT
#       - activities[0]: name=권민선, type=DRAFT
#       - 매칭 체크: '권민선' in '권민선' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         ✅ 업데이트: 1452697200000 → 1452756214000
#
#     🎯 업데이트 시도: index=1, name=김성수, action=APPROVAL
#       - activities[1]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=박상택, action=APPROVAL
#       - activities[2]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009530_01 → 2009530 (line 33)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=권민선, action=DRAFT
#       - activities[0]: name=권민선, type=DRAFT
#       - 매칭 체크: '권민선' in '권민선' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         ✅ 업데이트: 1452697200000 → 1452755319000
#
#     🎯 업데이트 시도: index=1, name=김성수, action=APPROVAL
#       - activities[1]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=박상택, action=APPROVAL
#       - activities[2]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009532_01 → 2009532 (line 34)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=권민선, action=DRAFT
#       - activities[0]: name=권민선, type=DRAFT
#       - 매칭 체크: '권민선' in '권민선' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         ✅ 업데이트: 1452697200000 → 1452756686000
#
#     🎯 업데이트 시도: index=1, name=김성수, action=APPROVAL
#       - activities[1]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=박상택, action=APPROVAL
#       - activities[2]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009533_01 → 2009533 (line 35)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=권민선, action=DRAFT
#       - activities[0]: name=권민선, type=DRAFT
#       - 매칭 체크: '권민선' in '권민선' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         ✅ 업데이트: 1452697200000 → 1452757087000
#
#     🎯 업데이트 시도: index=1, name=김성수, action=APPROVAL
#       - activities[1]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=박상택, action=APPROVAL
#       - activities[2]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009527_01 → 2009527 (line 36)
#     - need_update 항목 수: 5
#     - activities 항목 수: 5
#     - crawled 항목 수: 5
#
#     🎯 업데이트 시도: index=0, name=임현준, action=DRAFT
#       - activities[0]: name=임현준, type=DRAFT
#       - 매칭 체크: '임현준' in '임현준' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=임현준, action=DRAFT
#         ✅ 업데이트: 1452697200000 → 1452731470000
#
#     🎯 업데이트 시도: index=1, name=박정균, action=APPROVAL
#       - activities[1]: name=박정균, type=APPROVAL
#       - 매칭 체크: '박정균' in '박정균' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=임현준, action=DRAFT
#         - crawled[1]: name=편영수, action=APPROVAL
#         - crawled[2]: name=박정균, action=APPROVAL
#         - crawled[3]: name=김문철, action=APPROVAL
#         - crawled[4]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=박상택, action=APPROVAL
#       - activities[2]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=임현준, action=DRAFT
#         - crawled[1]: name=편영수, action=APPROVAL
#         - crawled[2]: name=박정균, action=APPROVAL
#         - crawled[3]: name=김문철, action=APPROVAL
#         - crawled[4]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=편영수, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 5)
#
#     🎯 업데이트 시도: index=9, name=김문철, action=AGREEMENT
#       ❌ index 9가 범위 초과 (activities 길이: 5)
#
#   🔍 매치된 문서: doc_2009529_01 → 2009529 (line 37)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=원진희, action=DRAFT
#       - activities[0]: name=원진희, type=DRAFT
#       - 매칭 체크: '원진희' in '원진희' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=원진희, action=DRAFT
#         ✅ 업데이트: 1453647600000 → 1453729201000
#
#     🎯 업데이트 시도: index=1, name=박상택, action=APPROVAL
#       - activities[1]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=원진희, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=박상택, action=APPROVAL
#         - crawled[3]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=CEO, action=APPROVAL
#       - activities[2]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=원진희, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=박상택, action=APPROVAL
#         - crawled[3]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009535_01 → 2009535 (line 39)
#     - need_update 항목 수: 6
#     - activities 항목 수: 6
#     - crawled 항목 수: 6
#
#     🎯 업데이트 시도: index=0, name=강정례, action=DRAFT
#       - activities[0]: name=강정례, type=DRAFT
#       - 매칭 체크: '강정례' in '강정례' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         ✅ 업데이트: 1452697200000 → 1452758115000
#
#     🎯 업데이트 시도: index=1, name=윤상호, action=APPROVAL
#       - activities[1]: name=윤상호, type=APPROVAL
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         - crawled[1]: name=윤상호, action=APPROVAL
#         ✅ 업데이트: 1452697200000 → 1452758269000
#
#     🎯 업데이트 시도: index=2, name=김성수, action=APPROVAL
#       - activities[2]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         - crawled[1]: name=윤상호, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1452697200000 → 1452764831000
#
#     🎯 업데이트 시도: index=3, name=박상택, action=APPROVAL
#       - activities[3]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         - crawled[1]: name=윤상호, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#         ✅ 업데이트: 1453129200000 → 1453192462000
#
#     🎯 업데이트 시도: index=4, name=CEO, action=APPROVAL
#       - activities[4]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=강정례, action=DRAFT
#         - crawled[1]: name=윤상호, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#         - crawled[4]: name=CEO, action=APPROVAL
#         ✅ 업데이트: 1453215600000 → 1453246815000
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 6)
#
#   🔍 매치된 문서: doc_2009528_01 → 2009528 (line 40)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=편영수, action=DRAFT
#       - activities[0]: name=편영수, type=DRAFT
#       - 매칭 체크: '편영수' in '편영수' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         ✅ 업데이트: 1452697200000 → 1452736667000
#
#     🎯 업데이트 시도: index=1, name=박정균, action=APPROVAL
#       - activities[1]: name=박정균, type=APPROVAL
#       - 매칭 체크: '박정균' in '박정균' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         - crawled[1]: name=박정균, action=APPROVAL
#         ✅ 업데이트: 1452783600000 → 1452820889000
#
#     🎯 업데이트 시도: index=2, name=박상택, action=APPROVAL
#       - activities[2]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         - crawled[1]: name=박정균, action=APPROVAL
#         - crawled[2]: name=박상택, action=APPROVAL
#         ✅ 업데이트: 1452783600000 → 1452837006000
#
#     🎯 업데이트 시도: index=3, name=CEO, action=APPROVAL
#       - activities[3]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         - crawled[1]: name=박정균, action=APPROVAL
#         - crawled[2]: name=박상택, action=APPROVAL
#         - crawled[3]: name=CEO, action=APPROVAL
#         ✅ 업데이트: 1453215600000 → 1453246882000
#
#   🔍 매치된 문서: doc_2009538_01 → 2009538 (line 42)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=이성현, action=DRAFT
#       - activities[0]: name=이성현, type=DRAFT
#       - 매칭 체크: '이성현' in '이성현' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=이성현, action=DRAFT
#         ✅ 업데이트: 1452956400000 → 1453038596000
#
#     🎯 업데이트 시도: index=1, name=현광섭, action=APPROVAL
#       - activities[1]: name=현광섭, type=APPROVAL
#       - 매칭 체크: '현광섭' in '현광섭' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=이성현, action=DRAFT
#         - crawled[1]: name=현광섭, action=APPROVAL
#         ✅ 업데이트: 1453042800000 → 1453077725000
#
#     🎯 업데이트 시도: index=2, name=김성수, action=APPROVAL
#       - activities[2]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=이성현, action=DRAFT
#         - crawled[1]: name=현광섭, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1453042800000 → 1453081266000
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009544_01 → 2009544 (line 43)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=윤상호, action=DRAFT
#       - activities[0]: name=윤상호, type=DRAFT
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         ✅ 업데이트: 1453042800000 → 1453108573000
#
#     🎯 업데이트 시도: index=1, name=김성수, action=APPROVAL
#       - activities[1]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         - crawled[1]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1453042800000 → 1453109927000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009540_01 → 2009540 (line 44)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=권민선, action=DRAFT
#       - activities[0]: name=권민선, type=DRAFT
#       - 매칭 체크: '권민선' in '권민선' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         ✅ 업데이트: 1453042800000 → 1453092051000
#
#     🎯 업데이트 시도: index=1, name=김성수, action=APPROVAL
#       - activities[1]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=박상택, action=APPROVAL
#       - activities[2]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009543_01 → 2009543 (line 47)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=윤상호, action=DRAFT
#       - activities[0]: name=윤상호, type=DRAFT
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         ✅ 업데이트: 1453042800000 → 1453108127000
#
#     🎯 업데이트 시도: index=1, name=임현준, action=APPROVAL
#       - activities[1]: name=임현준, type=APPROVAL
#       - 매칭 체크: '임현준' in '임현준' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         - crawled[1]: name=임현준, action=APPROVAL
#         ✅ 업데이트: 1453042800000 → 1453108189000
#
#     🎯 업데이트 시도: index=2, name=김성수, action=APPROVAL
#       - activities[2]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         - crawled[1]: name=임현준, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1453129200000 → 1453159738000
#
#     🎯 업데이트 시도: index=3, name=박상택, action=APPROVAL
#       - activities[3]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         - crawled[1]: name=임현준, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#         ✅ 업데이트: 1453129200000 → 1453192184000
#
#   🔍 매치된 문서: doc_2009542_01 → 2009542 (line 48)
#     - need_update 항목 수: 2
#     - activities 항목 수: 2
#     - crawled 항목 수: 2
#
#     🎯 업데이트 시도: index=0, name=김광희, action=DRAFT
#       - activities[0]: name=김광희, type=DRAFT
#       - 매칭 체크: '김광희' in '김광희' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김광희, action=DRAFT
#         ✅ 업데이트: 1453042800000 → 1453098644000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 2)
#
#   🔍 매치된 문서: doc_2009545_01 → 2009545 (line 50)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=소성현, action=DRAFT
#       - activities[0]: name=소성현, type=DRAFT
#       - 매칭 체크: '소성현' in '소성현' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=소성현, action=DRAFT
#         ✅ 업데이트: 1453129200000 → 1453165415000
#
#     🎯 업데이트 시도: index=1, name=양기훈, action=APPROVAL
#       - activities[1]: name=양기훈, type=APPROVAL
#       - 매칭 체크: '양기훈' in '양기훈' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=소성현, action=DRAFT
#         - crawled[1]: name=양기훈, action=APPROVAL
#         ✅ 업데이트: 1453129200000 → 1453171147000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=APPROVAL
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009547_01 → 2009547 (line 51)
#     - need_update 항목 수: 2
#     - activities 항목 수: 2
#     - crawled 항목 수: 2
#
#     🎯 업데이트 시도: index=0, name=유성숙, action=DRAFT
#       - activities[0]: name=유성숙, type=DRAFT
#       - 매칭 체크: '유성숙' in '유성숙' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=유성숙, action=DRAFT
#         ✅ 업데이트: 1453215600000 → 1453263032000
#
#     🎯 업데이트 시도: index=1, name=김성수, action=APPROVAL
#       - activities[1]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=유성숙, action=DRAFT
#         - crawled[1]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1453215600000 → 1453273125000
#
#   🔍 매치된 문서: doc_2009548_01 → 2009548 (line 53)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=권민선, action=DRAFT
#       - activities[0]: name=권민선, type=DRAFT
#       - 매칭 체크: '권민선' in '권민선' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         ✅ 업데이트: 1453302000000 → 1453352853000
#
#     🎯 업데이트 시도: index=1, name=김성수, action=APPROVAL
#       - activities[1]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=박상택, action=APPROVAL
#       - activities[2]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김문철, action=APPROVAL
#         - crawled[2]: name=김성수, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009550_01 → 2009550 (line 54)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=권민선, action=DRAFT
#       - activities[0]: name=권민선, type=DRAFT
#       - 매칭 체크: '권민선' in '권민선' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         ✅ 업데이트: 1453302000000 → 1453355183000
#
#     🎯 업데이트 시도: index=1, name=김성수, action=APPROVAL
#       - activities[1]: name=김성수, type=APPROVAL
#       - 매칭 체크: '김성수' in '김성수' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김성수, action=APPROVAL
#         ✅ 업데이트: 1453302000000 → 1453355603000
#
#     🎯 업데이트 시도: index=8, name=정주연, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009552_01 → 2009552 (line 55)
#     - need_update 항목 수: 5
#     - activities 항목 수: 5
#     - crawled 항목 수: 5
#
#     🎯 업데이트 시도: index=0, name=편영수, action=DRAFT
#       - activities[0]: name=편영수, type=DRAFT
#       - 매칭 체크: '편영수' in '편영수' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         ✅ 업데이트: 1453302000000 → 1453360196000
#
#     🎯 업데이트 시도: index=1, name=박정균, action=APPROVAL
#       - activities[1]: name=박정균, type=APPROVAL
#       - 매칭 체크: '박정균' in '박정균' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         - crawled[1]: name=박정균, action=APPROVAL
#         ✅ 업데이트: 1453388400000 → 1453449171000
#
#     🎯 업데이트 시도: index=2, name=박상택, action=APPROVAL
#       - activities[2]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         - crawled[1]: name=박정균, action=APPROVAL
#         - crawled[2]: name=김문철, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#         - crawled[4]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=3, name=CEO, action=APPROVAL
#       - activities[3]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         - crawled[1]: name=박정균, action=APPROVAL
#         - crawled[2]: name=김문철, action=APPROVAL
#         - crawled[3]: name=박상택, action=APPROVAL
#         - crawled[4]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김문철, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 5)
#
#   🔍 매치된 문서: doc_2009553_01 → 2009553 (line 56)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=양기훈, action=DRAFT
#       - activities[0]: name=양기훈, type=DRAFT
#       - 매칭 체크: '양기훈' in '양기훈' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=양기훈, action=DRAFT
#         ✅ 업데이트: 1453302000000 → 1453360922000
#
#     🎯 업데이트 시도: index=1, name=박정균, action=APPROVAL
#       - activities[1]: name=박정균, type=APPROVAL
#       - 매칭 체크: '박정균' in '박정균' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=양기훈, action=DRAFT
#         - crawled[1]: name=박정균, action=APPROVAL
#         ✅ 업데이트: 1453388400000 → 1453449679000
#
#     🎯 업데이트 시도: index=2, name=박상택, action=APPROVAL
# ...
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김동력, action=APPROVAL
#         ✅ 업데이트: 1458226800000 → 1458254729000
#
#   🔍 매치된 문서: doc_2009737_01 → 2009737 (line 241)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=함종완, action=DRAFT
#       - activities[0]: name=함종완, type=DRAFT
#       - 매칭 체크: '함종완' in '함종완' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=함종완, action=DRAFT
#         ✅ 업데이트: 1458140400000 → 1458192555000
#
#     🎯 업데이트 시도: index=1, name=이형균, action=APPROVAL
#       - activities[1]: name=이형균, type=APPROVAL
#       - 매칭 체크: '이형균' in '이형균' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=함종완, action=DRAFT
#         - crawled[1]: name=이형균, action=APPROVAL
#         ✅ 업데이트: 1458140400000 → 1458204608000
#
#     🎯 업데이트 시도: index=2, name=장성봉, action=APPROVAL
#       - activities[2]: name=장성봉, type=APPROVAL
#       - 매칭 체크: '장성봉' in '장성봉' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=함종완, action=DRAFT
#         - crawled[1]: name=이형균, action=APPROVAL
#         - crawled[2]: name=장성봉, action=APPROVAL
#         ✅ 업데이트: 1458226800000 → 1458258920000
#
#     🎯 업데이트 시도: index=8, name=권민선, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009739_01 → 2009739 (line 242)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=김민서, action=DRAFT
#       - activities[0]: name=김민서, type=DRAFT
#       - 매칭 체크: '김민서' in '김민서' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김민서, action=DRAFT
#         ✅ 업데이트: 1458226800000 → 1458283285000
#
#     🎯 업데이트 시도: index=1, name=김동력, action=APPROVAL
#       - activities[1]: name=김동력, type=APPROVAL
#       - 매칭 체크: '김동력' in '김동력' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김민서, action=DRAFT
#         - crawled[1]: name=김재원, action=APPROVAL
#         - crawled[2]: name=김동력, action=APPROVAL
#         - crawled[3]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=2, name=CEO, action=APPROVAL
#       - activities[2]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김민서, action=DRAFT
#         - crawled[1]: name=김재원, action=APPROVAL
#         - crawled[2]: name=김동력, action=APPROVAL
#         - crawled[3]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김재원, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009738_01 → 2009738 (line 244)
#     - need_update 항목 수: 2
#     - activities 항목 수: 2
#     - crawled 항목 수: 2
#
#     🎯 업데이트 시도: index=0, name=윤상호, action=DRAFT
#       - activities[0]: name=윤상호, type=DRAFT
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         ✅ 업데이트: 1458226800000 → 1458264044000
#
#     🎯 업데이트 시도: index=1, name=박상택, action=APPROVAL
#       - activities[1]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         - crawled[1]: name=박상택, action=APPROVAL
#         ✅ 업데이트: 1458226800000 → 1458272914000
#
#   🔍 매치된 문서: doc_2009741_01 → 2009741 (line 248)
#     - need_update 항목 수: 5
#     - activities 항목 수: 5
#     - crawled 항목 수: 5
#
#     🎯 업데이트 시도: index=0, name=유성숙, action=DRAFT
#       - activities[0]: name=유성숙, type=DRAFT
#       - 매칭 체크: '유성숙' in '유성숙' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=유성숙, action=DRAFT
#         ✅ 업데이트: 1458486000000 → 1458521730000
#
#     🎯 업데이트 시도: index=1, name=박정균, action=APPROVAL
#       - activities[1]: name=박정균, type=APPROVAL
#       - 매칭 체크: '박정균' in '박정균' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=유성숙, action=DRAFT
#         - crawled[1]: name=박정균, action=APPROVAL
#         ✅ 업데이트: 1458486000000 → 1458542001000
#
#     🎯 업데이트 시도: index=2, name=CEO, action=APPROVAL
#       - activities[2]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=유성숙, action=DRAFT
#         - crawled[1]: name=박정균, action=APPROVAL
#         - crawled[2]: name=김민서, action=APPROVAL
#         - crawled[3]: name=김동력, action=APPROVAL
#         - crawled[4]: name=CEO, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김민서, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 5)
#
#     🎯 업데이트 시도: index=9, name=김동력, action=AGREEMENT
#       ❌ index 9가 범위 초과 (activities 길이: 5)
#
#   🔍 매치된 문서: doc_2009742_01 → 2009742 (line 249)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=임성진, action=DRAFT
#       - activities[0]: name=임성진, type=DRAFT
#       - 매칭 체크: '임성진' in '임성진' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=임성진, action=DRAFT
#         ✅ 업데이트: 1458486000000 → 1458524938000
#
#     🎯 업데이트 시도: index=1, name=이형균, action=APPROVAL
#       - activities[1]: name=이형균, type=APPROVAL
#       - 매칭 체크: '이형균' in '이형균' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=임성진, action=DRAFT
#         - crawled[1]: name=이형균, action=APPROVAL
#         ✅ 업데이트: 1458486000000 → 1458526271000
#
#     🎯 업데이트 시도: index=2, name=장성봉, action=APPROVAL
#       - activities[2]: name=장성봉, type=APPROVAL
#       - 매칭 체크: '장성봉' in '장성봉' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=임성진, action=DRAFT
#         - crawled[1]: name=이형균, action=APPROVAL
#         - crawled[2]: name=장성봉, action=APPROVAL
#         ✅ 업데이트: 1458658800000 → 1458691921000
#
#   🔍 매치된 문서: doc_2009748_01 → 2009748 (line 251)
#     - need_update 항목 수: 4
#     - activities 항목 수: 4
#     - crawled 항목 수: 4
#
#     🎯 업데이트 시도: index=0, name=박희빈, action=DRAFT
#       - activities[0]: name=박희빈, type=DRAFT
#       - 매칭 체크: '박희빈' in '박희빈' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=박희빈, action=DRAFT
#         ✅ 업데이트: 1458572400000 → 1458608140000
#
#     🎯 업데이트 시도: index=1, name=윤상호, action=APPROVAL
#       - activities[1]: name=윤상호, type=APPROVAL
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=박희빈, action=DRAFT
#         - crawled[1]: name=윤상호, action=APPROVAL
#         ✅ 업데이트: 1458572400000 → 1458614915000
#
#     🎯 업데이트 시도: index=8, name=박상택, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 4)
#
#     🎯 업데이트 시도: index=9, name=권민선, action=AGREEMENT
#       ❌ index 9가 범위 초과 (activities 길이: 4)
#
#   🔍 매치된 문서: doc_2009746_01 → 2009746 (line 253)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=소성현, action=DRAFT
#       - activities[0]: name=소성현, type=DRAFT
#       - 매칭 체크: '소성현' in '소성현' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=소성현, action=DRAFT
#         ✅ 업데이트: 1458572400000 → 1458603833000
#
#     🎯 업데이트 시도: index=1, name=양기훈, action=APPROVAL
#       - activities[1]: name=양기훈, type=APPROVAL
#       - 매칭 체크: '양기훈' in '양기훈' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=소성현, action=DRAFT
#         - crawled[1]: name=양기훈, action=APPROVAL
#         ✅ 업데이트: 1458572400000 → 1458615881000
#
#     🎯 업데이트 시도: index=8, name=김재원, action=APPROVAL
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009752_01 → 2009752 (line 257)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=권민선, action=DRAFT
#       - activities[0]: name=권민선, type=DRAFT
#       - 매칭 체크: '권민선' in '권민선' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         ✅ 업데이트: 1458658800000 → 1458709141000
#
#     🎯 업데이트 시도: index=1, name=김동력, action=APPROVAL
#       - activities[1]: name=김동력, type=APPROVAL
#       - 매칭 체크: '김동력' in '김동력' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김동력, action=APPROVAL
#         ✅ 업데이트: 1458745200000 → 1458775590000
#
#     🎯 업데이트 시도: index=2, name=CEO, action=APPROVAL
#       - activities[2]: name=CEO, type=APPROVAL
#       - 매칭 체크: 'CEO' in 'CEO' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=권민선, action=DRAFT
#         - crawled[1]: name=김동력, action=APPROVAL
#         - crawled[2]: name=CEO, action=APPROVAL
#         ✅ 업데이트: 1458745200000 → 1458794869000
#
#   🔍 매치된 문서: doc_2009755_01 → 2009755 (line 258)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=편영수, action=DRAFT
#       - activities[0]: name=편영수, type=DRAFT
#       - 매칭 체크: '편영수' in '편영수' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         ✅ 업데이트: 1458745200000 → 1458780437000
#
#     🎯 업데이트 시도: index=1, name=박상택, action=APPROVAL
#       - activities[1]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=편영수, action=DRAFT
#         - crawled[1]: name=박상택, action=APPROVAL
#         ✅ 업데이트: 1458831600000 → 1458863092000
#
#     🎯 업데이트 시도: index=8, name=김재원, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009758_01 → 2009758 (line 259)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=김민서, action=DRAFT
#       - activities[0]: name=김민서, type=DRAFT
#       - 매칭 체크: '김민서' in '김민서' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김민서, action=DRAFT
#         ✅ 업데이트: 1458745200000 → 1458801696000
#
#     🎯 업데이트 시도: index=1, name=김동력, action=APPROVAL
#       - activities[1]: name=김동력, type=APPROVAL
#       - 매칭 체크: '김동력' in '김동력' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=김민서, action=DRAFT
#         - crawled[1]: name=김재원, action=APPROVAL
#         - crawled[2]: name=김동력, action=APPROVAL
#       ⚠️ crawled에서 매칭 항목 못 찾음
#
#     🎯 업데이트 시도: index=8, name=김재원, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009757_01 → 2009757 (line 260)
#     - need_update 항목 수: 2
#     - activities 항목 수: 2
#     - crawled 항목 수: 2
#
#     🎯 업데이트 시도: index=0, name=윤상호, action=DRAFT
#       - activities[0]: name=윤상호, type=DRAFT
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         ✅ 업데이트: 1458745200000 → 1458785050000
#
#     🎯 업데이트 시도: index=8, name=김재원, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 2)
#
#   🔍 매치된 문서: doc_2009754_01 → 2009754 (line 261)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=윤상호, action=DRAFT
#       - activities[0]: name=윤상호, type=DRAFT
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         ✅ 업데이트: 1458745200000 → 1458780237000
#
#     🎯 업데이트 시도: index=1, name=박상택, action=APPROVAL
#       - activities[1]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         - crawled[1]: name=박상택, action=APPROVAL
#         ✅ 업데이트: 1458831600000 → 1458862869000
#
#     🎯 업데이트 시도: index=8, name=김재원, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009760_01 → 2009760 (line 263)
#     - need_update 항목 수: 2
#     - activities 항목 수: 2
#     - crawled 항목 수: 2
#
#     🎯 업데이트 시도: index=0, name=현광섭, action=DRAFT
#       - activities[0]: name=현광섭, type=DRAFT
#       - 매칭 체크: '현광섭' in '현광섭' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=현광섭, action=DRAFT
#         ✅ 업데이트: 1458745200000 → 1458811729000
#
#     🎯 업데이트 시도: index=8, name=김재원, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 2)
#
#   🔍 매치된 문서: doc_2009756_01 → 2009756 (line 264)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=윤상호, action=DRAFT
#       - activities[0]: name=윤상호, type=DRAFT
#       - 매칭 체크: '윤상호' in '윤상호' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         ✅ 업데이트: 1458745200000 → 1458780503000
#
#     🎯 업데이트 시도: index=1, name=박상택, action=APPROVAL
#       - activities[1]: name=박상택, type=APPROVAL
#       - 매칭 체크: '박상택' in '박상택' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=윤상호, action=DRAFT
#         - crawled[1]: name=박상택, action=APPROVAL
#         ✅ 업데이트: 1458831600000 → 1458862925000
#
#     🎯 업데이트 시도: index=8, name=김재원, action=AGREEMENT
#       ❌ index 8가 범위 초과 (activities 길이: 3)
#
#   🔍 매치된 문서: doc_2009762_01 → 2009762 (line 265)
#     - need_update 항목 수: 3
#     - activities 항목 수: 3
#     - crawled 항목 수: 3
#
#     🎯 업데이트 시도: index=0, name=마상미, action=DRAFT
#       - activities[0]: name=마상미, type=DRAFT
#       - 매칭 체크: '마상미' in '마상미' = True
#       - 매칭 체크: 'DRAFT' == 'DRAFT' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=마상미, action=DRAFT
#         ✅ 업데이트: 1458831600000 → 1458877810000
#
#     🎯 업데이트 시도: index=1, name=이형균, action=APPROVAL
#       - activities[1]: name=이형균, type=APPROVAL
#       - 매칭 체크: '이형균' in '이형균' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=마상미, action=DRAFT
#         - crawled[1]: name=이형균, action=APPROVAL
#         ✅ 업데이트: 1458831600000 → 1458877861000
#
#     🎯 업데이트 시도: index=2, name=장성봉, action=APPROVAL
#       - activities[2]: name=장성봉, type=APPROVAL
#       - 매칭 체크: '장성봉' in '장성봉' = True
#       - 매칭 체크: 'APPROVAL' == 'APPROVAL' = True
#       ✅ 첫 번째 매칭 성공!
#         - crawled[0]: name=마상미, action=DRAFT
#         - crawled[1]: name=이형균, action=APPROVAL
#         - crawled[2]: name=장성봉, action=APPROVAL
#         ✅ 업데이트: 1458831600000 → 1458884716000
#   ⚠️ 파싱 에러 (line 271): Expecting ',' delimiter: line 1 column 6169 (char 6168)
#   ⚠️ 파싱 에러 (line 279): Expecting ',' delimiter: line 1 column 6388 (char 6387)
#   ⚠️ 파싱 에러 (line 288): Expecting ',' delimiter: line 1 column 6351 (char 6350)
#   ⚠️ 파싱 에러 (line 383): Expecting ',' delimiter: line 1 column 6510 (char 6509)
#   ⚠️ 파싱 에러 (line 410): Expecting ',' delimiter: line 1 column 7292 (char 7291)
#   ⚠️ 파싱 에러 (line 450): Expecting ',' delimiter: line 1 column 6180 (char 6179)
#   ⚠️ 파싱 에러 (line 525): Expecting ',' delimiter: line 1 column 6347 (char 6346)
#   ⚠️ 파싱 에러 (line 532): Expecting ',' delimiter: line 1 column 6164 (char 6163)
#   ⚠️ 파싱 에러 (line 546): Expecting ',' delimiter: line 1 column 6254 (char 6253)
#   ⚠️ 파싱 에러 (line 615): Expecting ',' delimiter: line 1 column 6241 (char 6240)
#   ⚠️ 파싱 에러 (line 637): Expecting ',' delimiter: line 1 column 6189 (char 6188)
#   ⚠️ 파싱 에러 (line 658): Expecting ',' delimiter: line 1 column 6372 (char 6371)
#   ⚠️ 파싱 에러 (line 739): Expecting ',' delimiter: line 1 column 6212 (char 6211)
#   ⚠️ 파싱 에러 (line 744): Expecting ',' delimiter: line 1 column 6430 (char 6429)
#   ⚠️ 파싱 에러 (line 753): Expecting ',' delimiter: line 1 column 6249 (char 6248)
#   ⚠️ 파싱 에러 (line 790): Expecting ',' delimiter: line 1 column 9868 (char 9867)
#
# ======================================================================
# 🎉 업데이트 완료!
# ======================================================================
# 📊 처리 결과:
#   - 전체 문서: 7704개
#   - sourceId 매치: 171개
#   - 업데이트: 353개 결재선
#   - 출력 파일: documents_2020_actTimefixed.cmds
# ======================================================================
