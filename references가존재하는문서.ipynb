# %%
# references가 존재하는 문서들의 sourceId 숫자를 뽑는 코드
import json
import re

result = []

# cmds 파일 읽기 (정확한 파일명 사용)
with open('documents_2025_02.cmds', 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        
        # addDocument로 시작하는 줄만 처리
        if line.startswith('addDocument '):
            # "addDocument " 이후의 JSON 부분만 추출
            json_str = line.replace('addDocument ', '', 1)
            
            try:
                data = json.loads(json_str)
                
                # references가 존재하고 비어있지 않은 경우
                if 'references' in data and data['references']:
                    # sourceId에서 숫자만 추출
                    source_id = data['sourceId']  # 예: "doc_18876965_02"
                    match = re.search(r'doc_(\d+)_\d+', source_id)
                    if match:
                        number = match.group(1)  # "18876965"
                        result.append(number)
            except json.JSONDecodeError:
                # JSON 파싱 에러 시 스킵
                continue

print(f"추출된 숫자 개수: {len(result)}")
print(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       5 result = []
#       7 # cmds 파일 읽기 (정확한 파일명 사용)
# ----> 8 with open('documents_2025_02.cmds', 'r', encoding='utf-8') as f:
#       9     for line in f:
#      10         line = line.strip()
#
# File ~\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'documents_2025_02.cmds'
