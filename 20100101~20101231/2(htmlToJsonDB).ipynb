# %%
pip install beautifulsoup4 pymysql lxml
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\leejuhwan\miniconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: pymysql in c:\users\leejuhwan\miniconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: lxml in c:\users\leejuhwan\miniconda3\lib\site-packages (6.0.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\leejuhwan\miniconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\leejuhwan\miniconda3\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# drafter 이름 안나오는건 보완

# endYear 컬럼 추가해서 여러 기간 폴더 데이터를 하나의 테이블에 구분해서 저장할 수 있게 변경

# + type이 합의인것만 - AGREEMENT로 변경
# 디비 저장 오류 수정 

import os
import json
import re
from datetime import datetime
from bs4 import BeautifulSoup
import pymysql
from pathlib import Path

class ApprovalDocParser:
    def __init__(self, base_path):
        self.base_path = base_path
        
    def extract_source_id(self, filename):
        """파일명에서 마지막 숫자 추출"""
        numbers = re.findall(r'\d+', filename)
        return numbers[-1] if numbers else None
    
    def parse_datetime_to_unix(self, date_str):
        """날짜 문자열을 Unix timestamp(밀리초)로 변환"""
        try:
            dt = datetime.strptime(date_str.strip(), "%Y-%m-%d %H:%M:%S")
            return int(dt.timestamp() * 1000)
        except:
            return None
    
    def extract_person_info(self, text):
        """이름/직책/부서 형식에서 정보 추출"""
        text = re.sub(r'\d+', '', text).strip()
        parts = text.split('/')
        if len(parts) >= 3:
            return {
                'name': parts[0].strip(),
                'positionName': parts[1].strip(),
                'deptName': parts[2].strip()
            }
        return None
    
    def parse_html(self, html_path):
        """HTML 파일 파싱"""
        with open(html_path, 'r', encoding='utf-8') as f:
            soup = BeautifulSoup(f.read(), 'html.parser')
        
        filename = os.path.basename(html_path)
        source_id = self.extract_source_id(filename)
        
        doc_num_elem = soup.find('p', class_='team')
        doc_num = doc_num_elem.get_text(strip=True) if doc_num_elem else ""
        
        references_elem = soup.find('span', class_='disInline o-i-min-fileList')
        references = []
        if references_elem:
            next_elem = references_elem.find_next_sibling()
            if next_elem:
                references = next_elem.get_text(strip=True)
            else:
                parent = references_elem.parent
                references = parent.get_text(strip=True)
        
        title_elem = soup.find('title')
        title = title_elem.get_text(strip=True) if title_elem else ""
        
        attaches = []
        verti_tops = soup.find_all('span', class_='verti_Top')
        for vt in verti_tops:
            a_tag = vt.find('a')
            if a_tag and a_tag.get('href'):
                attaches.append({
                    'name': a_tag.get_text(strip=True),
                    'path': a_tag.get('href')
                })
        
        # 기존 방식: user_spans에서 drafter 추출
        user_spans = soup.find_all('span', class_='user')
        drafter = {}
        if user_spans:
            first_user = user_spans[0]
            name_elem = first_user.find('span', class_='F_12_black_b')
            if name_elem:
                info = self.extract_person_info(name_elem.get_text(strip=True))
                if info:
                    drafter = {
                        'positionName': info['positionName'],
                        'deptName': info['deptName'],
                        'name': info['name'],
                        'emailId': '',
                        'deptCode': ''
                    }
        
        # drafter가 비어있으면 테이블의 "기안자" 행에서 추출 (백업)
        if not drafter or not drafter.get('name'):
            drafter_th = soup.find('th', string=lambda s: s and '기안자' in s)
            if drafter_th:
                drafter_td = drafter_th.find_next_sibling('td')
                if drafter_td:
                    bg01_div = drafter_td.find('div', class_='bg01')
                    if bg01_div:
                        name = bg01_div.get_text(strip=True)
                        if name:  # 이름이 실제로 있으면
                            drafter = {
                                'positionName': '',
                                'deptName': '',
                                'name': name,
                                'emailId': '',
                                'deptCode': ''
                            }
        
        created_at = None
        if user_spans:
            date_elem = user_spans[0].find('span', class_='F_11_gray')
            if date_elem:
                created_at = self.parse_datetime_to_unix(date_elem.get_text(strip=True))
        
        referrers = []
        ref_th = soup.find('th', string=lambda s: s and '참조' in s)
        if ref_th:
            ref_td = ref_th.find_next_sibling('td')
            if ref_td:
                ref_text = ref_td.get_text(strip=True)
                ref_list = re.split(r'[,\s]+', ref_text)
                for ref in ref_list:
                    if ref:
                        info = self.extract_person_info(ref)
                        if info:
                            referrers.append({
                                'name': info['name'],
                                'empNo': '',
                                'deptCode': ''
                            })
        
        # 결재선 영역에서 "합의"인 사람들의 이름 추출
        agreement_names = []
        appr_line_area = soup.find('div', id='apprLineArea')
        if appr_line_area:
            red_spans = appr_line_area.find_all('span', class_='red')
            for red_span in red_spans:
                if '합의' in red_span.get_text(strip=True):
                    # red span의 부모 li의 이전 형제 li에서 이름 찾기
                    parent_li = red_span.find_parent('li')
                    if parent_li:
                        prev_li = parent_li.find_previous_sibling('li')
                        if prev_li:
                            name_text = prev_li.get_text(strip=True)
                            # 이름만 추출 (숫자 제거 등)
                            if name_text:
                                agreement_names.append(name_text)
        
        activities = []
        for idx, user_span in enumerate(user_spans):
            name_elem = user_span.find('span', class_='F_12_black_b')
            date_elem = user_span.find('span', class_='F_11_gray')
            
            if name_elem:
                info = self.extract_person_info(name_elem.get_text(strip=True))
                if info:
                    action_comment = ""
                    next_elem = user_span.next_sibling
                    while next_elem:
                        if hasattr(next_elem, 'name') and next_elem.name == 'div':
                            action_comment = next_elem.get_text(strip=True)
                            break
                        next_elem = next_elem.next_sibling
                    
                    # 기본 타입 설정
                    action_type = 'DRAFT' if idx == 0 else 'APPROVAL'
                    
                    # 이 사람이 합의자 리스트에 있으면 AGREEMENT로 변경
                    if info['name'] in agreement_names:
                        action_type = 'AGREEMENT'
                    
                    activities.append({
                        'positionName': info['positionName'],
                        'deptName': info['deptName'],
                        'actionLogType': action_type,
                        'name': info['name'],
                        'emailId': '',
                        'type': action_type,
                        'actionDate': self.parse_datetime_to_unix(date_elem.get_text(strip=True)) if date_elem else None,
                        'deptCode': '',
                        'actionComment': action_comment
                    })
        
        result = {
            'sourceId': source_id,
            'docNum': doc_num,
            'references': references,
            'docType': 'DRAFT',
            'title': title,
            'attaches': attaches,
            'drafter': drafter,
            'createdAt': created_at,
            'docBody': '',
            'docStatus': 'COMPLETE',
            'referrers': referrers,
            'activities': activities,
            'formName': '',
            'isPublic': False
        }
        
        return result
    
    def process_all_files(self):
        """모든 HTML 파일 처리"""
        all_results = []
        approval_path = Path(self.base_path) / '결재'
        
        if not approval_path.exists():
            print(f"경로를 찾을 수 없습니다: {approval_path}")
            return all_results
            
        html_files = list(approval_path.rglob('*.html'))
        # html_files = list(approval_path.rglob('*.html'))[:10]
        print(f"총 {len(html_files)}개의 HTML 파일을 찾았습니다.")
        
        for idx, html_file in enumerate(html_files, 1):
            try:
                print(f"처리 중... [{idx}/{len(html_files)}] {html_file.name}")
                result = self.parse_html(html_file)
                all_results.append(result)
            except Exception as e:
                print(f"오류 발생 ({html_file.name}): {e}")
        
        return all_results
    
    def save_to_json(self, data, output_path):
        """JSON 파일로 저장"""
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)
        print(f"JSON 파일 저장 완료: {output_path}")
    
    def save_to_mariadb(self, data, db_config, end_year):
        """MariaDB에 저장 - 안정성 강화 버전"""
        conn = None
        cursor = None
        
        try:
            print("\n=== DB 연결 시작 ===")
            print(f"Host: {db_config['host']}, Database: {db_config['database']}")
            
            # DB 연결
            conn = pymysql.connect(
                host=db_config['host'],
                user=db_config['user'],
                password=db_config['password'],
                database=db_config['database'],
                charset='utf8mb4'
            )
            print("✓ DB 연결 성공")
            
            cursor = conn.cursor()
            
            # 테이블 생성
            print("\n=== 테이블 생성 시작 ===")
            create_table_sql = """
            CREATE TABLE IF NOT EXISTS documents (
                id INT AUTO_INCREMENT PRIMARY KEY,
                source_id VARCHAR(50),
                doc_num VARCHAR(100),
                doc_type VARCHAR(50),
                title VARCHAR(500),
                doc_status VARCHAR(50),
                created_at BIGINT,
                drafter_name VARCHAR(100),
                drafter_position VARCHAR(100),
                drafter_dept VARCHAR(100),
                form_name VARCHAR(200),
                is_public BOOLEAN,
                end_year INT,
                `references` TEXT,
                attaches TEXT,
                referrers TEXT,
                activities TEXT,
                doc_body TEXT,
                created_date TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
                INDEX idx_source_id (source_id),
                INDEX idx_doc_num (doc_num),
                INDEX idx_created_at (created_at),
                INDEX idx_end_year (end_year)
            ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_unicode_ci;
            """
            cursor.execute(create_table_sql)
            print("✓ 테이블 생성/확인 완료")
            
            # 기존 데이터 확인
            cursor.execute("SELECT COUNT(*) FROM documents")
            existing_count = cursor.fetchone()[0]
            print(f"✓ 기존 데이터: {existing_count}건")
            
            # 데이터 삽입
            print(f"\n=== 데이터 삽입 시작 ({len(data)}건) ===")
            insert_sql = """
            INSERT INTO documents 
            (source_id, doc_num, doc_type, title, doc_status, created_at, 
             drafter_name, drafter_position, drafter_dept, form_name, is_public, end_year,
             `references`, attaches, referrers, activities, doc_body)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            
            success_count = 0
            error_count = 0
            error_details = []
            
            for idx, doc in enumerate(data, 1):
                try:
                    # 데이터 길이 제한 및 안전한 변환
                    def safe_string(value, max_length=None):
                        if value is None:
                            return ''
                        s = str(value).strip()
                        if max_length and len(s) > max_length:
                            s = s[:max_length]
                        return s
                    
                    # JSON 데이터를 안전하게 변환 (ensure_ascii=True로 특수문자 이스케이프)
                    def safe_json(value):
                        if not value:
                            return '[]'
                        try:
                            # ensure_ascii=True로 모든 비ASCII 문자를 이스케이프
                            return json.dumps(value, ensure_ascii=True)
                        except:
                            return '[]'
                    
                    values = (
                        safe_string(doc.get('sourceId'), 50),
                        safe_string(doc.get('docNum'), 100),
                        safe_string(doc.get('docType'), 50),
                        safe_string(doc.get('title'), 500),
                        safe_string(doc.get('docStatus'), 50),
                        doc.get('createdAt'),
                        safe_string(doc.get('drafter', {}).get('name'), 100),
                        safe_string(doc.get('drafter', {}).get('positionName'), 100),
                        safe_string(doc.get('drafter', {}).get('deptName'), 100),
                        safe_string(doc.get('formName'), 200),
                        doc.get('isPublic', False),
                        end_year,
                        safe_string(doc.get('references')),
                        safe_json(doc.get('attaches', [])),
                        safe_json(doc.get('referrers', [])),
                        safe_json(doc.get('activities', [])),
                        safe_string(doc.get('docBody'))
                    )
                    
                    cursor.execute(insert_sql, values)
                    success_count += 1
                    
                    # 100건마다만 출력 (로그 줄이기)
                    if idx % 100 == 0 or idx == len(data):
                        print(f"  진행: {idx}/{len(data)} (성공: {success_count}, 실패: {error_count})")
                    
                except Exception as e:
                    error_count += 1
                    error_msg = f"sourceId: {doc.get('sourceId')} - {str(e)[:80]}"
                    error_details.append(error_msg)
                    
                    # 처음 5개 오류만 즉시 출력
                    if error_count <= 5:
                        print(f"  [오류 {error_count}] {error_msg}")
            
            # 커밋
            print("\n=== 커밋 시작 ===")
            conn.commit()
            print(f"✓ 커밋 완료")
            
            # 결과 요약
            print(f"\n=== 결과 요약 ===")
            print(f"✓ 성공: {success_count}건")
            print(f"✗ 실패: {error_count}건")
            
            if error_count > 5:
                print(f"\n처음 5개 외 {error_count - 5}개의 추가 오류가 발생했습니다.")
                print("모든 오류 보기:")
                for err in error_details[:20]:  # 최대 20개만 출력
                    print(f"  - {err}")
                if len(error_details) > 20:
                    print(f"  ... 외 {len(error_details) - 20}개 더")
            
            # 최종 확인
            cursor.execute("SELECT COUNT(*) FROM documents")
            final_count = cursor.fetchone()[0]
            print(f"\n✓ 최종 데이터: {final_count}건 (이번 실행으로 {success_count}건 추가)")
            
        except pymysql.Error as e:
            print(f"\n❌ DB 오류 발생:")
            print(f"  Error Code: {e.args[0]}")
            print(f"  Error Message: {e.args[1]}")
            
        except Exception as e:
            print(f"\n❌ 일반 오류 발생: {e}")
            
        finally:
            if cursor:
                cursor.close()
            if conn:
                conn.close()
                print("\n✓ DB 연결 종료")


def main():
    base_path = r'C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html' #컨트롤러
    end_year = 2010  #컨트롤러 - 폴더 기간에 맞게 수정
    
    parser = ApprovalDocParser(base_path)
    
    print("HTML 파일 파싱 시작...")
    results = parser.process_all_files()
    
    output_json_path = 'two_htmltojsondb_convert.json' #컨트롤러
    parser.save_to_json(results, output_json_path)
    
    # DB 설정
    db_config = {
        'host': 'localhost',
        'user': 'root',
        'password': '1234',
        'database': 'any_approval' #컨트롤러 - 통합 DB명
    }
    
    # MariaDB에 저장
    print("\n" + "="*50)
    parser.save_to_mariadb(results, db_config, end_year)
    print("="*50)
    
    print(f"\n완료! 총 {len(results)}건 처리됨")


if __name__ == '__main__':
    main()
# Out:
# HTML 파일 파싱 시작...
# 총 840개의 HTML 파일을 찾았습니다.
# 처리 중... [1/840] 20100108_국내출장비 신청합니다._2002068.html
# 처리 중... [2/840] 20100108_출장비 신청합니다._2002067.html
# 처리 중... [3/840] 20100109_출장비_2002069.html
# 처리 중... [4/840] 20100118_국내출장비 신청(창원대,인제대,실트론)_2002070.html
# 처리 중... [5/840] 20100118_사진보드 꾸밀시 필요한  비품 신청_2002071.html
# 처리 중... [6/840] 20100118_사진보드 꾸밀시 필요한  비품 신청_2002072.html
# 처리 중... [7/840] 20100118_한국한의학 연구원 프로젝트 인원투입요청 (2010.01.18)_2002073.html
# 처리 중... [8/840] 20100119_[기술연구부문] 회사 공용 개발서버 Memory 확장관련 비용승인 품의_2002074.html
# 처리 중... [9/840] 20100120_USB메모리 구매신청_2002075.html
# 처리 중... [10/840] 20100120_[채용품의] ITO 팀 아웃소싱전문가 채용_2002078.html
# 처리 중... [11/840] 20100120_[회사공통 영업용 Demo 솔루션 관리를 위한 USB구매요청]_2002076.html
# 처리 중... [12/840] 20100120_출장비용 품의 드립니다._2002077.html
# 처리 중... [13/840] 20100121_LG하우시스 개발자 김재호씨 업무 중지 요청입니다._2002079.html
# 처리 중... [14/840] 20100122_[견적품의] 식품의약품안전평가원 연구관리시스템 등 운영을 위한 동부CNI 견적 제출건_2002082.html
# 처리 중... [15/840] 20100122_[채용품의] 식품의약품안전평가원 연구관리시스템 운영인력_2002081.html
# 처리 중... [16/840] 20100122_[품의] LG호학 기술원 인원소싱 품의_2002080.html
# 처리 중... [17/840] 20100125_2010년 1월 잔업식대 신청합니다._2002083.html
# 처리 중... [18/840] 20100125_[휴가신청] Refresh 휴가를 신청합니다._2002084.html
# 처리 중... [19/840] 20100125_국내 출장비 신청(1_19,22,25 - 3일 KT본사)_2002085.html
# 처리 중... [20/840] 20100126_KT C_P 승인요청_2002087.html
# 처리 중... [21/840] 20100126_[품의]팬택 특허시스템 유지보수 계약 체결 건_2002089.html
# 처리 중... [22/840] 20100126_서버계정신청_2002086.html
# 처리 중... [23/840] 20100126_휴가신청 결재요청_2002088.html
# 처리 중... [24/840] 20100127_KT 검색엔진 구매요청_2002090.html
# 처리 중... [25/840] 20100127_[재품의]아웃소싱 인원 계약 체결-권태용_2002093.html
# 처리 중... [26/840] 20100127_식약청 프로젝트 개발팀 자체 회식비 사용 신청 건_2002091.html
# 처리 중... [27/840] 20100127_식약청 프로젝트 경비 사용 승인 건_2002092.html
# 처리 중... [28/840] 20100128_LG화학 특허자산관리 프로젝트 비용변경 품의_2002094.html
# 처리 중... [29/840] 20100128_비품구매 신청 품의_2002095.html
# 처리 중... [30/840] 20100129_1월 법인카드 사용 내역_2002098.html
# 처리 중... [31/840] 20100129_국내출장비 신청(창원대,인제대,실트론)_택시비 청구_2002097.html
# 처리 중... [32/840] 20100129_현대HDS DRM시스템 공급 계약건_2002096.html
# 처리 중... [33/840] 20100131_2010년1월 법인카드내역서_2002099.html
# 처리 중... [34/840] 20100201_201001월분 식대 신청입니다.^^_2002100.html
# 처리 중... [35/840] 20100201_[품의]영업관리시스템 구축 비용 결제건_2002102.html
# 처리 중... [36/840] 20100201_시내교통비 신청_2002101.html
# 처리 중... [37/840] 20100201_한국한의학연구원_201001월_법인카드사용보고서_2002103.html
# 처리 중... [38/840] 20100202_사업부 사기진작비 사용 정산건_2002104.html
# 처리 중... [39/840] 20100204_2010년 1월 시내교통비 품의 신청합니다._2002105.html
# 처리 중... [40/840] 20100204_2010년 1월 시내교통비 품의 신청합니다._2002107.html
# 처리 중... [41/840] 20100204_Project 리프레쉬 휴가 신청합니다._2002109.html
# 처리 중... [42/840] 20100204_프로젝트 선투입 요청서 (한국산업기술진흥원 녹색인증제 정보시스템 구축)_2002108.html
# 처리 중... [43/840] 20100204_휴가신청합니다._2002106.html
# 처리 중... [44/840] 20100205_2010년 1월 법인카드 사용보고서_2002117.html
# 처리 중... [45/840] 20100205_2010년 1월 법인카드 사용실적내역 보고서_2002111.html
# 처리 중... [46/840] 20100205_KIAT 야근근무 저녁식대 품의요청_허지훈_2002115.html
# 처리 중... [47/840] 20100205_[계약체결]식품의약품안전청 통합유지보수 계약 건_2002113.html
# 처리 중... [48/840] 20100205_[법인카드 사용보고] 박정균수석(2010_01월)_2002116.html
# 처리 중... [49/840] 20100205_[품의] LG화학 실험실정보화시스템 구축 인력 소싱 품의 (유상권 대체)_2002110.html
# 처리 중... [50/840] 20100205_설연휴  휴가신청 합니다._2002112.html
# 처리 중... [51/840] 20100205_시내교통비 품의요청합니다._2002114.html
# 처리 중... [52/840] 20100208_(신청서)제증명서 발급_2002121.html
# 처리 중... [53/840] 20100208_[품의] 2010년 1월 법인카드 사용내역 보고_2002118.html
# 처리 중... [54/840] 20100208_[품의] 식약청 완료보고서 제본 22부_2002119.html
# 처리 중... [55/840] 20100208_국내출장비 신청(인제대_한국전기연구원)_2002123.html
# 처리 중... [56/840] 20100208_비품_소모품 구매 신청_2002120.html
# 처리 중... [57/840] 20100208_한의학연구원  통합연구관리시스템구축(1단계) - ISP수행 계약체결요청_2002122.html
# 처리 중... [58/840] 20100209_KIAT 국가기수사업화정보망 구축 검색엔진 구매 수정 계약건_2002124.html
# 처리 중... [59/840] 20100209_시내교통비 신청_2002125.html
# 처리 중... [60/840] 20100210_R&D 사업부 유상권 입니다. _2002129.html
# 처리 중... [61/840] 20100210_설연휴 이후 연차휴가를 신청합니다._2002128.html
# 처리 중... [62/840] 20100210_야근식비 (2010년 1월)_2002127.html
# 처리 중... [63/840] 20100210_출장 경비 신청 품의_2002126.html
# 처리 중... [64/840] 20100211_ 시내 교통비 청구 _2002131.html
# 처리 중... [65/840] 20100211_[품의] 식품의약품안전평가원 [연구관리시스템 추가구축] 프로젝트 이행인센티브 지급건_2002132.html
# 처리 중... [66/840] 20100211_소모품 비용 청구 승인요청_2002130.html
# 처리 중... [67/840] 20100211_출장품의서_2002133.html
# 처리 중... [68/840] 20100212_식약청 프로젝트 경비 사용 승인 건(1월분)_2002134.html
# 처리 중... [69/840] 20100216_아웃소싱 인원 계약 체결 품의-김빌리_2002137.html
# 처리 중... [70/840] 20100216_아웃소싱 인원 계약 체결 품의-류광수,김수경_2002136.html
# 처리 중... [71/840] 20100216_아웃소싱 인원 계약 체결 품의-박승진_2002135.html
# 처리 중... [72/840] 20100217_KIAT 프로젝트 비용 지급품의_2002141.html
# 처리 중... [73/840] 20100217_LG하우시스 PMS 개발 폴더 권한 요청 _2002143.html
# 처리 중... [74/840] 20100217_데자뷰테크놀로지(전자펜, 이미지전환 솔루션) 협력사계약 체결건_2002142.html
# 처리 중... [75/840] 20100217_보안솔루션 테르텐 파트너 계약서 _2002140.html
# 처리 중... [76/840] 20100217_비품_소모품 구매 품의_2002138.html
# 처리 중... [77/840] 20100217_삼성전기 경비신청합니다._2002139.html
# 처리 중... [78/840] 20100217_한국한의학연구원_변경CP 품의 바랍니다_2002144.html
# 처리 중... [79/840] 20100218_2월 브레인밸류 아웃소싱 H_C 비용 품의_2002148.html
# 처리 중... [80/840] 20100218_2월 아웃소싱 비용 결제 품의-기술연구부문_2002147.html
# 처리 중... [81/840] 20100218_KT(분당) 출장비 신청_2002146.html
# 처리 중... [82/840] 20100218_[LAMS PJT종료에 따른 개발자 식사지원]_2002145.html
# 처리 중... [83/840] 20100219_[품의] LG화학기술뤙 실험실정보화시스템 구축_2002150.html
# 처리 중... [84/840] 20100219_[품의] LG화학기술원 New KMS 운영인력 채용 (김규일차장 업무 대체)_2002151.html
# 처리 중... [85/840] 20100219_한의학 연구원 투입인원 명함신청_2002149.html
# 처리 중... [86/840] 20100220_2월 아웃소싱 비용 결제 품의-R&D사업부_2002152.html
# 처리 중... [87/840] 20100220_아웃소싱 인원 계약 진행 품의-한국전기연구원(이동언)_2002154.html
# 처리 중... [88/840] 20100220_아웃소싱 인원 계약 진행 품의-한국한의학연구원(박기영,오경진)_2002153.html
# 처리 중... [89/840] 20100222_2010년 코아로직 특허시스템 하자보수 서비스 계약 체결 품의_2002155.html
# 처리 중... [90/840] 20100222_국내 출장 경비 신청 품의_2002156.html
# 처리 중... [91/840] 20100222_소모품 구매 신청 품의_2002157.html
# 처리 중... [92/840] 20100223_2월 법인 카드 사용 내역 정산 보고입니다._2002158.html
# 처리 중... [93/840] 20100223_기술지원팀 회식비 지원요청합니다._2002159.html
# 처리 중... [94/840] 20100223_아웃소싱 비용 결제 품의-1월분(솔루션사업부)_2002160.html
# 처리 중... [95/840] 20100224_사랑니 치료로 인한 반차휴가 신청합니다._2002162.html
# 처리 중... [96/840] 20100224_아웃소싱 인원 계약 체결-박명규씨 외 3명(LG화학 실험실 구축)_2002161.html
# 처리 중... [97/840] 20100225_2010년 2월 법인카드 사용내역서_2002165.html
# 처리 중... [98/840] 20100225_대전 LG화학기술연구원 SM 2010년 2월 CARD 사용내역 정산 보고_2002166.html
# 처리 중... [99/840] 20100225_시내교통비신청(2_24)_2002164.html
# 처리 중... [100/840] 20100225_연차휴가(3_2) 신청합니다._2002163.html
# 처리 중... [101/840] 20100226_2월 교통비 사용내역_2002169.html
# 처리 중... [102/840] 20100226_메디슨_iPIMS공급_CP_2002167.html
# 처리 중... [103/840] 20100226_전기연구원 프로젝트 야근식권 구매_2002168.html
# 처리 중... [104/840] 20100228_한국한의학연구원 201002월 법인카드사용 내역서_2002170.html
# 처리 중... [105/840] 20100302_2010년 2월 법인카드 사용 실적_2002172.html
# 처리 중... [106/840] 20100302_2월 법인카드 사용내역_2002177.html
# 처리 중... [107/840] 20100302_2월 법인카드 정산 보고 (LG화학 제안출장)_2002178.html
# 처리 중... [108/840] 20100302_LG화학 연구소 출장비 품의신청합니다._2002175.html
# 처리 중... [109/840] 20100302_LG화학기술원 출장 현금 교통비지급건_2002174.html
# 처리 중... [110/840] 20100302_[LG화학특허경영 제안 지원관련 출장비 품의]_2002180.html
# 처리 중... [111/840] 20100302_[기술연구부문 2월 법인카드사용내역 보고]_2002179.html
# 처리 중... [112/840] 20100302_[품의] 법인카드 정산 보고 (R&D사업부 김대화이사)_2002171.html
# 처리 중... [113/840] 20100302_교통비 이용건_2002176.html
# 처리 중... [114/840] 20100302_대전 LG화학 기술원 출장비 신청합니다._2002173.html
# 처리 중... [115/840] 20100303_3월 9일 반차 요청드립니다._2002181.html
# 처리 중... [116/840] 20100303_아웃소싱 인건비 비용 결제 품의-한국전기연구원(이동언)_2002182.html
# 처리 중... [117/840] 20100303_휴가신청_2002183.html
# 처리 중... [118/840] 20100304_법인 공인인증서 갱신_2002184.html
# 처리 중... [119/840] 20100304_연차휴가 신청합니다._2002185.html
# 처리 중... [120/840] 20100305_LG화학기술원 출장 현금 교통비지급건_2002189.html
# 처리 중... [121/840] 20100305_국내 출장 신청 품의_2002188.html
# 처리 중... [122/840] 20100305_국내 출장비 신청 품의_2002186.html
# 처리 중... [123/840] 20100305_메디슨_iPIMS공급_계약품의_2002190.html
# 처리 중... [124/840] 20100305_야근식대 (2010년 2월)_2002187.html
# 처리 중... [125/840] 20100305_오른쪽 무릎 반달연골 수술 병가_2002191.html
# 처리 중... [126/840] 20100308_국내출장 비용 청구(교통비)_2002192.html
# 처리 중... [127/840] 20100308_창원 한국전기원(3_3~3_5) 출장비_2002193.html
# 처리 중... [128/840] 20100310_2010년 2월 잔업식대 청구내역입니다._2002194.html
# 처리 중... [129/840] 20100311_3월 법인카드 정산보고_2002197.html
# 처리 중... [130/840] 20100311_한의학 연구원 ISP참석_2002196.html
# 처리 중... [131/840] 20100311_향방작계 예비군 교육으로 인하여 오전 반차 신청드립니다._2002195.html
# 처리 중... [132/840] 20100311_현대HDS 소디프 신소재 DRM 구축 구매 계약 품의(마크애니)_2002198.html
# 처리 중... [133/840] 20100312_국내출장 비용 청구(교통비)_2002199.html
# 처리 중... [134/840] 20100312_프로젝트 인원투입(아웃소싱) 품의_2002201.html
# 처리 중... [135/840] 20100312_한국한의학연구원 변경CP 품의 요청 (20100310)_2002200.html
# 처리 중... [136/840] 20100313_제증명서 발급 신청 품의_2002202.html
# 처리 중... [137/840] 20100314_외조부님 상으로 인한 공가 신청 품의_2002204.html
# 처리 중... [138/840] 20100314_한의학연구원_PM교체에따른_3월12일까지 법인카드사용내역서 보고_2002203.html
# 처리 중... [139/840] 20100315_기술지원팀 외부직원 그룹웨어 메일신청합니다.(김수경씨)_2002205.html
# 처리 중... [140/840] 20100315_대전 LG 화학 기술원 출장 신청 품의_2002209.html
# 처리 중... [141/840] 20100315_연차휴가 승인요청_2002207.html
# 처리 중... [142/840] 20100315_연차휴가사용 품의_2002208.html
# 처리 중... [143/840] 20100315_원천징수영수증 발급신청_2002206.html
# 처리 중... [144/840] 20100316_KT목동 주차비 신청_2002212.html
# 처리 중... [145/840] 20100316_[2010년2월]잔업식대 신청 품의_2002215.html
# 처리 중... [146/840] 20100316_영업비용 사용 건_2002210.html
# 처리 중... [147/840] 20100316_전기연구원 검색엔진 구매신청(재기안)_2002213.html
# 처리 중... [148/840] 20100316_창원 한국전기원(3_8~3_12) 출장비_2002211.html
# 처리 중... [149/840] 20100316_한국한의학연구원 출장경비 신청_2002214.html
# 처리 중... [150/840] 20100317_시내교통비 신청_2002216.html
# 처리 중... [151/840] 20100318_KIAT 프로젝트 인원투입(아웃소싱 선투입) 품의_2002218.html
# 처리 중... [152/840] 20100318_LG화학 Windows7 호환성 완화 워크샵_2002219.html
# 처리 중... [153/840] 20100318_국내출장 비용 청구_2002220.html
# 처리 중... [154/840] 20100318_비품 구매품의_2002217.html
# 처리 중... [155/840] 20100318_연차휴가 신청_2002221.html
# 처리 중... [156/840] 20100319_3월 아웃소싱 인건비 비용 결제 품의-BV 아웃소싱 H_C _2002223.html
# 처리 중... [157/840] 20100319_3월 아웃소싱 인건비 비용 결제 품의-기술지원부문_2002224.html
# 처리 중... [158/840] 20100319_3월 아웃소싱 인건비 비용 결제 품의-솔루션사업부_2002225.html
# 처리 중... [159/840] 20100319_창원 한국전기원(3_15~3_18) 출장비_2002222.html
# 처리 중... [160/840] 20100322_[품의] R&D 사업부 LG화학기술원 및 대전 지역 개발자 채용_2002226.html
# 처리 중... [161/840] 20100322_대전 LG 화학 기술원 전자연구노트 OPEN 지원을 위한 출장 품의_2002228.html
# 처리 중... [162/840] 20100322_주성엔지니어링_iPIMS(std.) 공급_2002227.html
# 처리 중... [163/840] 20100323_3월 아웃소싱 인건비 비용 결제 품의-R&D사업부_2002229.html
# 처리 중... [164/840] 20100323_KIAT 녹색인증제 정보시스템 구축 CP품의_2002230.html
# 처리 중... [165/840] 20100323_[견적품의]IP-MART 기능개선과제 견적품의_2002232.html
# 처리 중... [166/840] 20100323_아웃소싱 비용 결제 품의-KIAT 웹접근성 코딩 부분_2002231.html
# 처리 중... [167/840] 20100324_3월 급여대장_2002234.html
# 처리 중... [168/840] 20100324_KIAT 프로젝트 비용 지급 품의_2002237.html
# 처리 중... [169/840] 20100324_아웃소싱 계약 품의-LG화학기술원 실험실정보화 구축_2002236.html
# 처리 중... [170/840] 20100324_인센티브 지급 품의서_2002233.html
# 처리 중... [171/840] 20100324_한국전기연구원 출장품의 입니다._2002235.html
# 처리 중... [172/840] 20100324_한국한의학연구원 프로젝트 비용 품의_2002238.html
# 처리 중... [173/840] 20100324_한국한의학연구원 프로젝트 비용 품의_2002239.html
# 처리 중... [174/840] 20100325_부산 위,대장 내시경 검사. 병원진료 개인용무_2002242.html
# 처리 중... [175/840] 20100325_연차신청_2002241.html
# 처리 중... [176/840] 20100325_예비군 향방기본훈련 으로 인한 휴가 신청_2002240.html
# 처리 중... [177/840] 20100326_2010년 3월 법인카드 사용내역서_2002244.html
# 처리 중... [178/840] 20100326_DRM 시스템 구축 프로젝트 비용 지급품의_2002246.html
# 처리 중... [179/840] 20100326_반차 사용 품의_2002245.html
# 처리 중... [180/840] 20100326_시내교통비 신청 품의 (창원출장)_2002243.html
# 처리 중... [181/840] 20100329_2010.3월 법인카드 사용실적 보고_2002248.html
# 처리 중... [182/840] 20100329_2010년 3월 법인카드 사용내역 (이형균)_2002250.html
# 처리 중... [183/840] 20100329_2010년 3월 법인카드 사용내역_2002251.html
# 처리 중... [184/840] 20100329_2010년3월 체크카드 사용내역(김승범)_2002255.html
# 처리 중... [185/840] 20100329_3월 법인카드 사용 내역서_2002253.html
# 처리 중... [186/840] 20100329_[교육신청 품의] 특허기술경영전략_2002249.html
# 처리 중... [187/840] 20100329_[기술연구부문 - 박정균] 3월 법인카드사용내역 정산_2002256.html
# 처리 중... [188/840] 20100329_대전 LG화학기술연구원 SM 2010년 3월 CARD 사용내역 정산 보고_2002247.html
# 처리 중... [189/840] 20100329_솔루션사업부 신입사원(정선규) 교육수강 품의_2002254.html
# 처리 중... [190/840] 20100329_창원 한국전기원(3_22~3_26) 출장비_2002252.html
# 처리 중... [191/840] 20100330_3월 교통비 사용내역건_2002262.html
# 처리 중... [192/840] 20100330_3월 법인 카드 사용 내역입니다._2002257.html
# 처리 중... [193/840] 20100330_3월 비용 사용 내역 품의_2002260.html
# 처리 중... [194/840] 20100330_3월 접대비 사용 내역 건_2002261.html
# 처리 중... [195/840] 20100330_LG화학 Windows7 및 보안 SW 통합 회의_2002259.html
# 처리 중... [196/840] 20100330_[계약체결]대동공업 2010년도 산업재산권(특허) 유지보수 계약 체결건_2002263.html
# 처리 중... [197/840] 20100330_단체_협회 비용 지급 품의_2002258.html
# 처리 중... [198/840] 20100330_병원진찰로 인해 반차휴가 요청합니다._2002264.html
# 처리 중... [199/840] 20100331_식약청 프로젝트 비용지급 품의_2002265.html
# 처리 중... [200/840] 20100401_[기술지원팀 격려 인센티브 지급품의]_2002268.html
# 처리 중... [201/840] 20100401_국내출장 비용 청구(교통비)_2002267.html
# 처리 중... [202/840] 20100401_연차휴가 사용 품의_2002266.html
# 처리 중... [203/840] 20100402_Windows7 대비 업체 설명회 - 트윈타워_2002272.html
# 처리 중... [204/840] 20100402_명함신청_2002271.html
# 처리 중... [205/840] 20100402_세미나 참가비 신청_2002270.html
# 처리 중... [206/840] 20100402_아웃소싱 계약 품의-솔루션사업부_2002269.html
# 처리 중... [207/840] 20100403_국내출장비 신청 품의-대전, 울산_2002273.html
# 처리 중... [208/840] 20100405_KIAT 야근근무 저녁식대 품의요청_허지훈_2002274.html
# 처리 중... [209/840] 20100405_[세미나 참가 비용지원 품의]_2002275.html
# 처리 중... [210/840] 20100405_창원 한국전기원(3_29~4_2) 출장비_2002276.html
# 처리 중... [211/840] 20100406_농업기술실용화재단_iPIMS 및  온라인 기술거래 사이트 구축_2002277.html
# 처리 중... [212/840] 20100407_연차 휴가 사용 품의-민방위훈련_2002279.html
# 처리 중... [213/840] 20100407_프로젝트 관리 전문가 교육 신청件_2002278.html
# 처리 중... [214/840] 20100408_4월 법인카드 내역입니다._2002280.html
# 처리 중... [215/840] 20100408_메디슨 지재권통합관리시스템_하드웨어 발주 품의_2002281.html
# 처리 중... [216/840] 20100409_Refresh 휴가요청합니다._2002283.html
# 처리 중... [217/840] 20100409_[메디슨] 검색엔진 발주 승인요청_2002282.html
# 처리 중... [218/840] 20100412_계약체결 품의-한국전기연구원 _2002284.html
# 처리 중... [219/840] 20100412_국내출장비 신청 품의 _2002288.html
# 처리 중... [220/840] 20100412_동원예비군 훈련 참석으로 휴가 신청합니다._2002286.html
# 처리 중... [221/840] 20100412_메디슨_프로젝트_소프트웨어_발주신청_2002285.html
# 처리 중... [222/840] 20100412_아웃소싱 비용 결제 품의-LG화학기술연구원 실험실정보화_2002287.html
# 처리 중... [223/840] 20100413_김하응 휴가신청_2002289.html
# 처리 중... [224/840] 20100414_사내교통비 신청_2002290.html
# 처리 중... [225/840] 20100415_노트북메모리 구매 승인요청_2002291.html
# 처리 중... [226/840] 20100416_교통비 신청합니다._2002292.html
# 처리 중... [227/840] 20100419_4월 12일 출장비청구합니다(LG하우시스 PMS)_2002294.html
# 처리 중... [228/840] 20100419_LG 화학 특허분석리스크관리시스템 BM 출장비 청구_2002293.html
# 처리 중... [229/840] 20100419_시내교통비 신청 _2002296.html
# 처리 중... [230/840] 20100419_창원 한국전기원(4_5~4_15) 출장비_2002297.html
# 처리 중... [231/840] 20100419_휴가 사용 품의_2002295.html
# 처리 중... [232/840] 20100420_4월 아웃소싱 인건비 비용 결제 품의-R&D사업 1팀_2002301.html
# 처리 중... [233/840] 20100420_4월 아웃소싱 인건비 비용 결제 품의-R&D사업 2팀_2002302.html
# 처리 중... [234/840] 20100420_4월 아웃소싱 인건비 비용 결제 품의-기술지원부문_2002299.html
# 처리 중... [235/840] 20100420_4월 아웃소싱 인건비 비용 결제 품의-브레인밸류 H_C_2002303.html
# 처리 중... [236/840] 20100420_4월 아웃소싱 인건비 비용 결제 품의-솔루션사업부_2002300.html
# 처리 중... [237/840] 20100420_차원준 과장 입사 채용품의건_2002298.html
# 처리 중... [238/840] 20100421_NES 2010 정보보호 세미나 참석_2002311.html
# 처리 중... [239/840] 20100421_교통비 신청품의_2002307.html
# 처리 중... [240/840] 20100421_국내출장비 신청 품의-대전_2002304.html
# 처리 중... [241/840] 20100421_녹색인증 프로젝트 사기진작비 품의요청_2002309.html
# 처리 중... [242/840] 20100421_대우조선해양 제안참가용_2002312.html
# 처리 중... [243/840] 20100421_대전 LG화학기술연구원 고객 행사 참여 회식비 사용신청 품의의건._2002310.html
# 처리 중... [244/840] 20100421_병원진찰로 인해 반차휴가 요청합니다._2002306.html
# 처리 중... [245/840] 20100421_영업사원 품위유지 비용 요청건_2002305.html
# 처리 중... [246/840] 20100421_창원 한국전기원(4_12~4_20) 출장비_2002308.html
# 처리 중... [247/840] 20100422_4월 급여대장_2002314.html
# 처리 중... [248/840] 20100422_아웃소싱 선투입 품의 (제일모직)_2002313.html
# 처리 중... [249/840] 20100423_KMS 프로젝트 야근근무 식대신청합니다._2002318.html
# 처리 중... [250/840] 20100423_LG화학기술원 4월 교통비 청구합니다._2002317.html
# 처리 중... [251/840] 20100423_국내출장비 신청 품의(권순숙)_2002315.html
# 처리 중... [252/840] 20100423_연차휴가 품의요청_2002316.html
# 처리 중... [253/840] 20100426_2010년 계룡산 춘계행사 품의서_2002319.html
# 처리 중... [254/840] 20100426_LG화학 특허분석리스크관리시스템 외주인원 요청 (긴급)_2002320.html
# 처리 중... [255/840] 20100427_2010년 4월 법인카드 사용내역_2002323.html
# 처리 중... [256/840] 20100427_2010년 4월 법인카드 사용내역서_2002321.html
# 처리 중... [257/840] 20100427_4_2 법인카드 정지시 사용한 금액입니다._2002324.html
# 처리 중... [258/840] 20100427_LG TIPIS PI 인력투입관련품의_2002326.html
# 처리 중... [259/840] 20100427_국내출장_교통비 신청_2002325.html
# 처리 중... [260/840] 20100427_원니스 뉴스레터 발행지원사업_2002322.html
# 처리 중... [261/840] 20100427_창원 한국전기원(4_19~4_26) 출장비_2002327.html
# 처리 중... [262/840] 20100428_4월 법인 카드 실적보고_2002328.html
# 처리 중... [263/840] 20100428_RND 사업팀 마상미과장 휴가 사용 품의서_2002331.html
# 처리 중... [264/840] 20100428_교통비 신청 품의입니다._2002330.html
# 처리 중... [265/840] 20100428_국내출장비 신청 품의 - 20100428_2002332.html
# 처리 중... [266/840] 20100428_대전 LG화학기술연구원 SM 2010년 4월 CARD 사용내역 정산 보고(5021-2314-9983-1902)_2002334.html
# 처리 중... [267/840] 20100428_아웃소싱 선투입 품의 (녹색인증2차) - 재기안_2002333.html
# 처리 중... [268/840] 20100428_창원 출장 식대 선지급 요청_2002329.html
# 처리 중... [269/840] 20100429_2010년 4월 법인카드 사용내역_2002335.html
# 처리 중... [270/840] 20100429_2010년4월 법인카드 사용내역(법인카드로 변경건)_2002336.html
# 처리 중... [271/840] 20100429_PJT C_P 품의 (KIAT 기술선별시스템)_2002338.html
# 처리 중... [272/840] 20100429_한국전기원-안산분원(4_28) 출장비_2002339.html
# 처리 중... [273/840] 20100429_회식비 사용 신청 품의 (녹색인증 프로젝트)_2002337.html
# 처리 중... [274/840] 20100430_2010년 4월 법인카드 사용내역 (이형균)_2002341.html
# 처리 중... [275/840] 20100430_2010년 4월 카드사용내역 정산보고_편영수_2002340.html
# 처리 중... [276/840] 20100430_4월 교통비 사용내역건_2002349.html
# 처리 중... [277/840] 20100430_4월 접대비 사용 내역 건_2002347.html
# 처리 중... [278/840] 20100430_OCI 문서보안_매체제어 유지보수 계약건_2002346.html
# 처리 중... [279/840] 20100430_[기술연구부문-박정균]4월 법인카드 사용내역_2002343.html
# 처리 중... [280/840] 20100430_넥솔론 문서보안_매체제어 계약 건_2002344.html
# 처리 중... [281/840] 20100430_메디슨 주차비 지급 승인요청_2002342.html
# 처리 중... [282/840] 20100430_영업비용 사용건_2002348.html
# 처리 중... [283/840] 20100430_창원 한국전기원(4_19~4_22) 출장비_2002350.html
# 처리 중... [284/840] 20100430_한국타이어 문서보안 유지보수_2002345.html
# 처리 중... [285/840] 20100501_4월 법인카드 사용 내역서_2002351.html
# 처리 중... [286/840] 20100504_농업기술실용화재단_지재권통합관리시스템구축_견적서_2002352.html
# 처리 중... [287/840] 20100504_제일모직 프로젝트 야근식대 선지급 요청_2002353.html
# 처리 중... [288/840] 20100504_휴가 사용 품의-제주도 여행_2002354.html
# 처리 중... [289/840] 20100506_LG화학 특허분석리스크관리시스템 투입 인력 품의_2002355.html
# 처리 중... [290/840] 20100507_휴가 신청합니다. (2010_05_24)_2002356.html
# 처리 중... [291/840] 20100509_대전 LG화학기술연구원 SM 2010년 4월 CARD 사용내역 정산 보고(4265-8639-8922-0200)_2002357.html
# 처리 중... [292/840] 20100510_연차휴가 품의 신청_허지훈_2002358.html
# 처리 중... [293/840] 20100512_LG화학 특허분석리스크관리시스템 투입 인원 품의(조찬형K)_2002360.html
# 처리 중... [294/840] 20100512_야근식대(2010년 4월)_2002359.html
# 처리 중... [295/840] 20100513_KT목동 주차비 신청_2002363.html
# 처리 중... [296/840] 20100513_연차휴가 사용품의_2002361.html
# 처리 중... [297/840] 20100513_한국전기연구원 출장품의_2002362.html
# 처리 중... [298/840] 20100514_5월 18일 개인휴사 사용_2002364.html
# 처리 중... [299/840] 20100514_휴가 사용 품의_2002365.html
# 처리 중... [300/840] 20100517_개인휴가품의_2002367.html
# 처리 중... [301/840] 20100517_연차휴가 사용신청_2002366.html
# 처리 중... [302/840] 20100519_[기술연구부문 신입사원채용품의]_2002368.html
# 처리 중... [303/840] 20100520_5월 아웃소싱 인건비 지급 품의-R&D사업부 1팀_2002375.html
# 처리 중... [304/840] 20100520_5월 아웃소싱 인건비 지급 품의-R&D사업부 2팀_2002376.html
# 처리 중... [305/840] 20100520_5월 아웃소싱 인건비 지급 품의-기술지원부문_2002373.html
# 처리 중... [306/840] 20100520_5월 아웃소싱 인건비 지급 품의-브레인밸류 H_C_2002372.html
# 처리 중... [307/840] 20100520_5월 아웃소싱 인건비 지급 품의-솔루션사업부_2002374.html
# 처리 중... [308/840] 20100520_LGE PI 관련 - 시외출장비(대전청사) 교통비 신청_2002370.html
# 처리 중... [309/840] 20100520_LG화학 특허분석리스크관리시스템 투입 인원 품의(디자이너 한재훈 과장)_2002369.html
# 처리 중... [310/840] 20100520_고객사 담당자 부친상 조문건_2002377.html
# 처리 중... [311/840] 20100520_연차휴가 신청 (김하응 2010.05.31 ~ 2010.06.01) _2002371.html
# 처리 중... [312/840] 20100524_PJT C_P 품의 (제일모직 지재권시스템)_2002379.html
# 처리 중... [313/840] 20100524_식약청 연구관리시스템 유지보수사업 1월분 청구(아웃소싱)_2002378.html
# 처리 중... [314/840] 20100525_[한의학연구원] 통합연구관리시스템 1단계 구축 전자결재연동 외주아웃소싱건_2002382.html
# 처리 중... [315/840] 20100525_교육 신청 품의_2002381.html
# 처리 중... [316/840] 20100525_모바일_스마트폰 수익모델 및 신사업전략 세미나 참석_2002383.html
# 처리 중... [317/840] 20100525_휴가 사용 품의_2002380.html
# 처리 중... [318/840] 20100526_LG하우시스 PMS 개발 출장비 신청 품의(개인 사용 금액)_2002384.html
# 처리 중... [319/840] 20100526_운반비 신청(LG하우시스 검수확인서)_2002385.html
# 처리 중... [320/840] 20100527_ 2010년 5월 체크카드 사용내역서_2002387.html
# 처리 중... [321/840] 20100527_LG화학 특허분석리스크관리시스템 인력소싱 품의_2002392.html
# 처리 중... [322/840] 20100527_국내출장비 사용 품의-LG화학기술원_2002388.html
# 처리 중... [323/840] 20100527_대전 LG화학기술연구원 SM 2010년 5월 CARD 사용내역 정산 보고(4265-8639-8922-0200)_2002391.html
# 처리 중... [324/840] 20100527_비품_소매품 구매 청구_2002386.html
# 처리 중... [325/840] 20100527_시내교통비 신청_2002389.html
# 처리 중... [326/840] 20100528_2010년 5월 개인체크카드 사용내역(법인카드 한도초과로 대체사용 )_2002394.html
# 처리 중... [327/840] 20100528_2010년 5월 법인카드 사용내역_2002393.html
# 처리 중... [328/840] 20100528_5월 교통비 이용 내역_2002396.html
# 처리 중... [329/840] 20100528_5월 법인카드 사용 내역서_2002400.html
# 처리 중... [330/840] 20100528_5월 전기연구원 출장비 품의_2002399.html
# 처리 중... [331/840] 20100528_5월 접대비 사용내역_2002395.html
# 처리 중... [332/840] 20100528_AnyFive 회식비 지원 요청_2002397.html
# 처리 중... [333/840] 20100528_대전 사무실 임대 품의 및 가계약 지급 품의 (20만원)_2002398.html
# 처리 중... [334/840] 20100529_[대전] LG화학기술원 KMS 프로젝트 완료 휴가요청_2002401.html
# 처리 중... [335/840] 20100530_5월 잔업식대 신청합니다._2002403.html
# 처리 중... [336/840] 20100530_대전 LG화학 기술원 출장비 신청합니다._2002402.html
# 처리 중... [337/840] 20100531_2010년 5월 법인카드 사용내역 (이형균)_2002406.html
# 처리 중... [338/840] 20100531_5월법인카드사용내역 송부(박정균)_2002405.html
# 처리 중... [339/840] 20100531_법인카드 사용내역 정산 보고_2002404.html
# 처리 중... [340/840] 20100603_5월 아웃소싱 인건비 지급 품의-조정필씨_2002407.html
# 처리 중... [341/840] 20100604_대전 LG화학기술연구원 SM 2010년 5월 CARD 사용내역 정산 보고(5021-2314-9983-1902)_2002408.html
# 처리 중... [342/840] 20100607_6월 아웃소싱 인건비 지급 품의-조정필(조기철수 비용)_2002410.html
# 처리 중... [343/840] 20100607_시내교통비 신청 품의_2002411.html
# 처리 중... [344/840] 20100607_연차휴가 사용_2002409.html
# 처리 중... [345/840] 20100608_[품의] 대전지사 사무실 임대 및 사무실 집기 구매 품의_2002416.html
# 처리 중... [346/840] 20100608_교통비 품의 신청합니다._2002412.html
# 처리 중... [347/840] 20100608_야근식대(2010년 5월)_2002415.html
# 처리 중... [348/840] 20100608_키워드 광고 비용 결제_2002414.html
# 처리 중... [349/840] 20100608_휴일근무 식대품의 신청합니다._2002413.html
# 처리 중... [350/840] 20100609_휴가신청_2002417.html
# 처리 중... [351/840] 20100610_[휴가 품의]_2002418.html
# 처리 중... [352/840] 20100611_노트북 배터리 구매요청_2002419.html
# 처리 중... [353/840] 20100611_명합신청합니다.(김광희)_2002420.html
# 처리 중... [354/840] 20100614_기술연구소 사원 유정 사직서 제출 합니다._2002422.html
# 처리 중... [355/840] 20100614_연차휴가 사용 품의_2002421.html
# 처리 중... [356/840] 20100614_한국전기연구원 출장비 (이진근D)_2002423.html
# 처리 중... [357/840] 20100615_제일모직 프로젝트 야근식대 선지급 요청_2002424.html
# 처리 중... [358/840] 20100616_제증명서 발급품의 신청합니다._2002425.html
# 처리 중... [359/840] 20100616_휴가 사용 승인 요청_2002426.html
# 처리 중... [360/840] 20100617_6월 아웃소싱 인건비 지급 품의-R&D사업부 1팀_2002429.html
# 처리 중... [361/840] 20100617_6월 아웃소싱 인건비 지급 품의-R&D사업부 2팀_2002431.html
# 처리 중... [362/840] 20100617_6월 아웃소싱 인건비 지급 품의-기술지원부문_2002432.html
# 처리 중... [363/840] 20100617_6월 아웃소싱 인건비 지급 품의-브레인밸류 H_C_2002428.html
# 처리 중... [364/840] 20100617_6월 아웃소싱 인건비 지급 품의-솔루션사업부_2002430.html
# 처리 중... [365/840] 20100617_KIAT_온라인기술정보제작관리시스템개발 계약_2002427.html
# 처리 중... [366/840] 20100618_LG화학 특허분석리스크관리시스템 프로젝트 CP품의(재품의)_2002433.html
# 처리 중... [367/840] 20100618_연차 휴가사용 승인 요청드립니다._2002434.html
# 처리 중... [368/840] 20100622_노트북 메모리 구매 품의_2002435.html
# 처리 중... [369/840] 20100622_마우스 구매신청_2002436.html
# 처리 중... [370/840] 20100622_인센티브 지급 품의_2002437.html
# 처리 중... [371/840] 20100623_6월 급여대장_2002438.html
# 처리 중... [372/840] 20100623_재직증명서 발급 신청件_2002439.html
# 처리 중... [373/840] 20100624_영업비용 사용건_2002440.html
# 처리 중... [374/840] 20100625_6월 카드 사용 실적 보고_2002444.html
# 처리 중... [375/840] 20100625_예비군 훈련에 따른 휴가사용_2002441.html
# 처리 중... [376/840] 20100625_한국전기연구원 출장비 신청_2002442.html
# 처리 중... [377/840] 20100625_한의학연구원 출장비 품의_2002443.html
# 처리 중... [378/840] 20100627_6월 잔업식대 신청합니다._2002445.html
# 처리 중... [379/840] 20100628_2010년 6월 법인카드 사용내역 (이형균)_2002447.html
# 처리 중... [380/840] 20100628_[법인카드사용내역] 박정균_6월_2002446.html
# 처리 중... [381/840] 20100629_ 2010년 6월 체크카드 사용내역서_2002449.html
# 처리 중... [382/840] 20100629_2010년 6월 CARD 사용내역 정산 보고_편영수K_2002448.html
# 처리 중... [383/840] 20100629_6월 법인카드 사용내역 보고_2002458.html
# 처리 중... [384/840] 20100629_6월 접대비 사용내역_2002454.html
# 처리 중... [385/840] 20100629_국내 출장비 신청_2002450.html
# 처리 중... [386/840] 20100629_엘피온 문서보안_매체제어 계약품의_2002452.html
# 처리 중... [387/840] 20100629_오후휴가 신청합니다._2002453.html
# 처리 중... [388/840] 20100629_제안서 작성건으로 인한 파일서버 사용신청_2002451.html
# 처리 중... [389/840] 20100629_한국전기연구원 검색엔진 구매 비용 지급 품의_2002456.html
# 처리 중... [390/840] 20100629_한국전기연구원 도서관 특허정보 연계 비용 지급 품의_2002457.html
# 처리 중... [391/840] 20100629_한국전기연구원 인터페이스 개발 비용 지급 품의_2002455.html
# 처리 중... [392/840] 20100630_2010년 6월 법인카드 사용내역 정산 보고_2002460.html
# 처리 중... [393/840] 20100630_6월 29일 출장비 신청 품의(본사 출장)_2002461.html
# 처리 중... [394/840] 20100630_6월 시내교통비(주유) 신청건_2002462.html
# 처리 중... [395/840] 20100630_김하응_시내교통비 신청 _2002459.html
# 처리 중... [396/840] 20100630_야근근무 식대 신청서_허지훈_2002463.html
# 처리 중... [397/840] 20100701_6월 법인 카드 사용 보고_2002464.html
# 처리 중... [398/840] 20100701_아웃소싱 선투입 품의 (녹색인증2차)_2002465.html
# 처리 중... [399/840] 20100705_서울반도체 마크프로 온라인연계 구축 견적서 품의요청합니다._2002466.html
# 처리 중... [400/840] 20100705_파일서버 접근 권한 요청_2002467.html
# 처리 중... [401/840] 20100707_DRM시스템 추가 구입건_2002468.html
# 처리 중... [402/840] 20100707_기술지원팀 회식비 지원요청합니다._2002469.html
# 처리 중... [403/840] 20100707_예비군 연기 신청으로 인한 재직증명서 발급 결재 부탁드립니다._2002470.html
# 처리 중... [404/840] 20100708_국내출장교통비 신청합니다._2002472.html
# 처리 중... [405/840] 20100708_대전 진민동 사원숙소 임대기간 연장건_2002473.html
# 처리 중... [406/840] 20100708_직원회식비용 처리건_2002471.html
# 처리 중... [407/840] 20100709_노트북 LCD 패널 고장에 따른 수리신청 품의._2002475.html
# 처리 중... [408/840] 20100709_병가 신청_2002474.html
# 처리 중... [409/840] 20100709_한의학 연구원 프로젝트 지원 출장비 품의_2002476.html
# 처리 중... [410/840] 20100712_휴가 사용 품의_2002477.html
# 처리 중... [411/840] 20100713_[식약청] 연구관리시스템 기능개선사업 CP품의 건_2002479.html
# 처리 중... [412/840] 20100713_야근식대(2010년 6월)_2002478.html
# 처리 중... [413/840] 20100714_[대전지사] 대전지역 근무 자사직원을 위한 회식비 사용 신청 검_2002481.html
# 처리 중... [414/840] 20100714_노틸러스효성 지재권관리시스템 구축 계약_2002482.html
# 처리 중... [415/840] 20100714_노틸러스효성_지재권관리솔루션(iPIMS) 공급_CP_2002480.html
# 처리 중... [416/840] 20100715_제일모직 프로젝트 야근식대 선지급 요청_2002483.html
# 처리 중... [417/840] 20100716_2010년 하계휴가 일정입니다._2002489.html
# 처리 중... [418/840] 20100716_[식약청] 연구관리시스템 기능개선 사업-PDF변환 솔루션 탑재PC구매건_2002487.html
# 처리 중... [419/840] 20100716_[식약청]연구관리시스템 기능개선사업-고속스캐너 구매건_2002488.html
# 처리 중... [420/840] 20100716_제일모직 회식비 신청_2002484.html
# 처리 중... [421/840] 20100716_제증명서 발급 신청 품의_2002486.html
# 처리 중... [422/840] 20100716_특허포트폴리오 투입 인원 이력서 _2002485.html
# 처리 중... [423/840] 20100719_7월 아웃소싱 인건비 지급 품의-R&D사업부 1팀_2002495.html
# 처리 중... [424/840] 20100719_7월 아웃소싱 인건비 지급 품의-R&D사업부 2팀_2002496.html
# 처리 중... [425/840] 20100719_7월 아웃소싱 인건비 지급 품의-기술지원부문_2002493.html
# 처리 중... [426/840] 20100719_7월 아웃소싱 인건비 지급 품의-브레인밸류 H_C_2002492.html
# 처리 중... [427/840] 20100719_7월 아웃소싱 인건비 지급 품의-솔루션사업부_2002494.html
# 처리 중... [428/840] 20100719_제출용 근로소득원천징수영증 발급 신청_2002490.html
# 처리 중... [429/840] 20100719_현대중공업 차년도 기능제안으로 인한 출장비를 요청드립니다._2002491.html
# 처리 중... [430/840] 20100720_식품의약품안전평가원 연구관리시스템 기능개선사업 아웃소싱인력 투입품의건_2002497.html
# 처리 중... [431/840] 20100721_마크애니 김병섭 전무 부친상 부의금 신청_2002498.html
# 처리 중... [432/840] 20100721_메디슨 iPIMS 공급 프로젝트 종료 C_P 품의_2002499.html
# 처리 중... [433/840] 20100722_2010년 2_4분기 부가세 _2002503.html
# 처리 중... [434/840] 20100722_7월 급여대장_2002502.html
# 처리 중... [435/840] 20100722_[결제품의]식약청 연구관리시스템 기능개선 사업-PDF변환 솔루션 탑재 PC_2002504.html
# 처리 중... [436/840] 20100722_선영프로젝트 식대 결재 부탁드립니다._2002505.html
# 처리 중... [437/840] 20100722_소모품 구입비 품의 올립니다._2002501.html
# 처리 중... [438/840] 20100722_퇴직 품의 올립니다._2002500.html
# 처리 중... [439/840] 20100723_2010년 하기휴가 신청_2002509.html
# 처리 중... [440/840] 20100723_2010년 하기휴가 신청_2002510.html
# 처리 중... [441/840] 20100723_[품의] 하계휴가등 사용 품의 (2010.08.02 ~ 13)_2002508.html
# 처리 중... [442/840] 20100723_여름휴가 신청_2002507.html
# 처리 중... [443/840] 20100723_하기휴가 사용 품의_2002506.html
# 처리 중... [444/840] 20100726_2010년 7월 CARD 사용내역 정산 보고-이형균_2002514.html
# 처리 중... [445/840] 20100726_[LG U+ 특허시스템 개선 프로젝트 CP 품의]_2002511.html
# 처리 중... [446/840] 20100726_[하계휴가품의]_2002515.html
# 처리 중... [447/840] 20100726_아이피큐브파트너스 CP품의_2002512.html
# 처리 중... [448/840] 20100726_영문번역료 지급품의_2002516.html
# 처리 중... [449/840] 20100726_하기휴가 사용 품의_2002513.html
# 처리 중... [450/840] 20100727_LG화학기술원 특허경영포토폴리오프로젝트 개발자(백승덕)자사인력채용 건_2002518.html
# 처리 중... [451/840] 20100727_[교육품의] K-IFRS 해설 및 무형자산(기술;지식 등) 가치평가 실무과정_2002517.html
# 처리 중... [452/840] 20100727_법인카드 사용내역 정산 보고 (2010년 7월)_2002519.html
# 처리 중... [453/840] 20100728_7월 시내교통비(주유) 사용내역건_2002523.html
# 처리 중... [454/840] 20100728_7월 접대비 사용내역_2002521.html
# 처리 중... [455/840] 20100728_[발주품의]식약청 연구관리시스템 기능개선-PDF변환 솔루션_2002524.html
# 처리 중... [456/840] 20100728_[아웃소싱인력 계약연장품의]_2002522.html
# 처리 중... [457/840] 20100728_주성엔지니어링 접대비 신청_2002520.html
# 처리 중... [458/840] 20100729_ 2010년 7월 체크카드 사용내역서_2002525.html
# 처리 중... [459/840] 20100729_7월 법인카드 정산 보고서_2002529.html
# 처리 중... [460/840] 20100729_[7월 법인카드사용내역_박정균]_2002527.html
# 처리 중... [461/840] 20100729_[인력아웃소싱 품의]_2002530.html
# 처리 중... [462/840] 20100729_발명진흥회 IP-MART개선 CP품의_2002528.html
# 처리 중... [463/840] 20100729_법인카드 사용내역(7월) 보고_2002526.html
# 처리 중... [464/840] 20100730_2010년 하계휴가 사용품의_2002532.html
# 처리 중... [465/840] 20100730_출장 교통비 신청_2002531.html
# 처리 중... [466/840] 20100802_2010년 7월 CARD 사용내역 정산 보고_2002533.html
# 처리 중... [467/840] 20100802_LG화학 특허분석리스크관리프로젝트 외주개발자 소싱 요청(검색엔진전문가)_2002536.html
# 처리 중... [468/840] 20100802_[이메일신청]식약청 신규개발투입인원 이메일 신청합니다._2002537.html
# 처리 중... [469/840] 20100802_김성권_2002535.html
# 처리 중... [470/840] 20100802_하드디스크 구매 품의(KIAT)_2002534.html
# 처리 중... [471/840] 20100803_LG화학 특허분석리스크관리프로젝트 CP변경 품의_2002539.html
# 처리 중... [472/840] 20100803_재직증명서 발급신청_2002540.html
# 처리 중... [473/840] 20100803_한국산업기술진흥원 녹색인증2단계 CP 품의_2002538.html
# 처리 중... [474/840] 20100804_2010년 여름휴가 품의요청_2002541.html
# 처리 중... [475/840] 20100805_금년 하기휴가 신청합니다_2002542.html
# 처리 중... [476/840] 20100805_하계휴가신청 (8_2 ~ 8_5)_2002543.html
# 처리 중... [477/840] 20100806_고객사(KIAT)출입을 위한 재직증명서 사본요청_2002545.html
# 처리 중... [478/840] 20100806_엘피온 계약에 대한  할인요청건_2002544.html
# 처리 중... [479/840] 20100809_야근식대(2010년 7월)_2002546.html
# 처리 중... [480/840] 20100810_DRM 매체제어시스템 구축(엘피온) 대금지급 _2002548.html
# 처리 중... [481/840] 20100810_DRM 시스템 구축(넥솔론) 대금지급 품의_2002549.html
# 처리 중... [482/840] 20100810_LG화학 특허분석리스크관리프로젝트 CP변경 품의_2002547.html
# 처리 중... [483/840] 20100810_[대전 지역] SI사업 인력투입계획_2002550.html
# 처리 중... [484/840] 20100810_실험실정보화부문 닷넷 개발자 전문인력 채용계획 품의_2002551.html
# 처리 중... [485/840] 20100811_(이진근D) 연차휴가를 신청합니다._2002554.html
# 처리 중... [486/840] 20100811_LG화학 특허분석리스크관리프로젝트 CP변경 품의_2002556.html
# 처리 중... [487/840] 20100811_주성엔지니어링 접대비 신청_2002552.html
# 처리 중... [488/840] 20100811_특허분석리스크 인원운영 합의 사항_2002555.html
# 처리 중... [489/840] 20100811_휴가 신청_2002553.html
# 처리 중... [490/840] 20100812_[자사채용요청품의] 하이닉스 연구소 운영인력 채용요청 품의 (중급)_2002557.html
# 처리 중... [491/840] 20100812_국내 출장비 신청(교통비)_2002558.html
# 처리 중... [492/840] 20100812_국내출장비 신청 품의_2002559.html
# 처리 중... [493/840] 20100813_2010-08-14 주말근무 신청 품의_2002561.html
# 처리 중... [494/840] 20100813_주성엔지니어링 지식재산통합관리시스템 CP 품의_2002560.html
# 처리 중... [495/840] 20100816_ IPMART 웹표준 소스 _2002563.html
# 처리 중... [496/840] 20100816_IPMART 영문사이트 구축 - 디자인 이미지 구입_2002562.html
# 처리 중... [497/840] 20100816_[파일서버] 계정신청_2002564.html
# 처리 중... [498/840] 20100816_국내출장비 신청 품의(대전 출장)_2002565.html
# 처리 중... [499/840] 20100817_8월 아웃소싱 인건비 지급 품의-R&D사업부_2002572.html
# 처리 중... [500/840] 20100817_8월 아웃소싱 인건비 지급 품의-기술지원부문_2002570.html
# 처리 중... [501/840] 20100817_8월 아웃소싱 인건비 지급 품의-솔루션사업부_2002571.html
# 처리 중... [502/840] 20100817_사무용가구 렌탈 비용_2002568.html
# 처리 중... [503/840] 20100817_사용중인 노트북PC 노후화로 인한 변경 구매 품의._2002569.html
# 처리 중... [504/840] 20100817_영업비용 품의_2002567.html
# 처리 중... [505/840] 20100817_특허분석리스크관리 프로젝트 8월이후 운영계획(8월 17일)_2002566.html
# 처리 중... [506/840] 20100819_8월 아웃소싱 인건비 지급 품의-브레인밸류 H_C_2002573.html
# 처리 중... [507/840] 20100819_[LG전자 특허시스템 TIPIS개선 Project C_P품의]_2002574.html
# 처리 중... [508/840] 20100819_예비군 훈련_2002575.html
# 처리 중... [509/840] 20100820_대전지역 프로젝트 인력운영계획 _2002576.html
# 처리 중... [510/840] 20100820_퇴직서_2002577.html
# 처리 중... [511/840] 20100824_[품의] 선영특허법률사무소 업무포털시스템 구축 프로젝트 인센티브 지급건_2002579.html
# 처리 중... [512/840] 20100824_한국전기연구원(창원) 출장 품의_2002578.html
# 처리 중... [513/840] 20100825_김하응_노트북교체_품의_2002581.html
# 처리 중... [514/840] 20100825_자산(노트북) 구매 품의_2002582.html
# 처리 중... [515/840] 20100825_재직증명서발급신청 의 건 (장명훈)_2002580.html
# 처리 중... [516/840] 20100826_재직증명서 _ 원천징수 요청합니다._2002583.html
# 처리 중... [517/840] 20100826_한국전기연구원(창원) 출장비 품의_2002584.html
# 처리 중... [518/840] 20100830_2010년 8월 CARD 사용내역 정산 보고_편영수K_2002593.html
# 처리 중... [519/840] 20100830_2010년 8월 체크카드 사용내역서_2002592.html
# 처리 중... [520/840] 20100830_8월 법인카드 정산 보고_2002586.html
# 처리 중... [521/840] 20100830_8월법인카드사용내역_2002587.html
# 처리 중... [522/840] 20100830_[결제품의]식약청 연구관리시스템 기능개선 사업-PDF변환 솔루션 선급금 지급_2002588.html
# 처리 중... [523/840] 20100830_[결제품의]키워드 광고비 결제-오버추어코리아_2002590.html
# 처리 중... [524/840] 20100830_대전 지사 비품_소모품 구매 품의 요청합니다._2002595.html
# 처리 중... [525/840] 20100830_법인카드 사용재역 정산보고 (2010년 8월)_2002591.html
# 처리 중... [526/840] 20100830_법인카드 정산 품의(8월분)_박정균_2002596.html
# 처리 중... [527/840] 20100830_연차휴가 사용신청_2002585.html
# 처리 중... [528/840] 20100830_전자연구노트 출장비 8월분 신청합니다._2002594.html
# 처리 중... [529/840] 20100830_접대비 품의_2002589.html
# 처리 중... [530/840] 20100831_[LG전자 Project 출입증 발급용 증명서 발행요청]_2002598.html
# 처리 중... [531/840] 20100831_[식약청]회식비 신청합니다._2002600.html
# 처리 중... [532/840] 20100831_영업비용 사용 신청건_2002597.html
# 처리 중... [533/840] 20100831_이테크건설 문서보안 유지보수 계약 건_2002599.html
# 처리 중... [534/840] 20100901_8월 교통비 사용내역_2002601.html
# 처리 중... [535/840] 20100901_[결제품의]PATINEX 2010 참가비 결제-한국특허정보원_2002607.html
# 처리 중... [536/840] 20100901_국내 출장비 신청(교통비)_2002602.html
# 처리 중... [537/840] 20100901_명합신청_2002603.html
# 처리 중... [538/840] 20100901_반차 휴가 신청_허지훈_2002605.html
# 처리 중... [539/840] 20100901_서버 계정 사용신청 _2002606.html
# 처리 중... [540/840] 20100901_이천 하이닉스 반도체 인터뷰 출장 품의_2002604.html
# 처리 중... [541/840] 20100902_8월 접대비 사용내역 재상신_2002608.html
# 처리 중... [542/840] 20100902_반차 사용 품의_2002610.html
# 처리 중... [543/840] 20100902_이천 하이닉스 반도체 인터뷰 출장 품의_2002609.html
# 처리 중... [544/840] 20100903_이천 하이닉스 근무자 숙소 품의_2002611.html
# 처리 중... [545/840] 20100906_2010년 8월 CARD 사용내역 정산 보고-이형균_2002613.html
# 처리 중... [546/840] 20100906_노틸러스효성 특허시스템 데이터 이관 출장비 신청 품의._2002614.html
# 처리 중... [547/840] 20100906_녹색인증2차_법인카드사용내역정산보고_김하응_2002612.html
# 처리 중... [548/840] 20100907_[견적서]LG하우시스 보아니(전용웹) 유지보수(2011년 예산)_2002619.html
# 처리 중... [549/840] 20100907_[견적서]실트론 특허시스템 유지보수(2011년 예산)_2002618.html
# 처리 중... [550/840] 20100907_[전자연구노트 3개 기관 개선] 대전지사 파견 관련 비용처리 품의_2002617.html
# 처리 중... [551/840] 20100907_한의학 2차과제 제안서 작성 및 8월 실적회의 참석 출장비 법인카드 사용 품의_2002615.html
# 처리 중... [552/840] 20100907_효성 데이터이관_한의학제안등 출장 2010년 8월 CARD 사용내역 정산 보고(4265-8639-8922-0283)_2002616.html
# 처리 중... [553/840] 20100908_[메일계정신청]식약청 신규인력 계정신청합니다._2002621.html
# 처리 중... [554/840] 20100908_야근식대(2010년 8월)_2002620.html
# 처리 중... [555/840] 20100909_[휴가품의] 하계휴가 일부 사용 품의_2002625.html
# 처리 중... [556/840] 20100909_상여금 지급 품의 _2002627.html
# 처리 중... [557/840] 20100909_신혼여행 연차휴가 품의 요청_2002623.html
# 처리 중... [558/840] 20100909_신혼여행 휴가 품의요청_2002622.html
# 처리 중... [559/840] 20100909_직원 명절 선물 비용지급_2002626.html
# 처리 중... [560/840] 20100909_퇴직서_2002624.html
# 처리 중... [561/840] 20100910_추석연휴 연차휴가 사용 요청_2002628.html
# 처리 중... [562/840] 20100913_김하응차장  연차휴가신청_2002631.html
# 처리 중... [563/840] 20100913_연차휴가 사용신청_2002629.html
# 처리 중... [564/840] 20100913_휴가 사용 품의_2002630.html
# 처리 중... [565/840] 20100914_[발명진흥회 IP-MART 개선 인력 지원 품의]_2002634.html
# 처리 중... [566/840] 20100914_[품의] 연차사용 신청_2002632.html
# 처리 중... [567/840] 20100914_[품의] 연차사용 신청_2002633.html
# 처리 중... [568/840] 20100915_9월 아웃소싱 인건비 지급 품의-대전지사_2002638.html
# 처리 중... [569/840] 20100915_9월 아웃소싱 인건비 지급 품의-브레인밸류 H_C_2002639.html
# 처리 중... [570/840] 20100915_9월 아웃소싱 인건비 지급 품의-사업팀_2002637.html
# 처리 중... [571/840] 20100915_9월 아웃소싱 인건비 지급 품의-전문가Gr._2002636.html
# 처리 중... [572/840] 20100915_[품의] 대전 한국한의학연구원 PM 및 대전지역 개발리더 역할자 채용 품의 _2002635.html
# 처리 중... [573/840] 20100915_휴가 신청합니다. (2010_09_20)_2002640.html
# 처리 중... [574/840] 20100916_LG 전자 TIPIS 개선 프로젝트 소모품 구입 품의_2002644.html
# 처리 중... [575/840] 20100916_[품의]연차 사용신청_2002645.html
# 처리 중... [576/840] 20100916_교육훈련 신청 품의_2002647.html
# 처리 중... [577/840] 20100916_연차휴가 사용 품의_2002641.html
# 처리 중... [578/840] 20100916_한국산업기술진흥원 녹색인증2단계 변경 CP 품의_2002646.html
# 처리 중... [579/840] 20100916_한국석유공사 문서보안시스템 구축 계약건_2002642.html
# 처리 중... [580/840] 20100916_휴가 신청건_2002643.html
# 처리 중... [581/840] 20100917_9월 아웃소싱 인건비 지급 품의-기술지원Gr._2002650.html
# 처리 중... [582/840] 20100917_[재품의]아웃소싱 인원 투입 품의-선영 업무포탈 구축_2002649.html
# 처리 중... [583/840] 20100917_연차 휴가 사용 승인요청 _2002651.html
# 처리 중... [584/840] 20100917_연차휴가 신청합니다._2002648.html
# 처리 중... [585/840] 20100918_8월 급여대장_2002652.html
# 처리 중... [586/840] 20100918_연차휴가 사용 품의_2002653.html
# 처리 중... [587/840] 20100926_하이닉스 가을야유회 참가비 신청_2002654.html
# 처리 중... [588/840] 20100927_CISSP과정 교육출장 신청건_2002655.html
# 처리 중... [589/840] 20100928_9월 법인 카드 사용 정산 보고_2002656.html
# 처리 중... [590/840] 20100928_[LG화학_기술연구원] 서울 트윈빌딩 출장_2002658.html
# 처리 중... [591/840] 20100928_[결제품의]회사 간판 신규 제작 건_2002657.html
# 처리 중... [592/840] 20100928_예비군 훈련으로 인한 휴가신청 품의 입니다._2002659.html
# 처리 중... [593/840] 20100929_2010년 9월 CARD 사용내역 정산 보고-이형균_2002667.html
# 처리 중... [594/840] 20100929_2010년 9월 CARD 사용내역 정산 보고_편영수K_2002665.html
# 처리 중... [595/840] 20100929_9월 교통비 사용 내역_2002661.html
# 처리 중... [596/840] 20100929_9월 접대비 사용내역_2002662.html
# 처리 중... [597/840] 20100929_[재직증명서발급요청]_2002660.html
# 처리 중... [598/840] 20100929_국내 출장비 신청(교통비)_2002664.html
# 처리 중... [599/840] 20100929_재직증명서 발급신청_2002663.html
# 처리 중... [600/840] 20100929_재직증명서 발급요청_2002666.html
# 처리 중... [601/840] 20100930_[식약청]9월야근식대 품의요청합니다._2002669.html
# 처리 중... [602/840] 20100930_전자연구노트 출장비 신청_2002670.html
# 처리 중... [603/840] 20100930_제증명서 발급 신청합니다._2002668.html
# 처리 중... [604/840] 20101001_2010년 9월 법인카드 사용내역 정산 보고_2002673.html
# 처리 중... [605/840] 20101001_9월비용정산내역_2002671.html
# 처리 중... [606/840] 20101001_녹색인증제시스템_카드정산보고(2010.09.01 ~ 2010.09.30)_2002676.html
# 처리 중... [607/840] 20101001_재직증명서 발급 요청_2002672.html
# 처리 중... [608/840] 20101001_카드사용내역_2002674.html
# 처리 중... [609/840] 20101001_프로젝트 경비 비용 지출 품의_2002675.html
# 처리 중... [610/840] 20101002_[9월 법인카드사용내역_박정균]_2002677.html
# 처리 중... [611/840] 20101003_9월 식대 신청_2002678.html
# 처리 중... [612/840] 20101004_[연장계약]LG화학 특허 포트폴리오 PJT-조찬형과장 연장_2002679.html
# 처리 중... [613/840] 20101004_야근식대(2010년 9월)_2002680.html
# 처리 중... [614/840] 20101005_9월 잔업식대 품의_2002682.html
# 처리 중... [615/840] 20101005_[결제품의]LG전자 IP 축구대회 회비_2002681.html
# 처리 중... [616/840] 20101006_[식약청]파일 업로드 기술지원 견적품의입니다._2002685.html
# 처리 중... [617/840] 20101006_접대비 신청(노틸러스효성)_2002683.html
# 처리 중... [618/840] 20101006_하이닉스 HC 시스템 구축 프로젝트 고객 미팅 출장비 신청 품의._2002684.html
# 처리 중... [619/840] 20101007_2차 방문]하이닉스 HC 시스템 구축 프로젝트 고객 미팅 출장비 신청 품의._2002687.html
# 처리 중... [620/840] 20101007_휴가 사용 품의_2002686.html
# 처리 중... [621/840] 20101011_CISSP교육 출장비 신청件_2002689.html
# 처리 중... [622/840] 20101011_국내출장비 신청 품의(권순숙)_2002688.html
# 처리 중... [623/840] 20101011_노틸러스 효성PJT 진행시 발생한 시내교통비 신청품의_2002690.html
# 처리 중... [624/840] 20101012_21일 축구 경기 참가 경비 신청_2002694.html
# 처리 중... [625/840] 20101012_[LG화학_기술연구원] 서울 트윈 타워 출장 신청서_2002693.html
# 처리 중... [626/840] 20101012_[재기안]아웃소싱 인원 투입 품의-LG화학기술연구원 실험실 2단계_2002691.html
# 처리 중... [627/840] 20101012_아웃소싱 인원 투입 품의-식약청 NTIS 연계 구축_2002692.html
# 처리 중... [628/840] 20101013_LG전자 TIPIS 프로젝트 팀 회식비 사용신청_2002695.html
# 처리 중... [629/840] 20101013_[결제품의]PATINEX 2010  비품 임대비 결제_2002697.html
# 처리 중... [630/840] 20101013_[결제품의]메디슨 iPIMS 구축-검색엔진 구매_2002696.html
# 처리 중... [631/840] 20101013_교통비 청구_2002698.html
# 처리 중... [632/840] 20101015_[그룹웨어 계정신청] 기술지원그룹 이형진 대리 계정 승인요청 _2002699.html
# 처리 중... [633/840] 20101015_국내출장 비용 청구서_2002700.html
# 처리 중... [634/840] 20101018_10월 아웃소싱 인건비 지급 품의-기술지원Gr._2002704.html
# 처리 중... [635/840] 20101018_10월 아웃소싱 인건비 지급 품의-대전지사_2002707.html
# 처리 중... [636/840] 20101018_10월 아웃소싱 인건비 지급 품의-사업팀_2002705.html
# 처리 중... [637/840] 20101018_10월 아웃소싱 인건비 지급 품의-전문가Gr._2002706.html
# 처리 중... [638/840] 20101018_LG화학기술연구원 실험실자동화시스템 구축(2단계) C_P 품의_2002708.html
# 처리 중... [639/840] 20101018_[품의] 연차사용품의 (2010.10.18 월 - 오전 반차)_2002701.html
# 처리 중... [640/840] 20101018_국내출장비 신청 품의(권순숙)_2002703.html
# 처리 중... [641/840] 20101018_직원 채용 품의-김현숙_2002702.html
# 처리 중... [642/840] 20101019_야근근무 식대 신청서_2002710.html
# 처리 중... [643/840] 20101019_연차휴가 사용신청_2002709.html
# 처리 중... [644/840] 20101020_기술지원그룹 사기진작비 사전 승인요청 _2002711.html
# 처리 중... [645/840] 20101021_접대비_중식_2002712.html
# 처리 중... [646/840] 20101022_2010년 3_4분기 부가세 품의_2002715.html
# 처리 중... [647/840] 20101022_9월 급여지급 품의_2002714.html
# 처리 중... [648/840] 20101022_[결제품의]KIAT 녹색인증 구축 2단계-디자인팜(잔금 부분)_2002713.html
# 처리 중... [649/840] 20101025_LG화학실험실자동화구축2차 회식비 사용 신청 품의(20101025)_2002719.html
# 처리 중... [650/840] 20101025_[IPIMS] 코드사이닝 인증서 만료에 따른 갱신 승인요청 _2002721.html
# 처리 중... [651/840] 20101025_국내출장비 신청 품의 (외주 김현주 과장)_2002722.html
# 처리 중... [652/840] 20101025_대전지사 PC 구매 품의_2002716.html
# 처리 중... [653/840] 20101025_연차 휴가 품의_2002720.html
# 처리 중... [654/840] 20101025_주성엔지니어링 PJT 회식비 신청합니다._2002717.html
# 처리 중... [655/840] 20101025_주성엔지니어링 검색엔진 구매요청드립니다._2002718.html
# 처리 중... [656/840] 20101026_[결제품의]한마음 체육대회-대행업체 계약금_2002723.html
# 처리 중... [657/840] 20101026_교통비청구_2002724.html
# 처리 중... [658/840] 20101027_10월 30일 체육행사 불참 품의_2002726.html
# 처리 중... [659/840] 20101027_2010년 10월 체크카드 사용내역서_2002725.html
# 처리 중... [660/840] 20101027_SWCM 관련 인원 회식_2002727.html
# 처리 중... [661/840] 20101027_[결제품의]벤처기업대상 시상식 사진 구매_2002728.html
# 처리 중... [662/840] 20101027_[휴가사용품의] 김화연 대리 시조모상_2002729.html
# 처리 중... [663/840] 20101028_국내출장비 청구_2002730.html
# 처리 중... [664/840] 20101028_대전신규입사자 환영회(20101012) 회식비용 정산 요청_2002731.html
# 처리 중... [665/840] 20101028_외조모상 휴가_2002732.html
# 처리 중... [666/840] 20101029_10월 야근식대 신청합니다._2002738.html
# 처리 중... [667/840] 20101029_LG전자 Project 경비사용 신청합니다._2002734.html
# 처리 중... [668/840] 20101029_[발명진흥회 IP MART개선과제 통합검색모듈 도급품의]_2002736.html
# 처리 중... [669/840] 20101029_[연차휴가 사용품의]_2002737.html
# 처리 중... [670/840] 20101029_국내출장비 신청 품의 (외주 김현주 과장)_2002735.html
# 처리 중... [671/840] 20101029_법인카드 사용 내역 정산 보고_2002733.html
# 처리 중... [672/840] 20101029_식약청 음료구매 품의요청합니다._2002739.html
# 처리 중... [673/840] 20101102_10월 교통비 사용내역_2002746.html
# 처리 중... [674/840] 20101102_10월 접대비 사용내역_2002747.html
# 처리 중... [675/840] 20101102_10월경비정산내역_2002751.html
# 처리 중... [676/840] 20101102_2010년 10월 CARD 사용내역 정산 보고_2002752.html
# 처리 중... [677/840] 20101102_2010년 10월 법인카드 사용내역 정산 보고_2002745.html
# 처리 중... [678/840] 20101102_[10월 법인카드 사용내역 보고] 박정균_2002744.html
# 처리 중... [679/840] 20101102_[결제품의]주성엔지니어링 iPIMS 구축-아웃소싱 인건비 결제_2002741.html
# 처리 중... [680/840] 20101102_[결제품의]한마음 체육대회 총 소요비용 및 결제 품의_2002742.html
# 처리 중... [681/840] 20101102_국내출장비 신청(교통비)_2002753.html
# 처리 중... [682/840] 20101102_김하응_시내교통비(녹색인증제시스템)_20101029_2002748.html
# 처리 중... [683/840] 20101102_녹색인증제시스템구축_체크카드사용내역서_20101001~20101030_2002749.html
# 처리 중... [684/840] 20101102_주성엔지니어링_영업비용 사용 신청_2002740.html
# 처리 중... [685/840] 20101102_휴가 신청件_2002750.html
# 처리 중... [686/840] 20101102_휴가(오전 반차) 사용 품의_2002743.html
# 처리 중... [687/840] 20101103_[결제품의]KIAT 녹색인증 구축 2단계-디자인팜(추가 비용 부분)_2002754.html
# 처리 중... [688/840] 20101103_연차휴가 사용신청(11_10)_2002755.html
# 처리 중... [689/840] 20101104_2010년 10월 법인 카드 사용 내역 보고 _2002758.html
# 처리 중... [690/840] 20101104_R&D 특허센터 고객 접대비 관련 사후 품의요청_2002757.html
# 처리 중... [691/840] 20101104_기술지원팀 업무처리관련 Remote Call 서비스 사용 재계약 품의 드립니다. _2002756.html
# 처리 중... [692/840] 20101105_법인카드 10월 정산 보고 (김은영)_2002759.html
# 처리 중... [693/840] 20101105_야근식대(2010년 10월)_2002760.html
# 처리 중... [694/840] 20101106_휴가신쳥 품의 입니다._2002761.html
# 처리 중... [695/840] 20101108_[보고] 법인카드 정산 (2010.10)_2002764.html
# 처리 중... [696/840] 20101108_[품의] 식품의약품안전평가원 - 연구관리시스템 NTIS 연계 CP 품의_2002762.html
# 처리 중... [697/840] 20101108_[품의] 식품의약품안전평가원 - 연구관리시스템 기능개선 (CP 변경품의)_2002763.html
# 처리 중... [698/840] 20101108_[품의] 하이닉스 H_C 구축 - 맨인 도급 계약서 작성 품의_2002765.html
# 처리 중... [699/840] 20101109_10월 야근 식대 신청_2002766.html
# 처리 중... [700/840] 20101110_대전지사 공용 하드디스크 구매 요청_2002767.html
# 처리 중... [701/840] 20101111_2010년 10월 CARD 사용내역 정산 보고_이형균_2002768.html
# 처리 중... [702/840] 20101111_hynix 특허대리인 변리수가 정산제 개선 프로젝트 법인카드 발급 신청._2002769.html
# 처리 중... [703/840] 20101112_[주성엔지니어링] 검색엔진 DRM문제 해결관련 용역비품의_2002770.html
# 처리 중... [704/840] 20101115_[10월]회식비 품의신청합니다._2002774.html
# 처리 중... [705/840] 20101115_김하응차장_연차휴가 신청_2002773.html
# 처리 중... [706/840] 20101115_체육대회 상품 관부가세 품의_2002771.html
# 처리 중... [707/840] 20101115_휴가 신청_2002772.html
# 처리 중... [708/840] 20101116_[결제품의]아웃소싱 인건비 지급 품의-김득환(한의학 개발자)_2002780.html
# 처리 중... [709/840] 20101116_[구매품의]대전지사 공유 H_D 구매_2002781.html
# 처리 중... [710/840] 20101116_김하응차장_연차휴가(반차) 요청_2002776.html
# 처리 중... [711/840] 20101116_번역비용 지급 품의_2002777.html
# 처리 중... [712/840] 20101116_출장품의서(원진희)_2002779.html
# 처리 중... [713/840] 20101116_출장품의서_2002778.html
# 처리 중... [714/840] 20101116_퇴직품의_2002775.html
# 처리 중... [715/840] 20101117_노트북 LCD 패널 수리비용 품의_2002783.html
# 처리 중... [716/840] 20101117_연차휴가 사용_2002782.html
# 처리 중... [717/840] 20101118_11월 아웃소싱 인건비 지급 품의-경영기획팀(브레인밸류 H_C))_2002793.html
# 처리 중... [718/840] 20101118_11월 아웃소싱 인건비 지급 품의-경영기획팀(연간 계약인원)_2002787.html
# 처리 중... [719/840] 20101118_11월 아웃소싱 인건비 지급 품의-기술지원Gr.(김화연대리)_2002791.html
# 처리 중... [720/840] 20101118_11월 아웃소싱 인건비 지급 품의-대전지사(김은영차장)_2002792.html
# 처리 중... [721/840] 20101118_11월 아웃소싱 인건비 지급 품의-사업팀(박정균수석)_2002790.html
# 처리 중... [722/840] 20101118_11월 아웃소싱 인건비 지급 품의-영업팀(김대화이사)_2002789.html
# 처리 중... [723/840] 20101118_11월 아웃소싱 인건비 지급 품의-전문가Gr.(김성수이사)_2002788.html
# 처리 중... [724/840] 20101118_[구매품의]주성엔지니어링 iPIMS 구축-검색엔진 및 DRM 연동 개발_2002794.html
# 처리 중... [725/840] 20101118_[품의] 한국연구재단 제안발표 참석으로 인하여 출장신청합니다._2002786.html
# 처리 중... [726/840] 20101118_식약청 출장품의 신청합니다._2002784.html
# 처리 중... [727/840] 20101118_휴가 사용 신청件_2002785.html
# 처리 중... [728/840] 20101119_퇴직품의_2002795.html
# 처리 중... [729/840] 20101122_[결제품의]식약청 연구관리시스템 기능개선 사업-글루시스(PDF변환 Customizing)_2002799.html
# 처리 중... [730/840] 20101122_연차휴가 사용(11_24) _2002796.html
# 처리 중... [731/840] 20101122_전자연구노트 프로젝트 출장 품의서_2002798.html
# 처리 중... [732/840] 20101122_퇴직금 중간정산 지급품의_2002797.html
# 처리 중... [733/840] 20101123_11월 급여대장_2002802.html
# 처리 중... [734/840] 20101123_[구매품의]한국한의학연구원 통합연구관리 구축 2단계-전자결재연동(SNT)_2002801.html
# 처리 중... [735/840] 20101123_[프로젝트 인센티브 품의] 발명진흥회 IP-MART개선_2002806.html
# 처리 중... [736/840] 20101123_[프로젝트인센티브 추천품의] 주성엔지니어링 프로젝트 수행 인센티브품의_2002804.html
# 처리 중... [737/840] 20101123_[프로젝트인센티브추천품의] 아이피큐브파트너스_2002805.html
# 처리 중... [738/840] 20101123_전자연구노트 프로젝트 출장비 정산 품의_2002803.html
# 처리 중... [739/840] 20101123_휴가 사용 승인 요청_2002800.html
# 처리 중... [740/840] 20101124_11월법인카드정산_2002810.html
# 처리 중... [741/840] 20101124_[11월]비용품의 신청합니다._2002809.html
# 처리 중... [742/840] 20101124_선영 프로젝트 야근식대 경비사용 신청품의_2002808.html
# 처리 중... [743/840] 20101124_연차신청(병원치료)_2002807.html
# 처리 중... [744/840] 20101125_11월 교통비 품의_2002817.html
# 처리 중... [745/840] 20101125_11월 법인카드 사용내역 정산 보고_2002818.html
# 처리 중... [746/840] 20101125_11월 아웃소싱 인건비 지급 품의-장소영씨건_2002812.html
# 처리 중... [747/840] 20101125_[계약품의]R&D특허센터 전자연구노트 활성화를 위한 홈페이지 구축 건_2002816.html
# 처리 중... [748/840] 20101125_김하응-연차신청(병원치료)_2002813.html
# 처리 중... [749/840] 20101125_출산휴가를 신청합니다._2002815.html
# 처리 중... [750/840] 20101125_회식비 사용 신청 품의_2002814.html
# 처리 중... [751/840] 20101125_휴가 신청합니다. (2010_12_03)_2002819.html
# 처리 중... [752/840] 20101125_휴가를 요청합니다._2002811.html
# 처리 중... [753/840] 20101126_주성엔지니어링(경기도)의 출장비를 신청합니다._2002820.html
# 처리 중... [754/840] 20101129_11월 야근식대 신청합니다._2002823.html
# 처리 중... [755/840] 20101129_2010년 11월 CARD 사용내역 정산 보고_이형균_2002825.html
# 처리 중... [756/840] 20101129_[11월]회식비 품의신청합니다._2002824.html
# 처리 중... [757/840] 20101129_[계약품의]GS홀딩스 상표출원관리시스템 유지보수의 건_2002827.html
# 처리 중... [758/840] 20101129_신입사원 교육 지원 도서 구입 승인요청 _2002822.html
# 처리 중... [759/840] 20101129_전자연구노트 기술지원 경비 신청합니다._2002821.html
# 처리 중... [760/840] 20101129_휴가 사용 신청 품의-병원 진료_2002828.html
# 처리 중... [761/840] 20101129_휴가 신청합니다. (2010_12_06)_2002826.html
# 처리 중... [762/840] 20101130_11월 법인카드 사용 결재 요청 건._2002829.html
# 처리 중... [763/840] 20101130_[식약청]오송출장 법인카드 신청품의_2002832.html
# 처리 중... [764/840] 20101130_쇼핑백 제작_2002831.html
# 처리 중... [765/840] 20101130_연차휴가 품의 신청_2002830.html
# 처리 중... [766/840] 20101201_[2010_11월 박정균 법인카드사용내역]_2002833.html
# 처리 중... [767/840] 20101201_[결제품의]키워드 광고비 결제-오버추어코리아_2002835.html
# 처리 중... [768/840] 20101201_법인카드 사용내역 정산 보고 (2010년 11월)_2002834.html
# 처리 중... [769/840] 20101201_서울 출장 - 여의도 트윈빌딩 (LG화학 본사)_2002836.html
# 처리 중... [770/840] 20101202_2010년 11월 CARD 사용내역 정산 보고_2002839.html
# 처리 중... [771/840] 20101202_[계약품의]유지선(프리랜서) 투입_계약 품의-LG전자 G-TIPIS 구축_2002840.html
# 처리 중... [772/840] 20101202_[계약품의]최명식(다른정보기술) 투입_계약 품의-한국한의학연구원(조찬형 대체)_2002841.html
# 처리 중... [773/840] 20101202_국내출장경비 청구_2002837.html
# 처리 중... [774/840] 20101202_국내출장비 신청(교통비)_2002842.html
# 처리 중... [775/840] 20101202_김하응_체크카드사용내역서_20101101~20101130(재기안)_2002843.html
# 처리 중... [776/840] 20101202_법인카드사용내역 정산(11월)_2002838.html
# 처리 중... [777/840] 20101203_11월 법인카드 정산 보고_2002846.html
# 처리 중... [778/840] 20101203_2010년 11월 야근근무식대신청서 _2002845.html
# 처리 중... [779/840] 20101203_[결제품의]식약청 NTIS연계 구축 사업-우인시스템_2002844.html
# 처리 중... [780/840] 20101206_휴가 사용 품의_2002847.html
# 처리 중... [781/840] 20101207_12월 아웃소싱 인건비 지급 품의-김득환(한국한의학연구원)_2002848.html
# 처리 중... [782/840] 20101209_야근식대(2010년 11월)_2002849.html
# 처리 중... [783/840] 20101209_휴가 사용건에 대한 선월차 후결재_2002850.html
# 처리 중... [784/840] 20101210_R&D특허센터 홈페이지 구축사업 CP 품의_2002851.html
# 처리 중... [785/840] 20101210_쇼핑백 구매 _2002852.html
# 처리 중... [786/840] 20101212_김하응-시내교통비 요청 (20101212)_2002853.html
# 처리 중... [787/840] 20101213_국내출장비 신청 품의_2002854.html
# 처리 중... [788/840] 20101213_이성권-모니터구매요청(본사 유휴장비 사용가능)_2002855.html
# 처리 중... [789/840] 20101214_[계약품의]하이닉스반도체 특허 H_C 구축-김성현,박승한,최은현_2002856.html
# 처리 중... [790/840] 20101214_퇴직신청합니다._2002857.html
# 처리 중... [791/840] 20101215_12월 17일 워크샵 참석 국내출장비 품의_2002859.html
# 처리 중... [792/840] 20101215_퇴직금 정산 지급품의_2002858.html
# 처리 중... [793/840] 20101216_LG전자 G-TIPIS 구축 견적서_2002861.html
# 처리 중... [794/840] 20101216_전자연구노트 프로젝트 출장비 정산 품의_2002860.html
# 처리 중... [795/840] 20101219_경비신청-김하응(1220)_2002862.html
# 처리 중... [796/840] 20101220_명함신청_2002863.html
# 처리 중... [797/840] 20101221_12월 아웃소싱 인건비 지급 품의-경영기획팀(연간 계약인원)_2002866.html
# 처리 중... [798/840] 20101221_12월 아웃소싱 인건비 지급 품의-사업팀(박정균)_2002868.html
# 처리 중... [799/840] 20101221_12월 아웃소싱 인건비 지급 품의-사업팀(최성민_2002870.html
# 처리 중... [800/840] 20101221_12월 아웃소싱 인건비 지급 품의-전문가Gr.(김규일)_2002865.html
# 처리 중... [801/840] 20101221_12월 아웃소싱 인건비 지급 품의-전문가Gr.(김성수)_2002867.html
# 처리 중... [802/840] 20101221_12월 아웃소싱 인건비 지급 품의-전문가Gr.(이형균)_2002869.html
# 처리 중... [803/840] 20101221_로플렉스법률실사 자문료 결재 품의_2002871.html
# 처리 중... [804/840] 20101221_우리회계법인 간이실사 용역비 결재 품의_2002864.html
# 처리 중... [805/840] 20101222_[결제품의]프로젝트 구매비 지급 품의_2002873.html
# 처리 중... [806/840] 20101222_휴가 사용 품의 _2002872.html
# 처리 중... [807/840] 20101223_12월 급여 지급 품의_2002875.html
# 처리 중... [808/840] 20101223_12월 급여 지급 품의_2002877.html
# 처리 중... [809/840] 20101223_LG전자 송년회 회식비 후품의 신청_2002874.html
# 처리 중... [810/840] 20101223_세미나 비용신청_2002876.html
# 처리 중... [811/840] 20101224_LG전자 SI관련 간식비 품의요청_2002878.html
# 처리 중... [812/840] 20101224_[결제품의]상표출원 대리인 수수료 및 관납료-smartLAB_KBrain_2002879.html
# 처리 중... [813/840] 20101225_김하응(1224)-교통비신청(톨게이트비)_2002880.html
# 처리 중... [814/840] 20101227_국내출장비 신청 품의_2002881.html
# 처리 중... [815/840] 20101228_2010년 12월 CARD 사용내역 정산 보고_이형균_2002884.html
# 처리 중... [816/840] 20101228_[김화연] 2010.12월 체크카드 사용내역 정산 보고_2002886.html
# 처리 중... [817/840] 20101228_[출장비품의] 12월 품의요청합니다._2002885.html
# 처리 중... [818/840] 20101228_그랜져TG 자동차세 건._2002883.html
# 처리 중... [819/840] 20101228_책상 및 파티션 외 구입 건 (11층 사무실 설치용)_2002882.html
# 처리 중... [820/840] 20101228_하이닉스 변리수가정산제 개선 프로젝트 2010년 12월 CARD 사용내역 정산 보고(5021-2314-9982-6902)_2002887.html
# 처리 중... [821/840] 20101229_12월 법인카드사용내역 정산 보고_2002889.html
# 처리 중... [822/840] 20101229_12월 카드 사용내역 정산 보고-김동력_2002888.html
# 처리 중... [823/840] 20101229_2010년 12월 체크카드 사용내역서_2002896.html
# 처리 중... [824/840] 20101229_[결제품의]식약청 NTIS 연계- 개발 지원(우인시스템)_2002893.html
# 처리 중... [825/840] 20101229_[결제품의]식약청 연구관리시스템 기능 개선-PDF솔루션(정상네트워크)_2002894.html
# 처리 중... [826/840] 20101229_[결제품의]식약청 연구관리시스템 기능개선 사업-글루시스(PDF변환 Customizing)_2002895.html
# 처리 중... [827/840] 20101229_[품의] 하이닉스 특허 H_C 구축 프로젝트_2002890.html
# 처리 중... [828/840] 20101229_국내출장비 신청 품의 - 20101229_2002891.html
# 처리 중... [829/840] 20101229_김하응_체크카드사용내역서_20101201~20101229_2002898.html
# 처리 중... [830/840] 20101229_법인카드 사용내역 정산 보고 - 201012_2002892.html
# 처리 중... [831/840] 20101229_솔루션 사업부 대전지사 이주헌 대리 퇴직 품의_2002897.html
# 처리 중... [832/840] 20101229_원룸 숙소 임차 건._2002899.html
# 처리 중... [833/840] 20101230_2010년 12월 CARD 사용내역 정산 보고_2002900.html
# 처리 중... [834/840] 20101230_2010년도 결산, 세무조정 및 장부기장 법인 변경 건._2002904.html
# 처리 중... [835/840] 20101230_[교통비 품의 청구_ 하이닉스 방문]_2002903.html
# 처리 중... [836/840] 20101230_[법인카드사용내역 정산보고 12월_박정균]_2002902.html
# 처리 중... [837/840] 20101230_[잔업식대] 12월 식약청 잔업식대품의_2002905.html
# 처리 중... [838/840] 20101230_국내출장비 신청(교통비)_2002901.html
# 처리 중... [839/840] 20101231_2010년 12월 법인카드 사용내역 정산_2002906.html
# 처리 중... [840/840] 20101231_법인카드 사용내역 정산 보고(10월,11월,12월)_2002907.html
# JSON 파일 저장 완료: two_htmltojsondb_convert.json
#
# ==================================================
#
# === DB 연결 시작 ===
# Host: localhost, Database: any_approval
# ✓ DB 연결 성공
#
# === 테이블 생성 시작 ===
# ✓ 테이블 생성/확인 완료
# ✓ 기존 데이터: 22466건
#
# === 데이터 삽입 시작 (840건) ===
#   진행: 100/840 (성공: 100, 실패: 0)
#   진행: 200/840 (성공: 200, 실패: 0)
#   진행: 300/840 (성공: 300, 실패: 0)
#   진행: 400/840 (성공: 400, 실패: 0)
#   진행: 500/840 (성공: 500, 실패: 0)
#   진행: 600/840 (성공: 600, 실패: 0)
#   진행: 700/840 (성공: 700, 실패: 0)
#   진행: 800/840 (성공: 800, 실패: 0)
#   진행: 840/840 (성공: 840, 실패: 0)
#
# === 커밋 시작 ===
# ✓ 커밋 완료
#
# === 결과 요약 ===
# ✓ 성공: 840건
# ✗ 실패: 0건
#
# ✓ 최종 데이터: 23306건 (이번 실행으로 840건 추가)
#
# ✓ DB 연결 종료
# ==================================================
#
# 완료! 총 840건 처리됨
