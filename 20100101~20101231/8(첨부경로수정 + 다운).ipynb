# %%
# 첨부파일 경로 변환 - any_approval DB 전자결재 문서용
# documents 테이블의 attaches 컬럼 처리
# end_year로 연도별 필터링

import json
import os
import shutil
from pathlib import Path
import pymysql
from sqlalchemy import create_engine

# ==================== DB 설정 ====================
USER = "root"
PASS = "1234"
HOST = "127.0.0.1"
PORT = 3306
DB = "any_approval"  # ✨ 변경

# ==================== 설정 영역 (여기를 수정하세요) ====================

# 종료연도 (필터링용)
END_YEAR = 2010  # ✨ 변경: 2025, 2024, 2023 등

# 첨부파일 원본 경로들 - 여러 경로 추가 가능
BASE_FILE_PATHS = [
    # r"C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\apr",  # ✨ brd → apr
    # r"C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\apr",  # ✨ brd → apr
    # r"C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\apr",  # ✨ brd → apr
    r"C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr",  # ✨ brd → apr
    # 더 추가하고 싶으면 여기에 계속 추가
]

# 첨부파일 복사본 저장 폴더 (연도별로 자동 생성)
OUTPUT_FILE_FOLDER = rf"C:\Users\LEEJUHWAN\Downloads\approval_{END_YEAR}_attachments"  # ✨ 변경

# path에서 제거할 접두사 (이 부분을 제거하고 상대경로로 변경)
REMOVE_PREFIX = r"C:\Users\LEEJUHWAN\Downloads"

# ======================================================================


def find_attachment_folder(doc_id):
    """여러 경로에서 첨부파일 폴더 찾기"""
    for base_path in BASE_FILE_PATHS:
        attachment_folder = Path(base_path) / doc_id
        if attachment_folder.exists():
            return attachment_folder
    return None


def find_file_in_folder(folder, filename):
    """폴더 내에서 파일명과 일치하는 파일 찾기 (대소문자 구분 없음)"""
    if not folder or not folder.exists():
        return None
    
    # 정확한 파일명으로 먼저 찾기
    target_file = folder / filename
    if target_file.exists() and target_file.is_file():
        return target_file
    
    # 대소문자 구분 없이 찾기
    for file in folder.iterdir():
        if file.is_file() and file.name.lower() == filename.lower():
            return file
    
    return None


def process_single_document_attachments(data, doc_index):
    """하나의 document의 첨부파일 처리"""
    
    # source_id에서 문서ID 추출
    source_id = data.get('source_id', '')  # ✨ sourceId → source_id
    if not source_id:
        print(f"⚠️ [{doc_index}] source_id 없음, 건너뜀")
        return data
    
    doc_id = source_id  # ✨ lstrip('_') 제거, 그대로 사용
    
    # attaches 배열 확인
    attaches = data.get('attaches', [])
    if not attaches:
        return data  # 첨부파일 없으면 그대로 반환
    
    # 여러 경로에서 첨부파일 폴더 찾기
    attachment_folder = find_attachment_folder(doc_id)
    
    if not attachment_folder:
        print(f"⚠️ [{doc_index}] 문서ID {doc_id} 폴더 없음 (모든 경로 검색 완료)")
        # 폴더가 없으면 모든 첨부파일의 path를 공란으로
        for attach in attaches:
            attach['path'] = ''
        return data
    
    # 복사본 저장할 문서별 폴더 생성
    output_doc_folder = Path(OUTPUT_FILE_FOLDER) / f"apr{doc_id}"  # ✨ brd → apr
    output_doc_folder.mkdir(parents=True, exist_ok=True)
    
    print(f"\n📄 [{doc_index}] 문서ID: {doc_id}")
    print(f"   원본: {attachment_folder}")
    print(f"   복사: {output_doc_folder}")
    print(f"   ✅ 첨부파일 {len(attaches)}개 발견")
    
    # 각 첨부파일 처리
    processed_attaches = []
    copied_count = 0
    
    for idx, attach in enumerate(attaches):
        filename = attach.get('name', '')
        if not filename:
            print(f"      ⚠️ [{idx}] 파일명 없음 - path 공란 처리")
            attach['path'] = ''
            processed_attaches.append(attach)
            continue
        
        # 원본 폴더에서 파일 찾기
        source_file = find_file_in_folder(attachment_folder, filename)
        
        if source_file:
            # 복사본 파일 경로
            dest_file = output_doc_folder / filename
            
            # 파일 복사
            try:
                shutil.copy2(source_file, dest_file)
                copied_count += 1
                print(f"      ✅ {filename}")
                
                # path를 상대경로로 변경 (REMOVE_PREFIX 제거)
                new_path = str(dest_file).replace('\\', '/')
                if REMOVE_PREFIX:
                    new_path = new_path.replace(REMOVE_PREFIX.replace('\\', '/'), '').lstrip('/')
                    new_path = new_path.replace(REMOVE_PREFIX, '').lstrip('\\')
                
                attach['path'] = new_path
                
            except Exception as e:
                print(f"      ❌ {filename} 복사 실패: {e}")
                attach['path'] = ''
        else:
            print(f"      ⚠️ 파일 없음: {filename} - path 공란 처리")
            attach['path'] = ''
        
        processed_attaches.append(attach)
    
    print(f"   📊 복사 완료: {copied_count}/{len(attaches)}개")
    
    # 수정된 attaches 적용
    data['attaches'] = processed_attaches
    return data


def process_db(end_year):
    """DB에서 특정 end_year의 데이터만 읽고 처리 후 DB에 업데이트"""
    
    # 출력 폴더 생성
    os.makedirs(OUTPUT_FILE_FOLDER, exist_ok=True)
    
    # DB 연결
    print(f"📂 DB 연결 중...")
    print(f"📂 종료연도: {end_year}")  # ✨ 변경
    print(f"📂 검색할 첨부파일 경로: {len(BASE_FILE_PATHS)}개\n")
    
    connection = pymysql.connect(
        host=HOST,
        user=USER,
        password=PASS,
        database=DB,
        port=PORT,
        charset='utf8mb4'
    )
    
    try:
        with connection.cursor(pymysql.cursors.DictCursor) as cursor:
            # 1. DB에서 특정 end_year의 데이터만 읽기
            query = "SELECT * FROM documents WHERE end_year = %s"  # ✨ 변경
            cursor.execute(query, (end_year,))
            documents = cursor.fetchall()  # ✨ posts → documents
            
            total_count = len(documents)
            print(f"✅ 총 {total_count}개의 documents 발견\n")
            
            # 2. 각 document 처리
            success_count = 0
            total_attachments = 0
            
            for idx, doc in enumerate(documents, 1):  # ✨ post → doc
                try:
                    # ✨ attaches 파싱 (이미 JSON이면 그대로, 문자열이면 loads)
                    attaches_data = doc.get('attaches', [])
                    if isinstance(attaches_data, str):
                        doc['attaches'] = json.loads(attaches_data)
                    else:
                        doc['attaches'] = attaches_data if attaches_data else []
                    
                    # 첨부파일이 있는 경우만 카운트
                    if doc.get('attaches'):
                        total_attachments += len(doc.get('attaches'))
                    
                    # 기존 로직 그대로 사용
                    result = process_single_document_attachments(doc, idx)
                    
                    # attaches가 변경된 경우 DB 업데이트
                    if result.get('attaches'):
                        # attaches를 JSON 문자열로 변환
                        attaches_json = json.dumps(result['attaches'], ensure_ascii=False)
                        
                        update_query = """
                            UPDATE documents 
                            SET attaches = %s 
                            WHERE source_id = %s AND end_year = %s
                        """  # ✨ board_posts → documents, attaches_json → attaches, sourceId → source_id, type → end_year
                        cursor.execute(update_query, (attaches_json, result['source_id'], end_year))
                        success_count += 1
                    
                except Exception as e:
                    print(f"❌ [Document {idx}] 처리 오류: {e}")
                    continue
            
            # 변경사항 커밋
            connection.commit()
            
            print(f"\n{'='*60}")
            print(f"✅ 처리 완료!")
            print(f"   - 종료연도: {end_year}")  # ✨ 변경
            print(f"   - 첨부파일 있는 documents: {success_count}개")
            print(f"   - 총 첨부파일 개수: {total_attachments}개")
            print(f"   - 복사된 파일 위치: {OUTPUT_FILE_FOLDER}")
            print(f"   - DB 테이블: documents (attaches 컬럼 업데이트)")  # ✨ 변경
            print(f"{'='*60}")
    
    finally:
        connection.close()
        print("\n✅ DB 연결 종료")


# 실행
if __name__ == "__main__":
    process_db(END_YEAR)  # ✨ BOARD_TYPE → END_YEAR
# Out:
# 📂 DB 연결 중...
# 📂 종료연도: 2010
# 📂 검색할 첨부파일 경로: 1개
#
# ✅ 총 840개의 documents 발견
#
#
# 📄 [11] 문서ID: 2002076
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002076
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002076
#    ✅ 첨부파일 1개 발견
#       ✅ Re 보고자사 솔루션에 대한 Demo 내역 및 정리 방안.htm
#    📊 복사 완료: 1/1개
#
# 📄 [14] 문서ID: 2002082
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002082
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002082
#    ✅ 첨부파일 1개 발견
#       ✅ 식품의약품안전평가원_연구관리시스템운영_견적서(20100122).xls
#    📊 복사 완료: 1/1개
#
# 📄 [16] 문서ID: 2002080
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002080
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002080
#    ✅ 첨부파일 1개 발견
#       ✅ eRND_A.3.2.1.자원관리_v1.2(20090121).xls
#    📊 복사 완료: 1/1개
#
# 📄 [20] 문서ID: 2002087
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002087
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002087
#    ✅ 첨부파일 1개 발견
#       ✅ KT_iPIMS공급_CP(V2.3.3)_20100126.xls
#    📊 복사 완료: 1/1개
#
# 📄 [21] 문서ID: 2002089
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002089
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002089
#    ✅ 첨부파일 1개 발견
#       ✅ 팬택_특허시스템유지보수(20100125)v1.0.doc
#    📊 복사 완료: 1/1개
#
# 📄 [27] 문서ID: 2002092
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002092
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002092
#    ✅ 첨부파일 1개 발견
#       ✅ 연구관리시스템추가구축사업-경비내역-100125.xls
#    📊 복사 완료: 1/1개
#
# 📄 [28] 문서ID: 2002094
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002094
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002094
#    ✅ 첨부파일 1개 발견
#       ✅ LG화학기술연구원_특허자산관리시스템구축_CP(V2.3)_20100115.xls
#    📊 복사 완료: 1/1개
#
# 📄 [32] 문서ID: 2002096
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002096
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002096
#    ✅ 첨부파일 2개 발견
#       ✅ HDS_시스템공급내역서.xls
#       ✅ 소디프DRM시스템구축 계약(현대HDS_애니파이브).doc
#    📊 복사 완료: 2/2개
#
# 📄 [33] 문서ID: 2002099
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002099
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002099
#    ✅ 첨부파일 1개 발견
#       ✅ 윤상호_법인카드사용신청서(201001).ppt
#    📊 복사 완료: 1/1개
#
# 📄 [34] 문서ID: 2002100
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002100
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002100
#    ✅ 첨부파일 2개 발견
#       ✅ 야근근무식대신청서_박천석_201001.ppt
#       ✅ 야근근무식대신청서_장명훈_201001.ppt
#    📊 복사 완료: 2/2개
#
# 📄 [47] 문서ID: 2002113
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002113
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002113
#    ✅ 첨부파일 1개 발견
#       ✅ 유지보수상세내역서.xls
#    📊 복사 완료: 1/1개
#
# 📄 [53] 문서ID: 2002118
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002118
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002118
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브_법인카드사용내역상세(201001)(김대화_보고용).xls
#    📊 복사 완료: 1/1개
#
# 📄 [60] 문서ID: 2002129
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002129
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002129
#    ✅ 첨부파일 2개 발견
#       ✅ 비밀유지 서약서_퇴사시.doc
#       ✅ 사직서.hwp
#    📊 복사 완료: 2/2개
#
# 📄 [68] 문서ID: 2002134
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002134
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002134
#    ✅ 첨부파일 1개 발견
#       ✅ 연구관리시스템추가구축사업-경비내역-100205.xls
#    📊 복사 완료: 1/1개
#
# 📄 [74] 문서ID: 2002142
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002142
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002142
#    ✅ 첨부파일 2개 발견
#       ✅ BP 표준계약서(Live Form)_10년 2월_애니파이브시스템.doc
#       ✅ BP 표준계약서(세라템)_10년 2월_애니파이브시스템.doc
#    📊 복사 완료: 2/2개
#
# 📄 [75] 문서ID: 2002140
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002140
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002140
#    ✅ 첨부파일 1개 발견
#       ✅ (테르텐)영업파트너계약서_애니파이브시스템-100217.doc
#    📊 복사 완료: 1/1개
# ⚠️ [78] 문서ID 2002144 폴더 없음 (모든 경로 검색 완료)
#
# 📄 [83] 문서ID: 2002150
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002150
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002150
#    ✅ 첨부파일 1개 발견
#       ✅ LG화학기술연구원_실험실정보화시스템구축_CP(V3.0.0)_20100219.xls
#    📊 복사 완료: 1/1개
#
# 📄 [89] 문서ID: 2002155
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002155
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002155
#    ✅ 첨부파일 1개 발견
#       ✅ 코아로직_특허유지보수_계약서(20100205).doc
#    📊 복사 완료: 1/1개
#
# 📄 [102] 문서ID: 2002167
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002167
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002167
#    ✅ 첨부파일 1개 발견
#       ✅ 메디슨_iPIMS구축건_CP(V3.0.0)_20100226.xls
#    📊 복사 완료: 1/1개
#
# 📄 [106] 문서ID: 2002177
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002177
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002177
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201002)_김기두.xls
#    📊 복사 완료: 1/1개
#
# 📄 [112] 문서ID: 2002171
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002171
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002171
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브_법인카드사용내역상세(201002)(김대화_보고용).xls
#    📊 복사 완료: 1/1개
#
# 📄 [123] 문서ID: 2002190
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002190
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002190
#    ✅ 첨부파일 1개 발견
#       ✅ 메디슨_iPIMS공급_계약서(20100305).doc
#    📊 복사 완료: 1/1개
#
# 📄 [125] 문서ID: 2002191
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002191
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002191
#    ✅ 첨부파일 2개 발견
#       ✅ Scan20001.JPG
#       ✅ 휴직원-양기훈.hwp
#    📊 복사 완료: 2/2개
#
# 📄 [132] 문서ID: 2002198
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002198
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002198
#    ✅ 첨부파일 1개 발견
#       ✅ 소디프DRM시스템구축 계약(애니파이브_마크애니).doc
#    📊 복사 완료: 1/1개
# ⚠️ [135] 문서ID 2002200 폴더 없음 (모든 경로 검색 완료)
# ⚠️ [138] 문서ID 2002203 폴더 없음 (모든 경로 검색 완료)
#
# 📄 [162] 문서ID: 2002227
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002227
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002227
#    ✅ 첨부파일 1개 발견
#       ✅ 주성엔지니어링_IPIMS_견적서(20100322).xls
#    📊 복사 완료: 1/1개
#
# 📄 [164] 문서ID: 2002230
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002230
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002230
#    ✅ 첨부파일 1개 발견
#       ✅ 한국산업기술진흥원_녹색인증제정보시스템구축_CP(V3_0_0)_20100318.xls
#    📊 복사 완료: 1/1개
#
# 📄 [165] 문서ID: 2002232
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002232
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002232
#    ✅ 첨부파일 1개 발견
#       ✅ 한국발명진흥회_인터넷기술장터개선(수요자중심형기술거래시스템개편)_견적서(20100323).xls
#    📊 복사 완료: 1/1개
#
# 📄 [167] 문서ID: 2002234
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002234
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002234
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년 3월급여대장(20100319).xls
#    📊 복사 완료: 1/1개
#
# 📄 [170] 문서ID: 2002233
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002233
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002233
#    ✅ 첨부파일 1개 발견
#       ✅ 경비사용내역서(20100324).doc
#    📊 복사 완료: 1/1개
#
# 📄 [184] 문서ID: 2002255
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002255
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002255
#    ✅ 첨부파일 1개 발견
#       ✅ 한의학 통합연구관리1차-카드사용내역-201010년03월.xls
#    📊 복사 완료: 1/1개
#
# 📄 [189] 문서ID: 2002254
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002254
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002254
#    ✅ 첨부파일 1개 발견
#       ✅ 오라클자바교육센터 자바교육과정.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [194] 문서ID: 2002261
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002261
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002261
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201003)_김기두.xls
#    📊 복사 완료: 1/1개
#
# 📄 [211] 문서ID: 2002277
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002277
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002277
#    ✅ 첨부파일 1개 발견
#       ✅ 농업기술실용화재단_지재권솔루션(iPIMS)_견적서(20100406).xls
#    📊 복사 완료: 1/1개
#
# 📄 [215] 문서ID: 2002281
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002281
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002281
#    ✅ 첨부파일 2개 발견
#       ✅ ANYFIVE_발주서_제품(20100407).xls
#       ✅ 물품 공급 및 기술 지원 계약서_애니파이브시스템.doc
#    📊 복사 완료: 2/2개
#
# 📄 [218] 문서ID: 2002284
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002284
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002284
#    ✅ 첨부파일 1개 발견
#       ✅ 전기연구원 특허정보연계 견적서_링크소프트.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [221] 문서ID: 2002285
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002285
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002285
#    ✅ 첨부파일 1개 발견
#       ✅ 메디슨_발주서_SW(20100413).xls
#    📊 복사 완료: 1/1개
#
# 📄 [242] 문서ID: 2002312
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002312
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002312
#    ✅ 첨부파일 4개 발견
#       ✅ [공통]IT_RFP_양식2.doc
#       ✅ [공통]IT_RFP_양식3.doc
#       ✅ [공통]IT_RFP_양식4.doc
#       ✅ [공통]IT_RFP_양식5.doc
#    📊 복사 완료: 4/4개
#
# 📄 [247] 문서ID: 2002314
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002314
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002314
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년 4월급여대장(20100413).xls
#    📊 복사 완료: 1/1개
#
# 📄 [251] 문서ID: 2002315
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002315
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002315
#    ✅ 첨부파일 1개 발견
#       ✅ 경비지출내역_20100406.xls
#    📊 복사 완료: 1/1개
#
# 📄 [255] 문서ID: 2002323
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002323
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002323
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201004)_김성수.xls
#    📊 복사 완료: 1/1개
#
# 📄 [260] 문서ID: 2002322
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002322
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002322
#    ✅ 첨부파일 1개 발견
#       ✅ 원니스_특허분쟁정보 뉴스레터_견적서(20100427).xls
#    📊 복사 완료: 1/1개
#
# 📄 [269] 문서ID: 2002335
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002335
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002335
#    ✅ 첨부파일 1개 발견
#       ✅ 한의학 통합연구관리1차-카드사용내역-201010년04월.xls
#    📊 복사 완료: 1/1개
#
# 📄 [271] 문서ID: 2002338
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002338
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002338
#    ✅ 첨부파일 1개 발견
#       ✅ KIAT_기술선별시스템 구축(기능개선)_CP(V3.1.0)_20100429.xls
#    📊 복사 완료: 1/1개
#
# 📄 [275] 문서ID: 2002340
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002340
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002340
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201004)_편영수.xls
#    📊 복사 완료: 1/1개
#
# 📄 [276] 문서ID: 2002349
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002349
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002349
#    ✅ 첨부파일 1개 발견
#       ✅ 회사 교통비(주유 외)사용 내역(4월).xls
#    📊 복사 완료: 1/1개
#
# 📄 [277] 문서ID: 2002347
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002347
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002347
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201004)_김기두.xls
#    📊 복사 완료: 1/1개
#
# 📄 [278] 문서ID: 2002346
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002346
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002346
#    ✅ 첨부파일 1개 발견
#       ✅ 유지보수_현대HDS-(OCI).doc
#    📊 복사 완료: 1/1개
#
# 📄 [280] 문서ID: 2002344
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002344
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002344
#    ✅ 첨부파일 1개 발견
#       ✅ 현대HDS(넥솔론 문서보안계약)_0419 - 애니파이브시스템.doc
#    📊 복사 완료: 1/1개
#
# 📄 [284] 문서ID: 2002345
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002345
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002345
#    ✅ 첨부파일 1개 발견
#       ✅ 유지보수 계약서(현대HDS-한국타이어문서보안).doc
#    📊 복사 완료: 1/1개
#
# 📄 [286] 문서ID: 2002352
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002352
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002352
#    ✅ 첨부파일 1개 발견
#       ✅ 농업기술실용화재단_지재권통합관리시스템구축_견적서(20100504).xls
#    📊 복사 완료: 1/1개
#
# 📄 [312] 문서ID: 2002379
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002379
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002379
#    ✅ 첨부파일 1개 발견
#       ✅ 제일모직 지식재산권시스템 구축_CP(V3.1.0)_20100524.xls
#    📊 복사 완료: 1/1개
#
# 📄 [313] 문서ID: 2002378
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002378
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002378
#    ✅ 첨부파일 2개 발견
#       ✅ R&D_1월_유지보수_대금지급요청서.pdf
#       ✅ 통합유지보수월간보고서_R&D_201001.hwp
#    📊 복사 완료: 2/2개
#
# 📄 [327] 문서ID: 2002393
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002393
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002393
#    ✅ 첨부파일 1개 발견
#       ✅ 한의학 통합연구관리1차-카드사용내역-201010년05월.xls
#    📊 복사 완료: 1/1개
#
# 📄 [328] 문서ID: 2002396
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002396
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002396
#    ✅ 첨부파일 1개 발견
#       ✅ 회사 교통비(주유 외)사용 내역(5월).xls
#    📊 복사 완료: 1/1개
#
# 📄 [331] 문서ID: 2002395
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002395
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002395
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201005)_김기두.xls
#    📊 복사 완료: 1/1개
#
# 📄 [332] 문서ID: 2002397
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002397
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002397
#    ✅ 첨부파일 1개 발견
#       ✅ 2010_PJT사기진작비외_LG화학기술연구원SM.xls
#    📊 복사 완료: 1/1개
#
# 📄 [339] 문서ID: 2002404
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002404
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002404
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201005)_김성수.xls
#    📊 복사 완료: 1/1개
#
# 📄 [345] 문서ID: 2002416
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002416
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002416
#    ✅ 첨부파일 1개 발견
#       ✅ 대전사무실 계약 집기 예산 20100608.xls
#    📊 복사 완료: 1/1개
#
# 📄 [357] 문서ID: 2002424
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002424
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002424
#    ✅ 첨부파일 1개 발견
#       ✅ 제일모직_저녁식대쿠폰사용이력.xls
#    📊 복사 완료: 1/1개
#
# 📄 [365] 문서ID: 2002427
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002427
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002427
#    ✅ 첨부파일 2개 발견
#       ✅ 한국산업기술진흥원_온라인기술정보제작관리시스템개발 계약서.hwp
#       ✅ 한국산업기술진흥원_온라인기술정보제작관리시스템개발 수행계획서 (2).hwp
#    📊 복사 완료: 2/2개
#
# 📄 [366] 문서ID: 2002433
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002433
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002433
#    ✅ 첨부파일 1개 발견
#       ✅ LG화학_특허포트폴리오시스템구축_CP(V3.1.1)_20100618.xls
#    📊 복사 완료: 1/1개
#
# 📄 [371] 문서ID: 2002438
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002438
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002438
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년 6월급여대장(20100623).xls
#    📊 복사 완료: 1/1개
#
# 📄 [382] 문서ID: 2002448
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002448
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002448
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(20100629)_편영수K.xls
#    📊 복사 완료: 1/1개
#
# 📄 [383] 문서ID: 2002458
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002458
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002458
#    ✅ 첨부파일 1개 발견
#       ✅ 한의학 통합연구관리1차-카드사용내역-201010년06월.xls
#    📊 복사 완료: 1/1개
#
# 📄 [384] 문서ID: 2002454
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002454
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002454
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201006)_김기두.xls
#    📊 복사 완료: 1/1개
#
# 📄 [386] 문서ID: 2002452
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002452
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002452
#    ✅ 첨부파일 1개 발견
#       ✅ 시스템구축 계약VER_0501 - 현대-애니파이브(엘피온).doc
#    📊 복사 완료: 1/1개
#
# 📄 [392] 문서ID: 2002460
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002460
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002460
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201006)_김성수.xls
#    📊 복사 완료: 1/1개
#
# 📄 [394] 문서ID: 2002462
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002462
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002462
#    ✅ 첨부파일 1개 발견
#       ✅ 회사 교통비(주유 외)사용 내역(6월).xls
#    📊 복사 완료: 1/1개
#
# 📄 [399] 문서ID: 2002466
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002466
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002466
#    ✅ 첨부파일 1개 발견
#       ✅ 서울반도체_마크프로온라인연계구축_견적서(20100702)_최종.xls
#    📊 복사 완료: 1/1개
#
# 📄 [401] 문서ID: 2002468
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002468
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002468
#    ✅ 첨부파일 1개 발견
#       ✅ 한국타이어_문서보안 발주서_20100707.xls
#    📊 복사 완료: 1/1개
#
# 📄 [402] 문서ID: 2002469
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002469
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002469
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년도_사기진작비_기술지원팀_201007.xls
#    📊 복사 완료: 1/1개
#
# 📄 [411] 문서ID: 2002479
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002479
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002479
#    ✅ 첨부파일 1개 발견
#       ✅ 식품의약품안전평가원_연구관리기능개선사업_CP(V3.1.0)_20100712.xls
#    📊 복사 완료: 1/1개
#
# 📄 [414] 문서ID: 2002482
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002482
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002482
#    ✅ 첨부파일 1개 발견
#       ✅ 노틸러스효성_iPIMS공급_계약서(20100714).doc
#    📊 복사 완료: 1/1개
#
# 📄 [415] 문서ID: 2002480
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002480
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002480
#    ✅ 첨부파일 1개 발견
#       ✅ 노틸러스 효성_지재권관리시스템구축_CP(V3.1.0)_201000714.xls
#    📊 복사 완료: 1/1개
#
# 📄 [416] 문서ID: 2002483
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002483
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002483
#    ✅ 첨부파일 1개 발견
#       ✅ 제일모직_저녁식대쿠폰사용이력.xls
#    📊 복사 완료: 1/1개
#
# 📄 [417] 문서ID: 2002489
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002489
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002489
#    ✅ 첨부파일 1개 발견
#       ✅ 2010하계휴가일정_20100716.xls
#    📊 복사 완료: 1/1개
#
# 📄 [418] 문서ID: 2002487
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002487
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002487
#    ✅ 첨부파일 1개 발견
#       ✅ PDF변환서버-PC모델1.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [419] 문서ID: 2002488
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002488
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002488
#    ✅ 첨부파일 2개 발견
#       ✅ S2010-195(식약청-애니파이브_fi-5530c2 _100712).pdf
#       ✅ 후지-fi5530c2-Acr44.pdf
#    📊 복사 완료: 2/2개
#
# 📄 [422] 문서ID: 2002485
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002485
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002485
#    ✅ 첨부파일 1개 발견
#       ✅ 백승덕_이력서.hwp
#    📊 복사 완료: 1/1개
#
# 📄 [432] 문서ID: 2002499
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002499
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002499
#    ✅ 첨부파일 1개 발견
#       ✅ 종료_메디슨_iPIMS구축_CP(V3.0.0)_20100720.xls
#    📊 복사 완료: 1/1개
#
# 📄 [433] 문서ID: 2002503
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002503
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002503
#    ✅ 첨부파일 1개 발견
#       ✅ ANY_2010년_2분기_부가세산출(20100715).xls
#    📊 복사 완료: 1/1개
#
# 📄 [434] 문서ID: 2002502
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002502
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002502
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년 7월급여대장(20100710).xls
#    📊 복사 완료: 1/1개
#
# 📄 [436] 문서ID: 2002505
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002505
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002505
#    ✅ 첨부파일 1개 발견
#       ✅ 선영프로젝트 식대내역(2010.04.30~2010.06.27).xls
#    📊 복사 완료: 1/1개
#
# 📄 [445] 문서ID: 2002511
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002511
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002511
#    ✅ 첨부파일 1개 발견
#       ✅ LGU+_특허시스템개선_CP(V3.1.0)_201000726.xls
#    📊 복사 완료: 1/1개
#
# 📄 [447] 문서ID: 2002512
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002512
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002512
#    ✅ 첨부파일 1개 발견
#       ✅ ICP_IP시스템구축_CP(V3.1.0)_201000726.xls
#    📊 복사 완료: 1/1개
#
# 📄 [451] 문서ID: 2002517
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002517
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002517
#    ✅ 첨부파일 1개 발견
#       ✅ 교육과정개설안내 (K-IFRS 해설 및 무형자산평가 실무)-100707.hwp
#    📊 복사 완료: 1/1개
#
# 📄 [452] 문서ID: 2002519
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002519
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002519
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201007)_김성수.xls
#    📊 복사 완료: 1/1개
#
# 📄 [453] 문서ID: 2002523
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002523
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002523
#    ✅ 첨부파일 1개 발견
#       ✅ 회사 교통비(주유 외)사용 내역(7월).xls
#    📊 복사 완료: 1/1개
#
# 📄 [454] 문서ID: 2002521
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002521
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002521
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201007)_김기두.xls
#    📊 복사 완료: 1/1개
#
# 📄 [462] 문서ID: 2002528
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002528
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002528
#    ✅ 첨부파일 1개 발견
#       ✅ 발명진흥회_IPMART개선_CP(V3 1 0)_201000729.xls
#    📊 복사 완료: 1/1개
#
# 📄 [466] 문서ID: 2002533
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002533
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002533
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(20100729)_편영수K.xls
#    📊 복사 완료: 1/1개
#
# 📄 [471] 문서ID: 2002539
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002539
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002539
#    ✅ 첨부파일 1개 발견
#       ✅ LG화학_특허포트폴리오시스템구축_CP(V3.1.2)_20100802.xls
#    📊 복사 완료: 1/1개
#
# 📄 [473] 문서ID: 2002538
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002538
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002538
#    ✅ 첨부파일 1개 발견
#       ✅ 한국산업기술진흥원_녹색인증2단계_CP(V3.1.0)_20100803.xls
#    📊 복사 완료: 1/1개
#
# 📄 [482] 문서ID: 2002547
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002547
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002547
#    ✅ 첨부파일 1개 발견
#       ✅ LG화학_특허포트폴리오시스템구축_CP(V3.1.2)_20100804.xls
#    📊 복사 완료: 1/1개
#
# 📄 [486] 문서ID: 2002556
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002556
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002556
#    ✅ 첨부파일 1개 발견
#       ✅ LG화학_특허포트폴리오시스템구축_CP(V3.1.1)_20100811.xls
#    📊 복사 완료: 1/1개
#
# 📄 [494] 문서ID: 2002560
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002560
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002560
#    ✅ 첨부파일 1개 발견
#       ✅ 주성엔지니어링_지적재산온라인시스템구축_CP(V3.1.0)_20100813.xls
#    📊 복사 완료: 1/1개
#
# 📄 [507] 문서ID: 2002574
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002574
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002574
#    ✅ 첨부파일 1개 발견
#       ✅ LG전자_TIPIS특허관리시스템개선_CP(V3.1.0)_20100819.xls
#    📊 복사 완료: 1/1개
#
# 📄 [509] 문서ID: 2002576
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002576
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002576
#    ✅ 첨부파일 1개 발견
#       ✅ 인력운영현황_20100820.xls
#    📊 복사 완료: 1/1개
#
# 📄 [518] 문서ID: 2002593
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002593
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002593
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(20100830)_편영수K.xls
#    📊 복사 완료: 1/1개
#
# 📄 [521] 문서ID: 2002587
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002587
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002587
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(20100830).xls
#    📊 복사 완료: 1/1개
#
# 📄 [525] 문서ID: 2002591
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002591
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002591
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201008)_김성수.xls
#    📊 복사 완료: 1/1개
#
# 📄 [533] 문서ID: 2002599
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002599
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002599
#    ✅ 첨부파일 1개 발견
#       ✅ 이테크건설_유지보수 발주서_20100831.xls
#    📊 복사 완료: 1/1개
#
# 📄 [534] 문서ID: 2002601
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002601
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002601
#    ✅ 첨부파일 1개 발견
#       ✅ 회사 교통비(주유 외)사용 내역(8월).xls
#    📊 복사 완료: 1/1개
#
# 📄 [541] 문서ID: 2002608
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002608
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002608
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201008)_김기두.xls
#    📊 복사 완료: 1/1개
#
# 📄 [548] 문서ID: 2002619
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002619
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002619
#    ✅ 첨부파일 1개 발견
#       ✅ LG하우시스_보아니유지보수_견적서(20100906).xls
#    📊 복사 완료: 1/1개
#
# 📄 [549] 문서ID: 2002618
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002618
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002618
#    ✅ 첨부파일 1개 발견
#       ✅ 실트론_특허하자보수_견적서(20100906).xls
#    📊 복사 완료: 1/1개
#
# 📄 [578] 문서ID: 2002646
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002646
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002646
#    ✅ 첨부파일 1개 발견
#       ✅ 한국산업기술진흥원_녹색인증2단계_CP(V3.1.0)_20100914.xls
#    📊 복사 완료: 1/1개
#
# 📄 [579] 문서ID: 2002642
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002642
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002642
#    ✅ 첨부파일 1개 발견
#       ✅ 한국석유공사_문서보안 발주서_20100916.xls
#    📊 복사 완료: 1/1개
#
# 📄 [585] 문서ID: 2002652
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002652
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002652
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년 9월급여대장(20100910).xls
#    📊 복사 완료: 1/1개
#
# 📄 [594] 문서ID: 2002665
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002665
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002665
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(20100928)_편영수K.xls
#    📊 복사 완료: 1/1개
#
# 📄 [595] 문서ID: 2002661
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002661
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002661
#    ✅ 첨부파일 1개 발견
#       ✅ 회사 교통비(주유 외)사용 내역(9월).xls
#    📊 복사 완료: 1/1개
#
# 📄 [596] 문서ID: 2002662
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002662
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002662
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201009)_김기두.xls
#    📊 복사 완료: 1/1개
#
# 📄 [600] 문서ID: 2002666
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002666
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002666
#    ✅ 첨부파일 1개 발견
#       ✅ 이현구(에이치아이엘).doc
#    📊 복사 완료: 1/1개
#
# 📄 [604] 문서ID: 2002673
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002673
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002673
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201009)_김성수.xls
#    📊 복사 완료: 1/1개
#
# 📄 [608] 문서ID: 2002674
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002674
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002674
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(20100930).xls
#    📊 복사 완료: 1/1개
#
# 📄 [609] 문서ID: 2002675
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002675
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002675
#    ✅ 첨부파일 3개 발견
#       ✅ 1.제경비결산_7월_anyfive.xls
#       ✅ 1.제경비결산_8월_anyfive.xls
#       ✅ 1.제경비결산_9월_anyfive.xls
#    📊 복사 완료: 3/3개
#
# 📄 [616] 문서ID: 2002685
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002685
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002685
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브_식약청_CallCharge_20100909.xls
#    📊 복사 완료: 1/1개
#
# 📄 [629] 문서ID: 2002697
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002697
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002697
#    ✅ 첨부파일 1개 발견
#       ✅ PATNEX_2010_비용결산(20101005).xls
#    📊 복사 완료: 1/1개
#
# 📄 [638] 문서ID: 2002708
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002708
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002708
#    ✅ 첨부파일 1개 발견
#       ✅ LG화학기술원_실험실자동화시스템구축(2단계)_CP(V3_1_0)_20101005.xls
#    📊 복사 완료: 1/1개
#
# 📄 [644] 문서ID: 2002711
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002711
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002711
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년도_사기진작비_기술지원팀_2010.xls
#    📊 복사 완료: 1/1개
#
# 📄 [646] 문서ID: 2002715
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002715
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002715
#    ✅ 첨부파일 1개 발견
#       ✅ ANY_2010년_3분기_부가세산출(20101022).xls
#    📊 복사 완료: 1/1개
#
# 📄 [647] 문서ID: 2002714
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002714
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002714
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년 10월급여대장(20101013).xls
#    📊 복사 완료: 1/1개
#
# 📄 [649] 문서ID: 2002719
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002719
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002719
#    ✅ 첨부파일 1개 발견
#       ✅ 실험실자동화구축2차_비용사용대장.xls
#    📊 복사 완료: 1/1개
#
# 📄 [656] 문서ID: 2002723
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002723
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002723
#    ✅ 첨부파일 1개 발견
#       ✅ 이벤트포커스_(주)애니파이브 시스템 한마음 체육대회_최종2차.xls.xls
#    📊 복사 완료: 1/1개
#
# 📄 [668] 문서ID: 2002736
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002736
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002736
#    ✅ 첨부파일 1개 발견
#       ✅ 견적서_발명진흥회201010).pdf
#    📊 복사 완료: 1/1개
#
# 📄 [673] 문서ID: 2002746
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002746
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002746
#    ✅ 첨부파일 1개 발견
#       ✅ 회사 교통비(주유 외)사용 내역(10월).xls
#    📊 복사 완료: 1/1개
#
# 📄 [674] 문서ID: 2002747
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002747
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002747
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201010)_김기두.xls
#    📊 복사 완료: 1/1개
#
# 📄 [675] 문서ID: 2002751
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002751
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002751
#    ✅ 첨부파일 1개 발견
#       ✅ _카드사용실적보고(20101030).xls
#    📊 복사 완료: 1/1개
#
# 📄 [676] 문서ID: 2002752
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002752
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002752
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(20101028)_편영수K.xls
#    📊 복사 완료: 1/1개
#
# 📄 [677] 문서ID: 2002745
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002745
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002745
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201010)_김성수.xls
#    📊 복사 완료: 1/1개
#
# 📄 [680] 문서ID: 2002742
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002742
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002742
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년_한마음체육대회_비용결산(20101101).xls
#    📊 복사 완료: 1/1개
#
# 📄 [695] 문서ID: 2002764
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002764
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002764
#    ✅ 첨부파일 1개 발견
#       ✅ 법인카드(10월분 내역서).xls
#    📊 복사 완료: 1/1개
#
# 📄 [696] 문서ID: 2002762
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002762
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002762
#    ✅ 첨부파일 1개 발견
#       ✅ 식품의약품안전평가원_NTIS연계_CP(V3.1.0)_20101108.xls
#    📊 복사 완료: 1/1개
#
# 📄 [697] 문서ID: 2002763
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002763
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002763
#    ✅ 첨부파일 3개 발견
#       ✅ 식약청_연구관리시스템기능개선_CP변경안검토(20101103).xls
#       ✅ 식약청_연구관리시스템기능개선_일정협의안(20101103).xls
#       ✅ 식품의약품안전평가원_연구관리기능개선사업_CP(V3[1].1.0)_20101103.xls
#    📊 복사 완료: 3/3개
#
# 📄 [698] 문서ID: 2002765
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002765
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002765
#    ✅ 첨부파일 2개 발견
#       ✅ (맨인소프트)하이닉스_Hourly Charge구축_견적서(20100916).xls
#       ✅ 하이닉스_특허HC구축_CP(V3.1.0)_20101108_김대화초안.xls
#    📊 복사 완료: 2/2개
#
# 📄 [701] 문서ID: 2002768
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002768
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002768
#    ✅ 첨부파일 1개 발견
#       ✅ 실험실자동화구축2차_비용사용대장.xls
#    📊 복사 완료: 1/1개
#
# 📄 [703] 문서ID: 2002770
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002770
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002770
#    ✅ 첨부파일 1개 발견
#       ✅ 견적서(애니파이브시스템_주성PJT 특허검색 내 DRM 연동관련_20101112_2).pdf
#    📊 복사 완료: 1/1개
#
# 📄 [732] 문서ID: 2002797
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002797
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002797
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년_퇴직금중간정산내역서(20101122).xls
#    📊 복사 완료: 1/1개
#
# 📄 [733] 문서ID: 2002802
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002802
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002802
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년 11월급여대장(20101115).xls
#    📊 복사 완료: 1/1개
#
# 📄 [734] 문서ID: 2002801
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002801
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002801
#    ✅ 첨부파일 1개 발견
#       ✅ 한국한의학연구원_전자결재연동_계약서(20101123).doc
#    📊 복사 완료: 1/1개
#
# 📄 [738] 문서ID: 2002803
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002803
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002803
#    ✅ 첨부파일 1개 발견
#       ✅ 전자연구노트  프로젝트 출장 품의서(원진희_20101122).xls
#    📊 복사 완료: 1/1개
#
# 📄 [740] 문서ID: 2002810
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002810
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002810
#    ✅ 첨부파일 1개 발견
#       ✅ _카드사용실적보고(20101130).xls
#    📊 복사 완료: 1/1개
#
# 📄 [744] 문서ID: 2002817
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002817
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002817
#    ✅ 첨부파일 1개 발견
#       ✅ 회사 교통비(주유 외)사용 내역(11월).xls
#    📊 복사 완료: 1/1개
#
# 📄 [745] 문서ID: 2002818
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002818
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002818
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201011)_김기두.xls
#    📊 복사 완료: 1/1개
#
# 📄 [747] 문서ID: 2002816
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002816
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002816
#    ✅ 첨부파일 1개 발견
#       ✅ 2010-11-23 계약서_애니파이브시스템.hwp
#    📊 복사 완료: 1/1개
#
# 📄 [757] 문서ID: 2002827
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002827
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002827
#    ✅ 첨부파일 1개 발견
#       ✅ 통합 ITO 서비스 유지보수-애니파이브시스템.doc
#    📊 복사 완료: 1/1개
#
# 📄 [764] 문서ID: 2002831
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002831
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002831
#    ✅ 첨부파일 1개 발견
#       ✅ 쇼핑백견적서[1].hwp
#    📊 복사 완료: 1/1개
#
# 📄 [768] 문서ID: 2002834
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002834
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002834
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201011)_김성수.xls
#    📊 복사 완료: 1/1개
#
# 📄 [770] 문서ID: 2002839
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002839
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002839
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(20101129)_편영수K.xls
#    📊 복사 완료: 1/1개
#
# 📄 [778] 문서ID: 2002845
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002845
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002845
#    ✅ 첨부파일 1개 발견
#       ✅ 야근근무식대신청서_차원준_201011.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [784] 문서ID: 2002851
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002851
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002851
#    ✅ 첨부파일 1개 발견
#       ✅ R&D특허센터_연구노트활성화를 위한 홈페이지 개발_CP(V3.1.0)_20101209.xls
#    📊 복사 완료: 1/1개
#
# 📄 [785] 문서ID: 2002852
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002852
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002852
#    ✅ 첨부파일 1개 발견
#       ✅ 쇼핑백견적서[1].hwp
#    📊 복사 완료: 1/1개
#
# 📄 [792] 문서ID: 2002858
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002858
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002858
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년_퇴직금정산내역서(20101215).xls
#    📊 복사 완료: 1/1개
#
# 📄 [793] 문서ID: 2002861
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002861
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002861
#    ✅ 첨부파일 1개 발견
#       ✅ LG전자_G-TIPIS_견적서(20101216).xls
#    📊 복사 완료: 1/1개
#
# 📄 [794] 문서ID: 2002860
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002860
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002860
#    ✅ 첨부파일 1개 발견
#       ✅ 전자연구노트  프로젝트 출장 품의서(원진희_20101129).xls
#    📊 복사 완료: 1/1개
#
# 📄 [803] 문서ID: 2002871
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002871
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002871
#    ✅ 첨부파일 1개 발견
#       ✅ 법률자문료청구및세금계산서.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [804] 문서ID: 2002864
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002864
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002864
#    ✅ 첨부파일 5개 발견
#       ✅ 우리회계법인세금계산서.JPG
#       ✅ 우리회계법인실사계약서1.JPG
#       ✅ 우리회계법인실사계약서2.JPG
#       ✅ 우리회계법인실사계약서3.JPG
#       ✅ 우리회계법인실사용역청구서.pdf
#    📊 복사 완료: 5/5개
#
# 📄 [807] 문서ID: 2002875
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002875
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002875
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년 12월급여대장(20101215).xls
#    📊 복사 완료: 1/1개
#
# 📄 [808] 문서ID: 2002877
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002877
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002877
#    ✅ 첨부파일 1개 발견
#       ✅ 2010년 12월급여대장(20101215).xls
#    📊 복사 완료: 1/1개
#
# 📄 [812] 문서ID: 2002879
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002879
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002879
#    ✅ 첨부파일 1개 발견
#       ✅ 견적서_1012-0032__애니파이브시스템_상표출원4건.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [816] 문서ID: 2002886
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002886
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002886
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(20101228).xls
#    📊 복사 완료: 1/1개
#
# 📄 [818] 문서ID: 2002883
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002883
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002883
#    ✅ 첨부파일 1개 발견
#       ✅ File0006.PDF
#    📊 복사 완료: 1/1개
#
# 📄 [819] 문서ID: 2002882
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002882
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002882
#    ✅ 첨부파일 2개 발견
#       ✅ 렌탈가이드1118.pdf
#       ✅ 렌탈가이드1215.pdf
#    📊 복사 완료: 2/2개
#
# 📄 [827] 문서ID: 2002890
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002890
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002890
#    ✅ 첨부파일 1개 발견
#       ✅ 하이닉스반도체_특허HC구축_CP(V3.3.0)_20101229.xls
#    📊 복사 완료: 1/1개
#
# 📄 [830] 문서ID: 2002892
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002892
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002892
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(201012)_김성수.xls
#    📊 복사 완료: 1/1개
#
# 📄 [832] 문서ID: 2002899
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002899
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002899
#    ✅ 첨부파일 2개 발견
#       ✅ 계약원룸.ppt
#       ✅ 등기부등본.PDF
#    📊 복사 완료: 2/2개
#
# 📄 [833] 문서ID: 2002900
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002900
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002900
#    ✅ 첨부파일 1개 발견
#       ✅ 카드사용실적보고(20101229)_편영수K.xls
#    📊 복사 완료: 1/1개
#
# 📄 [834] 문서ID: 2002904
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002904
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002904
#    ✅ 첨부파일 1개 발견
#       ✅ 기장대리계약서.doc
#    📊 복사 완료: 1/1개
#
# 📄 [835] 문서ID: 2002903
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002903
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002903
#    ✅ 첨부파일 1개 발견
#       ✅ 하이패스확인증.bmp
#    📊 복사 완료: 1/1개
#
# 📄 [840] 문서ID: 2002907
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\apr\2002907
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments\apr2002907
#    ✅ 첨부파일 1개 발견
#       ✅ 201010-최성민_체크카드사용내역서.xls
#    📊 복사 완료: 1/1개
#
# ============================================================
# ✅ 처리 완료!
#    - 종료연도: 2010
#    - 첨부파일 있는 documents: 173개
#    - 총 첨부파일 개수: 196개
#    - 복사된 파일 위치: C:\Users\LEEJUHWAN\Downloads\approval_2010_attachments
#    - DB 테이블: documents (attaches 컬럼 업데이트)
# ============================================================
#
# ✅ DB 연결 종료
