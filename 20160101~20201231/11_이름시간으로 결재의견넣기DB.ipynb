# %%
# 결재의견 찾는 로직 강화. (lxml 파서를 사용해야 <br/> 태그 이후의 <div>를 제대로 인식)
"""
 [기능]
 HTML 파일의 "결재의견" 테이블에서 의견을 추출하여
 DB documents 테이블의 activities JSON 내 actionComment 필드 업데이트

 [파서 선택]
 - lxml 파서 사용 (필수!)
 - html.parser는 <br/> 태그 이후의 <div>를 제대로 인식 못함

 [HTML 파싱 로직]
 1. <table summary='결재의견'> 테이블 찾기
 2. span.user에서 이름(F_12_black_b), 시간(F_11_gray) 추출
 3. user_span의 next_siblings 순회하여 의견 추출
    - <br> 태그 이후의 <div> 또는 텍스트 노드에서 추출
    - 다음 user_span 만나면 중단

 [DB 업데이트 로직]
 1. 특정 end_year 문서의 activities 조회
 2. 모든 actionComment를 빈값으로 초기화
 3. HTML에서 추출한 의견과 매칭 (name + actionDate 동시 일치)
 4. 매칭 성공 시 actionComment 업데이트
 5. 변경된 activities JSON을 DB에 UPDATE

 [시간대 처리]
 - HTML의 시간을 KST로 파싱 → Unix timestamp(ms)로 변환
 - DB의 actionDate와 정확히 매칭

 [디버깅 기능]
 - 특정 source_id(예: 2002153) 처리 시 상세 로그 출력
 - siblings 탐색 과정, 매칭 과정 추적

 [설정 (#여기를 수정하세요)]
 - base_path: HTML 폴더 경로
 - end_year: 대상 연도 (WHERE 조건)
 - db_config: DB 접속 정보

 [의존성]
 - beautifulsoup4
 - lxml (파서)
 - pymysql
 - pytz
  -> pip install beautifulsoup4 lxml pymysql pytz
"""
import os
import json
import re
from datetime import datetime
import pytz
from bs4 import BeautifulSoup
import pymysql
from pathlib import Path

class ActionCommentUpdater:
    def __init__(self, base_path):
        self.base_path = base_path
        self.kst = pytz.timezone('Asia/Seoul')
        
    def extract_source_id(self, filename):
        """파일명에서 마지막 숫자 추출"""
        numbers = re.findall(r'\d+', filename)
        return numbers[-1] if numbers else None
    
    def extract_person_info(self, text):
        """이름/직책/부서 형식에서 이름만 추출"""
        text = re.sub(r'\d+', '', text).strip()
        parts = text.split('/')
        if len(parts) >= 1:
            return parts[0].strip()
        return None
    
    def parse_html_for_comments(self, html_path):
        """HTML 파일에서 source_id와 결재의견 추출"""
        with open(html_path, 'r', encoding='utf-8') as f:
            # lxml 파서 사용 (html.parser는 일부 HTML을 제대로 파싱 못함)
            soup = BeautifulSoup(f.read(), 'lxml')
        
        filename = os.path.basename(html_path)
        source_id = self.extract_source_id(filename)
        
        # 결재의견 영역 찾기
        activities = []
        
        # "결재의견" 테이블 찾기
        approval_table = soup.find('table', summary='결재의견')
        if not approval_table:
            return {'sourceId': source_id, 'activities': activities}
        
        # td 안의 모든 span.user 찾기
        user_spans = approval_table.find_all('span', class_='user')
        
        for user_span in user_spans:
            # 이름 추출
            name_elem = user_span.find('span', class_='F_12_black_b')
            if not name_elem:
                continue
            
            name = self.extract_person_info(name_elem.get_text(strip=True))
            if not name:
                continue
            
            # 시간 추출
            time_elem = user_span.find('span', class_='F_11_gray')
            action_date = None
            if time_elem:
                time_text = time_elem.get_text(strip=True)
                try:
                    dt_naive = datetime.strptime(time_text, '%Y-%m-%d %H:%M:%S')
                    dt_kst = self.kst.localize(dt_naive)
                    action_date = int(dt_kst.timestamp() * 1000)
                except:
                    pass
            
            # 의견 추출: user_span의 다음 형제들에서 div 또는 텍스트 찾기
            action_comment = ""
            
            # 디버깅: 2002153인 경우 상세 로그
            if source_id == '2002153':
                print(f"\n  [{name}] siblings 탐색:")
                # 먼저 모든 siblings를 확인
                all_siblings = list(user_span.next_siblings)
                for idx, s in enumerate(all_siblings[:10]):  # 최대 10개까지
                    s_type = type(s).__name__
                    s_name = getattr(s, 'name', 'N/A')
                    s_class = s.get('class', []) if hasattr(s, 'get') else []
                    s_text = str(s)[:50] if s_type == 'NavigableString' else (s.get_text(strip=True)[:30] if hasattr(s, 'get_text') else '')
                    print(f"    sibling[{idx}]: type={s_type}, name={s_name}, class={s_class}, text={repr(s_text)}")
            
            # user_span의 next_siblings에서 div 또는 의견 텍스트 찾기
            br_found = False
            for idx, sibling in enumerate(user_span.next_siblings):
                if hasattr(sibling, 'name') and sibling.name:
                    # br 태그를 만나면 플래그 설정
                    if sibling.name == 'br':
                        br_found = True
                        continue
                    
                    # 다음 user_span을 만나면 중단
                    if sibling.name == 'span' and 'user' in sibling.get('class', []):
                        if source_id == '2002153':
                            print(f"    → 다음 user_span 발견, 중단")
                        break
                    
                    # div를 찾으면 의견 추출
                    if sibling.name == 'div':
                        action_comment = sibling.get_text(strip=True)
                        if source_id == '2002153':
                            print(f"    → div 발견! 의견: {action_comment[:50]}")
                        break
                else:
                    # NavigableString (텍스트 노드)인 경우
                    # br 다음에 오는 의미있는 텍스트를 추출
                    if br_found and sibling and str(sibling).strip():
                        action_comment = str(sibling).strip()
                        if source_id == '2002153':
                            print(f"    → 텍스트 노드 발견! 의견: {action_comment[:50]}")
                        break
            
            activities.append({
                'name': name,
                'actionDate': action_date,
                'actionComment': action_comment
            })
        
        return {
            'sourceId': source_id,
            'activities': activities
        }

        
    def process_all_html_files(self):
        """모든 HTML 파일에서 결재의견 추출"""
        all_results = {}
        approval_path = Path(self.base_path) / '결재'
        
        if not approval_path.exists():
            print(f"경로를 찾을 수 없습니다: {approval_path}")
            return all_results
            
        html_files = list(approval_path.rglob('*.html'))
        print(f"총 {len(html_files)}개의 HTML 파일을 찾았습니다.")
        
        for idx, html_file in enumerate(html_files, 1):
            try:
                if idx % 100 == 0 or idx == len(html_files):
                    print(f"HTML 파싱 중... [{idx}/{len(html_files)}] {html_file.name}")
                result = self.parse_html_for_comments(html_file)
                source_id = result['sourceId']
                if source_id:
                    all_results[source_id] = result['activities']
                    
                    # 디버깅: 2002153 파일 확인
                    if source_id == '2002153':
                        print(f"\n★★★ HTML 파싱 완료: source_id=2002153 ★★★")
                        print(f"파일명: {html_file.name}")
                        print(f"activities 개수: {len(result['activities'])}")
                        
            except Exception as e:
                print(f"오류 발생 ({html_file.name}): {e}")
                import traceback
                if source_id == '2002153':
                    traceback.print_exc()
        
        print(f"\n✅ HTML 파싱 완료: {len(all_results)}개 문서\n")
        
        # 최종 확인
        if '2002153' in all_results:
            print(f"★ 2002153 최종 확인:")
            for idx, act in enumerate(all_results['2002153']):
                print(f"  [{idx}] {act['name']}, {act['actionDate']}, 의견: {act['actionComment'][:30] if act['actionComment'] else '(없음)'}")
        
        return all_results
    
    def update_action_comments(self, db_config, end_year, html_comments):
        """DB의 결재의견 업데이트"""
        conn = None
        cursor = None
        
        try:
            print("=== DB 연결 시작 ===")
            conn = pymysql.connect(
                host=db_config['host'],
                user=db_config['user'],
                password=db_config['password'],
                database=db_config['database'],
                charset='utf8mb4'
            )
            print("✓ DB 연결 성공\n")
            cursor = conn.cursor(pymysql.cursors.DictCursor)
            
            # 디버깅: HTML에 2002153 있는지 확인
            if '2002153' in html_comments:
                print(f"★★★ HTML 딕셔너리에 2002153 존재 확인! ★★★")
                print(f"HTML activities 개수: {len(html_comments['2002153'])}")
                for idx, act in enumerate(html_comments['2002153']):
                    print(f"  [{idx}] 이름:{act['name']}, 날짜:{act['actionDate']}, 의견:{act['actionComment'][:50] if act['actionComment'] else '(없음)'}")
            else:
                print(f"⚠️ HTML 딕셔너리에 2002153 없음!")
            print()
            
            # Step 1: end_year = 2020인 documents 조회
            print(f"=== Step 1: end_year={end_year} 문서 조회 ===")
            cursor.execute("""
                SELECT id, source_id, activities
                FROM documents
                WHERE end_year = %s
            """, (end_year,))
            
            documents = cursor.fetchall()
            print(f"✓ 조회 완료: {len(documents)}건\n")
            
            # Step 2 & 3: 결재의견 초기화 및 업데이트
            print(f"=== Step 2 & 3: 결재의견 초기화 및 업데이트 ===")
            
            total_count = 0
            updated_count = 0
            matched_count = 0
            error_count = 0
            
            for doc in documents:
                total_count += 1
                
                if total_count % 1000 == 0:
                    print(f"처리 중... {total_count}/{len(documents)}건 (매칭: {matched_count}건)")
                
                doc_id = doc['id']
                source_id = doc['source_id']
                activities_str = doc['activities']
                
                if not activities_str:
                    continue
                
                try:
                    # activities JSON 파싱
                    activities = json.loads(activities_str)
                    
                    # 디버깅: 2002153 처리 시작
                    if source_id == '2002153':
                        print(f"\n★★★ DB 처리: source_id=2002153 ★★★")
                        print(f"DB id: {doc_id}")
                        print(f"DB activities 개수: {len(activities)}")
                        for idx, act in enumerate(activities):
                            print(f"  DB[{idx}] 이름:{act['name']}, 날짜:{act['actionDate']}, 의견:{act.get('actionComment', '(없음)')[:30]}")
                    
                    # 모든 actionComment 초기화
                    for activity in activities:
                        activity['actionComment'] = ''
                    
                    # HTML에서 추출한 결재의견이 있으면 매칭
                    if source_id in html_comments:
                        html_activities = html_comments[source_id]
                        
                        # 디버깅: 2002153 매칭 시작
                        if source_id == '2002153':
                            print(f"\n  → 매칭 시작...")
                            print(f"  DB activities:")
                            for idx, act in enumerate(activities):
                                from datetime import datetime
                                if act.get('actionDate'):
                                    dt_str = datetime.fromtimestamp(act['actionDate']/1000).strftime('%Y-%m-%d %H:%M:%S')
                                else:
                                    dt_str = 'None'
                                print(f"    DB[{idx}] {act['name']} / {act['actionDate']} ({dt_str})")
                            print(f"  HTML activities:")
                            for idx, act in enumerate(html_activities):
                                if act.get('actionDate'):
                                    dt_str = datetime.fromtimestamp(act['actionDate']/1000).strftime('%Y-%m-%d %H:%M:%S')
                                else:
                                    dt_str = 'None'
                                print(f"    HTML[{idx}] {act['name']} / {act['actionDate']} ({dt_str}) / {act['actionComment'][:30] if act['actionComment'] else '(없음)'}")
                        
                        # name + actionDate 매칭
                        for db_activity in activities:
                            db_name = db_activity.get('name', '')
                            db_date = db_activity.get('actionDate')
                            
                            for html_activity in html_activities:
                                html_name = html_activity.get('name', '')
                                html_date = html_activity.get('actionDate')
                                html_comment = html_activity.get('actionComment', '')
                                
                                # 이름과 날짜가 모두 일치
                                if db_name == html_name and db_date == html_date:
                                    db_activity['actionComment'] = html_comment
                                    if html_comment:  # 빈값이 아닌 의견만 카운트
                                        matched_count += 1
                                    
                                    # 디버깅: 2002153 매칭 성공
                                    if source_id == '2002153':
                                        print(f"  ✓ 매칭 성공: {db_name}, {db_date}")
                                        print(f"    의견: {html_comment[:50] if html_comment else '(없음)'}")
                                    break
                        
                        # 디버깅: 2002153 매칭 후 결과
                        if source_id == '2002153':
                            print(f"\n  → 매칭 후 DB activities:")
                            for idx, act in enumerate(activities):
                                print(f"  [{idx}] 의견:{act['actionComment'][:50] if act['actionComment'] else '(빈값)'}")
                    
                    # DB 업데이트
                    updated_activities_str = json.dumps(activities, ensure_ascii=False, separators=(',', ':'))
                    cursor.execute("""
                        UPDATE documents 
                        SET activities = %s 
                        WHERE id = %s
                    """, (updated_activities_str, doc_id))
                    conn.commit()
                    updated_count += 1
                    
                except json.JSONDecodeError as e:
                    error_count += 1
                    print(f"⚠️ JSON 파싱 에러 (id={doc_id}, source_id={source_id}): {str(e)}")
                except Exception as e:
                    error_count += 1
                    print(f"⚠️ 업데이트 에러 (id={doc_id}): {str(e)}")
                    conn.rollback()
            
            print(f"\n=== 결과 요약 ===")
            print(f"총 처리: {total_count}건")
            print(f"업데이트: {updated_count}건")
            print(f"의견 매칭: {matched_count}건 (빈값 제외)")
            if error_count > 0:
                print(f"⚠️ 에러: {error_count}건")
            
        except Exception as e:
            print(f"❌ 오류 발생: {e}")
            if conn:
                conn.rollback()
        
        finally:
            if cursor:
                cursor.close()
            if conn:
                conn.close()
                print("\n✓ DB 연결 종료")


def main():
    #여기를 수정하세요
    # 설정
    base_path = r'C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html'
    end_year = 2020
    
    db_config = {
        'host': 'localhost',
        'user': 'root',
        'password': '1234',
        'database': 'any_approval'
    }
    
    # 실행
    updater = ActionCommentUpdater(base_path)
    
    # 1. HTML에서 결재의견 추출
    print("="*60)
    html_comments = updater.process_all_html_files()
    
    # 2. DB 업데이트
    print("="*60)
    updater.update_action_comments(db_config, end_year, html_comments)
    print("="*60)
    
    print("\n✅ 모든 작업 완료!")


if __name__ == '__main__':
    main()
# Out:
# ============================================================
# 총 7704개의 HTML 파일을 찾았습니다.
# HTML 파싱 중... [100/7704] 20160204_휴가 품의_2009595.html
# HTML 파싱 중... [200/7704] 20160307_휴가 품의_2009690.html
# HTML 파싱 중... [300/7704] 20160401_법인카드 사용내역 정산 보고 - 현광섭(2016.03)_2989353.html
# HTML 파싱 중... [400/7704] 20160426_대전숙소(세종아파트) 2016년 3월 관리비_3093067.html
# HTML 파싱 중... [500/7704] 20160524_국민권익위원회 5월 사기진작비 품의신청_3172052.html
# HTML 파싱 중... [600/7704] 20160620_연차휴가사용 품의(6_21)_3253028.html
# HTML 파싱 중... [700/7704] 20160720_[외주인력투입계약품의] LG화확 기술원 비문관리체계 개선(이돈경)_5600251.html
# HTML 파싱 중... [800/7704] 20160812_여름휴가 품의_5807435.html
# HTML 파싱 중... [900/7704] 20160908_신용보증기금 HP장비납품_5953879.html
# HTML 파싱 중... [1000/7704] 20161010_장기출장 품의서 기안올립니다._6136837.html
# HTML 파싱 중... [1100/7704] 20161025_10-28 NHN Mo, PC x4_6220679.html
# HTML 파싱 중... [1200/7704] 20161109_11-14 다우 PC, NB x14대_6311294.html
# HTML 파싱 중... [1300/7704] 20161128_2016년 11월 법인카드 사용 품의_6513503.html
# HTML 파싱 중... [1400/7704] 20161213_법인차량(34오9405)타이어외 부품교체비용 지급요청_6638142.html
# HTML 파싱 중... [1500/7704] 20161227_휴가 품의_6717081.html
# HTML 파싱 중... [1600/7704] 20170117_[외주인력투입계약품의] ETRI 기술가치평가 지원 시스템 고도화_반응형 웹 및 퍼블리싱 (김나연)_6841140.html
# HTML 파싱 중... [1700/7704] 20170206_동우화인켐 단기출장 품의_6944314.html
# HTML 파싱 중... [1800/7704] 20170224_02-27 DCT Server x4대_7053637.html
# HTML 파싱 중... [1900/7704] 20170314_03-12 NHN Monitor x 7대_7155436.html
# HTML 파싱 중... [2000/7704] 20170327_유틸렉스 전자연구노트 회식비 지원 요청_7225928.html
# HTML 파싱 중... [2100/7704] 20170410_[비용사용품의] 17년 춘계행사 체육대회 제반 비용 사용 품의 건_7316723.html
# HTML 파싱 중... [2200/7704] 20170426_SK텔레콤 업체등록을 위한 신용평가 품의_7417083.html
# HTML 파싱 중... [2300/7704] 20170517_5_19일 휴가 요청드립니다._7517404.html
# HTML 파싱 중... [2400/7704] 20170601_LG화학 상표관리모듈 구축 계약 품의_7612371.html
# HTML 파싱 중... [2500/7704] 20170620_[대금결제] 외주용역비 대금 결제의 건 (6_26자)_7716954.html
# HTML 파싱 중... [2600/7704] 20170707_서울 기숙사(예성오피스텔) 6월 도시가스비 품의_7829119.html
# HTML 파싱 중... [2700/7704] 20170726_하계휴가 및 리프래쉬 휴가 품의_7947662.html
# HTML 파싱 중... [2800/7704] 20170816_08-13 NHN Monitor x 20대_8057843.html
# HTML 파싱 중... [2900/7704] 20170906_[대금결제] BNK금융그룹 IT센터이전 지원서비스 매입 대금 결제의 건(일시불) - 디리아_8182752.html
# HTML 파싱 중... [3000/7704] 20170925_연차 휴가 신청합니다._8291960.html
# HTML 파싱 중... [3100/7704] 20171019_외주인원 투입 품의 -한국콘텐츠진흥원 사업관리시스템(변철수)_8406872.html
# HTML 파싱 중... [3200/7704] 20171108_11-12 NHN PC, Monitor x 20_8528068.html
# HTML 파싱 중... [3300/7704] 20171128_[대금결제] 11월 지급보류 외주용역비 대금 결제의 건 - 연승훈(이연소프트뱅크)_8643391.html
# HTML 파싱 중... [3400/7704] 20171218_삼성SDI '18년 지식재산관리시스템 유지보수 계약_8764948.html
# HTML 파싱 중... [3500/7704] 20180103_[대금결제] IIPC위원회 사무실 임대의 건_8853115.html
# HTML 파싱 중... [3600/7704] 20180125_01-36 이랜드 NB, Part x 26대_8984249.html
# HTML 파싱 중... [3700/7704] 20180220_02-29 다우기술 Part x 8대_9123453.html
# HTML 파싱 중... [3800/7704] 20180307_한화토탈 과제관리시스템 장기출장 품의_9214593.html
# HTML 파싱 중... [3900/7704] 20180328_재직증명서 및 4대보험가입확인세 요청_9333590.html
# HTML 파싱 중... [4000/7704] 20180413_동우화인켐 출장 경비 품의_9438827.html
# HTML 파싱 중... [4100/7704] 20180502_휴가사용신청서_9548865.html
# HTML 파싱 중... [4200/7704] 20180523_05-34 Atsys Server, Part x 3대_9661732.html
# HTML 파싱 중... [4300/7704] 20180612_[대금결제] 요다정보기술 &quot;BNK금융그룹 데이타센터 이전&quot; 사업 매입 대금 결제의 건 - 안덕기(프리랜서)_9782379.html
# HTML 파싱 중... [4400/7704] 20180702_대전지사 윤석현 6월 야근식대 지급 신청서 품의_9894660.html
# HTML 파싱 중... [4500/7704] 20180724_07-29 NHN Monitor x 28_10028745.html
# HTML 파싱 중... [4600/7704] 20180814_출장비 지급 신청_10148245.html
# HTML 파싱 중... [4700/7704] 20180905_제증명서 발급 신청_10275112.html
# HTML 파싱 중... [4800/7704] 20181004_10-04 NHN PC, Monitor x 25_10430441.html
# HTML 파싱 중... [4900/7704] 20181101_휴가 사용 신청서_최태영_2018.11.02(금)_10592726.html
# HTML 파싱 중... [5000/7704] 20181129_11-34 Atsys Server x 1_10768183.html
# HTML 파싱 중... [5100/7704] 20181220_20181217 야근 택시비 청구_10900148.html
# HTML 파싱 중... [5200/7704] 20190121_연차 휴가 품의서_11082463.html
# HTML 파싱 중... [5300/7704] 20190215_[대금결제] 외주용역비 대금 결제의 건 - 프리랜서(02_15일자)_11220276.html
# HTML 파싱 중... [5400/7704] 20190315_동우화인켐 출장 교통비 지급 품의_11388981.html
# HTML 파싱 중... [5500/7704] 20190411_휴가 신청합니다._11557088.html
# HTML 파싱 중... [5600/7704] 20190502_[SK케미칼 특허시스템]4월 야근식대를 신청합니다._11682126.html
# HTML 파싱 중... [5700/7704] 20190531_출장비 지급 신청서_11853210.html
# HTML 파싱 중... [5800/7704] 20190621_연차휴가 품의_11979063.html
# HTML 파싱 중... [5900/7704] 20190717_기타경비 신청의 건_12139665.html
# HTML 파싱 중... [6000/7704] 20190808_여름휴가사용신청_12265760.html
# HTML 파싱 중... [6100/7704] 20190830_[대금결제] &quot;클라우드기반 부품정보서비스제공 서버&quot; 국내특허출원 의견_보정서 제출 수수료 및 관납료_12391076.html
# HTML 파싱 중... [6200/7704] 20190927_09-26 NHN WS, PC, Monitor x 14_12547871.html
# HTML 파싱 중... [6300/7704] 20191018_택시비 지급 품의_12669479.html
# HTML 파싱 중... [6400/7704] 20191108_대전 항공우주연구원 출장비 지급 신청_12797105.html
# HTML 파싱 중... [6500/7704] 20191129_한화시스템 지식재산관리 시스템 용역 권태욱 투입 품의 작성_12924695.html
# HTML 파싱 중... [6600/7704] 20191227_2019.12.31(화) 연차 품의_13096662.html
# HTML 파싱 중... [6700/7704] 20200121_연차휴가 사용신청_13231308.html
# HTML 파싱 중... [6800/7704] 20200229_야근식대 지급 신청드립니다._13449955.html
# HTML 파싱 중... [6900/7704] 20200331_2020년 2월 야근식대 지급 신청서 품의 작성_13621964.html
# HTML 파싱 중... [7000/7704] 20200503_야근식대 지급 신청서_13790052.html
# HTML 파싱 중... [7100/7704] 20200612_휴가 사용 신청서_14014529.html
# HTML 파싱 중... [7200/7704] 20200724_'20.07.24 연차품의_14248756.html
# HTML 파싱 중... [7300/7704] 20200828_김상욱 반차 입니다._14440221.html
# HTML 파싱 중... [7400/7704] 20201019_[대금결제] ETRI 통합정보(ETRIware) 유지관리 계약 - 2020년 9월분 대금 지급의 건_14705552.html
# HTML 파싱 중... [7500/7704] 20201111_LG U+ MEC기반 5G 플랫폼 구축_선투입 품의_14856103.html
# HTML 파싱 중... [7600/7704] 20201208_휴가 신청_15018001.html
# HTML 파싱 중... [7700/7704] 20201230_퇴직 품의서_15147253.html
# HTML 파싱 중... [7704/7704] 20201231_출장비 지급 신청합니다._15155817.html
#
# ✅ HTML 파싱 완료: 7704개 문서
#
# ============================================================
# === DB 연결 시작 ===
# ✓ DB 연결 성공
#
# ⚠️ HTML 딕셔너리에 2002153 없음!
#
# === Step 1: end_year=2020 문서 조회 ===
# ✓ 조회 완료: 7704건
#
# === Step 2 & 3: 결재의견 초기화 및 업데이트 ===
# 처리 중... 1000/7704건 (매칭: 2525건)
# 처리 중... 2000/7704건 (매칭: 6116건)
# 처리 중... 3000/7704건 (매칭: 9855건)
# 처리 중... 4000/7704건 (매칭: 13355건)
# 처리 중... 5000/7704건 (매칭: 16607건)
# 처리 중... 6000/7704건 (매칭: 19947건)
# 처리 중... 7000/7704건 (매칭: 23318건)
#
# === 결과 요약 ===
# 총 처리: 7704건
# 업데이트: 7704건
# 의견 매칭: 25615건 (빈값 제외)
#
# ✓ DB 연결 종료
# ============================================================
#
# ✅ 모든 작업 완료!

# %%
import os
import json
import re
from datetime import datetime
import pytz
from bs4 import BeautifulSoup
import pymysql
from pathlib import Path

class ActionCommentUpdater:
    def __init__(self, base_path):
        self.base_path = base_path
        self.kst = pytz.timezone('Asia/Seoul')
        
    def extract_source_id(self, filename):
        """파일명에서 마지막 숫자 추출"""
        numbers = re.findall(r'\d+', filename)
        return numbers[-1] if numbers else None
    
    def extract_person_info(self, text):
        """이름/직책/부서 형식에서 이름만 추출"""
        text = re.sub(r'\d+', '', text).strip()
        parts = text.split('/')
        if len(parts) >= 1:
            return parts[0].strip()
        return None
    
    def parse_html_for_comments(self, html_path):
        """HTML 파일에서 source_id와 결재의견 추출"""
        with open(html_path, 'r', encoding='utf-8') as f:
            soup = BeautifulSoup(f.read(), 'html.parser')
        
        filename = os.path.basename(html_path)
        source_id = self.extract_source_id(filename)
        
        # span.user에서 이름, 시간, 의견 추출
        activities = []
        user_spans = soup.find_all('span', class_='user')
        
        for user_span in user_spans:
            # 이름 추출
            name_elem = user_span.find('span', class_='F_12_black_b')
            if not name_elem:
                continue
            
            name = self.extract_person_info(name_elem.get_text(strip=True))
            if not name:
                continue
            
            # 시간 추출
            time_elem = user_span.find('span', class_='F_11_gray')
            action_date = None
            if time_elem:
                time_text = time_elem.get_text(strip=True)
                try:
                    # 2020-12-31 13:57:02 형식 파싱
                    dt_naive = datetime.strptime(time_text, '%Y-%m-%d %H:%M:%S')
                    dt_kst = self.kst.localize(dt_naive)
                    action_date = int(dt_kst.timestamp() * 1000)
                except:
                    pass
            
            # 의견 추출
            action_comment = ""
            for sibling in user_span.next_siblings:
                if hasattr(sibling, 'name'):
                    if sibling.name == 'span' and 'user' in sibling.get('class', []):
                        break
                    if sibling.name == 'div':
                        action_comment = sibling.get_text(strip=True)
                        break
            
            activities.append({
                'name': name,
                'actionDate': action_date,
                'actionComment': action_comment
            })
        
        return {
            'sourceId': source_id,
            'activities': activities
        }
    
    def process_all_html_files(self):
        """모든 HTML 파일에서 결재의견 추출"""
        all_results = {}
        approval_path = Path(self.base_path) / '결재'
        
        if not approval_path.exists():
            print(f"경로를 찾을 수 없습니다: {approval_path}")
            return all_results
            
        html_files = list(approval_path.rglob('*.html'))
        print(f"총 {len(html_files)}개의 HTML 파일을 찾았습니다.")
        
        for idx, html_file in enumerate(html_files, 1):
            try:
                if idx % 100 == 0 or idx == len(html_files):
                    print(f"HTML 파싱 중... [{idx}/{len(html_files)}] {html_file.name}")
                result = self.parse_html_for_comments(html_file)
                source_id = result['sourceId']
                if source_id:
                    all_results[source_id] = result['activities']
            except Exception as e:
                print(f"오류 발생 ({html_file.name}): {e}")
        
        print(f"\n✅ HTML 파싱 완료: {len(all_results)}개 문서\n")
        return all_results
    
    def update_action_comments(self, db_config, end_year, html_comments):
        """DB의 결재의견 업데이트"""
        conn = None
        cursor = None
        
        try:
            print("=== DB 연결 시작 ===")
            conn = pymysql.connect(
                host=db_config['host'],
                user=db_config['user'],
                password=db_config['password'],
                database=db_config['database'],
                charset='utf8mb4'
            )
            print("✓ DB 연결 성공\n")
            cursor = conn.cursor(pymysql.cursors.DictCursor)
            
            # Step 1: end_year = 2020인 documents 조회
            print(f"=== Step 1: end_year={end_year} 문서 조회 ===")
            cursor.execute("""
                SELECT id, source_id, activities
                FROM documents
                WHERE end_year = %s
            """, (end_year,))
            
            documents = cursor.fetchall()
            print(f"✓ 조회 완료: {len(documents)}건\n")
            
            # Step 2 & 3: 결재의견 초기화 및 업데이트
            print(f"=== Step 2 & 3: 결재의견 초기화 및 업데이트 ===")
            
            total_count = 0
            updated_count = 0
            matched_count = 0
            error_count = 0
            
            for doc in documents:
                total_count += 1
                
                if total_count % 1000 == 0:
                    print(f"처리 중... {total_count}/{len(documents)}건 (매칭: {matched_count}건)")
                
                doc_id = doc['id']
                source_id = doc['source_id']
                activities_str = doc['activities']
                
                if not activities_str:
                    continue
                
                try:
                    # activities JSON 파싱
                    activities = json.loads(activities_str)
                    
                    # 모든 actionComment 초기화
                    for activity in activities:
                        activity['actionComment'] = ''
                    
                    # HTML에서 추출한 결재의견이 있으면 매칭
                    if source_id in html_comments:
                        html_activities = html_comments[source_id]
                        
                        # name + actionDate 매칭
                        for db_activity in activities:
                            db_name = db_activity.get('name', '')
                            db_date = db_activity.get('actionDate')
                            
                            for html_activity in html_activities:
                                html_name = html_activity.get('name', '')
                                html_date = html_activity.get('actionDate')
                                html_comment = html_activity.get('actionComment', '')
                                
                                # 이름과 날짜가 모두 일치
                                if db_name == html_name and db_date == html_date:
                                    db_activity['actionComment'] = html_comment
                                    if html_comment:  # 빈값이 아닌 의견만 카운트
                                        matched_count += 1
                                    break
                    
                    # DB 업데이트
                    updated_activities_str = json.dumps(activities, ensure_ascii=False, separators=(',', ':'))
                    cursor.execute("""
                        UPDATE documents 
                        SET activities = %s 
                        WHERE id = %s
                    """, (updated_activities_str, doc_id))
                    conn.commit()
                    updated_count += 1
                    
                except json.JSONDecodeError as e:
                    error_count += 1
                    print(f"⚠️ JSON 파싱 에러 (id={doc_id}, source_id={source_id}): {str(e)}")
                except Exception as e:
                    error_count += 1
                    print(f"⚠️ 업데이트 에러 (id={doc_id}): {str(e)}")
                    conn.rollback()
            
            print(f"\n=== 결과 요약 ===")
            print(f"총 처리: {total_count}건")
            print(f"업데이트: {updated_count}건")
            print(f"의견 매칭: {matched_count}건 (빈값 제외)")
            if error_count > 0:
                print(f"⚠️ 에러: {error_count}건")
            
        except Exception as e:
            print(f"❌ 오류 발생: {e}")
            if conn:
                conn.rollback()
        
        finally:
            if cursor:
                cursor.close()
            if conn:
                conn.close()
                print("\n✓ DB 연결 종료")


def main():
    # 설정
    base_path = r'C:\Users\LEEJUHWAN\Downloads\2020-01-01~2020-12-31\html'
    end_year = 2020
    
    db_config = {
        'host': 'localhost',
        'user': 'root',
        'password': '1234',
        'database': 'any_approval'
    }
    
    # 실행
    updater = ActionCommentUpdater(base_path)
    
    # 1. HTML에서 결재의견 추출
    print("="*60)
    html_comments = updater.process_all_html_files()
    
    # 2. DB 업데이트
    print("="*60)
    updater.update_action_comments(db_config, end_year, html_comments)
    print("="*60)
    
    print("\n✅ 모든 작업 완료!")


if __name__ == '__main__':
    main()
# Out:
# ============================================================
# 총 840개의 HTML 파일을 찾았습니다.
# HTML 파싱 중... [100/840] 20100225_연차휴가(3_2) 신청합니다._2002163.html
# HTML 파싱 중... [200/840] 20100401_[기술지원팀 격려 인센티브 지급품의]_2002268.html
# HTML 파싱 중... [300/840] 20100517_개인휴가품의_2002367.html
# HTML 파싱 중... [400/840] 20100705_파일서버 접근 권한 요청_2002467.html
# HTML 파싱 중... [500/840] 20100817_8월 아웃소싱 인건비 지급 품의-기술지원부문_2002570.html
# HTML 파싱 중... [600/840] 20100929_재직증명서 발급요청_2002666.html
# HTML 파싱 중... [700/840] 20101110_대전지사 공용 하드디스크 구매 요청_2002767.html
# HTML 파싱 중... [800/840] 20101221_12월 아웃소싱 인건비 지급 품의-전문가Gr.(김규일)_2002865.html
# HTML 파싱 중... [840/840] 20101231_법인카드 사용내역 정산 보고(10월,11월,12월)_2002907.html
#
# ✅ HTML 파싱 완료: 840개 문서
#
# ============================================================
# === DB 연결 시작 ===
# ✓ DB 연결 성공
#
# === Step 1: end_year=2010 문서 조회 ===
# ✓ 조회 완료: 840건
#
# === Step 2 & 3: 결재의견 초기화 및 업데이트 ===
#
# === 결과 요약 ===
# 총 처리: 840건
# 업데이트: 840건
# 의견 매칭: 361건 (빈값 제외)
#
# ✓ DB 연결 종료
# ============================================================
#
# ✅ 모든 작업 완료!
