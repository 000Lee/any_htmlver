# %%
pip install beautifulsoup4 pymysql lxml
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\leejuhwan\miniconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: pymysql in c:\users\leejuhwan\miniconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: lxml in c:\users\leejuhwan\miniconda3\lib\site-packages (6.0.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\leejuhwan\miniconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\leejuhwan\miniconda3\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# drafter 이름 안나오는건 보완

# endYear 컬럼 추가해서 여러 기간 폴더 데이터를 하나의 테이블에 구분해서 저장할 수 있게 변경

# + type이 합의인것만 - AGREEMENT로 변경
# 디비 저장 오류 수정 

import os
import json
import re
from datetime import datetime
from bs4 import BeautifulSoup
import pymysql
from pathlib import Path

class ApprovalDocParser:
    def __init__(self, base_path):
        self.base_path = base_path
        
    def extract_source_id(self, filename):
        """파일명에서 마지막 숫자 추출"""
        numbers = re.findall(r'\d+', filename)
        return numbers[-1] if numbers else None
    
    def parse_datetime_to_unix(self, date_str):
        """날짜 문자열을 Unix timestamp(밀리초)로 변환"""
        try:
            dt = datetime.strptime(date_str.strip(), "%Y-%m-%d %H:%M:%S")
            return int(dt.timestamp() * 1000)
        except:
            return None
    
    def extract_person_info(self, text):
        """이름/직책/부서 형식에서 정보 추출"""
        text = re.sub(r'\d+', '', text).strip()
        parts = text.split('/')
        if len(parts) >= 3:
            return {
                'name': parts[0].strip(),
                'positionName': parts[1].strip(),
                'deptName': parts[2].strip()
            }
        return None
    
    def parse_html(self, html_path):
        """HTML 파일 파싱"""
        with open(html_path, 'r', encoding='utf-8') as f:
            soup = BeautifulSoup(f.read(), 'html.parser')
        
        filename = os.path.basename(html_path)
        source_id = self.extract_source_id(filename)
        
        doc_num_elem = soup.find('p', class_='team')
        doc_num = doc_num_elem.get_text(strip=True) if doc_num_elem else ""
        
        references_elem = soup.find('span', class_='disInline o-i-min-fileList')
        references = []
        if references_elem:
            next_elem = references_elem.find_next_sibling()
            if next_elem:
                references = next_elem.get_text(strip=True)
            else:
                parent = references_elem.parent
                references = parent.get_text(strip=True)
        
        title_elem = soup.find('title')
        title = title_elem.get_text(strip=True) if title_elem else ""
        
        attaches = []
        verti_tops = soup.find_all('span', class_='verti_Top')
        for vt in verti_tops:
            a_tag = vt.find('a')
            if a_tag and a_tag.get('href'):
                attaches.append({
                    'name': a_tag.get_text(strip=True),
                    'path': a_tag.get('href')
                })
        
        # 기존 방식: user_spans에서 drafter 추출
        user_spans = soup.find_all('span', class_='user')
        drafter = {}
        if user_spans:
            first_user = user_spans[0]
            name_elem = first_user.find('span', class_='F_12_black_b')
            if name_elem:
                info = self.extract_person_info(name_elem.get_text(strip=True))
                if info:
                    drafter = {
                        'positionName': info['positionName'],
                        'deptName': info['deptName'],
                        'name': info['name'],
                        'emailId': '',
                        'deptCode': ''
                    }
        
        # drafter가 비어있으면 테이블의 "기안자" 행에서 추출 (백업)
        if not drafter or not drafter.get('name'):
            drafter_th = soup.find('th', string=lambda s: s and '기안자' in s)
            if drafter_th:
                drafter_td = drafter_th.find_next_sibling('td')
                if drafter_td:
                    bg01_div = drafter_td.find('div', class_='bg01')
                    if bg01_div:
                        name = bg01_div.get_text(strip=True)
                        if name:  # 이름이 실제로 있으면
                            drafter = {
                                'positionName': '',
                                'deptName': '',
                                'name': name,
                                'emailId': '',
                                'deptCode': ''
                            }
        
        created_at = None
        if user_spans:
            date_elem = user_spans[0].find('span', class_='F_11_gray')
            if date_elem:
                created_at = self.parse_datetime_to_unix(date_elem.get_text(strip=True))
        
        referrers = []
        ref_th = soup.find('th', string=lambda s: s and '참조' in s)
        if ref_th:
            ref_td = ref_th.find_next_sibling('td')
            if ref_td:
                ref_text = ref_td.get_text(strip=True)
                ref_list = re.split(r'[,\s]+', ref_text)
                for ref in ref_list:
                    if ref:
                        info = self.extract_person_info(ref)
                        if info:
                            referrers.append({
                                'name': info['name'],
                                'empNo': '',
                                'deptCode': ''
                            })
        
        # 결재선 영역에서 "합의"인 사람들의 이름 추출
        agreement_names = []
        appr_line_area = soup.find('div', id='apprLineArea')
        if appr_line_area:
            red_spans = appr_line_area.find_all('span', class_='red')
            for red_span in red_spans:
                if '합의' in red_span.get_text(strip=True):
                    # red span의 부모 li의 이전 형제 li에서 이름 찾기
                    parent_li = red_span.find_parent('li')
                    if parent_li:
                        prev_li = parent_li.find_previous_sibling('li')
                        if prev_li:
                            name_text = prev_li.get_text(strip=True)
                            # 이름만 추출 (숫자 제거 등)
                            if name_text:
                                agreement_names.append(name_text)
        
        activities = []
        for idx, user_span in enumerate(user_spans):
            name_elem = user_span.find('span', class_='F_12_black_b')
            date_elem = user_span.find('span', class_='F_11_gray')
            
            if name_elem:
                info = self.extract_person_info(name_elem.get_text(strip=True))
                if info:
                    action_comment = ""
                    next_elem = user_span.next_sibling
                    while next_elem:
                        if hasattr(next_elem, 'name') and next_elem.name == 'div':
                            action_comment = next_elem.get_text(strip=True)
                            break
                        next_elem = next_elem.next_sibling
                    
                    # 기본 타입 설정
                    action_type = 'DRAFT' if idx == 0 else 'APPROVAL'
                    
                    # 이 사람이 합의자 리스트에 있으면 AGREEMENT로 변경
                    if info['name'] in agreement_names:
                        action_type = 'AGREEMENT'
                    
                    activities.append({
                        'positionName': info['positionName'],
                        'deptName': info['deptName'],
                        'actionLogType': action_type,
                        'name': info['name'],
                        'emailId': '',
                        'type': action_type,
                        'actionDate': self.parse_datetime_to_unix(date_elem.get_text(strip=True)) if date_elem else None,
                        'deptCode': '',
                        'actionComment': action_comment
                    })
        
        result = {
            'sourceId': source_id,
            'docNum': doc_num,
            'references': references,
            'docType': 'DRAFT',
            'title': title,
            'attaches': attaches,
            'drafter': drafter,
            'createdAt': created_at,
            'docBody': '',
            'docStatus': 'COMPLETE',
            'referrers': referrers,
            'activities': activities,
            'formName': '',
            'isPublic': False
        }
        
        return result
    
    def process_all_files(self):
        """모든 HTML 파일 처리"""
        all_results = []
        approval_path = Path(self.base_path) / '결재'
        
        if not approval_path.exists():
            print(f"경로를 찾을 수 없습니다: {approval_path}")
            return all_results
            
        html_files = list(approval_path.rglob('*.html'))
        # html_files = list(approval_path.rglob('*.html'))[:10]
        print(f"총 {len(html_files)}개의 HTML 파일을 찾았습니다.")
        
        for idx, html_file in enumerate(html_files, 1):
            try:
                print(f"처리 중... [{idx}/{len(html_files)}] {html_file.name}")
                result = self.parse_html(html_file)
                all_results.append(result)
            except Exception as e:
                print(f"오류 발생 ({html_file.name}): {e}")
        
        return all_results
    
    def save_to_json(self, data, output_path):
        """JSON 파일로 저장"""
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)
        print(f"JSON 파일 저장 완료: {output_path}")
    
    def save_to_mariadb(self, data, db_config, end_year):
        """MariaDB에 저장 - 안정성 강화 버전"""
        conn = None
        cursor = None
        
        try:
            print("\n=== DB 연결 시작 ===")
            print(f"Host: {db_config['host']}, Database: {db_config['database']}")
            
            # DB 연결
            conn = pymysql.connect(
                host=db_config['host'],
                user=db_config['user'],
                password=db_config['password'],
                database=db_config['database'],
                charset='utf8mb4'
            )
            print("✓ DB 연결 성공")
            
            cursor = conn.cursor()
            
            # 테이블 생성
            print("\n=== 테이블 생성 시작 ===")
            create_table_sql = """
            CREATE TABLE IF NOT EXISTS documents (
                id INT AUTO_INCREMENT PRIMARY KEY,
                source_id VARCHAR(50),
                doc_num VARCHAR(100),
                doc_type VARCHAR(50),
                title VARCHAR(500),
                doc_status VARCHAR(50),
                created_at BIGINT,
                drafter_name VARCHAR(100),
                drafter_position VARCHAR(100),
                drafter_dept VARCHAR(100),
                form_name VARCHAR(200),
                is_public BOOLEAN,
                end_year INT,
                `references` TEXT,
                attaches TEXT,
                referrers TEXT,
                activities TEXT,
                doc_body TEXT,
                created_date TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
                INDEX idx_source_id (source_id),
                INDEX idx_doc_num (doc_num),
                INDEX idx_created_at (created_at),
                INDEX idx_end_year (end_year)
            ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_unicode_ci;
            """
            cursor.execute(create_table_sql)
            print("✓ 테이블 생성/확인 완료")
            
            # 기존 데이터 확인
            cursor.execute("SELECT COUNT(*) FROM documents")
            existing_count = cursor.fetchone()[0]
            print(f"✓ 기존 데이터: {existing_count}건")
            
            # 데이터 삽입
            print(f"\n=== 데이터 삽입 시작 ({len(data)}건) ===")
            insert_sql = """
            INSERT INTO documents 
            (source_id, doc_num, doc_type, title, doc_status, created_at, 
             drafter_name, drafter_position, drafter_dept, form_name, is_public, end_year,
             `references`, attaches, referrers, activities, doc_body)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            
            success_count = 0
            error_count = 0
            error_details = []
            
            for idx, doc in enumerate(data, 1):
                try:
                    # 데이터 길이 제한 및 안전한 변환
                    def safe_string(value, max_length=None):
                        if value is None:
                            return ''
                        s = str(value).strip()
                        if max_length and len(s) > max_length:
                            s = s[:max_length]
                        return s
                    
                    # JSON 데이터를 안전하게 변환 (ensure_ascii=True로 특수문자 이스케이프)
                    def safe_json(value):
                        if not value:
                            return '[]'
                        try:
                            # ensure_ascii=True로 모든 비ASCII 문자를 이스케이프
                            return json.dumps(value, ensure_ascii=True)
                        except:
                            return '[]'
                    
                    values = (
                        safe_string(doc.get('sourceId'), 50),
                        safe_string(doc.get('docNum'), 100),
                        safe_string(doc.get('docType'), 50),
                        safe_string(doc.get('title'), 500),
                        safe_string(doc.get('docStatus'), 50),
                        doc.get('createdAt'),
                        safe_string(doc.get('drafter', {}).get('name'), 100),
                        safe_string(doc.get('drafter', {}).get('positionName'), 100),
                        safe_string(doc.get('drafter', {}).get('deptName'), 100),
                        safe_string(doc.get('formName'), 200),
                        doc.get('isPublic', False),
                        end_year,
                        safe_string(doc.get('references')),
                        safe_json(doc.get('attaches', [])),
                        safe_json(doc.get('referrers', [])),
                        safe_json(doc.get('activities', [])),
                        safe_string(doc.get('docBody'))
                    )
                    
                    cursor.execute(insert_sql, values)
                    success_count += 1
                    
                    # 100건마다만 출력 (로그 줄이기)
                    if idx % 100 == 0 or idx == len(data):
                        print(f"  진행: {idx}/{len(data)} (성공: {success_count}, 실패: {error_count})")
                    
                except Exception as e:
                    error_count += 1
                    error_msg = f"sourceId: {doc.get('sourceId')} - {str(e)[:80]}"
                    error_details.append(error_msg)
                    
                    # 처음 5개 오류만 즉시 출력
                    if error_count <= 5:
                        print(f"  [오류 {error_count}] {error_msg}")
            
            # 커밋
            print("\n=== 커밋 시작 ===")
            conn.commit()
            print(f"✓ 커밋 완료")
            
            # 결과 요약
            print(f"\n=== 결과 요약 ===")
            print(f"✓ 성공: {success_count}건")
            print(f"✗ 실패: {error_count}건")
            
            if error_count > 5:
                print(f"\n처음 5개 외 {error_count - 5}개의 추가 오류가 발생했습니다.")
                print("모든 오류 보기:")
                for err in error_details[:20]:  # 최대 20개만 출력
                    print(f"  - {err}")
                if len(error_details) > 20:
                    print(f"  ... 외 {len(error_details) - 20}개 더")
            
            # 최종 확인
            cursor.execute("SELECT COUNT(*) FROM documents")
            final_count = cursor.fetchone()[0]
            print(f"\n✓ 최종 데이터: {final_count}건 (이번 실행으로 {success_count}건 추가)")
            
        except pymysql.Error as e:
            print(f"\n❌ DB 오류 발생:")
            print(f"  Error Code: {e.args[0]}")
            print(f"  Error Message: {e.args[1]}")
            
        except Exception as e:
            print(f"\n❌ 일반 오류 발생: {e}")
            
        finally:
            if cursor:
                cursor.close()
            if conn:
                conn.close()
                print("\n✓ DB 연결 종료")


def main():
    base_path = r'C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html' #컨트롤러
    end_year = 2020  #컨트롤러 - 폴더 기간에 맞게 수정
    
    parser = ApprovalDocParser(base_path)
    
    print("HTML 파일 파싱 시작...")
    results = parser.process_all_files()
    
    output_json_path = 'two_htmltojsondb_convert.json' #컨트롤러
    parser.save_to_json(results, output_json_path)
    
    # DB 설정
    db_config = {
        'host': 'localhost',
        'user': 'root',
        'password': '1234',
        'database': 'any_approval' #컨트롤러 - 통합 DB명
    }
    
    # MariaDB에 저장
    print("\n" + "="*50)
    parser.save_to_mariadb(results, db_config, end_year)
    print("="*50)
    
    print(f"\n완료! 총 {len(results)}건 처리됨")


if __name__ == '__main__':
    main()

# %%
# endYear 컬럼 추가해서 여러 기간 폴더 데이터를 하나의 테이블에 구분해서 저장할 수 있게 변경

# + type이 합의인것만 - AGREEMENT로 변경
# 디비 저장 오류 수정 

import os
import json
import re
from datetime import datetime
from bs4 import BeautifulSoup
import pymysql
from pathlib import Path

class ApprovalDocParser:
    def __init__(self, base_path):
        self.base_path = base_path
        
    def extract_source_id(self, filename):
        """파일명에서 마지막 숫자 추출"""
        numbers = re.findall(r'\d+', filename)
        return numbers[-1] if numbers else None
    
    def parse_datetime_to_unix(self, date_str):
        """날짜 문자열을 Unix timestamp(밀리초)로 변환"""
        try:
            dt = datetime.strptime(date_str.strip(), "%Y-%m-%d %H:%M:%S")
            return int(dt.timestamp() * 1000)
        except:
            return None
    
    def extract_person_info(self, text):
        """이름/직책/부서 형식에서 정보 추출"""
        text = re.sub(r'\d+', '', text).strip()
        parts = text.split('/')
        if len(parts) >= 3:
            return {
                'name': parts[0].strip(),
                'positionName': parts[1].strip(),
                'deptName': parts[2].strip()
            }
        return None
    
    def parse_html(self, html_path):
        """HTML 파일 파싱"""
        with open(html_path, 'r', encoding='utf-8') as f:
            soup = BeautifulSoup(f.read(), 'html.parser')
        
        filename = os.path.basename(html_path)
        source_id = self.extract_source_id(filename)
        
        doc_num_elem = soup.find('p', class_='team')
        doc_num = doc_num_elem.get_text(strip=True) if doc_num_elem else ""
        
        references_elem = soup.find('span', class_='disInline o-i-min-fileList')
        references = []
        if references_elem:
            next_elem = references_elem.find_next_sibling()
            if next_elem:
                references = next_elem.get_text(strip=True)
            else:
                parent = references_elem.parent
                references = parent.get_text(strip=True)
        
        title_elem = soup.find('title')
        title = title_elem.get_text(strip=True) if title_elem else ""
        
        attaches = []
        verti_tops = soup.find_all('span', class_='verti_Top')
        for vt in verti_tops:
            a_tag = vt.find('a')
            if a_tag and a_tag.get('href'):
                attaches.append({
                    'name': a_tag.get_text(strip=True),
                    'path': a_tag.get('href')
                })
        
        user_spans = soup.find_all('span', class_='user')
        drafter = {}
        if user_spans:
            first_user = user_spans[0]
            name_elem = first_user.find('span', class_='F_12_black_b')
            if name_elem:
                info = self.extract_person_info(name_elem.get_text(strip=True))
                if info:
                    drafter = {
                        'positionName': info['positionName'],
                        'deptName': info['deptName'],
                        'name': info['name'],
                        'emailId': '',
                        'deptCode': ''
                    }
        
        created_at = None
        if user_spans:
            date_elem = user_spans[0].find('span', class_='F_11_gray')
            if date_elem:
                created_at = self.parse_datetime_to_unix(date_elem.get_text(strip=True))
        
        referrers = []
        ref_th = soup.find('th', string=lambda s: s and '참조' in s)
        if ref_th:
            ref_td = ref_th.find_next_sibling('td')
            if ref_td:
                ref_text = ref_td.get_text(strip=True)
                ref_list = re.split(r'[,\s]+', ref_text)
                for ref in ref_list:
                    if ref:
                        info = self.extract_person_info(ref)
                        if info:
                            referrers.append({
                                'name': info['name'],
                                'empNo': '',
                                'deptCode': ''
                            })
        
        # 결재선 영역에서 "합의"인 사람들의 이름 추출
        agreement_names = []
        appr_line_area = soup.find('div', id='apprLineArea')
        if appr_line_area:
            red_spans = appr_line_area.find_all('span', class_='red')
            for red_span in red_spans:
                if '합의' in red_span.get_text(strip=True):
                    # red span의 부모 li의 이전 형제 li에서 이름 찾기
                    parent_li = red_span.find_parent('li')
                    if parent_li:
                        prev_li = parent_li.find_previous_sibling('li')
                        if prev_li:
                            name_text = prev_li.get_text(strip=True)
                            # 이름만 추출 (숫자 제거 등)
                            if name_text:
                                agreement_names.append(name_text)
        
        activities = []
        for idx, user_span in enumerate(user_spans):
            name_elem = user_span.find('span', class_='F_12_black_b')
            date_elem = user_span.find('span', class_='F_11_gray')
            
            if name_elem:
                info = self.extract_person_info(name_elem.get_text(strip=True))
                if info:
                    action_comment = ""
                    next_elem = user_span.next_sibling
                    while next_elem:
                        if hasattr(next_elem, 'name') and next_elem.name == 'div':
                            action_comment = next_elem.get_text(strip=True)
                            break
                        next_elem = next_elem.next_sibling
                    
                    # 기본 타입 설정
                    action_type = 'DRAFT' if idx == 0 else 'APPROVAL'
                    
                    # 이 사람이 합의자 리스트에 있으면 AGREEMENT로 변경
                    if info['name'] in agreement_names:
                        action_type = 'AGREEMENT'
                    
                    activities.append({
                        'positionName': info['positionName'],
                        'deptName': info['deptName'],
                        'actionLogType': action_type,
                        'name': info['name'],
                        'emailId': '',
                        'type': action_type,
                        'actionDate': self.parse_datetime_to_unix(date_elem.get_text(strip=True)) if date_elem else None,
                        'deptCode': '',
                        'actionComment': action_comment
                    })
        
        result = {
            'sourceId': source_id,
            'docNum': doc_num,
            'references': references,
            'docType': 'DRAFT',
            'title': title,
            'attaches': attaches,
            'drafter': drafter,
            'createdAt': created_at,
            'docBody': '',
            'docStatus': 'COMPLETE',
            'referrers': referrers,
            'activities': activities,
            'formName': '',
            'isPublic': False
        }
        
        return result
    
    def process_all_files(self):
        """모든 HTML 파일 처리"""
        all_results = []
        approval_path = Path(self.base_path) / '결재'
        
        if not approval_path.exists():
            print(f"경로를 찾을 수 없습니다: {approval_path}")
            return all_results
            
        html_files = list(approval_path.rglob('*.html'))
        # html_files = list(approval_path.rglob('*.html'))[:10]
        print(f"총 {len(html_files)}개의 HTML 파일을 찾았습니다.")
        
        for idx, html_file in enumerate(html_files, 1):
            try:
                print(f"처리 중... [{idx}/{len(html_files)}] {html_file.name}")
                result = self.parse_html(html_file)
                all_results.append(result)
            except Exception as e:
                print(f"오류 발생 ({html_file.name}): {e}")
        
        return all_results
    
    def save_to_json(self, data, output_path):
        """JSON 파일로 저장"""
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)
        print(f"JSON 파일 저장 완료: {output_path}")
    
    def save_to_mariadb(self, data, db_config, end_year):
        """MariaDB에 저장 - 안정성 강화 버전"""
        conn = None
        cursor = None
        
        try:
            print("\n=== DB 연결 시작 ===")
            print(f"Host: {db_config['host']}, Database: {db_config['database']}")
            
            # DB 연결
            conn = pymysql.connect(
                host=db_config['host'],
                user=db_config['user'],
                password=db_config['password'],
                database=db_config['database'],
                charset='utf8mb4'
            )
            print("✓ DB 연결 성공")
            
            cursor = conn.cursor()
            
            # 테이블 생성
            print("\n=== 테이블 생성 시작 ===")
            create_table_sql = """
            CREATE TABLE IF NOT EXISTS documents (
                id INT AUTO_INCREMENT PRIMARY KEY,
                source_id VARCHAR(50),
                doc_num VARCHAR(100),
                doc_type VARCHAR(50),
                title VARCHAR(500),
                doc_status VARCHAR(50),
                created_at BIGINT,
                drafter_name VARCHAR(100),
                drafter_position VARCHAR(100),
                drafter_dept VARCHAR(100),
                form_name VARCHAR(200),
                is_public BOOLEAN,
                end_year INT,
                `references` TEXT,
                attaches TEXT,
                referrers TEXT,
                activities TEXT,
                doc_body TEXT,
                created_date TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
                INDEX idx_source_id (source_id),
                INDEX idx_doc_num (doc_num),
                INDEX idx_created_at (created_at),
                INDEX idx_end_year (end_year)
            ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_unicode_ci;
            """
            cursor.execute(create_table_sql)
            print("✓ 테이블 생성/확인 완료")
            
            # 기존 데이터 확인
            cursor.execute("SELECT COUNT(*) FROM documents")
            existing_count = cursor.fetchone()[0]
            print(f"✓ 기존 데이터: {existing_count}건")
            
            # 데이터 삽입
            print(f"\n=== 데이터 삽입 시작 ({len(data)}건) ===")
            insert_sql = """
            INSERT INTO documents 
            (source_id, doc_num, doc_type, title, doc_status, created_at, 
             drafter_name, drafter_position, drafter_dept, form_name, is_public, end_year,
             `references`, attaches, referrers, activities, doc_body)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            
            success_count = 0
            error_count = 0
            error_details = []
            
            for idx, doc in enumerate(data, 1):
                try:
                    # 데이터 길이 제한 및 안전한 변환
                    def safe_string(value, max_length=None):
                        if value is None:
                            return ''
                        s = str(value).strip()
                        if max_length and len(s) > max_length:
                            s = s[:max_length]
                        return s
                    
                    # JSON 데이터를 안전하게 변환 (ensure_ascii=True로 특수문자 이스케이프)
                    def safe_json(value):
                        if not value:
                            return '[]'
                        try:
                            # ensure_ascii=True로 모든 비ASCII 문자를 이스케이프
                            return json.dumps(value, ensure_ascii=True)
                        except:
                            return '[]'
                    
                    values = (
                        safe_string(doc.get('sourceId'), 50),
                        safe_string(doc.get('docNum'), 100),
                        safe_string(doc.get('docType'), 50),
                        safe_string(doc.get('title'), 500),
                        safe_string(doc.get('docStatus'), 50),
                        doc.get('createdAt'),
                        safe_string(doc.get('drafter', {}).get('name'), 100),
                        safe_string(doc.get('drafter', {}).get('positionName'), 100),
                        safe_string(doc.get('drafter', {}).get('deptName'), 100),
                        safe_string(doc.get('formName'), 200),
                        doc.get('isPublic', False),
                        end_year,
                        safe_string(doc.get('references')),
                        safe_json(doc.get('attaches', [])),
                        safe_json(doc.get('referrers', [])),
                        safe_json(doc.get('activities', [])),
                        safe_string(doc.get('docBody'))
                    )
                    
                    cursor.execute(insert_sql, values)
                    success_count += 1
                    
                    # 100건마다만 출력 (로그 줄이기)
                    if idx % 100 == 0 or idx == len(data):
                        print(f"  진행: {idx}/{len(data)} (성공: {success_count}, 실패: {error_count})")
                    
                except Exception as e:
                    error_count += 1
                    error_msg = f"sourceId: {doc.get('sourceId')} - {str(e)[:80]}"
                    error_details.append(error_msg)
                    
                    # 처음 5개 오류만 즉시 출력
                    if error_count <= 5:
                        print(f"  [오류 {error_count}] {error_msg}")
            
            # 커밋
            print("\n=== 커밋 시작 ===")
            conn.commit()
            print(f"✓ 커밋 완료")
            
            # 결과 요약
            print(f"\n=== 결과 요약 ===")
            print(f"✓ 성공: {success_count}건")
            print(f"✗ 실패: {error_count}건")
            
            if error_count > 5:
                print(f"\n처음 5개 외 {error_count - 5}개의 추가 오류가 발생했습니다.")
                print("모든 오류 보기:")
                for err in error_details[:20]:  # 최대 20개만 출력
                    print(f"  - {err}")
                if len(error_details) > 20:
                    print(f"  ... 외 {len(error_details) - 20}개 더")
            
            # 최종 확인
            cursor.execute("SELECT COUNT(*) FROM documents")
            final_count = cursor.fetchone()[0]
            print(f"\n✓ 최종 데이터: {final_count}건 (이번 실행으로 {success_count}건 추가)")
            
        except pymysql.Error as e:
            print(f"\n❌ DB 오류 발생:")
            print(f"  Error Code: {e.args[0]}")
            print(f"  Error Message: {e.args[1]}")
            
        except Exception as e:
            print(f"\n❌ 일반 오류 발생: {e}")
            
        finally:
            if cursor:
                cursor.close()
            if conn:
                conn.close()
                print("\n✓ DB 연결 종료")


def main():
    base_path = r'C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html' #컨트롤러
    end_year = 2020  #컨트롤러 - 폴더 기간에 맞게 수정
    
    parser = ApprovalDocParser(base_path)
    
    print("HTML 파일 파싱 시작...")
    results = parser.process_all_files()
    
    output_json_path = 'two_htmltojsondb_convert.json' #컨트롤러
    parser.save_to_json(results, output_json_path)
    
    # DB 설정
    db_config = {
        'host': 'localhost',
        'user': 'root',
        'password': '1234',
        'database': 'any_approval' #컨트롤러 - 통합 DB명
    }
    
    # MariaDB에 저장
    print("\n" + "="*50)
    parser.save_to_mariadb(results, db_config, end_year)
    print("="*50)
    
    print(f"\n완료! 총 {len(results)}건 처리됨")


if __name__ == '__main__':
    main()
# Out:
# HTML 파일 파싱 시작...
# 총 7704개의 HTML 파일을 찾았습니다.
# 처리 중... [1/7704] 20160104_12월 야근식대 청구_2009497.html
# 처리 중... [2/7704] 20160104_2016.01.08일(금) 반차 신청_2009503.html
# 처리 중... [3/7704] 20160104_ETRI 출장 교통비 신청_2009500.html
# 처리 중... [4/7704] 20160104_영남대학교 기술사업화포털시스템 검색엔진 구매 품의_2009502.html
# 처리 중... [5/7704] 20160104_정보보안기사 교재구입 요청_2009499.html
# 처리 중... [6/7704] 20160104_출장 품의(생산기술연구원)_2009501.html
# 처리 중... [7/7704] 20160104_취약점 개선 및 적용으로 인한 야간근무 교통비_2009498.html
# 처리 중... [8/7704] 20160105_12월 잔업식대_2009507.html
# 처리 중... [9/7704] 20160105_R&D사업팀 사원 이은희입니다._2009504.html
# 처리 중... [10/7704] 20160105_[계약변경 협의건] 현대엔지비 기술지식서비스 시스템 구축_2009505.html
# 처리 중... [11/7704] 20160105_대전 정보통신기술진흥센터(IITP) 출장비 정산 품의_2009508.html
# 처리 중... [12/7704] 20160105_서버계정 신청_2009506.html
# 처리 중... [13/7704] 20160105_워크샵 주유비 품의 입니다._2009509.html
# 처리 중... [14/7704] 20160106_SK케미칼 지재권관리시스템 2016년 유지보수 계약 품의_2009510.html
# 처리 중... [15/7704] 20160107_건강검진비 지급 신청_2009511.html
# 처리 중... [16/7704] 20160107_현대엔지비 기술지식서비스팀 저녁 및 주말 식대_2009512.html
# 처리 중... [17/7704] 20160108_[채용품의] 경력사원 입사품의_권민선(사업지원팀) _ 문규원(IPR사업팀)_2009513.html
# 처리 중... [18/7704] 20160108_[채용품의] 김학선(R&D사업팀)_2009514.html
# 처리 중... [19/7704] 20160108_영남대학교 기술사업화포털시스템 구축 출장비 품의_2009516.html
# 처리 중... [20/7704] 20160108_휴가신청_2009515.html
# 처리 중... [21/7704] 20160111_2016년1월 아웃소싱 인건비 지급 품의(1월15일 지급건)_2009519.html
# 처리 중... [22/7704] 20160111_심평원 프로젝트 교통비(강정례)_2009518.html
# 처리 중... [23/7704] 20160111_심평원 프로젝트 중식 식대기안(강정례)_2009517.html
# 처리 중... [24/7704] 20160112_OCI 보안웹서버 SSL인증서 발급의 건_2009520.html
# 처리 중... [25/7704] 20160112_국토교통부 항공안전종합통제시스템 2차사업 계약 품의_2009522.html
# 처리 중... [26/7704] 20160112_김형환 휴직 품의_2009523.html
# 처리 중... [27/7704] 20160112_대전숙소(세종아파트) 관리비_2015년 9~11월_2009524.html
# 처리 중... [28/7704] 20160112_심평원 의료자원 신고일원화시스템 구축 신고포털 부문 추가 계약 건_2009521.html
# 처리 중... [29/7704] 20160113_연차상신(강정례)_2009525.html
# 처리 중... [30/7704] 20160113_휴가 신청_2009526.html
# 처리 중... [31/7704] 20160114_[대금결제] 웹취약성 보안점검 구매(현대엔지비 연구관리지원시스템 구축)_2009536.html
# 처리 중... [32/7704] 20160114_[외주인력투입계약품의_대내] LG CNS 2016년 사내 MPS서비스 운영 (박계수)_2009531.html
# 처리 중... [33/7704] 20160114_[외주인력투입계약품의_대내] LG화학 기술연구원 P2MS개발 (김성연)_2009530.html
# 처리 중... [34/7704] 20160114_[외주인력투입수정계약품의] LG화학 ASK(신청시스템 개발) (구성윤)_2009532.html
# 처리 중... [35/7704] 20160114_[외주인력투입수정계약품의] LG화학 ASK(신청시스템 개발) (권우현)_2009533.html
# 처리 중... [36/7704] 20160114_[한국생산기술연구원]프린터기 구매_2009527.html
# 처리 중... [37/7704] 20160114_경조금 지급 신청_2009529.html
# 처리 중... [38/7704] 20160114_연차상신(강정례)_2009534.html
# 처리 중... [39/7704] 20160114_퇴사기안(강정례-퇴직희망일 변경으로 재기안)_2009535.html
# 처리 중... [40/7704] 20160114_한국생산기술연 CP 품의_2009528.html
# 처리 중... [41/7704] 20160115_[대금결제] 한국항공우주연구원 특허관리시스템 구축 서버구매_2009537.html
# 처리 중... [42/7704] 20160117_대전 장기출장비 품의_2009538.html
# 처리 중... [43/7704] 20160118_ETRI 출장 교통비 신청_2009544.html
# 처리 중... [44/7704] 20160118_[외주인력투입계약품의_대외] ETRI_품질보증기반 과제수행을 위한 PMS개선 (김종명)_2009540.html
# 처리 중... [45/7704] 20160118_[현대엔지비 연구관리지원시스템구축_기술지식서비스]웹취약성 보안점검 구매를 신청합니다._2009541.html
# 처리 중... [46/7704] 20160118_국민권익위원회 16년 공통행정 전산자원 유지관리 및 위탁운영 용역(운영시스템) 계약 건_2009539.html
# 처리 중... [47/7704] 20160118_연차 휴가 사용신청_2009543.html
# 처리 중... [48/7704] 20160118_재직증명서 발급신청합니다._2009542.html
# 처리 중... [49/7704] 20160119_[IITP PM 성과수당 지급 품의]_2009546.html
# 처리 중... [50/7704] 20160119_원자력연구원 외 1 곳 시내교통비 품의_2009545.html
# 처리 중... [51/7704] 20160120_연차휴가 사용(2016.01.22)_2009547.html
# 처리 중... [52/7704] 20160121_OCI지식재산통합관리 프로젝트 팀 회식비 지원 요청_2009555.html
# 처리 중... [53/7704] 20160121_[외주인력투입계약품의_대외] ETRI_신)연구비관리시스템 관련 PMS시스템 연계 (김성우)_2009548.html
# 처리 중... [54/7704] 20160121_사람인 인재열람상품 100건(150일사용) 신청_2009550.html
# 처리 중... [55/7704] 20160121_서버계정 신청_2009552.html
# 처리 중... [56/7704] 20160121_영남대_항우연 프로젝트 회식비 품의_2009553.html
# 처리 중... [57/7704] 20160121_영남대학교 출장 교통비 신청_2009554.html
# 처리 중... [58/7704] 20160121_출장비 정산 품의(단기출장 2일)_2009551.html
# 처리 중... [59/7704] 20160121_한국생산기술연구원 프로젝트 관련 장기출장 품의건_2009549.html
# 처리 중... [60/7704] 20160122_2016년1월 아웃소싱 인건비 지급 품의(1월25일 지급건) _2009557.html
# 처리 중... [61/7704] 20160122_[대금결제] ETRI R&BD  응용시스템 유지보수 - 2015년 12월분 대금 지급의 건_2009556.html
# 처리 중... [62/7704] 20160124_병가 신청_2009558.html
# 처리 중... [63/7704] 20160125_2015년 4_4분기 부가세 납부 품의_2009562.html
# 처리 중... [64/7704] 20160125_2016년 1월 급여지급 품의_2009560.html
# 처리 중... [65/7704] 20160125_[대금결제] ETRI R&BD 응용시스템 유지보수 - 2015년 12월분 대금 지급의 건_2009563.html
# 처리 중... [66/7704] 20160125_네이버 광고관리시스템 비즈머니 구매_2009561.html
# 처리 중... [67/7704] 20160125_퇴사합니다. _2009559.html
# 처리 중... [68/7704] 20160126_2016년 1월 체크카드 사용내역서_2009565.html
# 처리 중... [69/7704] 20160126_법인카드 정산 품의___2009566.html
# 처리 중... [70/7704] 20160126_학자금 지급 신청 _2009564.html
# 처리 중... [71/7704] 20160127_2016년 1월 법인카드 정산 보고_2009567.html
# 처리 중... [72/7704] 20160127_2016년01월 법인카드 정산내역 품의(송준선)_2009568.html
# 처리 중... [73/7704] 20160127_[외주인력투입수정계약품의] ETRI 기술가치평가 지원 시스템 개발 (김지혜)_2009569.html
# 처리 중... [74/7704] 20160127_[외주인력투입수정계약품의] LG화학[기술원]물리적보안 V2.0 업그레이드 (최민영)_2009570.html
# 처리 중... [75/7704] 20160127_대전숙소(세종아파트) 관리비_2015년 12월_2009574.html
# 처리 중... [76/7704] 20160127_명함 발급 요청_2009573.html
# 처리 중... [77/7704] 20160127_법인카드 사용내역 정산 보고_2016년1월_이형균 _2009575.html
# 처리 중... [78/7704] 20160127_신사업팀 박상권 이사 선친기일참석 휴가요청의 건 _2009571.html
# 처리 중... [79/7704] 20160127_주성엔지니어링 2016년 유지보수 계약 품의_2009572.html
# 처리 중... [80/7704] 20160128_법인카드 정산 품의_2009576.html
# 처리 중... [81/7704] 20160128_서적구매 품의합니다._2009577.html
# 처리 중... [82/7704] 20160129_OCI 프로젝트 팀 회식비 청구합니다._2009580.html
# 처리 중... [83/7704] 20160129_개인휴가 요청합니다._2009581.html
# 처리 중... [84/7704] 20160129_사직원_함지연_2009579.html
# 처리 중... [85/7704] 20160129_출장 품의(생산기술연구원)_2009578.html
# 처리 중... [86/7704] 20160131_김하응(20160131)_IITP_법인카드정산_2009582.html
# 처리 중... [87/7704] 20160201_1월 잔업식대_2009587.html
# 처리 중... [88/7704] 20160201_김하응 2월5일 휴가신청_2009586.html
# 처리 중... [89/7704] 20160201_서버 접근권한 신청_2009585.html
# 처리 중... [90/7704] 20160201_연차 휴가 신청_2009588.html
# 처리 중... [91/7704] 20160201_연차휴가 신청_2009583.html
# 처리 중... [92/7704] 20160201_출장비 정산 품의(단기출장 1일)_2009584.html
# 처리 중... [93/7704] 20160202_[한국생산기술연구원] 개발자 PC 납품 품의건_2009589.html
# 처리 중... [94/7704] 20160202_서적 품의 입니다._2009590.html
# 처리 중... [95/7704] 20160203_16.1월 법인카드 정산품의_2009591.html
# 처리 중... [96/7704] 20160203_휴가 품의_2009592.html
# 처리 중... [97/7704] 20160204_R&D 사업팀 이아영 사원입니다. 휴가 신청합니다._2009596.html
# 처리 중... [98/7704] 20160204_휴가 신청_2009598.html
# 처리 중... [99/7704] 20160204_휴가 품의_2009594.html
# 처리 중... [100/7704] 20160204_휴가 품의_2009595.html
# 처리 중... [101/7704] 20160204_휴가 품의_2009597.html
# 처리 중... [102/7704] 20160204_휴가일정 변경 품의(ANY-인사- 1980)_2009593.html
# 처리 중... [103/7704] 20160205_연차휴가 품의_2009599.html
# 처리 중... [104/7704] 20160208_김형환 복직 품의_2009600.html
# 처리 중... [105/7704] 20160211_고객지원 대표번호의 종속번호 변경 및 사내 내선 시스템 적용의 건_2009602.html
# 처리 중... [106/7704] 20160211_사내 내선 시스템 장애수리의 건_2009601.html
# 처리 중... [107/7704] 20160212_2016년2월 아웃소싱 인건비 지급 품의(2월15일 지급건)_2009603.html
# 처리 중... [108/7704] 20160212_[외주인력투입계약품의_대내] LG 화학 감광재DB, 시뮬레이션 자동화 구축 (송은석) _2009606.html
# 처리 중... [109/7704] 20160212_[외주인력투입계약품의_대내] LG화학 기술연구원 테크센터 공학 물성 DB개선 (최용석) _2009607.html
# 처리 중... [110/7704] 20160212_[외주인력투입수정계약품의] OCI특허시스템 구축 (문명진)_2009605.html
# 처리 중... [111/7704] 20160212_에트리 PMS개선 외 사기진작비 품의_2009604.html
# 처리 중... [112/7704] 20160212_한국생산기술연구원 착수보고 접대비 품의_2009608.html
# 처리 중... [113/7704] 20160215_2016년 01월 18일 ~ 2월 02일 야근식대_2009614.html
# 처리 중... [114/7704] 20160215_2016년 업무보고 사이트 적용으로 인한 야간근무 교통비_2009615.html
# 처리 중... [115/7704] 20160215_2016년2월 아웃소싱 인건비 지급 품의(2월15일 지급건) _2009610.html
# 처리 중... [116/7704] 20160215_[채용품의] 전진우_2009613.html
# 처리 중... [117/7704] 20160215_단기출장 품의(대전 ETRI, LG화학)_2009612.html
# 처리 중... [118/7704] 20160215_재직증명서 _ 근로소득원천징수영수증 요청_2009616.html
# 처리 중... [119/7704] 20160215_재직증명서 발급 요청 드립니다. _2009611.html
# 처리 중... [120/7704] 20160215_출장비 정산 품의(단기출장 1일)_2009609.html
# 처리 중... [121/7704] 20160216_신규입사자용 모니터 구매(김문철,권민선,문규원)의 건_2009617.html
# 처리 중... [122/7704] 20160216_연차휴가 신청합니다(병가후결제)_2009618.html
# 처리 중... [123/7704] 20160217_2016년 1월 야근근무 식대신청서_2009621.html
# 처리 중... [124/7704] 20160217_ICT-Bay2단계 고도화 - 검색기능고도화 관련 발주품의 _2009619.html
# 처리 중... [125/7704] 20160217_명함발급신청_2009620.html
# 처리 중... [126/7704] 20160218_중부지사 복합기 신규 구매의 건_2009622.html
# 처리 중... [127/7704] 20160219_[외주인력투입수정계약품의] ETRI_품질보증기반 과제수행을 위한 PMS개선 (전진우)_2009624.html
# 처리 중... [128/7704] 20160219_원자력연구원 외 1 곳 시내교통비 품의_2009623.html
# 처리 중... [129/7704] 20160219_재직증명서 및 근로소득 원천징수 영수증 발급 신청의 건_2009626.html
# 처리 중... [130/7704] 20160219_출장비 정산 품의(단기출장)_2009625.html
# 처리 중... [131/7704] 20160221_네이버 광고관리시스템 비즈머니 구매_2009627.html
# 처리 중... [132/7704] 20160222_단기출장 품의(대전 ETRI, LG화학)_2009629.html
# 처리 중... [133/7704] 20160222_배설희 비자연장 신청_2009628.html
# 처리 중... [134/7704] 20160222_연차휴가 결재품의_2009631.html
# 처리 중... [135/7704] 20160222_연차휴가 품의_2009630.html
# 처리 중... [136/7704] 20160223_16.02.02 시내교통비 품의_2009634.html
# 처리 중... [137/7704] 20160223_[2월 개인경비품의 ]_2009633.html
# 처리 중... [138/7704] 20160223_개인카드 사용(숙박비) 비용 청구_2009636.html
# 처리 중... [139/7704] 20160223_반차휴가_2009635.html
# 처리 중... [140/7704] 20160223_연차 휴가 품의_2009632.html
# 처리 중... [141/7704] 20160224_2016년2월 아웃소싱 인건비 지급 품의(2월25일 지급건)_2009638.html
# 처리 중... [142/7704] 20160224_전사 환경정비 비용지급 의뢰의 건_2009637.html
# 처리 중... [143/7704] 20160225_2016년 2월 급여지급 품의_2009643.html
# 처리 중... [144/7704] 20160225_[대금결제] ETRI R&BD 응용시스템 유지보수 - 2016년 1월분 대금 지급의 건_2009641.html
# 처리 중... [145/7704] 20160225_교통비 품의_2009640.html
# 처리 중... [146/7704] 20160225_신청시스템 개발자 이세용 선투입 품의 건_2009639.html
# 처리 중... [147/7704] 20160225_퇴직원 제출_2009642.html
# 처리 중... [148/7704] 20160226_2016년 2월 법인카드 정산 보고_2009649.html
# 처리 중... [149/7704] 20160226_2016년 2월 체크카드 사용내역서_2009644.html
# 처리 중... [150/7704] 20160226_법인카드 사용내역 정산 보고 - 현광섭(2016.01)_2009646.html
# 처리 중... [151/7704] 20160226_법인카드 사용내역 정산 보고 - 현광섭(2016.02)_2009647.html
# 처리 중... [152/7704] 20160226_서버 사용권한 승인 요청합니다. _2009648.html
# 처리 중... [153/7704] 20160226_장기 출장비 품의_2009650.html
# 처리 중... [154/7704] 20160226_출장 품의_2009651.html
# 처리 중... [155/7704] 20160226_출장비 정산 품의(단기출장)_2009645.html
# 처리 중... [156/7704] 20160229_16.02.29 교육 품의_2009657.html
# 처리 중... [157/7704] 20160229_2016년02월 법인카드 정산내역 품의(송준선)_2009660.html
# 처리 중... [158/7704] 20160229_LG CNS 파트너 교육 품의_2009659.html
# 처리 중... [159/7704] 20160229_LGCNS Secure Coding실무 교육품의_2009658.html
# 처리 중... [160/7704] 20160229_LGCNS 교육 품의입니다._2009656.html
# 처리 중... [161/7704] 20160229_감사원 유지보수(현대HDS)_2009652.html
# 처리 중... [162/7704] 20160229_병가 품의_2009654.html
# 처리 중... [163/7704] 20160229_연차휴가 상신의 건_2009653.html
# 처리 중... [164/7704] 20160229_휴가상신의 건_2009655.html
# 처리 중... [165/7704] 20160301_2월 잔업식대_2009661.html
# 처리 중... [166/7704] 20160302_[대금결제] 특허권 차량 게이트웨이,차량 네트워크 인터페이스 장치 및 방법 외 2건 연차료 납부의 건_2009663.html
# 처리 중... [167/7704] 20160302_[채용품의]경력사원 입사 품의-김재원_2009665.html
# 처리 중... [168/7704] 20160302_기업정관 번역비 품의_2009669.html
# 처리 중... [169/7704] 20160302_대전교통비 품의_2009668.html
# 처리 중... [170/7704] 20160302_문서보관용 철재케비넷 구매 안의 건_2009664.html
# 처리 중... [171/7704] 20160302_연차휴가 품의_2009662.html
# 처리 중... [172/7704] 20160302_영남대학교 기술사업화포털시스템 SSL 인증서 구매 품의_2009667.html
# 처리 중... [173/7704] 20160302_재직증명서 발급 신청의 건_2009670.html
# 처리 중... [174/7704] 20160302_통역사 고용비 품의_2009666.html
# 처리 중... [175/7704] 20160303_개인휴가 요청 드립니다._2009672.html
# 처리 중... [176/7704] 20160303_연차휴가 사용(2016.03.18)  _2009673.html
# 처리 중... [177/7704] 20160303_휴가신청서 - 양태웅 대리(2016.03.04)_2009671.html
# 처리 중... [178/7704] 20160304_2016년 2월 법인카드 정산_2009681.html
# 처리 중... [179/7704] 20160304_ETRI 출장 교통비 신청(2016년 2월)_2009675.html
# 처리 중... [180/7704] 20160304_[한국생산기술연구원]천안 숙소 인터넷 가입요청건_2009682.html
# 처리 중... [181/7704] 20160304_교통비 품의_2009678.html
# 처리 중... [182/7704] 20160304_대전숙소(세종아파트) 관리비_2016년 1월_2009685.html
# 처리 중... [183/7704] 20160304_문서보관용  철재캐비넷 구매비용 지급 의뢰의 건_2009684.html
# 처리 중... [184/7704] 20160304_법인카드 정산 품의_2009683.html
# 처리 중... [185/7704] 20160304_연차휴가 품의_2009676.html
# 처리 중... [186/7704] 20160304_재직증명서 발급 요청 품의_2009680.html
# 처리 중... [187/7704] 20160304_퇴직금 정산 품의(함지연)_2009677.html
# 처리 중... [188/7704] 20160304_휴가 품의_2009679.html
# 처리 중... [189/7704] 20160304_휴가요청_2009674.html
# 처리 중... [190/7704] 20160305_SK 이노베이션 시스템 교통비 품의(20160302)_2009686.html
# 처리 중... [191/7704] 20160307_[외주인력투입계약품의_대내] LG화학[기술원]P2MS 시스템 구축 (최민영)_2009694.html
# 처리 중... [192/7704] 20160307_[외주인력투입계약품의_대내] LG화학[기술원]P2MS 시스템 구축 (최지희(오문희))_2009695.html
# 처리 중... [193/7704] 20160307_[외주인력투입수정계약품의] ETRI_신)연구비관리시스템 관련 PMS시스템 연계 (김성우)_2009689.html
# 처리 중... [194/7704] 20160307_대전 lg화학 장기 결재 품의_2009696.html
# 처리 중... [195/7704] 20160307_배설희 반일 휴가(등록증 받기)_2009692.html
# 처리 중... [196/7704] 20160307_연차휴가 신청합니다(병가후결제)_2009693.html
# 처리 중... [197/7704] 20160307_연차휴가 품의_2009691.html
# 처리 중... [198/7704] 20160307_연차휴가품의_2009688.html
# 처리 중... [199/7704] 20160307_예비군 훈련 품의_2009687.html
# 처리 중... [200/7704] 20160307_휴가 품의_2009690.html
# 처리 중... [201/7704] 20160308_ICT-Bay2단계 웹취약점점검관련 발주품의_2009706.html
# 처리 중... [202/7704] 20160308_개인휴가사용_2009705.html
# 처리 중... [203/7704] 20160308_법인카드 정산 품의_2009698.html
# 처리 중... [204/7704] 20160308_연차휴가 상신의 건_2009701.html
# 처리 중... [205/7704] 20160308_연차휴가 품의_2009697.html
# 처리 중... [206/7704] 20160308_연차휴가 품의_2009700.html
# 처리 중... [207/7704] 20160308_영남대학교 기술사업화포털시스템 구축 출장비 품의_2009702.html
# 처리 중... [208/7704] 20160308_예비군 훈련 품의_2009703.html
# 처리 중... [209/7704] 20160308_재직증명서 발급_2009699.html
# 처리 중... [210/7704] 20160308_휴가신청_2009704.html
# 처리 중... [211/7704] 20160309_LS산전 지적재산관리시스템 유지보수 계약_2009707.html
# 처리 중... [212/7704] 20160310_2016년3월 아웃소싱 인건비 지급 품의(3월15일 지급건)_2009708.html
# 처리 중... [213/7704] 20160310_기술지원팀 인사발령 품의_2009709.html
# 처리 중... [214/7704] 20160310_에트리 PMS개선 검수완료 사기진작비 품의_2009710.html
# 처리 중... [215/7704] 20160310_한국항공우주연구원 출장 교통비 품의_2009711.html
# 처리 중... [216/7704] 20160311_LG화학기술원 동영상서버 복구비용 품의_2009713.html
# 처리 중... [217/7704] 20160311_퇴직원 제출의 건(김문철)_2009712.html
# 처리 중... [218/7704] 20160314_IP정보검색사 양성 교육 (방인영 차장)_2009721.html
# 처리 중... [219/7704] 20160314_[채용 및 입사품의_경력] 퀘스텔 IP솔루션 고객지원 및 교육_방인영_2009722.html
# 처리 중... [220/7704] 20160314_네이버 광고관리시스템 비즈머니 구매_2009714.html
# 처리 중... [221/7704] 20160314_대전 출장 교통비 신청(2016년 3월)_2009716.html
# 처리 중... [222/7704] 20160314_반차품의_2009719.html
# 처리 중... [223/7704] 20160314_사무실 입간판 구매비용 지급 의뢰의 건_2009718.html
# 처리 중... [224/7704] 20160314_시내교통비 품의_2009723.html
# 처리 중... [225/7704] 20160314_연차휴가사용 품의_2009715.html
# 처리 중... [226/7704] 20160314_오후 반차 휴가 품의서_2009717.html
# 처리 중... [227/7704] 20160314_휴가신청서_2009720.html
# 처리 중... [228/7704] 20160315_3월 21일자 인터넷 언론보도 (디지털타임스)_2009729.html
# 처리 중... [229/7704] 20160315_LG화학기술원 SM 사기진작비 품의_2009730.html
# 처리 중... [230/7704] 20160315_[대금결제] ETRI R&BD 응용시스템 유지보수 - 2016년 2월분 대금 지급의 건_2009725.html
# 처리 중... [231/7704] 20160315_교육 신청 품의_2009724.html
# 처리 중... [232/7704] 20160315_나노종합기술원 제안발표 출장 품의_2009727.html
# 처리 중... [233/7704] 20160315_출장비 정산 품의(대구 영남대학교)_2009726.html
# 처리 중... [234/7704] 20160315_파일서버 접근 요청 기안_2009728.html
# 처리 중... [235/7704] 20160316_[외주인력투입계약품의_대내] LG화학 기술연구원 특수p동 시스템 개선 개발 (김은옥) _2009732.html
# 처리 중... [236/7704] 20160316_[외주인력투입수정계약품의] LG화학 기술연구원 물리보안 v2.0 업그레이드 (최재훈)_2009733.html
# 처리 중... [237/7704] 20160316_연차휴가 상신의 건_2009734.html
# 처리 중... [238/7704] 20160316_예비군 휴가 신청합니다._2009731.html
# 처리 중... [239/7704] 20160317_[외주인력투입수정계약품의] LG화학 기술연구원 충방전시스템 기능개선 (유남근)_2009735.html
# 처리 중... [240/7704] 20160317_퇴직 품의_2009736.html
# 처리 중... [241/7704] 20160317_휴가 품의_2009737.html
# 처리 중... [242/7704] 20160318_[대금결제]한국정보산업협동조합 가입에 따른 출자금 및 가입비 납부 지급의 건 _2009739.html
# 처리 중... [243/7704] 20160318_나노종합기술원 제안발표 출장비 정산 품의_2009740.html
# 처리 중... [244/7704] 20160318_연차 휴가 신청_2009738.html
# 처리 중... [245/7704] 20160321_2016년 03월 25일 (금) 오휴 휴가 신청합니다_2009744.html
# 처리 중... [246/7704] 20160321_삼성SDI 출장 교통비 신청_2009743.html
# 처리 중... [247/7704] 20160321_에트리 PMS개선사업 외 장기출장 품의_2009745.html
# 처리 중... [248/7704] 20160321_클립아트코리아(이미지라이센스) 1년기업회원 연장_2009741.html
# 처리 중... [249/7704] 20160321_휴가 신청_2009742.html
# 처리 중... [250/7704] 20160322_ 2016년3월 아웃소싱 인건비 지급 품의(3월25일 지급건) _2009749.html
# 처리 중... [251/7704] 20160322_[출장 품의]대전 lg화학 장기 출장_2009748.html
# 처리 중... [252/7704] 20160322_개인카드 사용(숙박비) 비용 청구_2009751.html
# 처리 중... [253/7704] 20160322_동우화인켐 외 1곳  시내교통비 품의_2009746.html
# 처리 중... [254/7704] 20160322_연차휴가 품의_2009750.html
# 처리 중... [255/7704] 20160322_휴가 품의(송준선)_2009747.html
# 처리 중... [256/7704] 20160323_교통비 품의_2009753.html
# 처리 중... [257/7704] 20160323_인턴사원 정규직 전환에 따른 연봉계약의 건 (이아영)_2009752.html
# 처리 중... [258/7704] 20160324_2016년 02월 법인카드 정산 재품의_2009755.html
# 처리 중... [259/7704] 20160324_[대금결제]3월 21일자 인터넷 언론보도(디지털타임스) 수수료지급 품의_2009758.html
# 처리 중... [260/7704] 20160324_본사 주차비 신청_2009757.html
# 처리 중... [261/7704] 20160324_삼성SDI 출장 교통비 신청_2009754.html
# 처리 중... [262/7704] 20160324_시내교통비 품의_2009759.html
# 처리 중... [263/7704] 20160324_시내교통비 품의_2009760.html
# 처리 중... [264/7704] 20160324_한국생명공학연구원 출장 교통비 신청_2009756.html
# 처리 중... [265/7704] 20160325_병원진료로 개인휴가사용_2009762.html
# 처리 중... [266/7704] 20160325_연차휴가 결재품의_2009761.html
# 처리 중... [267/7704] 20160328_2016년 3월 체크카드 사용내역서_2974993.html
# 처리 중... [268/7704] 20160328_연차휴가 품의_2977532.html
# 처리 중... [269/7704] 20160328_휴가 품의_2976775.html
# 처리 중... [270/7704] 20160329_3월 21일 저녁 식대_2979121.html
# 처리 중... [271/7704] 20160329_3월 법인카드정산품의_2978801.html
# 처리 중... [272/7704] 20160329_ETRI 석식 식대 결재 요청 드립니다._2980943.html
# 처리 중... [273/7704] 20160329_[대금결제] LG화학기술원 동영상서버 복구 비용 대금지급 품의_2979334.html
# 처리 중... [274/7704] 20160329_[대금결제] 영남대학교 기술사업화포털시스템 검색엔진 구매 대금지급 품의_2980152.html
# 처리 중... [275/7704] 20160329_삼성SDI 특허시스템 통합 CP(영업)_2979591.html
# 처리 중... [276/7704] 20160329_휴가 신청_2980803.html
# 처리 중... [277/7704] 20160330_2016년 3월 급여지급 품의_2982590.html
# 처리 중... [278/7704] 20160330_2016년 3월 법인카드 정산 품의_2981860.html
# 처리 중... [279/7704] 20160330_2016년03월 법인카드 정산내역 품의(송준선)_2983943.html
# 처리 중... [280/7704] 20160330_3월 법인카드 정산_R&amp;D사업팀 장성봉_2982996.html
# 처리 중... [281/7704] 20160330_OCI 지식재산통합관리 시스템 구축 관련 접대비 예산 요청_2983236.html
# 처리 중... [282/7704] 20160330_교통비 신청 품의_2981791.html
# 처리 중... [283/7704] 20160330_법인카드 사용내역 정산 보고_2016년3월_이형균_2984929.html
# 처리 중... [284/7704] 20160330_법인카드 사용내역 정산 보고_3월_2983875.html
# 처리 중... [285/7704] 20160330_세종아파트 관리비[2016년2월]_2984868.html
# 처리 중... [286/7704] 20160330_시내교통비_2982272.html
# 처리 중... [287/7704] 20160330_파일서버 권한신청_2983195.html
# 처리 중... [288/7704] 20160331_2016년 3월 법인카드 정산 품의(임현준)_2985244.html
# 처리 중... [289/7704] 20160331_[결제품의] 일학습병행제 전담인력 활동수당 지급의 건(5월~11월분)-박정균,유태경_2985802.html
# 처리 중... [290/7704] 20160331_[생기연] 천안숙소 3월분 경비지급신청 件_2987011.html
# 처리 중... [291/7704] 20160331_[휴가] 연차 휴가_2986539.html
# 처리 중... [292/7704] 20160331_개인신상휴가_2986798.html
# 처리 중... [293/7704] 20160331_박천석 선임 에트리 철수 관련 식사_2987480.html
# 처리 중... [294/7704] 20160331_출산휴가 승인요청_2986246.html
# 처리 중... [295/7704] 20160331_퇴사 희망_2987291.html
# 처리 중... [296/7704] 20160401_'16.04.01 단기 출장 품의_2991319.html
# 처리 중... [297/7704] 20160401_건설기술연구원 출장품의_2989557.html
# 처리 중... [298/7704] 20160401_단기 출장 사전 품의_2989584.html
# 처리 중... [299/7704] 20160401_단기출장 품의(대전 ETRI)_2992684.html
# 처리 중... [300/7704] 20160401_법인카드 사용내역 정산 보고 - 현광섭(2016.03)_2989353.html
# 처리 중... [301/7704] 20160401_현대 EP 업무 협의 시내 출장비 품의_2992445.html
# 처리 중... [302/7704] 20160403_ICT-Bay 이미지 구매요청건_2993923.html
# 처리 중... [303/7704] 20160404_ETRI 출장비 신청_2996561.html
# 처리 중... [304/7704] 20160404_연차휴가 품의_2996615.html
# 처리 중... [305/7704] 20160404_예비군 훈련 품의_2995255.html
# 처리 중... [306/7704] 20160404_재직증명서 발급신청합니다._2996003.html
# 처리 중... [307/7704] 20160405_[외주인력투입계약품의_대내] LG화학 기술연구원 물리보안 v2.0업그레이드 (문무성)_2999433.html
# 처리 중... [308/7704] 20160405_대전지역 신사업 추진계획 및 경영간담회 참석 출장품의 件_2999445.html
# 처리 중... [309/7704] 20160405_야근 식대 결재품의_3002809.html
# 처리 중... [310/7704] 20160405_연차휴가 품의_3002560.html
# 처리 중... [311/7704] 20160405_연차휴가요청 드립니다_3002688.html
# 처리 중... [312/7704] 20160405_전자신문 E-Frontier 광고상품 계약품의_2999543.html
# 처리 중... [313/7704] 20160405_중앙자활센터 제안 설명회 참석 시내교통비 품의_2998829.html
# 처리 중... [314/7704] 20160406_[삼성물산(주)패션부문_지식재산통합관리시스템]접대비를 신청합니다._3006784.html
# 처리 중... [315/7704] 20160406_[외주인력투입수정계약품의] LG화학 기술연구원 신청시스템 개발 (이세용)_3006378.html
# 처리 중... [316/7704] 20160406_개인휴가_3003067.html
# 처리 중... [317/7704] 20160406_건설기술연구원 교통비 품의_3003159.html
# 처리 중... [318/7704] 20160406_천안 숙소 물품(세탁기) 구매 품의건_3004247.html
# 처리 중... [319/7704] 20160406_퇴직연금 및 연차수당 지급 품의(하현우)_3003558.html
# 처리 중... [320/7704] 20160406_휴가 재요청 드립니다._3005192.html
# 처리 중... [321/7704] 20160406_휴가 품의_3006669.html
# 처리 중... [322/7704] 20160407_(재기안)_ICT-Bay2단계 법인카드정산 (201603)_3008052.html
# 처리 중... [323/7704] 20160407_3월 개인경비품의_3009567.html
# 처리 중... [324/7704] 20160407_ICT-Bay2단계 완료보고회 접대비_3009627.html
# 처리 중... [325/7704] 20160407_ICT-Bay2단계 접대비품의 요청건_3009556.html
# 처리 중... [326/7704] 20160407_[ICT사업2팀] 2016년 3월 일반경비 신청_3008364.html
# 처리 중... [327/7704] 20160407_개인휴가 신청 합니다,_3009812.html
# 처리 중... [328/7704] 20160407_법인카드 정산 품의_3009758.html
# 처리 중... [329/7704] 20160407_삼성SDI 프로젝트용 노트북 렌탈 건_3009837.html
# 처리 중... [330/7704] 20160407_연차휴가 상신의 건_3008946.html
# 처리 중... [331/7704] 20160407_연차휴가 품의_3008932.html
# 처리 중... [332/7704] 20160407_연차휴가_3009726.html
# 처리 중... [333/7704] 20160407_출장비 정산 품의 올립니다._3010538.html
# 처리 중... [334/7704] 20160407_휴가승인 요청드립니다._3009784.html
# 처리 중... [335/7704] 20160408_휴가 품의_3046273.html
# 처리 중... [336/7704] 20160408_휴가 품의입니다._3046848.html
# 처리 중... [337/7704] 20160411_공무원연금공단 주거래은행시스템사업 계약의 건_3052503.html
# 처리 중... [338/7704] 20160411_단기출장 품의(대전 ETRI)_3052779.html
# 처리 중... [339/7704] 20160411_대전 LG화학 기술원 출장 품의(4_12)_3053020.html
# 처리 중... [340/7704] 20160411_동우화인켐 단기출장 품의_3052838.html
# 처리 중... [341/7704] 20160411_연차 품의 올립니다._3053574.html
# 처리 중... [342/7704] 20160411_출장비 정산 품의(단기출장)_3052701.html
# 처리 중... [343/7704] 20160411_출장품의(LG화학 업무지원)_3052516.html
# 처리 중... [344/7704] 20160411_휴가신청_3052063.html
# 처리 중... [345/7704] 20160412_3월 야근식대 청구_3056906.html
# 처리 중... [346/7704] 20160412_sales force 용으로 쓸수 있는 이매일 계정 부탁드립니다_3054467.html
# 처리 중... [347/7704] 20160412_[외주인력투입수정계약품의] LG화학 기술연구원 충방전시스템 기능개선 (유남근)_3055614.html
# 처리 중... [348/7704] 20160413_SK 이노베이션 시스템 단기 출장 품의_3058975.html
# 처리 중... [349/7704] 20160414_2016년4월 아웃소싱 인건비 지급 품의(4월15일 지급건)_3062525.html
# 처리 중... [350/7704] 20160414_대전 지사 이전식 참가 출장 품의_3062664.html
# 처리 중... [351/7704] 20160414_워크샵 출장품의_3062652.html
# 처리 중... [352/7704] 20160414_휴가 신청합니다._3061868.html
# 처리 중... [353/7704] 20160418_IR TFT 워크샵 조식품의_3070061.html
# 처리 중... [354/7704] 20160418_LG화학기술원 정보지원팀 소속 단합대회건_3070452.html
# 처리 중... [355/7704] 20160418_단기출장 품의(대전 ETRI)_3071400.html
# 처리 중... [356/7704] 20160418_연차휴가 상신의 건_3069415.html
# 처리 중... [357/7704] 20160418_출장비 정산 품의(단기출장)_3071392.html
# 처리 중... [358/7704] 20160418_휴가 품의 입니다._3071345.html
# 처리 중... [359/7704] 20160418_휴가 품의_3067479.html
# 처리 중... [360/7704] 20160419_[대금결제] 대전 사무실 이전에 따른 간판 제작_3073956.html
# 처리 중... [361/7704] 20160419_오전 반차 품의_3072514.html
# 처리 중... [362/7704] 20160419_통역사 고용비 품의 (한국번역연구소)_3072247.html
# 처리 중... [363/7704] 20160420_2016년 4월 아웃소싱 인건비 지급 품의 (4월25일 지급건)_3077891.html
# 처리 중... [364/7704] 20160420_3월 법인카드 사용내역 품의_3077902.html
# 처리 중... [365/7704] 20160420_3월 법인카드 사용내역 품의_3078063.html
# 처리 중... [366/7704] 20160420_SK 이노베이션 시스템 교통비 품의(20160420)_3079097.html
# 처리 중... [367/7704] 20160420_[대금결제] ANYFIVE-IHS 고객초청 컨퍼런스 사은품 제작의 건_3077410.html
# 처리 중... [368/7704] 20160420_[대금결제] ETRI R&amp;BD 응용시스템 유지보수 - 2016년 3월분 대금 지급의 건_3077578.html
# 처리 중... [369/7704] 20160420_[대금결제] 도서 구매의 건(왜 다시 소재부품인가_)_3078331.html
# 처리 중... [370/7704] 20160420_[출장 품의] 대전 LG화학 기술원 출장연장 품의_3076747.html
# 처리 중... [371/7704] 20160420_동우화인켐 시내교통비 품의_3076077.html
# 처리 중... [372/7704] 20160420_번역비용 품의 (트랜스옥션)_3077917.html
# 처리 중... [373/7704] 20160420_장기 출장 품의_3076919.html
# 처리 중... [374/7704] 20160420_퇴직연금 지급 품의(함종완)_3078161.html
# 처리 중... [375/7704] 20160421_3월 법인카드 정산 품의_3081824.html
# 처리 중... [376/7704] 20160421_삼성SDI 특허관리통합시스템구축 관련 사기진작비 품의_3081200.html
# 처리 중... [377/7704] 20160422_공무원연금공단 주거래은행시스템 사업 계약품의_3083363.html
# 처리 중... [378/7704] 20160422_대전 LG화학기술원 출장비 청구 품의_3085548.html
# 처리 중... [379/7704] 20160422_대전지사 이전식 참석 출장비 청구 품의_3085569.html
# 처리 중... [380/7704] 20160422_워크샵 출장비 청구 품의_3085559.html
# 처리 중... [381/7704] 20160424_연차휴가 품의_3087307.html
# 처리 중... [382/7704] 20160425_2016년 4월 급여지급 품의_3090096.html
# 처리 중... [383/7704] 20160425_2016년 4월 법인카드 정산 품의(임현준)_3091219.html
# 처리 중... [384/7704] 20160425_ETRI 출장비 정산 품의_3088931.html
# 처리 중... [385/7704] 20160425_IHS-ANYFIVE 컨퍼런스 준비 - 빔프로젝트 대여 (엘비젼)_3091453.html
# 처리 중... [386/7704] 20160425_IHS-ANYFIVE 컨퍼런스 준비 디자인출력물 (세제기업)_3091413.html
# 처리 중... [387/7704] 20160425_LG전자 TIPIS2.0 구축 프로젝트 계약품의_3087709.html
# 처리 중... [388/7704] 20160425_RedChip 투자 및 IR 행사 현수막 제작 (세제기업)_3091388.html
# 처리 중... [389/7704] 20160425_[생기연] 천안숙소 3월~4월 경비지급신청 件_3091258.html
# 처리 중... [390/7704] 20160425_네이버 키워드광고 관리 시스템 비즈머니 구매_3090831.html
# 처리 중... [391/7704] 20160425_삼성SDI 투입과련 유류비 청구의 건_3091499.html
# 처리 중... [392/7704] 20160425_연차 휴가_3091435.html
# 처리 중... [393/7704] 20160425_연차 휴가_3091444.html
# 처리 중... [394/7704] 20160425_연차휴가품의_3091373.html
# 처리 중... [395/7704] 20160425_주말근무식대 (4월23일 토요일)_3091464.html
# 처리 중... [396/7704] 20160425_주말근무식대 (4월24일 일요일)_3091468.html
# 처리 중... [397/7704] 20160425_중식 식대 품의 (4_25 RedChip IR_투자 계약 행사)_3091471.html
# 처리 중... [398/7704] 20160426_2016년 4월 체크카드 사용내역서_3091973.html
# 처리 중... [399/7704] 20160426_[채용 및 입사품의_경력] R&amp;D사업부 SW개발팀_ 윤창근_3094300.html
# 처리 중... [400/7704] 20160426_대전숙소(세종아파트) 2016년 3월 관리비_3093067.html
# 처리 중... [401/7704] 20160426_법인카드 정산 품의_3094529.html
# 처리 중... [402/7704] 20160426_연차휴가 사용 품의_3092980.html
# 처리 중... [403/7704] 20160426_연차휴가 신청_3092391.html
# 처리 중... [404/7704] 20160426_연차휴가 품의_3092030.html
# 처리 중... [405/7704] 20160426_예비군훈련휴가 품의_3095119.html
# 처리 중... [406/7704] 20160426_출장비 정산 품의(단기출장)_3091905.html
# 처리 중... [407/7704] 20160426_퇴직신청서 - 양태웅 대리_3095512.html
# 처리 중... [408/7704] 20160426_한국생산기술연구원 프로젝트 관련 특허사무소 화면 검토 및 의견 수집 출장품의의 건_3094127.html
# 처리 중... [409/7704] 20160427_2016년 05월 02일 (월) 오휴 휴가 신청합니다_3096410.html
# 처리 중... [410/7704] 20160427_2016년04월 법인카드 정산내역 품의(송준선)_3097823.html
# 처리 중... [411/7704] 20160427_4월 법인카드 정산 품의_3097861.html
# 처리 중... [412/7704] 20160427_4월법인카드 정산 품의(중부사업팀 장성봉)_3095947.html
# 처리 중... [413/7704] 20160427_[민방위 훈련 건] S_W개발2팀_3096033.html
# 처리 중... [414/7704] 20160427_사직서_3098331.html
# 처리 중... [415/7704] 20160427_연차휴가 품의_3097802.html
# 처리 중... [416/7704] 20160428_2016년 4월 28일자 디지털타임스 인터넷 기사 보도비용_3103185.html
# 처리 중... [417/7704] 20160428_2016년 4월 법인카드 사용내역 정산 보고_R&amp;D사업부_3102596.html
# 처리 중... [418/7704] 20160428_IHS 행사 관련 시내교통비 품의_3103002.html
# 처리 중... [419/7704] 20160428_IHS-ANYFIVE 컨퍼런스 자료집 재본비용 (킨코스)_3102450.html
# 처리 중... [420/7704] 20160428_[휴가품의] 5_6일_3099874.html
# 처리 중... [421/7704] 20160428_개인 휴가 요청 드립니다._3099827.html
# 처리 중... [422/7704] 20160428_법인카드 사용내역 정산 보고 - 현광섭(2016.04)_3102222.html
# 처리 중... [423/7704] 20160428_연차 휴가 사용 품의서_3100370.html
# 처리 중... [424/7704] 20160428_연차 휴가 사용 품의서_3100387.html
# 처리 중... [425/7704] 20160428_예비군 품의입니다._3100017.html
# 처리 중... [426/7704] 20160428_휴가신청서 - 양태웅 대리(2016.04.29)_3099772.html
# 처리 중... [427/7704] 20160428_휴가의 건_3100447.html
# 처리 중... [428/7704] 20160429_2016년 4월 법인카드 사용내역 품의_3104608.html
# 처리 중... [429/7704] 20160429_4월 법인카드 정산 품의_3107308.html
# 처리 중... [430/7704] 20160429_ICT-Bay2단계 법인카드정산 (201604)_3105428.html
# 처리 중... [431/7704] 20160429_[외주인력투입계약품의_대내] 삼성SDI 특허관리 통합시스템 개발 (이승배, 신승우)_3106176.html
# 처리 중... [432/7704] 20160429_대전지사 파일서버 품의 입니다._3103289.html
# 처리 중... [433/7704] 20160429_시내교통비_3105187.html
# 처리 중... [434/7704] 20160429_연차 휴가 품의_3105446.html
# 처리 중... [435/7704] 20160429_휴가 품의_3105288.html
# 처리 중... [436/7704] 20160502_김하응부장_5월6일_휴가요청건_3109002.html
# 처리 중... [437/7704] 20160502_민방위 품의_3113195.html
# 처리 중... [438/7704] 20160502_법인카드 사용내역 정산 보고_2016년4월_이형균_3108810.html
# 처리 중... [439/7704] 20160502_연차휴가 품의_3113189.html
# 처리 중... [440/7704] 20160503_4월 잔업식대청구_3118519.html
# 처리 중... [441/7704] 20160503_김형환 재직증명서 발급 품의_3113974.html
# 처리 중... [442/7704] 20160503_명함 발급 요청_3116146.html
# 처리 중... [443/7704] 20160503_야근 택시비 청구_3118522.html
# 처리 중... [444/7704] 20160503_연차휴가 신청_3115741.html
# 처리 중... [445/7704] 20160503_연차휴가 신청_3117537.html
# 처리 중... [446/7704] 20160503_연차휴가품의_3118457.html
# 처리 중... [447/7704] 20160504_'16.05.04 시내교통비 품의_3120849.html
# 처리 중... [448/7704] 20160504_2016년 05월 06일 연차휴가 신청입니다._3119071.html
# 처리 중... [449/7704] 20160504_[ICT사업2팀] 2016년 4월 일반경비 신청_3120144.html
# 처리 중... [450/7704] 20160504_[법인카드 정산품의_4월]_3120072.html
# 처리 중... [451/7704] 20160504_[휴가신청] 임현준(5_6)_3119687.html
# 처리 중... [452/7704] 20160504_개인경비 품의_4월_3120875.html
# 처리 중... [453/7704] 20160504_기술지원팀 회식비 품의_3121826.html
# 처리 중... [454/7704] 20160504_민방위훈련 품의_3120504.html
# 처리 중... [455/7704] 20160504_신우진 연차휴가 신청_3120593.html
# 처리 중... [456/7704] 20160504_연차휴가 품의_3119160.html
# 처리 중... [457/7704] 20160504_인턴사원 정규직 전환에 따른 연봉계약의 건 (김학선)_3120824.html
# 처리 중... [458/7704] 20160504_휴가신청_3118773.html
# 처리 중... [459/7704] 20160504_휴가신청서 - 양태웅 대리(2016.05.06)_3120564.html
# 처리 중... [460/7704] 20160509_'16.04월 ETRI 출장품의_3127894.html
# 처리 중... [461/7704] 20160509_IITP ICT-Bay 2단계 2차 PM성과수당 품의_3129774.html
# 처리 중... [462/7704] 20160509_[대금결제] 외부 디자인 인건비 지급의 건-김묘경_3129106.html
# 처리 중... [463/7704] 20160509_[한국생산기술연구원]특허법인 이상 특허 자문 구매 품의건_3129810.html
# 처리 중... [464/7704] 20160509_김상욱 예비군훈련_3126159.html
# 처리 중... [465/7704] 20160510_[대금결제] ICT-Bay2단계 웹취약점 점검-비트러스트_3131001.html
# 처리 중... [466/7704] 20160510_[대금결제] 번역 시스템 및 번역 서비스 제공방법 연차료 납부의 건_3131301.html
# 처리 중... [467/7704] 20160510_재직증명서 _ 근로소득원천징수 영수증 발급신청_3135181.html
# 처리 중... [468/7704] 20160511_02월 15일 ~ 05월 10일 야근 저녁식대_3137332.html
# 처리 중... [469/7704] 20160511_[대금결재 품의] ICT-Bay2단계(검색기능 고도화)-다이퀘스트_3136929.html
# 처리 중... [470/7704] 20160511_현대엔지비 기술지식서비스시스템 검색엔진 도입 및 품질개선 계약_3135861.html
# 처리 중... [471/7704] 20160512_'16.05.04 시내교통비 품의_3140656.html
# 처리 중... [472/7704] 20160512_2016년5월 아웃소싱 인건비 지급 품의(5월16일 지급건)_3141862.html
# 처리 중... [473/7704] 20160512_LG전자 TIPIS2.0 구축 프로젝트 C_P 승인 품의_3142299.html
# 처리 중... [474/7704] 20160512_과학기술정책연구원 고객 미팅 교통비 신청 품의_3141399.html
# 처리 중... [475/7704] 20160513_연차휴가 품의_3144678.html
# 처리 중... [476/7704] 20160513_연차휴가 품의_3146266.html
# 처리 중... [477/7704] 20160513_일본 출장 품의(퀘스텔 세일즈 미팅)_3143632.html
# 처리 중... [478/7704] 20160513_휴가 품의_3143231.html
# 처리 중... [479/7704] 20160515_SK 이노베이션 시스템 단기 출장 품의_3146877.html
# 처리 중... [480/7704] 20160515_예비군훈련 품의_3146876.html
# 처리 중... [481/7704] 20160516_동우화인켐 단기출장 품의_3150897.html
# 처리 중... [482/7704] 20160516_민방위훈련(5_20) 품의_3150908.html
# 처리 중... [483/7704] 20160517_LG전자 TIPIS2.0 구축 프로젝트 현업 W_S 후 고객 접대_3151999.html
# 처리 중... [484/7704] 20160517_연차휴가 결재상신 드립니다._3153234.html
# 처리 중... [485/7704] 20160517_예비군 품의입니다._3155568.html
# 처리 중... [486/7704] 20160517_예비군훈련 품의_3152430.html
# 처리 중... [487/7704] 20160517_현대엔지비 기술지식 서비스시스템 검색엔진 구매 품의_3154683.html
# 처리 중... [488/7704] 20160518_[대금결제] ETRI R&amp;BD 응용시스템 유지보수 - 2016년 4월분 대금 지급의 건_3155875.html
# 처리 중... [489/7704] 20160520_2016년 5월 아웃소싱 인건비 지급 품의 (5월25일 지급건)_3165501.html
# 처리 중... [490/7704] 20160520_한국항공우주연구원 기술통합관리시스템 구축 출장품의_3164971.html
# 처리 중... [491/7704] 20160521_ios&nbsp;개발 및 참고 교재 신청_3166524.html
# 처리 중... [492/7704] 20160523_IBM 계약서 번역비용 (한국번역연구소)_3171242.html
# 처리 중... [493/7704] 20160523_연차 휴가 (수정품의)_3171053.html
# 처리 중... [494/7704] 20160523_연차 휴가 품의 신청(건강검진)_3170983.html
# 처리 중... [495/7704] 20160523_접대비_3168061.html
# 처리 중... [496/7704] 20160523_휴가 신청 품의(송준선)_3170483.html
# 처리 중... [497/7704] 20160524_R&amp;D사업부 Melt-in W_S 결재 요청 건_3173866.html
# 처리 중... [498/7704] 20160524_R&amp;D사업부 Melt-in W_S 출장 품의_3172438.html
# 처리 중... [499/7704] 20160524_[대금결제] 상표권 &quot;ANYFVIE&quot; 존속기간 만료에 따른 갱신등록 신청의 건_3171523.html
# 처리 중... [500/7704] 20160524_국민권익위원회 5월 사기진작비 품의신청_3172052.html
# 처리 중... [501/7704] 20160524_대전숙소(세종아파트) 2016년 4월 관리비_3173392.html
# 처리 중... [502/7704] 20160524_동우화인켐 시내교통비 품의_3172683.html
# 처리 중... [503/7704] 20160524_예비군 품의입니다._3174806.html
# 처리 중... [504/7704] 20160525_2016년 5월 급여지급 품의_3176381.html
# 처리 중... [505/7704] 20160525_단기 출장 사전 품의_3176127.html
# 처리 중... [506/7704] 20160525_아모레퍼시픽 지재권관리시스템 재구축 계약품의_3175541.html
# 처리 중... [507/7704] 20160525_장기 출장비 품의신청합니다._3177822.html
# 처리 중... [508/7704] 20160526_5_30 오전 반차 신청_3182292.html
# 처리 중... [509/7704] 20160526_5월 법인카드 정산 품의_3181073.html
# 처리 중... [510/7704] 20160526_[중부사업팀 장성봉이사]5월 법인카드 비용정산 품의 드립니다._3182479.html
# 처리 중... [511/7704] 20160526_[채용 및 입사품의_신입(U-CAMP수료)] S_W개발1팀_ 임민규_3181844.html
# 처리 중... [512/7704] 20160526_[채용 및 입사품의_신입(U-CAMP수료)] S_W개발1팀_ 임태호_3181867.html
# 처리 중... [513/7704] 20160526_경기도청 통합유지보수 계약 품의_3181102.html
# 처리 중... [514/7704] 20160526_김상욱 예비군훈련_3181061.html
# 처리 중... [515/7704] 20160526_법인카드 정산 품의 (16년5월, 박근록B)_3181517.html
# 처리 중... [516/7704] 20160526_연차휴가품의_3181104.html
# 처리 중... [517/7704] 20160527_5월 법인카드 정산내역 결재 요청_이승근_3182853.html
# 처리 중... [518/7704] 20160527_김하응_시내교통비(야근귀가_0526)_3185978.html
# 처리 중... [519/7704] 20160527_단기출장 사전 품의_3184098.html
# 처리 중... [520/7704] 20160527_출장비 정산 품의 올립니다._3183490.html
# 처리 중... [521/7704] 20160527_한국항공우주연구원 출장비 정산 품의_3185859.html
# 처리 중... [522/7704] 20160527_휴가 신청_3183050.html
# 처리 중... [523/7704] 20160527_휴가_3184166.html
# 처리 중... [524/7704] 20160528_법인카드 사용내역 정산 보고_2016년5월_이형균_3186978.html
# 처리 중... [525/7704] 20160529_2016년 5월 법인카드 정산 품의(임현준)_3187289.html
# 처리 중... [526/7704] 20160529_[생기연] 천안숙소 4월~5월 경비지급신청 件_3187294.html
# 처리 중... [527/7704] 20160529_개인 반차(오전)_3187207.html
# 처리 중... [528/7704] 20160530_2016_05_24 대전 출장 품의_3188736.html
# 처리 중... [529/7704] 20160530_2016_05_25 대전 출장 품의_3188766.html
# 처리 중... [530/7704] 20160530_2016_05_27 대전 출장 품의_3188791.html
# 처리 중... [531/7704] 20160530_5월 법인카드 품의_3191859.html
# 처리 중... [532/7704] 20160530_[법인카드정산품의]_3190258.html
# 처리 중... [533/7704] 20160530_근로소득원천징수영수증 요청_3189625.html
# 처리 중... [534/7704] 20160530_단기 출장 사전 품의_3191022.html
# 처리 중... [535/7704] 20160530_대전 출장 교통비 품의 신청(5_24,25)_3188190.html
# 처리 중... [536/7704] 20160530_데이터 통계분석을 위한 기본서 구매 요청_3187640.html
# 처리 중... [537/7704] 20160530_법인카드 정산 품의_3190547.html
# 처리 중... [538/7704] 20160530_퇴직연금 지급 품의(한정윤)_3188564.html
# 처리 중... [539/7704] 20160531_대전 출장 교통비 신청 품의(5_27)_3192377.html
# 처리 중... [540/7704] 20160601_SK 이노베이션 시스템 교통비 품의(20160518)_3196683.html
# 처리 중... [541/7704] 20160601_[ICT사업2팀] 2016년 5월 일반경비 신청_3200468.html
# 처리 중... [542/7704] 20160601_[출장 품의] 대전 LG화학 기술원 출장연장 품의_3200433.html
# 처리 중... [543/7704] 20160601_김하응부장_6월3일_휴가요청건_3198494.html
# 처리 중... [544/7704] 20160601_신우진 연차휴가 신청_3200100.html
# 처리 중... [545/7704] 20160602_2016년 5월 법인카드 사용내역 품의_3204147.html
# 처리 중... [546/7704] 20160602_2016년05월 법인카드 정산내역 품의(송준선)_3202897.html
# 처리 중... [547/7704] 20160602_세미나(워크숍) 참가 품의_3204112.html
# 처리 중... [548/7704] 20160603_[채용 및 입사품의_경력] S_W개발2팀_ 구재웅_3209320.html
# 처리 중... [549/7704] 20160603_연차 휴가_3207851.html
# 처리 중... [550/7704] 20160608_LGC 기술연구원 P2MS 개발 프로젝트 - Realgrid S_W 구매 납품 건_3217598.html
# 처리 중... [551/7704] 20160608_네이버 키워드광고 관리 시스템 비즈머니 구매_3218005.html
# 처리 중... [552/7704] 20160608_서버용 하드디스크 구매 품의_3217351.html
# 처리 중... [553/7704] 20160608_연차 휴가 요청 드립니다_3220760.html
# 처리 중... [554/7704] 20160608_휴가신청_3216836.html
# 처리 중... [555/7704] 20160609_5월 잔업식대청구_3225269.html
# 처리 중... [556/7704] 20160609_[LG전자 TIPIS2.0] 사기진작 회식 품의_3225095.html
# 처리 중... [557/7704] 20160609_삼성 SDI 출장 품의_3225256.html
# 처리 중... [558/7704] 20160609_출장비 정산 품의 올립니다_3222958.html
# 처리 중... [559/7704] 20160610_6월 21일 통역사 고용비 품의 (한국번역연구소)_3229043.html
# 처리 중... [560/7704] 20160610_시내교통비_3226089.html
# 처리 중... [561/7704] 20160610_신우진 출장 품의_3226789.html
# 처리 중... [562/7704] 20160610_연차휴가 품의_3227190.html
# 처리 중... [563/7704] 20160613_'16.06.13 단기출장 품의_3230505.html
# 처리 중... [564/7704] 20160613_'16.06.13 예비군 훈련 품의_3230578.html
# 처리 중... [565/7704] 20160613_LG화학 운영파트 회식 품의_3231162.html
# 처리 중... [566/7704] 20160613_SK 이노베이션 시스템 단기 출장 품의_3234788.html
# 처리 중... [567/7704] 20160613_[채용 및 입사품의_경력] S_W개발2팀_ 정형구_3234395.html
# 처리 중... [568/7704] 20160613_동우화인켐 단기출장 품의_3230515.html
# 처리 중... [569/7704] 20160613_반차 휴가 신청_3230347.html
# 처리 중... [570/7704] 20160613_시내교통비 품의(2016_06_10)_3231361.html
# 처리 중... [571/7704] 20160613_한국생산기술연 기술평가시스템 개발인력 지원_3234164.html
# 처리 중... [572/7704] 20160613_휴가 상신의 건_3232024.html
# 처리 중... [573/7704] 20160614_2016-06-16~2016-06-17 휴가 품의_3237649.html
# 처리 중... [574/7704] 20160614_2016년6월 아웃소싱 인건비 지급 품의(6월15일 지급건)_3238277.html
# 처리 중... [575/7704] 20160614_민방위 훈련 참석_3238246.html
# 처리 중... [576/7704] 20160614_연차휴가 결재품의_3235296.html
# 처리 중... [577/7704] 20160614_연차휴가 신청_3235298.html
# 처리 중... [578/7704] 20160615_PIUC 컨퍼런스 스폰서 참가비용 (한국지식재산서비스협회)_3241070.html
# 처리 중... [579/7704] 20160615_SK 이노베이션 시스템 교통비 품의(20160615)_3242908.html
# 처리 중... [580/7704] 20160615_연차휴가 상신의 건_3239999.html
# 처리 중... [581/7704] 20160616_'16.06.16 예비군 훈련 품의_3245106.html
# 처리 중... [582/7704] 20160616_김하응_시외교통비(산림청 출장_0615)_3244536.html
# 처리 중... [583/7704] 20160616_연차휴가 신청_3243169.html
# 처리 중... [584/7704] 20160617_2016년 06월 08일 교통비 품의_3248339.html
# 처리 중... [585/7704] 20160617_[대금결제] ETRI R&amp;BD 응용시스템 유지보수 - 2016년 5월분 대금 지급의 건_3247246.html
# 처리 중... [586/7704] 20160617_개인 휴가를 신청합니다._3247148.html
# 처리 중... [587/7704] 20160617_고용센터제출서류_3248379.html
# 처리 중... [588/7704] 20160617_동우화인켐 시내교통비 품의_3248394.html
# 처리 중... [589/7704] 20160617_원자력연구원 단기출장 품의_3248429.html
# 처리 중... [590/7704] 20160619_한국생산기술연구원 사용자교육 출장품의 건_3250866.html
# 처리 중... [591/7704] 20160620_'16.06.20 시내교통비 품의_3252498.html
# 처리 중... [592/7704] 20160620_'16.06.20 하계휴가 품의_3252531.html
# 처리 중... [593/7704] 20160620_2016년 6월 아웃소싱 인건비 지급 품의 (6월27일 지급건)_3254347.html
# 처리 중... [594/7704] 20160620_U-CAMP 23기 교육수당 지급의 건 _임민규, 임태호_3252822.html
# 처리 중... [595/7704] 20160620_[외주인력투입계약품의] 2016년 LG전자 TIPIS 2.0구축(유지선, 김란)_3253892.html
# 처리 중... [596/7704] 20160620_[외주인력투입수정계약품의] 삼성SDI 특허관리 통합시스템 개발 (신승우)_3253156.html
# 처리 중... [597/7704] 20160620_김하응부장_대전_산림청 출장품의(20160615)_3253025.html
# 처리 중... [598/7704] 20160620_병가 휴가 신청_3255281.html
# 처리 중... [599/7704] 20160620_연차휴가 사용 품의_3251035.html
# 처리 중... [600/7704] 20160620_연차휴가사용 품의(6_21)_3253028.html
# 처리 중... [601/7704] 20160620_오후 반차_3251742.html
# 처리 중... [602/7704] 20160621_삼성 SDI 출장 연장 품의_3259453.html
# 처리 중... [603/7704] 20160621_연차휴가품의_3256196.html
# 처리 중... [604/7704] 20160621_휴가 신청_3258054.html
# 처리 중... [605/7704] 20160622_[LGC 기술연구원] 비문관리 체계개선 프로젝트 계약 품의_3260129.html
# 처리 중... [606/7704] 20160622_삼성SDI 지식재산권 통합시스템 개선 프로젝트 회식_3260425.html
# 처리 중... [607/7704] 20160622_연차휴가 품의_3261908.html
# 처리 중... [608/7704] 20160623_대전_세종아파트_관리비_2016년5월_3266569.html
# 처리 중... [609/7704] 20160623_대전숙소 정리 및 이사비용_3266657.html
# 처리 중... [610/7704] 20160623_신우진 연차휴가 신청_3266233.html
# 처리 중... [611/7704] 20160623_출장 숙박비 품의_3266610.html
# 처리 중... [612/7704] 20160624_2016년 6월 급여지급 품의_3268875.html
# 처리 중... [613/7704] 20160624_2016년 6월 야근식대 결재요청_3268761.html
# 처리 중... [614/7704] 20160624_2016년 GS칼텍스 통합유지보수 - 지식재산권관리 시스템 계약_3269416.html
# 처리 중... [615/7704] 20160624_2016년06월 법인카드 정산내역 품의(송준선)_3271155.html
# 처리 중... [616/7704] 20160624_5월 국민권익위원회 사기진작비 영수증청구_3269765.html
# 처리 중... [617/7704] 20160624_6월 법인카드 정산내역 결재 요청_이승근_3267673.html
# 처리 중... [618/7704] 20160624_6월 야근식대 명세서_3269733.html
# 처리 중... [619/7704] 20160624_7월 사기진작비 품의서_3269840.html
# 처리 중... [620/7704] 20160624_연차 휴가(2016.07.01)_3268840.html
# 처리 중... [621/7704] 20160627_[R&amp;D ES사업부_정현철] 2016년 6월 카드사용내역 보고_3276440.html
# 처리 중... [622/7704] 20160627_개인 휴가 사용_3275222.html
# 처리 중... [623/7704] 20160627_공가 및 연차 휴가 상신_3274323.html
# 처리 중... [624/7704] 20160627_삼양 지식재산권관리시스템 유지보수 계약_3274641.html
# 처리 중... [625/7704] 20160627_연차 상신-금종화 대리_3272252.html
# 처리 중... [626/7704] 20160627_오후 반차 휴가 품의입니다 [ 이세원 사원 ]_3273077.html
# 처리 중... [627/7704] 20160627_원자력연구원 시내교통비 품의_3273511.html
# 처리 중... [628/7704] 20160628_2016년 07월 08일 (금) 전일 휴가 신청합니다_3277526.html
# 처리 중... [629/7704] 20160628_2016년 6월 27일 병가_3277191.html
# 처리 중... [630/7704] 20160628_6월 법인카드 정산품의_3277934.html
# 처리 중... [631/7704] 20160628_[채용 및 입사품의_경력] 경영기획팀_ 윤다솔_3280124.html
# 처리 중... [632/7704] 20160628_기초과학연구원 지식재산권 통합관리시스템 유지보수 계약_3280046.html
# 처리 중... [633/7704] 20160628_서울 본사 출장비 품의_3277783.html
# 처리 중... [634/7704] 20160629_동원 예비군 훈련 품의_3282599.html
# 처리 중... [635/7704] 20160629_명함을 신청합니다._3282445.html
# 처리 중... [636/7704] 20160630_2016 특허정보사용자컨퍼런스(PIUC) 총 소요금액 정산 품의_3285995.html
# 처리 중... [637/7704] 20160630_6월 법인카드 정산 품의_3288192.html
# 처리 중... [638/7704] 20160630_[외주인력투입계약품의] LG화학 기술원 2016년 상반기 실험실 자동화과제(송은석)_3288569.html
# 처리 중... [639/7704] 20160630_고려대학교 지식재산관리시스템 플랫폼 개선 계약_3287980.html
# 처리 중... [640/7704] 20160630_법인카드 사용내역 정산 보고_2016년6월_이형균_3289821.html
# 처리 중... [641/7704] 20160630_연차휴가 신청합니다_3285213.html
# 처리 중... [642/7704] 20160630_연차휴가 품의_3285660.html
# 처리 중... [643/7704] 20160630_연차휴가신청_3287208.html
# 처리 중... [644/7704] 20160630_제안서 제출 출장 품의_3288885.html
# 처리 중... [645/7704] 20160630_한국기초과학지원연구원 관련 제안 협의 출장 품의(6_8)_3287602.html
# 처리 중... [646/7704] 20160630_현대자동차 제안발표 교통비 품의 요청_3287936.html
# 처리 중... [647/7704] 20160701_2016년 6월 법인카드 정산품의_3292072.html
# 처리 중... [648/7704] 20160701_법인카드 정산 품의 (16년6월, 박근록B)_3292325.html
# 처리 중... [649/7704] 20160704_'16.07.04 휴가 품의_3296930.html
# 처리 중... [650/7704] 20160704_2016년 07월 04일 (월) 오후 휴가 신청합니다_3297426.html
# 처리 중... [651/7704] 20160704_김상욱 예비군 훈련_3298043.html
# 처리 중... [652/7704] 20160704_동우화인켐 단기출장 품의_3300490.html
# 처리 중... [653/7704] 20160704_연차 휴가_3300425.html
# 처리 중... [654/7704] 20160704_팬택 특허시스템 운영 및 유지보수 계약_3295929.html
# 처리 중... [655/7704] 20160705_2016-07-05 휴가 품의_3302693.html
# 처리 중... [656/7704] 20160705_[R&amp;D ES사업부] 2016년 6월 일반경비 신청_3303215.html
# 처리 중... [657/7704] 20160705_화학Part 2016년 7월 회식 품의_3302433.html
# 처리 중... [658/7704] 20160706_2016년 5월 법인카드 정산 품의(임현준)_3307760.html
# 처리 중... [659/7704] 20160706_사람인 인재열람상품 100건(150일사용)신청_3306837.html
# 처리 중... [660/7704] 20160707_6월 시내교통비_3311253.html
# 처리 중... [661/7704] 20160708_6월 법인카드 정산품의_3315360.html
# 처리 중... [662/7704] 20160708_과학기술정책연구원 출장 품의_3315585.html
# 처리 중... [663/7704] 20160708_동우화인켐 단기출장 품의_3316793.html
# 처리 중... [664/7704] 20160708_동우화인켐 시내교통비 품의_3316750.html
# 처리 중... [665/7704] 20160708_반차휴가_3317241.html
# 처리 중... [666/7704] 20160708_오전 반차 휴가 품의입니다 [ 이세원 사원 ]_3315870.html
# 처리 중... [667/7704] 20160708_접대비 품의(LGCNS 화학기술원팀)_3315547.html
# 처리 중... [668/7704] 20160708_출장비 정산 품의(20160704)_3315791.html
# 처리 중... [669/7704] 20160708_퇴직연금 지급 품의 (박상택부사장)_3316485.html
# 처리 중... [670/7704] 20160711_네이버 키워드광고 관리 시스템 비즈머니 구매_4204726.html
# 처리 중... [671/7704] 20160711_명함발급 신청_4206034.html
# 처리 중... [672/7704] 20160711_배설희 여름 휴가 품의_4204716.html
# 처리 중... [673/7704] 20160711_법인카드 정산품의_4204859.html
# 처리 중... [674/7704] 20160711_출장비 정산 품의(20160707)_4205516.html
# 처리 중... [675/7704] 20160712_[대금지급] LG화학 Orbit.com 온라인 검색 서비스 계약에 대한 대금 지급의 건_4633875.html
# 처리 중... [676/7704] 20160712_반차 휴가(2016.07.16)_4633648.html
# 처리 중... [677/7704] 20160712_병원진료 개인휴가사용_4632805.html
# 처리 중... [678/7704] 20160712_휴가 상신의 건_4632936.html
# 처리 중... [679/7704] 20160713_2016년7월 아웃소싱 인건비 지급 품의(7월15일 지급건)_5082048.html
# 처리 중... [680/7704] 20160713_반차품의_5080359.html
# 처리 중... [681/7704] 20160714_건설기술연구원 고도화 관련 미팅_5085471.html
# 처리 중... [682/7704] 20160714_동우화인켐 시내교통비 품의_5085502.html
# 처리 중... [683/7704] 20160714_휴가 요청_5084624.html
# 처리 중... [684/7704] 20160715_IPIS 2.0 구축 프로젝트 중간보고 후, 회식_5124421.html
# 처리 중... [685/7704] 20160715_성주그룹 IP법무통합관리시스템 유지보수 계약_5121561.html
# 처리 중... [686/7704] 20160717_6월 잔업식대청구_5523933.html
# 처리 중... [687/7704] 20160718_연차휴가 요청_5528120.html
# 처리 중... [688/7704] 20160718_하계 휴가 신청_5525794.html
# 처리 중... [689/7704] 20160719_2016년 07월 20일(수) 오휴 휴가 신청합니다_5589657.html
# 처리 중... [690/7704] 20160719_[대금결제] ETRI R&amp;BD 응용시스템 유지보수 - 2016년 6월분 대금 지급의 건_5586630.html
# 처리 중... [691/7704] 20160719_건설기술연구원 시내교통비 품의_5586779.html
# 처리 중... [692/7704] 20160719_과학기술정책연구원 출장 품의(20160719)_5588325.html
# 처리 중... [693/7704] 20160719_연차휴가 상신의 건_5591575.html
# 처리 중... [694/7704] 20160719_원자력연구원 단기출장 품의_5586406.html
# 처리 중... [695/7704] 20160719_장기출장 품의 결재올립니다._5592353.html
# 처리 중... [696/7704] 20160719_증명서 발급 신청_5589557.html
# 처리 중... [697/7704] 20160719_휴가 신청(오후 반차)_5589375.html
# 처리 중... [698/7704] 20160720_[외주인력투입계약품의] ETRI 2015년 R&amp;BD플랫폼(2차) 응용시스템 유지관리 (안재우)_5600335.html
# 처리 중... [699/7704] 20160720_[외주인력투입계약품의] LG화학 기술원 모바일 서비스 통합(최현준)_5599347.html
# 처리 중... [700/7704] 20160720_[외주인력투입계약품의] LG화확 기술원 비문관리체계 개선(이돈경)_5600251.html
# 처리 중... [701/7704] 20160720_여름휴가 품의 입니다._5595045.html
# 처리 중... [702/7704] 20160720_여름휴가 품의 입니다._5595094.html
# 처리 중... [703/7704] 20160720_연차휴가 품의_5594667.html
# 처리 중... [704/7704] 20160720_퇴사_5599804.html
# 처리 중... [705/7704] 20160720_하계 휴가 - 이세원사원_5598969.html
# 처리 중... [706/7704] 20160720_휴가 신청_5598758.html
# 처리 중... [707/7704] 20160721_2016년 7월 아웃소싱 인건비 지급 품의 (7월25일 지급건)_5603435.html
# 처리 중... [708/7704] 20160721_2016년 김상욱 하계휴가 품의_5604000.html
# 처리 중... [709/7704] 20160721_연차휴가 상신의 건_5603482.html
# 처리 중... [710/7704] 20160721_하계 휴가 품의_5603728.html
# 처리 중... [711/7704] 20160722_여름휴가 품의 올립니다._5612144.html
# 처리 중... [712/7704] 20160722_휴가 품의_5612328.html
# 처리 중... [713/7704] 20160724_2016년 하계휴가품의_5616356.html
# 처리 중... [714/7704] 20160724_연차휴가 신청(하계휴가)_5616243.html
# 처리 중... [715/7704] 20160725_2016년 7월 급여지급 품의_5618902.html
# 처리 중... [716/7704] 20160725_2016년 김상욱 하계휴가 품의_5623118.html
# 처리 중... [717/7704] 20160725_[여름휴가 품의]_5619128.html
# 처리 중... [718/7704] 20160725_반차휴가 품의_5624753.html
# 처리 중... [719/7704] 20160725_오후 반차_5623562.html
# 처리 중... [720/7704] 20160725_원자력연구원 시내교통비 품의_5620417.html
# 처리 중... [721/7704] 20160725_하계휴가 품의 올립니다._5622999.html
# 처리 중... [722/7704] 20160725_하계휴가품의_5617059.html
# 처리 중... [723/7704] 20160725_하계휴가품의_5622916.html
# 처리 중... [724/7704] 20160726_2016년 08월 1일~5일 휴가 신청합니다_5629861.html
# 처리 중... [725/7704] 20160726_2016년 7월 법인카드 정산보고_5630938.html
# 처리 중... [726/7704] 20160726_2016년 하계휴가 품의_5629728.html
# 처리 중... [727/7704] 20160726_7월 사기진작비 청구_5629439.html
# 처리 중... [728/7704] 20160726_SK케미칼 라이센스 및 기능개선 사업의 건_5625152.html
# 처리 중... [729/7704] 20160726_국민권익위원회 7월 저녁식대 청구_5629338.html
# 처리 중... [730/7704] 20160726_김형환 하계휴가 품의_5632416.html
# 처리 중... [731/7704] 20160726_대전지역 파견직원 고객관리 역량 증대 세미나_5629882.html
# 처리 중... [732/7704] 20160726_삼성SDI 출장 품의_5632028.html
# 처리 중... [733/7704] 20160726_서버용 하드디스크 구매 품의_5625568.html
# 처리 중... [734/7704] 20160726_여름 휴가 신청합니다._5624906.html
# 처리 중... [735/7704] 20160726_여름휴가 결재 요청 드립니다._5629310.html
# 처리 중... [736/7704] 20160726_여름휴가 신청 (8.02 ~ 8.05)_5630969.html
# 처리 중... [737/7704] 20160726_여름휴가_5625954.html
# 처리 중... [738/7704] 20160727_SK 이노베이션 시스템 단기 출장 품의_5638334.html
# 처리 중... [739/7704] 20160727_[7월 법인카드 정산품의]_5637771.html
# 처리 중... [740/7704] 20160727_여름휴가 품의 요청_5632841.html
# 처리 중... [741/7704] 20160727_연차품의_5635251.html
# 처리 중... [742/7704] 20160727_하계휴가 품의_5633269.html
# 처리 중... [743/7704] 20160727_하계휴가_5637928.html
# 처리 중... [744/7704] 20160728_2016년 7월 법인카드 정산 품의(임현준)_5641483.html
# 처리 중... [745/7704] 20160728_[생기연] 천안숙소 6월~7월 경비지급신청 件_5641667.html
# 처리 중... [746/7704] 20160728_대전숙소(세종아파트) 관리비_2016년 6월분_5646633.html
# 처리 중... [747/7704] 20160728_숙소비 품의_5640593.html
# 처리 중... [748/7704] 20160728_예비군 훈련 품의 올립니다._5640959.html
# 처리 중... [749/7704] 20160728_출장비 정산 품의(단기출장)_5641421.html
# 처리 중... [750/7704] 20160728_하계휴가 품의_5643178.html
# 처리 중... [751/7704] 20160728_하계휴가 품의_5643301.html
# 처리 중... [752/7704] 20160729_2016년 6월 법인카드 정산품의7_5647644.html
# 처리 중... [753/7704] 20160729_2016년07월 법인카드 정산내역 품의(송준선)_5649101.html
# 처리 중... [754/7704] 20160729_법인카드정산품의_5652938.html
# 처리 중... [755/7704] 20160729_에트리 R&amp;BD2차유지관리 및 PMS시스템유지관리 사기진작비 품의_5648385.html
# 처리 중... [756/7704] 20160729_연차 휴가 신청(오전반차 사후품의)_5651672.html
# 처리 중... [757/7704] 20160729_하계 연차휴가 상신의 건_5652107.html
# 처리 중... [758/7704] 20160729_하계휴가_5647521.html
# 처리 중... [759/7704] 20160801_동부증권 네트워크 포렌식 시스템 유지보수_5660661.html
# 처리 중... [760/7704] 20160802_'16.08.02 휴가 품의 상신_5663122.html
# 처리 중... [761/7704] 20160802_2016년 7월 법인카드 정산 품의_5668061.html
# 처리 중... [762/7704] 20160802_휴가신청_5662484.html
# 처리 중... [763/7704] 20160803_접대비_5668337.html
# 처리 중... [764/7704] 20160803_하계휴가 (일정변경)_5673551.html
# 처리 중... [765/7704] 20160803_하계휴가_5670014.html
# 처리 중... [766/7704] 20160804_하계 휴가 품의_5676838.html
# 처리 중... [767/7704] 20160804_하계휴가_5678351.html
# 처리 중... [768/7704] 20160805_2016년 하계 건국대학교 현장실습 중식비 지급의 건_박진수, 김다혜, 전하라, 마수원, 정성재_5771119.html
# 처리 중... [769/7704] 20160805_ETRI 'R&amp;BD 1차 및 분리발주 응용시스템 유지관리' 계약 품의_5774507.html
# 처리 중... [770/7704] 20160805_ETRI R&amp;BD 1차 및 분리발주 응용시스템 유지관리 구매 폼의_5774706.html
# 처리 중... [771/7704] 20160805_[외주인력투입계약품의] 2016년 LG전자 TIPIS 2.0구축 (문명진)_5773836.html
# 처리 중... [772/7704] 20160805_[외주인력투입계약품의] kt ds 오픈소스SW 컴플라이언스 관리 솔루션 개발 (김수진)_5773196.html
# 처리 중... [773/7704] 20160805_[외주인력투입수정계약품의] 2016년 LG전자 TIPIS2.0구축 (김란)_5773148.html
# 처리 중... [774/7704] 20160807_7월 야근식대 청구_5776694.html
# 처리 중... [775/7704] 20160808_법인카드 정산 품의 (16년7월, 박근록B)_5777742.html
# 처리 중... [776/7704] 20160808_시내교통비 정산 품의(6_28, 7_4)_5784582.html
# 처리 중... [777/7704] 20160808_여름 휴가 신청합니다._5783835.html
# 처리 중... [778/7704] 20160808_일반경비 품의 - TIPIS2.0 구축 프로젝트 회의비(6_29)_5784682.html
# 처리 중... [779/7704] 20160808_접대비 신청의 건_5779574.html
# 처리 중... [780/7704] 20160809_2016년 7월 일반경비 신청_5787210.html
# 처리 중... [781/7704] 20160809_동우화인켐 단기출장 품의_5786244.html
# 처리 중... [782/7704] 20160809_반차 휴가_5793465.html
# 처리 중... [783/7704] 20160809_빅데이터 전문인력양성 교육 참가_5790691.html
# 처리 중... [784/7704] 20160809_하계휴가 신청의 건_5787763.html
# 처리 중... [785/7704] 20160810_하기휴가 품의(송준선)_5794009.html
# 처리 중... [786/7704] 20160811_2016년 여름 휴가 결재 입니다._5804691.html
# 처리 중... [787/7704] 20160811_7월 시내교통비_5800752.html
# 처리 중... [788/7704] 20160811_김상욱 예비군 훈련_5802556.html
# 처리 중... [789/7704] 20160811_연차 휴가 품의_5801669.html
# 처리 중... [790/7704] 20160812_20160829 예비군훈련_5810171.html
# 처리 중... [791/7704] 20160812_2016년8월 아웃소싱 인건비 지급 품의(8월15일 지급건)_5811302.html
# 처리 중... [792/7704] 20160812_SK케미칼 작업 후 귀가 택시비 입니다._5808473.html
# 처리 중... [793/7704] 20160812_김하응부장_나주_농어촌진흥공사 출장품의(20160816)_5809938.html
# ...
# 처리 중... [7511/7704] 20201113_[대금결제]외주용역비 대금 결제의 건-프리랜서(11_16일자)_14868721.html
# 처리 중... [7512/7704] 20201113_기술연구소 최우석 사원 퇴직 품의서_14869881.html
# 처리 중... [7513/7704] 20201113_기타 경비 신청 (20.11.13)_14870795.html
# 처리 중... [7514/7704] 20201113_기타 경비 신청 (20.11.13)_14870826.html
# 처리 중... [7515/7704] 20201113_대금결제] 한국연구재단  2020년 NRF 정보시스템 통합 위탁운영 매입대금 결제의 건_14867250.html
# 처리 중... [7516/7704] 20201113_대중소 상생협력기금 구축 식대 품의_14869045.html
# 처리 중... [7517/7704] 20201113_연차휴가 신청(11_12, 1일)_14870880.html
# 처리 중... [7518/7704] 20201114_경비 신청_14874064.html
# 처리 중... [7519/7704] 20201115_야근 교통비 지급 신청의 건_14874696.html
# 처리 중... [7520/7704] 20201115_야근식대 지급 신청의 건_14874692.html
# 처리 중... [7521/7704] 20201116_대전 원자력연구원 출장비 지급 신청서 입니다_14880287.html
# 처리 중... [7522/7704] 20201116_재직증명서 신청_14879028.html
# 처리 중... [7523/7704] 20201117_신성호_연차 결재 품의_14884099.html
# 처리 중... [7524/7704] 20201117_연차휴가 신청_14889355.html
# 처리 중... [7525/7704] 20201118_2020.11.11(수)-2020.11.13(금) 연차 품의_14899077.html
# 처리 중... [7526/7704] 20201118_단기출장 품의서 송부의 件_14897507.html
# 처리 중... [7527/7704] 20201118_휴가 사용 신청의 件_14897541.html
# 처리 중... [7528/7704] 20201119_2020년 11월 26일(목) ~ 2020년 12월 01일(화) 하계 휴가 신청합니다_14906481.html
# 처리 중... [7529/7704] 20201119_[C_P 품의] AI기반 모태펀드 출자펀드 찾기 시스템 개발_14902770.html
# 처리 중... [7530/7704] 20201119_[대금결제] ETRI 통합정보(ETRIware) 유지관리 계약 - 2020년 10월분 대금 지급의 건_14901097.html
# 처리 중... [7531/7704] 20201119_연차 휴가 품의_14901743.html
# 처리 중... [7532/7704] 20201120_'20.11.19 출장비 지급 신청 품의_14907494.html
# 처리 중... [7533/7704] 20201120_2020년 11월 20일 반차 신청합니다._14907275.html
# 처리 중... [7534/7704] 20201120_[S_W]금호석유화학 지식재산통합관리시스텝 재구축관련 DRM 구입 품의_14908970.html
# 처리 중... [7535/7704] 20201120_[S_W]한국발명진흥회 IP금융관리시스템 구축관련 전자인증 공인인증시스템 구입 품의_14908409.html
# 처리 중... [7536/7704] 20201120_개인휴가 신청 _ 2020-11-25 (수), 1일_14907448.html
# 처리 중... [7537/7704] 20201120_신우진 연차휴가 (오후반차) 신청_14909374.html
# 처리 중... [7538/7704] 20201123_[대금결제] Dell 사업 매입 대금 결제의 건-에스씨지솔루션즈 외(11월)_14915461.html
# 처리 중... [7539/7704] 20201123_[휴가]사용신청드립니다._14915688.html
# 처리 중... [7540/7704] 20201123_연차신청서(박형남) 입니다._14918868.html
# 처리 중... [7541/7704] 20201124_ETRI사업팀 회식 품의_14924258.html
# 처리 중... [7542/7704] 20201124_연차 품의서_14929625.html
# 처리 중... [7543/7704] 20201124_휴가사용신청서_14930682.html
# 처리 중... [7544/7704] 20201125_20201127_연차 신청합니다_14938271.html
# 처리 중... [7545/7704] 20201125_[반차휴가] 김우석 선임 11월 25일 오후 반차 신청서_14934093.html
# 처리 중... [7546/7704] 20201125_금호석유화학 프로젝트의 회식비 사용 품의를 요청합니다._14940681.html
# 처리 중... [7547/7704] 20201125_김상욱 휴가 사용 신청서 입니다._14938357.html
# 처리 중... [7548/7704] 20201125_연차휴가를 신청합니다._14940673.html
# 처리 중... [7549/7704] 20201125_휴가 사용 신청 품의_14938196.html
# 처리 중... [7550/7704] 20201126_11월 기타 경비 신청 합니다_14946046.html
# 처리 중... [7551/7704] 20201126_경동윤_사원_ICT사업팀 휴가신청서 제출합니다._14944149.html
# 처리 중... [7552/7704] 20201126_휴가 사용 신청_14943665.html
# 처리 중... [7553/7704] 20201127_[대금결제] 관세청 국가간 원산지정보 자료교환 시스템 확대 구축 매입 대금 결제의 건-한국렌탈_14950146.html
# 처리 중... [7554/7704] 20201127_반차 신청합니다._14952260.html
# 처리 중... [7555/7704] 20201127_소모품 구매 품의서 기안의 건_14952269.html
# 처리 중... [7556/7704] 20201127_휴가 사용 신청의 건_14948957.html
# 처리 중... [7557/7704] 20201128_출장비 지급 신청의 件_14956840.html
# 처리 중... [7558/7704] 20201129_사업자등록증 사본, 피보험자격이력내역서, 주업종코드확인서 요청_14957756.html
# 처리 중... [7559/7704] 20201129_제증명서 발급 신청서_14957757.html
# 처리 중... [7560/7704] 20201130_(계약변경) 이화여자대학교 산학협력단_지식재산권 통합 관리 시스템 유지보수 용역_14967536.html
# 처리 중... [7561/7704] 20201130_(신규) 20년 SKC 특허관리시스템 유지보수 계약_14967600.html
# 처리 중... [7562/7704] 20201130_AI기반 모태펀드 출자펀드 찾기 시스템 개발을 위한 AI 업체 아웃소싱의 건_14966035.html
# 처리 중... [7563/7704] 20201130_[LG U+ MEC기반 5G 공공선도 플랫폼]에 대한 매출_매입 계약 품의_14961402.html
# 처리 중... [7564/7704] 20201130_과제비 카드 (4626)_14967986.html
# 처리 중... [7565/7704] 20201130_과제비카드 (5525) 사용 내역 품의서_14967987.html
# 처리 중... [7566/7704] 20201130_구매계약 품의(외주인력)GS칼텍스 법무관련 시스템 개선 프로젝트_14963738.html
# 처리 중... [7567/7704] 20201130_야근 교통비 지급 신청의 건_14967812.html
# 처리 중... [7568/7704] 20201130_야근식대 지급 신청의 件_14968010.html
# 처리 중... [7569/7704] 20201130_야근식대 지급 신청의 건_14967800.html
# 처리 중... [7570/7704] 20201130_주차비 등 비용 신청서_14967984.html
# 처리 중... [7571/7704] 20201130_택시비 품의_14962759.html
# 처리 중... [7572/7704] 20201130_회의 출장비 청구_14967761.html
# 처리 중... [7573/7704] 20201130_휴가사용신청서_14958204.html
# 처리 중... [7574/7704] 20201201_대중소 상생협력기금 종합관리시스템 개발서버(PC) 구매 품의_14969115.html
# 처리 중... [7575/7704] 20201201_신우진 연차휴가 신청_14974251.html
# 처리 중... [7576/7704] 20201201_연차신청서(박형남) 입니다._14976644.html
# 처리 중... [7577/7704] 20201201_장기출장 품의_14975798.html
# 처리 중... [7578/7704] 20201201_정책과제 AI 평가용 특허평가요소 DB 구매의 건 (한국발명진흥회)_14971246.html
# 처리 중... [7579/7704] 20201202_LG U+ MEC기반 5G 공공선도 플랫폼_선투입 품의 #2_14980129.html
# 처리 중... [7580/7704] 20201202_연차휴가_12_11(금)_이형균_14978586.html
# 처리 중... [7581/7704] 20201202_퇴직 요청 드립니다._14979900.html
# 처리 중... [7582/7704] 20201203_11월 출장비 신청의 건_14987688.html
# 처리 중... [7583/7704] 20201203_2020.12.03 휴가 기안_14992571.html
# 처리 중... [7584/7704] 20201203_20201204_연차 신청합니다_14990833.html
# 처리 중... [7585/7704] 20201203_금호석유화학 지식재산통합관리시스템 재구축관련 DRM 매입계약 품의_14990292.html
# 처리 중... [7586/7704] 20201203_오후 반차 신청합니다._14988519.html
# 처리 중... [7587/7704] 20201203_출장 교통비_14988728.html
# 처리 중... [7588/7704] 20201204_AI기반 모태펀드 출자펀드 찾기 시스템 개발을 위한 동영상 제작 아웃소싱의 건_15002297.html
# 처리 중... [7589/7704] 20201204_전주대 빅데이터 플랫폼 구축 확대 및 학생성공 지원서비스 고도화 사업 외주인력 구매 품의의 건_15002586.html
# 처리 중... [7590/7704] 20201204_한국발명진흥회 IP금융관리시스템 구축관련 전자인증 공인인증시스템 매입계약 품의_15001461.html
# 처리 중... [7591/7704] 20201207_12월 9일 병가신청서_15010275.html
# 처리 중... [7592/7704] 20201207_대구경북과학기술원 연구사업지원플랫폼 구축 CP_15005711.html
# 처리 중... [7593/7704] 20201207_정책과제 AI기반 기술사업력평가 솔루션 개발 기업DB 구매 건(NICE D&amp;B)_15011720.html
# 처리 중... [7594/7704] 20201207_휴가 사용신청서 품의_15009173.html
# 처리 중... [7595/7704] 20201208_[입사품의] 입사품의(백유라)_15015322.html
# 처리 중... [7596/7704] 20201208_연차 신청의 건 (12_09, 수)_15018130.html
# 처리 중... [7597/7704] 20201208_휴가 사용 신청서 기안합니다._15019134.html
# 처리 중... [7598/7704] 20201208_휴가 사용 신청서_15021726.html
# 처리 중... [7599/7704] 20201208_휴가 신청(12_18)입니다._15019595.html
# 처리 중... [7600/7704] 20201208_휴가 신청_15018001.html
# 처리 중... [7601/7704] 20201209_[휴가]사용 신청드립니다._15025385.html
# 처리 중... [7602/7704] 20201209_기타 경비 신청 (20.12.09)_15030706.html
# 처리 중... [7603/7704] 20201209_대우조선해양 지식재산통합관리시스템 재구축 관련 S_W(검색엔진) 구매 품의_15023964.html
# 처리 중... [7604/7704] 20201209_연차휴가 품의 요청_15025219.html
# 처리 중... [7605/7704] 20201209_휴가 요청합니다._15025179.html
# 처리 중... [7606/7704] 20201210_2020년 12월 11일 반차 신청합니다._15038445.html
# 처리 중... [7607/7704] 20201210_[야근식대 품의]_15033647.html
# 처리 중... [7608/7704] 20201210_연차휴가 결재요청_15032685.html
# 처리 중... [7609/7704] 20201211_(갱신) 한국자동차연구원 2021년 지식재산통합관리시스템 유지보수 계약 품의_15042780.html
# 처리 중... [7610/7704] 20201211_(기능개선) 국가수리과학연구소 연구과제시스템 기능개선_15042682.html
# 처리 중... [7611/7704] 20201211_12월 17일  ~ 12월 22일 휴가 사용 신청_15042402.html
# 처리 중... [7612/7704] 20201211_[휴가]사용 신청드립니다._15043723.html
# 처리 중... [7613/7704] 20201211_강원준 사원 휴가 사용 신청서 결재요청 드립니다._15044720.html
# 처리 중... [7614/7704] 20201211_개인 휴가 신청_조신행 사원_2020.12.18(금)_15041046.html
# 처리 중... [7615/7704] 20201214_[대금결제] 12월 외주용역비 대금 결제의 건-프리랜서(12_15)_15058383.html
# 처리 중... [7616/7704] 20201214_개인휴가 신청 _ 2020-12-15 (화), 1일_15052561.html
# 처리 중... [7617/7704] 20201214_대전 금호석유화학 연구소 출장 품의 입니다._15049865.html
# 처리 중... [7618/7704] 20201214_대전 원자력연구원 출장 품의서 입니다_15052528.html
# 처리 중... [7619/7704] 20201214_사원 박희철 12월 21일 휴가 사용 신청서_15053678.html
# 처리 중... [7620/7704] 20201214_휴가 사용 신청의 件_15058438.html
# 처리 중... [7621/7704] 20201214_휴가 신청 합니다._15050228.html
# 처리 중... [7622/7704] 20201215_AI기반 모태펀드 출자펀드 찾기 시스템 개발을 위한 동영상 제작 외주인력 계약의 건_15066824.html
# 처리 중... [7623/7704] 20201215_[반차신청] 김우석 선임 12월 18일 오후반차 신청_15063618.html
# 처리 중... [7624/7704] 20201215_정책과제 AI 평가용 특허평가요소 DB 구매의 건 (한국발명진흥회)_15066777.html
# 처리 중... [7625/7704] 20201215_휴가 사용 신청서_15059716.html
# 처리 중... [7626/7704] 20201215_휴가사용 품의(송준선)_15062320.html
# 처리 중... [7627/7704] 20201216_2020.12.04_택시비 품의_15069759.html
# 처리 중... [7628/7704] 20201216_2020년 12월 17일 반차 신청합니다._15070451.html
# 처리 중... [7629/7704] 20201216_[LG화학} PLM_Color.com 리뉴얼에 대한 매출_매입 계약 품의_15073322.html
# 처리 중... [7630/7704] 20201216_연차휴가를 신청합니다._15072250.html
# 처리 중... [7631/7704] 20201217_'20.12.21 ~'20.12.24 연차품의_15077517.html
# 처리 중... [7632/7704] 20201217_[가톨릭대학교]지식재산권 관리시스템 재구축 계약관련_15077438.html
# 처리 중... [7633/7704] 20201217_연차신청_15080629.html
# 처리 중... [7634/7704] 20201217_제증명서_15081379.html
# 처리 중... [7635/7704] 20201217_출장비 지급 신청서 입니다._15078648.html
# 처리 중... [7636/7704] 20201217_휴가 사용 신청합니다._15082307.html
# 처리 중... [7637/7704] 20201217_휴가 신청_15079542.html
# 처리 중... [7638/7704] 20201218_2020.12.28(월)-2020.12.31(목) 하계휴가 품의_15088992.html
# 처리 중... [7639/7704] 20201218_2020_12_24_사원_경동윤 휴가 신청서입니다._15086718.html
# 처리 중... [7640/7704] 20201218_[대금결제] Dell 사업 매입 대금 결제의 건-에스씨지솔루션즈 외(12월)_15086245.html
# 처리 중... [7641/7704] 20201218_[대금결제] ETRI 통합정보(ETRIware) 유지관리 계약 - 2020년 11월분 대금 지급의 건_15083828.html
# 처리 중... [7642/7704] 20201218_기술기반 스타트업의 자금 조달을 위한 AI기반 기술사업력 평가 솔루션 개발 GPU서버 렌탈의 건(한국렌탈)_15089317.html
# 처리 중... [7643/7704] 20201218_전주대 빅데이터 플랫폼 구축 확대 및 학생성공 지원서비스 고도화 사업 외주인력 구매계약 품의_15089550.html
# 처리 중... [7644/7704] 20201218_정책과제 AI기반 기술사업력평가 솔루션 개발 기업DB 구매 건(NICE D&amp;B)_15090032.html
# 처리 중... [7645/7704] 20201219_정책과제용 GPU 서버 렌탈 품의_15090746.html
# 처리 중... [7646/7704] 20201220_휴가 사용신청서 품의_15091620.html
# 처리 중... [7647/7704] 20201221_(갱신) LGCNS 2021년 사내 IT관리_특허관리시스템 유지보수 계약 품의_15092878.html
# 처리 중... [7648/7704] 20201221_(갱신) 한화토탈 2021년 연구과제시스템 유지보수 계약 품의_15091982.html
# 처리 중... [7649/7704] 20201221_(계약변경) 2021년 LG하우시스 지적재산관리시스템 유지보수 계약품의_15092643.html
# 처리 중... [7650/7704] 20201221_(기능개선) SK케미칼 지식재산관리시스템 AIP GW 로직추가 기능개선 계약(SK바이오사이언스)_15091896.html
# 처리 중... [7651/7704] 20201221_(기능개선) SK케미칼 지식재산관리시스템 AIP GW 로직추가 기능개선 계약(SK케미칼)_15091878.html
# 처리 중... [7652/7704] 20201221_(기능개선) SK케미칼 지식재산관리시스템 AIP GW 로직추가 기능개선 계약(SK플라즈마)_15091928.html
# 처리 중... [7653/7704] 20201221_(기능개선) 동우화인켐 ezLABs Flash 변경 기능개선_15093034.html
# 처리 중... [7654/7704] 20201221_(신규) 한국건설기술연구원 2021년도 기술사업화시스템(K-TIPS) 유지보수 계약품의_15093601.html
# 처리 중... [7655/7704] 20201221_2020.12.19_택시비 품의_15095923.html
# 처리 중... [7656/7704] 20201221_ETRI사업팀 회식비 사용품의_15096785.html
# 처리 중... [7657/7704] 20201221_[대금결제] KIAT &quot;사업관리시스템(K-PASS)고도화 용역&quot; 매입대금 결제의 건-케이씨씨정보통신_15100869.html
# 처리 중... [7658/7704] 20201221_[대금결제] 대중소기업농어업협력재단 &quot;대중소기업상생협력기금 종합관리시스템 구축용역&quot; 매입대금 결제의 건-케이씨씨정보통신, 암펠_15100845.html
# 처리 중... [7659/7704] 20201221_[대금결제] 한국벤처투자 AI기반 모태펀드 출자펀드 찾기 시스템 개발 관련 비용 지급의 건(에이아이더 등 3개 업체)_15099663.html
# 처리 중... [7660/7704] 20201221_대전 원자력연구원 출장비 지급 신청서 입니다_15095550.html
# 처리 중... [7661/7704] 20201221_신우진 연차휴가 신청_15099779.html
# 처리 중... [7662/7704] 20201222_[대금결제] SKC &quot;지식재산관리시스템 구축&quot; 사업 S_W(검색엔진) 매입대금 결제의 건-다이퀘스트_15104566.html
# 처리 중... [7663/7704] 20201222_[대금결제] 전주대 &quot;빅데이터 플랫폼 구축 확대 및 학생성공 지원서비스 고도화&quot; 매입대금 결제의 건-와이즈정보_15106022.html
# 처리 중... [7664/7704] 20201222_대중소기업상생협력기금 종합관리시스템 구축 - H_W구매 품의_15108475.html
# 처리 중... [7665/7704] 20201222_휴가 사용 신청서_15101870.html
# 처리 중... [7666/7704] 20201223_[대금결제] 12월 외주용역비 대금 결제의 건-협력사_15116773.html
# 처리 중... [7667/7704] 20201223_강원준 사원 휴가 사용 신청서 올립니다._15118046.html
# 처리 중... [7668/7704] 20201223_연차휴가_12_31(목)_이형균_15112413.html
# 처리 중... [7669/7704] 20201223_휴가 사용 신청서 기안합니다._15117947.html
# 처리 중... [7670/7704] 20201223_휴가신청_15110779.html
# 처리 중... [7671/7704] 20201224_20201224_12월 교통비 신청 합니다_15122024.html
# 처리 중... [7672/7704] 20201224_20201224_기타 경비 신청합니다_15121947.html
# 처리 중... [7673/7704] 20201224_[LG화학 특허시스템 운영]에 관한 매출매입 계약품의_15120957.html
# 처리 중... [7674/7704] 20201224_[입사품의] 경력사원 입사품의(박태민)_15125711.html
# 처리 중... [7675/7704] 20201224_휴가 사용 신청서_이의환 선임_15118588.html
# 처리 중... [7676/7704] 20201224_휴가 신청_15124492.html
# 처리 중... [7677/7704] 20201224_휴가 신청드립니다._15119275.html
# 처리 중... [7678/7704] 20201228_12월 기타 경비 신청서_15128525.html
# 처리 중... [7679/7704] 20201228_2020년 12월 29일 ~ 31일 연차 신청합니다._15127963.html
# 처리 중... [7680/7704] 20201228_연차 휴가 신청(12_31, 1일)_15131405.html
# 처리 중... [7681/7704] 20201228_연차휴가 신청_15131894.html
# 처리 중... [7682/7704] 20201228_퇴직 품의서 입니다._15131855.html
# 처리 중... [7683/7704] 20201228_휴가 사용 신청서_15132058.html
# 처리 중... [7684/7704] 20201229_12월 31일 휴가 사용 신청_15143833.html
# 처리 중... [7685/7704] 20201229_2020년 12월 31일(목) 연차 휴가 신청합니다_15140962.html
# 처리 중... [7686/7704] 20201229_연차 신청합니다._15143289.html
# 처리 중... [7687/7704] 20201229_연차 품의서_15140253.html
# 처리 중... [7688/7704] 20201229_연차 품의서_15140325.html
# 처리 중... [7689/7704] 20201229_연차 품의서_15144318.html
# 처리 중... [7690/7704] 20201229_연차 품의서_15144596.html
# 처리 중... [7691/7704] 20201229_출장비 지급 신청서_15140175.html
# 처리 중... [7692/7704] 20201229_휴가 사용 신청서_15145098.html
# 처리 중... [7693/7704] 20201229_휴가 사용 신청의 건_15140203.html
# 처리 중... [7694/7704] 20201230_'20.12.31 연차품의_15147178.html
# 처리 중... [7695/7704] 20201230_2020.12.30 휴가 기안_15146558.html
# 처리 중... [7696/7704] 20201230_경조금 지급 신청(부친 칠순)_15151800.html
# 처리 중... [7697/7704] 20201230_연차 휴가 품의_15147728.html
# 처리 중... [7698/7704] 20201230_연차휴가 신청_15147817.html
# 처리 중... [7699/7704] 20201230_출장 품의서_15146335.html
# 처리 중... [7700/7704] 20201230_퇴직 품의서_15147253.html
# 처리 중... [7701/7704] 20201230_휴가 사용 신청서_15145153.html
# 처리 중... [7702/7704] 20201231_야근 식대 지급 신청합니다._15155889.html
# 처리 중... [7703/7704] 20201231_야근식대 지급 신청의 件_15159947.html
# 처리 중... [7704/7704] 20201231_출장비 지급 신청합니다._15155817.html
# JSON 파일 저장 완료: two_htmltojsondb_convert.json
#
# ==================================================
#
# === DB 연결 시작 ===
# Host: localhost, Database: any_approval
# ✓ DB 연결 성공
#
# === 테이블 생성 시작 ===
# ✓ 테이블 생성/확인 완료
# ✓ 기존 데이터: 8175건
#
# === 데이터 삽입 시작 (7704건) ===
#   진행: 100/7704 (성공: 100, 실패: 0)
#   진행: 200/7704 (성공: 200, 실패: 0)
#   진행: 300/7704 (성공: 300, 실패: 0)
#   진행: 400/7704 (성공: 400, 실패: 0)
#   진행: 500/7704 (성공: 500, 실패: 0)
#   진행: 600/7704 (성공: 600, 실패: 0)
#   진행: 700/7704 (성공: 700, 실패: 0)
#   진행: 800/7704 (성공: 800, 실패: 0)
#   진행: 900/7704 (성공: 900, 실패: 0)
#   진행: 1000/7704 (성공: 1000, 실패: 0)
#   진행: 1100/7704 (성공: 1100, 실패: 0)
#   진행: 1200/7704 (성공: 1200, 실패: 0)
#   진행: 1300/7704 (성공: 1300, 실패: 0)
#   진행: 1400/7704 (성공: 1400, 실패: 0)
#   진행: 1500/7704 (성공: 1500, 실패: 0)
#   진행: 1600/7704 (성공: 1600, 실패: 0)
#   진행: 1700/7704 (성공: 1700, 실패: 0)
#   진행: 1800/7704 (성공: 1800, 실패: 0)
#   진행: 1900/7704 (성공: 1900, 실패: 0)
#   진행: 2000/7704 (성공: 2000, 실패: 0)
#   진행: 2100/7704 (성공: 2100, 실패: 0)
#   진행: 2200/7704 (성공: 2200, 실패: 0)
#   진행: 2300/7704 (성공: 2300, 실패: 0)
#   진행: 2400/7704 (성공: 2400, 실패: 0)
#   진행: 2500/7704 (성공: 2500, 실패: 0)
#   진행: 2600/7704 (성공: 2600, 실패: 0)
#   진행: 2700/7704 (성공: 2700, 실패: 0)
#   진행: 2800/7704 (성공: 2800, 실패: 0)
#   진행: 2900/7704 (성공: 2900, 실패: 0)
#   진행: 3000/7704 (성공: 3000, 실패: 0)
#   진행: 3100/7704 (성공: 3100, 실패: 0)
#   진행: 3200/7704 (성공: 3200, 실패: 0)
#   진행: 3300/7704 (성공: 3300, 실패: 0)
#   진행: 3400/7704 (성공: 3400, 실패: 0)
#   진행: 3500/7704 (성공: 3500, 실패: 0)
#   진행: 3600/7704 (성공: 3600, 실패: 0)
#   진행: 3700/7704 (성공: 3700, 실패: 0)
#   진행: 3800/7704 (성공: 3800, 실패: 0)
#   진행: 3900/7704 (성공: 3900, 실패: 0)
#   진행: 4000/7704 (성공: 4000, 실패: 0)
#   진행: 4100/7704 (성공: 4100, 실패: 0)
#   진행: 4200/7704 (성공: 4200, 실패: 0)
#   진행: 4300/7704 (성공: 4300, 실패: 0)
#   진행: 4400/7704 (성공: 4400, 실패: 0)
#   진행: 4500/7704 (성공: 4500, 실패: 0)
#   진행: 4600/7704 (성공: 4600, 실패: 0)
#   진행: 4700/7704 (성공: 4700, 실패: 0)
#   진행: 4800/7704 (성공: 4800, 실패: 0)
#   진행: 4900/7704 (성공: 4900, 실패: 0)
#   진행: 5000/7704 (성공: 5000, 실패: 0)
#   진행: 5100/7704 (성공: 5100, 실패: 0)
#   진행: 5200/7704 (성공: 5200, 실패: 0)
#   진행: 5300/7704 (성공: 5300, 실패: 0)
#   진행: 5400/7704 (성공: 5400, 실패: 0)
#   진행: 5500/7704 (성공: 5500, 실패: 0)
#   진행: 5600/7704 (성공: 5600, 실패: 0)
#   진행: 5700/7704 (성공: 5700, 실패: 0)
#   진행: 5800/7704 (성공: 5800, 실패: 0)
#   진행: 5900/7704 (성공: 5900, 실패: 0)
#   진행: 6000/7704 (성공: 6000, 실패: 0)
#   진행: 6100/7704 (성공: 6100, 실패: 0)
#   진행: 6200/7704 (성공: 6200, 실패: 0)
#   진행: 6300/7704 (성공: 6300, 실패: 0)
#   진행: 6400/7704 (성공: 6400, 실패: 0)
#   진행: 6500/7704 (성공: 6500, 실패: 0)
#   진행: 6600/7704 (성공: 6600, 실패: 0)
#   진행: 6700/7704 (성공: 6700, 실패: 0)
#   진행: 6800/7704 (성공: 6800, 실패: 0)
#   진행: 6900/7704 (성공: 6900, 실패: 0)
#   진행: 7000/7704 (성공: 7000, 실패: 0)
#   진행: 7100/7704 (성공: 7100, 실패: 0)
#   진행: 7200/7704 (성공: 7200, 실패: 0)
#   진행: 7300/7704 (성공: 7300, 실패: 0)
#   진행: 7400/7704 (성공: 7400, 실패: 0)
#   진행: 7500/7704 (성공: 7500, 실패: 0)
#   진행: 7600/7704 (성공: 7600, 실패: 0)
#   진행: 7700/7704 (성공: 7700, 실패: 0)
#   진행: 7704/7704 (성공: 7704, 실패: 0)
#
# === 커밋 시작 ===
# ✓ 커밋 완료
#
# === 결과 요약 ===
# ✓ 성공: 7704건
# ✗ 실패: 0건
#
# ✓ 최종 데이터: 15879건 (이번 실행으로 7704건 추가)
#
# ✓ DB 연결 종료
# ==================================================
#
# 완료! 총 7704건 처리됨
