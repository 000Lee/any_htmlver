# %%
# 이미지 경로 변환 - any_approval DB 전자결재 문서용
# documents 테이블의 doc_body 컬럼 처리
# end_year로 연도별 필터링

import json
import os
import shutil
import re
from pathlib import Path
import pymysql
from sqlalchemy import create_engine

# ==================== DB 설정 ====================
USER = "root"
PASS = "1234"
HOST = "127.0.0.1"
PORT = 3306
DB = "any_approval"

# ==================== 설정 영역 (여기를 수정하세요) ====================

# 종료연도 (필터링용)
END_YEAR = 2025  # ✨ 2025, 2024, 2023 등

# 이미지 원본 경로들 - 여러 경로 추가 가능
BASE_IMAGE_PATHS = [
    r"C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor",
    r"C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\daumeditor",
    # r"C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\namoeditor",
    # r"C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor",
    # 더 추가하고 싶으면 여기에 계속 추가
]

# 이미지 복사본 저장 폴더 (연도별로 자동 생성)
OUTPUT_IMAGE_FOLDER = rf"C:\Users\LEEJUHWAN\Downloads\approval_{END_YEAR}_img"  # ✨ 연도 반영

# src에서 제거할 접두사 (이 부분을 제거하고 상대경로로 변경)
REMOVE_PREFIX = r"C:\Users\LEEJUHWAN\Downloads"

# ======================================================================


def find_image_folder(folder_name):
    """여러 경로에서 이미지 폴더 찾기"""
    for base_path in BASE_IMAGE_PATHS:
        image_folder = Path(base_path) / folder_name
        if image_folder.exists():
            return image_folder
    return None


def process_single_document(data, doc_index):
    """하나의 document 데이터 처리"""
    
    # source_id에서 문서ID 추출
    source_id = data.get('source_id', '')
    if not source_id:
        print(f"⚠️ [{doc_index}] source_id 없음, 건너뜀")
        return data  # 원본 그대로 반환
    
    doc_id = source_id  # ✨ lstrip('_') 제거, 그대로 사용
    folder_name = f"apr{doc_id}"  # ✨ brd → apr
    
    # 여러 경로에서 이미지 폴더 찾기
    image_folder = find_image_folder(folder_name)
    
    if not image_folder:
        print(f"⚠️ [{doc_index}] 폴더 없음: {folder_name} (모든 경로 검색 완료)")
        return data  # 원본 그대로 반환
    
    # 복사본 저장할 문서별 폴더 생성
    output_doc_folder = Path(OUTPUT_IMAGE_FOLDER) / folder_name
    output_doc_folder.mkdir(parents=True, exist_ok=True)
    
    print(f"\n📄 [{doc_index}] 문서ID: {doc_id}")
    print(f"   원본: {image_folder}")
    print(f"   복사: {output_doc_folder}")
    
    # HTML에서 img 태그 찾기
    html_content = data.get('doc_body', '')  # ✨ content → doc_body
    if not html_content:
        print(f"   ⚠️ doc_body 없음")
        return data
    
    img_pattern = r'<img[^>]+src="([^"]+)"[^>]*>'
    img_matches = list(re.finditer(img_pattern, html_content))
    
    if not img_matches:
        print(f"   ℹ️ 이미지 없음")
        return data
    
    print(f"   ✅ 이미지 {len(img_matches)}개 발견")
    
    # 파일 복사 & src 경로 변경
    new_html = html_content
    copied_count = 0
    
    for idx, match in enumerate(img_matches):
        old_src = match.group(1)
        
        # 원본 파일 (0, 1, 2...)
        old_file = image_folder / str(idx)
        
        # 복사본 파일 (.jpg 확장자 추가)
        new_file = output_doc_folder / f"{idx}.jpg"
        
        # 파일 복사
        if old_file.exists():
            shutil.copy2(old_file, new_file)
            copied_count += 1
            print(f"      ✅ {old_file.name} → {new_file.name}")
            
            # src 경로 변경 (상대경로로)
            new_src = str(new_file).replace('\\', '/')
            if REMOVE_PREFIX:
                prefix_with_slash = REMOVE_PREFIX.replace('\\', '/')
                if new_src.startswith(prefix_with_slash):
                    new_src = new_src[len(prefix_with_slash):].lstrip('/')
            
            new_html = new_html.replace(old_src, new_src, 1)
        else:
            print(f"      ⚠️ 파일 없음: {old_file.name} - src 공란 처리")
            # src를 빈 문자열로 변경
            new_html = new_html.replace(old_src, '', 1)
    
    print(f"   📊 복사 완료: {copied_count}/{len(img_matches)}개")
    
    # 수정된 HTML 적용
    data['doc_body'] = new_html  # ✨ content → doc_body
    return data


def process_db(end_year):
    """DB에서 특정 end_year의 데이터만 읽고 처리 후 DB에 업데이트"""
    
    # 출력 폴더 생성
    os.makedirs(OUTPUT_IMAGE_FOLDER, exist_ok=True)
    
    # DB 연결
    print(f"📂 DB 연결 중...")
    print(f"📂 종료연도: {end_year}")  # ✨ 추가
    print(f"📂 검색할 이미지 경로: {len(BASE_IMAGE_PATHS)}개\n")
    
    connection = pymysql.connect(
        host=HOST,
        user=USER,
        password=PASS,
        database=DB,
        port=PORT,
        charset='utf8mb4'
    )
    
    try:
        with connection.cursor(pymysql.cursors.DictCursor) as cursor:
            # 1. DB에서 특정 end_year의 데이터만 읽기
            query = "SELECT * FROM documents WHERE end_year = %s"  # ✨ WHERE 조건 추가
            cursor.execute(query, (end_year,))
            documents = cursor.fetchall()
            
            total_count = len(documents)
            print(f"✅ 총 {total_count}개의 documents 발견\n")
            
            # 2. 각 document 처리
            processed_count = 0
            
            for idx, doc in enumerate(documents, 1):
                try:
                    # 원본 doc_body 저장 (비교용)
                    original_content = doc.get('doc_body', '')
                    
                    # 기존 로직 그대로 사용
                    result = process_single_document(doc, idx)
                    
                    # doc_body가 변경된 경우만 DB 업데이트
                    if result['doc_body'] != original_content:
                        update_query = """
                            UPDATE documents 
                            SET doc_body = %s 
                            WHERE source_id = %s AND end_year = %s
                        """  # ✨ WHERE 조건에 end_year도 추가
                        cursor.execute(update_query, (result['doc_body'], result['source_id'], end_year))
                        processed_count += 1
                    
                except Exception as e:
                    print(f"❌ [Document {idx}] 처리 오류: {e}")
                    continue
            
            # 변경사항 커밋
            connection.commit()
            
            print(f"\n{'='*60}")
            print(f"✅ 처리 완료!")
            print(f"   - 종료연도: {end_year}")  # ✨ 추가
            print(f"   - 처리된 documents: {processed_count}/{total_count}개")
            print(f"   - 복사된 이미지 위치: {OUTPUT_IMAGE_FOLDER}")
            print(f"   - DB 테이블: documents (doc_body 컬럼 업데이트)")
            print(f"{'='*60}")
    
    finally:
        connection.close()
        print("\n✅ DB 연결 종료")


# 실행
if __name__ == "__main__":
    process_db(END_YEAR)  # ✨ end_year 인자 추가
# Out:
# 📂 DB 연결 중...
# 📂 종료연도: 2025
# 📂 검색할 이미지 경로: 2개
#
# ✅ 총 8175개의 documents 발견
#
# ⚠️ [1] 폴더 없음: apr15167823 (모든 경로 검색 완료)
# ⚠️ [2] 폴더 없음: apr15168441 (모든 경로 검색 완료)
# ⚠️ [3] 폴더 없음: apr15162004 (모든 경로 검색 완료)
# ⚠️ [4] 폴더 없음: apr15175949 (모든 경로 검색 완료)
# ⚠️ [5] 폴더 없음: apr15178865 (모든 경로 검색 완료)
# ⚠️ [6] 폴더 없음: apr15177378 (모든 경로 검색 완료)
# ⚠️ [7] 폴더 없음: apr15179751 (모든 경로 검색 완료)
# ⚠️ [8] 폴더 없음: apr15188281 (모든 경로 검색 완료)
# ⚠️ [9] 폴더 없음: apr15182306 (모든 경로 검색 완료)
# ⚠️ [10] 폴더 없음: apr15184591 (모든 경로 검색 완료)
# ⚠️ [11] 폴더 없음: apr15186114 (모든 경로 검색 완료)
# ⚠️ [12] 폴더 없음: apr15183357 (모든 경로 검색 완료)
# ⚠️ [13] 폴더 없음: apr15184385 (모든 경로 검색 완료)
# ⚠️ [14] 폴더 없음: apr15194468 (모든 경로 검색 완료)
# ⚠️ [15] 폴더 없음: apr15193931 (모든 경로 검색 완료)
# ⚠️ [16] 폴더 없음: apr15204511 (모든 경로 검색 완료)
# ⚠️ [17] 폴더 없음: apr15204479 (모든 경로 검색 완료)
# ⚠️ [18] 폴더 없음: apr15213513 (모든 경로 검색 완료)
# ⚠️ [19] 폴더 없음: apr15211771 (모든 경로 검색 완료)
# ⚠️ [20] 폴더 없음: apr15208122 (모든 경로 검색 완료)
# ⚠️ [21] 폴더 없음: apr15213173 (모든 경로 검색 완료)
# ⚠️ [22] 폴더 없음: apr15215131 (모든 경로 검색 완료)
# ⚠️ [23] 폴더 없음: apr15215004 (모든 경로 검색 완료)
# ⚠️ [24] 폴더 없음: apr15219472 (모든 경로 검색 완료)
# ⚠️ [25] 폴더 없음: apr15219427 (모든 경로 검색 완료)
# ⚠️ [26] 폴더 없음: apr15223113 (모든 경로 검색 완료)
# ⚠️ [27] 폴더 없음: apr15222759 (모든 경로 검색 완료)
# ⚠️ [28] 폴더 없음: apr15238785 (모든 경로 검색 완료)
# ⚠️ [29] 폴더 없음: apr15237032 (모든 경로 검색 완료)
# ⚠️ [30] 폴더 없음: apr15236379 (모든 경로 검색 완료)
# ⚠️ [31] 폴더 없음: apr15235939 (모든 경로 검색 완료)
# ⚠️ [32] 폴더 없음: apr15241791 (모든 경로 검색 완료)
#
# 📄 [33] 문서ID: 15241300
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15241300
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15241300
#    ✅ 이미지 5개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#       ✅ 3 → 3.jpg
#       ✅ 4 → 4.jpg
#    📊 복사 완료: 5/5개
# ⚠️ [34] 폴더 없음: apr15242491 (모든 경로 검색 완료)
# ⚠️ [35] 폴더 없음: apr15255805 (모든 경로 검색 완료)
# ⚠️ [36] 폴더 없음: apr15248570 (모든 경로 검색 완료)
# ⚠️ [37] 폴더 없음: apr15250268 (모든 경로 검색 완료)
# ⚠️ [38] 폴더 없음: apr15252525 (모든 경로 검색 완료)
#
# 📄 [39] 문서ID: 15260823
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15260823
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15260823
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [40] 폴더 없음: apr15260341 (모든 경로 검색 완료)
# ⚠️ [41] 폴더 없음: apr15260360 (모든 경로 검색 완료)
# ⚠️ [42] 폴더 없음: apr15260370 (모든 경로 검색 완료)
# ⚠️ [43] 폴더 없음: apr15260379 (모든 경로 검색 완료)
# ⚠️ [44] 폴더 없음: apr15261417 (모든 경로 검색 완료)
# ⚠️ [45] 폴더 없음: apr15263937 (모든 경로 검색 완료)
# ⚠️ [46] 폴더 없음: apr15263459 (모든 경로 검색 완료)
# ⚠️ [47] 폴더 없음: apr15263948 (모든 경로 검색 완료)
#
# 📄 [48] 문서ID: 15270125
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15270125
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15270125
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [49] 폴더 없음: apr15266468 (모든 경로 검색 완료)
# ⚠️ [50] 폴더 없음: apr15273227 (모든 경로 검색 완료)
# ⚠️ [51] 폴더 없음: apr15277303 (모든 경로 검색 완료)
# ⚠️ [52] 폴더 없음: apr15274037 (모든 경로 검색 완료)
# ⚠️ [53] 폴더 없음: apr15276089 (모든 경로 검색 완료)
# ⚠️ [54] 폴더 없음: apr15284696 (모든 경로 검색 완료)
#
# 📄 [55] 문서ID: 15281420
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15281420
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15281420
#    ✅ 이미지 4개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#       ✅ 3 → 3.jpg
#    📊 복사 완료: 4/4개
# ⚠️ [56] 폴더 없음: apr15282191 (모든 경로 검색 완료)
# ⚠️ [57] 폴더 없음: apr15281429 (모든 경로 검색 완료)
# ⚠️ [58] 폴더 없음: apr15293791 (모든 경로 검색 완료)
# ⚠️ [59] 폴더 없음: apr15294678 (모든 경로 검색 완료)
# ⚠️ [60] 폴더 없음: apr15296205 (모든 경로 검색 완료)
# ⚠️ [61] 폴더 없음: apr15288901 (모든 경로 검색 완료)
# ⚠️ [62] 폴더 없음: apr15290605 (모든 경로 검색 완료)
# ⚠️ [63] 폴더 없음: apr15302575 (모든 경로 검색 완료)
# ⚠️ [64] 폴더 없음: apr15304184 (모든 경로 검색 완료)
# ⚠️ [65] 폴더 없음: apr15310441 (모든 경로 검색 완료)
# ⚠️ [66] 폴더 없음: apr15309642 (모든 경로 검색 완료)
#
# 📄 [67] 문서ID: 15312340
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15312340
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15312340
#    ✅ 이미지 4개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#       ✅ 3 → 3.jpg
#    📊 복사 완료: 4/4개
# ⚠️ [68] 폴더 없음: apr15310142 (모든 경로 검색 완료)
# ⚠️ [69] 폴더 없음: apr15310401 (모든 경로 검색 완료)
# ⚠️ [70] 폴더 없음: apr15309482 (모든 경로 검색 완료)
# ⚠️ [71] 폴더 없음: apr15314070 (모든 경로 검색 완료)
# ⚠️ [72] 폴더 없음: apr15313270 (모든 경로 검색 완료)
# ⚠️ [73] 폴더 없음: apr15315036 (모든 경로 검색 완료)
# ⚠️ [74] 폴더 없음: apr15315047 (모든 경로 검색 완료)
# ⚠️ [75] 폴더 없음: apr15319072 (모든 경로 검색 완료)
# ⚠️ [76] 폴더 없음: apr15316273 (모든 경로 검색 완료)
# ⚠️ [77] 폴더 없음: apr15313234 (모든 경로 검색 완료)
# ⚠️ [78] 폴더 없음: apr15315872 (모든 경로 검색 완료)
# ⚠️ [79] 폴더 없음: apr15313563 (모든 경로 검색 완료)
# ⚠️ [80] 폴더 없음: apr15324656 (모든 경로 검색 완료)
# ⚠️ [81] 폴더 없음: apr15327002 (모든 경로 검색 완료)
# ⚠️ [82] 폴더 없음: apr15320884 (모든 경로 검색 완료)
# ⚠️ [83] 폴더 없음: apr15326487 (모든 경로 검색 완료)
# ⚠️ [84] 폴더 없음: apr15330489 (모든 경로 검색 완료)
# ⚠️ [85] 폴더 없음: apr15340761 (모든 경로 검색 완료)
# ⚠️ [86] 폴더 없음: apr15337660 (모든 경로 검색 완료)
# ⚠️ [87] 폴더 없음: apr15337635 (모든 경로 검색 완료)
#
# 📄 [88] 문서ID: 15332304
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15332304
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15332304
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [89] 폴더 없음: apr15336633 (모든 경로 검색 완료)
# ⚠️ [90] 폴더 없음: apr15340814 (모든 경로 검색 완료)
# ⚠️ [91] 폴더 없음: apr15345414 (모든 경로 검색 완료)
# ⚠️ [92] 폴더 없음: apr15347013 (모든 경로 검색 완료)
# ⚠️ [93] 폴더 없음: apr15347485 (모든 경로 검색 완료)
# ⚠️ [94] 폴더 없음: apr15348296 (모든 경로 검색 완료)
# ⚠️ [95] 폴더 없음: apr15349060 (모든 경로 검색 완료)
# ⚠️ [96] 폴더 없음: apr15351837 (모든 경로 검색 완료)
# ⚠️ [97] 폴더 없음: apr15356532 (모든 경로 검색 완료)
# ⚠️ [98] 폴더 없음: apr15355386 (모든 경로 검색 완료)
# ⚠️ [99] 폴더 없음: apr15359740 (모든 경로 검색 완료)
# ⚠️ [100] 폴더 없음: apr15362351 (모든 경로 검색 완료)
# ⚠️ [101] 폴더 없음: apr15370601 (모든 경로 검색 완료)
# ⚠️ [102] 폴더 없음: apr15371818 (모든 경로 검색 완료)
# ⚠️ [103] 폴더 없음: apr15370340 (모든 경로 검색 완료)
# ⚠️ [104] 폴더 없음: apr15377405 (모든 경로 검색 완료)
# ⚠️ [105] 폴더 없음: apr15382181 (모든 경로 검색 완료)
# ⚠️ [106] 폴더 없음: apr15380279 (모든 경로 검색 완료)
# ⚠️ [107] 폴더 없음: apr15385270 (모든 경로 검색 완료)
# ⚠️ [108] 폴더 없음: apr15377356 (모든 경로 검색 완료)
# ⚠️ [109] 폴더 없음: apr15392888 (모든 경로 검색 완료)
# ⚠️ [110] 폴더 없음: apr15388474 (모든 경로 검색 완료)
# ⚠️ [111] 폴더 없음: apr15391835 (모든 경로 검색 완료)
# ⚠️ [112] 폴더 없음: apr15398744 (모든 경로 검색 완료)
# ⚠️ [113] 폴더 없음: apr15397718 (모든 경로 검색 완료)
# ⚠️ [114] 폴더 없음: apr15394875 (모든 경로 검색 완료)
# ⚠️ [115] 폴더 없음: apr15406737 (모든 경로 검색 완료)
# ⚠️ [116] 폴더 없음: apr15407831 (모든 경로 검색 완료)
# ⚠️ [117] 폴더 없음: apr15404259 (모든 경로 검색 완료)
# ⚠️ [118] 폴더 없음: apr15413555 (모든 경로 검색 완료)
# ⚠️ [119] 폴더 없음: apr15416101 (모든 경로 검색 완료)
# ⚠️ [120] 폴더 없음: apr15412559 (모든 경로 검색 완료)
# ⚠️ [121] 폴더 없음: apr15413002 (모든 경로 검색 완료)
# ⚠️ [122] 폴더 없음: apr15418731 (모든 경로 검색 완료)
# ⚠️ [123] 폴더 없음: apr15424352 (모든 경로 검색 완료)
# ⚠️ [124] 폴더 없음: apr15422130 (모든 경로 검색 완료)
# ⚠️ [125] 폴더 없음: apr15418675 (모든 경로 검색 완료)
# ⚠️ [126] 폴더 없음: apr15423448 (모든 경로 검색 완료)
# ⚠️ [127] 폴더 없음: apr15427585 (모든 경로 검색 완료)
# ⚠️ [128] 폴더 없음: apr15427134 (모든 경로 검색 완료)
# ⚠️ [129] 폴더 없음: apr15425947 (모든 경로 검색 완료)
# ⚠️ [130] 폴더 없음: apr15428886 (모든 경로 검색 완료)
# ⚠️ [131] 폴더 없음: apr15431940 (모든 경로 검색 완료)
# ⚠️ [132] 폴더 없음: apr15439810 (모든 경로 검색 완료)
# ⚠️ [133] 폴더 없음: apr15449793 (모든 경로 검색 완료)
# ⚠️ [134] 폴더 없음: apr15443629 (모든 경로 검색 완료)
# ⚠️ [135] 폴더 없음: apr15442285 (모든 경로 검색 완료)
# ⚠️ [136] 폴더 없음: apr15444686 (모든 경로 검색 완료)
# ⚠️ [137] 폴더 없음: apr15443589 (모든 경로 검색 완료)
# ⚠️ [138] 폴더 없음: apr15449968 (모든 경로 검색 완료)
# ⚠️ [139] 폴더 없음: apr15457976 (모든 경로 검색 완료)
# ⚠️ [140] 폴더 없음: apr15452261 (모든 경로 검색 완료)
# ⚠️ [141] 폴더 없음: apr15452466 (모든 경로 검색 완료)
# ⚠️ [142] 폴더 없음: apr15453360 (모든 경로 검색 완료)
# ⚠️ [143] 폴더 없음: apr15466074 (모든 경로 검색 완료)
# ⚠️ [144] 폴더 없음: apr15463060 (모든 경로 검색 완료)
# ⚠️ [145] 폴더 없음: apr15460132 (모든 경로 검색 완료)
# ⚠️ [146] 폴더 없음: apr15461640 (모든 경로 검색 완료)
# ⚠️ [147] 폴더 없음: apr15467415 (모든 경로 검색 완료)
# ⚠️ [148] 폴더 없음: apr15468791 (모든 경로 검색 완료)
# ⚠️ [149] 폴더 없음: apr15473638 (모든 경로 검색 완료)
# ⚠️ [150] 폴더 없음: apr15475801 (모든 경로 검색 완료)
# ⚠️ [151] 폴더 없음: apr15475811 (모든 경로 검색 완료)
# ⚠️ [152] 폴더 없음: apr15475835 (모든 경로 검색 완료)
# ⚠️ [153] 폴더 없음: apr15478738 (모든 경로 검색 완료)
# ⚠️ [154] 폴더 없음: apr15476030 (모든 경로 검색 완료)
# ⚠️ [155] 폴더 없음: apr15485084 (모든 경로 검색 완료)
# ⚠️ [156] 폴더 없음: apr15484992 (모든 경로 검색 완료)
# ⚠️ [157] 폴더 없음: apr15484981 (모든 경로 검색 완료)
# ⚠️ [158] 폴더 없음: apr15485278 (모든 경로 검색 완료)
# ⚠️ [159] 폴더 없음: apr15489447 (모든 경로 검색 완료)
# ⚠️ [160] 폴더 없음: apr15489464 (모든 경로 검색 완료)
# ⚠️ [161] 폴더 없음: apr15511406 (모든 경로 검색 완료)
# ⚠️ [162] 폴더 없음: apr15512371 (모든 경로 검색 완료)
# ⚠️ [163] 폴더 없음: apr15517450 (모든 경로 검색 완료)
# ⚠️ [164] 폴더 없음: apr15518800 (모든 경로 검색 완료)
# ⚠️ [165] 폴더 없음: apr15515194 (모든 경로 검색 완료)
# ⚠️ [166] 폴더 없음: apr15518902 (모든 경로 검색 완료)
# ⚠️ [167] 폴더 없음: apr15530892 (모든 경로 검색 완료)
# ⚠️ [168] 폴더 없음: apr15536532 (모든 경로 검색 완료)
# ⚠️ [169] 폴더 없음: apr15539864 (모든 경로 검색 완료)
# ⚠️ [170] 폴더 없음: apr15544598 (모든 경로 검색 완료)
# ⚠️ [171] 폴더 없음: apr15543249 (모든 경로 검색 완료)
# ⚠️ [172] 폴더 없음: apr15544773 (모든 경로 검색 완료)
# ⚠️ [173] 폴더 없음: apr15548135 (모든 경로 검색 완료)
# ⚠️ [174] 폴더 없음: apr15545682 (모든 경로 검색 완료)
# ⚠️ [175] 폴더 없음: apr15550027 (모든 경로 검색 완료)
# ⚠️ [176] 폴더 없음: apr15550779 (모든 경로 검색 완료)
# ⚠️ [177] 폴더 없음: apr15555001 (모든 경로 검색 완료)
# ⚠️ [178] 폴더 없음: apr15563397 (모든 경로 검색 완료)
# ⚠️ [179] 폴더 없음: apr15560602 (모든 경로 검색 완료)
# ⚠️ [180] 폴더 없음: apr15568372 (모든 경로 검색 완료)
# ⚠️ [181] 폴더 없음: apr15567588 (모든 경로 검색 완료)
# ⚠️ [182] 폴더 없음: apr15581565 (모든 경로 검색 완료)
# ⚠️ [183] 폴더 없음: apr15588086 (모든 경로 검색 완료)
# ⚠️ [184] 폴더 없음: apr15587395 (모든 경로 검색 완료)
# ⚠️ [185] 폴더 없음: apr15587527 (모든 경로 검색 완료)
# ⚠️ [186] 폴더 없음: apr15589167 (모든 경로 검색 완료)
# ⚠️ [187] 폴더 없음: apr15588762 (모든 경로 검색 완료)
# ⚠️ [188] 폴더 없음: apr15594295 (모든 경로 검색 완료)
# ⚠️ [189] 폴더 없음: apr15589614 (모든 경로 검색 완료)
# ⚠️ [190] 폴더 없음: apr15594567 (모든 경로 검색 완료)
#
# 📄 [191] 문서ID: 15598972
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15598972
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15598972
#    ✅ 이미지 3개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#    📊 복사 완료: 3/3개
#
# 📄 [192] 문서ID: 15612862
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15612862
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15612862
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [193] 폴더 없음: apr15612084 (모든 경로 검색 완료)
# ⚠️ [194] 폴더 없음: apr15612520 (모든 경로 검색 완료)
# ⚠️ [195] 폴더 없음: apr15618394 (모든 경로 검색 완료)
# ⚠️ [196] 폴더 없음: apr15621344 (모든 경로 검색 완료)
# ⚠️ [197] 폴더 없음: apr15619012 (모든 경로 검색 완료)
# ⚠️ [198] 폴더 없음: apr15622382 (모든 경로 검색 완료)
# ⚠️ [199] 폴더 없음: apr15620990 (모든 경로 검색 완료)
# ⚠️ [200] 폴더 없음: apr15618962 (모든 경로 검색 완료)
# ⚠️ [201] 폴더 없음: apr15619833 (모든 경로 검색 완료)
# ⚠️ [202] 폴더 없음: apr15621473 (모든 경로 검색 완료)
# ⚠️ [203] 폴더 없음: apr15627090 (모든 경로 검색 완료)
# ⚠️ [204] 폴더 없음: apr15630438 (모든 경로 검색 완료)
# ⚠️ [205] 폴더 없음: apr15630039 (모든 경로 검색 완료)
# ⚠️ [206] 폴더 없음: apr15635917 (모든 경로 검색 완료)
# ⚠️ [207] 폴더 없음: apr15637260 (모든 경로 검색 완료)
# ⚠️ [208] 폴더 없음: apr15640167 (모든 경로 검색 완료)
# ⚠️ [209] 폴더 없음: apr15646030 (모든 경로 검색 완료)
# ⚠️ [210] 폴더 없음: apr15646240 (모든 경로 검색 완료)
# ⚠️ [211] 폴더 없음: apr15646187 (모든 경로 검색 완료)
# ⚠️ [212] 폴더 없음: apr15645920 (모든 경로 검색 완료)
# ⚠️ [213] 폴더 없음: apr15642122 (모든 경로 검색 완료)
# ⚠️ [214] 폴더 없음: apr15645550 (모든 경로 검색 완료)
# ⚠️ [215] 폴더 없음: apr15655348 (모든 경로 검색 완료)
#
# 📄 [216] 문서ID: 15654748
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15654748
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15654748
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [217] 폴더 없음: apr15664432 (모든 경로 검색 완료)
# ⚠️ [218] 폴더 없음: apr15666951 (모든 경로 검색 완료)
# ⚠️ [219] 폴더 없음: apr15665643 (모든 경로 검색 완료)
# ⚠️ [220] 폴더 없음: apr15673391 (모든 경로 검색 완료)
# ⚠️ [221] 폴더 없음: apr15670440 (모든 경로 검색 완료)
# ⚠️ [222] 폴더 없음: apr15670368 (모든 경로 검색 완료)
# ⚠️ [223] 폴더 없음: apr15678061 (모든 경로 검색 완료)
# ⚠️ [224] 폴더 없음: apr15688842 (모든 경로 검색 완료)
# ⚠️ [225] 폴더 없음: apr15688759 (모든 경로 검색 완료)
# ⚠️ [226] 폴더 없음: apr15688711 (모든 경로 검색 완료)
# ⚠️ [227] 폴더 없음: apr15690007 (모든 경로 검색 완료)
# ⚠️ [228] 폴더 없음: apr15700398 (모든 경로 검색 완료)
# ⚠️ [229] 폴더 없음: apr15703997 (모든 경로 검색 완료)
# ⚠️ [230] 폴더 없음: apr15698390 (모든 경로 검색 완료)
# ⚠️ [231] 폴더 없음: apr15698279 (모든 경로 검색 완료)
# ⚠️ [232] 폴더 없음: apr15696529 (모든 경로 검색 완료)
# ⚠️ [233] 폴더 없음: apr15704380 (모든 경로 검색 완료)
# ⚠️ [234] 폴더 없음: apr15704439 (모든 경로 검색 완료)
# ⚠️ [235] 폴더 없음: apr15717209 (모든 경로 검색 완료)
# ⚠️ [236] 폴더 없음: apr15721062 (모든 경로 검색 완료)
# ⚠️ [237] 폴더 없음: apr15718815 (모든 경로 검색 완료)
# ⚠️ [238] 폴더 없음: apr15721578 (모든 경로 검색 완료)
# ⚠️ [239] 폴더 없음: apr15723250 (모든 경로 검색 완료)
# ⚠️ [240] 폴더 없음: apr15732937 (모든 경로 검색 완료)
#
# 📄 [241] 문서ID: 15744992
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15744992
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15744992
#    ✅ 이미지 3개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#    📊 복사 완료: 3/3개
# ⚠️ [242] 폴더 없음: apr15738302 (모든 경로 검색 완료)
# ⚠️ [243] 폴더 없음: apr15738561 (모든 경로 검색 완료)
# ⚠️ [244] 폴더 없음: apr15744997 (모든 경로 검색 완료)
# ⚠️ [245] 폴더 없음: apr15742849 (모든 경로 검색 완료)
# ⚠️ [246] 폴더 없음: apr15746447 (모든 경로 검색 완료)
# ⚠️ [247] 폴더 없음: apr15746476 (모든 경로 검색 완료)
# ⚠️ [248] 폴더 없음: apr15738065 (모든 경로 검색 완료)
# ⚠️ [249] 폴더 없음: apr15748264 (모든 경로 검색 완료)
# ⚠️ [250] 폴더 없음: apr15747068 (모든 경로 검색 완료)
# ⚠️ [251] 폴더 없음: apr15747963 (모든 경로 검색 완료)
# ⚠️ [252] 폴더 없음: apr15750635 (모든 경로 검색 완료)
# ⚠️ [253] 폴더 없음: apr15749860 (모든 경로 검색 완료)
# ⚠️ [254] 폴더 없음: apr15747972 (모든 경로 검색 완료)
# ⚠️ [255] 폴더 없음: apr15749134 (모든 경로 검색 완료)
# ⚠️ [256] 폴더 없음: apr15750266 (모든 경로 검색 완료)
# ⚠️ [257] 폴더 없음: apr15752761 (모든 경로 검색 완료)
# ⚠️ [258] 폴더 없음: apr15760104 (모든 경로 검색 완료)
# ⚠️ [259] 폴더 없음: apr15759731 (모든 경로 검색 완료)
# ⚠️ [260] 폴더 없음: apr15762007 (모든 경로 검색 완료)
# ⚠️ [261] 폴더 없음: apr15764930 (모든 경로 검색 완료)
# ⚠️ [262] 폴더 없음: apr15765144 (모든 경로 검색 완료)
#
# 📄 [263] 문서ID: 15774451
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15774451
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15774451
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [264] 폴더 없음: apr15781758 (모든 경로 검색 완료)
# ⚠️ [265] 폴더 없음: apr15783382 (모든 경로 검색 완료)
#
# 📄 [266] 문서ID: 15791376
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15791376
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15791376
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [267] 폴더 없음: apr15786270 (모든 경로 검색 완료)
# ⚠️ [268] 폴더 없음: apr15799823 (모든 경로 검색 완료)
# ⚠️ [269] 폴더 없음: apr15796734 (모든 경로 검색 완료)
# ⚠️ [270] 폴더 없음: apr15807093 (모든 경로 검색 완료)
# ⚠️ [271] 폴더 없음: apr15804139 (모든 경로 검색 완료)
# ⚠️ [272] 폴더 없음: apr15807741 (모든 경로 검색 완료)
# ⚠️ [273] 폴더 없음: apr15813813 (모든 경로 검색 완료)
# ⚠️ [274] 폴더 없음: apr15811357 (모든 경로 검색 완료)
# ⚠️ [275] 폴더 없음: apr15823653 (모든 경로 검색 완료)
# ⚠️ [276] 폴더 없음: apr15820689 (모든 경로 검색 완료)
# ⚠️ [277] 폴더 없음: apr15817617 (모든 경로 검색 완료)
# ⚠️ [278] 폴더 없음: apr15833815 (모든 경로 검색 완료)
# ⚠️ [279] 폴더 없음: apr15826777 (모든 경로 검색 완료)
# ⚠️ [280] 폴더 없음: apr15829825 (모든 경로 검색 완료)
# ⚠️ [281] 폴더 없음: apr15827074 (모든 경로 검색 완료)
#
# 📄 [282] 문서ID: 15834348
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15834348
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15834348
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [283] 폴더 없음: apr15836981 (모든 경로 검색 완료)
# ⚠️ [284] 폴더 없음: apr15834399 (모든 경로 검색 완료)
# ⚠️ [285] 폴더 없음: apr15840015 (모든 경로 검색 완료)
# ⚠️ [286] 폴더 없음: apr15842049 (모든 경로 검색 완료)
# ⚠️ [287] 폴더 없음: apr15849526 (모든 경로 검색 완료)
# ⚠️ [288] 폴더 없음: apr15842305 (모든 경로 검색 완료)
# ⚠️ [289] 폴더 없음: apr15849584 (모든 경로 검색 완료)
# ⚠️ [290] 폴더 없음: apr15851725 (모든 경로 검색 완료)
# ⚠️ [291] 폴더 없음: apr15850631 (모든 경로 검색 완료)
# ⚠️ [292] 폴더 없음: apr15852361 (모든 경로 검색 완료)
# ⚠️ [293] 폴더 없음: apr15850672 (모든 경로 검색 완료)
# ⚠️ [294] 폴더 없음: apr15869326 (모든 경로 검색 완료)
# ⚠️ [295] 폴더 없음: apr15862400 (모든 경로 검색 완료)
# ⚠️ [296] 폴더 없음: apr15865691 (모든 경로 검색 완료)
# ⚠️ [297] 폴더 없음: apr15871474 (모든 경로 검색 완료)
# ⚠️ [298] 폴더 없음: apr15875688 (모든 경로 검색 완료)
# ⚠️ [299] 폴더 없음: apr15870773 (모든 경로 검색 완료)
# ⚠️ [300] 폴더 없음: apr15873929 (모든 경로 검색 완료)
# ⚠️ [301] 폴더 없음: apr15873021 (모든 경로 검색 완료)
# ⚠️ [302] 폴더 없음: apr15872028 (모든 경로 검색 완료)
# ⚠️ [303] 폴더 없음: apr15877309 (모든 경로 검색 완료)
# ⚠️ [304] 폴더 없음: apr15875555 (모든 경로 검색 완료)
# ⚠️ [305] 폴더 없음: apr15882494 (모든 경로 검색 완료)
# ⚠️ [306] 폴더 없음: apr15879959 (모든 경로 검색 완료)
# ⚠️ [307] 폴더 없음: apr15883893 (모든 경로 검색 완료)
# ⚠️ [308] 폴더 없음: apr15880707 (모든 경로 검색 완료)
# ⚠️ [309] 폴더 없음: apr15905470 (모든 경로 검색 완료)
# ⚠️ [310] 폴더 없음: apr15900408 (모든 경로 검색 완료)
# ⚠️ [311] 폴더 없음: apr15902607 (모든 경로 검색 완료)
# ⚠️ [312] 폴더 없음: apr15903380 (모든 경로 검색 완료)
# ⚠️ [313] 폴더 없음: apr15899777 (모든 경로 검색 완료)
# ⚠️ [314] 폴더 없음: apr15911671 (모든 경로 검색 완료)
# ⚠️ [315] 폴더 없음: apr15913590 (모든 경로 검색 완료)
# ⚠️ [316] 폴더 없음: apr15916628 (모든 경로 검색 완료)
# ⚠️ [317] 폴더 없음: apr15922959 (모든 경로 검색 완료)
# ⚠️ [318] 폴더 없음: apr15918541 (모든 경로 검색 완료)
# ⚠️ [319] 폴더 없음: apr15917148 (모든 경로 검색 완료)
# ⚠️ [320] 폴더 없음: apr15920805 (모든 경로 검색 완료)
# ⚠️ [321] 폴더 없음: apr15926295 (모든 경로 검색 완료)
# ⚠️ [322] 폴더 없음: apr15928342 (모든 경로 검색 완료)
# ⚠️ [323] 폴더 없음: apr15928229 (모든 경로 검색 완료)
# ⚠️ [324] 폴더 없음: apr15928257 (모든 경로 검색 완료)
# ⚠️ [325] 폴더 없음: apr15925527 (모든 경로 검색 완료)
# ⚠️ [326] 폴더 없음: apr15925386 (모든 경로 검색 완료)
# ⚠️ [327] 폴더 없음: apr15929792 (모든 경로 검색 완료)
# ⚠️ [328] 폴더 없음: apr15947160 (모든 경로 검색 완료)
# ⚠️ [329] 폴더 없음: apr15946039 (모든 경로 검색 완료)
#
# 📄 [330] 문서ID: 15942504
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15942504
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15942504
#    ✅ 이미지 4개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#       ✅ 3 → 3.jpg
#    📊 복사 완료: 4/4개
# ⚠️ [331] 폴더 없음: apr15940835 (모든 경로 검색 완료)
# ⚠️ [332] 폴더 없음: apr15945736 (모든 경로 검색 완료)
# ⚠️ [333] 폴더 없음: apr15952726 (모든 경로 검색 완료)
# ⚠️ [334] 폴더 없음: apr15954943 (모든 경로 검색 완료)
# ⚠️ [335] 폴더 없음: apr15963208 (모든 경로 검색 완료)
#
# 📄 [336] 문서ID: 15961394
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15961394
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15961394
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [337] 폴더 없음: apr15960313 (모든 경로 검색 완료)
# ⚠️ [338] 폴더 없음: apr15961995 (모든 경로 검색 완료)
# ⚠️ [339] 폴더 없음: apr15963761 (모든 경로 검색 완료)
# ⚠️ [340] 폴더 없음: apr15958511 (모든 경로 검색 완료)
# ⚠️ [341] 폴더 없음: apr15963163 (모든 경로 검색 완료)
# ⚠️ [342] 폴더 없음: apr15973322 (모든 경로 검색 완료)
#
# 📄 [343] 문서ID: 15978061
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15978061
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15978061
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [344] 폴더 없음: apr15979839 (모든 경로 검색 완료)
#
# 📄 [345] 문서ID: 15984267
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15984267
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15984267
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [346] 폴더 없음: apr15984017 (모든 경로 검색 완료)
# ⚠️ [347] 폴더 없음: apr15994129 (모든 경로 검색 완료)
#
# 📄 [348] 문서ID: 15995542
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr15995542
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr15995542
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [349] 폴더 없음: apr15993168 (모든 경로 검색 완료)
# ⚠️ [350] 폴더 없음: apr15994205 (모든 경로 검색 완료)
# ⚠️ [351] 폴더 없음: apr16002993 (모든 경로 검색 완료)
# ⚠️ [352] 폴더 없음: apr16002098 (모든 경로 검색 완료)
# ⚠️ [353] 폴더 없음: apr15999958 (모든 경로 검색 완료)
# ⚠️ [354] 폴더 없음: apr16009666 (모든 경로 검색 완료)
# ⚠️ [355] 폴더 없음: apr16008100 (모든 경로 검색 완료)
#
# 📄 [356] 문서ID: 16012259
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16012259
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16012259
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [357] 폴더 없음: apr16024308 (모든 경로 검색 완료)
#
# 📄 [358] 문서ID: 16019692
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16019692
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16019692
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [359] 폴더 없음: apr16024443 (모든 경로 검색 완료)
# ⚠️ [360] 폴더 없음: apr16024407 (모든 경로 검색 완료)
# ⚠️ [361] 폴더 없음: apr16018357 (모든 경로 검색 완료)
# ⚠️ [362] 폴더 없음: apr16015404 (모든 경로 검색 완료)
# ⚠️ [363] 폴더 없음: apr16015703 (모든 경로 검색 완료)
# ⚠️ [364] 폴더 없음: apr16016413 (모든 경로 검색 완료)
# ⚠️ [365] 폴더 없음: apr16018375 (모든 경로 검색 완료)
# ⚠️ [366] 폴더 없음: apr16024978 (모든 경로 검색 완료)
#
# 📄 [367] 문서ID: 16028718
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16028718
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16028718
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [368] 폴더 없음: apr16027151 (모든 경로 검색 완료)
# ⚠️ [369] 폴더 없음: apr16031162 (모든 경로 검색 완료)
# ⚠️ [370] 폴더 없음: apr16037844 (모든 경로 검색 완료)
# ⚠️ [371] 폴더 없음: apr16038293 (모든 경로 검색 완료)
# ⚠️ [372] 폴더 없음: apr16034390 (모든 경로 검색 완료)
# ⚠️ [373] 폴더 없음: apr16040266 (모든 경로 검색 완료)
# ⚠️ [374] 폴더 없음: apr16044473 (모든 경로 검색 완료)
# ⚠️ [375] 폴더 없음: apr16051408 (모든 경로 검색 완료)
# ⚠️ [376] 폴더 없음: apr16057125 (모든 경로 검색 완료)
# ⚠️ [377] 폴더 없음: apr16062054 (모든 경로 검색 완료)
# ⚠️ [378] 폴더 없음: apr16061546 (모든 경로 검색 완료)
# ⚠️ [379] 폴더 없음: apr16066123 (모든 경로 검색 완료)
# ⚠️ [380] 폴더 없음: apr16069651 (모든 경로 검색 완료)
# ⚠️ [381] 폴더 없음: apr16068037 (모든 경로 검색 완료)
# ⚠️ [382] 폴더 없음: apr16066921 (모든 경로 검색 완료)
# ⚠️ [383] 폴더 없음: apr16062699 (모든 경로 검색 완료)
# ⚠️ [384] 폴더 없음: apr16060848 (모든 경로 검색 완료)
# ⚠️ [385] 폴더 없음: apr16071450 (모든 경로 검색 완료)
# ⚠️ [386] 폴더 없음: apr16070446 (모든 경로 검색 완료)
# ⚠️ [387] 폴더 없음: apr16074598 (모든 경로 검색 완료)
# ⚠️ [388] 폴더 없음: apr16075510 (모든 경로 검색 완료)
# ⚠️ [389] 폴더 없음: apr16070642 (모든 경로 검색 완료)
# ⚠️ [390] 폴더 없음: apr16075399 (모든 경로 검색 완료)
# ⚠️ [391] 폴더 없음: apr16079135 (모든 경로 검색 완료)
# ⚠️ [392] 폴더 없음: apr16081048 (모든 경로 검색 완료)
# ⚠️ [393] 폴더 없음: apr16080595 (모든 경로 검색 완료)
# ⚠️ [394] 폴더 없음: apr16088177 (모든 경로 검색 완료)
# ⚠️ [395] 폴더 없음: apr16088285 (모든 경로 검색 완료)
# ⚠️ [396] 폴더 없음: apr16087112 (모든 경로 검색 완료)
# ⚠️ [397] 폴더 없음: apr16087071 (모든 경로 검색 완료)
# ⚠️ [398] 폴더 없음: apr16093483 (모든 경로 검색 완료)
# ⚠️ [399] 폴더 없음: apr16093904 (모든 경로 검색 완료)
# ⚠️ [400] 폴더 없음: apr16094756 (모든 경로 검색 완료)
#
# 📄 [401] 문서ID: 16099960
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16099960
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16099960
#    ✅ 이미지 3개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#    📊 복사 완료: 3/3개
# ⚠️ [402] 폴더 없음: apr16099327 (모든 경로 검색 완료)
#
# 📄 [403] 문서ID: 16107594
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16107594
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16107594
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [404] 폴더 없음: apr16106152 (모든 경로 검색 완료)
# ⚠️ [405] 폴더 없음: apr16106657 (모든 경로 검색 완료)
# ⚠️ [406] 폴더 없음: apr16103832 (모든 경로 검색 완료)
# ⚠️ [407] 폴더 없음: apr16107131 (모든 경로 검색 완료)
# ⚠️ [408] 폴더 없음: apr16110803 (모든 경로 검색 완료)
# ⚠️ [409] 폴더 없음: apr16128844 (모든 경로 검색 완료)
# ⚠️ [410] 폴더 없음: apr16127362 (모든 경로 검색 완료)
# ⚠️ [411] 폴더 없음: apr16138069 (모든 경로 검색 완료)
# ⚠️ [412] 폴더 없음: apr16133975 (모든 경로 검색 완료)
# ⚠️ [413] 폴더 없음: apr16137360 (모든 경로 검색 완료)
# ⚠️ [414] 폴더 없음: apr16139408 (모든 경로 검색 완료)
#
# 📄 [415] 문서ID: 16145504
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16145504
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16145504
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [416] 폴더 없음: apr16142551 (모든 경로 검색 완료)
# ⚠️ [417] 폴더 없음: apr16146186 (모든 경로 검색 완료)
# ⚠️ [418] 폴더 없음: apr16143114 (모든 경로 검색 완료)
# ⚠️ [419] 폴더 없음: apr16150011 (모든 경로 검색 완료)
# ⚠️ [420] 폴더 없음: apr16141766 (모든 경로 검색 완료)
# ⚠️ [421] 폴더 없음: apr16153436 (모든 경로 검색 완료)
# ⚠️ [422] 폴더 없음: apr16154143 (모든 경로 검색 완료)
# ⚠️ [423] 폴더 없음: apr16155153 (모든 경로 검색 완료)
# ⚠️ [424] 폴더 없음: apr16154985 (모든 경로 검색 완료)
# ⚠️ [425] 폴더 없음: apr16152979 (모든 경로 검색 완료)
# ⚠️ [426] 폴더 없음: apr16150576 (모든 경로 검색 완료)
# ⚠️ [427] 폴더 없음: apr16153645 (모든 경로 검색 완료)
# ⚠️ [428] 폴더 없음: apr16154200 (모든 경로 검색 완료)
# ⚠️ [429] 폴더 없음: apr16161555 (모든 경로 검색 완료)
# ⚠️ [430] 폴더 없음: apr16161057 (모든 경로 검색 완료)
# ⚠️ [431] 폴더 없음: apr16158555 (모든 경로 검색 완료)
# ⚠️ [432] 폴더 없음: apr16170194 (모든 경로 검색 완료)
# ⚠️ [433] 폴더 없음: apr16166748 (모든 경로 검색 완료)
#
# 📄 [434] 문서ID: 16168874
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16168874
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16168874
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [435] 폴더 없음: apr16167302 (모든 경로 검색 완료)
# ⚠️ [436] 폴더 없음: apr16170363 (모든 경로 검색 완료)
# ⚠️ [437] 폴더 없음: apr16177010 (모든 경로 검색 완료)
# ⚠️ [438] 폴더 없음: apr16177040 (모든 경로 검색 완료)
# ⚠️ [439] 폴더 없음: apr16177069 (모든 경로 검색 완료)
# ⚠️ [440] 폴더 없음: apr16177090 (모든 경로 검색 완료)
# ⚠️ [441] 폴더 없음: apr16175008 (모든 경로 검색 완료)
#
# 📄 [442] 문서ID: 16175507
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16175507
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16175507
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [443] 폴더 없음: apr16173630 (모든 경로 검색 완료)
# ⚠️ [444] 폴더 없음: apr16174540 (모든 경로 검색 완료)
# ⚠️ [445] 폴더 없음: apr16179184 (모든 경로 검색 완료)
# ⚠️ [446] 폴더 없음: apr16173699 (모든 경로 검색 완료)
# ⚠️ [447] 폴더 없음: apr16176419 (모든 경로 검색 완료)
# ⚠️ [448] 폴더 없음: apr16181382 (모든 경로 검색 완료)
# ⚠️ [449] 폴더 없음: apr16181959 (모든 경로 검색 완료)
# ⚠️ [450] 폴더 없음: apr16184061 (모든 경로 검색 완료)
# ⚠️ [451] 폴더 없음: apr16186338 (모든 경로 검색 완료)
# ⚠️ [452] 폴더 없음: apr16186469 (모든 경로 검색 완료)
# ⚠️ [453] 폴더 없음: apr16183387 (모든 경로 검색 완료)
# ⚠️ [454] 폴더 없음: apr16188718 (모든 경로 검색 완료)
# ⚠️ [455] 폴더 없음: apr16195171 (모든 경로 검색 완료)
# ⚠️ [456] 폴더 없음: apr16195190 (모든 경로 검색 완료)
# ⚠️ [457] 폴더 없음: apr16195212 (모든 경로 검색 완료)
#
# 📄 [458] 문서ID: 16194413
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16194413
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16194413
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [459] 폴더 없음: apr16199203 (모든 경로 검색 완료)
# ⚠️ [460] 폴더 없음: apr16190948 (모든 경로 검색 완료)
# ⚠️ [461] 폴더 없음: apr16199199 (모든 경로 검색 완료)
# ⚠️ [462] 폴더 없음: apr16196583 (모든 경로 검색 완료)
# ⚠️ [463] 폴더 없음: apr16199126 (모든 경로 검색 완료)
# ⚠️ [464] 폴더 없음: apr16190983 (모든 경로 검색 완료)
# ⚠️ [465] 폴더 없음: apr16197908 (모든 경로 검색 완료)
# ⚠️ [466] 폴더 없음: apr16208111 (모든 경로 검색 완료)
# ⚠️ [467] 폴더 없음: apr16199633 (모든 경로 검색 완료)
# ⚠️ [468] 폴더 없음: apr16204396 (모든 경로 검색 완료)
# ⚠️ [469] 폴더 없음: apr16205030 (모든 경로 검색 완료)
# ⚠️ [470] 폴더 없음: apr16205057 (모든 경로 검색 완료)
# ⚠️ [471] 폴더 없음: apr16206345 (모든 경로 검색 완료)
# ⚠️ [472] 폴더 없음: apr16204236 (모든 경로 검색 완료)
# ⚠️ [473] 폴더 없음: apr16204944 (모든 경로 검색 완료)
# ⚠️ [474] 폴더 없음: apr16214055 (모든 경로 검색 완료)
# ⚠️ [475] 폴더 없음: apr16214097 (모든 경로 검색 완료)
# ⚠️ [476] 폴더 없음: apr16215743 (모든 경로 검색 완료)
# ⚠️ [477] 폴더 없음: apr16212134 (모든 경로 검색 완료)
# ⚠️ [478] 폴더 없음: apr16223432 (모든 경로 검색 완료)
# ⚠️ [479] 폴더 없음: apr16223480 (모든 경로 검색 완료)
# ⚠️ [480] 폴더 없음: apr16223508 (모든 경로 검색 완료)
# ⚠️ [481] 폴더 없음: apr16218527 (모든 경로 검색 완료)
# ⚠️ [482] 폴더 없음: apr16222759 (모든 경로 검색 완료)
# ⚠️ [483] 폴더 없음: apr16232882 (모든 경로 검색 완료)
# ⚠️ [484] 폴더 없음: apr16229309 (모든 경로 검색 완료)
# ⚠️ [485] 폴더 없음: apr16234389 (모든 경로 검색 완료)
# ⚠️ [486] 폴더 없음: apr16227810 (모든 경로 검색 완료)
# ⚠️ [487] 폴더 없음: apr16231680 (모든 경로 검색 완료)
# ⚠️ [488] 폴더 없음: apr16236948 (모든 경로 검색 완료)
# ⚠️ [489] 폴더 없음: apr16232226 (모든 경로 검색 완료)
# ⚠️ [490] 폴더 없음: apr16232788 (모든 경로 검색 완료)
# ⚠️ [491] 폴더 없음: apr16236952 (모든 경로 검색 완료)
# ⚠️ [492] 폴더 없음: apr16240936 (모든 경로 검색 완료)
# ⚠️ [493] 폴더 없음: apr16242932 (모든 경로 검색 완료)
# ⚠️ [494] 폴더 없음: apr16243145 (모든 경로 검색 완료)
# ⚠️ [495] 폴더 없음: apr16251043 (모든 경로 검색 완료)
# ⚠️ [496] 폴더 없음: apr16251131 (모든 경로 검색 완료)
# ⚠️ [497] 폴더 없음: apr16253436 (모든 경로 검색 완료)
# ⚠️ [498] 폴더 없음: apr16246588 (모든 경로 검색 완료)
# ⚠️ [499] 폴더 없음: apr16246656 (모든 경로 검색 완료)
# ⚠️ [500] 폴더 없음: apr16246418 (모든 경로 검색 완료)
# ⚠️ [501] 폴더 없음: apr16246660 (모든 경로 검색 완료)
# ⚠️ [502] 폴더 없음: apr16255248 (모든 경로 검색 완료)
# ⚠️ [503] 폴더 없음: apr16255365 (모든 경로 검색 완료)
# ⚠️ [504] 폴더 없음: apr16257697 (모든 경로 검색 완료)
# ⚠️ [505] 폴더 없음: apr16258422 (모든 경로 검색 완료)
# ⚠️ [506] 폴더 없음: apr16256094 (모든 경로 검색 완료)
# ⚠️ [507] 폴더 없음: apr16260414 (모든 경로 검색 완료)
# ⚠️ [508] 폴더 없음: apr16255121 (모든 경로 검색 완료)
# ⚠️ [509] 폴더 없음: apr16262848 (모든 경로 검색 완료)
# ⚠️ [510] 폴더 없음: apr16262862 (모든 경로 검색 완료)
# ⚠️ [511] 폴더 없음: apr16262881 (모든 경로 검색 완료)
# ⚠️ [512] 폴더 없음: apr16266084 (모든 경로 검색 완료)
# ⚠️ [513] 폴더 없음: apr16266032 (모든 경로 검색 완료)
# ⚠️ [514] 폴더 없음: apr16265494 (모든 경로 검색 완료)
# ⚠️ [515] 폴더 없음: apr16263053 (모든 경로 검색 완료)
# ⚠️ [516] 폴더 없음: apr16264156 (모든 경로 검색 완료)
#
# 📄 [517] 문서ID: 16278375
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16278375
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16278375
#    ✅ 이미지 3개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#    📊 복사 완료: 3/3개
# ⚠️ [518] 폴더 없음: apr16273776 (모든 경로 검색 완료)
# ⚠️ [519] 폴더 없음: apr16273612 (모든 경로 검색 완료)
# ⚠️ [520] 폴더 없음: apr16278676 (모든 경로 검색 완료)
# ⚠️ [521] 폴더 없음: apr16273278 (모든 경로 검색 완료)
# ⚠️ [522] 폴더 없음: apr16276370 (모든 경로 검색 완료)
# ⚠️ [523] 폴더 없음: apr16287459 (모든 경로 검색 완료)
#
# 📄 [524] 문서ID: 16284831
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16284831
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16284831
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [525] 폴더 없음: apr16284438 (모든 경로 검색 완료)
# ⚠️ [526] 폴더 없음: apr16289997 (모든 경로 검색 완료)
# ⚠️ [527] 폴더 없음: apr16288935 (모든 경로 검색 완료)
# ⚠️ [528] 폴더 없음: apr16295403 (모든 경로 검색 완료)
# ⚠️ [529] 폴더 없음: apr16289104 (모든 경로 검색 완료)
# ⚠️ [530] 폴더 없음: apr16297232 (모든 경로 검색 완료)
# ⚠️ [531] 폴더 없음: apr16297251 (모든 경로 검색 완료)
# ⚠️ [532] 폴더 없음: apr16299732 (모든 경로 검색 완료)
# ⚠️ [533] 폴더 없음: apr16299755 (모든 경로 검색 완료)
# ⚠️ [534] 폴더 없음: apr16299767 (모든 경로 검색 완료)
# ⚠️ [535] 폴더 없음: apr16299774 (모든 경로 검색 완료)
# ⚠️ [536] 폴더 없음: apr16302006 (모든 경로 검색 완료)
# ⚠️ [537] 폴더 없음: apr16296615 (모든 경로 검색 완료)
# ⚠️ [538] 폴더 없음: apr16307841 (모든 경로 검색 완료)
# ⚠️ [539] 폴더 없음: apr16307793 (모든 경로 검색 완료)
# ⚠️ [540] 폴더 없음: apr16308513 (모든 경로 검색 완료)
# ⚠️ [541] 폴더 없음: apr16308492 (모든 경로 검색 완료)
# ⚠️ [542] 폴더 없음: apr16307570 (모든 경로 검색 완료)
# ⚠️ [543] 폴더 없음: apr16307522 (모든 경로 검색 완료)
# ⚠️ [544] 폴더 없음: apr16318454 (모든 경로 검색 완료)
# ⚠️ [545] 폴더 없음: apr16321090 (모든 경로 검색 완료)
# ⚠️ [546] 폴더 없음: apr16316621 (모든 경로 검색 완료)
# ⚠️ [547] 폴더 없음: apr16313508 (모든 경로 검색 완료)
# ⚠️ [548] 폴더 없음: apr16314040 (모든 경로 검색 완료)
# ⚠️ [549] 폴더 없음: apr16321645 (모든 경로 검색 완료)
# ⚠️ [550] 폴더 없음: apr16321967 (모든 경로 검색 완료)
# ⚠️ [551] 폴더 없음: apr16323363 (모든 경로 검색 완료)
# ⚠️ [552] 폴더 없음: apr16331403 (모든 경로 검색 완료)
# ⚠️ [553] 폴더 없음: apr16331432 (모든 경로 검색 완료)
# ⚠️ [554] 폴더 없음: apr16333755 (모든 경로 검색 완료)
# ⚠️ [555] 폴더 없음: apr16331462 (모든 경로 검색 완료)
#
# 📄 [556] 문서ID: 16335084
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16335084
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16335084
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [557] 폴더 없음: apr16332149 (모든 경로 검색 완료)
# ⚠️ [558] 폴더 없음: apr16331119 (모든 경로 검색 완료)
# ⚠️ [559] 폴더 없음: apr16329792 (모든 경로 검색 완료)
# ⚠️ [560] 폴더 없음: apr16329973 (모든 경로 검색 완료)
# ⚠️ [561] 폴더 없음: apr16330492 (모든 경로 검색 완료)
# ⚠️ [562] 폴더 없음: apr16335720 (모든 경로 검색 완료)
# ⚠️ [563] 폴더 없음: apr16336927 (모든 경로 검색 완료)
# ⚠️ [564] 폴더 없음: apr16333908 (모든 경로 검색 완료)
# ⚠️ [565] 폴더 없음: apr16332910 (모든 경로 검색 완료)
# ⚠️ [566] 폴더 없음: apr16342260 (모든 경로 검색 완료)
#
# 📄 [567] 문서ID: 16343349
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16343349
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16343349
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [568] 폴더 없음: apr16338693 (모든 경로 검색 완료)
# ⚠️ [569] 폴더 없음: apr16340802 (모든 경로 검색 완료)
# ⚠️ [570] 폴더 없음: apr16344477 (모든 경로 검색 완료)
# ⚠️ [571] 폴더 없음: apr16337655 (모든 경로 검색 완료)
# ⚠️ [572] 폴더 없음: apr16339273 (모든 경로 검색 완료)
# ⚠️ [573] 폴더 없음: apr16347844 (모든 경로 검색 완료)
# ⚠️ [574] 폴더 없음: apr16347849 (모든 경로 검색 완료)
# ⚠️ [575] 폴더 없음: apr16350848 (모든 경로 검색 완료)
# ⚠️ [576] 폴더 없음: apr16350417 (모든 경로 검색 완료)
# ⚠️ [577] 폴더 없음: apr16347859 (모든 경로 검색 완료)
# ⚠️ [578] 폴더 없음: apr16349875 (모든 경로 검색 완료)
# ⚠️ [579] 폴더 없음: apr16353865 (모든 경로 검색 완료)
# ⚠️ [580] 폴더 없음: apr16358148 (모든 경로 검색 완료)
# ⚠️ [581] 폴더 없음: apr16360230 (모든 경로 검색 완료)
# ⚠️ [582] 폴더 없음: apr16358065 (모든 경로 검색 완료)
# ⚠️ [583] 폴더 없음: apr16354802 (모든 경로 검색 완료)
# ⚠️ [584] 폴더 없음: apr16354858 (모든 경로 검색 완료)
# ⚠️ [585] 폴더 없음: apr16360218 (모든 경로 검색 완료)
# ⚠️ [586] 폴더 없음: apr16368273 (모든 경로 검색 완료)
# ⚠️ [587] 폴더 없음: apr16365379 (모든 경로 검색 완료)
# ⚠️ [588] 폴더 없음: apr16364023 (모든 경로 검색 완료)
#
# 📄 [589] 문서ID: 16365590
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16365590
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16365590
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [590] 폴더 없음: apr16363883 (모든 경로 검색 완료)
# ⚠️ [591] 폴더 없음: apr16367617 (모든 경로 검색 완료)
# ⚠️ [592] 폴더 없음: apr16373582 (모든 경로 검색 완료)
# ⚠️ [593] 폴더 없음: apr16373614 (모든 경로 검색 완료)
# ⚠️ [594] 폴더 없음: apr16373656 (모든 경로 검색 완료)
# ⚠️ [595] 폴더 없음: apr16373689 (모든 경로 검색 완료)
# ⚠️ [596] 폴더 없음: apr16373701 (모든 경로 검색 완료)
# ⚠️ [597] 폴더 없음: apr16371433 (모든 경로 검색 완료)
# ⚠️ [598] 폴더 없음: apr16370407 (모든 경로 검색 완료)
# ⚠️ [599] 폴더 없음: apr16382238 (모든 경로 검색 완료)
# ⚠️ [600] 폴더 없음: apr16375259 (모든 경로 검색 완료)
# ⚠️ [601] 폴더 없음: apr16374007 (모든 경로 검색 완료)
# ⚠️ [602] 폴더 없음: apr16372147 (모든 경로 검색 완료)
# ⚠️ [603] 폴더 없음: apr16370286 (모든 경로 검색 완료)
# ⚠️ [604] 폴더 없음: apr16375956 (모든 경로 검색 완료)
# ⚠️ [605] 폴더 없음: apr16376569 (모든 경로 검색 완료)
# ⚠️ [606] 폴더 없음: apr16386536 (모든 경로 검색 완료)
# ⚠️ [607] 폴더 없음: apr16391956 (모든 경로 검색 완료)
# ⚠️ [608] 폴더 없음: apr16391985 (모든 경로 검색 완료)
# ⚠️ [609] 폴더 없음: apr16389740 (모든 경로 검색 완료)
# ⚠️ [610] 폴더 없음: apr16387279 (모든 경로 검색 완료)
# ⚠️ [611] 폴더 없음: apr16390893 (모든 경로 검색 완료)
# ⚠️ [612] 폴더 없음: apr16387931 (모든 경로 검색 완료)
# ⚠️ [613] 폴더 없음: apr16389664 (모든 경로 검색 완료)
# ⚠️ [614] 폴더 없음: apr16397653 (모든 경로 검색 완료)
# ⚠️ [615] 폴더 없음: apr16396522 (모든 경로 검색 완료)
# ⚠️ [616] 폴더 없음: apr16397721 (모든 경로 검색 완료)
# ⚠️ [617] 폴더 없음: apr16402505 (모든 경로 검색 완료)
# ⚠️ [618] 폴더 없음: apr16402566 (모든 경로 검색 완료)
# ⚠️ [619] 폴더 없음: apr16407993 (모든 경로 검색 완료)
# ⚠️ [620] 폴더 없음: apr16403803 (모든 경로 검색 완료)
# ⚠️ [621] 폴더 없음: apr16406835 (모든 경로 검색 완료)
# ⚠️ [622] 폴더 없음: apr16411146 (모든 경로 검색 완료)
# ⚠️ [623] 폴더 없음: apr16408716 (모든 경로 검색 완료)
# ⚠️ [624] 폴더 없음: apr16408817 (모든 경로 검색 완료)
# ⚠️ [625] 폴더 없음: apr16415290 (모든 경로 검색 완료)
# ⚠️ [626] 폴더 없음: apr16415357 (모든 경로 검색 완료)
# ⚠️ [627] 폴더 없음: apr16415381 (모든 경로 검색 완료)
# ⚠️ [628] 폴더 없음: apr16412196 (모든 경로 검색 완료)
# ⚠️ [629] 폴더 없음: apr16413376 (모든 경로 검색 완료)
# ⚠️ [630] 폴더 없음: apr16414650 (모든 경로 검색 완료)
# ⚠️ [631] 폴더 없음: apr16417041 (모든 경로 검색 완료)
# ⚠️ [632] 폴더 없음: apr16422064 (모든 경로 검색 완료)
# ⚠️ [633] 폴더 없음: apr16429268 (모든 경로 검색 완료)
# ⚠️ [634] 폴더 없음: apr16426138 (모든 경로 검색 완료)
# ⚠️ [635] 폴더 없음: apr16429257 (모든 경로 검색 완료)
# ⚠️ [636] 폴더 없음: apr16427367 (모든 경로 검색 완료)
# ⚠️ [637] 폴더 없음: apr16431997 (모든 경로 검색 완료)
# ⚠️ [638] 폴더 없음: apr16434651 (모든 경로 검색 완료)
# ⚠️ [639] 폴더 없음: apr16434683 (모든 경로 검색 완료)
# ⚠️ [640] 폴더 없음: apr16434707 (모든 경로 검색 완료)
# ⚠️ [641] 폴더 없음: apr16435557 (모든 경로 검색 완료)
# ⚠️ [642] 폴더 없음: apr16435656 (모든 경로 검색 완료)
# ⚠️ [643] 폴더 없음: apr16437136 (모든 경로 검색 완료)
# ⚠️ [644] 폴더 없음: apr16434009 (모든 경로 검색 완료)
# ⚠️ [645] 폴더 없음: apr16442755 (모든 경로 검색 완료)
# ⚠️ [646] 폴더 없음: apr16445414 (모든 경로 검색 완료)
# ⚠️ [647] 폴더 없음: apr16445424 (모든 경로 검색 완료)
# ⚠️ [648] 폴더 없음: apr16445388 (모든 경로 검색 완료)
# ⚠️ [649] 폴더 없음: apr16445409 (모든 경로 검색 완료)
# ⚠️ [650] 폴더 없음: apr16445469 (모든 경로 검색 완료)
# ⚠️ [651] 폴더 없음: apr16448567 (모든 경로 검색 완료)
# ⚠️ [652] 폴더 없음: apr16445443 (모든 경로 검색 완료)
# ⚠️ [653] 폴더 없음: apr16447913 (모든 경로 검색 완료)
# ⚠️ [654] 폴더 없음: apr16446919 (모든 경로 검색 완료)
# ⚠️ [655] 폴더 없음: apr16452173 (모든 경로 검색 완료)
# ⚠️ [656] 폴더 없음: apr16456285 (모든 경로 검색 완료)
# ⚠️ [657] 폴더 없음: apr16455373 (모든 경로 검색 완료)
# ⚠️ [658] 폴더 없음: apr16455387 (모든 경로 검색 완료)
# ⚠️ [659] 폴더 없음: apr16456143 (모든 경로 검색 완료)
# ⚠️ [660] 폴더 없음: apr16457537 (모든 경로 검색 완료)
#
# 📄 [661] 문서ID: 16453442
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16453442
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16453442
#    ✅ 이미지 3개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#    📊 복사 완료: 3/3개
# ⚠️ [662] 폴더 없음: apr16452436 (모든 경로 검색 완료)
# ⚠️ [663] 폴더 없음: apr16455524 (모든 경로 검색 완료)
# ⚠️ [664] 폴더 없음: apr16461011 (모든 경로 검색 완료)
# ⚠️ [665] 폴더 없음: apr16460300 (모든 경로 검색 완료)
# ⚠️ [666] 폴더 없음: apr16462197 (모든 경로 검색 완료)
# ⚠️ [667] 폴더 없음: apr16461963 (모든 경로 검색 완료)
# ⚠️ [668] 폴더 없음: apr16461631 (모든 경로 검색 완료)
# ⚠️ [669] 폴더 없음: apr16460080 (모든 경로 검색 완료)
# ⚠️ [670] 폴더 없음: apr16466639 (모든 경로 검색 완료)
# ⚠️ [671] 폴더 없음: apr16463146 (모든 경로 검색 완료)
# ⚠️ [672] 폴더 없음: apr16460249 (모든 경로 검색 완료)
# ⚠️ [673] 폴더 없음: apr16462062 (모든 경로 검색 완료)
#
# 📄 [674] 문서ID: 16470079
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16470079
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16470079
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [675] 폴더 없음: apr16470566 (모든 경로 검색 완료)
# ⚠️ [676] 폴더 없음: apr16470739 (모든 경로 검색 완료)
# ⚠️ [677] 폴더 없음: apr16475353 (모든 경로 검색 완료)
# ⚠️ [678] 폴더 없음: apr16475370 (모든 경로 검색 완료)
# ⚠️ [679] 폴더 없음: apr16475385 (모든 경로 검색 완료)
# ⚠️ [680] 폴더 없음: apr16476289 (모든 경로 검색 완료)
# ⚠️ [681] 폴더 없음: apr16477939 (모든 경로 검색 완료)
# ⚠️ [682] 폴더 없음: apr16483193 (모든 경로 검색 완료)
# ⚠️ [683] 폴더 없음: apr16487003 (모든 경로 검색 완료)
# ⚠️ [684] 폴더 없음: apr16485373 (모든 경로 검색 완료)
# ⚠️ [685] 폴더 없음: apr16483584 (모든 경로 검색 완료)
# ⚠️ [686] 폴더 없음: apr16483425 (모든 경로 검색 완료)
# ⚠️ [687] 폴더 없음: apr16492612 (모든 경로 검색 완료)
# ⚠️ [688] 폴더 없음: apr16502541 (모든 경로 검색 완료)
# ⚠️ [689] 폴더 없음: apr16500019 (모든 경로 검색 완료)
# ⚠️ [690] 폴더 없음: apr16500510 (모든 경로 검색 완료)
# ⚠️ [691] 폴더 없음: apr16501064 (모든 경로 검색 완료)
# ⚠️ [692] 폴더 없음: apr16501902 (모든 경로 검색 완료)
# ⚠️ [693] 폴더 없음: apr16500040 (모든 경로 검색 완료)
# ⚠️ [694] 폴더 없음: apr16501529 (모든 경로 검색 완료)
# ⚠️ [695] 폴더 없음: apr16504675 (모든 경로 검색 완료)
# ⚠️ [696] 폴더 없음: apr16504387 (모든 경로 검색 완료)
# ⚠️ [697] 폴더 없음: apr16509241 (모든 경로 검색 완료)
# ⚠️ [698] 폴더 없음: apr16509261 (모든 경로 검색 완료)
# ⚠️ [699] 폴더 없음: apr16509285 (모든 경로 검색 완료)
# ⚠️ [700] 폴더 없음: apr16509307 (모든 경로 검색 완료)
#
# 📄 [701] 문서ID: 16508596
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16508596
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16508596
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [702] 폴더 없음: apr16507876 (모든 경로 검색 완료)
# ⚠️ [703] 폴더 없음: apr16509891 (모든 경로 검색 완료)
# ⚠️ [704] 폴더 없음: apr16510138 (모든 경로 검색 완료)
# ⚠️ [705] 폴더 없음: apr16514050 (모든 경로 검색 완료)
# ⚠️ [706] 폴더 없음: apr16509088 (모든 경로 검색 완료)
# ⚠️ [707] 폴더 없음: apr16521098 (모든 경로 검색 완료)
# ⚠️ [708] 폴더 없음: apr16521345 (모든 경로 검색 완료)
# ⚠️ [709] 폴더 없음: apr16517269 (모든 경로 검색 완료)
# ⚠️ [710] 폴더 없음: apr16517588 (모든 경로 검색 완료)
# ⚠️ [711] 폴더 없음: apr16518756 (모든 경로 검색 완료)
# ⚠️ [712] 폴더 없음: apr16519460 (모든 경로 검색 완료)
# ⚠️ [713] 폴더 없음: apr16528622 (모든 경로 검색 완료)
# ⚠️ [714] 폴더 없음: apr16529116 (모든 경로 검색 완료)
# ⚠️ [715] 폴더 없음: apr16528832 (모든 경로 검색 완료)
#
# 📄 [716] 문서ID: 16531496
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16531496
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16531496
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [717] 폴더 없음: apr16524991 (모든 경로 검색 완료)
# ⚠️ [718] 폴더 없음: apr16530796 (모든 경로 검색 완료)
# ⚠️ [719] 폴더 없음: apr16524854 (모든 경로 검색 완료)
# ⚠️ [720] 폴더 없음: apr16528333 (모든 경로 검색 완료)
# ⚠️ [721] 폴더 없음: apr16534561 (모든 경로 검색 완료)
# ⚠️ [722] 폴더 없음: apr16533567 (모든 경로 검색 완료)
# ⚠️ [723] 폴더 없음: apr16533601 (모든 경로 검색 완료)
# ⚠️ [724] 폴더 없음: apr16533629 (모든 경로 검색 완료)
# ⚠️ [725] 폴더 없음: apr16533650 (모든 경로 검색 완료)
# ⚠️ [726] 폴더 없음: apr16536224 (모든 경로 검색 완료)
# ⚠️ [727] 폴더 없음: apr16537961 (모든 경로 검색 완료)
# ⚠️ [728] 폴더 없음: apr16533250 (모든 경로 검색 완료)
# ⚠️ [729] 폴더 없음: apr16533442 (모든 경로 검색 완료)
# ⚠️ [730] 폴더 없음: apr16534640 (모든 경로 검색 완료)
# ⚠️ [731] 폴더 없음: apr16546339 (모든 경로 검색 완료)
# ⚠️ [732] 폴더 없음: apr16541153 (모든 경로 검색 완료)
# ⚠️ [733] 폴더 없음: apr16541196 (모든 경로 검색 완료)
# ⚠️ [734] 폴더 없음: apr16545727 (모든 경로 검색 완료)
# ⚠️ [735] 폴더 없음: apr16541524 (모든 경로 검색 완료)
# ⚠️ [736] 폴더 없음: apr16543172 (모든 경로 검색 완료)
# ⚠️ [737] 폴더 없음: apr16552560 (모든 경로 검색 완료)
# ⚠️ [738] 폴더 없음: apr16552282 (모든 경로 검색 완료)
# ⚠️ [739] 폴더 없음: apr16552199 (모든 경로 검색 완료)
# ⚠️ [740] 폴더 없음: apr16548875 (모든 경로 검색 완료)
# ⚠️ [741] 폴더 없음: apr16548251 (모든 경로 검색 완료)
# ⚠️ [742] 폴더 없음: apr16556491 (모든 경로 검색 완료)
#
# 📄 [743] 문서ID: 16556761
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16556761
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16556761
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [744] 폴더 없음: apr16559754 (모든 경로 검색 완료)
# ⚠️ [745] 폴더 없음: apr16557747 (모든 경로 검색 완료)
# ⚠️ [746] 폴더 없음: apr16564817 (모든 경로 검색 완료)
# ⚠️ [747] 폴더 없음: apr16560189 (모든 경로 검색 완료)
# ⚠️ [748] 폴더 없음: apr16566509 (모든 경로 검색 완료)
# ⚠️ [749] 폴더 없음: apr16566550 (모든 경로 검색 완료)
# ⚠️ [750] 폴더 없음: apr16565637 (모든 경로 검색 완료)
# ⚠️ [751] 폴더 없음: apr16565555 (모든 경로 검색 완료)
# ⚠️ [752] 폴더 없음: apr16575229 (모든 경로 검색 완료)
# ⚠️ [753] 폴더 없음: apr16573988 (모든 경로 검색 완료)
# ⚠️ [754] 폴더 없음: apr16579114 (모든 경로 검색 완료)
# ⚠️ [755] 폴더 없음: apr16577766 (모든 경로 검색 완료)
# ⚠️ [756] 폴더 없음: apr16586706 (모든 경로 검색 완료)
# ⚠️ [757] 폴더 없음: apr16584259 (모든 경로 검색 완료)
# ⚠️ [758] 폴더 없음: apr16590692 (모든 경로 검색 완료)
# ⚠️ [759] 폴더 없음: apr16590330 (모든 경로 검색 완료)
# ⚠️ [760] 폴더 없음: apr16583597 (모든 경로 검색 완료)
# ⚠️ [761] 폴더 없음: apr16585074 (모든 경로 검색 완료)
# ⚠️ [762] 폴더 없음: apr16594741 (모든 경로 검색 완료)
# ⚠️ [763] 폴더 없음: apr16595254 (모든 경로 검색 완료)
# ⚠️ [764] 폴더 없음: apr16595272 (모든 경로 검색 완료)
# ⚠️ [765] 폴더 없음: apr16595287 (모든 경로 검색 완료)
# ⚠️ [766] 폴더 없음: apr16596291 (모든 경로 검색 완료)
# ⚠️ [767] 폴더 없음: apr16601708 (모든 경로 검색 완료)
# ⚠️ [768] 폴더 없음: apr16603408 (모든 경로 검색 완료)
# ⚠️ [769] 폴더 없음: apr16602193 (모든 경로 검색 완료)
# ⚠️ [770] 폴더 없음: apr16602787 (모든 경로 검색 완료)
# ⚠️ [771] 폴더 없음: apr16614899 (모든 경로 검색 완료)
# ⚠️ [772] 폴더 없음: apr16614814 (모든 경로 검색 완료)
# ⚠️ [773] 폴더 없음: apr16625666 (모든 경로 검색 완료)
# ⚠️ [774] 폴더 없음: apr16622515 (모든 경로 검색 완료)
# ⚠️ [775] 폴더 없음: apr16622548 (모든 경로 검색 완료)
# ⚠️ [776] 폴더 없음: apr16622583 (모든 경로 검색 완료)
# ⚠️ [777] 폴더 없음: apr16621301 (모든 경로 검색 완료)
# ⚠️ [778] 폴더 없음: apr16623275 (모든 경로 검색 완료)
# ⚠️ [779] 폴더 없음: apr16623870 (모든 경로 검색 완료)
# ⚠️ [780] 폴더 없음: apr16631955 (모든 경로 검색 완료)
# ⚠️ [781] 폴더 없음: apr16633298 (모든 경로 검색 완료)
# ⚠️ [782] 폴더 없음: apr16632358 (모든 경로 검색 완료)
# ⚠️ [783] 폴더 없음: apr16630823 (모든 경로 검색 완료)
# ⚠️ [784] 폴더 없음: apr16630517 (모든 경로 검색 완료)
# ⚠️ [785] 폴더 없음: apr16630470 (모든 경로 검색 완료)
# ⚠️ [786] 폴더 없음: apr16639838 (모든 경로 검색 완료)
# ⚠️ [787] 폴더 없음: apr16639665 (모든 경로 검색 완료)
# ⚠️ [788] 폴더 없음: apr16638811 (모든 경로 검색 완료)
# ⚠️ [789] 폴더 없음: apr16639200 (모든 경로 검색 완료)
# ⚠️ [790] 폴더 없음: apr16640968 (모든 경로 검색 완료)
# ⚠️ [791] 폴더 없음: apr16639609 (모든 경로 검색 완료)
# ⚠️ [792] 폴더 없음: apr16639731 (모든 경로 검색 완료)
# ⚠️ [793] 폴더 없음: apr16644510 (모든 경로 검색 완료)
# ⚠️ [794] 폴더 없음: apr16651625 (모든 경로 검색 완료)
# ⚠️ [795] 폴더 없음: apr16648811 (모든 경로 검색 완료)
#
# 📄 [796] 문서ID: 16650669
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16650669
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16650669
#    ✅ 이미지 3개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#    📊 복사 완료: 3/3개
# ⚠️ [797] 폴더 없음: apr16651101 (모든 경로 검색 완료)
# ⚠️ [798] 폴더 없음: apr16647800 (모든 경로 검색 완료)
# ⚠️ [799] 폴더 없음: apr16656477 (모든 경로 검색 완료)
# ⚠️ [800] 폴더 없음: apr16657522 (모든 경로 검색 완료)
# ⚠️ [801] 폴더 없음: apr16657562 (모든 경로 검색 완료)
# ⚠️ [802] 폴더 없음: apr16657546 (모든 경로 검색 완료)
# ⚠️ [803] 폴더 없음: apr16654288 (모든 경로 검색 완료)
# ⚠️ [804] 폴더 없음: apr16657386 (모든 경로 검색 완료)
# ⚠️ [805] 폴더 없음: apr16656507 (모든 경로 검색 완료)
# ⚠️ [806] 폴더 없음: apr16662258 (모든 경로 검색 완료)
# ⚠️ [807] 폴더 없음: apr16665266 (모든 경로 검색 완료)
# ⚠️ [808] 폴더 없음: apr16665297 (모든 경로 검색 완료)
# ⚠️ [809] 폴더 없음: apr16665315 (모든 경로 검색 완료)
#
# 📄 [810] 문서ID: 16664515
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16664515
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16664515
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [811] 폴더 없음: apr16667174 (모든 경로 검색 완료)
# ⚠️ [812] 폴더 없음: apr16662509 (모든 경로 검색 완료)
# ⚠️ [813] 폴더 없음: apr16668857 (모든 경로 검색 완료)
# ⚠️ [814] 폴더 없음: apr16666125 (모든 경로 검색 완료)
# ⚠️ [815] 폴더 없음: apr16676907 (모든 경로 검색 완료)
# ⚠️ [816] 폴더 없음: apr16674817 (모든 경로 검색 완료)
# ⚠️ [817] 폴더 없음: apr16674511 (모든 경로 검색 완료)
# ⚠️ [818] 폴더 없음: apr16670226 (모든 경로 검색 완료)
# ⚠️ [819] 폴더 없음: apr16681177 (모든 경로 검색 완료)
# ⚠️ [820] 폴더 없음: apr16681200 (모든 경로 검색 완료)
# ⚠️ [821] 폴더 없음: apr16681218 (모든 경로 검색 완료)
# ⚠️ [822] 폴더 없음: apr16681237 (모든 경로 검색 완료)
# ⚠️ [823] 폴더 없음: apr16681253 (모든 경로 검색 완료)
# ⚠️ [824] 폴더 없음: apr16679697 (모든 경로 검색 완료)
# ⚠️ [825] 폴더 없음: apr16684216 (모든 경로 검색 완료)
# ⚠️ [826] 폴더 없음: apr16681358 (모든 경로 검색 완료)
# ⚠️ [827] 폴더 없음: apr16678540 (모든 경로 검색 완료)
# ⚠️ [828] 폴더 없음: apr16678593 (모든 경로 검색 완료)
# ⚠️ [829] 폴더 없음: apr16679540 (모든 경로 검색 완료)
# ⚠️ [830] 폴더 없음: apr16678716 (모든 경로 검색 완료)
# ⚠️ [831] 폴더 없음: apr16685376 (모든 경로 검색 완료)
#
# 📄 [832] 문서ID: 16688611
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16688611
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16688611
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
#
# 📄 [833] 문서ID: 16687257
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16687257
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16687257
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [834] 폴더 없음: apr16690603 (모든 경로 검색 완료)
# ⚠️ [835] 폴더 없음: apr16690703 (모든 경로 검색 완료)
# ⚠️ [836] 폴더 없음: apr16687513 (모든 경로 검색 완료)
# ⚠️ [837] 폴더 없음: apr16694245 (모든 경로 검색 완료)
# ⚠️ [838] 폴더 없음: apr16694408 (모든 경로 검색 완료)
# ⚠️ [839] 폴더 없음: apr16690900 (모든 경로 검색 완료)
# ⚠️ [840] 폴더 없음: apr16693821 (모든 경로 검색 완료)
#
# 📄 [841] 문서ID: 16700138
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16700138
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16700138
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [842] 폴더 없음: apr16701869 (모든 경로 검색 완료)
# ⚠️ [843] 폴더 없음: apr16696145 (모든 경로 검색 완료)
# ⚠️ [844] 폴더 없음: apr16697576 (모든 경로 검색 완료)
# ⚠️ [845] 폴더 없음: apr16707755 (모든 경로 검색 완료)
# ⚠️ [846] 폴더 없음: apr16707775 (모든 경로 검색 완료)
# ⚠️ [847] 폴더 없음: apr16703936 (모든 경로 검색 완료)
# ⚠️ [848] 폴더 없음: apr16705484 (모든 경로 검색 완료)
# ⚠️ [849] 폴더 없음: apr16710427 (모든 경로 검색 완료)
# ⚠️ [850] 폴더 없음: apr16704222 (모든 경로 검색 완료)
# ⚠️ [851] 폴더 없음: apr16718689 (모든 경로 검색 완료)
# ⚠️ [852] 폴더 없음: apr16718725 (모든 경로 검색 완료)
# ⚠️ [853] 폴더 없음: apr16718919 (모든 경로 검색 완료)
# ⚠️ [854] 폴더 없음: apr16716200 (모든 경로 검색 완료)
# ⚠️ [855] 폴더 없음: apr16715360 (모든 경로 검색 완료)
# ⚠️ [856] 폴더 없음: apr16713103 (모든 경로 검색 완료)
# ⚠️ [857] 폴더 없음: apr16715218 (모든 경로 검색 완료)
# ⚠️ [858] 폴더 없음: apr16722316 (모든 경로 검색 완료)
# ⚠️ [859] 폴더 없음: apr16722332 (모든 경로 검색 완료)
# ⚠️ [860] 폴더 없음: apr16722770 (모든 경로 검색 완료)
# ⚠️ [861] 폴더 없음: apr16727670 (모든 경로 검색 완료)
# ⚠️ [862] 폴더 없음: apr16728931 (모든 경로 검색 완료)
# ⚠️ [863] 폴더 없음: apr16721389 (모든 경로 검색 완료)
# ⚠️ [864] 폴더 없음: apr16723418 (모든 경로 검색 완료)
# ⚠️ [865] 폴더 없음: apr16725121 (모든 경로 검색 완료)
# ⚠️ [866] 폴더 없음: apr16725314 (모든 경로 검색 완료)
# ⚠️ [867] 폴더 없음: apr16728899 (모든 경로 검색 완료)
# ⚠️ [868] 폴더 없음: apr16721462 (모든 경로 검색 완료)
# ⚠️ [869] 폴더 없음: apr16723154 (모든 경로 검색 완료)
# ⚠️ [870] 폴더 없음: apr16731310 (모든 경로 검색 완료)
# ⚠️ [871] 폴더 없음: apr16736146 (모든 경로 검색 완료)
# ⚠️ [872] 폴더 없음: apr16736077 (모든 경로 검색 완료)
# ⚠️ [873] 폴더 없음: apr16730453 (모든 경로 검색 완료)
# ⚠️ [874] 폴더 없음: apr16731144 (모든 경로 검색 완료)
# ⚠️ [875] 폴더 없음: apr16731454 (모든 경로 검색 완료)
# ⚠️ [876] 폴더 없음: apr16735748 (모든 경로 검색 완료)
# ⚠️ [877] 폴더 없음: apr16747193 (모든 경로 검색 완료)
# ⚠️ [878] 폴더 없음: apr16757161 (모든 경로 검색 완료)
# ⚠️ [879] 폴더 없음: apr16757205 (모든 경로 검색 완료)
# ⚠️ [880] 폴더 없음: apr16757274 (모든 경로 검색 완료)
# ⚠️ [881] 폴더 없음: apr16758889 (모든 경로 검색 완료)
# ⚠️ [882] 폴더 없음: apr16761734 (모든 경로 검색 완료)
# ⚠️ [883] 폴더 없음: apr16752339 (모든 경로 검색 완료)
# ⚠️ [884] 폴더 없음: apr16756005 (모든 경로 검색 완료)
# ⚠️ [885] 폴더 없음: apr16764016 (모든 경로 검색 완료)
# ⚠️ [886] 폴더 없음: apr16762804 (모든 경로 검색 완료)
# ⚠️ [887] 폴더 없음: apr16773238 (모든 경로 검색 완료)
# ⚠️ [888] 폴더 없음: apr16773279 (모든 경로 검색 완료)
# ⚠️ [889] 폴더 없음: apr16772464 (모든 경로 검색 완료)
# ⚠️ [890] 폴더 없음: apr16776799 (모든 경로 검색 완료)
# ⚠️ [891] 폴더 없음: apr16776806 (모든 경로 검색 완료)
# ⚠️ [892] 폴더 없음: apr16776917 (모든 경로 검색 완료)
# ⚠️ [893] 폴더 없음: apr16777829 (모든 경로 검색 완료)
# ⚠️ [894] 폴더 없음: apr16771620 (모든 경로 검색 완료)
# ⚠️ [895] 폴더 없음: apr16772495 (모든 경로 검색 완료)
# ⚠️ [896] 폴더 없음: apr16780840 (모든 경로 검색 완료)
# ⚠️ [897] 폴더 없음: apr16780869 (모든 경로 검색 완료)
# ⚠️ [898] 폴더 없음: apr16784150 (모든 경로 검색 완료)
# ⚠️ [899] 폴더 없음: apr16780910 (모든 경로 검색 완료)
# ⚠️ [900] 폴더 없음: apr16782949 (모든 경로 검색 완료)
# ⚠️ [901] 폴더 없음: apr16782578 (모든 경로 검색 완료)
# ⚠️ [902] 폴더 없음: apr16779824 (모든 경로 검색 완료)
# ⚠️ [903] 폴더 없음: apr16782699 (모든 경로 검색 완료)
# ⚠️ [904] 폴더 없음: apr16783555 (모든 경로 검색 완료)
# ⚠️ [905] 폴더 없음: apr16784836 (모든 경로 검색 완료)
# ⚠️ [906] 폴더 없음: apr16788345 (모든 경로 검색 완료)
# ⚠️ [907] 폴더 없음: apr16790755 (모든 경로 검색 완료)
# ⚠️ [908] 폴더 없음: apr16790817 (모든 경로 검색 완료)
# ⚠️ [909] 폴더 없음: apr16790864 (모든 경로 검색 완료)
# ⚠️ [910] 폴더 없음: apr16796966 (모든 경로 검색 완료)
# ⚠️ [911] 폴더 없음: apr16792352 (모든 경로 검색 완료)
# ⚠️ [912] 폴더 없음: apr16798481 (모든 경로 검색 완료)
# ⚠️ [913] 폴더 없음: apr16804151 (모든 경로 검색 완료)
# ⚠️ [914] 폴더 없음: apr16804175 (모든 경로 검색 완료)
# ⚠️ [915] 폴더 없음: apr16804196 (모든 경로 검색 완료)
# ⚠️ [916] 폴더 없음: apr16804239 (모든 경로 검색 완료)
# ⚠️ [917] 폴더 없음: apr16806499 (모든 경로 검색 완료)
#
# 📄 [918] 문서ID: 16801287
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16801287
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr16801287
#    ✅ 이미지 3개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#    📊 복사 완료: 3/3개
#
# 📄 [919] 문서ID: 16804457
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr16804457
# ...
#
# 📄 [7924] 문서ID: 26153759
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26153759
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26153759
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [7925] 문서ID: 26153476
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26153476
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26153476
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [7926] 폴더 없음: apr26152734 (모든 경로 검색 완료)
# ⚠️ [7927] 폴더 없음: apr26151237 (모든 경로 검색 완료)
# ⚠️ [7928] 폴더 없음: apr26158071 (모든 경로 검색 완료)
# ⚠️ [7929] 폴더 없음: apr26157397 (모든 경로 검색 완료)
#
# 📄 [7930] 문서ID: 26161258
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26161258
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26161258
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [7931] 문서ID: 26162589
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26162589
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26162589
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [7932] 문서ID: 26161795
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26161795
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26161795
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [7933] 문서ID: 26162200
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26162200
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26162200
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [7934] 문서ID: 26161522
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26161522
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26161522
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [7935] 문서ID: 26161717
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26161717
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26161717
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [7936] 폴더 없음: apr26163747 (모든 경로 검색 완료)
# ⚠️ [7937] 폴더 없음: apr26162633 (모든 경로 검색 완료)
# ⚠️ [7938] 폴더 없음: apr26163450 (모든 경로 검색 완료)
# ⚠️ [7939] 폴더 없음: apr26163386 (모든 경로 검색 완료)
# ⚠️ [7940] 폴더 없음: apr26163837 (모든 경로 검색 완료)
# ⚠️ [7941] 폴더 없음: apr26157954 (모든 경로 검색 완료)
# ⚠️ [7942] 폴더 없음: apr26157963 (모든 경로 검색 완료)
# ⚠️ [7943] 폴더 없음: apr26163415 (모든 경로 검색 완료)
# ⚠️ [7944] 폴더 없음: apr26167025 (모든 경로 검색 완료)
# ⚠️ [7945] 폴더 없음: apr26165770 (모든 경로 검색 완료)
# ⚠️ [7946] 폴더 없음: apr26165794 (모든 경로 검색 완료)
# ⚠️ [7947] 폴더 없음: apr26166512 (모든 경로 검색 완료)
# ⚠️ [7948] 폴더 없음: apr26166535 (모든 경로 검색 완료)
# ⚠️ [7949] 폴더 없음: apr26168777 (모든 경로 검색 완료)
# ⚠️ [7950] 폴더 없음: apr26165460 (모든 경로 검색 완료)
# ⚠️ [7951] 폴더 없음: apr26167699 (모든 경로 검색 완료)
# ⚠️ [7952] 폴더 없음: apr26169192 (모든 경로 검색 완료)
# ⚠️ [7953] 폴더 없음: apr26170748 (모든 경로 검색 완료)
# ⚠️ [7954] 폴더 없음: apr26168019 (모든 경로 검색 완료)
# ⚠️ [7955] 폴더 없음: apr26172983 (모든 경로 검색 완료)
# ⚠️ [7956] 폴더 없음: apr26165856 (모든 경로 검색 완료)
# ⚠️ [7957] 폴더 없음: apr26178435 (모든 경로 검색 완료)
# ⚠️ [7958] 폴더 없음: apr26177881 (모든 경로 검색 완료)
#
# 📄 [7959] 문서ID: 26178012
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26178012
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26178012
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [7960] 폴더 없음: apr26177334 (모든 경로 검색 완료)
#
# 📄 [7961] 문서ID: 26177416
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26177416
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26177416
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [7962] 폴더 없음: apr26177475 (모든 경로 검색 완료)
# ⚠️ [7963] 폴더 없음: apr26177447 (모든 경로 검색 완료)
# ⚠️ [7964] 폴더 없음: apr26175783 (모든 경로 검색 완료)
# ⚠️ [7965] 폴더 없음: apr26175835 (모든 경로 검색 완료)
# ⚠️ [7966] 폴더 없음: apr26174137 (모든 경로 검색 완료)
# ⚠️ [7967] 폴더 없음: apr26181396 (모든 경로 검색 완료)
# ⚠️ [7968] 폴더 없음: apr26182431 (모든 경로 검색 완료)
# ⚠️ [7969] 폴더 없음: apr26188176 (모든 경로 검색 완료)
# ⚠️ [7970] 폴더 없음: apr26185393 (모든 경로 검색 완료)
# ⚠️ [7971] 폴더 없음: apr26186255 (모든 경로 검색 완료)
# ⚠️ [7972] 폴더 없음: apr26184923 (모든 경로 검색 완료)
# ⚠️ [7973] 폴더 없음: apr26195506 (모든 경로 검색 완료)
# ⚠️ [7974] 폴더 없음: apr26195539 (모든 경로 검색 완료)
# ⚠️ [7975] 폴더 없음: apr26197074 (모든 경로 검색 완료)
# ⚠️ [7976] 폴더 없음: apr26195958 (모든 경로 검색 완료)
# ⚠️ [7977] 폴더 없음: apr26197499 (모든 경로 검색 완료)
# ⚠️ [7978] 폴더 없음: apr26197946 (모든 경로 검색 완료)
# ⚠️ [7979] 폴더 없음: apr26207812 (모든 경로 검색 완료)
# ⚠️ [7980] 폴더 없음: apr26209452 (모든 경로 검색 완료)
# ⚠️ [7981] 폴더 없음: apr26206479 (모든 경로 검색 완료)
# ⚠️ [7982] 폴더 없음: apr26204142 (모든 경로 검색 완료)
# ⚠️ [7983] 폴더 없음: apr26203048 (모든 경로 검색 완료)
# ⚠️ [7984] 폴더 없음: apr26208172 (모든 경로 검색 완료)
# ⚠️ [7985] 폴더 없음: apr26206307 (모든 경로 검색 완료)
# ⚠️ [7986] 폴더 없음: apr26204849 (모든 경로 검색 완료)
# ⚠️ [7987] 폴더 없음: apr26202354 (모든 경로 검색 완료)
# ⚠️ [7988] 폴더 없음: apr26211312 (모든 경로 검색 완료)
# ⚠️ [7989] 폴더 없음: apr26216117 (모든 경로 검색 완료)
# ⚠️ [7990] 폴더 없음: apr26218847 (모든 경로 검색 완료)
# ⚠️ [7991] 폴더 없음: apr26216993 (모든 경로 검색 완료)
# ⚠️ [7992] 폴더 없음: apr26217025 (모든 경로 검색 완료)
# ⚠️ [7993] 폴더 없음: apr26217628 (모든 경로 검색 완료)
# ⚠️ [7994] 폴더 없음: apr26214220 (모든 경로 검색 완료)
# ⚠️ [7995] 폴더 없음: apr26216594 (모든 경로 검색 완료)
# ⚠️ [7996] 폴더 없음: apr26212848 (모든 경로 검색 완료)
# ⚠️ [7997] 폴더 없음: apr26223031 (모든 경로 검색 완료)
# ⚠️ [7998] 폴더 없음: apr26220701 (모든 경로 검색 완료)
# ⚠️ [7999] 폴더 없음: apr26221955 (모든 경로 검색 완료)
# ⚠️ [8000] 폴더 없음: apr26222545 (모든 경로 검색 완료)
# ⚠️ [8001] 폴더 없음: apr26222513 (모든 경로 검색 완료)
# ⚠️ [8002] 폴더 없음: apr26219870 (모든 경로 검색 완료)
# ⚠️ [8003] 폴더 없음: apr26235966 (모든 경로 검색 완료)
# ⚠️ [8004] 폴더 없음: apr26232813 (모든 경로 검색 완료)
# ⚠️ [8005] 폴더 없음: apr26235458 (모든 경로 검색 완료)
# ⚠️ [8006] 폴더 없음: apr26235482 (모든 경로 검색 완료)
#
# 📄 [8007] 문서ID: 26235605
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26235605
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26235605
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [8008] 문서ID: 26235180
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26235180
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26235180
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [8009] 문서ID: 26235524
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26235524
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26235524
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [8010] 문서ID: 26234982
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26234982
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26234982
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [8011] 폴더 없음: apr26234657 (모든 경로 검색 완료)
# ⚠️ [8012] 폴더 없음: apr26234839 (모든 경로 검색 완료)
# ⚠️ [8013] 폴더 없음: apr26235538 (모든 경로 검색 완료)
# ⚠️ [8014] 폴더 없음: apr26233237 (모든 경로 검색 완료)
# ⚠️ [8015] 폴더 없음: apr26235914 (모든 경로 검색 완료)
# ⚠️ [8016] 폴더 없음: apr26234341 (모든 경로 검색 완료)
# ⚠️ [8017] 폴더 없음: apr26238356 (모든 경로 검색 완료)
# ⚠️ [8018] 폴더 없음: apr26232749 (모든 경로 검색 완료)
# ⚠️ [8019] 폴더 없음: apr26233023 (모든 경로 검색 완료)
# ⚠️ [8020] 폴더 없음: apr26241814 (모든 경로 검색 완료)
# ⚠️ [8021] 폴더 없음: apr26241856 (모든 경로 검색 완료)
# ⚠️ [8022] 폴더 없음: apr26241882 (모든 경로 검색 완료)
# ⚠️ [8023] 폴더 없음: apr26241916 (모든 경로 검색 완료)
# ⚠️ [8024] 폴더 없음: apr26242570 (모든 경로 검색 완료)
# ⚠️ [8025] 폴더 없음: apr26241286 (모든 경로 검색 완료)
# ⚠️ [8026] 폴더 없음: apr26249113 (모든 경로 검색 완료)
# ⚠️ [8027] 폴더 없음: apr26241284 (모든 경로 검색 완료)
# ⚠️ [8028] 폴더 없음: apr26243999 (모든 경로 검색 완료)
# ⚠️ [8029] 폴더 없음: apr26246634 (모든 경로 검색 완료)
# ⚠️ [8030] 폴더 없음: apr26242072 (모든 경로 검색 완료)
# ⚠️ [8031] 폴더 없음: apr26241320 (모든 경로 검색 완료)
# ⚠️ [8032] 폴더 없음: apr26247401 (모든 경로 검색 완료)
# ⚠️ [8033] 폴더 없음: apr26249499 (모든 경로 검색 완료)
# ⚠️ [8034] 폴더 없음: apr26242729 (모든 경로 검색 완료)
# ⚠️ [8035] 폴더 없음: apr26241493 (모든 경로 검색 완료)
# ⚠️ [8036] 폴더 없음: apr26248067 (모든 경로 검색 완료)
# ⚠️ [8037] 폴더 없음: apr26243419 (모든 경로 검색 완료)
# ⚠️ [8038] 폴더 없음: apr26242079 (모든 경로 검색 완료)
# ⚠️ [8039] 폴더 없음: apr26246060 (모든 경로 검색 완료)
# ⚠️ [8040] 폴더 없음: apr26242819 (모든 경로 검색 완료)
# ⚠️ [8041] 폴더 없음: apr26252439 (모든 경로 검색 완료)
# ⚠️ [8042] 폴더 없음: apr26256336 (모든 경로 검색 완료)
# ⚠️ [8043] 폴더 없음: apr26258416 (모든 경로 검색 완료)
# ⚠️ [8044] 폴더 없음: apr26255832 (모든 경로 검색 완료)
# ⚠️ [8045] 폴더 없음: apr26255175 (모든 경로 검색 완료)
# ⚠️ [8046] 폴더 없음: apr26261113 (모든 경로 검색 완료)
# ⚠️ [8047] 폴더 없음: apr26262500 (모든 경로 검색 완료)
# ⚠️ [8048] 폴더 없음: apr26252923 (모든 경로 검색 완료)
# ⚠️ [8049] 폴더 없음: apr26252599 (모든 경로 검색 완료)
# ⚠️ [8050] 폴더 없음: apr26257774 (모든 경로 검색 완료)
# ⚠️ [8051] 폴더 없음: apr26261770 (모든 경로 검색 완료)
# ⚠️ [8052] 폴더 없음: apr26256911 (모든 경로 검색 완료)
# ⚠️ [8053] 폴더 없음: apr26260829 (모든 경로 검색 완료)
# ⚠️ [8054] 폴더 없음: apr26252988 (모든 경로 검색 완료)
# ⚠️ [8055] 폴더 없음: apr26253484 (모든 경로 검색 완료)
# ⚠️ [8056] 폴더 없음: apr26259211 (모든 경로 검색 완료)
# ⚠️ [8057] 폴더 없음: apr26260949 (모든 경로 검색 완료)
# ⚠️ [8058] 폴더 없음: apr26256484 (모든 경로 검색 완료)
# ⚠️ [8059] 폴더 없음: apr26260799 (모든 경로 검색 완료)
# ⚠️ [8060] 폴더 없음: apr26273095 (모든 경로 검색 완료)
# ⚠️ [8061] 폴더 없음: apr26269665 (모든 경로 검색 완료)
# ⚠️ [8062] 폴더 없음: apr26270669 (모든 경로 검색 완료)
# ⚠️ [8063] 폴더 없음: apr26272462 (모든 경로 검색 완료)
#
# 📄 [8064] 문서ID: 26270327
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26270327
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26270327
#    ✅ 이미지 3개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#    📊 복사 완료: 3/3개
# ⚠️ [8065] 폴더 없음: apr26271945 (모든 경로 검색 완료)
# ⚠️ [8066] 폴더 없음: apr26269002 (모든 경로 검색 완료)
# ⚠️ [8067] 폴더 없음: apr26273212 (모든 경로 검색 완료)
# ⚠️ [8068] 폴더 없음: apr26274723 (모든 경로 검색 완료)
# ⚠️ [8069] 폴더 없음: apr26273064 (모든 경로 검색 완료)
# ⚠️ [8070] 폴더 없음: apr26266664 (모든 경로 검색 완료)
# ⚠️ [8071] 폴더 없음: apr26273417 (모든 경로 검색 완료)
# ⚠️ [8072] 폴더 없음: apr26273409 (모든 경로 검색 완료)
# ⚠️ [8073] 폴더 없음: apr26278490 (모든 경로 검색 완료)
# ⚠️ [8074] 폴더 없음: apr26282874 (모든 경로 검색 완료)
# ⚠️ [8075] 폴더 없음: apr26282890 (모든 경로 검색 완료)
# ⚠️ [8076] 폴더 없음: apr26280317 (모든 경로 검색 완료)
# ⚠️ [8077] 폴더 없음: apr26288190 (모든 경로 검색 완료)
# ⚠️ [8078] 폴더 없음: apr26292290 (모든 경로 검색 완료)
#
# 📄 [8079] 문서ID: 26294261
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26294261
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26294261
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [8080] 폴더 없음: apr26291955 (모든 경로 검색 완료)
# ⚠️ [8081] 폴더 없음: apr26307756 (모든 경로 검색 완료)
# ⚠️ [8082] 폴더 없음: apr26302267 (모든 경로 검색 완료)
# ⚠️ [8083] 폴더 없음: apr26305944 (모든 경로 검색 완료)
# ⚠️ [8084] 폴더 없음: apr26302052 (모든 경로 검색 완료)
# ⚠️ [8085] 폴더 없음: apr26302742 (모든 경로 검색 완료)
# ⚠️ [8086] 폴더 없음: apr26302211 (모든 경로 검색 완료)
# ⚠️ [8087] 폴더 없음: apr26300325 (모든 경로 검색 완료)
# ⚠️ [8088] 폴더 없음: apr26300301 (모든 경로 검색 완료)
# ⚠️ [8089] 폴더 없음: apr26317968 (모든 경로 검색 완료)
# ⚠️ [8090] 폴더 없음: apr26310393 (모든 경로 검색 완료)
# ⚠️ [8091] 폴더 없음: apr26312747 (모든 경로 검색 완료)
# ⚠️ [8092] 폴더 없음: apr26315116 (모든 경로 검색 완료)
# ⚠️ [8093] 폴더 없음: apr26313613 (모든 경로 검색 완료)
# ⚠️ [8094] 폴더 없음: apr26313340 (모든 경로 검색 완료)
# ⚠️ [8095] 폴더 없음: apr26322481 (모든 경로 검색 완료)
# ⚠️ [8096] 폴더 없음: apr26322351 (모든 경로 검색 완료)
# ⚠️ [8097] 폴더 없음: apr26319584 (모든 경로 검색 완료)
# ⚠️ [8098] 폴더 없음: apr26327041 (모든 경로 검색 완료)
# ⚠️ [8099] 폴더 없음: apr26329166 (모든 경로 검색 완료)
# ⚠️ [8100] 폴더 없음: apr26329187 (모든 경로 검색 완료)
# ⚠️ [8101] 폴더 없음: apr26330129 (모든 경로 검색 완료)
# ⚠️ [8102] 폴더 없음: apr26330079 (모든 경로 검색 완료)
# ⚠️ [8103] 폴더 없음: apr26329168 (모든 경로 검색 완료)
#
# 📄 [8104] 문서ID: 26332959
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26332959
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26332959
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [8105] 폴더 없음: apr26328382 (모든 경로 검색 완료)
# ⚠️ [8106] 폴더 없음: apr26329871 (모든 경로 검색 완료)
# ⚠️ [8107] 폴더 없음: apr26328007 (모든 경로 검색 완료)
# ⚠️ [8108] 폴더 없음: apr26328028 (모든 경로 검색 완료)
# ⚠️ [8109] 폴더 없음: apr26336187 (모든 경로 검색 완료)
# ⚠️ [8110] 폴더 없음: apr26337020 (모든 경로 검색 완료)
# ⚠️ [8111] 폴더 없음: apr26344398 (모든 경로 검색 완료)
#
# 📄 [8112] 문서ID: 26342715
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26342715
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26342715
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [8113] 문서ID: 26342951
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26342951
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26342951
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [8114] 문서ID: 26343185
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26343185
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26343185
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [8115] 문서ID: 26343397
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26343397
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26343397
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [8116] 문서ID: 26342824
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26342824
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26342824
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [8117] 문서ID: 26343084
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26343084
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26343084
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [8118] 폴더 없음: apr26343687 (모든 경로 검색 완료)
# ⚠️ [8119] 폴더 없음: apr26337844 (모든 경로 검색 완료)
# ⚠️ [8120] 폴더 없음: apr26338607 (모든 경로 검색 완료)
# ⚠️ [8121] 폴더 없음: apr26339547 (모든 경로 검색 완료)
# ⚠️ [8122] 폴더 없음: apr26349251 (모든 경로 검색 완료)
# ⚠️ [8123] 폴더 없음: apr26352776 (모든 경로 검색 완료)
#
# 📄 [8124] 문서ID: 26352114
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor\apr26352114
#    복사: C:\Users\LEEJUHWAN\Downloads\approval_2025_img\apr26352114
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [8125] 폴더 없음: apr26352029 (모든 경로 검색 완료)
# ⚠️ [8126] 폴더 없음: apr26352187 (모든 경로 검색 완료)
# ⚠️ [8127] 폴더 없음: apr26350336 (모든 경로 검색 완료)
# ⚠️ [8128] 폴더 없음: apr26348387 (모든 경로 검색 완료)
# ⚠️ [8129] 폴더 없음: apr26349404 (모든 경로 검색 완료)
# ⚠️ [8130] 폴더 없음: apr26352223 (모든 경로 검색 완료)
# ⚠️ [8131] 폴더 없음: apr26349877 (모든 경로 검색 완료)
# ⚠️ [8132] 폴더 없음: apr26347874 (모든 경로 검색 완료)
# ⚠️ [8133] 폴더 없음: apr26353974 (모든 경로 검색 완료)
# ⚠️ [8134] 폴더 없음: apr26348466 (모든 경로 검색 완료)
# ⚠️ [8135] 폴더 없음: apr26362912 (모든 경로 검색 완료)
# ⚠️ [8136] 폴더 없음: apr26360477 (모든 경로 검색 완료)
# ⚠️ [8137] 폴더 없음: apr26361165 (모든 경로 검색 완료)
# ⚠️ [8138] 폴더 없음: apr26362273 (모든 경로 검색 완료)
# ⚠️ [8139] 폴더 없음: apr26369146 (모든 경로 검색 완료)
# ⚠️ [8140] 폴더 없음: apr26365219 (모든 경로 검색 완료)
# ⚠️ [8141] 폴더 없음: apr26370939 (모든 경로 검색 완료)
# ⚠️ [8142] 폴더 없음: apr26367271 (모든 경로 검색 완료)
# ⚠️ [8143] 폴더 없음: apr26371563 (모든 경로 검색 완료)
# ⚠️ [8144] 폴더 없음: apr26375598 (모든 경로 검색 완료)
# ⚠️ [8145] 폴더 없음: apr26376310 (모든 경로 검색 완료)
# ⚠️ [8146] 폴더 없음: apr26376738 (모든 경로 검색 완료)
# ⚠️ [8147] 폴더 없음: apr26374932 (모든 경로 검색 완료)
# ⚠️ [8148] 폴더 없음: apr26373770 (모든 경로 검색 완료)
# ⚠️ [8149] 폴더 없음: apr26373581 (모든 경로 검색 완료)
# ⚠️ [8150] 폴더 없음: apr26381761 (모든 경로 검색 완료)
# ⚠️ [8151] 폴더 없음: apr26387592 (모든 경로 검색 완료)
# ⚠️ [8152] 폴더 없음: apr26383540 (모든 경로 검색 완료)
# ⚠️ [8153] 폴더 없음: apr26384640 (모든 경로 검색 완료)
# ⚠️ [8154] 폴더 없음: apr26383472 (모든 경로 검색 완료)
# ⚠️ [8155] 폴더 없음: apr26382907 (모든 경로 검색 완료)
# ⚠️ [8156] 폴더 없음: apr26393516 (모든 경로 검색 완료)
# ⚠️ [8157] 폴더 없음: apr26393540 (모든 경로 검색 완료)
# ⚠️ [8158] 폴더 없음: apr26393568 (모든 경로 검색 완료)
# ⚠️ [8159] 폴더 없음: apr26397080 (모든 경로 검색 완료)
# ⚠️ [8160] 폴더 없음: apr26392919 (모든 경로 검색 완료)
# ⚠️ [8161] 폴더 없음: apr26394835 (모든 경로 검색 완료)
# ⚠️ [8162] 폴더 없음: apr26394912 (모든 경로 검색 완료)
# ⚠️ [8163] 폴더 없음: apr26395343 (모든 경로 검색 완료)
# ⚠️ [8164] 폴더 없음: apr26394789 (모든 경로 검색 완료)
# ⚠️ [8165] 폴더 없음: apr26405557 (모든 경로 검색 완료)
# ⚠️ [8166] 폴더 없음: apr26402005 (모든 경로 검색 완료)
# ⚠️ [8167] 폴더 없음: apr26418339 (모든 경로 검색 완료)
# ⚠️ [8168] 폴더 없음: apr26412980 (모든 경로 검색 완료)
# ⚠️ [8169] 폴더 없음: apr26412997 (모든 경로 검색 완료)
# ⚠️ [8170] 폴더 없음: apr26415193 (모든 경로 검색 완료)
# ⚠️ [8171] 폴더 없음: apr26412538 (모든 경로 검색 완료)
# ⚠️ [8172] 폴더 없음: apr26413296 (모든 경로 검색 완료)
# ⚠️ [8173] 폴더 없음: apr26415581 (모든 경로 검색 완료)
# ⚠️ [8174] 폴더 없음: apr26418857 (모든 경로 검색 완료)
# ⚠️ [8175] 폴더 없음: apr26418663 (모든 경로 검색 완료)
#
# ============================================================
# ✅ 처리 완료!
#    - 종료연도: 2025
#    - 처리된 documents: 472/8175개
#    - 복사된 이미지 위치: C:\Users\LEEJUHWAN\Downloads\approval_2025_img
#    - DB 테이블: documents (doc_body 컬럼 업데이트)
# ============================================================
#
# ✅ DB 연결 종료
